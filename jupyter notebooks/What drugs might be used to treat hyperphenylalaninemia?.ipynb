# %%
# import modules from biothings_explorer
from biothings_explorer.hint import Hint
from biothings_explorer.user_query_dispatcher import FindConnection

# %% [markdown]
# **Hint** module: Find corresponding bio-entity representation used in BioThings Explorer based on user input (could be any database IDs, symbols, names)
#
# **FindConnection** module: Find intermediate bio-entities which connects user specified input and output

# %% [markdown]
# ## Step 1: Find representation of "hyperphenylalaninemia" in BTE

# %%
ht = Hint()
# find all potential representations of hyperphenylalaninemia
hyperphenylalaninemia_hint = ht.query("hyperphenylalaninemia")
# select the correct representation of hyperphenylalaninemia
hyperphenylalaninemia = hyperphenylalaninemia_hint['DiseaseOrPhenotypicFeature'][0]
hyperphenylalaninemia
# Out:
# {'mondo': 'MONDO:0016543',
#  'umls': 'C0751435',
#  'name': 'hyperphenylalaninemia',
#  'display': 'mondo(MONDO:0016543) umls(C0751435) name(hyperphenylalaninemia) ',
#  'type': 'DiseaseOrPhenotypicFeature',
#  'primary': {'identifier': 'mondo',
#   'cls': 'DiseaseOrPhenotypicFeature',
#   'value': 'MONDO:0016543'}}

# %% [markdown]
# ## Step 2: Find drugs that are associated with genes which invovled in hyperphenylalaninemia

# %%
help(FindConnection.__init__)
# Out:
# Help on function __init__ in module biothings_explorer.user_query_dispatcher:
#
# __init__(self, input_obj, output_obj, intermediate_nodes, registry=None)
#     Find relationships in the Knowledge Graph between an Input Object and an Output Object.
#
#     params
#     ------
#     input_obj (required): must be an object returned from Hint corresponding to a specific biomedical entity.
#                           Examples:
#             Hint().query("Fanconi anemia")['DiseaseOrPhenotypicFeature'][0]
#             Hint().query("acetaminophen")['ChemicalSubstance'][0]
#
#     output_obj (required): must EITHER be an object returned from Hint corresponding to a specific biomedical
#                            entity, OR be a string or list of strings corresponding to Biolink Entity classes.
#                            Examples:
#             Hint().query("acetaminophen")['ChemicalSubstance'][0]
#             'Gene'
#             ['Gene','ChemicalSubstance']
#
#     intermediate_nodes (required): the semantic type(s) of the intermediate node(s).  Examples:
#             None                         : no intermediate node, find direct connections only
#             []                           : no intermediate node, find direct connections only
#             ['BiologicalEntity']         : one intermediate node of any semantic type
#             ['Gene']                     : one intermediate node that must be a Gene
#             [('Gene','Pathway')]         : one intermediate node that must be a Gene or a Pathway
#             ['Gene','Pathway']           : two intermediate nodes, first must be a Gene, second must be a Pathway.
#             ['Gene',('Pathway','Gene')]  : two intermediate nodes, first must be a Gene, second must be a Pathway or Gene.
#                                               **NOTE**: queries with more than one intermediate node are currently not supported

# %%
fc = FindConnection(input_obj=hyperphenylalaninemia, output_obj='ChemicalSubstance', intermediate_nodes=['Gene'])

# %%
fc.connect(verbose=True)
# Out:
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'hyperphenylalaninemia' and 'ChemicalSubstance'. Paths will have 1 intermediate node.
#
# Intermediate node #1 will have these type constraints: Gene
#
#
#
#
# ========== QUERY #1 -- fetch all Gene entities linked to hyperphenylalaninemia ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because hyperphenylalaninemia is of type 'DiseaseOrPhenotypicFeature', BTE will query our meta-KG for APIs that can take 'DiseaseOrPhenotypicFeature' as input
#
# BTE found 3 apis:
#
# API 1. biolink_disease2gene(1 API call)
# API 2. mydisease.info(1 API call)
# API 3. semmeddisease(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 2.1: http://mydisease.info/v1/query (POST "q=C0751435,C0751436&scopes=mondo.xrefs.umls,disgenet.xrefs.umls&fields=disgenet.genes_related_to_disease&species=human&size=100")
# API 3.1: http://pending.biothings.io/semmed/query (POST "q=C0751435,C0751436&scopes=umls&fields=AFFECTS.protein,ASSOCIATED_WITH.gene,CAUSES_reverse.gene,AFFECTS_reverse.gene,AFFECTS.gene,AFFECTS_reverse.protein&species=human&size=100")
# API 1.1: https://api.monarchinitiative.org/api/bioentity/disease/MONDO:0016543/genes?rows=100
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 biolink_disease2gene: 4 hits
# API 2.1 mydisease.info: 10 hits
# API 3.1 semmeddisease: 11 hits
#
# After id-to-object translation, BTE retrieved 12 unique objects.
#
#
# ========== QUERY #2 -- fetch all ChemicalSubstance entities linked to Gene entities ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because the inputs is of type 'Gene', BTE will query our meta-KG for APIs that can take 'Gene' as input
#
# BTE found 3 apis:
#
# API 1. dgidb_gene2chemical(9 API calls)
# API 2. semmedgene(1 API call)
# API 3. mychem.info(3 API calls)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 3.2: http://www.dgidb.org/api/v2/interactions.json?genes=GCH1
# API 3.3: http://www.dgidb.org/api/v2/interactions.json?genes=HAL
# API 3.5: http://www.dgidb.org/api/v2/interactions.json?genes=PTS
# API 3.1: http://www.dgidb.org/api/v2/interactions.json?genes=PCBD1
# API 3.4: http://www.dgidb.org/api/v2/interactions.json?genes=CACNA1A
# API 3.6: http://www.dgidb.org/api/v2/interactions.json?genes=QDPR
# API 1.1: http://mychem.info/v1/query (POST "q=PCBD1,GCH1,HAL,CACNA1A,PTS,QDPR,PAH,HSPA4,AKR1B10&scopes=drugbank.enzymes.gene_name&fields=drugbank.id&species=human&size=100")
# API 3.9: http://www.dgidb.org/api/v2/interactions.json?genes=AKR1B10
# API 3.8: http://www.dgidb.org/api/v2/interactions.json?genes=HSPA4
# API 3.7: http://www.dgidb.org/api/v2/interactions.json?genes=PAH
# API 1.2: http://mychem.info/v1/query (POST "q=PCBD1,GCH1,HAL,CACNA1A,PTS,QDPR,PAH,HSPA4,AKR1B10&scopes=drugbank.targets.gene_name&fields=drugbank.id&species=human&size=100")
# API 1.3: http://mychem.info/v1/query (POST "q=PCBD1,GCH1,HAL,CACNA1A,PTS,QDPR,PAH,HSPA4,AKR1B10&scopes=drugcentral.bioactivity.uniprot.gene_symbol&fields=chembl.molecule_chembl_id&species=human&size=100")
# API 2.1: https://pending.biothings.io/semmedgene/query (POST "q=C1412323,C1415465,C1415760,C1419129,C0017337,C1456413,C1415012,C1419182,C1418251,C1418296,C0017361&scopes=umls&fields=affects.chemical_substance,interacts_with.chemical_substance,interacts_with_reverse.chemical_substance,associated_with_reverse.chemical_substance,affects_reverse.chemical_substance,associated_with.chemical_substance&species=human&size=100")
#
#
# ==== Step #3: Output normalization ====
#
# API 3.1 dgidb_gene2chemical: 1 hits
# API 3.2 dgidb_gene2chemical: 1 hits
# API 3.3 dgidb_gene2chemical: 1 hits
# API 3.4 dgidb_gene2chemical: 11 hits
# API 3.5 dgidb_gene2chemical: No hits
# API 3.6 dgidb_gene2chemical: 1 hits
# API 3.7 dgidb_gene2chemical: 8 hits
# API 3.8 dgidb_gene2chemical: 35 hits
# API 3.9 dgidb_gene2chemical: 3 hits
# API 1.1 mychem.info: 2 hits
# API 1.2 mychem.info: 27 hits
# API 1.3 mychem.info: 11 hits
# API 2.1 semmedgene: 3700 hits
#
# After id-to-object translation, BTE retrieved 2545 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# In the #1 query, BTE found 12 unique Gene nodes
# In the #2 query, BTE found 2545 unique ChemicalSubstance nodes

# %% [markdown]
# ## Step 3: Display and Filter results

# %%
df = fc.display_table_view()

# %%
df
# Out:
#                       input                  input_type           pred1  \
# 0     hyperphenylalaninemia  DiseaseOrPhenotypicFeature        causedBy
# 1     hyperphenylalaninemia  DiseaseOrPhenotypicFeature        causedBy
# 2     hyperphenylalaninemia  DiseaseOrPhenotypicFeature        causedBy
# 3     hyperphenylalaninemia  DiseaseOrPhenotypicFeature        causedBy
# 4     hyperphenylalaninemia  DiseaseOrPhenotypicFeature        causedBy
# ...                     ...                         ...             ...
# 1077  hyperphenylalaninemia  DiseaseOrPhenotypicFeature  associatedWith
# 1078  hyperphenylalaninemia  DiseaseOrPhenotypicFeature  associatedWith
# 1079  hyperphenylalaninemia  DiseaseOrPhenotypicFeature  associatedWith
# 1080  hyperphenylalaninemia  DiseaseOrPhenotypicFeature        causedBy
# 1081  hyperphenylalaninemia  DiseaseOrPhenotypicFeature        causedBy
#
#      pred1_source             pred1_api pred1_pubmed     node1_id node1_name  \
# 0          semmed         semmeddisease               entrez:3308      HSPA4
# 1          semmed         semmeddisease               entrez:3308      HSPA4
# 2          semmed         semmeddisease               entrez:3308      HSPA4
# 3          semmed         semmeddisease               entrez:3308      HSPA4
# 4          semmed         semmeddisease               entrez:3308      HSPA4
# ...           ...                   ...          ...          ...        ...
# 1077      biolink  biolink_disease2gene               entrez:5805        PTS
# 1078     disgenet        mydisease.info         None  entrez:5805        PTS
# 1079     disgenet        mydisease.info         None  entrez:5805        PTS
# 1080       semmed         semmeddisease               entrez:5805        PTS
# 1081       semmed         semmeddisease               entrez:3308      HSPA4
#
#      node1_type                     pred2 pred2_source            pred2_api  \
# 0          Gene  molecularlyInteractsWith       semmed           semmedgene
# 1          Gene                targetedBy        dgidb  dgidb_gene2chemical
# 2          Gene  molecularlyInteractsWith       semmed           semmedgene
# 3          Gene  molecularlyInteractsWith       semmed           semmedgene
# 4          Gene  molecularlyInteractsWith       semmed           semmedgene
# ...         ...                       ...          ...                  ...
# 1077       Gene  molecularlyInteractsWith       semmed           semmedgene
# 1078       Gene  molecularlyInteractsWith       semmed           semmedgene
# 1079       Gene  molecularlyInteractsWith       semmed           semmedgene
# 1080       Gene  molecularlyInteractsWith       semmed           semmedgene
# 1081       Gene  molecularlyInteractsWith       semmed           semmedgene
#
#      pred2_pubmed            output_id   output_name        output_type
# 0                     chembl:CHEMBL135     ESTRADIOL  ChemicalSubstance
# 1            None  chembl:CHEMBL276832   HYDRALAZINE  ChemicalSubstance
# 2                     chembl:CHEMBL131  PREDNISOLONE  ChemicalSubstance
# 3                        umls:C0014417          None  ChemicalSubstance
# 4                        umls:C0142812          None  ChemicalSubstance
# ...           ...                  ...           ...                ...
# 1077                     umls:C0684179          None  ChemicalSubstance
# 1078                     umls:C0684179          None  ChemicalSubstance
# 1079                     umls:C0684179          None  ChemicalSubstance
# 1080                     umls:C0684179          None  ChemicalSubstance
# 1081                     umls:C0006632          None  ChemicalSubstance
#
# [1082 rows x 16 columns]

# %%
df[df['pred1'] == 'causedBy']
# Out:
#                       input                  input_type     pred1  \
# 0     hyperphenylalaninemia  DiseaseOrPhenotypicFeature  causedBy
# 1     hyperphenylalaninemia  DiseaseOrPhenotypicFeature  causedBy
# 2     hyperphenylalaninemia  DiseaseOrPhenotypicFeature  causedBy
# 3     hyperphenylalaninemia  DiseaseOrPhenotypicFeature  causedBy
# 4     hyperphenylalaninemia  DiseaseOrPhenotypicFeature  causedBy
# ...                     ...                         ...       ...
# 1072  hyperphenylalaninemia  DiseaseOrPhenotypicFeature  causedBy
# 1075  hyperphenylalaninemia  DiseaseOrPhenotypicFeature  causedBy
# 1076  hyperphenylalaninemia  DiseaseOrPhenotypicFeature  causedBy
# 1080  hyperphenylalaninemia  DiseaseOrPhenotypicFeature  causedBy
# 1081  hyperphenylalaninemia  DiseaseOrPhenotypicFeature  causedBy
#
#      pred1_source      pred1_api pred1_pubmed     node1_id node1_name  \
# 0          semmed  semmeddisease               entrez:3308      HSPA4
# 1          semmed  semmeddisease               entrez:3308      HSPA4
# 2          semmed  semmeddisease               entrez:3308      HSPA4
# 3          semmed  semmeddisease               entrez:3308      HSPA4
# 4          semmed  semmeddisease               entrez:3308      HSPA4
# ...           ...            ...          ...          ...        ...
# 1072       semmed  semmeddisease               entrez:3308      HSPA4
# 1075       semmed  semmeddisease               entrez:5053        PAH
# 1076       semmed  semmeddisease               entrez:5053        PAH
# 1080       semmed  semmeddisease               entrez:5805        PTS
# 1081       semmed  semmeddisease               entrez:3308      HSPA4
#
#      node1_type                     pred2 pred2_source            pred2_api  \
# 0          Gene  molecularlyInteractsWith       semmed           semmedgene
# 1          Gene                targetedBy        dgidb  dgidb_gene2chemical
# 2          Gene  molecularlyInteractsWith       semmed           semmedgene
# 3          Gene  molecularlyInteractsWith       semmed           semmedgene
# 4          Gene  molecularlyInteractsWith       semmed           semmedgene
# ...         ...                       ...          ...                  ...
# 1072       Gene  molecularlyInteractsWith       semmed           semmedgene
# 1075       Gene  molecularlyInteractsWith       semmed           semmedgene
# 1076       Gene  molecularlyInteractsWith       semmed           semmedgene
# 1080       Gene  molecularlyInteractsWith       semmed           semmedgene
# 1081       Gene  molecularlyInteractsWith       semmed           semmedgene
#
#      pred2_pubmed            output_id   output_name        output_type
# 0                     chembl:CHEMBL135     ESTRADIOL  ChemicalSubstance
# 1            None  chembl:CHEMBL276832   HYDRALAZINE  ChemicalSubstance
# 2                     chembl:CHEMBL131  PREDNISOLONE  ChemicalSubstance
# 3                        umls:C0014417          None  ChemicalSubstance
# 4                        umls:C0142812          None  ChemicalSubstance
# ...           ...                  ...           ...                ...
# 1072                  chembl:CHEMBL405   AMPHETAMINE  ChemicalSubstance
# 1075                   chembl:CHEMBL59      DOPAMINE  ChemicalSubstance
# 1076                   chembl:CHEMBL59      DOPAMINE  ChemicalSubstance
# 1080                     umls:C0684179          None  ChemicalSubstance
# 1081                     umls:C0006632          None  ChemicalSubstance
#
# [624 rows x 16 columns]
