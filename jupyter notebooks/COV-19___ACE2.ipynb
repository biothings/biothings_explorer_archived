# %%
from biothings_explorer.user_query_dispatcher import FindConnection
from biothings_explorer.hint import Hint
ht = Hint()

# %%
ace2 = ht.query("ACE2")['Gene'][0]

# %%
fc = FindConnection(input_obj=ace2, output_obj='ChemicalSubstance', intermediate_nodes=['BiologicalEntity'])
fc.connect(verbose=True)
# Out:
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'ACE2' and 'ChemicalSubstance'.                   Paths will have 1 intermediate node.
#
# Intermediate node #1 will have these type constraints: BiologicalEntity
#
#
#
# ========== QUERY #1 -- fetch all Biological Entities linked to ACE2 ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because ACE2 is of type 'Gene', BTE will query our meta-KG for APIs that can take 'Gene' as input and                   'None' as output
#
# BTE found 18 apis:
#
# API 1. biolink_gene2disease(1 API call)
# API 2. biolink_geneinteraction(1 API call)
# API 3. biolink_gene2anatomy(1 API call)
# API 4. mygene.info(4 API calls)
# API 5. DISEASES(1 API call)
# API 6. mychem.info(3 API calls)
# API 7. mydisease.info(1 API call)
# API 8. myvariant.info(1 API call)
# API 9. robokop_gene2chemical(1 API call)
# API 10. ebigene2phenotype(1 API call)
# API 11. pfocr(1 API call)
# API 12. robokop_gene2genefamily(1 API call)
# API 13. semmedgene(11 API calls)
# API 14. ctd_gene2disease(1 API call)
# API 15. opentarget(1 API call)
# API 16. dgidb_gene2chemical(1 API call)
# API 17. biolink_gene2phenotype(1 API call)
# API 18. semmeddisease(7 API calls)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 4.1: http://mygene.info/v3/query (POST "q=ENSG00000130234&scopes=ensembl.gene&fields=ensembl.protein,ensembl.transcript,uniprot.Swiss-Prot&species=human&size=100")
# API 6.1: http://mychem.info/v1/query (POST "q=ACE2&scopes=drugbank.enzymes.gene_name&fields=drugbank.id&species=human&size=100")
# API 4.2: http://mygene.info/v3/query (POST "q=59272&scopes=entrezgene&fields=pantherdb.ortholog.Ensembl,go.CC.id,pantherdb.ortholog.TAIR,pantherdb.ortholog.FlyBase,go.MF.id,pantherdb.ortholog.PomBase,pantherdb.ortholog.dictyBase,pantherdb.ortholog.ZFIN,pantherdb.ortholog.HGNC,pantherdb.ortholog.RGD,pantherdb.ortholog.SGD,pathway.wikipathways.id,pathway.reactome.id,go.BP.id,pantherdb.ortholog.MGI&species=human&size=100")
# API 6.3: http://mychem.info/v1/query (POST "q=ACE2&scopes=drugcentral.bioactivity.uniprot.gene_symbol&fields=chembl.molecule_chembl_id&species=human&size=100")
# API 6.2: http://mychem.info/v1/query (POST "q=ACE2&scopes=drugbank.targets.gene_name&fields=drugbank.id&species=human&size=100")
# API 4.4: http://mygene.info/v3/query (POST "q=13557&scopes=pantherdb.ortholog.HGNC&fields=entrezgene&species=human&size=100")
# API 4.3: http://mygene.info/v3/query (POST "q=ENSG00000130234&scopes=pantherdb.ortholog.Ensembl&fields=entrezgene&species=human&size=100")
# API 7.1: http://mydisease.info/v1/query (POST "q=59272&scopes=disgenet.genes_related_to_disease.gene_id&fields=mondo.xrefs.umls,disgenet.xrefs.umls&species=human&size=100")
# API 16.1: http://www.dgidb.org/api/v2/interactions.json?genes=ACE2
# API 15.1: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000130234&datasource=chembl&size=15&fields=drug
# API 8.1: http://myvariant.info/v1/query (POST "q=59272&scopes=dbsnp.gene.geneid&fields=dbsnp.rsid&species=human&size=100")
# API 18.3: http://pending.biothings.io/semmed/query (POST "q=C1422064&scopes=AFFECTS_reverse.gene.umls&fields=umls&species=human&size=100")
# API 18.4: http://pending.biothings.io/semmed/query (POST "q=C1422064&scopes=AFFECTS_reverse.protein.umls&fields=umls&species=human&size=100")
# API 18.2: http://pending.biothings.io/semmed/query (POST "q=C1422064&scopes=AFFECTS.protein.umls&fields=umls&species=human&size=100")
# API 18.1: http://pending.biothings.io/semmed/query (POST "q=C1422064&scopes=AFFECTS.gene.umls&fields=umls&species=human&size=100")
# API 3.1: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:59272/anatomy?rows=100
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html'
# biolink_gene2anatomy failed
# API 17.1: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:59272/phenotypes?rows=100
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html'
# biolink_gene2phenotype failed
# API 2.1: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:59272/interactions?rows=100
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html'
# biolink_geneinteraction failed
# API 1.1: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:59272/diseases?rows=100
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html'
# biolink_gene2disease failed
# API 18.6: http://pending.biothings.io/semmed/query (POST "q=C1422064&scopes=ASSOCIATED_WITH_reverse.gene.umls&fields=umls&species=human&size=100")
# API 18.7: http://pending.biothings.io/semmed/query (POST "q=C1422064&scopes=CAUSES_reverse.gene.umls&fields=umls&species=human&size=100")
# API 18.5: http://pending.biothings.io/semmed/query (POST "q=C1422064&scopes=ASSOCIATED_WITH.gene.umls&fields=umls&species=human&size=100")
# API 13.3: https://pending.biothings.io/semmedgene/query (POST "q=C1422064&scopes=associated_with.gene.umls&fields=umls&species=human&size=100")
# API 13.5: https://pending.biothings.io/semmedgene/query (POST "q=C1422064&scopes=disrupts.protein.umls&fields=umls&species=human&size=100")
# API 13.2: https://pending.biothings.io/semmedgene/query (POST "q=C1422064&scopes=affects.protein.umls&fields=umls&species=human&size=100")
# API 13.4: https://pending.biothings.io/semmedgene/query (POST "q=C1422064&scopes=disrupts.gene.umls&fields=umls&species=human&size=100")
# API 13.6: https://pending.biothings.io/semmedgene/query (POST "q=C1422064&scopes=inhibits.gene.umls&fields=umls&species=human&size=100")
# API 13.9: https://pending.biothings.io/semmedgene/query (POST "q=C1422064&scopes=interacts_with.protein.umls&fields=umls&species=human&size=100")
# API 13.7: https://pending.biothings.io/semmedgene/query (POST "q=C1422064&scopes=inhibits.protein.umls&fields=umls&species=human&size=100")
# API 13.1: https://pending.biothings.io/semmedgene/query (POST "q=C1422064&scopes=affects.gene.umls&fields=umls&species=human&size=100")
# API 13.8: https://pending.biothings.io/semmedgene/query (POST "q=C1422064&scopes=interacts_with.gene.umls&fields=umls&species=human&size=100")
# API 13.11: https://pending.biothings.io/semmedgene/query (POST "q=C1422064&scopes=umls&fields=stimulates.protein.umls,disrupts.cell.umls,affects.phenotypic_feature.umls,affects.anatomical_entity.umls,inhibits.biological_process_or_activity.umls,interacts_with.gene.umls,associated_with.anatomical_entity.umls,associated_with.cell.umls,affects.cell_component.umls,inhibits.cell_component.umls,associated_with_reverse.anatomical_entity.umls,affects_reverse.cell_component.umls,affects_reverse.cell.umls,stimulates.anatomical_entity.umls,affects.cell.umls,inhibits.phenotypic_feature.umls,interacts_with.protein.umls,disrupts.phenotypic_feature.umls,associated_with.gene.umls,interacts_with.cell_component.umls,affects_reverse.biological_process_or_activity.umls,interacts_with.biological_process_or_activity.umls,associated_with.chemical_substance.umls,inhibits.gene.umls,stimulates.cell.umls,disrupts.biological_process_or_activity.umls,affects.gene.umls,associated_with_reverse.chemical_substance.umls,associated_with.phenotypic_feature.umls,affects_reverse.chemical_substance.umls,interacts_with_reverse.cell.umls,affects.chemical_substance.umls,interacts_with_reverse.biological_process_or_activity.umls,inhibits.protein.umls,stimulates.biological_process_or_activity.umls,associated_with_reverse.biological_process_or_activity.umls,affects.protein.umls,interacts_with_reverse.chemical_substance.umls,stimulates.cell_component.umls,associated_with.biological_process_or_activity.umls,affects.biological_process_or_activity.umls,disrupts.protein.umls,interacts_with.cell.umls,interacts_with.chemical_substance.umls,disrupts.gene.umls,interacts_with_reverse.cell_component.umls,stimulates.phenotypic_feature.umls,disrupts.cell_component.umls&species=human&size=100")
# API 13.10: https://pending.biothings.io/semmedgene/query (POST "q=C1422064&scopes=stimulates.protein.umls&fields=umls&species=human&size=100")
# API 5.1: https://pending.biothings.io/DISEASES/query (POST "q=ACE2&scopes=DISEASES.associatedWith.symbol&fields=_id&species=human&size=100")
# API 10.1: https://pending.biothings.io/ebigene2phenotype/query (POST "q=13557&scopes=_id&fields=gene2phenotype.phenotypes&species=human&size=100")
# API 11.1: https://pending.biothings.io/pfocr/query (POST "q=59272&scopes=associatedWith.genes&fields=_id&species=human&size=100")
# API 14.1: http://ctdbase.org/tools/batchQuery.go?inputType=gene&inputTerms=59272&report=diseases_curated&format=json
# 0, message='Attempt to decode JSON with unexpected mimetype: text/plain;charset=utf-8'
# API 12.1: https://robokop.renci.org/api/simple/expand/gene/HGNC:13557/gene_family/
# API 9.1: https://robokop.renci.org/api/simple/expand/gene/HGNC:13557/chemical_substance/
#
#
# ==== Step #3: Output normalization ====
#
# API 5.1 DISEASES: 31 hits
# API 3.1 biolink_gene2anatomy: No hits
# API 1.1 biolink_gene2disease: No hits
# API 17.1 biolink_gene2phenotype: No hits
# API 2.1 biolink_geneinteraction: No hits
# API 14.1 ctd_gene2disease: 7 hits
# API 16.1 dgidb_gene2chemical: 4 hits
# API 10.1 ebigene2phenotype: No hits
# API 6.1 mychem.info: No hits
# API 6.2 mychem.info: 2 hits
# API 6.3 mychem.info: 2 hits
# API 7.1 mydisease.info: 12 hits
# API 4.1 mygene.info: 2 hits
# API 4.2 mygene.info: 56 hits
# API 4.3 mygene.info: No hits
# API 4.4 mygene.info: No hits
# API 8.1 myvariant.info: 100 hits
# API 15.1 opentarget: No hits
# API 11.1 pfocr: 34 hits
# API 9.1 robokop_gene2chemical: 2 hits
# API 12.1 robokop_gene2genefamily: 1 hits
# API 18.1 semmeddisease: No hits
# API 18.2 semmeddisease: No hits
# API 18.3 semmeddisease: 17 hits
# API 18.4 semmeddisease: No hits
# API 18.5 semmeddisease: 7 hits
# API 18.6 semmeddisease: 49 hits
# API 18.7 semmeddisease: 17 hits
# API 13.1 semmedgene: No hits
# API 13.2 semmedgene: No hits
# API 13.3 semmedgene: No hits
# API 13.4 semmedgene: No hits
# API 13.5 semmedgene: No hits
# API 13.6 semmedgene: 28 hits
# API 13.7 semmedgene: No hits
# API 13.8 semmedgene: 25 hits
# API 13.9 semmedgene: No hits
# API 13.10 semmedgene: No hits
# API 13.11 semmedgene: 101 hits
#
# After id-to-object translation, BTE retrieved 430 unique objects.
#
#
# ========== QUERY #2.1 -- fetch all ChemicalSubstance entities linked to DiseaseOrPhenotypicFeature entites ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because None is of type 'DiseaseOrPhenotypicFeature', BTE will query our meta-KG for APIs that can take 'DiseaseOrPhenotypicFeature' as input and                   'ChemicalSubstance' as output
#
# BTE found 4 apis:
#
# API 1. semmeddisease(1 API call)
# API 2. mychem.info(2 API calls)
# API 3. mydisease.info(1 API call)
# API 4. cohd_disease2chemical(26 API calls)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.19: http://cohd.io/api/frequencies/associatedConceptDomainFreq?dataset_id=1&concept_id=438067&domain=Drug
# API 1.14: http://cohd.io/api/frequencies/associatedConceptDomainFreq?dataset_id=1&concept_id=201826&domain=Drug
# API 1.2: http://cohd.io/api/frequencies/associatedConceptDomainFreq?dataset_id=1&concept_id=4195694&domain=Drug
# API 1.4: http://cohd.io/api/frequencies/associatedConceptDomainFreq?dataset_id=1&concept_id=4174977&domain=Drug
# API 1.6: http://cohd.io/api/frequencies/associatedConceptDomainFreq?dataset_id=1&concept_id=75650&domain=Drug
# API 1.13: http://cohd.io/api/frequencies/associatedConceptDomainFreq?dataset_id=1&concept_id=261071&domain=Drug
# API 4.1: http://pending.biothings.io/semmed/query (POST "q=C0154251,C0028754,C0021368,C1446614,C0001418,C0553980,C0687133,C0023772,C0017661,C0002395,C1301700,C0178664,C1145670,C0022658,C0022665,C0242488,C0030660,C0007193,C0043094,C0340515,C0007137,C0206062,C0038454,C0004238,C0878751,C0029866,C0032285,C0004153,C0011849,C0879626,C1175175,C0160420,C0009566,C2720293,C0000786,C0033687,C0035222,C0012634,C0020544,C1285162,C0684309,C0740457,C0010054,C0239946,C0010068,C0522569,C0085580,C0015697,C0013369,C0007222,C0242973,C1845667,C0016059,C0011881,C0020456,C1853365,C0024530,C0242339,C0041227,C0162871,C0011884,C0042373,C0039870,C0920563,C1970029,C0346255,C0018609,C0277785,C0011854,C0332448,C0039614,C0149721,C1969379,C0020564,C0035126,C0018802,C0023895,C0018798,C0149939,C0020507,C1956346,C0021655,C0021400,C0041234,C0221198,C0151654,C1368683,C0007134,C0020538,C0022661,C0520863,C0087086,C0008354,C0011860,C0024115,C1855457,C0518003,C0152021,C0018801,C0751688,C0027051,C0011847,C0264716,C0021308,C0151744,C0524851,C0033141,C1970028,C0264490,C0948008,C0242606,C0017665,C0007820,C0040053,C1291117,C0018799&scopes=umls&fields=TREATS_reverse.chemical_substance.umls,ASSOCIATED_WITH_reverse.chemical_substance.umls,AFFECTS_reverse.chemical_substance.umls,ASSOCIATED_WITH.chemical_substance.umls,AFFECTS.chemical_substance.umls&species=human&size=100")
# API 1.1: http://cohd.io/api/frequencies/associatedConceptDomainFreq?dataset_id=1&concept_id=321588&domain=Drug
# API 1.21: http://cohd.io/api/frequencies/associatedConceptDomainFreq?dataset_id=1&concept_id=194984&domain=Drug
# API 1.16: http://cohd.io/api/frequencies/associatedConceptDomainFreq?dataset_id=1&concept_id=4214376&domain=Drug
# API 1.15: http://cohd.io/api/frequencies/associatedConceptDomainFreq?dataset_id=1&concept_id=4119786&domain=Drug
# API 1.3: http://cohd.io/api/frequencies/associatedConceptDomainFreq?dataset_id=1&concept_id=196523&domain=Drug
# API 1.25: http://cohd.io/api/frequencies/associatedConceptDomainFreq?dataset_id=1&concept_id=439399&domain=Drug
# API 1.17: http://cohd.io/api/frequencies/associatedConceptDomainFreq?dataset_id=1&concept_id=255848&domain=Drug
# API 1.7: http://cohd.io/api/frequencies/associatedConceptDomainFreq?dataset_id=1&concept_id=320752&domain=Drug
# API 1.12: http://cohd.io/api/frequencies/associatedConceptDomainFreq?dataset_id=1&concept_id=312723&domain=Drug
# API 1.5: http://cohd.io/api/frequencies/associatedConceptDomainFreq?dataset_id=1&concept_id=378419&domain=Drug
# API 1.11: http://cohd.io/api/frequencies/associatedConceptDomainFreq?dataset_id=1&concept_id=316139&domain=Drug
# API 1.9: http://cohd.io/api/frequencies/associatedConceptDomainFreq?dataset_id=1&concept_id=252365&domain=Drug
# API 1.8: http://cohd.io/api/frequencies/associatedConceptDomainFreq?dataset_id=1&concept_id=201820&domain=Drug
# API 1.22: http://cohd.io/api/frequencies/associatedConceptDomainFreq?dataset_id=1&concept_id=435740&domain=Drug
# API 1.10: http://cohd.io/api/frequencies/associatedConceptDomainFreq?dataset_id=1&concept_id=433736&domain=Drug
# API 1.24: http://cohd.io/api/frequencies/associatedConceptDomainFreq?dataset_id=1&concept_id=4163710&domain=Drug
# API 1.23: http://cohd.io/api/frequencies/associatedConceptDomainFreq?dataset_id=1&concept_id=313217&domain=Drug
# API 1.20: http://cohd.io/api/frequencies/associatedConceptDomainFreq?dataset_id=1&concept_id=201254&domain=Drug
# API 1.26: http://cohd.io/api/frequencies/associatedConceptDomainFreq?dataset_id=1&concept_id=198677&domain=Drug
# API 1.18: http://cohd.io/api/frequencies/associatedConceptDomainFreq?dataset_id=1&concept_id=317576&domain=Drug
# API 3.1: http://mydisease.info/v1/query (POST "q=D050197,D018307,D011507,D003928,D003967,D001281,D014517,C000657245,D003327,D009765,D003924,D009203,D002318,C562386,D006943,D019636,D007680,D002311,C537750,D006973,D050171,D017544,D002561,D006250,D013851,D002294,D000544,D006977,D052439,D005922,D015433,D006331,D003920,D007676,D006330,D000022,D007251,D003930,D014355,D017563,D012131,D002292,D002771,D004719,D008107,D014352,D009375,D013742,C564520,D008052,D011014,D045169,D006333,C565230,D004194,D013927,D008288,D003324,D006965,D012128,D008171,D020521,D055371,D014652,D003922,D000230,D017202,D007674&scopes=mondo.xrefs.mesh,disgenet.xrefs.mesh&fields=ctd.chemical_related_to_disease.mesh_chemical_id&species=human&size=100")
# API 2.2: http://mychem.info/v1/query (POST "q=C0154251,C0028754,C0021368,C1446614,C0001418,C0553980,C0687133,C0023772,C0017661,C0002395,C1301700,C0178664,C1145670,C0022658,C0022665,C0242488,C0030660,C0007193,C0043094,C0340515,C0007137,C0206062,C0038454,C0004238,C0878751,C0029866,C0032285,C0004153,C0011849,C0879626,C1175175,C0160420,C0009566,C2720293,C0000786,C0033687,C0035222,C0012634,C0020544,C1285162,C0684309,C0740457,C0010054,C0239946,C0010068,C0522569,C0085580,C0015697,C0013369,C0007222,C0242973,C1845667,C0016059,C0011881,C0020456,C1853365,C0024530,C0242339,C0041227,C0162871,C0011884,C0042373,C0039870,C0920563,C1970029,C0346255,C0018609,C0277785,C0011854,C0332448,C0039614,C0149721,C1969379,C0020564,C0035126,C0018802,C0023895,C0018798,C0149939,C0020507,C1956346,C0021655,C0021400,C0041234,C0221198,C0151654,C1368683,C0007134,C0020538,C0022661,C0520863,C0087086,C0008354,C0011860,C0024115,C1855457,C0518003,C0152021,C0018801,C0751688,C0027051,C0011847,C0264716,C0021308,C0151744,C0524851,C0033141,C1970028,C0264490,C0948008,C0242606,C0017665,C0007820,C0040053,C1291117,C0018799&scopes=drugcentral.drug_use.indication.umls_cui&fields=chembl.molecule_chembl_id&species=human&size=100")
# API 2.1: http://mychem.info/v1/query (POST "q=C0154251,C0028754,C0021368,C1446614,C0001418,C0553980,C0687133,C0023772,C0017661,C0002395,C1301700,C0178664,C1145670,C0022658,C0022665,C0242488,C0030660,C0007193,C0043094,C0340515,C0007137,C0206062,C0038454,C0004238,C0878751,C0029866,C0032285,C0004153,C0011849,C0879626,C1175175,C0160420,C0009566,C2720293,C0000786,C0033687,C0035222,C0012634,C0020544,C1285162,C0684309,C0740457,C0010054,C0239946,C0010068,C0522569,C0085580,C0015697,C0013369,C0007222,C0242973,C1845667,C0016059,C0011881,C0020456,C1853365,C0024530,C0242339,C0041227,C0162871,C0011884,C0042373,C0039870,C0920563,C1970029,C0346255,C0018609,C0277785,C0011854,C0332448,C0039614,C0149721,C1969379,C0020564,C0035126,C0018802,C0023895,C0018798,C0149939,C0020507,C1956346,C0021655,C0021400,C0041234,C0221198,C0151654,C1368683,C0007134,C0020538,C0022661,C0520863,C0087086,C0008354,C0011860,C0024115,C1855457,C0518003,C0152021,C0018801,C0751688,C0027051,C0011847,C0264716,C0021308,C0151744,C0524851,C0033141,C1970028,C0264490,C0948008,C0242606,C0017665,C0007820,C0040053,C1291117,C0018799&scopes=drugcentral.drug_use.contraindication.umls_cui&fields=chembl.molecule_chembl_id&species=human&size=100")
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 cohd_disease2chemical: 3727 hits
# API 1.2 cohd_disease2chemical: 1186 hits
# API 1.3 cohd_disease2chemical: 5239 hits
# API 1.4 cohd_disease2chemical: 80 hits
# API 1.5 cohd_disease2chemical: 1710 hits
# API 1.6 cohd_disease2chemical: 2371 hits
# API 1.7 cohd_disease2chemical: 432 hits
# API 1.8 cohd_disease2chemical: 224 hits
# API 1.9 cohd_disease2chemical: 575 hits
# API 1.10 cohd_disease2chemical: 5606 hits
# API 1.11 cohd_disease2chemical: 4080 hits
# API 1.12 cohd_disease2chemical: 1491 hits
# API 1.13 cohd_disease2chemical: 1270 hits
# API 1.14 cohd_disease2chemical: 5582 hits
# API 1.15 cohd_disease2chemical: 2109 hits
# API 1.16 cohd_disease2chemical: 2938 hits
# API 1.17 cohd_disease2chemical: 5363 hits
# API 1.18 cohd_disease2chemical: 4312 hits
# API 1.19 cohd_disease2chemical: 49 hits
# API 1.20 cohd_disease2chemical: 2387 hits
# API 1.21 cohd_disease2chemical: 3918 hits
# API 1.22 cohd_disease2chemical: No hits
# API 1.23 cohd_disease2chemical: 5126 hits
# API 1.24 cohd_disease2chemical: 1862 hits
# API 1.25 cohd_disease2chemical: 260 hits
# API 1.26 cohd_disease2chemical: No hits
# API 2.1 mychem.info: 1627 hits
# API 2.2 mychem.info: 321 hits
# API 3.1 mydisease.info: 19195 hits
# API 4.1 semmeddisease: 77581 hits
#
# After id-to-object translation, BTE retrieved 18495 unique objects.
#
#
# ========== QUERY #2.2 -- fetch all ChemicalSubstance entities linked to ChemicalSubstance entites ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because None is of type 'ChemicalSubstance', BTE will query our meta-KG for APIs that can take 'ChemicalSubstance' as input and                   'ChemicalSubstance' as output
#
# BTE found 1 apis:
#
# API 1. semmedchemical(4 API calls)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.2: https://pending.biothings.io/semmedchemical/query (POST "q=C0003015,C0682921,C0001962,C0772162,C1098320,C0608663,C0065556,C0016384,C0065374,C0248719,C0309049,C0014027,C1314787,C0684162,C1257987,C0036860,C0066685,C0286651,C0014939,C0017725,C0058206,C0012854,C0006674&scopes=associated_with.chemical_substance.umls&fields=umls&species=human&size=100")
# API 1.1: https://pending.biothings.io/semmedchemical/query (POST "q=C0003015,C0682921,C0001962,C0772162,C1098320,C0608663,C0065556,C0016384,C0065374,C0248719,C0309049,C0014027,C1314787,C0684162,C1257987,C0036860,C0066685,C0286651,C0014939,C0017725,C0058206,C0012854,C0006674&scopes=affects.chemical_substance.umls&fields=umls&species=human&size=100")
# API 1.4: https://pending.biothings.io/semmedchemical/query (POST "q=C0003015,C0682921,C0001962,C0772162,C1098320,C0608663,C0065556,C0016384,C0065374,C0248719,C0309049,C0014027,C1314787,C0684162,C1257987,C0036860,C0066685,C0286651,C0014939,C0017725,C0058206,C0012854,C0006674&scopes=umls&fields=interacts_with.chemical_substance.umls,associated_with.chemical_substance.umls,affects.chemical_substance.umls&species=human&size=100")
# API 1.3: https://pending.biothings.io/semmedchemical/query (POST "q=C0003015,C0682921,C0001962,C0772162,C1098320,C0608663,C0065556,C0016384,C0065374,C0248719,C0309049,C0014027,C1314787,C0684162,C1257987,C0036860,C0066685,C0286651,C0014939,C0017725,C0058206,C0012854,C0006674&scopes=interacts_with.chemical_substance.umls&fields=umls&species=human&size=100")
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 semmedchemical: No hits
# API 1.2 semmedchemical: No hits
# API 1.3 semmedchemical: 1177 hits
# API 1.4 semmedchemical: 6668 hits
#
# After id-to-object translation, BTE retrieved 3908 unique objects.
#
#
# ========== QUERY #2.3 -- fetch all ChemicalSubstance entities linked to Pathway entites ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because None is of type 'Pathway', BTE will query our meta-KG for APIs that can take 'Pathway' as input and                   'ChemicalSubstance' as output
# We are sorry! We couln't find any APIs which can do the type of query for you!
#
#
# ========== QUERY #2.4 -- fetch all ChemicalSubstance entities linked to Gene entites ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because None is of type 'Gene', BTE will query our meta-KG for APIs that can take 'Gene' as input and                   'ChemicalSubstance' as output
#
# BTE found 5 apis:
#
# API 1. mychem.info(3 API calls)
# API 2. robokop_gene2chemical(28 API calls)
# API 3. semmedgene(1 API call)
# API 4. opentarget(28 API calls)
# API 5. dgidb_gene2chemical(30 API calls)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 4.5: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000100591&datasource=chembl&size=15&fields=drug
# API 4.4: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000105329&datasource=chembl&size=15&fields=drug
# API 4.7: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000163914&datasource=chembl&size=15&fields=drug
# API 4.11: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000159640&datasource=chembl&size=15&fields=drug
# API 4.9: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000131238&datasource=chembl&size=15&fields=drug
# API 4.1: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000139352&datasource=chembl&size=15&fields=drug
# API 4.16: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000100351&datasource=chembl&size=15&fields=drug
# API 4.21: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSGALG00000016554&datasource=chembl&size=15&fields=drug
# API 4.13: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000159479&datasource=chembl&size=15&fields=drug
# API 4.28: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000168827&datasource=chembl&size=15&fields=drug
# API 4.20: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000142599&datasource=chembl&size=15&fields=drug
# API 4.27: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000096395&datasource=chembl&size=15&fields=drug
# API 4.19: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000142192&datasource=chembl&size=15&fields=drug
# API 4.8: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000167193&datasource=chembl&size=15&fields=drug
# API 4.18: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000067900&datasource=chembl&size=15&fields=drug
# API 4.25: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000144891&datasource=chembl&size=15&fields=drug
# API 4.26: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000214274&datasource=chembl&size=15&fields=drug
# API 4.3: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000080561&datasource=chembl&size=15&fields=drug
# API 5.27: http://www.dgidb.org/api/v2/interactions.json?genes=AC113554.1
# API 4.6: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000166340&datasource=chembl&size=15&fields=drug
# API 4.14: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000100030&datasource=chembl&size=15&fields=drug
# API 5.23: http://www.dgidb.org/api/v2/interactions.json?genes=ERVK-10
# API 5.5: http://www.dgidb.org/api/v2/interactions.json?genes=NANOS1
# API 5.3: http://www.dgidb.org/api/v2/interactions.json?genes=AHSA1
# API 5.12: http://www.dgidb.org/api/v2/interactions.json?genes=TGFB1
# API 5.8: http://www.dgidb.org/api/v2/interactions.json?genes=CLN3
# API 5.24: http://www.dgidb.org/api/v2/interactions.json?genes=RERE
# API 5.2: http://www.dgidb.org/api/v2/interactions.json?genes=ACE
# API 5.6: http://www.dgidb.org/api/v2/interactions.json?genes=PTTG1IP
# API 4.10: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000183255&datasource=chembl&size=15&fields=drug
# API 4.22: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000264813&datasource=chembl&size=15&fields=drug
# API 4.12: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000188603&datasource=chembl&size=15&fields=drug
# API 4.15: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000118271&datasource=chembl&size=15&fields=drug
# API 5.19: http://www.dgidb.org/api/v2/interactions.json?genes=MLN
# API 4.2: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000004142&datasource=chembl&size=15&fields=drug
# API 4.17: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000188613&datasource=chembl&size=15&fields=drug
# API 4.23: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000175206&datasource=chembl&size=15&fields=drug
# API 5.14: http://www.dgidb.org/api/v2/interactions.json?genes=MIR27A
# API 4.24: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000173156&datasource=chembl&size=15&fields=drug
# API 5.22: http://www.dgidb.org/api/v2/interactions.json?genes=RHO
# API 5.20: http://www.dgidb.org/api/v2/interactions.json?genes=DIANPH
# API 5.17: http://www.dgidb.org/api/v2/interactions.json?genes=AGTR1
# API 5.25: http://www.dgidb.org/api/v2/interactions.json?genes=ROCK1
# API 3.1: https://pending.biothings.io/semmedgene/query (POST "q=C0059100,C1417190,C1705543,C0017337,C1539560,C3539824,C1412517,C1335631,C1705516,C0034861,C1335144,C1705767,C1419345,C0033634,C3273301,C1412886,C1706637,C3542911,C0002570,C0907533,C1456380,C1706176,C0600388,C1706108,C1332009,C3812737,C0669365,C1537729,C1426572,C1442864,C1421224,C0389995,C1428254,C0669368,C0662902,C1422035,C3889381,C0084913,C1705844,C1452025,C1120843,C0051844,C1705148,C3539645,C0030956,C2825815,C1417168,C0812252,C1366882,C1413495,C0010531,C0051169,C0172537,C1540042,C1366557,C0008546,C1413931,C0014442,C0025250,C0243045,C1367482,C1364818,C1417807,C1705633,C1427871,C1439284,C1415284,C1305628,C1419385,C1709136,C3147205,C1260229,C1418854&scopes=umls&fields=interacts_with_reverse.chemical_substance.umls,associated_with_reverse.chemical_substance.umls,affects_reverse.chemical_substance.umls,interacts_with.chemical_substance.umls,affects.chemical_substance.umls,associated_with.chemical_substance.umls&species=human&size=100")
# API 5.7: http://www.dgidb.org/api/v2/interactions.json?genes=ANG
# API 5.1: http://www.dgidb.org/api/v2/interactions.json?genes=CRK
# API 5.15: http://www.dgidb.org/api/v2/interactions.json?genes=MED8
# API 5.11: http://www.dgidb.org/api/v2/interactions.json?genes=TTR
# API 5.28: http://www.dgidb.org/api/v2/interactions.json?genes=PPT1
# API 5.16: http://www.dgidb.org/api/v2/interactions.json?genes=MID2
# API 5.9: http://www.dgidb.org/api/v2/interactions.json?genes=POLDIP2
# API 5.21: http://www.dgidb.org/api/v2/interactions.json?genes=TPP1
# API 5.4: http://www.dgidb.org/api/v2/interactions.json?genes=APP
# API 5.10: http://www.dgidb.org/api/v2/interactions.json?genes=MAPK1
# API 5.29: http://www.dgidb.org/api/v2/interactions.json?genes=RHOD
# API 5.26: http://www.dgidb.org/api/v2/interactions.json?genes=ASCL1
# API 5.30: http://www.dgidb.org/api/v2/interactions.json?genes=GRAP2
# API 5.18: http://www.dgidb.org/api/v2/interactions.json?genes=NPPA
# API 5.13: http://www.dgidb.org/api/v2/interactions.json?genes=GFM1
# API 1.1: http://mychem.info/v1/query (POST "q=CRK,ACE,AHSA1,APP,NANOS1,PTTG1IP,ANG,CLN3,POLDIP2,MAPK1,TTR,TGFB1,GFM1,MIR27A,MED8,MID2,AGTR1,NPPA,MLN,DIANPH,TPP1,RHO,ERVK-10,RERE,ROCK1,ASCL1,AC113554.1,PPT1,RHOD,GRAP2&scopes=drugbank.enzymes.gene_name&fields=drugbank.id&species=human&size=100")
# API 1.3: http://mychem.info/v1/query (POST "q=CRK,ACE,AHSA1,APP,NANOS1,PTTG1IP,ANG,CLN3,POLDIP2,MAPK1,TTR,TGFB1,GFM1,MIR27A,MED8,MID2,AGTR1,NPPA,MLN,DIANPH,TPP1,RHO,ERVK-10,RERE,ROCK1,ASCL1,AC113554.1,PPT1,RHOD,GRAP2&scopes=drugcentral.bioactivity.uniprot.gene_symbol&fields=chembl.molecule_chembl_id&species=human&size=100")
# API 1.2: http://mychem.info/v1/query (POST "q=CRK,ACE,AHSA1,APP,NANOS1,PTTG1IP,ANG,CLN3,POLDIP2,MAPK1,TTR,TGFB1,GFM1,MIR27A,MED8,MID2,AGTR1,NPPA,MLN,DIANPH,TPP1,RHO,ERVK-10,RERE,ROCK1,ASCL1,AC113554.1,PPT1,RHOD,GRAP2&scopes=drugbank.targets.gene_name&fields=drugbank.id&species=human&size=100")
# API 2.28: https://robokop.renci.org/api/simple/expand/gene/HGNC:738/chemical_substance/
# API 2.4: https://robokop.renci.org/api/simple/expand/gene/HGNC:10012/chemical_substance/
# API 2.23: https://robokop.renci.org/api/simple/expand/gene/HGNC:670/chemical_substance/
# API 2.19: https://robokop.renci.org/api/simple/expand/gene/HGNC:2707/chemical_substance/
# API 2.18: https://robokop.renci.org/api/simple/expand/gene/HGNC:9325/chemical_substance/
# API 2.22: https://robokop.renci.org/api/simple/expand/gene/HGNC:7096/chemical_substance/
# API 2.24: https://robokop.renci.org/api/simple/expand/gene/HGNC:13524/chemical_substance/
# API 2.1: https://robokop.renci.org/api/simple/expand/gene/HGNC:4563/chemical_substance/
# API 2.12: https://robokop.renci.org/api/simple/expand/gene/HGNC:1189/chemical_substance/
# API 2.11: https://robokop.renci.org/api/simple/expand/gene/HGNC:13780/chemical_substance/
# API 2.13: https://robokop.renci.org/api/simple/expand/gene/HGNC:336/chemical_substance/
# API 2.6: https://robokop.renci.org/api/simple/expand/gene/HGNC:483/chemical_substance/
# API 2.25: https://robokop.renci.org/api/simple/expand/gene/HGNC:9965/chemical_substance/
# API 2.21: https://robokop.renci.org/api/simple/expand/gene/HGNC:10251/chemical_substance/
# API 2.3: https://robokop.renci.org/api/simple/expand/gene/HGNC:23781/chemical_substance/
# API 2.20: https://robokop.renci.org/api/simple/expand/gene/HGNC:2074/chemical_substance/
# API 2.10: https://robokop.renci.org/api/simple/expand/gene/HGNC:7141/chemical_substance/
# API 2.16: https://robokop.renci.org/api/simple/expand/gene/HGNC:19971/chemical_substance/
# API 2.14: https://robokop.renci.org/api/simple/expand/gene/HGNC:2073/chemical_substance/
# API 2.26: https://robokop.renci.org/api/simple/expand/gene/HGNC:39004/chemical_substance/
# API 2.27: https://robokop.renci.org/api/simple/expand/gene/HGNC:23044/chemical_substance/
# API 2.2: https://robokop.renci.org/api/simple/expand/gene/HGNC:31613/chemical_substance/
# API 2.5: https://robokop.renci.org/api/simple/expand/gene/HGNC:2362/chemical_substance/
# API 2.9: https://robokop.renci.org/api/simple/expand/gene/HGNC:12405/chemical_substance/
# API 2.8: https://robokop.renci.org/api/simple/expand/gene/HGNC:6871/chemical_substance/
# API 2.17: https://robokop.renci.org/api/simple/expand/gene/HGNC:620/chemical_substance/
# API 2.7: https://robokop.renci.org/api/simple/expand/gene/HGNC:11766/chemical_substance/
# API 2.15: https://robokop.renci.org/api/simple/expand/gene/HGNC:7939/chemical_substance/
#
#
# ==== Step #3: Output normalization ====
#
# API 5.1 dgidb_gene2chemical: No hits
# API 5.2 dgidb_gene2chemical: 45 hits
# API 5.3 dgidb_gene2chemical: No hits
# API 5.4 dgidb_gene2chemical: 22 hits
# API 5.5 dgidb_gene2chemical: No hits
# API 5.6 dgidb_gene2chemical: No hits
# API 5.7 dgidb_gene2chemical: 2 hits
# API 5.8 dgidb_gene2chemical: No hits
# API 5.9 dgidb_gene2chemical: No hits
# API 5.10 dgidb_gene2chemical: 29 hits
# API 5.11 dgidb_gene2chemical: 2 hits
# API 5.12 dgidb_gene2chemical: 37 hits
# API 5.13 dgidb_gene2chemical: No hits
# API 5.14 dgidb_gene2chemical: No hits
# API 5.15 dgidb_gene2chemical: No hits
# API 5.16 dgidb_gene2chemical: No hits
# API 5.17 dgidb_gene2chemical: 40 hits
# API 5.18 dgidb_gene2chemical: 1 hits
# API 5.19 dgidb_gene2chemical: 1 hits
# API 5.20 dgidb_gene2chemical: No hits
# API 5.21 dgidb_gene2chemical: 1 hits
# API 5.22 dgidb_gene2chemical: 6 hits
# API 5.23 dgidb_gene2chemical: No hits
# API 5.24 dgidb_gene2chemical: No hits
# API 5.25 dgidb_gene2chemical: 16 hits
# API 5.26 dgidb_gene2chemical: No hits
# API 5.27 dgidb_gene2chemical: No hits
# API 5.28 dgidb_gene2chemical: 3 hits
# API 5.29 dgidb_gene2chemical: No hits
# API 5.30 dgidb_gene2chemical: No hits
# API 1.1 mychem.info: 1 hits
# API 1.2 mychem.info: 106 hits
# API 1.3 mychem.info: 78 hits
# API 4.1 opentarget: No hits
# API 4.2 opentarget: No hits
# API 4.3 opentarget: No hits
# API 4.4 opentarget: 15 hits
# API 4.5 opentarget: No hits
# API 4.6 opentarget: No hits
# API 4.7 opentarget: No hits
# API 4.8 opentarget: No hits
# API 4.9 opentarget: No hits
# API 4.10 opentarget: No hits
# API 4.11 opentarget: 15 hits
# API 4.12 opentarget: No hits
# API 4.13 opentarget: No hits
# API 4.14 opentarget: 10 hits
# API 4.15 opentarget: 15 hits
# API 4.16 opentarget: No hits
# API 4.17 opentarget: No hits
# API 4.18 opentarget: 15 hits
# API 4.19 opentarget: 15 hits
# API 4.20 opentarget: No hits
# API 4.21 opentarget: No hits
# API 4.22 opentarget: No hits
# API 4.23 opentarget: No hits
# API 4.24 opentarget: No hits
# API 4.25 opentarget: 15 hits
# API 4.26 opentarget: No hits
# API 4.27 opentarget: No hits
# API 4.28 opentarget: No hits
# API 2.1 robokop_gene2chemical: No hits
# API 2.2 robokop_gene2chemical: No hits
# API 2.3 robokop_gene2chemical: No hits
# API 2.4 robokop_gene2chemical: No hits
# API 2.5 robokop_gene2chemical: No hits
# API 2.6 robokop_gene2chemical: 1 hits
# API 2.7 robokop_gene2chemical: 15 hits
# API 2.8 robokop_gene2chemical: 4 hits
# API 2.9 robokop_gene2chemical: 3 hits
# API 2.10 robokop_gene2chemical: 2 hits
# API 2.11 robokop_gene2chemical: No hits
# API 2.12 robokop_gene2chemical: No hits
# API 2.13 robokop_gene2chemical: 4 hits
# API 2.14 robokop_gene2chemical: No hits
# API 2.15 robokop_gene2chemical: 5 hits
# API 2.16 robokop_gene2chemical: No hits
# API 2.17 robokop_gene2chemical: 12 hits
# API 2.18 robokop_gene2chemical: 2 hits
# API 2.19 robokop_gene2chemical: 7 hits
# API 2.20 robokop_gene2chemical: No hits
# API 2.21 robokop_gene2chemical: 1 hits
# API 2.22 robokop_gene2chemical: No hits
# API 2.23 robokop_gene2chemical: No hits
# API 2.24 robokop_gene2chemical: No hits
# API 2.25 robokop_gene2chemical: No hits
# API 2.26 robokop_gene2chemical: No hits
# API 2.27 robokop_gene2chemical: No hits
# API 2.28 robokop_gene2chemical: No hits
# API 3.1 semmedgene: 28067 hits
#
# After id-to-object translation, BTE retrieved 7284 unique objects.
#
#
# ========== QUERY #2.5 -- fetch all ChemicalSubstance entities linked to SequenceVariant entites ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because None is of type 'SequenceVariant', BTE will query our meta-KG for APIs that can take 'SequenceVariant' as input and                   'ChemicalSubstance' as output
# We are sorry! We couln't find any APIs which can do the type of query for you!
#
#
# ========== QUERY #2.6 -- fetch all ChemicalSubstance entities linked to GeneFamily entites ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because None is of type 'GeneFamily', BTE will query our meta-KG for APIs that can take 'GeneFamily' as input and                   'ChemicalSubstance' as output
# We are sorry! We couln't find any APIs which can do the type of query for you!
#
#
# ========== QUERY #2.7 -- fetch all ChemicalSubstance entities linked to Transcript entites ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because None is of type 'Transcript', BTE will query our meta-KG for APIs that can take 'Transcript' as input and                   'ChemicalSubstance' as output
# We are sorry! We couln't find any APIs which can do the type of query for you!
#
#
# ========== QUERY #2.8 -- fetch all ChemicalSubstance entities linked to Protein entites ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because None is of type 'Protein', BTE will query our meta-KG for APIs that can take 'Protein' as input and                   'ChemicalSubstance' as output
# We are sorry! We couln't find any APIs which can do the type of query for you!
#
#
# ========== QUERY #2.9 -- fetch all ChemicalSubstance entities linked to Cell entites ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because None is of type 'Cell', BTE will query our meta-KG for APIs that can take 'Cell' as input and                   'ChemicalSubstance' as output
#
# BTE found 1 apis:
#
# API 1. semmedchemical(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.1: https://pending.biothings.io/semmedchemical/query (POST "q=C1135918,C0225360,C1511246,C0005773,C1522214&scopes=affects.cell.umls&fields=umls&species=human&size=100")
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 semmedchemical: 388 hits
#
# After id-to-object translation, BTE retrieved 331 unique objects.
#
#
# ========== QUERY #2.10 -- fetch all ChemicalSubstance entities linked to MolecularActivity entites ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because None is of type 'MolecularActivity', BTE will query our meta-KG for APIs that can take 'MolecularActivity' as input and                   'ChemicalSubstance' as output
# We are sorry! We couln't find any APIs which can do the type of query for you!
#
#
# ========== QUERY #2.11 -- fetch all ChemicalSubstance entities linked to BiologicalProcess entites ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because None is of type 'BiologicalProcess', BTE will query our meta-KG for APIs that can take 'BiologicalProcess' as input and                   'ChemicalSubstance' as output
#
# BTE found 1 apis:
#
# API 1. semmedchemical(5 API calls)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.3: https://pending.biothings.io/semmedchemical/query (POST "q=C1150120,C0920644,C0678863,C0232164,C0041904,C0162493,C0007227,C0078994,C1150182,C0007586,C0007613,C1148759,C0080311,C0037313,C0600520,C1510890,C0870868,C0042765,C0162638,C0040649,C0026559,C0031715,C1156247,C1514248,C0017262,C0010813,C0013081,C0019868,C0596290&scopes=associated_with.biological_process_or_activity.umls&fields=umls&species=human&size=100")
# API 1.5: https://pending.biothings.io/semmedchemical/query (POST "q=C1150120,C0920644,C0678863,C0232164,C0041904,C0162493,C0007227,C0078994,C1150182,C0007586,C0007613,C1148759,C0080311,C0037313,C0600520,C1510890,C0870868,C0042765,C0162638,C0040649,C0026559,C0031715,C1156247,C1514248,C0017262,C0010813,C0013081,C0019868,C0596290&scopes=causes.biological_process_or_activity.umls&fields=umls&species=human&size=100")
# API 1.2: https://pending.biothings.io/semmedchemical/query (POST "q=C1150120,C0920644,C0678863,C0232164,C0041904,C0162493,C0007227,C0078994,C1150182,C0007586,C0007613,C1148759,C0080311,C0037313,C0600520,C1510890,C0870868,C0042765,C0162638,C0040649,C0026559,C0031715,C1156247,C1514248,C0017262,C0010813,C0013081,C0019868,C0596290&scopes=affects_reverse.biological_process_or_activity.umls&fields=umls&species=human&size=100")
# API 1.4: https://pending.biothings.io/semmedchemical/query (POST "q=C1150120,C0920644,C0678863,C0232164,C0041904,C0162493,C0007227,C0078994,C1150182,C0007586,C0007613,C1148759,C0080311,C0037313,C0600520,C1510890,C0870868,C0042765,C0162638,C0040649,C0026559,C0031715,C1156247,C1514248,C0017262,C0010813,C0013081,C0019868,C0596290&scopes=associated_with_reverse.biological_process_or_activity.umls&fields=umls&species=human&size=100")
# API 1.1: https://pending.biothings.io/semmedchemical/query (POST "q=C1150120,C0920644,C0678863,C0232164,C0041904,C0162493,C0007227,C0078994,C1150182,C0007586,C0007613,C1148759,C0080311,C0037313,C0600520,C1510890,C0870868,C0042765,C0162638,C0040649,C0026559,C0031715,C1156247,C1514248,C0017262,C0010813,C0013081,C0019868,C0596290&scopes=affects.biological_process_or_activity.umls&fields=umls&species=human&size=100")
#
#
# ==== Step #3: Output normalization ====
# API 1.1 semmedchemical: 2243 hits
# API 1.2 semmedchemical: 479 hits
# API 1.3 semmedchemical: No hits
# API 1.4 semmedchemical: 5 hits
# API 1.5 semmedchemical: 664 hits
#
# After id-to-object translation, BTE retrieved 1902 unique objects.
#
#
# ========== QUERY #2.12 -- fetch all ChemicalSubstance entities linked to CellularComponent entites ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because None is of type 'CellularComponent', BTE will query our meta-KG for APIs that can take 'CellularComponent' as input and                   'ChemicalSubstance' as output
# We are sorry! We couln't find any APIs which can do the type of query for you!
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# In the #1 query, BTE found 104 unique DiseaseOrPhenotypicFeature nodes
# In the #1 query, BTE found 26 unique ChemicalSubstance nodes
# In the #1 query, BTE found 38 unique Pathway nodes
# In the #1 query, BTE found 82 unique Gene nodes
# In the #1 query, BTE found 100 unique SequenceVariant nodes
# In the #1 query, BTE found 1 unique GeneFamily nodes
# In the #1 query, BTE found 5 unique Transcript nodes
# In the #1 query, BTE found 3 unique Protein nodes
# In the #1 query, BTE found 5 unique Cell nodes
# In the #1 query, BTE found 10 unique MolecularActivity nodes
# In the #1 query, BTE found 46 unique BiologicalProcess nodes
# In the #1 query, BTE found 10 unique CellularComponent nodes
# In the #2 query, BTE found 22339 unique ChemicalSubstance nodes

# %%
g = fc.fc.G

# %%
chemicals = {}
for k, v in g.nodes(data=True):
    if v['type'] == 'ChemicalSubstance':
        chemicals[k] = v

# %%
chemicals.keys()
# Out:
# dict_keys(['CHEMBL260273', 'DB05203', 'C0003015', 'C0012854', 'C0058206', 'C0065556', 'C0682921', 'C0772162', 'C1098320', 'C1314787', 'C0014939', 'C0309049', 'C0608663', 'C0684162', 'C1257987', 'LISINOPRIL', 'ORE-1001', 'FLUTAMIDE', 'MOEXIPRIL', 'ENALAPRILAT', 'CARBARIL', 'ALCOHOL', 'DEXTROSE', 'CALCITRIOL', 'TELMISARTAN', 'ATORVASTATIN', '19041324', '40220357', '40240688', '46275349', '938330', '35605482', '43011850', '35603428', '40231925', '19073712', '19059056', '19077652', '40231041', '19135374', '36249718', '40221387', '19072321', '36249643', '46275280', '40221385', '36249739', '40173301', '40232756', '36249736', '968477', '19123989', '40171396', '40221386', '35603226', '993653', '19077546', '19123106', '19019419', '19073777', '957136', '19078558', '40167213', '1113076', '19080217', '40160974', '1113346', '1790982', '35604998', '40221384', '35603227', '46287618', '40226999', '19049335', '19077241', '46275856', '42708658', '1718752', '1127433', '1332419', '19075034', '36249737', '40232444', '19131157', '19078921', '19041823', '19019418', '46275400', '1551170', '19073093', '19073187', '1836434', '1742255', '46275794', '40220388', '36249687', '46234043', '46287345', '46275446', '19065567', '40166828', '19115197', '19130168', '19122573', '1332421', '19023551', '35606395', '40227012', '19075601', '19134047', '40166830', '19046742', '19079658', '46287328', '19129446', '19077513', '1551192', '35605848', '43012671', '46275444', '19049684', '987250', '19078559', '19123593', '40163500', '19019073', '19077548', '35606552', '19075380', '40167259', '1545959', '42709116', '35603043', '1322185', '19079119', '36249734', '19008723', '19077344', '19077547', '19022749', '40166540', '40163555', '19041255', '36250141', '43011889', '1545996', '1593190', '19079322', '40167218', '1560751', '19079626', '19080128', '1308251', '40167196', '1718737', '19078106', '19019072', '1707348', '40166541', '40221352', '967434', '1112892', '19078557', '19123592', '1539411', '42707671', '40220960', '19077343', '40164929', '42708743', '19079524', '40232754', '766820', '19123105', '19019112', '19022750', '19072176', '19023799', '42902743', '40221904', '19019336', '19023791', '968985', '40162515', '953102', '1539407', '1309992', '19011661', '35605895', '1551123', '36249703', '35606533', '19080129', '40174776', '46275385', '950641', '19010270', '40166824', '40243310', '1518292', '43559979', '40168991', '35603224', '19123104', '19020053', '46287338', '968005', '1154619', '40163473', '19079171', '46287372', '19073094', '40241504', '19028193', '1308250', '19078924', '36249738', '40166831', '40163554', '1718735', '35605730', '19074247', '40166829', '1593063', '46234523', '19035115', '40163525', '19079712', '956877', '19006967', '40221369', '40221822', '19019113', '19068781', '1136682', '711589', '19072933', '43011826', '1593519', '40185280', '1545997', '1742254', '1707346', '40163900', '40227544', '1346990', '35603045', '40163535', '752095', '19022781', '19034804', '46287424', '1545999', '40185304', '942384', '1346991', '40184727', '40173508', '939510', '19071700', '40164897', '19082350', '19127954', '19126173', '906891', '40221381', '19036628', '40167261', '1593966', '1703065', '19113528', '35603805', '42707627', '40244449', '19019003', '40175291', '19135631', '19077763', '19129398', '35603243', '19018935', '40175400', '19122432', '42628989', '997899', '1167323', '19127677', '961050', '40173099', '40185305', '1150347', '19121242', '19078552', '723042', '40174811', '19132783', '778765', '40169706', '1154621', '40231928', '35603556', '46234049', '1836433', '19033500', '19077375', '40185276', '1551122', '907020', '40231805', '19090761', '40165065', '19126665', '1545998', '19121580', '40175394', '19018787', '40231648', '19076659', '19059823', '19137328', '1113013', '40236805', '40229192', '40226969', '35606561', '40163511', '40162312', '1301154', '36250167', '40231927', '40160992', '40227057', '40163818', '40163567', '40163492', '725178', '40228087', '40232700', '1308221 ...

# %%
df = fc.display_table_view()

# %% [markdown]
# ### No. 2 NELFINAVIR MESYLATE

# %%
df.loc[df['output_name'] == 'NELFINAVIR']
# Out:
#      input input_type           pred1 pred1_source   pred1_api pred1_pubmed  \
# 4897  ACE2       Gene  associatedWith       semmed  semmedgene         None
#
#              node1_type       node1_name       node1_id     pred2  \
# 4897  BiologicalProcess  Down-Regulation  umls:C0013081  causedBy
#
#         pred2_source       pred2_api pred2_pubmed        output_type  \
# 4897  semmedchemical  semmedchemical         None  ChemicalSubstance
#
#      output_name         output_id
# 4897  NELFINAVIR  chembl:CHEMBL584

# %% [markdown]
# ### No. 3 AMOPYROQUINE

# %%
df.loc[df['output_name'] == 'C0051735']
# Out:
#        input input_type           pred1 pred1_source pred1_api pred1_pubmed  \
# 107716  ACE2       Gene  associatedWith     DISEASES  DISEASES         None
#
#                         node1_type node1_name             node1_id      pred2  \
# 107716  DiseaseOrPhenotypicFeature    malaria  mondo:MONDO:0005136  treatedBy
#
#        pred2_source      pred2_api pred2_pubmed        output_type  \
# 107716       semmed  semmeddisease         None  ChemicalSubstance
#
#        output_name      output_id
# 107716    C0051735  umls:C0051735

# %% [markdown]
# ### No. 7 HANFANGCHIN A

# %%
df.loc[df['output_name'] == 'C0076316']
# Out:
#      input input_type                pred1 pred1_source   pred1_api  \
# 5938  ACE2       Gene       associatedWith       semmed  semmedgene
# 5939  ACE2       Gene       associatedWith       semmed  semmedgene
# 5940  ACE2       Gene  decreasesActivityOf       semmed  semmedgene
# 5941  ACE2       Gene       associatedWith       semmed  semmedgene
# 5942  ACE2       Gene       associatedWith       semmed  semmedgene
# 5943  ACE2       Gene       associatedWith       semmed  semmedgene
# 5944  ACE2       Gene  decreasesActivityOf       semmed  semmedgene
#
#      pred1_pubmed         node1_type                  node1_name  \
# 5938         None  BiologicalProcess                  Cell Cycle
# 5939         None  BiologicalProcess             Cell physiology
# 5940         None  BiologicalProcess             Cell physiology
# 5941         None  BiologicalProcess  Transcriptional Activation
# 5942         None  BiologicalProcess            Cardiac function
# 5943         None  BiologicalProcess               hyphal growth
# 5944         None  BiologicalProcess                       Sleep
#
#            node1_id           pred2    pred2_source       pred2_api  \
# 5938  umls:C0007586        causedBy  semmedchemical  semmedchemical
# 5939  umls:C0007613        causedBy  semmedchemical  semmedchemical
# 5940  umls:C0007613        causedBy  semmedchemical  semmedchemical
# 5941  umls:C0162493  associatedWith  semmedchemical  semmedchemical
# 5942  umls:C0232164  associatedWith  semmedchemical  semmedchemical
# 5943  umls:C1156247  associatedWith  semmedchemical  semmedchemical
# 5944  umls:C0037313  associatedWith  semmedchemical  semmedchemical
#
#      pred2_pubmed        output_type output_name      output_id
# 5938         None  ChemicalSubstance    C0076316  umls:C0076316
# 5939         None  ChemicalSubstance    C0076316  umls:C0076316
# 5940         None  ChemicalSubstance    C0076316  umls:C0076316
# 5941         None  ChemicalSubstance    C0076316  umls:C0076316
# 5942         None  ChemicalSubstance    C0076316  umls:C0076316
# 5943         None  ChemicalSubstance    C0076316  umls:C0076316
# 5944         None  ChemicalSubstance    C0076316  umls:C0076316

# %% [markdown]
# ### No. 11 FERROQUINE

# %%
df.loc[df['output_name'] == 'C1313506']
# Out:
#        input input_type           pred1 pred1_source pred1_api pred1_pubmed  \
# 107843  ACE2       Gene  associatedWith     DISEASES  DISEASES         None
#
#                         node1_type node1_name             node1_id      pred2  \
# 107843  DiseaseOrPhenotypicFeature    malaria  mondo:MONDO:0005136  treatedBy
#
#        pred2_source      pred2_api pred2_pubmed        output_type  \
# 107843       semmed  semmeddisease         None  ChemicalSubstance
#
#        output_name      output_id
# 107843    C1313506  umls:C1313506

# %% [markdown]
# ### No. 13 ASTEMIZOLE

# %%
df.loc[df['output_name'] == 'ASTEMIZOLE']
# Out:
#       input input_type                     pred1 pred1_source   pred1_api  \
# 20464  ACE2       Gene  molecularlyInteractsWith   semmedgene  semmedgene
# 20465  ACE2       Gene  molecularlyInteractsWith       semmed  semmedgene
#
#       pred1_pubmed node1_type node1_name       node1_id  \
# 20464         None       Gene   C0017337  umls:C0017337
# 20465         None       Gene   C0017337  umls:C0017337
#
#                           pred2 pred2_source   pred2_api pred2_pubmed  \
# 20464  molecularlyInteractsWith       semmed  semmedgene         None
# 20465  molecularlyInteractsWith       semmed  semmedgene         None
#
#              output_type output_name            output_id
# 20464  ChemicalSubstance  ASTEMIZOLE  chembl:CHEMBL296419
# 20465  ChemicalSubstance  ASTEMIZOLE  chembl:CHEMBL296419

# %% [markdown]
# ### No. 14 amodiaquine

# %%
df.loc[df['output_name'] == 'AMODIAQUINE']
# Out:
#       input input_type                     pred1 pred1_source   pred1_api  \
# 20156  ACE2       Gene  molecularlyInteractsWith   semmedgene  semmedgene
# 20157  ACE2       Gene  molecularlyInteractsWith   semmedgene  semmedgene
#
#       pred1_pubmed node1_type node1_name          node1_id  \
# 20156         None       Gene   C0010531     umls:C0010531
# 20157         None       Gene    ERVK-10  entrez:100616101
#
#                           pred2 pred2_source   pred2_api pred2_pubmed  \
# 20156  molecularlyInteractsWith       semmed  semmedgene         None
# 20157  molecularlyInteractsWith       semmed  semmedgene         None
#
#              output_type  output_name         output_id
# 20156  ChemicalSubstance  AMODIAQUINE  chembl:CHEMBL682
# 20157  ChemicalSubstance  AMODIAQUINE  chembl:CHEMBL682

# %% [markdown]
# ### No. 22 (+)-MEFLOQUINE

# %%
df.loc[df['output_name'] == 'C0208248']
# Out:
#        input input_type           pred1 pred1_source pred1_api pred1_pubmed  \
# 107774  ACE2       Gene  associatedWith     DISEASES  DISEASES         None
#
#                         node1_type node1_name             node1_id      pred2  \
# 107774  DiseaseOrPhenotypicFeature    malaria  mondo:MONDO:0005136  treatedBy
#
#        pred2_source      pred2_api pred2_pubmed        output_type  \
# 107774       semmed  semmeddisease         None  ChemicalSubstance
#
#        output_name      output_id
# 107774    C0208248  umls:C0208248

# %% [markdown]
# ABOVE REFERS TO: name(Mefloquine Hydrochloride) umls(C0282398)

# %%
df.loc[df['output_name'] == 'C0208248']
# Out:
#        input input_type           pred1 pred1_source pred1_api pred1_pubmed  \
# 107774  ACE2       Gene  associatedWith     DISEASES  DISEASES         None
#
#                         node1_type node1_name             node1_id      pred2  \
# 107774  DiseaseOrPhenotypicFeature    malaria  mondo:MONDO:0005136  treatedBy
#
#        pred2_source      pred2_api pred2_pubmed        output_type  \
# 107774       semmed  semmeddisease         None  ChemicalSubstance
#
#        output_name      output_id
# 107774    C0208248  umls:C0208248

# %% [markdown]
# ABOVE REFERS TO: name(mefloquine-sulfadoxine-pyrimethamine) umls(C0208248)

# %% [markdown]
# ### No. 27 CEPHARANTHINE

# %%
df.loc[df['output_name'] == 'C0055082']
# Out:
#      input input_type                     pred1 pred1_source   pred1_api  \
# 8120  ACE2       Gene       activityDecreasedBy   semmedgene  semmedgene
# 8121  ACE2       Gene  molecularlyInteractsWith       semmed  semmedgene
#
#      pred1_pubmed node1_type node1_name       node1_id  \
# 8120         None       Gene   C1705767  umls:C1705767
# 8121         None       Gene   C0014442  umls:C0014442
#
#                          pred2 pred2_source   pred2_api pred2_pubmed  \
# 8120  molecularlyInteractsWith       semmed  semmedgene         None
# 8121  molecularlyInteractsWith       semmed  semmedgene         None
#
#             output_type output_name      output_id
# 8120  ChemicalSubstance    C0055082  umls:C0055082
# 8121  ChemicalSubstance    C0055082  umls:C0055082

# %% [markdown]
# ### No. 33 ANDROGRAPHOLIDE

# %%
df.loc[df['output_name'] == 'C0051821']
# Out:
#      input input_type                     pred1 pred1_source   pred1_api  \
# 1891  ACE2       Gene       activityDecreasedBy   semmedgene  semmedgene
# 1892  ACE2       Gene       activityDecreasedBy   semmedgene  semmedgene
# 1893  ACE2       Gene       activityDecreasedBy   semmedgene  semmedgene
# 1894  ACE2       Gene  molecularlyInteractsWith   semmedgene  semmedgene
# 1895  ACE2       Gene  molecularlyInteractsWith   semmedgene  semmedgene
# 1896  ACE2       Gene  molecularlyInteractsWith       semmed  semmedgene
# 1897  ACE2       Gene  molecularlyInteractsWith   semmedgene  semmedgene
# 1898  ACE2       Gene  molecularlyInteractsWith   semmedgene  semmedgene
# 1899  ACE2       Gene  molecularlyInteractsWith       semmed  semmedgene
# 1900  ACE2       Gene       decreasesActivityOf       semmed  semmedgene
# 1901  ACE2       Gene       activityDecreasedBy   semmedgene  semmedgene
# 1903  ACE2       Gene       activityDecreasedBy   semmedgene  semmedgene
# 1904  ACE2       Gene       activityDecreasedBy   semmedgene  semmedgene
# 1905  ACE2       Gene       activityDecreasedBy   semmedgene  semmedgene
# 1906  ACE2       Gene       activityDecreasedBy   semmedgene  semmedgene
# 1907  ACE2       Gene       decreasesActivityOf       semmed  semmedgene
# 1909  ACE2       Gene       decreasesActivityOf       semmed  semmedgene
# 1910  ACE2       Gene       decreasesActivityOf       semmed  semmedgene
#
#      pred1_pubmed node1_type node1_name       node1_id  \
# 1891         None       Gene   C1120843  umls:C1120843
# 1892         None       Gene   C3273301  umls:C3273301
# 1893         None       Gene   C1705633  umls:C1705633
# 1894         None       Gene   C1705633  umls:C1705633
# 1895         None       Gene   C0017337  umls:C0017337
# 1896         None       Gene   C0017337  umls:C0017337
# 1897         None       Gene   C0600388  umls:C0600388
# 1898         None       Gene   C1456380  umls:C1456380
# 1899         None       Gene   C0030956  umls:C0030956
# 1900         None       Gene   C1705543  umls:C1705543
# 1901         None       Gene        CRK    entrez:1398
# 1903         None       Gene      AHSA1   entrez:10598
# 1904         None       Gene      MAPK1    entrez:5594
# 1905         None       Gene      GRAP2    entrez:9402
# 1906         None       Gene    POLDIP2   entrez:26073
# 1907         None       Gene     DIANPH   entrez:23771
# 1909         None       Gene      TGFB1    entrez:7040
# 1910         None       Gene        APP     entrez:351
#
#                          pred2 pred2_source   pred2_api pred2_pubmed  \
# 1891  molecularlyInteractsWith       semmed  semmedgene         None
# 1892  molecularlyInteractsWith       semmed  semmedgene         None
# 1893  molecularlyInteractsWith       semmed  semmedgene         None
# 1894  molecularlyInteractsWith       semmed  semmedgene         None
# 1895  molecularlyInteractsWith       semmed  semmedgene         None
# 1896  molecularlyInteractsWith       semmed  semmedgene         None
# 1897  molecularlyInteractsWith       semmed  semmedgene         None
# 1898  molecularlyInteractsWith       semmed  semmedgene         None
# 1899  molecularlyInteractsWith       semmed  semmedgene         None
# 1900  molecularlyInteractsWith       semmed  semmedgene         None
# 1901  molecularlyInteractsWith       semmed  semmedgene         None
# 1903  molecularlyInteractsWith       semmed  semmedgene         None
# 1904  molecularlyInteractsWith       semmed  semmedgene         None
# 1905  molecularlyInteractsWith       semmed  semmedgene         None
# 1906  molecularlyInteractsWith       semmed  semmedgene         None
# 1907  molecularlyInteractsWith       semmed  semmedgene         None
# 1909  molecularlyInteractsWith       semmed  semmedgene         None
# 1910  molecularlyInteractsWith       semmed  semmedgene         None
#
#             output_type output_name      output_id
# 1891  ChemicalSubstance    C0051821  umls:C0051821
# 1892  ChemicalSubstance    C0051821  umls:C0051821
# 1893  ChemicalSubstance    C0051821  umls:C0051821
# 1894  ChemicalSubstance    C0051821  umls:C0051821
# 1895  ChemicalSubstance    C0051821  umls:C0051821
# 1896  ChemicalSubstance    C0051821  umls:C0051821
# 1897  ChemicalSubstance    C0051821  umls:C0051821
# 1898  ChemicalSubstance    C0051821  umls:C0051821
# 1899  ChemicalSubstance    C0051821  umls:C0051821
# 1900  ChemicalSubstance    C0051821  umls:C0051821
# 1901  ChemicalSubstance    C0051821  umls:C0051821
# 1903  ChemicalSubstance    C0051821  umls:C0051821
# 1904  ChemicalSubstance    C0051821  umls:C0051821
# 1905  ChemicalSubstance    C0051821  umls:C0051821
# 1906  ChemicalSubstance    C0051821  umls:C0051821
# 1907  ChemicalSubstance    C0051821  umls:C0051821
# 1909  ChemicalSubstance    C0051821  umls:C0051821
# 1910  ChemicalSubstance    C0051821  umls:C0051821

# %% [markdown]
# ### No. 39 NAFOXIDINE

# %%
df.loc[df['output_name'] == 'C0027328']
# Out:
#        input input_type                     pred1 pred1_source   pred1_api  \
# 124417  ACE2       Gene  molecularlyInteractsWith       semmed  semmedgene
#
#        pred1_pubmed node1_type node1_name       node1_id  \
# 124417         None       Gene   C0172537  umls:C0172537
#
#                            pred2 pred2_source   pred2_api pred2_pubmed  \
# 124417  molecularlyInteractsWith       semmed  semmedgene         None
#
#               output_type output_name      output_id
# 124417  ChemicalSubstance    C0027328  umls:C0027328

# %% [markdown]
# ### No. 48 RETINALDEHYDE

# %%
df.loc[df['output_name'] == 'C0035331']
# Out:
#       input input_type                     pred1 pred1_source   pred1_api  \
# 10725  ACE2       Gene       activityDecreasedBy   semmedgene  semmedgene
# 10726  ACE2       Gene       activityDecreasedBy   semmedgene  semmedgene
# 10727  ACE2       Gene  molecularlyInteractsWith   semmedgene  semmedgene
# 10728  ACE2       Gene  molecularlyInteractsWith       semmed  semmedgene
# 10731  ACE2       Gene  molecularlyInteractsWith       semmed  semmedgene
# 10733  ACE2       Gene       activityDecreasedBy   semmedgene  semmedgene
# 10734  ACE2       Gene       activityDecreasedBy   semmedgene  semmedgene
# 10735  ACE2       Gene  molecularlyInteractsWith   semmedgene  semmedgene
# 10738  ACE2       Gene       activityDecreasedBy   semmedgene  semmedgene
# 10740  ACE2       Gene  molecularlyInteractsWith   semmedgene  semmedgene
#
#       pred1_pubmed node1_type node1_name          node1_id  \
# 10725         None       Gene   C0033634     umls:C0033634
# 10726         None       Gene   C1705767     umls:C1705767
# 10727         None       Gene   C0017337     umls:C0017337
# 10728         None       Gene   C0017337     umls:C0017337
# 10731         None       Gene   C0014442     umls:C0014442
# 10733         None       Gene      MAPK1       entrez:5594
# 10734         None       Gene        TTR       entrez:7276
# 10735         None       Gene        TTR       entrez:7276
# 10738         None       Gene        RHO       entrez:6010
# 10740         None       Gene    ERVK-10  entrez:100616101
#
#                           pred2 pred2_source   pred2_api pred2_pubmed  \
# 10725  molecularlyInteractsWith       semmed  semmedgene         None
# 10726  molecularlyInteractsWith       semmed  semmedgene         None
# 10727  molecularlyInteractsWith       semmed  semmedgene         None
# 10728  molecularlyInteractsWith       semmed  semmedgene         None
# 10731  molecularlyInteractsWith       semmed  semmedgene         None
# 10733  molecularlyInteractsWith       semmed  semmedgene         None
# 10734  molecularlyInteractsWith       semmed  semmedgene         None
# 10735  molecularlyInteractsWith       semmed  semmedgene         None
# 10738  molecularlyInteractsWith       semmed  semmedgene         None
# 10740  molecularlyInteractsWith       semmed  semmedgene         None
#
#              output_type output_name      output_id
# 10725  ChemicalSubstance    C0035331  umls:C0035331
# 10726  ChemicalSubstance    C0035331  umls:C0035331
# 10727  ChemicalSubstance    C0035331  umls:C0035331
# 10728  ChemicalSubstance    C0035331  umls:C0035331
# 10731  ChemicalSubstance    C0035331  umls:C0035331
# 10733  ChemicalSubstance    C0035331  umls:C0035331
# 10734  ChemicalSubstance    C0035331  umls:C0035331
# 10735  ChemicalSubstance    C0035331  umls:C0035331
# 10738  ChemicalSubstance    C0035331  umls:C0035331
# 10740  ChemicalSubstance    C0035331  umls:C0035331

# %% [markdown]
# ### No. 59 CLOFAZIMINE

# %%
df.loc[df['output_name'] == 'CLOFAZIMINE']
# Out:
#       input input_type                pred1 pred1_source   pred1_api  \
# 17999  ACE2       Gene  activityDecreasedBy   semmedgene  semmedgene
#
#       pred1_pubmed node1_type node1_name       node1_id  \
# 17999         None       Gene   C0033634  umls:C0033634
#
#                           pred2 pred2_source   pred2_api pred2_pubmed  \
# 17999  molecularlyInteractsWith       semmed  semmedgene         None
#
#              output_type  output_name          output_id
# 17999  ChemicalSubstance  CLOFAZIMINE  chembl:CHEMBL1292

# %% [markdown]
# ### No. 63 PERHEXILINE

# %%
df.loc[df['output_name'] == 'PERHEXILINE']
# Out:
#       input input_type           pred1   pred1_source      pred1_api  \
# 20432  ACE2       Gene  associatedWith  semmeddisease  semmeddisease
# 20433  ACE2       Gene  associatedWith       DISEASES       DISEASES
#
#       pred1_pubmed                  node1_type               node1_name  \
# 20432         None  DiseaseOrPhenotypicFeature                 C0879626
# 20433         None  DiseaseOrPhenotypicFeature  coronary artery disease
#
#                   node1_id      pred2 pred2_source      pred2_api  \
# 20432        umls:C0879626  treatedBy       semmed  semmeddisease
# 20433  mondo:MONDO:0005010  treatedBy       semmed  semmeddisease
#
#       pred2_pubmed        output_type  output_name           output_id
# 20432         None  ChemicalSubstance  PERHEXILINE  chembl:CHEMBL75880
# 20433         None  ChemicalSubstance  PERHEXILINE  chembl:CHEMBL75880

# %% [markdown]
# ### No. 65 resiniferatoxin

# %%
df.loc[df['output_name'] == 'C0073081']
# Out:
#       input input_type                pred1 pred1_source   pred1_api  \
# 14327  ACE2       Gene  decreasesActivityOf       semmed  semmedgene
# 14329  ACE2       Gene  decreasesActivityOf       semmed  semmedgene
#
#       pred1_pubmed node1_type node1_name       node1_id  \
# 14327         None       Gene   C1709136  umls:C1709136
# 14329         None       Gene   C0669365  umls:C0669365
#
#                           pred2 pred2_source   pred2_api pred2_pubmed  \
# 14327  molecularlyInteractsWith       semmed  semmedgene         None
# 14329  molecularlyInteractsWith       semmed  semmedgene         None
#
#              output_type output_name      output_id
# 14327  ChemicalSubstance    C0073081  umls:C0073081
# 14329  ChemicalSubstance    C0073081  umls:C0073081

# %% [markdown]
# ### No. 69 EBASTINE

# %%
df.loc[df['output_name'] == 'EBASTINE']
# Out:
#       input input_type                     pred1 pred1_source   pred1_api  \
# 20415  ACE2       Gene  molecularlyInteractsWith   semmedgene  semmedgene
# 20416  ACE2       Gene  molecularlyInteractsWith       semmed  semmedgene
#
#       pred1_pubmed node1_type node1_name       node1_id  \
# 20415         None       Gene   C0017337  umls:C0017337
# 20416         None       Gene   C0017337  umls:C0017337
#
#                           pred2 pred2_source   pred2_api pred2_pubmed  \
# 20415  molecularlyInteractsWith       semmed  semmedgene         None
# 20416  molecularlyInteractsWith       semmed  semmedgene         None
#
#              output_type output_name            output_id
# 20415  ChemicalSubstance    EBASTINE  chembl:CHEMBL305660
# 20416  ChemicalSubstance    EBASTINE  chembl:CHEMBL305660

# %% [markdown]
# ### No. 73 5-Azacytidine

# %%
df.loc[df['output_name'] == 'AZACITIDINE']
# Out:
#       input input_type                     pred1 pred1_source   pred1_api  \
# 12795  ACE2       Gene       activityDecreasedBy   semmedgene  semmedgene
# 12796  ACE2       Gene       activityDecreasedBy   semmedgene  semmedgene
# 12797  ACE2       Gene  molecularlyInteractsWith   semmedgene  semmedgene
# 12798  ACE2       Gene  molecularlyInteractsWith       semmed  semmedgene
# 12799  ACE2       Gene  molecularlyInteractsWith       semmed  semmedgene
# 12802  ACE2       Gene       activityDecreasedBy   semmedgene  semmedgene
# 12803  ACE2       Gene       activityDecreasedBy   semmedgene  semmedgene
#
#       pred1_pubmed node1_type node1_name       node1_id  \
# 12795         None       Gene   C0033634  umls:C0033634
# 12796         None       Gene   C1705767  umls:C1705767
# 12797         None       Gene   C0017337  umls:C0017337
# 12798         None       Gene   C0017337  umls:C0017337
# 12799         None       Gene   C0014442  umls:C0014442
# 12802         None       Gene        CRK    entrez:1398
# 12803         None       Gene      MAPK1    entrez:5594
#
#                           pred2 pred2_source   pred2_api pred2_pubmed  \
# 12795  molecularlyInteractsWith       semmed  semmedgene         None
# 12796  molecularlyInteractsWith       semmed  semmedgene         None
# 12797  molecularlyInteractsWith       semmed  semmedgene         None
# 12798  molecularlyInteractsWith       semmed  semmedgene         None
# 12799  molecularlyInteractsWith       semmed  semmedgene         None
# 12802  molecularlyInteractsWith       semmed  semmedgene         None
# 12803  molecularlyInteractsWith       semmed  semmedgene         None
#
#              output_type  output_name          output_id
# 12795  ChemicalSubstance  AZACITIDINE  chembl:CHEMBL1489
# 12796  ChemicalSubstance  AZACITIDINE  chembl:CHEMBL1489
# 12797  ChemicalSubstance  AZACITIDINE  chembl:CHEMBL1489
# 12798  ChemicalSubstance  AZACITIDINE  chembl:CHEMBL1489
# 12799  ChemicalSubstance  AZACITIDINE  chembl:CHEMBL1489
# 12802  ChemicalSubstance  AZACITIDINE  chembl:CHEMBL1489
# 12803  ChemicalSubstance  AZACITIDINE  chembl:CHEMBL1489

# %% [markdown]
# ### No. 76 AMIODARONE

# %%
df.loc[df['output_name'] == 'AMIODARONE']
# Out:
#      input input_type           pred1 pred1_source   pred1_api pred1_pubmed  \
# 6355  ACE2       Gene  associatedWith       semmed  semmedgene         None
# 6356  ACE2       Gene  associatedWith       semmed  semmedgene         None
#
#              node1_type                   node1_name       node1_id  \
# 6355  BiologicalProcess  Ventricular Function, Right  umls:C0080311
# 6356  BiologicalProcess    Left Ventricle Remodeling  umls:C0600520
#
#                pred2    pred2_source       pred2_api pred2_pubmed  \
# 6355  associatedWith  semmedchemical  semmedchemical         None
# 6356  associatedWith  semmedchemical  semmedchemical         None
#
#             output_type output_name         output_id
# 6355  ChemicalSubstance  AMIODARONE  chembl:CHEMBL633
# 6356  ChemicalSubstance  AMIODARONE  chembl:CHEMBL633

# %%
df.loc[df['output_name'] == 'C0700442']
# Out:
#        input input_type           pred1   pred1_source      pred1_api  \
# 114038  ACE2       Gene  associatedWith       DISEASES       DISEASES
# 114039  ACE2       Gene  associatedWith  semmeddisease  semmeddisease
# 114040  ACE2       Gene  associatedWith       DISEASES       DISEASES
# 114041  ACE2       Gene  associatedWith  semmeddisease  semmeddisease
# 114042  ACE2       Gene  associatedWith  semmeddisease  semmeddisease
# 114043  ACE2       Gene          causes  semmeddisease  semmeddisease
#
#        pred1_pubmed                  node1_type  \
# 114038         None  DiseaseOrPhenotypicFeature
# 114039         None  DiseaseOrPhenotypicFeature
# 114040         None  DiseaseOrPhenotypicFeature
# 114041         None  DiseaseOrPhenotypicFeature
# 114042         None  DiseaseOrPhenotypicFeature
# 114043         None  DiseaseOrPhenotypicFeature
#
#                            node1_name             node1_id      pred2  \
# 114038                  heart disease  mondo:MONDO:0005267  treatedBy
# 114039                  heart disease  mondo:MONDO:0005267  treatedBy
# 114040        coronary artery disease  mondo:MONDO:0005010  treatedBy
# 114041      idiopathic cardiomyopathy  mondo:MONDO:0005110  treatedBy
# 114042  atrial fibrillation (disease)  mondo:MONDO:0004981  treatedBy
# 114043       congenital heart disease  mondo:MONDO:0005453  treatedBy
#
#        pred2_source      pred2_api pred2_pubmed        output_type  \
# 114038       semmed  semmeddisease         None  ChemicalSubstance
# 114039       semmed  semmeddisease         None  ChemicalSubstance
# 114040       semmed  semmeddisease         None  ChemicalSubstance
# 114041       semmed  semmeddisease         None  ChemicalSubstance
# 114042       semmed  semmeddisease         None  ChemicalSubstance
# 114043       semmed  semmeddisease         None  ChemicalSubstance
#
#        output_name      output_id
# 114038    C0700442  umls:C0700442
# 114039    C0700442  umls:C0700442
# 114040    C0700442  umls:C0700442
# 114041    C0700442  umls:C0700442
# 114042    C0700442  umls:C0700442
# 114043    C0700442  umls:C0700442

# %% [markdown]
# Above refers to Amiodarone hydrochloride

# %% [markdown]
# ### No. 79 NSP 805

# %%
df.loc[df['output_name'] == 'C0660146']
# Out:
#       input input_type           pred1   pred1_source      pred1_api  \
# 24174  ACE2       Gene  associatedWith  semmeddisease  semmeddisease
#
#       pred1_pubmed                  node1_type node1_name       node1_id  \
# 24174         None  DiseaseOrPhenotypicFeature   C0018802  umls:C0018802
#
#            pred2 pred2_source      pred2_api pred2_pubmed        output_type  \
# 24174  treatedBy       semmed  semmeddisease         None  ChemicalSubstance
#
#       output_name      output_id
# 24174    C0660146  umls:C0660146

# %% [markdown]
# ### No. 81 CLORICROMENE

# %%
df.loc[df['output_name'] == 'C0050066']
# Out:
#        input input_type                     pred1 pred1_source   pred1_api  \
# 114517  ACE2       Gene  molecularlyInteractsWith       semmed  semmedgene
#
#        pred1_pubmed node1_type node1_name       node1_id  \
# 114517         None       Gene   C0014442  umls:C0014442
#
#                            pred2 pred2_source   pred2_api pred2_pubmed  \
# 114517  molecularlyInteractsWith       semmed  semmedgene         None
#
#               output_type output_name      output_id
# 114517  ChemicalSubstance    C0050066  umls:C0050066

# %% [markdown]
# ### No. 82 TIFLUADOM

# %%
df.loc[df['output_name'] == 'C0076670']
# Out:
#       input input_type           pred1   pred1_source      pred1_api  \
# 17363  ACE2       Gene  associatedWith  semmeddisease  semmeddisease
#
#       pred1_pubmed                  node1_type node1_name       node1_id  \
# 17363         None  DiseaseOrPhenotypicFeature   C0687133  umls:C0687133
#
#                 pred2 pred2_source      pred2_api pred2_pubmed  \
# 17363  associatedWith       semmed  semmeddisease         None
#
#              output_type output_name      output_id
# 17363  ChemicalSubstance    C0076670  umls:C0076670

# %% [markdown]
# ### No. 85 SCH-28080

# %%
df.loc[df['output_name'] == 'C0074142']
# Out:
#        input input_type                     pred1 pred1_source   pred1_api  \
# 131058  ACE2       Gene  molecularlyInteractsWith       semmed  semmedgene
#
#        pred1_pubmed node1_type node1_name       node1_id  \
# 131058         None       Gene   C0014442  umls:C0014442
#
#                            pred2 pred2_source   pred2_api pred2_pubmed  \
# 131058  molecularlyInteractsWith       semmed  semmedgene         None
#
#               output_type output_name      output_id
# 131058  ChemicalSubstance    C0074142  umls:C0074142

# %% [markdown]
# ### NO. 96 IMMUNOMYCIN

# %%
df.loc[df['output_name'] == 'C0123418']
# Out:
#        input input_type                     pred1 pred1_source   pred1_api  \
# 131170  ACE2       Gene  molecularlyInteractsWith       semmed  semmedgene
#
#        pred1_pubmed node1_type node1_name       node1_id  \
# 131170         None       Gene   C0014442  umls:C0014442
#
#                            pred2 pred2_source   pred2_api pred2_pubmed  \
# 131170  molecularlyInteractsWith       semmed  semmedgene         None
#
#               output_type output_name      output_id
# 131170  ChemicalSubstance    C0123418  umls:C0123418

# %% [markdown]
# ### NO.97 ARGLABIN

# %%
df.loc[df['output_name'] == 'C0661380']
# Out:
#      input input_type           pred1   pred1_source      pred1_api  \
# 9498  ACE2       Gene  associatedWith  semmeddisease  semmeddisease
#
#      pred1_pubmed                  node1_type node1_name       node1_id  \
# 9498         None  DiseaseOrPhenotypicFeature   C0021368  umls:C0021368
#
#           pred2 pred2_source      pred2_api pred2_pubmed        output_type  \
# 9498  treatedBy       semmed  semmeddisease         None  ChemicalSubstance
#
#      output_name      output_id
# 9498    C0661380  umls:C0661380

# %% [markdown]
# ### NO.100 TRETINOIN

# %%
df.loc[df['output_name'] == 'TRETINOIN']
# Out:
#      input input_type           pred1 pred1_source   pred1_api pred1_pubmed  \
# 6477  ACE2       Gene  associatedWith       semmed  semmedgene         None
# 6478  ACE2       Gene  associatedWith       semmed  semmedgene         None
# 6480  ACE2       Gene  associatedWith       semmed  semmedgene         None
# 6481  ACE2       Gene  associatedWith       semmed  semmedgene         None
# 6483  ACE2       Gene  associatedWith       semmed  semmedgene         None
#
#              node1_type                       node1_name       node1_id  \
# 6477  BiologicalProcess                       Cell Cycle  umls:C0007586
# 6478  BiologicalProcess                  Down-Regulation  umls:C0013081
# 6480  BiologicalProcess                    Morphogenesis  umls:C0026559
# 6481  BiologicalProcess               Cell Proliferation  umls:C0596290
# 6483  BiologicalProcess  Post-Transcriptional Regulation  umls:C1514248
#
#                pred2    pred2_source       pred2_api pred2_pubmed  \
# 6477        causedBy  semmedchemical  semmedchemical         None
# 6478        causedBy  semmedchemical  semmedchemical         None
# 6480  associatedWith  semmedchemical  semmedchemical         None
# 6481        causedBy  semmedchemical  semmedchemical         None
# 6483  associatedWith  semmedchemical  semmedchemical         None
#
#             output_type output_name        output_id
# 6477  ChemicalSubstance   TRETINOIN  chembl:CHEMBL38
# 6478  ChemicalSubstance   TRETINOIN  chembl:CHEMBL38
# 6480  ChemicalSubstance   TRETINOIN  chembl:CHEMBL38
# 6481  ChemicalSubstance   TRETINOIN  chembl:CHEMBL38
# 6483  ChemicalSubstance   TRETINOIN  chembl:CHEMBL38
