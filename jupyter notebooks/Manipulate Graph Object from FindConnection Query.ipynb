# %%
from biothings_explorer.user_query_dispatcher import FindConnection
from biothings_explorer.hint import Hint

# %%
ht = Hint()
# find all potential representations of CML
cml_hint = ht.query("chronic myelogenous leukemia")
# select the correct representation of CML
cml = cml_hint['Disease'][0]
cml
# Out:
# http://mydisease.info/v1/query {'fields': '_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet', 'dotfield': 'true', 'species': 'human', 'size': '5'} {'q': '"chronic myelogenous leukemia"', 'scopes': '_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet'}
# https://myvariant.info/v1/query {'fields': '_id,dbsnp.rsid,clinvar.rsid,dbnsfp.rsid,clinvar.hgvs.genomic,clinvar.hgvs.protein,clinvar.hgvs.coding,clinvar.rcv.accession', 'dotfield': 'true', 'species': 'human', 'size': '5'} {'q': '"chronic myelogenous leukemia"', 'scopes': '_id,dbsnp.rsid,clinvar.rsid,dbnsfp.rsid,clinvar.hgvs.genomic,clinvar.hgvs.protein,clinvar.hgvs.coding,clinvar.rcv.accession'}
# https://mychem.info/v1/query {'fields': 'chembl.molecule_chembl_id,drugbank.xrefs.chembl,drugcentral.xrefs.chembl_id,drugcentral.xrefs.drugbank_id,pharmgkb.xrefs.drugbank,chebi.xrefs.drugbank,drugbank.id,pubchem.cid,drugbank.xrefs.pubchem.cid,drugcentral.xrefs.pubchem_cid,pharmgkb.xrefs.pubchem.cid,chebi.id,chembl.chebi_par_id,drugbank.xrefs.chebi,drugcentral.xrefs.chebi,drugcentral.xrefs.umlscui,pharmgkb.xrefs.umls,umls.cui,umls.mesh,drugcentral.xrefs.mesh_descriptor_ui,ginas.xrefs.MESH,pharmgkb.xrefs.mesh,drugcentral.xrefs.unii,unii.unii,aeolus.unii,ginas.unii,chembl.pref_name,drugbank.name,umls.name,ginas.preferred_name,pharmgkb.name,chebi.name', 'dotfield': 'true', 'species': 'human', 'size': '5'} {'q': '"chronic myelogenous leukemia"', 'scopes': 'chembl.molecule_chembl_id,drugbank.xrefs.chembl,drugcentral.xrefs.chembl_id,drugcentral.xrefs.drugbank_id,pharmgkb.xrefs.drugbank,chebi.xrefs.drugbank,drugbank.id,pubchem.cid,drugbank.xrefs.pubchem.cid,drugcentral.xrefs.pubchem_cid,pharmgkb.xrefs.pubchem.cid,chebi.id,chembl.chebi_par_id,drugbank.xrefs.chebi,drugcentral.xrefs.chebi,drugcentral.xrefs.umlscui,pharmgkb.xrefs.umls,umls.cui,umls.mesh,drugcentral.xrefs.mesh_descriptor_ui,ginas.xrefs.MESH,pharmgkb.xrefs.mesh,drugcentral.xrefs.unii,unii.unii,aeolus.unii,ginas.unii,chembl.pref_name,drugbank.name,umls.name,ginas.preferred_name,pharmgkb.name,chebi.name'}
# https://biothings.ncats.io/geneset/query {'fields': 'go,umls,name,reactome,wikipathways,kegg,pharmgkb,type', 'dotfield': 'true', 'species': 'human', 'size': '5'} {'q': '"chronic myelogenous leukemia"', 'scopes': 'go,umls,name,reactome,wikipathways,kegg,pharmgkb,type'}
# https://biothings.ncats.io/semmedphenotype/query {'fields': 'name,umls', 'dotfield': 'true', 'species': 'human', 'size': '5'} {'q': '"chronic myelogenous leukemia"', 'scopes': 'name,umls'}
# https://biothings.ncats.io/semmed_anatomy/query {'fields': 'name,umls', 'dotfield': 'true', 'species': 'human', 'size': '5'} {'q': '"chronic myelogenous leukemia"', 'scopes': 'name,umls'}
# https://mygene.info/v3/query {'fields': 'entrezgene,name,symbol,umls.cui,umls.protein_cui,HGNC,uniprot.Swiss-Prot,ensembl.gene,OMIM,MGI', 'dotfield': 'true', 'species': 'human', 'size': '5'} {'q': '"chronic myelogenous leukemia"', 'scopes': 'entrezgene,name,symbol,umls.cui,umls.protein_cui,HGNC,uniprot.Swiss-Prot,ensembl.gene,OMIM,MGI'}
# {'MONDO': 'MONDO:0011996',
#  'DOID': 'DOID:8552',
#  'UMLS': 'C0023473',
#  'name': 'chronic myelogenous leukemia, BCR-ABL1 positive',
#  'OMIM': '608232',
#  'ORPHANET': '521',
#  'primary': {'identifier': 'MONDO',
#   'cls': 'Disease',
#   'value': 'MONDO:0011996'},
#  'display': 'MONDO(MONDO:0011996) DOID(DOID:8552) OMIM(608232) ORPHANET(521) UMLS(C0023473) name(chronic myelogenous leukemia, BCR-ABL1 positive)',
#  'type': 'Disease'}

# %%
# find all potential representations of imatinib
imatinib_hint = ht.query("imatinib")
# select the correct representation of imatinib
imatinib = imatinib_hint['ChemicalSubstance'][0]
imatinib
# Out:
# http://mydisease.info/v1/query {'fields': '_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet', 'dotfield': 'true', 'species': 'human', 'size': '5'} {'q': '"imatinib"', 'scopes': '_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet'}
# https://mygene.info/v3/query {'fields': 'entrezgene,name,symbol,umls.cui,umls.protein_cui,HGNC,uniprot.Swiss-Prot,ensembl.gene,OMIM,MGI', 'dotfield': 'true', 'species': 'human', 'size': '5'} {'q': '"imatinib"', 'scopes': 'entrezgene,name,symbol,umls.cui,umls.protein_cui,HGNC,uniprot.Swiss-Prot,ensembl.gene,OMIM,MGI'}
# https://biothings.ncats.io/semmed_anatomy/query {'fields': 'name,umls', 'dotfield': 'true', 'species': 'human', 'size': '5'} {'q': '"imatinib"', 'scopes': 'name,umls'}
# https://biothings.ncats.io/semmedphenotype/query {'fields': 'name,umls', 'dotfield': 'true', 'species': 'human', 'size': '5'} {'q': '"imatinib"', 'scopes': 'name,umls'}
# https://biothings.ncats.io/geneset/query {'fields': 'go,umls,name,reactome,wikipathways,kegg,pharmgkb,type', 'dotfield': 'true', 'species': 'human', 'size': '5'} {'q': '"imatinib"', 'scopes': 'go,umls,name,reactome,wikipathways,kegg,pharmgkb,type'}
# https://myvariant.info/v1/query {'fields': '_id,dbsnp.rsid,clinvar.rsid,dbnsfp.rsid,clinvar.hgvs.genomic,clinvar.hgvs.protein,clinvar.hgvs.coding,clinvar.rcv.accession', 'dotfield': 'true', 'species': 'human', 'size': '5'} {'q': '"imatinib"', 'scopes': '_id,dbsnp.rsid,clinvar.rsid,dbnsfp.rsid,clinvar.hgvs.genomic,clinvar.hgvs.protein,clinvar.hgvs.coding,clinvar.rcv.accession'}
# https://mychem.info/v1/query {'fields': 'chembl.molecule_chembl_id,drugbank.xrefs.chembl,drugcentral.xrefs.chembl_id,drugcentral.xrefs.drugbank_id,pharmgkb.xrefs.drugbank,chebi.xrefs.drugbank,drugbank.id,pubchem.cid,drugbank.xrefs.pubchem.cid,drugcentral.xrefs.pubchem_cid,pharmgkb.xrefs.pubchem.cid,chebi.id,chembl.chebi_par_id,drugbank.xrefs.chebi,drugcentral.xrefs.chebi,drugcentral.xrefs.umlscui,pharmgkb.xrefs.umls,umls.cui,umls.mesh,drugcentral.xrefs.mesh_descriptor_ui,ginas.xrefs.MESH,pharmgkb.xrefs.mesh,drugcentral.xrefs.unii,unii.unii,aeolus.unii,ginas.unii,chembl.pref_name,drugbank.name,umls.name,ginas.preferred_name,pharmgkb.name,chebi.name', 'dotfield': 'true', 'species': 'human', 'size': '5'} {'q': '"imatinib"', 'scopes': 'chembl.molecule_chembl_id,drugbank.xrefs.chembl,drugcentral.xrefs.chembl_id,drugcentral.xrefs.drugbank_id,pharmgkb.xrefs.drugbank,chebi.xrefs.drugbank,drugbank.id,pubchem.cid,drugbank.xrefs.pubchem.cid,drugcentral.xrefs.pubchem_cid,pharmgkb.xrefs.pubchem.cid,chebi.id,chembl.chebi_par_id,drugbank.xrefs.chebi,drugcentral.xrefs.chebi,drugcentral.xrefs.umlscui,pharmgkb.xrefs.umls,umls.cui,umls.mesh,drugcentral.xrefs.mesh_descriptor_ui,ginas.xrefs.MESH,pharmgkb.xrefs.mesh,drugcentral.xrefs.unii,unii.unii,aeolus.unii,ginas.unii,chembl.pref_name,drugbank.name,umls.name,ginas.preferred_name,pharmgkb.name,chebi.name'}
# {'DRUGBANK': 'DB00619',
#  'CHEBI': 'CHEBI:45783',
#  'name': 'imatinib',
#  'primary': {'identifier': 'CHEBI',
#   'cls': 'ChemicalSubstance',
#   'value': 'CHEBI:45783'},
#  'display': 'CHEBI(CHEBI:45783) DRUGBANK(DB00619) name(imatinib)',
#  'type': 'ChemicalSubstance'}

# %%
fc = FindConnection(input_obj=cml, output_obj=imatinib, intermediate_nodes='Gene')

# %%
# set verbose=True will display all steps which BTE takes to find the connection
fc.connect(verbose=True)
# Out:
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'chronic myelogenous leukemia, BCR-ABL1 positive' and 'imatinib'. Paths will have 1 intermediate node.
#
# Intermediate node #1 will have these type constraints: Gene
#
#
# ==========
# ========== QUERY #1 -- fetch all Gene entities linked to 'chronic myelogenous leukemia, BCR-ABL1 positive' ==========
# ==========
#
#
# BTE found 1 apis:
#
# API 1. mydisease.info(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# http://mydisease.info/v1/query {'fields': '_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet', 'dotfield': 'true', 'species': 'human'} {'q': 'MONDO:0011996', 'scopes': '_id'}
# 1: http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human (POST -d q=MONDO:0011996&scopes=_id)
# ==== Step #1: Query path planning ====
#
# Because chronic myelogenous leukemia, BCR-ABL1 positive is of type 'Disease', BTE will query our meta-KG for APIs that can take 'Disease' as input and 'Gene' as output
#
# BTE found 10 apis:
#
# API 1. DISEASES(1 API call)
# API 2. scigraph(1 API call)
# API 3. pharos(1 API call)
# API 4. cord_disease(1 API call)
# API 5. scibite(1 API call)
# API 6. semmed_disease(15 API calls)
# API 7. hetio(1 API call)
# API 8. mydisease(1 API call)
# API 9. mgi_gene2phenotype(1 API call)
# API 10. biolink(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# https://mydisease.info/v1/query {'fields': 'disgenet.genes_related_to_disease.gene_id'} {'q': 'C0023473,C0023474', 'scopes': 'mondo.xrefs.umls, disgenet.xrefs.umls'}
# API 8.1: https://mydisease.info/v1/query?fields=disgenet.genes_related_to_disease.gene_id (POST -d q=C0023473,C0023474&scopes=mondo.xrefs.umls, disgenet.xrefs.umls)
# https://biothings.ncats.io/semmed/query {'fields': 'coexists_with'} {'q': 'C0023473,C0023474', 'scopes': 'umls'}
# API 6.2: https://biothings.ncats.io/semmed/query?fields=coexists_with (POST -d q=C0023473,C0023474&scopes=umls)
# https://biothings.ncats.io/semmed/query {'fields': 'caused_by'} {'q': 'C0023473,C0023474', 'scopes': 'umls'}
# API 6.14: https://biothings.ncats.io/semmed/query?fields=caused_by (POST -d q=C0023473,C0023474&scopes=umls)
# https://biothings.ncats.io/cord_disease/query {'fields': 'associated_with'} {'q': 'DOID:8552', 'scopes': 'doid'}
# API 4.1: https://biothings.ncats.io/cord_disease/query?fields=associated_with (POST -d q=DOID:8552&scopes=doid)
# https://biothings.ncats.io/semmed/query {'fields': 'disrupted_by'} {'q': 'C0023473,C0023474', 'scopes': 'umls'}
# API 6.9: https://biothings.ncats.io/semmed/query?fields=disrupted_by (POST -d q=C0023473,C0023474&scopes=umls)
# https://biothings.ncats.io/semmed/query {'fields': 'positively_regulates'} {'q': 'C0023473,C0023474', 'scopes': 'umls'}
# API 6.4: https://biothings.ncats.io/semmed/query?fields=positively_regulates (POST -d q=C0023473,C0023474&scopes=umls)
# https://biothings.ncats.io/semmed/query {'fields': 'negatively_regulates'} {'q': 'C0023473,C0023474', 'scopes': 'umls'}
# API 6.11: https://biothings.ncats.io/semmed/query?fields=negatively_regulates (POST -d q=C0023473,C0023474&scopes=umls)
# https://biothings.ncats.io/semmed/query {'fields': 'disrupts'} {'q': 'C0023473,C0023474', 'scopes': 'umls'}
# API 6.13: https://biothings.ncats.io/semmed/query?fields=disrupts (POST -d q=C0023473,C0023474&scopes=umls)
# https://biothings.ncats.io/semmed/query {'fields': 'affects'} {'q': 'C0023473,C0023474', 'scopes': 'umls'}
# API 6.1: https://biothings.ncats.io/semmed/query?fields=affects (POST -d q=C0023473,C0023474&scopes=umls)
# https://biothings.ncats.io/semmed/query {'fields': 'negatively_regulated_by'} {'q': 'C0023473,C0023474', 'scopes': 'umls'}
# API 6.15: https://biothings.ncats.io/semmed/query?fields=negatively_regulated_by (POST -d q=C0023473,C0023474&scopes=umls)
# https://biothings.ncats.io/semmed/query {'fields': 'physically_interacts_with'} {'q': 'C0023473,C0023474', 'scopes': 'umls'}
# API 6.5: https://biothings.ncats.io/semmed/query?fields=physically_interacts_with (POST -d q=C0023473,C0023474&scopes=umls)
# https://biothings.ncats.io/semmed/query {'fields': 'positively_regulated_by'} {'q': 'C0023473,C0023474', 'scopes': 'umls'}
# API 6.7: https://biothings.ncats.io/semmed/query?fields=positively_regulated_by (POST -d q=C0023473,C0023474&scopes=umls)
# https://biothings.ncats.io/semmed/query {'fields': 'derives_from'} {'q': 'C0023473,C0023474', 'scopes': 'umls'}
# API 6.8: https://biothings.ncats.io/semmed/query?fields=derives_from (POST -d q=C0023473,C0023474&scopes=umls)
# https://biothings.ncats.io/semmed/query {'fields': 'prevented_by'} {'q': 'C0023473,C0023474', 'scopes': 'umls'}
# API 6.3: https://biothings.ncats.io/semmed/query?fields=prevented_by (POST -d q=C0023473,C0023474&scopes=umls)
# https://biothings.ncats.io/semmed/query {'fields': 'related_to'} {'q': 'C0023473,C0023474', 'scopes': 'umls'}
# API 6.12: https://biothings.ncats.io/semmed/query?fields=related_to (POST -d q=C0023473,C0023474&scopes=umls)
# https://biothings.ncats.io/semmed/query {'fields': 'affected_by'} {'q': 'C0023473,C0023474', 'scopes': 'umls'}
# API 6.10: https://biothings.ncats.io/semmed/query?fields=affected_by (POST -d q=C0023473,C0023474&scopes=umls)
# https://biothings.ncats.io/semmed/query {'fields': 'treated_by'} {'q': 'C0023473,C0023474', 'scopes': 'umls'}
# API 6.6: https://biothings.ncats.io/semmed/query?fields=treated_by (POST -d q=C0023473,C0023474&scopes=umls)
# API 10.1: https://api.monarchinitiative.org/api/bioentity/disease/MONDO:0011996/genes?rows=200
# https://pending.biothings.io/DISEASES/query {'fields': 'DISEASES.associatedWith'} {'q': 'DOID:8552', 'scopes': 'DISEASES.doid'}
# API 1.1: https://pending.biothings.io/DISEASES/query?fields=DISEASES.associatedWith (POST -d q=DOID:8552&scopes=DISEASES.doid)
# https://pending.biothings.io/mgigene2phenotype/query {'fields': '_id', 'size': '300'} {'q': 'DOID:8552', 'scopes': 'mgi.associated_with_disease.doid'}
# API 9.1: https://pending.biothings.io/mgigene2phenotype/query?fields=_id&size=300 (POST -d q=DOID:8552&scopes=mgi.associated_with_disease.doid)
# API 7.1: https://automat.renci.org/hetio/disease/gene/MONDO:0011996
# API 3.1: https://automat.renci.org/pharos/disease/gene/MONDO:0011996
# API 2.1: https://automat.renci.org/cord19_scigraph_v2/disease/gene/MONDO:0011996
# API 5.1: https://automat.renci.org/cord19_scibite_v2/disease/gene/MONDO:0011996
#
#
# ==== Step #3: Output normalization ====
#
# API 9.1 mgi_gene2phenotype: 8 hits
# API 6.1 semmed_disease: No hits
# API 6.2 semmed_disease: No hits
# API 1.1 DISEASES: 3 hits
# API 6.3 semmed_disease: 7 hits
# API 6.4 semmed_disease: No hits
# API 6.5 semmed_disease: No hits
# API 6.6 semmed_disease: 138 hits
# API 6.7 semmed_disease: No hits
# API 3.1 pharos: 7 hits
# API 6.8 semmed_disease: No hits
# API 2.1 scigraph: 3 hits
# API 6.9 semmed_disease: 26 hits
# API 4.1 cord_disease: 146 hits
# API 6.10 semmed_disease: 66 hits
# API 5.1 scibite: 12 hits
# API 7.1 hetio: No hits
# API 6.11 semmed_disease: No hits
# API 6.12 semmed_disease: 570 hits
# API 8.1 mydisease: No hits
# API 6.13 semmed_disease: No hits
# API 6.14 semmed_disease: 92 hits
# API 10.1 biolink: 4 hits
# API 6.15 semmed_disease: No hits
# check output_ids False
# output_ids_dict keys dict_keys(['Gene,MGI', 'Gene,SYMBOL', 'Gene,HGNC', 'Gene,UMLS', 'Gene,NCBIGene'])
#
# BTE found 1 apis:
#
# API 1. mygene.info(5 API calls)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# https://mygene.info/v3/query {'fields': 'entrezgene,name,symbol,umls.cui,umls.protein_cui,HGNC,uniprot.Swiss-Prot,ensembl.gene,OMIM,MGI', 'dotfield': 'true', 'species': 'human'} {'q': 'MGI:3621056,MGI:893598,MGI:3834478,MGI:1914167,MGI:107576,MGI:1891700,MGI:3834459,MGI:3834460', 'scopes': 'MGI'}
# 1: https://mygene.info/v3/query?fields=entrezgene,name,symbol,umls.cui,umls.protein_cui,HGNC,uniprot.Swiss-Prot,ensembl.gene,OMIM,MGI&dotfield=true&species=human (POST -d q=MGI:3621056,MGI:893598,MGI:3834478,MGI:1914167,MGI:107576,MGI:1891700,MGI:3834459,MGI:3834460&scopes=MGI)
# https://mygene.info/v3/query {'fields': 'entrezgene,name,symbol,umls.cui,umls.protein_cui,HGNC,uniprot.Swiss-Prot,ensembl.gene,OMIM,MGI', 'dotfield': 'true', 'species': 'human'} {'q': '2950,6580,84955,1796,9920,332,613,5624,3717,920,25,5159,284348,2157,94,7015,3791,5156,56648,9001,318', 'scopes': 'entrezgene'}
# 1: https://mygene.info/v3/query?fields=entrezgene,name,symbol,umls.cui,umls.protein_cui,HGNC,uniprot.Swiss-Prot,ensembl.gene,OMIM,MGI&dotfield=true&species=human (POST -d q=2950,6580,84955,1796,9920,332,613,5624,3717,920,25,5159,284348,2157,94,7015,3791,5156,56648,9001,318&scopes=entrezgene)
# https://mygene.info/v3/query {'fields': 'entrezgene,name,symbol,umls.cui,umls.protein_cui,HGNC,uniprot.Swiss-Prot,ensembl.gene,OMIM,MGI', 'dotfield': 'true', 'species': 'human'} {'q': 'CSNK1G1,BCR,ABL1', 'scopes': 'symbol'}
# 1: https://mygene.info/v3/query?fields=entrezgene,name,symbol,umls.cui,umls.protein_cui,HGNC,uniprot.Swiss-Prot,ensembl.gene,OMIM,MGI&dotfield=true&species=human (POST -d q=CSNK1G1,BCR,ABL1&scopes=symbol)
# https://mygene.info/v3/query {'fields': 'entrezgene,name,symbol,umls.cui,umls.protein_cui,HGNC,uniprot.Swiss-Prot,ensembl.gene,OMIM,MGI', 'dotfield': 'true', 'species': 'human'} {'q': '17381,17399,3005,3381,17433,3236,3443,17619,3495,3467,3765,3688,3697,3657,17881,28570,3824,28662,30043,30099,8095,30235,30287,30365,76,61,30935,8975,8951,8910,30830,8756,24662,18216,18270,18163,4268,4238,18752,18782,18786,4566,4552,4783,4703,4650,4651,4671,4931,4893,4840,4820,4823,4812,20373,9282,9255,31508,9366,9337,9335,9689,9658,9662,9644,14604,31586,14458,31621,9588,9779,5005,5358,19685,5438,5417,10571,5995,5992,5962,10853,10896,10933,10760,10764
# equivalent_id None
#
# After id-to-object translation, BTE retrieved 748 unique objects.
#
#
# ==========
# ========== QUERY #2 -- fetch all Gene entities linked to 'imatinib' ==========
# ==========
#
#
# BTE found 1 apis:
#
# API 1. mychem.info(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
# https://mychem.info/v1/query {'fields': 'chembl.molecule_chembl_id,drugbank.xrefs.chembl,drugcentral.xrefs.chembl_id,drugcentral.xrefs.drugbank_id,pharmgkb.xrefs.drugbank,chebi.xrefs.drugbank,drugbank.id,pubchem.cid,drugbank.xrefs.pubchem.cid,drugcentral.xrefs.pubchem_cid,pharmgkb.xrefs.pubchem.cid,chebi.id,chembl.chebi_par_id,drugbank.xrefs.chebi,drugcentral.xrefs.chebi,drugcentral.xrefs.umlscui,pharmgkb.xrefs.umls,umls.cui,umls.mesh,drugcentral.xrefs.mesh_descriptor_ui,ginas.xrefs.MESH,pharmgkb.xrefs.mesh,drugcentral.xrefs.unii,unii.unii,aeolus.unii,ginas.unii,chembl.pref_name,drugbank.name,umls.name,ginas.preferred_name,pharmgkb.name,chebi.name', 'dotfield': 'true', 'species': 'human'} {'q': 'CHEBI:45783', 'scopes': 'chebi.id,chembl.chebi_par_id,drugbank.xrefs.chebi,drugcentral.xrefs.chebi'}
# 1: https://mychem.info/v1/query?fields=chembl.molecule_chembl_id,drugbank.xrefs.chembl,drugcentral.xrefs.chembl_id,drugcentral.xrefs.drugbank_id,pharmgkb.xrefs.drugbank,chebi.xrefs.drugbank,drugbank.id,pubchem.cid,drugbank.xrefs.pubchem.cid,drugcentral.xrefs.pubchem_cid,pharmgkb.xrefs.pubchem.cid,chebi.id,chembl.chebi_par_id,drugbank.xrefs.chebi,drugcentral.xrefs.chebi,drugcentral.xrefs.umlscui,pharmgkb.xrefs.umls,umls.cui,umls.mesh,drugcentral.xrefs.mesh_descriptor_ui,ginas.xrefs.MESH,pharmgkb.xrefs.mesh,drugcentral.xrefs.unii,unii.unii,aeolus.unii,ginas.unii,chembl.pref_name,drugbank.name,umls.name,ginas.preferred_name,pharmgkb.name,chebi.name&dotfield=true&species=human (POST -d q=CHEBI:45783&scopes=chebi.id,chembl.chebi_par_id,drugbank.xrefs.chebi,drugcentral.xrefs.chebi)
# ==== Step #1: Query path planning ====
#
# Because imatinib is of type 'ChemicalSubstance', BTE will query our meta-KG for APIs that can take 'ChemicalSubstance' as input and 'Gene' as output
#
# BTE found 10 apis:
#
# API 1. scigraph(1 API call)
# API 2. pharos(1 API call)
# API 3. dgidb(2 API calls)
# API 4. semmed_chemical(13 API calls)
# API 5. scibite(1 API call)
# API 6. hmdb(1 API call)
# API 7. ctd(2 API calls)
# API 8. cord_chemical(1 API call)
# API 9. mychem(3 API calls)
# API 10. chembio(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# https://biothings.ncats.io/cord_chemical/query {'fields': 'associated_with'} {'q': 'CHEBI:45783', 'scopes': 'chebi'}
# API 8.1: https://biothings.ncats.io/cord_chemical/query?fields=associated_with (POST -d q=CHEBI:45783&scopes=chebi)
# API 6.1: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=C097613
# https://biothings.ncats.io/semmedchemical/query {'fields': 'related_to'} {'q': 'C0935989', 'scopes': 'umls'}
# API 4.5: https://biothings.ncats.io/semmedchemical/query?fields=related_to (POST -d q=C0935989&scopes=umls)
# https://biothings.ncats.io/semmedchemical/query {'fields': 'disrupted_by'} {'q': 'C0935989', 'scopes': 'umls'}
# API 4.4: https://biothings.ncats.io/semmedchemical/query?fields=disrupted_by (POST -d q=C0935989&scopes=umls)
# https://biothings.ncats.io/semmedchemical/query {'fields': 'negatively_regulated_by'} {'q': 'C0935989', 'scopes': 'umls'}
# API 4.3: https://biothings.ncats.io/semmedchemical/query?fields=negatively_regulated_by (POST -d q=C0935989&scopes=umls)
# https://biothings.ncats.io/semmedchemical/query {'fields': 'produces'} {'q': 'C0935989', 'scopes': 'umls'}
# API 4.8: https://biothings.ncats.io/semmedchemical/query?fields=produces (POST -d q=C0935989&scopes=umls)
# https://biothings.ncats.io/semmedchemical/query {'fields': 'disrupts'} {'q': 'C0935989', 'scopes': 'umls'}
# API 4.6: https://biothings.ncats.io/semmedchemical/query?fields=disrupts (POST -d q=C0935989&scopes=umls)
# https://biothings.ncats.io/semmedchemical/query {'fields': 'positively_regulated_by'} {'q': 'C0935989', 'scopes': 'umls'}
# API 4.13: https://biothings.ncats.io/semmedchemical/query?fields=positively_regulated_by (POST -d q=C0935989&scopes=umls)
# https://biothings.ncats.io/semmedchemical/query {'fields': 'affected_by'} {'q': 'C0935989', 'scopes': 'umls'}
# API 4.12: https://biothings.ncats.io/semmedchemical/query?fields=affected_by (POST -d q=C0935989&scopes=umls)
# https://biothings.ncats.io/semmedchemical/query {'fields': 'negatively_regulates'} {'q': 'C0935989', 'scopes': 'umls'}
# API 4.10: https://biothings.ncats.io/semmedchemical/query?fields=negatively_regulates (POST -d q=C0935989&scopes=umls)
# https://mychem.info/v1/query {'fields': 'drugbank.targets'} {'q': 'DB00619', 'scopes': 'drugbank.id'}
# API 9.1: https://mychem.info/v1/query?fields=drugbank.targets (POST -d q=DB00619&scopes=drugbank.id)
# https://mychem.info/v1/query {'fields': 'drugbank.enzymes'} {'q': 'DB00619', 'scopes': 'drugbank.id'}
# API 9.3: https://mychem.info/v1/query?fields=drugbank.enzymes (POST -d q=DB00619&scopes=drugbank.id)
# https://biothings.ncats.io/semmedchemical/query {'fields': 'positively_regulates'} {'q': 'C0935989', 'scopes': 'umls'}
# API 4.2: https://biothings.ncats.io/semmedchemical/query?fields=positively_regulates (POST -d q=C0935989&scopes=umls)
# https://mychem.info/v1/query {'fields': 'drugcentral.bioactivity'} {'q': 'CHEMBL941,CHEMBL1642', 'scopes': 'chembl.molecule_chembl_id'}
# API 9.2: https://mychem.info/v1/query?fields=drugcentral.bioactivity (POST -d q=CHEMBL941,CHEMBL1642&scopes=chembl.molecule_chembl_id)
# https://biothings.ncats.io/semmedchemical/query {'fields': 'affects'} {'q': 'C0935989', 'scopes': 'umls'}
# API 4.11: https://biothings.ncats.io/semmedchemical/query?fields=affects (POST -d q=C0935989&scopes=umls)
# https://biothings.ncats.io/semmedchemical/query {'fields': 'coexists_with'} {'q': 'C0935989', 'scopes': 'umls'}
# API 4.7: https://biothings.ncats.io/semmedchemical/query?fields=coexists_with (POST -d q=C0935989&scopes=umls)
# https://biothings.ncats.io/semmedchemical/query {'fields': 'produced_by'} {'q': 'C0935989', 'scopes': 'umls'}
# API 4.9: https://biothings.ncats.io/semmedchemical/query?fields=produced_by (POST -d q=C0935989&scopes=umls)
# https://biothings.ncats.io/semmedchemical/query {'fields': 'physically_interacts_with'} {'q': 'C0935989', 'scopes': 'umls'}
# API 4.1: https://biothings.ncats.io/semmedchemical/query?fields=physically_interacts_with (POST -d q=C0935989&scopes=umls)
# API 6.2: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D000068877
# API 1.1: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/gene/CHEBI:45783
# API 3.2: http://dgidb.genome.wustl.edu/api/v2/interactions.json?drugs=CHEMBL1642
# API 7.1: https://automat.renci.org/hmdb/chemical_substance/gene/CHEBI:45783
# API 2.1: https://automat.renci.org/pharos/chemical_substance/gene/CHEBI:45783
# API 5.1: https://automat.renci.org/cord19_scibite_v2/chemical_substance/gene/CHEBI:45783
# API 10.1: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:45783
# API 3.1: http://dgidb.genome.wustl.edu/api/v2/interactions.json?drugs=CHEMBL941
#
#
# ==== Step #3: Output normalization ====
#
# API 4.1 semmed_chemical: 300 hits
# API 10.1 chembio: No hits
# API 9.1 mychem: 9 hits
# API 9.2 mychem: 80 hits
# API 9.3 mychem: 9 hits
# API 5.1 scibite: 8 hits
# API 2.1 pharos: 6 hits
# API 4.2 semmed_chemical: 98 hits
# API 4.3 semmed_chemical: 38 hits
# API 4.4 semmed_chemical: No hits
# API 4.5 semmed_chemical: No hits
# API 1.1 scigraph: 3 hits
# API 3.1 dgidb: 34 hits
# API 3.2 dgidb: 5 hits
# API 7.1 hmdb: No hits
# API 4.6 semmed_chemical: No hits
# API 4.7 semmed_chemical: 138 hits
# API 4.8 semmed_chemical: No hits
# API 4.9 semmed_chemical: 12 hits
# API 8.1 cord_chemical: 172 hits
# API 6.1 ctd: No hits
# API 6.2 ctd: 199 hits
# API 4.10 semmed_chemical: 171 hits
# API 4.11 semmed_chemical: No hits
# API 4.12 semmed_chemical: No hits
# API 4.13 semmed_chemical: 39 hits
# check output_ids False
# output_ids_dict keys dict_keys(['Gene,UMLS', 'Gene,SYMBOL', 'Gene,NCBIGene', 'Gene,HGNC'])
#
# BTE found 1 apis:
#
# API 1. mygene.info(4 API calls)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# https://mygene.info/v3/query {'fields': 'entrezgene,name,symbol,umls.cui,umls.protein_cui,HGNC,uniprot.Swiss-Prot,ensembl.gene,OMIM,MGI', 'dotfield': 'true', 'species': 'human'} {'q
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'imatinib']

# %%
g.nodes["chronic myelogenous leukemia, BCR-ABL1 positive"]
# Out:
# {'type': 'Disease',
#  'identifier': 'name',
#  'level': 1,
#  'equivalent_ids': defaultdict(set,
#              {'MONDO': ['MONDO:0011996'],
#               'DOID': ['DOID:8552'],
#               'UMLS': ['C0023473', 'C0023474'],
#               'name': ['CHRONIC MYELOGENOUS LEUKEMIA, BCR-ABL1 POSITIVE',
#                'LEUKEMIA, MYELOID, CHRONIC-PHASE'],
#               'OMIM': ['608232'],
#               'ORPHANET': ['521']})}

# %%
g.nodes["FLT3"]
# Out:
# {'identifier': 'SYMBOL',
#  'type': 'Gene',
#  'level': 2,
#  'equivalent_ids': defaultdict(set,
#              {'NCBIGene': ['2322'],
#               'name': ['FMS RELATED RECEPTOR TYROSINE KINASE 3'],
#               'SYMBOL': ['FLT3'],
#               'UMLS': ['C1333568'],
#               'HGNC': ['3765'],
#               'UNIPROTKB': ['P36888'],
#               'ENSEMBL': ['ENSG00000122025']})}

# %%
g.nodes["imatinib"]
# Out:
# {'type': 'ChemicalSubstance',
#  'identifier': 'name',
#  'level': 1,
#  'equivalent_ids': defaultdict(set,
#              {'DRUGBANK': ['DB00619'],
#               'CHEBI': ['CHEBI:45783'],
#               'name': ['IMATINIB'],
#               'CHEMBL.COMPOUND': ['CHEMBL941', 'CHEMBL1642'],
#               'PUBCHEM': ['5291'],
#               'UMLS': ['C0935989'],
#               'MESH': ['C097613', 'D000068877'],
#               'UNII': ['BKJ8M8G5HI', '8A1O1M485B']})}

# %% [markdown]
# ## Retrieve all simple paths b

# %%
import networkx as nx
for path in nx.all_simple_paths(g, source="chronic myelogenous leukemia, BCR-ABL1 positive", target="imatinib"):
    print(path)
# Out:
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CCND2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SQSTM1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SQSTM1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SQSTM1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SQSTM1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CDKN2B', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0752312', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0752312', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0752312', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0752312', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SHC1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'RELA', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0033640', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0080279', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0080279', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0080279', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0080279', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0080279', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0080279', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0080279', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0080279', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0080279', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0080279', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0080279', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0080279', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CRK', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CRK', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CRK', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708837', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708837', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CXCL10', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'HSPA4', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'HSPA4', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0010762', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0010762', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0010762', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'IFI27', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'IFI27', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'IFI27', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'IFI27', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'IFI27', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'IFI27', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'MATK', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0751993', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0751993', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CP', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'RB1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SRC', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SRC', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SRC', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SRC', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705632', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705632', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CBL', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CBL', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CBL', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CBL', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CBL', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CBL', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ARHGAP32', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0169661', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0169661', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0169661', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0169661', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0169661', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0169661', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0169661', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0169661', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0169661', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'STAT5A', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'STAT5A', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'STAT5A', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'STAT5A', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'STAT5A', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'STAT5A', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'STAT5A', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'STAT5A', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'STAT5A', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'STAT5A', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'STAT5A', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'STAT5A', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'STAT5A', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'STAT5A', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'STAT5A', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'STAT5A', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'STAT5A', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'STAT5A', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'STAT5A', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'STAT5A', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'STAT5A', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704873', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'XIAP', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'XIAP', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'XIAP', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C2825806', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TNF', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TNF', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TNF', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TNF', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TNF', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TNF', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TNF', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TNF', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TNF', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TNF', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TNF', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TNF', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TNF', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TNF', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TNF', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TGFB1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TGFB1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TGFB1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TGFB1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TGFB1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TGFB1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CDKN2A', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CDKN2A', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CDKN2A', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CDKN2A', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1706320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1706320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1706320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1706320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1706320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1706320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1706320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1706320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1706320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1706320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1706320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1706320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1706320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1706320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0376623', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TBXAS1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'EREG', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1707145', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1707145', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1707145', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1707145', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'IL2RA', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'IL2RA', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C3272447', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PIK3CA', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PIK3CA', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PIK3CA', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PIK3CA', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PIK3CA', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PIK3CA', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ESR1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ESR1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ESR1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ESR1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ESR1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ESR1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ESR1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ESR1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ESR1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ESR1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ESR1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ESR1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', '7322', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PAX5', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CREBBP', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SMS', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CDKN1A', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CDKN1A', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CDKN1A', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CDKN1A', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'MYB', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'MYB', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SH2B2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TIMP1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CA2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C3814146', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C3814146', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0033713', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0033713', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'FYN', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0044602', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0044602', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0044602', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0044602', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0044602', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0044602', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0044602', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0044602', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'MDM2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'NDUFB3', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SEPHS1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708581', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708581', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708581', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708581', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708581', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708581', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708581', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708581', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708581', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708581', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708581', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708581', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708581', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708581', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708581', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708581', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'NF1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'NF1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705637', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705637', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705637', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705637', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705950', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PDLIM5', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'DPP4', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SPACA9', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'WT1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'WT1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'WT1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'WT1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'WT1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'WT1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'IFNG', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'IFNG', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'NDUFB4', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'NDUFB4', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABCD1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BLK', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BLK', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'MVD', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'MVD', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'MVD', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0031686', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0031686', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'G6PD', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'G6PD', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'G6PD', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'G6PD', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'EPB42', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ZNRD2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ZNRD2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ZNRD2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ZNRD2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ZNRD2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ZNRD2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'MICE', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CRKL', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CRKL', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CRKL', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CRKL', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CRKL', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CRKL', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PDGFRB', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PDGFRB', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PDGFRB', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PDGFRB', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PDGFRB', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PDGFRB', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PDGFRB', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PDGFRB', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PDGFRB', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PDGFRB', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PDGFRB', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PDGFRB', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PDGFRB', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'IL3', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'IL3', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'IL3', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PPP2R5C', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0031727', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0031727', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0031727', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0031727', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0031727', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0031727', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0031727', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0031727', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0031727', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0031727', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0031727', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0031727', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0031727', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0031727', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0031727', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0031727', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0031727', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0031727', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0031727', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0031727', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0031727', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0031727', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0031727', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0031727', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0031727', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0031727', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0031727', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0031727', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0031727', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0031727', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0031727', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0031727', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0031727', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0031727', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0031727', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SLC22A1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SLC22A1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SLC22A1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SLC22A1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SLC22A1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SLC22A1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SLC22A1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SLC22A1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SLC22A1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SLC22A1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SLC22A1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SLC22A1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SLC22A1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SLC22A1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SLC22A1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SLC22A1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708630', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708630', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708630', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708630', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708630', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708630', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708630', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708630', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABCG2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABCG2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABCG2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABCG2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABCG2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABCG2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABCG2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABCG2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABCG2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABCG2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABCG2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABCG2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABCG2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABCG2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABCG2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABCG2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABCG2', 'imatinib']
# ...
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCL2L11', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCL2L11', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCL2L11', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCL2L11', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCL2L11', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCL2L11', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCL2L11', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCL2L11', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCL2L11', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCL2L11', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'GLI3', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0080059', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0080059', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0080059', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0080059', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0080059', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0080059', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'DNAAF6', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'IL2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'IL2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'IL2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'IL2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'IL2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PSMD9', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PSMD9', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PSMD9', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PSMD9', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PSMD9', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PSMD9', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TNFAIP1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'NTRK1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'NTRK1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ATM', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0002059', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0002059', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CEL', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CEL', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'IL1B', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'IL1B', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'IL1B', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'H3P16', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'H3P16', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'H3P16', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SNHG5', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SNHG5', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SNHG5', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'MIR21', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'MIR21', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C3889436', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C3889436', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C3889436', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C3889436', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C3889436', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C3889436', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C3889436', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C3889436', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C3889436', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C3889436', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'LEP', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'LEP', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0014442', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0014442', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0014442', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1707163', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PRH1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CD44', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'EPHB4', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'EPHB4', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'EPHB4', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'EPHB4', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'EPHB4', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'EPHB4', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704927', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704927', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704927', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704927', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704927', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704927', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704927', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704927', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704927', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704927', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704927', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704927', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704927', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704927', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704927', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704927', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705280', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PDGFB', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PDGFB', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PDGFB', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PDGFB', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PDGFB', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PDGFB', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0079413', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0079413', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0079413', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0079413', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0079413', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0079413', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0079413', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0079413', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0079413', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0079413', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0079413', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0079413', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0079413', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0079413', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0079413', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0079413', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0079413', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0079413', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0079413', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0079413', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0079413', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0079413', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0079413', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0079413', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0079413', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0079413', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0079413', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0079413', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0014241', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0014241', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'INS', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'INS', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'INS', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705316', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705316', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705316', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705316', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705316', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705316', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SERPINE2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCL2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCL2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'RAP1A', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'RAP1A', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ZHX2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ZHX2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705526', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CXCR4', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CXCR4', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CXCR4', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CXCR4', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CXCR4', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CXCR4', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CXCR4', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CXCR4', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'EZH2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'DOK1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'NR0B2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'NR0B2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'NR0B2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CALR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SPG21', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'MAPK8', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'MAPK8', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'MAPK8', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'MAPK8', 'imatinib']
