# %%
from biothings_explorer.user_query_dispatcher import FindConnection
from biothings_explorer.hint import Hint

# %%
ht = Hint()
# find all potential representations of CML
cml_hint = ht.query("chronic myelogenous leukemia")
# select the correct representation of CML
cml = cml_hint['Disease'][0]
cml
# Out:
# {'MONDO': 'MONDO:0011996',
#  'DOID': 'DOID:8552',
#  'UMLS': 'C0023473',
#  'name': 'chronic myelogenous leukemia, BCR-ABL1 positive',
#  'OMIM': '608232',
#  'ORPHANET': '521',
#  'primary': {'identifier': 'MONDO',
#   'cls': 'Disease',
#   'value': 'MONDO:0011996'},
#  'display': 'MONDO(MONDO:0011996) DOID(DOID:8552) OMIM(608232) ORPHANET(521) UMLS(C0023473) name(chronic myelogenous leukemia, BCR-ABL1 positive)',
#  'type': 'Disease'}

# %%
# find all potential representations of imatinib
imatinib_hint = ht.query("imatinib")
# select the correct representation of imatinib
imatinib = imatinib_hint['ChemicalSubstance'][0]
imatinib
# Out:
# {'DRUGBANK': 'DB00619',
#  'CHEBI': 'CHEBI:45783',
#  'name': 'imatinib',
#  'primary': {'identifier': 'CHEBI',
#   'cls': 'ChemicalSubstance',
#   'value': 'CHEBI:45783'},
#  'display': 'CHEBI(CHEBI:45783) DRUGBANK(DB00619) name(imatinib)',
#  'type': 'ChemicalSubstance'}

# %%
fc = FindConnection(input_obj=cml, output_obj=imatinib, intermediate_nodes='Gene')

# %%
# set verbose=True will display all steps which BTE takes to find the connection
fc.connect(verbose=True)
# Out:
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'chronic myelogenous leukemia, BCR-ABL1 positive' and 'imatinib'. Paths will have 1 intermediate node.
#
# Intermediate node #1 will have these type constraints: Gene
#
#
# ==========
# ========== QUERY #1 -- fetch all Gene entities linked to 'chronic myelogenous leukemia, BCR-ABL1 positive' ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because chronic myelogenous leukemia, BCR-ABL1 positive is of type 'Disease', BTE will query our meta-KG for APIs that can take 'Disease' as input and 'Gene' as output
#
# BTE found 10 apis:
#
# API 1. DISEASES(1 API call)
# API 2. mydisease(1 API call)
# API 3. hetio(1 API call)
# API 4. biolink(1 API call)
# API 5. scibite(1 API call)
# API 6. mgi_gene2phenotype(1 API call)
# API 7. semmed_disease(15 API calls)
# API 8. scigraph(1 API call)
# API 9. pharos(1 API call)
# API 10. cord_disease(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 2.1: https://mydisease.info/v1/query?fields=disgenet.genes_related_to_disease.gene_id (POST -d q=C0023473,C0023474&scopes=mondo.xrefs.umls, disgenet.xrefs.umls)
# API 7.3: https://biothings.ncats.io/semmed/query?fields=prevented_by (POST -d q=C0023473,C0023474&scopes=umls)
# API 4.1: https://api.monarchinitiative.org/api/bioentity/disease/MONDO:0011996/genes?rows=200
# API 7.9: https://biothings.ncats.io/semmed/query?fields=disrupted_by (POST -d q=C0023473,C0023474&scopes=umls)
# API 7.7: https://biothings.ncats.io/semmed/query?fields=positively_regulated_by (POST -d q=C0023473,C0023474&scopes=umls)
# API 7.5: https://biothings.ncats.io/semmed/query?fields=physically_interacts_with (POST -d q=C0023473,C0023474&scopes=umls)
# API 7.6: https://biothings.ncats.io/semmed/query?fields=treated_by (POST -d q=C0023473,C0023474&scopes=umls)
# API 5.1: https://automat.renci.org/cord19_scibite_v2/disease/gene/MONDO:0011996
# API 1.1: https://pending.biothings.io/DISEASES/query?fields=DISEASES.associatedWith (POST -d q=DOID:8552&scopes=DISEASES.doid)
# API 6.1: https://pending.biothings.io/mgigene2phenotype/query?fields=_id&size=300 (POST -d q=DOID:8552&scopes=mgi.associated_with_disease.doid)
# API 7.4: https://biothings.ncats.io/semmed/query?fields=positively_regulates (POST -d q=C0023473,C0023474&scopes=umls)
# API 7.8: https://biothings.ncats.io/semmed/query?fields=derives_from (POST -d q=C0023473,C0023474&scopes=umls)
# API 7.12: https://biothings.ncats.io/semmed/query?fields=related_to (POST -d q=C0023473,C0023474&scopes=umls)
# API 7.15: https://biothings.ncats.io/semmed/query?fields=negatively_regulated_by (POST -d q=C0023473,C0023474&scopes=umls)
# API 10.1: https://biothings.ncats.io/cord_disease/query?fields=associated_with (POST -d q=DOID:8552&scopes=doid)
# API 3.1: https://automat.renci.org/hetio/disease/gene/MONDO:0011996
# API 9.1: https://automat.renci.org/pharos/disease/gene/MONDO:0011996
# API 8.1: https://automat.renci.org/cord19_scigraph_v2/disease/gene/MONDO:0011996
# API 7.2: https://biothings.ncats.io/semmed/query?fields=coexists_with (POST -d q=C0023473,C0023474&scopes=umls)
# API 7.11: https://biothings.ncats.io/semmed/query?fields=negatively_regulates (POST -d q=C0023473,C0023474&scopes=umls)
# API 7.10: https://biothings.ncats.io/semmed/query?fields=affected_by (POST -d q=C0023473,C0023474&scopes=umls)
# API 7.14: https://biothings.ncats.io/semmed/query?fields=caused_by (POST -d q=C0023473,C0023474&scopes=umls)
# API 7.13: https://biothings.ncats.io/semmed/query?fields=disrupts (POST -d q=C0023473,C0023474&scopes=umls)
# API 7.1: https://biothings.ncats.io/semmed/query?fields=affects (POST -d q=C0023473,C0023474&scopes=umls)
#
#
# ==== Step #3: Output normalization ====
#
# API 6.1 mgi_gene2phenotype: 8 hits
# API 7.1 semmed_disease: No hits
# API 7.2 semmed_disease: No hits
# API 1.1 DISEASES: 3 hits
# API 7.3 semmed_disease: 7 hits
# API 7.4 semmed_disease: No hits
# API 7.5 semmed_disease: No hits
# API 7.6 semmed_disease: 138 hits
# API 7.7 semmed_disease: No hits
# API 9.1 pharos: 7 hits
# API 7.8 semmed_disease: No hits
# API 8.1 scigraph: 3 hits
# API 7.9 semmed_disease: 26 hits
# API 10.1 cord_disease: 146 hits
# API 7.10 semmed_disease: 66 hits
# API 5.1 scibite: 12 hits
# API 3.1 hetio: No hits
# API 7.11 semmed_disease: No hits
# API 7.12 semmed_disease: 570 hits
# API 2.1 mydisease: No hits
# API 7.13 semmed_disease: No hits
# API 7.14 semmed_disease: 92 hits
# API 4.1 biolink: 4 hits
# API 7.15 semmed_disease: No hits
#
# After id-to-object translation, BTE retrieved 748 unique objects.
#
#
# ==========
# ========== QUERY #2 -- fetch all Gene entities linked to 'imatinib' ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because imatinib is of type 'ChemicalSubstance', BTE will query our meta-KG for APIs that can take 'ChemicalSubstance' as input and 'Gene' as output
#
# BTE found 10 apis:
#
# API 1. chembio(1 API call)
# API 2. dgidb(2 API calls)
# API 3. cord_chemical(1 API call)
# API 4. mychem(3 API calls)
# API 5. semmed_chemical(13 API calls)
# API 6. scibite(1 API call)
# API 7. ctd(2 API calls)
# API 8. scigraph(1 API call)
# API 9. pharos(1 API call)
# API 10. hmdb(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 7.1: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=C097613
# API 7.2: http://ctdbase.org/tools/batchQuery.go?inputType=chem&report=genes_curated&format=json&inputTerms=D000068877
# API 3.2: http://dgidb.genome.wustl.edu/api/v2/interactions.json?drugs=CHEMBL1642
# API 4.2: https://mychem.info/v1/query?fields=drugcentral.bioactivity (POST -d q=CHEMBL941,CHEMBL1642&scopes=chembl.molecule_chembl_id)
# API 4.3: https://mychem.info/v1/query?fields=drugbank.enzymes (POST -d q=DB00619&scopes=drugbank.id)
# API 4.1: https://mychem.info/v1/query?fields=drugbank.targets (POST -d q=DB00619&scopes=drugbank.id)
# API 3.1: http://dgidb.genome.wustl.edu/api/v2/interactions.json?drugs=CHEMBL941
# API 5.5: https://biothings.ncats.io/semmedchemical/query?fields=related_to (POST -d q=C0935989&scopes=umls)
# API 5.8: https://biothings.ncats.io/semmedchemical/query?fields=produces (POST -d q=C0935989&scopes=umls)
# API 5.12: https://biothings.ncats.io/semmedchemical/query?fields=affected_by (POST -d q=C0935989&scopes=umls)
# API 5.13: https://biothings.ncats.io/semmedchemical/query?fields=positively_regulated_by (POST -d q=C0935989&scopes=umls)
# API 5.6: https://biothings.ncats.io/semmedchemical/query?fields=disrupts (POST -d q=C0935989&scopes=umls)
# API 5.7: https://biothings.ncats.io/semmedchemical/query?fields=coexists_with (POST -d q=C0935989&scopes=umls)
# API 5.1: https://biothings.ncats.io/semmedchemical/query?fields=physically_interacts_with (POST -d q=C0935989&scopes=umls)
# API 5.9: https://biothings.ncats.io/semmedchemical/query?fields=produced_by (POST -d q=C0935989&scopes=umls)
# API 5.3: https://biothings.ncats.io/semmedchemical/query?fields=negatively_regulated_by (POST -d q=C0935989&scopes=umls)
# API 2.1: https://biothings.ncats.io/cord_chemical/query?fields=associated_with (POST -d q=CHEBI:45783&scopes=chebi)
# API 5.2: https://biothings.ncats.io/semmedchemical/query?fields=positively_regulates (POST -d q=C0935989&scopes=umls)
# API 5.10: https://biothings.ncats.io/semmedchemical/query?fields=negatively_regulates (POST -d q=C0935989&scopes=umls)
# API 5.4: https://biothings.ncats.io/semmedchemical/query?fields=disrupted_by (POST -d q=C0935989&scopes=umls)
# API 5.11: https://biothings.ncats.io/semmedchemical/query?fields=affects (POST -d q=C0935989&scopes=umls)
# API 1.1: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:45783
# API 10.1: https://automat.renci.org/hmdb/chemical_substance/gene/CHEBI:45783
# API 8.1: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/gene/CHEBI:45783
# API 6.1: https://automat.renci.org/cord19_scibite_v2/chemical_substance/gene/CHEBI:45783
# API 9.1: https://automat.renci.org/pharos/chemical_substance/gene/CHEBI:45783
#
#
# ==== Step #3: Output normalization ====
#
# API 5.1 semmed_chemical: 300 hits
# API 1.1 chembio: No hits
# API 4.1 mychem: 9 hits
# API 4.2 mychem: 80 hits
# API 4.3 mychem: 9 hits
# API 6.1 scibite: 8 hits
# API 9.1 pharos: 6 hits
# API 5.2 semmed_chemical: 98 hits
# API 5.3 semmed_chemical: 38 hits
# API 5.4 semmed_chemical: No hits
# API 5.5 semmed_chemical: No hits
# API 8.1 scigraph: 3 hits
# API 3.1 dgidb: 34 hits
# API 3.2 dgidb: 5 hits
# API 10.1 hmdb: No hits
# API 5.6 semmed_chemical: No hits
# API 5.7 semmed_chemical: 138 hits
# API 5.8 semmed_chemical: No hits
# API 5.9 semmed_chemical: 12 hits
# API 2.1 cord_chemical: 172 hits
# API 7.1 ctd: No hits
# API 7.2 ctd: 199 hits
# API 5.10 semmed_chemical: 171 hits
# API 5.11 semmed_chemical: No hits
# API 5.12 semmed_chemical: No hits
# API 5.13 semmed_chemical: 39 hits
# After id-to-object translation, BTE retrieved 730 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# BTE found 251 unique intermediate nodes connecting 'chronic myelogenous leukemia, BCR-ABL1 positive' and 'imatinib'

# %% [markdown]
# ## Retrieve the networkx graph from the query

# %%
g = fc.fc.sub_G

# %% [markdown]
# ## Retrieve all nodes

# %%
g.nodes()
# Out:
# NodeView(('GLI3', 'CDKN2B', 'C1708843', 'BCL2', 'C1335439', 'AHI1', 'PTEN', 'C3272447', 'FIP1L1', 'CDKN1A', 'FYN', 'C3814146', 'TNFAIP1', '7322', 'C1708630', 'MAPK1', 'C1704873', 'C0164786', 'C0031686', 'C1565434', 'C1705748', 'C1705280', 'EPHB4', 'TIMP1', 'CD82', 'FAP', 'CD4', 'G
# Out:
# ['imatinib', 'chronic myelogenous leukemia, BCR-ABL1 positive']

# %%
g.nodes["chronic myelogenous leukemia, BCR-ABL1 positive"]
# Out:
# {'type': 'Disease',
#  'identifier': 'name',
#  'level': 1,
#  'equivalent_ids': defaultdict(set,
#              {'MONDO': ['MONDO:0011996'],
#               'DOID': ['DOID:8552'],
#               'UMLS': ['C0023473', 'C0023474'],
#               'name': ['CHRONIC MYELOGENOUS LEUKEMIA, BCR-ABL1 POSITIVE',
#                'LEUKEMIA, MYELOID, CHRONIC-PHASE'],
#               'OMIM': ['608232'],
#               'ORPHANET': ['521']})}

# %%
g.nodes["FLT3"]
# Out:
# {'identifier': 'SYMBOL',
#  'type': 'Gene',
#  'level': 2,
#  'equivalent_ids': defaultdict(set,
#              {'NCBIGene': ['2322'],
#               'name': ['FMS RELATED RECEPTOR TYROSINE KINASE 3'],
#               'SYMBOL': ['FLT3'],
#               'UMLS': ['C1333568'],
#               'HGNC': ['3765'],
#               'UNIPROTKB': ['P36888'],
#               'ENSEMBL': ['ENSG00000122025']})}

# %%
g.nodes["imatinib"]
# Out:
# {'type': 'ChemicalSubstance',
#  'identifier': 'name',
#  'level': 1,
#  'equivalent_ids': defaultdict(set,
#              {'DRUGBANK': ['DB00619'],
#               'CHEBI': ['CHEBI:45783'],
#               'name': ['IMATINIB'],
#               'CHEMBL.COMPOUND': ['CHEMBL941', 'CHEMBL1642'],
#               'PUBCHEM': ['5291'],
#               'UMLS': ['C0935989'],
#               'MESH': ['C097613', 'D000068877'],
#               'UNII': ['BKJ8M8G5HI', '8A1O1M485B']})}

# %% [markdown]
# ## Retrieve all simple paths between the start and end node

# %%
import networkx as nx
for path in nx.all_simple_paths(g, source="chronic myelogenous leukemia, BCR-ABL1 positive", target="imatinib"):
    print(path)
# Out:
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'GLI3', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CDKN2B', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708843', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708843', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708843', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708843', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708843', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708843', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708843', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708843', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708843', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708843', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708843', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708843', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCL2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCL2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1335439', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'AHI1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PTEN', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PTEN', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PTEN', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PTEN', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PTEN', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PTEN', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PTEN', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PTEN', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PTEN', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PTEN', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PTEN', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PTEN', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PTEN', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PTEN', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PTEN', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PTEN', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C3272447', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'FIP1L1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'FIP1L1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'FIP1L1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'FIP1L1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'FIP1L1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'FIP1L1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'FIP1L1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CDKN1A', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CDKN1A', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CDKN1A', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CDKN1A', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'FYN', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C3814146', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C3814146', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TNFAIP1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', '7322', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708630', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708630', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708630', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708630', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708630', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708630', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708630', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708630', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'MAPK1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'MAPK1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'MAPK1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'MAPK1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'MAPK1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'MAPK1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704873', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0164786', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0164786', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0164786', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0164786', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0164786', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0164786', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0164786', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0164786', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0164786', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0164786', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0164786', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0164786', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0164786', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0164786', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0164786', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0164786', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0164786', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0164786', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0164786', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0164786', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0164786', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0164786', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0164786', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0164786', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0164786', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0164786', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0164786', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0164786', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0031686', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0031686', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1565434', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1565434', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1565434', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1565434', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705748', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705280', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'EPHB4', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'EPHB4', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'EPHB4', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'EPHB4', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'EPHB4', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'EPHB4', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TIMP1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CD82', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'FAP', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CD4', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CD4', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CD4', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CD4', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'G6PD', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'G6PD', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'G6PD', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'G6PD', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'WDTC1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PDLIM5', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0752312', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0752312', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0752312', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0752312', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'H19', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TBXAS1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'FGR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'FGR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'INS', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'INS', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'INS', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'MIR21', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'MIR21', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1707145', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1707145', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1707145', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1707145', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'NDUFB4', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'NDUFB4', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PTPN6', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PTPN6', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PTPN6', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PTPN6', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PTPN6', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705846', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PTS', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PTS', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PTS', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PTS', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PTS', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PTS', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SQSTM1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SQSTM1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SQSTM1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SQSTM1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'AMN', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1709425', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BLK', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BLK', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KIT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CREBBP', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SH2B2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ARHGAP32', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'HSPA4', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'HSPA4', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SEPHS1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1439337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1439337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1439337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1439337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1439337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1439337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PCNA', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705697', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705697', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ABL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'MSC', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'MSC', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705767', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705767', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705767', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705767', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705767', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0017337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0017337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0017337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0017337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0017337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0017337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0017337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0017337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0017337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0017337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0017337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0017337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0017337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0017337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0017337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0017337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0017337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0017337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0017337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0017337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0017337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0017337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0017337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0017337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0017337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0017337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0017337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0017337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0017337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0017337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0017337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0017337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0017337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0017337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0017337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0017337', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'EPB42', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0387583', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0387583', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PPP2R5C', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1707163', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'KITLG', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'FLT3', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'FLT3', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'FLT3', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'FLT3', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'FLT3', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'FLT3', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'FLT3', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'FLT3', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'FLT3', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'FLT3', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'NF1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'NF1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TERT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TERT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TERT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TERT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TERT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TERT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SMS', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'IL2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'IL2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'IL2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'IL2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'IL2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TCEAL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TCEAL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TCEAL1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'WT1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'WT1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'WT1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'WT1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'WT1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'WT1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1307407', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1307407', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1307407', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1307407', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1307407', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1307407', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1307407', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1307407', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1307407', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1307407', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1307407', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1307407', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1307407', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1307407', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1307407', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TMED7', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TMED7', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TMED7', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TMED7', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TMED7', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TMED7', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1706040', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ETV6', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ETV6', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ETV6', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ETV6', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0014442', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0014442', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0014442', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0087071', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0087071', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0087071', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0087071', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0087071', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0087071', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0087071', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0087071', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'NPB', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCR', 'imatinib']
# ...
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1704799', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TNF', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TNF', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TNF', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TNF', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TNF', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TNF', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TNF', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TNF', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TNF', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TNF', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TNF', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TNF', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TNF', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TNF', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'TNF', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PPIB', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCL2L11', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCL2L11', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCL2L11', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCL2L11', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCL2L11', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCL2L11', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCL2L11', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCL2L11', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCL2L11', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCL2L11', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCL2L11', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCL2L11', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCL2L11', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'BCL2L11', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'INPP5D', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C2825806', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1706320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1706320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1706320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1706320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1706320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1706320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1706320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1706320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1706320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1706320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1706320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1706320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1706320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1706320', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ISG20', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ISG20', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'MATK', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'CXCL8', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PIK3CA', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PIK3CA', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PIK3CA', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PIK3CA', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PIK3CA', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'PIK3CA', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'POU2F1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'POU2F1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'POU2F1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'POU2F1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'POU2F1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'POU2F1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'POU2F1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'POU2F1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'POU2F1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'POU2F1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'POU2F1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'POU2F1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'POU2F1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'POU2F1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'POU2F1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'POU2F1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'POU2F1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'POU2F1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'POU2F1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'POU2F1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'POU2F1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ESR1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ESR1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ESR1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ESR1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ESR1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ESR1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ESR1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ESR1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ESR1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ESR1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ESR1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'ESR1', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0079050', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0079050', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0079050', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0079050', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0079050', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0079050', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0079050', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0079050', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0079050', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0033713', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C0033713', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'IL6', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'IL6', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1705712', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SRC', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SRC', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SRC', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SRC', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'SCT', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'MYC', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'MYC', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'MYC', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'MYC', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'MYC', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'MYC', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'MYC', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'MYC', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'MYC', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'MYC', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'MYC', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'MYC', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708837', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'C1708837', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'MDM2', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'STAT3', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'STAT3', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'STAT3', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'STAT3', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'STAT3', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'STAT3', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'STAT3', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'STAT3', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'STAT3', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'STAT3', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'STAT3', 'imatinib']
# ['chronic myelogenous leukemia, BCR-ABL1 positive', 'STAT3', 'imatinib']
