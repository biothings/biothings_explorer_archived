# %% [markdown]
# # Introduction
#
# This notebook demonstrates how BioThings Explorer can be used to answer the following query:
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;*"Finding Marketed Drugs that Might Treat an Unknown Syndrome by Perturbing the Disease Mechanism Pathway"*
#
# ![](img/tidbit4_300.png)
#
# This query corresponds to [Tidbit 4](https://ncats.nih.gov/tidbit/tidbit_04.html) which was formulated as a demonstration of the NCATS Translator program.
#
# **Background of BTE**: BioThings Explorer can answer two classes of queries -- "EXPLAIN" and "PREDICT".  EXPLAIN queries are described in [EXPLAIN_demo.ipynb](https://github.com/biothings/biothings_explorer/blob/master/jupyter%20notebooks/EXPLAIN_demo.ipynb), and PREDICT queries are described in [PREDICT_demo.ipynb](https://github.com/biothings/biothings_explorer/blob/master/jupyter%20notebooks/PREDICT_demo.ipynb). Here, we describe PREDICT queries and how to use BioThings Explorer to execute them.  A more detailed overview of the BioThings Explorer systems is provided in [these slides](https://docs.google.com/presentation/d/1QWQqqQhPD_pzKryh6Wijm4YQswv8pAjleVORCPyJyDE/edit?usp=sharing).

# %% [markdown]
# **To experiment with an executable version of this notebook, [load it in Google Colaboratory](https://colab.research.google.com/github/biothings/biothings_explorer/blob/master/jupyter%20notebooks/TIDBIT%2004%20Finding%20Marketed%20Drugs%20that%20Might%20Treat%20an%20Unknown%20Syndrome%20by%20Perturbing%20the%20Disease%20Mechanism%20Pathway.ipynb).**

# %% [markdown]
# **Background of TIDBIT 04**:
#
# A five-year-old patient was brought to the emergency room with recurrent polymicrobial lung infections, only 29% small airway function and was unresponsive to antibiotics.
#
# The patient’s medical records included a genetics report from age 1, which showed a 1p34.1 chromosomal duplication encompassing 1.9 Mb, including the PRDX1 gene, which encodes Peroxiredoxin 1. The gene has been linked to airway disease in both rats and humans, and is known to act as an agonist of toll-like receptor 4 (TLR4), a pro-inflammatory receptor. In addition, two patients at another clinic were found to have 1p34.1 duplications:
#
# 1. One patient with a duplication including PRDX1 died with similar phenotypes
# 2. One patient with a duplication that did NOT include PRDX1 showed no airway disease phenotype
# While recurrent lung infections are typically treated with antibiotics, this patient was unresponsive to standard treatments. The patient’s earlier genetics report and data from other patients with similar duplications gave the physician evidence that PRDX1 may play a role in the disease, but no treatments directly related to the gene were known. With this information in mind, the physician asked a researcher familiar with Translator to try to find possible treatments for this patient.
#
# **How Might Translator Help?**
# The patient’s duplication of the 1p34.1 region of chromosome 1 gave Translator researchers a good place to start. Since PRDX1 is an agonist of TLR4, the duplication of the PRDX1 gene likely causes overexpression of PRDX1, which could lead to overactivity of both of the gene products. The researcher decided to try to find drugs that could be used to reduce the activity of those two proteins. An exhaustive search of chemical databases and PubMed to find safe drug options could take days to weeks.
#
# For a known genetic mutation, can Translator be used to quickly find existing modulators to compensate for the dysfunctional gene product?

# %% [markdown]
# ## Step 0: Load BioThings Explorer modules

# %% [markdown]
# First, install the `biothings_explorer` and `biothings_schema` packages, as described in this [README](https://github.com/biothings/biothings_explorer/blob/master/jupyter%20notebooks/README.md#prerequisite).  This only needs to be done once (but including it here for compability with [colab](https://colab.research.google.com/)).

# %%
# !pip install git+https://github.com/biothings/biothings_explorer#egg=biothings_explorer

# %% [markdown]
# ## Step 1: Find representation of "PRDX1" in BTE
#
# In this step, BioThings Explorer translates our query string "PRDX1"  into BioThings objects, which contain mappings to many common identifiers.  Generally, the top result returned by the `Hint` module will be the correct item, but you should confirm that using the identifiers shown.
#
# Search terms can correspond to any child of [BiologicalEntity](https://biolink.github.io/biolink-model/docs/BiologicalEntity.html) from the [Biolink Model](https://biolink.github.io/biolink-model/docs/), including `DiseaseOrPhenotypicFeature` (e.g., "lupus"), `ChemicalSubstance` (e.g., "acetaminophen"), `Gene` (e.g., "CDK2"), `BiologicalProcess` (e.g., "T cell differentiation"), and `Pathway` (e.g., "Citric acid cycle").

# %%
from biothings_explorer.hint import Hint
ht = Hint()
prdx1 = ht.query("PRDX1")['Gene'][0]

prdx1
# Out:
# {'entrez': '5052',
#  'name': 'peroxiredoxin 1',
#  'symbol': 'PRDX1',
#  'taxonomy': 9606,
#  'umls': 'C1418879',
#  'uniprot': 'Q06830',
#  'hgnc': '9352',
#  'ensembl': 'ENSG00000117450',
#  'display': 'entrez(5052) name(peroxiredoxin 1) symbol(PRDX1) taxonomy(9606) umls(C1418879) uniprot(Q06830) hgnc(9352) ensembl(ENSG00000117450) ',
#  'type': 'Gene',
#  'primary': {'identifier': 'entrez', 'cls': 'Gene', 'value': '5052'}}

# %% [markdown]
# ## Step 2: Find drugs that are associated with genes which are associated with PRDX1
#
# In this section, we find all paths in the knowledge graph that connect PRDX1 to any entity that is a chemical compound.  To do that, we will use `FindConnection`.  This class is a convenient wrapper around two advanced functions for **query path planning** and **query path execution**. More advanced features for both query path planning and query path execution are in development and will be documented in the coming months.
#
# The parameters for `FindConnection` are described below:

# %%
from biothings_explorer.user_query_dispatcher import FindConnection

fc = FindConnection(input_obj=prdx1, output_obj='ChemicalSubstance', intermediate_nodes=['Gene'])
fc.connect(verbose=True)
# Out:
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'PRDX1' and 'ChemicalSubstance'. Paths will have 1 intermediate node.
#
# Intermediate node #1 will have these type constraints: Gene
#
#
#
# ========== QUERY #1 -- fetch all Gene entities linked to PRDX1 ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because PRDX1 is of type 'Gene', BTE will query our meta-KG for APIs that can take 'Gene' as input and 'Gene' as output
#
# BTE found 3 apis:
#
# API 1. biolink_geneinteraction(1 API call)
# API 2. semmedgene(11 API calls)
# API 3. mygene.info(3 API calls)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 3.1: http://mygene.info/v3/query (POST "q=5052&scopes=entrezgene&fields=pantherdb.ortholog&species=human&size=100")
# API 3.3: http://mygene.info/v3/query (POST "q=9352&scopes=pantherdb.ortholog.HGNC&fields=entrezgene&species=human&size=100")
# API 3.2: http://mygene.info/v3/query (POST "q=ENSG00000117450&scopes=pantherdb.ortholog.Ensembl&fields=entrezgene&species=human&size=100")
# API 2.4: https://pending.biothings.io/semmedgene/query (POST "q=C1418879&scopes=disrupts.gene.umls&fields=umls&species=human&size=100")
# API 2.7: https://pending.biothings.io/semmedgene/query (POST "q=C1418879&scopes=inhibits.protein.umls&fields=umls&species=human&size=100")
# API 2.6: https://pending.biothings.io/semmedgene/query (POST "q=C1418879&scopes=inhibits.gene.umls&fields=umls&species=human&size=100")
# API 2.2: https://pending.biothings.io/semmedgene/query (POST "q=C1418879&scopes=affects.protein.umls&fields=umls&species=human&size=100")
# API 2.10: https://pending.biothings.io/semmedgene/query (POST "q=C1418879&scopes=stimulates.protein.umls&fields=umls&species=human&size=100")
# API 2.9: https://pending.biothings.io/semmedgene/query (POST "q=C1418879&scopes=interacts_with.protein.umls&fields=umls&species=human&size=100")
# API 2.5: https://pending.biothings.io/semmedgene/query (POST "q=C1418879&scopes=disrupts.protein.umls&fields=umls&species=human&size=100")
# API 2.1: https://pending.biothings.io/semmedgene/query (POST "q=C1418879&scopes=affects.gene.umls&fields=umls&species=human&size=100")
# API 2.8: https://pending.biothings.io/semmedgene/query (POST "q=C1418879&scopes=interacts_with.gene.umls&fields=umls&species=human&size=100")
# API 2.3: https://pending.biothings.io/semmedgene/query (POST "q=C1418879&scopes=associated_with.gene.umls&fields=umls&species=human&size=100")
# API 2.11: https://pending.biothings.io/semmedgene/query (POST "q=C1418879&scopes=umls&fields=disrupts.gene,inhibits.gene,associated_with.gene,affects.gene,stimulates.protein,disrupts.protein,inhibits.protein,interacts_with.gene,affects.protein,interacts_with.protein&species=human&size=100")
# API 1.1: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:5052/interactions?rows=100
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 biolink_geneinteraction: 100 hits
# API 3.1 mygene.info: 16 hits
# API 3.2 mygene.info: No hits
# API 3.3 mygene.info: 1 hits
# API 2.1 semmedgene: No hits
# API 2.2 semmedgene: No hits
# API 2.3 semmedgene: No hits
# API 2.4 semmedgene: No hits
# API 2.5 semmedgene: No hits
# API 2.6 semmedgene: 11 hits
# API 2.7 semmedgene: No hits
# API 2.8 semmedgene: 38 hits
# API 2.9 semmedgene: No hits
# API 2.10 semmedgene: No hits
# API 2.11 semmedgene: 85 hits
#
# After id-to-object translation, BTE retrieved 218 unique objects.
#
#
# ========== QUERY #2.1 -- fetch all ChemicalSubstance entities linked to Gene entites ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because None is of type 'Gene', BTE will query our meta-KG for APIs that can take 'Gene' as input and 'ChemicalSubstance' as output
#
# BTE found 5 apis:
#
# API 1. semmedgene(1 API call)
# API 2. mychem.info(3 API calls)
# API 3. dgidb_gene2chemical(146 API calls)
# API 4. opentarget(162 API calls)
# API 5. robokop_gene2chemical(146 API calls)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 4.16: http://www.dgidb.org/api/v2/interactions.json?genes=ZFR
# API 4.1: http://www.dgidb.org/api/v2/interactions.json?genes=RNF144A
# API 4.6: http://www.dgidb.org/api/v2/interactions.json?genes=LARP7
# API 4.4: http://www.dgidb.org/api/v2/interactions.json?genes=LGALS3
# API 4.14: http://www.dgidb.org/api/v2/interactions.json?genes=SYK
# API 4.11: http://www.dgidb.org/api/v2/interactions.json?genes=SESN1
# API 4.10: http://www.dgidb.org/api/v2/interactions.json?genes=CDC37
# API 4.12: http://www.dgidb.org/api/v2/interactions.json?genes=FERMT3
# dgidb_gene2chemical failed
# dgidb_gene2chemical failed
# API 4.8: http://www.dgidb.org/api/v2/interactions.json?genes=PPP2R5D
# dgidb_gene2chemical failed
# API 4.2: http://www.dgidb.org/api/v2/interactions.json?genes=CLEC4G
# API 4.3: http://www.dgidb.org/api/v2/interactions.json?genes=SCCPDH
# API 4.13: http://www.dgidb.org/api/v2/interactions.json?genes=RECQL4
# API 4.18: http://www.dgidb.org/api/v2/interactions.json?genes=PPT1
# API 4.5: http://www.dgidb.org/api/v2/interactions.json?genes=CALB2
# dgidb_gene2chemical failed
# API 4.17: http://www.dgidb.org/api/v2/interactions.json?genes=MST1
# dgidb_gene2chemical failed
# API 4.7: http://www.dgidb.org/api/v2/interactions.json?genes=KMT2A
# dgidb_gene2chemical failed
# dgidb_gene2chemical failed
# API 4.15: http://www.dgidb.org/api/v2/interactions.json?genes=CAT
# API 4.29: http://www.dgidb.org/api/v2/interactions.json?genes=COX6B1
# dgidb_gene2chemical failed
# API 4.21: http://www.dgidb.org/api/v2/interactions.json?genes=PDP1
# API 4.25: http://www.dgidb.org/api/v2/interactions.json?genes=GABPA
# API 4.27: http://www.dgidb.org/api/v2/interactions.json?genes=DAB2
# API 4.26: http://www.dgidb.org/api/v2/interactions.json?genes=TDGF1
# API 4.9: http://www.dgidb.org/api/v2/interactions.json?genes=SH3BGRL2
# dgidb_gene2chemical failed
# API 4.28: http://www.dgidb.org/api/v2/interactions.json?genes=MEPCE
# API 4.24: http://www.dgidb.org/api/v2/interactions.json?genes=PIK3CB
# API 4.19: http://www.dgidb.org/api/v2/interactions.json?genes=CUL2
# API 4.20: http://www.dgidb.org/api/v2/interactions.json?genes=PRRX1
# API 4.23: http://www.dgidb.org/api/v2/interactions.json?genes=TERF1
# API 4.30: http://www.dgidb.org/api/v2/interactions.json?genes=ETS1
# API 3.3: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000118058&datasource=chembl&size=15&fields=drug
# API 3.4: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=55872&datasource=chembl&size=15&fields=drug
# API 3.1: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000110063&datasource=chembl&size=15&fields=drug
# API 3.2: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000274442&datasource=chembl&size=15&fields=drug
# API 4.31: http://www.dgidb.org/api/v2/interactions.json?genes=VEGFA
# API 4.42: http://www.dgidb.org/api/v2/interactions.json?genes=NF2
# API 3.9: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000116132&datasource=chembl&size=15&fields=drug
# API 3.10: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000143653&datasource=chembl&size=15&fields=drug
# API 3.11: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000146457&datasource=chembl&size=15&fields=drug
# API 4.41: http://www.dgidb.org/api/v2/interactions.json?genes=COPS5
# API 3.5: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000121022&datasource=chembl&size=15&fields=drug
# API 3.6: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000146648&datasource=chembl&size=15&fields=drug
# API 3.13: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000121691&datasource=chembl&size=15&fields=drug
# API 4.40: http://www.dgidb.org/api/v2/interactions.json?genes=MTRNR2L1
# API 3.12: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000117748&datasource=chembl&size=15&fields=drug
# API 4.34: http://www.dgidb.org/api/v2/interactions.json?genes=CCNB1
# API 4.62: http://www.dgidb.org/api/v2/interactions.json?genes=CDK9
# API 1.1: https://pending.biothings.io/semmedgene/query (POST "q=C0138965,C0073337,C0282625,C1419243,C1539128,C1332695,C1425509,C1705047,C1335243,C3539596,C1418881,C1412825,C0071827,C1539098,C1424868,C1709820,C1335212,C1707152,C0074147,C2984529,C1367578,C2698689,C1826328,C0085114,C1825689,C1335262,C3147237,C1708291,C1335281,C3148432,C1427896,C1332810,C1419619,C0079427,C1427424,C0812303,C1825792,C1413633,C1336636,C1412173,C0031727,C0669365,C0007367,C1413614,C1419211,C4285071,C1705442,C0527356,C1826505,C1425940,C1424590,C2700100,C0140145,C0969119,C0056467,C1426950,C1414270,C0287531,C0017360,C1335208,C1705387,C1421999,C1419618,C1426741,C1824894,C0812201,C1413850,C1332813,C0164786,C1335607,C1421986,C0036773,C1823127,C1427252,C1419277,C0086661,C0812246,C1826417,C2681660,C1335892,C1426328,C1825463,C1418818,C1418837,C1413724,C0312359,C1424518,C1413365,C1705325,C1424135,C1413355,C1826784,C1709127,C3642141,C1425683,C1709439,C1706351,C1427105,C3272447,C1842840,C1335285,C1420667,C0672553,C1705997,C1425522,C0017822,C1539228,C1424792,C1413702,C1421047,C1539902,C1418882,C1420307,C0812252,C1413912,C1413826,C1424145,C1335213,C1418928,C1332733,C1412851,C1418696,C0812228,C0010531,C3714973,C1424323,C1414313,C1418270,C1332805,C1825553,C0059256,C0694888,C1705981,C1824317,C1705633,C1705691,C1334294,C1421289,C1332812,C1332102,C1423579,C1414905,C1826843,C1333895,C1426197,C0010642,C0376571,C0022959,C1427952,C0029073,C1705581,C1456380,C1439337,C1413290,C1826565,C1420306,C1413671,C1422009,C1427633,C1414968,C1539559,C1418596,C1424673,C1416831,C1418880,C1419620,C1427739,C1704928,C0919487,C1538595,C1335248,C1332811,C1423806,C0024750,C0079050,C1333202,C1336604,C1825621,C1707161,C1825045,C1823619,C0919528,C1332659,C1332809,C1427363,C1419236,C1424915,C1366537,C1413081,C1708031,C0694872,C1413696,C1332722,C1418582,C0248813,C1413138,C0033681,C0031678,C1822651,C0027021,C1705518,C1335267,C1418854,C1336690,C1417377&scopes=umls&fields=associated_with_reverse.chemical_substance,interacts_with.chemical_substance,affects.chemical_substance,associated_with.chemical_substance,affects_reverse.chemical_substance,interacts_with_reverse.chemical_substance&species=human&size=100")
# API 4.36: http://www.dgidb.org/api/v2/interactions.json?genes=PHB
# API 4.45: http://www.dgidb.org/api/v2/interactions.json?genes=GDPD5
# API 4.22: http://www.dgidb.org/api/v2/interactions.json?genes=ZFP36L2
# API 4.46: http://www.dgidb.org/api/v2/interactions.json?genes=APEX1
# API 4.59: http://www.dgidb.org/api/v2/interactions.json?genes=PRKDC
# API 4.33: http://www.dgidb.org/api/v2/interactions.json?genes=EIF4A3
# API 3.17: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000135870&datasource=chembl&size=15&fields=drug
# API 3.7: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000204490&datasource=chembl&size=15&fields=drug
# API 4.66: http://www.dgidb.org/api/v2/interactions.json?genes=RNH1
# API 4.32: http://www.dgidb.org/api/v2/interactions.json?genes=EEF1A1
# API 3.8: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000123131&datasource=chembl&size=15&fields=drug
# API 3.14: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000124006&datasource=chembl&size=15&fields=drug
# API 3.16: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000167815&datasource=chembl&size=15&fields=drug
# API 4.43: http://www.dgidb.org/api/v2/interactions.json?genes=PIDD1
# API 4.51: http://www.dgidb.org/api/v2/interactions.json?genes=PBK
# API 3.15: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000198478&datasource=chembl&size=15&fields=drug
# API 4.35: http://www.dgidb.org/api/v2/interactions.json?genes=CTSD
# API 4.37: http://www.dgidb.org/api/v2/interactions.json?genes=COPS6
# API 3.20: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000198668&datasource=chembl&size=15&fields=drug
# API 3.19: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000112096&datasource=chembl&size=15&fields=drug
# API 3.18: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000147601&datasource=chembl&size=15&fields=drug
# API 3.22: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000151692&datasource=chembl&size=15&fields=drug
# API 3.23: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000182566&datasource=chembl&size=15&fields=drug
# API 3.21: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000156508&datasource=chembl&size=15&fields=drug
# API 4.39: http://www.dgidb.org/api/v2/interactions.json?genes=PIK3CA
# API 3.25: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000130725&datasource=chembl&size=15&fields=drug
# API 4.38: http://www.dgidb.org/api/v2/interactions.json?genes=HEXIM1
# API 4.55: http://www.dgidb.org/api/v2/interactions.json?genes=PITX2
# API 4.57: http://www.dgidb.org/api/v2/interactions.json?genes=RASA1
# API 3.24: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000164951&datasource=chembl&size=15&fields=drug
# API 4.61: http://www.dgidb.org/api/v2/interactions.json?genes=LAP3
# API 3.26: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000228849&datasource=chembl&size=15&fields=drug
# API 4.47: http://www.dgidb.org/api/v2/interactions.json?genes=HDAC6
# API 4.60: http://www.dgidb.org/api/v2/interactions.json?genes=CUL7
# API 4.50: http://www.dgidb.org/api/v2/interactions.json?genes=ERVW-4
# API 4.91: http://www.dgidb.org/api/v2/interactions.json?genes=AAR2
# API 4.63: http://www.dgidb.org/api/v2/interactions.json?genes=BTRC
# API 4.48: http://www.dgidb.org/api/v2/interactions.json?genes=SESN2
# API 3.27: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000138823&datasource=chembl&size=15&fields=drug
# API 4.44: http://www.dgidb.org/api/v2/interactions.json?genes=RIOK1
# API 4.54: http://www.dgidb.org/api/v2/interactions.json?genes=HECTD1
# API 3.28: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000010810&datasource=chembl&size=15&fields=drug
# API 4.49: http://www.dgidb.org/api/v2/interactions.json?genes=RC3H1
# API 4.87: http://www.dgidb.org/api/v2/interactions.json?genes=CRY1
# API 3.29: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000196415&datasource=chembl&size=15&fields=drug
# API 4.52: http://www.dgidb.org/api/v2/interactions.json?genes=METTL14
# API 4.56: http://www.dgidb.org/api/v2/interactions.json?genes=PRDX4
# API 4.53: http://www.dgidb.org/api/v2/interactions.json?genes=WTAP
# API 3.30: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000196396&datasource=chembl&size=15&fields=drug
# API 4.58: http://www.dgidb.org/api/v2/interactions.json?genes=CDC42
# API 3.31: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000134283&datasource=chembl&size=15&fields=drug
# API 4.70: http://www.dgidb.org/api/v2/interactions.json?genes=TXN
# API 3.32: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000039068&datasource=chembl&size=15&fields=drug
# API 4.97: http://www.dgidb.org/api/v2/interactions.json?genes=PEBP1
# API 3.34: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000284792&datasource=chembl&size=15&fields=drug
# API 3.33: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000139842&datasource=chembl&size=15&fields=drug
# API 3.35: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000083799&datasource=chembl&size=15&fields=drug
# API 3.36: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000118260&datasource=chembl&size=15&fields=drug
# API 4.71: http://www.dgidb.org/api/v2/interactions.json?genes=CUL4B
# API 4.88: http://www.dgidb.org/api/v2/interactions.json?genes=CPLX2
# API 3.37: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000001626&datasource=chembl&size=15&fields=drug
# API 4.77: http://www.dgidb.org/api/v2/interactions.json?genes=CDK2
# API 4.74: http://www.dgidb.org/api/v2/interactions.json?genes=YAP1
# API 4.72: http://www.dgidb.org/api/v2/interactions.json?genes=RNF123
# API 4.64: http://www.dgidb.org/api/v2/interactions.json?genes=FYN
# API 4.79: http://www.dgidb.org/api/v2/interactions.json?genes=RAB4B
# API 3.38: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000145920&datasource=chembl&size=15&fields=drug
# API 4.83: http://www.dgidb.org/api/v2/interactions.json?genes=GAPDH
# API 4.78: http://www.dgidb.org/api/v2/interactions.json?genes=PTPN1
# API 4.76: http://www.dgidb.org/api/v2/interactions.json?genes=PRDX6
# API 3.39: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000126267&datasource=chembl&size=15&fields=drug
# API 4.80: http://www.dgidb.org/api/v2/interactions.json?genes=CR2
# API 4.65: http://www.dgidb.org/api/v2/interactions.json?genes=SOD2
# API 4.85: http://www.dgidb.org/api/v2/interactions.json?genes=PRKN
# API 3.40: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000117984&datasource=chembl&size=15&fields=drug
# API 4.86: http://www.dgidb.org/api/v2/interactions.json?genes=SOD1
# API 4.69: http://www.dgidb.org/api/v2/interactions.json?genes=MYC
# API 3.41: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000126432&datasource=chembl&size=15&fields=drug
# API 4.82: http://www.dgidb.org/api/v2/interactions.json?genes=CUL4A
# API 4.90: http://www.dgidb.org/api/v2/interactions.json?genes=OBSL1
# API 4.92: http://www.dgidb.org/api/v2/interactions.json?genes=DCUN1D1
# API 4.68: http://www.dgidb.org/api/v2/interactions.json?genes=UBE2M
# API 3.42: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000165672&datasource=chembl&size=15&fields=drug
# API 4.94: http://www.dgidb.org/api/v2/interactions.json?genes=TLR4
# API 4.96: http://www.dgidb.org/api/v2/interactions.json?genes=TRBV20OR9-2
# API 4.84: http://www.dgidb.org/api/v2/interactions.json?genes=TP63
# API 3.43: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000063244&datasource=chembl&size=15&fields=drug
# API 4.75: http://www.dgidb.org/api/v2/interactions.json?genes=COX17
# API 4.73: http://www.dgidb.org/api/v2/interactions.json?genes=PRDX2
# API 4.95: http://www.dgidb.org/api/v2/interactions.json?genes=RAD52
# API 3.44: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000230108&datasource=chembl&size=15&fields=drug
# API 4.98: http://www.dgidb.org/api/v2/interactions.json?genes=ANAPC15
# API 4.93: http://www.dgidb.org/api/v2/interactions.json?genes=VRK3
# API 3.46: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000165025&datasource=chembl&size=15&fields=drug
# API 4.100: http://www.dgidb.org/api/v2/interactions.json?genes=ACY1
# API 3.47: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000271303&datasource=chembl&size=15&fields=drug
# API 4.89: http://www.dgidb.org/api/v2/interactions.json?genes=PRDX3
# API 3.45: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000121879&datasource=chembl&size=15&fields=drug
# API 4.81: http://www.dgidb.org/api/v2/interactions.json?genes=UCHL5
# API 4.110: http://www.dgidb.org/api/v2/interactions.json?genes=PPP2R1B
# API 4.112: http://www.dgidb.org/api/v2/interactions.json?genes=RPA3
# API 4.113: http://www.dgidb.org/api/v2/interactions.json?genes=RPA2
# API 4.114: http://www.dgidb.org/api/v2/interactions.json?genes=RBMS3
# API 4.99: http://www.dgidb.org/api/v2/interactions.json?genes=CFTR
# API 3.49: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000186834&datasource=chembl&size=15&fields=drug
# API 4.115: http://www.dgidb.org/api/v2/interactions.json?genes=PRTN3
# API 3.52: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000172137&datasource=chembl&size=15&fields=drug
# API 4.67: http://www.dgidb.org/api/v2/interactions.json?genes=TNF
# API 4.117: http://www.dgidb.org/api/v2/interactions.json?genes=CYLD
# API 4.116: http://www.dgidb.org/api/v2/interactions.json?genes=PTPRC
# API 3.53: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000284807&datasource=chembl&size=15&fields=drug
# API 4.119: http://www.dgidb.org/api/v2/interactions.json?genes=CUL1
# API 4.120: http://www.dgidb.org/api/v2/interactions.json?genes=SLC38A1
# API 3.54: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000256618&datasource=chembl&size=15&fields=drug
# API 4.121: http://www.dgidb.org/api/v2/interactions.json?genes=DHRS4
# API 3.55: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000105401&datasource=chembl&size=15&fields=drug
# API 4.122: http://www.dgidb.org/api/v2/interactions.json?genes=PPHLN1
# API 4.123: http://www.dgidb.org/api/v2/interactions.json?genes=OTUB1
# API 4.126: http://www.dgidb.org/api/v2/interactions.json?genes=PPP2R1A
# API 4.118: http://www.dgidb.org/api/v2/interactions.json?genes=NTRK1
# API 4.125: http://www.dgidb.org/api/v2/interactions.json?genes=CREB1
# API 3.59: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000131238&datasource=chembl&size=15&fields=drug
# API 4.127: http://www.dgidb.org/api/v2/interactions.json?genes=PRDX5
# API 4.128: http://www.dgidb.org/api/v2/interactions.json?genes=ISG15
# API 4.129: http://www.dgidb.org/api/v2/interactions.json?genes=PRPF8
# API 4.130: http://www.dgidb.org/api/v2/interactions.json?genes=DCPS
# API 4.131: http://www.dgidb.org/api/v2/interactions.json?genes=CDH1
# API 3.60: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000164093&datasource=chembl&size=15&fields=drug
# API 4.104: http://www.dgidb.org/api/v2/interactions.json?genes=PTEN
# API 3.57: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000243989&datasource=chembl&size=15&fields=drug
# API 3.63: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000160957&datasource=chembl&size=15&fields=drug
# API 3.62: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000092148&datasource=chembl&size=15&fields=drug
# API 4.132: http://www.dgidb.org/api/v2/interactions.json?genes=SUZ12
# API 4.124: http://www.dgidb.org/api/v2/interactions.json?genes=AKT1
# API 4.133: http://www.dgidb.org/api/v2/interactions.json?genes=HTRA2
# API 3.65: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000138495&datasource=chembl&size=15&fields=drug
# API 3.61: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000228321&datasource=chembl&size=15&fields=drug
# API 4.135: http://www.dgidb.org/api/v2/interactions.json?genes=DAZAP1
# API 3.48: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000094631&datasource=chembl&size=15&fields=drug
# API 4.136: http://www.dgidb.org/api/v2/interactions.json?genes=RPA1
# API 4.137: http://www.dgidb.org/api/v2/interactions.json?genes=JTB
# API 4.134: http://www.dgidb.org/api/v2/interactions.json?genes=CALM1
# API 4.138: http://www.dgidb.org/api/v2/interactions.json?genes=PIN1
# API 4.139: http://www.dgidb.org/api/v2/interactions.json?genes=RAD23A
# API 3.64: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000262418&datasource=chembl&size=15&fields=drug
# API 4.141: http://www.dgidb.org/api/v2/interactions.json?genes=CDC73
# API 4.142: http://www.dgidb.org/api/v2/interactions.json?genes=AGO4
# API 3.50: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000167770&datasource=chembl&size=15&fields=drug
# API 3.68: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000172757&datasource=chembl&size=15&fields=drug
# API 3.51: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000117592&datasource=chembl&size=15&fields=drug
# API 4.145: http://www.dgidb.org/api/v2/interactions.json?genes=U2AF2
# API 3.66: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000137693&datasource=chembl&size=15&fields=drug
# API 3.67: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000185345&datasource=chembl&size=15&fields=drug
# API 4.144: http://www.dgidb.org/api/v2/interactions.json?genes=PRKCZ
# API 3.69: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000071626&datasource=chembl&size=15&fields=drug
# API 4.146: http://www.dgidb.org/api/v2/interactions.json?genes=CUL5
# API 3.72: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000285441&datasource=chembl&size=15&fields=drug
# API 3.76: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000144642&datasource=chembl&size=15&fields=drug
# API 3.73: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000276230&datasource=chembl&size=15&fields=drug
# API 3.70: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000164944&datasource=chembl&size=15&fields=drug
# API 3.77: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000142208&datasource=chembl&size=15&fields=drug
# API 3.78: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000174231&datasource=chembl&size=15&fields=drug
# API 3.71: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000167085&datasource=chembl&size=15&fields=drug
# API 3.80: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000164068&datasource=chembl&size=15&fields=drug
# API 3.79: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000051382&datasource=chembl&size=15&fields=drug
# API 3.82: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000171862&datasource=chembl&size=15&fields=drug
# API 3.81: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000012048&datasource=chembl&size=15&fields=drug
# API 3.75: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000134371&datasource=chembl&size=15&fields=drug
# API 3.74: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000134057&datasource=chembl&size=15&fields=drug
# API 4.143: http://www.dgidb.org/api/v2/interactions.json?genes=AR
# API 3.84: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000002549&datasource=chembl&size=15&fields=drug
# API 3.56: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000023191&datasource=chembl&size=15&fields=drug
# API 3.58: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000134698&datasource=chembl&size=15&fields=drug
# robokop_gene2chemical failed
# API 3.85: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000130766&datasource=chembl&size=15&fields=drug
# API 2.1: http://mychem.info/v1/query (POST "q=RNF144A,CALB2,SCCPDH,KMT2A,PPP2R5D,SH3BGRL2,CDC37,SESN1,FERMT3,RECQL4,MST1,PPT1,PDP1,ZFP36L2,PIK3CB,MEPCE,COX6B1,ETS1,EEF1A1,CTSD,PHB,COPS6,GDPD5,HDAC6,MTRNR2L1,ERVW-4,PIDD1,RIOK1,APEX1,SESN2,RC3H1,PBK,HECTD1,PRDX4,RASA1,PRKDC,LAP3,TNF,UBE2M,MYC,TXN,CUL4B,RNF123,COX17,CDK2,PRDX6,PTPN1,RAB4B,GAPDH,TP63,PRKN,SOD1,CRY1,OBSL1,VRK3,AAR2,TRBV20OR9-2,RAD52,PEBP1,CFTR,ACY1,CUL3,BRCA1,DNPH1,TRIM4,VIRMA,RPA2,PRTN3,CYLD,DHRS4,OTUB1,CREB1,ISG15,HTRA2,DCPS,CALM1,DAZAP1,PIN1,AR,CPLX2,U2AF2,CDC73,CLEC4G,LGALS3,LARP7,SYK,CAT,ZFR,PRRX1,CUL2,TERF1,GABPA,TDGF1,DAB2,VEGFA,EIF4A3,CCNB1,HEXIM1,PIK3CA,NF2,COPS5,METTL14,WTAP,PITX2,CDC42,CUL7,CDK9,BTRC,FYN,SOD2,RNH1,YAP1,PRDX2,CR2,UCHL5,CUL4A,PRDX3,DCUN1D1,TLR4,ANAPC15,CRK,SRXN1,MTTP,PTEN,CFL1,RPA3,PPP2R1B,RBMS3,PTPRC,NTRK1,CUL1,PPHLN1,AKT1,PPP2R1A,PRDX5,PRPF8,CDH1,SUZ12,RPA1,JTB,RAD23A,EGFR,AGO4,SLC38A1,PRKCZ,CUL5&scopes=drugbank.enzymes.gene_name&fields=drugbank.id&species=human&size=100")
# API 3.86: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000152518&datasource=chembl&size=15&fields=drug
# API 3.87: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000178691&datasource=chembl&size=15&fields=drug
# API 3.88: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000132383&datasource=chembl&size=15&fields=drug
# API 3.83: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000146834&datasource=chembl&size=15&fields=drug
# API 3.91: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000073282&datasource=chembl&size=15&fields=drug
# API 3.92: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000136810&datasource=chembl&size=15&fields=drug
# API 3.93: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000153071&datasource=chembl&size=15&fields=drug
# API 3.89: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000179262&datasource=chembl&size=15&fields=drug
# API 3.90: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000136807&datasource=chembl&size=15&fields=drug
# API 4.140: http://www.dgidb.org/api/v2/interactions.json?genes=EGFR
# API 5.1: https://robokop.renci.org/api/simple/expand/gene/HGNC:1442/chemical_substance/
# API 5.3: https://robokop.renci.org/api/simple/expand/gene/HGNC:16783/chemical_substance/
# API 5.4: https://robokop.renci.org/api/simple/expand/gene/HGNC:8912/chemical_substance/
# API 2.3: http://mychem.info/v1/query (POST "q=RNF144A,CALB2,SCCPDH,KMT2A,PPP2R5D,SH3BGRL2,CDC37,SESN1,FERMT3,RECQL4,MST1,PPT1,PDP1,ZFP36L2,PIK3CB,MEPCE,COX6B1,ETS1,EEF1A1,CTSD,PHB,COPS6,GDPD5,HDAC6,MTRNR2L1,ERVW-4,PIDD1,RIOK1,APEX1,SESN2,RC3H1,PBK,HECTD1,PRDX4,RASA1,PRKDC,LAP3,TNF,UBE2M,MYC,TXN,CUL4B,RNF123,COX17,CDK2,PRDX6,PTPN1,RAB4B,GAPDH,TP63,PRKN,SOD1,CRY1,OBSL1,VRK3,AAR2,TRBV20OR9-2,RAD52,PEBP1,CFTR,ACY1,CUL3,BRCA1,DNPH1,TRIM4,VIRMA,RPA2,PRTN3,CYLD,DHRS4,OTUB1,CREB1,ISG15,HTRA2,DCPS,CALM1,DAZAP1,PIN1,AR,CPLX2,U2AF2,CDC73,CLEC4G,LGALS3,LARP7,SYK,CAT,ZFR,PRRX1,CUL2,TERF1,GABPA,TDGF1,DAB2,VEGFA,EIF4A3,CCNB1,HEXIM1,PIK3CA,NF2,COPS5,METTL14,WTAP,PITX2,CDC42,CUL7,CDK9,BTRC,FYN,SOD2,RNH1,YAP1,PRDX2,CR2,UCHL5,CUL4A,PRDX3,DCUN1D1,TLR4,ANAPC15,CRK,SRXN1,MTTP,PTEN,CFL1,RPA3,PPP2R1B,RBMS3,PTPRC,NTRK1,CUL1,PPHLN1,AKT1,PPP2R1A,PRDX5,PRPF8,CDH1,SUZ12,RPA1,JTB,RAD23A,EGFR,AGO4,SLC38A1,PRKCZ,CUL5&scopes=drugcentral.bioactivity.uniprot.gene_symbol&fields=chembl.molecule_chembl_id&species=human&size=100")
# API 5.2: https://robokop.renci.org/api/simple/expand/gene/HGNC:3189/chemical_substance/
# API 2.2: http://mychem.info/v1/query (POST "q=RNF144A,CALB2,SCCPDH,KMT2A,PPP2R5D,SH3BGRL2,CDC37,SESN1,FERMT3,RECQL4,MST1,PPT1,PDP1,ZFP36L2,PIK3CB,MEPCE,COX6B1,ETS1,EEF1A1,CTSD,PHB,COPS6,GDPD5,HDAC6,MTRNR2L1,ERVW-4,PIDD1,RIOK1,APEX1,SESN2,RC3H1,PBK,HECTD1,PRDX4,RASA1,PRKDC,LAP3,TNF,UBE2M,MYC,TXN,CUL4B,RNF123,COX17,CDK2,PRDX6,PTPN1,RAB4B,GAPDH,TP63,PRKN,SOD1,CRY1,OBSL1,VRK3,AAR2,TRBV20OR9-2,RAD52,PEBP1,CFTR,ACY1,CUL3,BRCA1,DNPH1,TRIM4,VIRMA,RPA2,PRTN3,CYLD,DHRS4,OTUB1,CREB1,ISG15,HTRA2,DCPS,CALM1,DAZAP1,PIN1,AR,CPLX2,U2AF2,CDC73,CLEC4G,LGALS3,LARP7,SYK,CAT,ZFR,PRRX1,CUL2,TERF1,GABPA,TDGF1,DAB2,VEGFA,EIF4A3,CCNB1,HEXIM1,PIK3CA,NF2,COPS5,METTL14,WTAP,PITX2,CDC42,CUL7,CDK9,BTRC,FYN,SOD2,RNH1,YAP1,PRDX2,CR2,UCHL5,CUL4A,PRDX3,DCUN1D1,TLR4,ANAPC15,CRK,SRXN1,MTTP,PTEN,CFL1,RPA3,PPP2R1B,RBMS3,PTPRC,NTRK1,CUL1,PPHLN1,AKT1,PPP2R1A,PRDX5,PRPF8,CDH1,SUZ12,RPA1,JTB,RAD23A,EGFR,AGO4,SLC38A1,PRKCZ,CUL5&scopes=drugbank.targets.gene_name&fields=drugbank.id&species=human&size=100")
# API 5.5: https://robokop.renci.org/api/simple/expand/gene/HGNC:11179/chemical_substance/
# API 5.8: https://robokop.renci.org/api/simple/expand/gene/HGNC:18449/chemical_substance/
# API 5.6: https://robokop.renci.org/api/simple/expand/gene/HGNC:16262/chemical_substance/
# API 5.7: https://robokop.renci.org/api/simple/expand/gene/HGNC:29812/chemical_substance/
# API 5.10: https://robokop.renci.org/api/simple/expand/gene/HGNC:9355/chemical_substance/
# API 3.94: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000142168&datasource=chembl&size=15&fields=drug
# API 5.9: https://robokop.renci.org/api/simple/expand/gene/HGNC:15979/chemical_substance/
# API 5.11: https://robokop.renci.org/api/simple/expand/gene/HGNC:29092/chemical_substance/
# API 3.95: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000044090&datasource=chembl&size=15&fields=drug
# API 5.12: https://robokop.renci.org/api/simple/expand/gene/HGNC:1736/chemical_substance/
# API 3.97: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000173531&datasource=chembl&size=15&fields=drug
# API 5.13: https://robokop.renci.org/api/simple/expand/gene/HGNC:9279/chemical_substance/
# API 5.14: https://robokop.renci.org/api/simple/expand/gene/HGNC:16132/chemical_substance/
# API 5.15: https://robokop.renci.org/api/simple/expand/gene/HGNC:9354/chemical_substance/
# API 3.96: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000157326&datasource=chembl&size=15&fields=drug
# API 5.17: https://robokop.renci.org/api/simple/expand/gene/HGNC:37155/chemical_substance/
# API 3.99: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000112667&datasource=chembl&size=15&fields=drug
# API 3.100: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000112715&datasource=chembl&size=15&fields=drug
# API 5.16: https://robokop.renci.org/api/simple/expand/gene/HGNC:644/chemical_substance/
# API 3.101: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000168090&datasource=chembl&size=15&fields=drug
# API 3.98: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000232810&datasource=chembl&size=15&fields=drug
# API 5.18: https://robokop.renci.org/api/simple/expand/gene/HGNC:4071/chemical_substance/
# API 3.102: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000131043&datasource=chembl&size=15&fields=drug
# API 5.21: https://robokop.renci.org/api/simple/expand/gene/HGNC:8031/chemical_substance/
# API 5.19: https://robokop.renci.org/api/simple/expand/gene/HGNC:18424/chemical_substance/
# API 3.103: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000056097&datasource=chembl&size=15&fields=drug
# API 3.104: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000055130&datasource=chembl&size=15&fields=drug
# API 5.20: https://robokop.renci.org/api/simple/expand/gene/HGNC:16753/chemical_substance/
# API 3.105: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000177595&datasource=chembl&size=15&fields=drug
# API 3.106: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000145715&datasource=chembl&size=15&fields=drug
# API 3.107: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000134954&datasource=chembl&size=15&fields=drug
# API 3.109: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000136997&datasource=chembl&size=15&fields=drug
# API 3.108: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000174720&datasource=chembl&size=15&fields=drug
# API 5.23: https://robokop.renci.org/api/simple/expand/gene/HGNC:29330/chemical_substance/
# API 5.24: https://robokop.renci.org/api/simple/expand/gene/HGNC:2280/chemical_substance/
# API 5.22: https://robokop.renci.org/api/simple/expand/gene/HGNC:1884/chemical_substance/
# API 3.110: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000124784&datasource=chembl&size=15&fields=drug
# API 5.25: https://robokop.renci.org/api/simple/expand/gene/HGNC:17340/chemical_substance/
# API 3.111: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000154727&datasource=chembl&size=15&fields=drug
# API 3.112: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000111640&datasource=chembl&size=15&fields=drug
# API 5.27: https://robokop.renci.org/api/simple/expand/gene/HGNC:1780/chemical_substance/
# API 3.113: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000081237&datasource=chembl&size=15&fields=drug
# API 5.26: https://robokop.renci.org/api/simple/expand/gene/HGNC:1108/chemical_substance/
# API 5.29: https://robokop.renci.org/api/simple/expand/gene/HGNC:23151/chemical_substance/
# API 3.114: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000123374&datasource=chembl&size=15&fields=drug
# API 3.115: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000158555&datasource=chembl&size=15&fields=drug
# API 5.28: https://robokop.renci.org/api/simple/expand/gene/HGNC:4053/chemical_substance/
# API 3.116: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSRNOG00000017695&datasource=chembl&size=15&fields=drug
# API 5.30: https://robokop.renci.org/api/simple/expand/gene/HGNC:587/chemical_substance/
# API 3.117: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000169083&datasource=chembl&size=15&fields=drug
# API 3.118: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000198400&datasource=chembl&size=15&fields=drug
# API 3.119: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000136869&datasource=chembl&size=15&fields=drug
# API 3.120: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000277804&datasource=chembl&size=15&fields=drug
# API 5.34: https://robokop.renci.org/api/simple/expand/gene/HGNC:24591/chemical_substance/
# API 5.32: https://robokop.renci.org/api/simple/expand/gene/HGNC:177/chemical_substance/
# API 3.121: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000089220&datasource=chembl&size=15&fields=drug
# API 5.36: https://robokop.renci.org/api/simple/expand/gene/HGNC:13427/chemical_substance/
# API 5.37: https://robokop.renci.org/api/simple/expand/gene/HGNC:2362/chemical_substance/
# API 3.122: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000146833&datasource=chembl&size=15&fields=drug
# API 5.33: https://robokop.renci.org/api/simple/expand/gene/HGNC:391/chemical_substance/
# API 5.38: https://robokop.renci.org/api/simple/expand/gene/HGNC:7380/chemical_substance/
# API 5.39: https://robokop.renci.org/api/simple/expand/gene/HGNC:24500/chemical_substance/
# API 5.41: https://robokop.renci.org/api/simple/expand/gene/HGNC:9782/chemical_substance/
# API 5.35: https://robokop.renci.org/api/simple/expand/gene/HGNC:2264/chemical_substance/
# API 3.123: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000166266&datasource=chembl&size=15&fields=drug
# API 5.43: https://robokop.renci.org/api/simple/expand/gene/HGNC:18282/chemical_substance/
# API 5.42: https://robokop.renci.org/api/simple/expand/gene/HGNC:9824/chemical_substance/
# API 3.124: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000110200&datasource=chembl&size=15&fields=drug
# API 5.46: https://robokop.renci.org/api/simple/expand/gene/HGNC:10074/chemical_substance/
# API 5.45: https://robokop.renci.org/api/simple/expand/gene/HGNC:20457/chemical_substance/
# API 3.125: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000141543&datasource=chembl&size=15&fields=drug
# API 5.40: https://robokop.renci.org/api/simple/expand/gene/HGNC:3236/chemical_substance/
# API 5.48: https://robokop.renci.org/api/simple/expand/gene/HGNC:24275/chemical_substance/
# API 5.47: https://robokop.renci.org/api/simple/expand/gene/HGNC:16491/chemical_substance/
# API 3.126: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000108094&datasource=chembl&size=15&fields=drug
# API 5.52: https://robokop.renci.org/api/simple/expand/gene/HGNC:9949/chemical_substance/
# API 5.44: https://robokop.renci.org/api/simple/expand/gene/HGNC:4141/chemical_substance/
# API 5.50: https://robokop.renci.org/api/simple/expand/gene/HGNC:14348/chemical_substance/
# API 5.49: https://robokop.renci.org/api/simple/expand/gene/HGNC:15886/chemical_substance/
# API 3.129: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000070831&datasource=chembl&size=15&fields=drug
# API 5.51: https://robokop.renci.org/api/simple/expand/gene/HGNC:9666/chemical_substance/
# API 3.127: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000002016&datasource=chembl&size=15&fields=drug
# API 3.128: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000036257&datasource=chembl&size=15&fields=drug
# API 5.54: https://robokop.renci.org/api/simple/expand/gene/HGNC:9303/chemical_substance/
# API 3.130: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000166167&datasource=chembl&size=15&fields=drug
# API 5.55: https://robokop.renci.org/api/simple/expand/gene/HGNC:18996/chemical_substance/
# API 5.59: https://robokop.renci.org/api/simple/expand/gene/HGNC:9812/chemical_substance/
# API 3.131: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000158290&datasource=chembl&size=15&fields=drug
# API 3.133: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000043093&datasource=chembl&size=15&fields=drug
# API 3.132: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000106399&datasource=chembl&size=15&fields=drug
# API 3.134: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000282830&datasource=chembl&size=15&fields=drug
# API 3.137: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000115317&datasource=chembl&size=15&fields=drug
# API 3.135: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000285069&datasource=chembl&size=15&fields=drug
# API 5.56: https://robokop.renci.org/api/simple/expand/gene/HGNC:9495/chemical_substance/
# API 5.58: https://robokop.renci.org/api/simple/expand/gene/HGNC:21218/chemical_substance/
# API 3.143: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000206439&datasource=chembl&size=15&fields=drug
# API 3.147: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000223952&datasource=chembl&size=15&fields=drug
# API 3.146: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000167193&datasource=chembl&size=15&fields=drug
# API 3.136: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000112640&datasource=chembl&size=15&fields=drug
# API 5.53: https://robokop.renci.org/api/simple/expand/gene/HGNC:9353/chemical_substance/
# API 5.64: https://robokop.renci.org/api/simple/expand/gene/HGNC:1144/chemical_substance/
# API 3.138: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000100823&datasource=chembl&size=15&fields=drug
# API 3.140: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000111371&datasource=chembl&size=15&fields=drug
# API 3.142: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000117322&datasource=chembl&size=15&fields=drug
# API 3.141: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000145388&datasource=chembl&size=15&fields=drug
# API 3.144: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000187608&datasource=chembl&size=15&fields=drug
# API 3.145: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000067606&datasource=chembl&size=15&fields=drug
# API 3.148: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000131981&datasource=chembl&size=15&fields=drug
# API 5.57: https://robokop.renci.org/api/simple/expand/gene/HGNC:1435/chemical_substance/
# API 3.149: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000143543&datasource=chembl&size=15&fields=drug
# API 3.150: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000008405&datasource=chembl&size=15&fields=drug
# API 3.151: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000127445&datasource=chembl&size=15&fields=drug
# API 3.158: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000228978&datasource=chembl&size=15&fields=drug
# API 3.152: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000080546&datasource=chembl&size=15&fields=drug
# API 3.153: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000253729&datasource=chembl&size=15&fields=drug
# API 3.156: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000105568&datasource=chembl&size=15&fields=drug
# API 3.154: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000105053&datasource=chembl&size=15&fields=drug
# API 3.155: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000167578&datasource=chembl&size=15&fields=drug
# API 3.157: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000241186&datasource=chembl&size=15&fields=drug
# API 3.160: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000116750&datasource=chembl&size=15&fields=drug
# API 3.159: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSGALG00000010243&datasource=chembl&size=15&fields=drug
# API 3.139: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000137713&datasource=chembl&size=15&fields=drug
# API 3.161: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000149781&datasource=chembl&size=15&fields=drug
# API 3.162: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000186575&datasource=chembl&size=15&fields=drug
# API 5.31: https://robokop.renci.org/api/simple/expand/gene/HGNC:11892/chemical_substance/
# API 5.61: https://robokop.renci.org/api/simple/expand/gene/HGNC:10291/chemical_substance/
# API 5.65: https://robokop.renci.org/api/simple/expand/gene/HGNC:16846/chemical_substance/
# API 5.60: https://robokop.renci.org/api/simple/expand/gene/HGNC:8607/chemical_substance/
# API 5.68: https://robokop.renci.org/api/simple/expand/gene/HGNC:23077/chemical_substance/
# API 5.69: https://robokop.renci.org/api/simple/expand/gene/HGNC:9642/chemical_substance/
# API 5.67: https://robokop.renci.org/api/simple/expand/gene/HGNC:21024/chemical_substance/
# API 5.62: https://robokop.renci.org/api/simple/expand/gene/HGNC:17101/chemical_substance/
# API 5.75: https://robokop.renci.org/api/simple/expand/gene/HGNC:20746/chemical_substance/
# ...
# API 4.15 dgidb_gene2chemical: 1 hits
# API 4.16 dgidb_gene2chemical: No hits
# API 4.17 dgidb_gene2chemical: 1 hits
# API 4.18 dgidb_gene2chemical: 3 hits
# API 4.19 dgidb_gene2chemical: No hits
# API 4.20 dgidb_gene2chemical: No hits
# API 4.21 dgidb_gene2chemical: No hits
# API 4.22 dgidb_gene2chemical: 1 hits
# API 4.23 dgidb_gene2chemical: No hits
# API 4.24 dgidb_gene2chemical: 67 hits
# API 4.25 dgidb_gene2chemical: 2 hits
# API 4.26 dgidb_gene2chemical: No hits
# API 4.27 dgidb_gene2chemical: No hits
# API 4.28 dgidb_gene2chemical: No hits
# API 4.29 dgidb_gene2chemical: 1 hits
# API 4.30 dgidb_gene2chemical: No hits
# API 4.31 dgidb_gene2chemical: 33 hits
# API 4.32 dgidb_gene2chemical: 2 hits
# API 4.33 dgidb_gene2chemical: No hits
# API 4.34 dgidb_gene2chemical: No hits
# API 4.35 dgidb_gene2chemical: 9 hits
# API 4.36 dgidb_gene2chemical: No hits
# API 4.37 dgidb_gene2chemical: No hits
# API 4.38 dgidb_gene2chemical: No hits
# API 4.39 dgidb_gene2chemical: 149 hits
# API 4.40 dgidb_gene2chemical: No hits
# API 4.41 dgidb_gene2chemical: No hits
# API 4.42 dgidb_gene2chemical: 11 hits
# API 4.43 dgidb_gene2chemical: No hits
# API 4.44 dgidb_gene2chemical: No hits
# API 4.45 dgidb_gene2chemical: No hits
# API 4.46 dgidb_gene2chemical: 3 hits
# API 4.47 dgidb_gene2chemical: 24 hits
# API 4.48 dgidb_gene2chemical: No hits
# API 4.49 dgidb_gene2chemical: No hits
# API 4.50 dgidb_gene2chemical: No hits
# API 4.51 dgidb_gene2chemical: 1 hits
# API 4.52 dgidb_gene2chemical: No hits
# API 4.53 dgidb_gene2chemical: No hits
# API 4.54 dgidb_gene2chemical: No hits
# API 4.55 dgidb_gene2chemical: No hits
# API 4.56 dgidb_gene2chemical: 1 hits
# API 4.57 dgidb_gene2chemical: No hits
# API 4.58 dgidb_gene2chemical: 2 hits
# API 4.59 dgidb_gene2chemical: 7 hits
# API 4.60 dgidb_gene2chemical: No hits
# API 4.61 dgidb_gene2chemical: 3 hits
# API 4.62 dgidb_gene2chemical: 14 hits
# API 4.63 dgidb_gene2chemical: 1 hits
# API 4.64 dgidb_gene2chemical: 15 hits
# API 4.65 dgidb_gene2chemical: 2 hits
# API 4.66 dgidb_gene2chemical: No hits
# API 4.67 dgidb_gene2chemical: 72 hits
# API 4.68 dgidb_gene2chemical: No hits
# API 4.69 dgidb_gene2chemical: 48 hits
# API 4.70 dgidb_gene2chemical: 1 hits
# API 4.71 dgidb_gene2chemical: No hits
# API 4.72 dgidb_gene2chemical: No hits
# API 4.73 dgidb_gene2chemical: 1 hits
# API 4.74 dgidb_gene2chemical: No hits
# API 4.75 dgidb_gene2chemical: No hits
# API 4.76 dgidb_gene2chemical: No hits
# API 4.77 dgidb_gene2chemical: 142 hits
# API 4.78 dgidb_gene2chemical: 35 hits
# API 4.79 dgidb_gene2chemical: No hits
# API 4.80 dgidb_gene2chemical: 2 hits
# API 4.81 dgidb_gene2chemical: No hits
# API 4.82 dgidb_gene2chemical: 3 hits
# API 4.83 dgidb_gene2chemical: 8 hits
# API 4.84 dgidb_gene2chemical: No hits
# API 4.85 dgidb_gene2chemical: No hits
# API 4.86 dgidb_gene2chemical: 2 hits
# API 4.87 dgidb_gene2chemical: 1 hits
# API 4.88 dgidb_gene2chemical: No hits
# API 4.89 dgidb_gene2chemical: No hits
# API 4.90 dgidb_gene2chemical: No hits
# API 4.91 dgidb_gene2chemical: No hits
# API 4.92 dgidb_gene2chemical: No hits
# API 4.93 dgidb_gene2chemical: No hits
# API 4.94 dgidb_gene2chemical: 13 hits
# API 4.95 dgidb_gene2chemical: 1 hits
# API 4.96 dgidb_gene2chemical: No hits
# API 4.97 dgidb_gene2chemical: 2 hits
# API 4.98 dgidb_gene2chemical: No hits
# API 4.99 dgidb_gene2chemical: 20 hits
# API 4.100 dgidb_gene2chemical: 2 hits
# API 4.101 dgidb_gene2chemical: No hits
# API 4.102 dgidb_gene2chemical: No hits
# API 4.103 dgidb_gene2chemical: No hits
# API 4.104 dgidb_gene2chemical: 104 hits
# API 4.105 dgidb_gene2chemical: No hits
# API 4.106 dgidb_gene2chemical: No hits
# API 4.107 dgidb_gene2chemical: No hits
# API 4.108 dgidb_gene2chemical: No hits
# API 4.109 dgidb_gene2chemical: No hits
# API 4.110 dgidb_gene2chemical: No hits
# API 4.111 dgidb_gene2chemical: No hits
# API 4.112 dgidb_gene2chemical: No hits
# API 4.113 dgidb_gene2chemical: No hits
# API 4.114 dgidb_gene2chemical: 1 hits
# API 4.115 dgidb_gene2chemical: 3 hits
# API 4.116 dgidb_gene2chemical: 8 hits
# API 4.117 dgidb_gene2chemical: No hits
# API 4.118 dgidb_gene2chemical: 37 hits
# API 4.119 dgidb_gene2chemical: No hits
# API 4.120 dgidb_gene2chemical: No hits
# API 4.121 dgidb_gene2chemical: 1 hits
# API 4.122 dgidb_gene2chemical: No hits
# API 4.123 dgidb_gene2chemical: No hits
# API 4.124 dgidb_gene2chemical: 43 hits
# API 4.125 dgidb_gene2chemical: 3 hits
# API 4.126 dgidb_gene2chemical: No hits
# API 4.127 dgidb_gene2chemical: 3 hits
# API 4.128 dgidb_gene2chemical: 1 hits
# API 4.129 dgidb_gene2chemical: No hits
# API 4.130 dgidb_gene2chemical: 2 hits
# API 4.131 dgidb_gene2chemical: 7 hits
# API 4.132 dgidb_gene2chemical: No hits
# API 4.133 dgidb_gene2chemical: No hits
# API 4.134 dgidb_gene2chemical: 15 hits
# API 4.135 dgidb_gene2chemical: No hits
# API 4.136 dgidb_gene2chemical: No hits
# API 4.137 dgidb_gene2chemical: No hits
# API 4.138 dgidb_gene2chemical: No hits
# API 4.139 dgidb_gene2chemical: No hits
# API 4.140 dgidb_gene2chemical: 146 hits
# API 4.141 dgidb_gene2chemical: No hits
# API 4.142 dgidb_gene2chemical: No hits
# API 4.143 dgidb_gene2chemical: 80 hits
# API 4.144 dgidb_gene2chemical: 10 hits
# API 4.145 dgidb_gene2chemical: No hits
# API 4.146 dgidb_gene2chemical: No hits
# API 2.1 mychem.info: 19 hits
# API 2.2 mychem.info: 518 hits
# API 2.3 mychem.info: 301 hits
# API 3.1 opentarget: No hits
# API 3.2 opentarget: No hits
# API 3.3 opentarget: No hits
# API 3.4 opentarget: No hits
# API 3.5 opentarget: No hits
# API 3.6 opentarget: 15 hits
# API 3.7 opentarget: No hits
# API 3.8 opentarget: No hits
# API 3.9 opentarget: No hits
# API 3.10 opentarget: No hits
# API 3.11 opentarget: No hits
# API 3.12 opentarget: No hits
# API 3.13 opentarget: No hits
# API 3.14 opentarget: No hits
# API 3.15 opentarget: No hits
# API 3.16 opentarget: No hits
# API 3.17 opentarget: No hits
# API 3.18 opentarget: No hits
# API 3.19 opentarget: No hits
# API 3.20 opentarget: No hits
# API 3.21 opentarget: No hits
# API 3.22 opentarget: No hits
# API 3.23 opentarget: No hits
# API 3.24 opentarget: No hits
# API 3.25 opentarget: No hits
# API 3.26 opentarget: No hits
# API 3.27 opentarget: 10 hits
# API 3.28 opentarget: 15 hits
# API 3.29 opentarget: No hits
# API 3.30 opentarget: No hits
# API 3.31 opentarget: No hits
# API 3.32 opentarget: No hits
# API 3.33 opentarget: 15 hits
# API 3.34 opentarget: No hits
# API 3.35 opentarget: No hits
# API 3.36 opentarget: No hits
# API 3.37 opentarget: 15 hits
# API 3.38 opentarget: No hits
# API 3.39 opentarget: No hits
# API 3.40 opentarget: No hits
# API 3.41 opentarget: No hits
# API 3.42 opentarget: No hits
# API 3.43 opentarget: No hits
# API 3.44 opentarget: No hits
# API 3.45 opentarget: 15 hits
# API 3.46 opentarget: 15 hits
# API 3.47 opentarget: No hits
# API 3.48 opentarget: 15 hits
# API 3.49 opentarget: No hits
# API 3.50 opentarget: No hits
# API 3.51 opentarget: No hits
# API 3.52 opentarget: No hits
# API 3.53 opentarget: No hits
# API 3.54 opentarget: No hits
# API 3.55 opentarget: No hits
# API 3.56 opentarget: No hits
# API 3.57 opentarget: No hits
# API 3.58 opentarget: No hits
# API 3.59 opentarget: No hits
# API 3.60 opentarget: No hits
# API 3.61 opentarget: No hits
# API 3.62 opentarget: No hits
# API 3.63 opentarget: No hits
# API 3.64 opentarget: No hits
# API 3.65 opentarget: No hits
# API 3.66 opentarget: No hits
# API 3.67 opentarget: No hits
# API 3.68 opentarget: No hits
# API 3.69 opentarget: No hits
# API 3.70 opentarget: No hits
# API 3.71 opentarget: No hits
# API 3.72 opentarget: No hits
# API 3.73 opentarget: No hits
# API 3.74 opentarget: No hits
# API 3.75 opentarget: No hits
# API 3.76 opentarget: No hits
# API 3.77 opentarget: 15 hits
# API 3.78 opentarget: No hits
# API 3.79 opentarget: 15 hits
# API 3.80 opentarget: No hits
# API 3.81 opentarget: No hits
# API 3.82 opentarget: No hits
# API 3.83 opentarget: No hits
# API 3.84 opentarget: 7 hits
# API 3.85 opentarget: No hits
# API 3.86 opentarget: No hits
# API 3.87 opentarget: No hits
# API 3.88 opentarget: No hits
# API 3.89 opentarget: No hits
# API 3.90 opentarget: 15 hits
# API 3.91 opentarget: No hits
# API 3.92 opentarget: No hits
# API 3.93 opentarget: No hits
# API 3.94 opentarget: 2 hits
# API 3.95 opentarget: No hits
# API 3.96 opentarget: No hits
# API 3.97 opentarget: No hits
# API 3.98 opentarget: 15 hits
# API 3.99 opentarget: No hits
# API 3.100 opentarget: 15 hits
# API 3.101 opentarget: No hits
# API 3.102 opentarget: No hits
# API 3.103 opentarget: No hits
# API 3.104 opentarget: No hits
# API 3.105 opentarget: No hits
# API 3.106 opentarget: No hits
# API 3.107 opentarget: No hits
# API 3.108 opentarget: No hits
# API 3.109 opentarget: No hits
# API 3.110 opentarget: No hits
# API 3.111 opentarget: No hits
# API 3.112 opentarget: No hits
# API 3.113 opentarget: 10 hits
# API 3.114 opentarget: 15 hits
# API 3.115 opentarget: No hits
# API 3.116 opentarget: No hits
# API 3.117 opentarget: 15 hits
# API 3.118 opentarget: 15 hits
# API 3.119 opentarget: 3 hits
# API 3.120 opentarget: No hits
# API 3.121 opentarget: No hits
# API 3.122 opentarget: No hits
# API 3.123 opentarget: No hits
# API 3.124 opentarget: No hits
# API 3.125 opentarget: No hits
# API 3.126 opentarget: No hits
# API 3.127 opentarget: No hits
# API 3.128 opentarget: No hits
# API 3.129 opentarget: No hits
# API 3.130 opentarget: No hits
# API 3.131 opentarget: No hits
# API 3.132 opentarget: No hits
# API 3.133 opentarget: No hits
# API 3.134 opentarget: No hits
# API 3.135 opentarget: No hits
# API 3.136 opentarget: No hits
# API 3.137 opentarget: No hits
# API 3.138 opentarget: No hits
# API 3.139 opentarget: No hits
# API 3.140 opentarget: No hits
# API 3.141 opentarget: No hits
# API 3.142 opentarget: No hits
# API 3.143 opentarget: No hits
# API 3.144 opentarget: No hits
# API 3.145 opentarget: 15 hits
# API 3.146 opentarget: No hits
# API 3.147 opentarget: No hits
# API 3.148 opentarget: No hits
# API 3.149 opentarget: No hits
# API 3.150 opentarget: No hits
# API 3.151 opentarget: No hits
# API 3.152 opentarget: No hits
# API 3.153 opentarget: 8 hits
# API 3.154 opentarget: No hits
# API 3.155 opentarget: No hits
# API 3.156 opentarget: No hits
# API 3.157 opentarget: 1 hits
# API 3.158 opentarget: No hits
# API 3.159 opentarget: No hits
# API 3.160 opentarget: No hits
# API 3.161 opentarget: No hits
# API 3.162 opentarget: No hits
# API 5.1 robokop_gene2chemical: No hits
# API 5.2 robokop_gene2chemical: 1 hits
# API 5.3 robokop_gene2chemical: No hits
# API 5.4 robokop_gene2chemical: No hits
# API 5.5 robokop_gene2chemical: 26 hits
# API 5.6 robokop_gene2chemical: 3 hits
# API 5.7 robokop_gene2chemical: 1 hits
# API 5.8 robokop_gene2chemical: No hits
# API 5.9 robokop_gene2chemical: 4 hits
# API 5.10 robokop_gene2chemical: 2 hits
# API 5.11 robokop_gene2chemical: No hits
# API 5.12 robokop_gene2chemical: 1 hits
# API 5.13 robokop_gene2chemical: No hits
# API 5.14 robokop_gene2chemical: 1 hits
# API 5.15 robokop_gene2chemical: 2 hits
# API 5.16 robokop_gene2chemical: 13 hits
# API 5.17 robokop_gene2chemical: No hits
# API 5.18 robokop_gene2chemical: No hits
# API 5.19 robokop_gene2chemical: No hits
# API 5.20 robokop_gene2chemical: 6 hits
# API 5.21 robokop_gene2chemical: No hits
# API 5.22 robokop_gene2chemical: 7 hits
# API 5.23 robokop_gene2chemical: No hits
# API 5.24 robokop_gene2chemical: No hits
# API 5.25 robokop_gene2chemical: No hits
# API 5.26 robokop_gene2chemical: No hits
# API 5.27 robokop_gene2chemical: No hits
# API 5.28 robokop_gene2chemical: 2 hits
# API 5.29 robokop_gene2chemical: No hits
# API 5.30 robokop_gene2chemical: 18 hits
# API 5.31 robokop_gene2chemical: 66 hits
# API 5.32 robokop_gene2chemical: 1 hits
# API 5.33 robokop_gene2chemical: 23 hits
# API 5.34 robokop_gene2chemical: No hits
# API 5.35 robokop_gene2chemical: 3 hits
# API 5.36 robokop_gene2chemical: No hits
# API 5.37 robokop_gene2chemical: No hits
# API 5.38 robokop_gene2chemical: No hits
# API 5.39 robokop_gene2chemical: No hits
# API 5.40 robokop_gene2chemical: 23 hits
# API 5.41 robokop_gene2chemical: No hits
# API 5.42 robokop_gene2chemical: No hits
# API 5.43 robokop_gene2chemical: No hits
# API 5.44 robokop_gene2chemical: 8 hits
# API 5.45 robokop_gene2chemical: No hits
# API 5.46 robokop_gene2chemical: No hits
# API 5.47 robokop_gene2chemical: No hits
# API 5.48 robokop_gene2chemical: No hits
# API 5.49 robokop_gene2chemical: No hits
# API 5.50 robokop_gene2chemical: 1 hits
# API 5.51 robokop_gene2chemical: No hits
# API 5.52 robokop_gene2chemical: No hits
# API 5.53 robokop_gene2chemical: 7 hits
# API 5.54 robokop_gene2chemical: No hits
# API 5.55 robokop_gene2chemical: No hits
# API 5.56 robokop_gene2chemical: No hits
# API 5.57 robokop_gene2chemical: 2 hits
# API 5.58 robokop_gene2chemical: No hits
# API 5.59 robokop_gene2chemical: No hits
# API 5.60 robokop_gene2chemical: 1 hits
# API 5.61 robokop_gene2chemical: No hits
# API 5.62 robokop_gene2chemical: 1 hits
# API 5.63 robokop_gene2chemical: 19 hits
# API 5.64 robokop_gene2chemical: No hits
# API 5.65 robokop_gene2chemical: No hits
# API 5.66 robokop_gene2chemical: 3 hits
# API 5.67 robokop_gene2chemical: No hits
# API 5.68 robokop_gene2chemical: No hits
# API 5.69 robokop_gene2chemical: 2 hits
# API 5.70 robokop_gene2chemical: No hits
# API 5.71 robokop_gene2chemical: 14 hits
# API 5.72 robokop_gene2chemical: No hits
# API 5.73 robokop_gene2chemical: No hits
# API 5.74 robokop_gene2chemical: 16 hits
# API 5.75 robokop_gene2chemical: No hits
# API 5.76 robokop_gene2chemical: 3 hits
# API 5.77 robokop_gene2chemical: No hits
# API 5.78 robokop_gene2chemical: No hits
# API 5.79 robokop_gene2chemical: No hits
# API 5.80 robokop_gene2chemical: No hits
# API 5.81 robokop_gene2chemical: 6 hits
# API 5.82 robokop_gene2chemical: No hits
# API 5.83 robokop_gene2chemical: No hits
# API 5.84 robokop_gene2chemical: No hits
# API 5.85 robokop_gene2chemical: No hits
# API 5.86 robokop_gene2chemical: 3 hits
# API 5.87 robokop_gene2chemical: No hits
# API 5.88 robokop_gene2chemical: No hits
# API 5.89 robokop_gene2chemical: No hits
# API 5.90 robokop_gene2chemical: No hits
# API 5.91 robokop_gene2chemical: No hits
# API 5.92 robokop_gene2chemical: 2 hits
# API 5.93 robokop_gene2chemical: No hits
# API 5.94 robokop_gene2chemical: No hits
# API 5.95 robokop_gene2chemical: 4 hits
# API 5.96 robokop_gene2chemical: No hits
# API 5.97 robokop_gene2chemical: No hits
# API 5.98 robokop_gene2chemical: No hits
# API 5.99 robokop_gene2chemical: No hits
# API 5.100 robokop_gene2chemical: No hits
# API 5.101 robokop_gene2chemical: 4 hits
# API 5.102 robokop_gene2chemical: 1 hits
# API 5.103 robokop_gene2chemical: No hits
# API 5.104 robokop_gene2chemical: No hits
# API 5.105 robokop_gene2chemical: 1 hits
# API 5.106 robokop_gene2chemical: No hits
# API 5.107 robokop_gene2chemical: 1 hits
# API 5.108 robokop_gene2chemical: No hits
# API 5.109 robokop_gene2chemical: No hits
# API 5.110 robokop_gene2chemical: 12 hits
# API 5.111 robokop_gene2chemical: No hits
# API 5.112 robokop_gene2chemical: No hits
# API 5.113 robokop_gene2chemical: No hits
# API 5.114 robokop_gene2chemical: 52 hits
# API 5.115 robokop_gene2chemical: 39 hits
# API 5.116 robokop_gene2chemical: No hits
# API 5.117 robokop_gene2chemical: 2 hits
# API 5.118 robokop_gene2chemical: No hits
# API 5.119 robokop_gene2chemical: 2 hits
# API 5.120 robokop_gene2chemical: 2 hits
# API 5.121 robokop_gene2chemical: No hits
# API 5.122 robokop_gene2chemical: 1 hits
# API 5.123 robokop_gene2chemical: No hits
# API 5.124 robokop_gene2chemical: No hits
# API 5.125 robokop_gene2chemical: No hits
# API 5.126 robokop_gene2chemical: No hits
# API 5.127 robokop_gene2chemical: No hits
# API 5.128 robokop_gene2chemical: No hits
# API 5.129 robokop_gene2chemical: No hits
# API 5.130 robokop_gene2chemical: 2 hits
# API 5.131 robokop_gene2chemical: 1 hits
# API 5.132 robokop_gene2chemical: No hits
# API 5.133 robokop_gene2chemical: 2 hits
# API 5.134 robokop_gene2chemical: No hits
# API 5.135 robokop_gene2chemical: No hits
# API 5.136 robokop_gene2chemical: No hits
# API 5.137 robokop_gene2chemical: No hits
# API 5.138 robokop_gene2chemical: No hits
# API 5.139 robokop_gene2chemical: No hits
# API 5.140 robokop_gene2chemical: No hits
# API 5.141 robokop_gene2chemical: 1 hits
# API 5.142 robokop_gene2chemical: 7 hits
# API 5.143 robokop_gene2chemical: No hits
# API 5.144 robokop_gene2chemical: 2 hits
# API 5.145 robokop_gene2chemical: No hits
# API 5.146 robokop_gene2chemical: No hits
# API 1.1 semmedgene: 25595 hits
#
# After id-to-object translation, BTE retrieved 6146 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# In the #1 query, BTE found 218 unique Gene nodes
# In the #2 query, BTE found 6146 unique ChemicalSubstance nodes

# %%
df = fc.display_table_view()

# %% [markdown]
# The df object contains the full output from BioThings Explorer. Each row shows one path that joins the input node (PRDX1) to an intermediate node (a gene or protein) to an ending node (a chemical compound). The data frame includes a set of columns with additional details on each node and edge (including human-readable labels, identifiers, and sources). Let's remove all examples where the output_name (the compound label) is None, and specifically focus on paths with specific mechanistic predicates decreasesActivityOf and targetedBy.

# %% [markdown]
# ### Filter for drugs that targets genes which decrease the activity of PRDX1

# %%
dfFilt = df.loc[df['output_name'].notnull()].query('pred1 == "decreasesActivityOf" and pred2 == "targetedBy"')
dfFilt
# Out:
#        input input_type                pred1 pred1_source   pred1_api  \
# 9348   PRDX1       Gene  decreasesActivityOf       semmed  semmedgene
# 9901   PRDX1       Gene  decreasesActivityOf       semmed  semmedgene
# 10324  PRDX1       Gene  decreasesActivityOf       semmed  semmedgene
# 10409  PRDX1       Gene  decreasesActivityOf       semmed  semmedgene
# 10697  PRDX1       Gene  decreasesActivityOf       semmed  semmedgene
# ...      ...        ...                  ...          ...         ...
# 33686  PRDX1       Gene  decreasesActivityOf       semmed  semmedgene
# 33687  PRDX1       Gene  decreasesActivityOf       semmed  semmedgene
# 33688  PRDX1       Gene  decreasesActivityOf       semmed  semmedgene
# 33689  PRDX1       Gene  decreasesActivityOf       semmed  semmedgene
# 33690  PRDX1       Gene  decreasesActivityOf       semmed  semmedgene
#
#       pred1_pubmed node1_type node1_name     node1_id       pred2  \
# 9348      21167242       Gene      CREB1  entrez:1385  targetedBy
# 9901      20683885       Gene        TNF  entrez:7124  targetedBy
# 10324     23185615       Gene      VEGFA  entrez:7422  targetedBy
# 10409     21167242       Gene      CREB1  entrez:1385  targetedBy
# 10697     23185615       Gene      VEGFA  entrez:7422  targetedBy
# ...            ...        ...        ...          ...         ...
# 33686     20683885       Gene        TNF  entrez:7124  targetedBy
# 33687     20683885       Gene        TNF  entrez:7124  targetedBy
# 33688     20683885       Gene        TNF  entrez:7124  targetedBy
# 33689     20683885       Gene        TNF  entrez:7124  targetedBy
# 33690     20683885       Gene        TNF  entrez:7124  targetedBy
#
#       pred2_source            pred2_api pred2_pubmed        output_type  \
# 9348         dgidb  dgidb_gene2chemical         None  ChemicalSubstance
# 9901   mychem.info          mychem.info         None  ChemicalSubstance
# 10324  mychem.info          mychem.info         None  ChemicalSubstance
# 10409        dgidb  dgidb_gene2chemical         None  ChemicalSubstance
# 10697        dgidb  dgidb_gene2chemical         None  ChemicalSubstance
# ...            ...                  ...          ...                ...
# 33686  mychem.info          mychem.info         None  ChemicalSubstance
# 33687  mychem.info          mychem.info         None  ChemicalSubstance
# 33688  mychem.info          mychem.info         None  ChemicalSubstance
# 33689  mychem.info          mychem.info         None  ChemicalSubstance
# 33690  mychem.info          mychem.info         None  ChemicalSubstance
#
#            output_name             output_id
# 9348           ALCOHOL      chembl:CHEMBL545
# 9901       EPINEPHRINE      chembl:CHEMBL679
# 10324      MINOCYCLINE     chembl:CHEMBL1434
# 10409         NICOTINE        chembl:CHEMBL3
# 10697      FENOFIBRATE      chembl:CHEMBL672
# ...                ...                   ...
# 33686       PLINABULIN  chembl:CHEMBL1096380
# 33687       DILMAPIMOD  chembl:CHEMBL2103838
# 33688        ATIPRIMOD   chembl:CHEMBL103735
# 33689  ANDROGRAPHOLIDE   chembl:CHEMBL186141
# 33690  PSEUDOEPHEDRINE     chembl:CHEMBL1590
#
# [219 rows x 16 columns]

# %%
dfFilt.node1_id.unique()
# Out:
# array(['entrez:1385', 'entrez:7124', 'entrez:7422', 'entrez:10013',
#        'entrez:4547', 'entrez:5657'], dtype=object)

# %%
dfFilt.node1_name.unique()
# Out:
# array(['CREB1', 'TNF', 'VEGFA', 'HDAC6', 'MTTP', 'PRTN3'], dtype=object)

# %% [markdown]
# ## Step 3: Evaluating Paths based on published pathway figures

# %% [markdown]
# Let's see if PRDX1 (entrez:5052) is in the same pathway as TNF (entrez:7124) using our newly created API [PFOCR](http://pending.biothings.io/pfocr)

# %%
import requests

# query pfocr to see if PRDX1 and VEGFA is in the same pathway figure
doc = requests.get('https://pending.biothings.io/pfocr/query?q=associatedWith.genes:5052 AND associatedWith.genes:7124').json()
doc
# Out:
# {'max_score': 9.817886,
#  'took': 1,
#  'total': 1,
#  'hits': [{'_id': 'PMC4749872__molce-39-1-40f1.jpg',
#    '_score': 9.817886,
#    'associatedWith': {'figureUrl': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4749872/bin/molce-39-1-40f1.jpg',
#     'genes': ['11221',
#      '1432',
#      '1843',
#      '3163',
#      '369',
#      '4217',
#      '4297',
#      '5052',
#      '5594',
#      '5595',
#      '5599',
#      '5600',
#      '5601',
#      '5602',
#      '5603',
#      '5604',
#      '5605',
#      '5606',
#      '5607',
#      '5608',
#      '5609',
#      '5894',
#      '6300',
#      '6416',
#      '673',
#      '7124',
#      '7180'],
#     'pmc': 'PMC4749872'}}]}

# %% [markdown]
# **image of PMC4749872__molce-39-1-40f1.jpg**

# %% [markdown]
# ![](img/molce-39-1-40f1.jpg)
