# %% [markdown]
# # Introduction
#
# This notebook demonstrates how BioThings Explorer can be used to answer the following query:
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;*"Finding Marketed Drugs that Might Treat an Unknown Syndrome by Perturbing the Disease Mechanism Pathway"*
#
# ![](img/tidbit4_300.png)
#
# This query corresponds to [Tidbit 4](https://ncats.nih.gov/tidbit/tidbit_04.html) which was formulated as a demonstration of the NCATS Translator program.
#
# **Background of BTE**: BioThings Explorer can answer two classes of queries -- "EXPLAIN" and "PREDICT".  EXPLAIN queries are described in [EXPLAIN_demo.ipynb](https://github.com/biothings/biothings_explorer/blob/master/jupyter%20notebooks/EXPLAIN_demo.ipynb), and PREDICT queries are described in [PREDICT_demo.ipynb](https://github.com/biothings/biothings_explorer/blob/master/jupyter%20notebooks/PREDICT_demo.ipynb). Here, we describe PREDICT queries and how to use BioThings Explorer to execute them.  A more detailed overview of the BioThings Explorer systems is provided in [these slides](https://docs.google.com/presentation/d/1QWQqqQhPD_pzKryh6Wijm4YQswv8pAjleVORCPyJyDE/edit?usp=sharing).

# %% [markdown]
# **Background of TIDBIT 04**:
#
# A five-year-old patient was brought to the emergency room with recurrent polymicrobial lung infections, only 29% small airway function and was unresponsive to antibiotics.
#
# The patient’s medical records included a genetics report from age 1, which showed a 1p34.1 chromosomal duplication encompassing 1.9 Mb, including the PRDX1 gene, which encodes Peroxiredoxin 1. The gene has been linked to airway disease in both rats and humans, and is known to act as an agonist of toll-like receptor 4 (TLR4), a pro-inflammatory receptor. In addition, two patients at another clinic were found to have 1p34.1 duplications:
#
# 1. One patient with a duplication including PRDX1 died with similar phenotypes
# 2. One patient with a duplication that did NOT include PRDX1 showed no airway disease phenotype
# While recurrent lung infections are typically treated with antibiotics, this patient was unresponsive to standard treatments. The patient’s earlier genetics report and data from other patients with similar duplications gave the physician evidence that PRDX1 may play a role in the disease, but no treatments directly related to the gene were known. With this information in mind, the physician asked a researcher familiar with Translator to try to find possible treatments for this patient.
#
# **How Might Translator Help?**
# The patient’s duplication of the 1p34.1 region of chromosome 1 gave Translator researchers a good place to start. Since PRDX1 is an agonist of TLR4, the duplication of the PRDX1 gene likely causes overexpression of PRDX1, which could lead to overactivity of both of the gene products. The researcher decided to try to find drugs that could be used to reduce the activity of those two proteins. An exhaustive search of chemical databases and PubMed to find safe drug options could take days to weeks.
#
# For a known genetic mutation, can Translator be used to quickly find existing modulators to compensate for the dysfunctional gene product?

# %% [markdown]
# ## Step 1: Find representation of "PRDX1" in BTE
#
# In this step, BioThings Explorer translates our query string "PRDX1"  into BioThings objects, which contain mappings to many common identifiers.  Generally, the top result returned by the `Hint` module will be the correct item, but you should confirm that using the identifiers shown.
#
# Search terms can correspond to any child of [BiologicalEntity](https://biolink.github.io/biolink-model/docs/BiologicalEntity.html) from the [Biolink Model](https://biolink.github.io/biolink-model/docs/), including `DiseaseOrPhenotypicFeature` (e.g., "lupus"), `ChemicalSubstance` (e.g., "acetaminophen"), `Gene` (e.g., "CDK2"), `BiologicalProcess` (e.g., "T cell differentiation"), and `Pathway` (e.g., "Citric acid cycle").

# %%
from biothings_explorer.hint import Hint
ht = Hint()
prdx1 = ht.query("PRDX1")['Gene'][0]

prdx1
# Out:
# {'entrez': '5052',
#  'name': 'peroxiredoxin 1',
#  'symbol': 'PRDX1',
#  'taxonomy': 9606,
#  'umls': 'C1418879',
#  'uniprot': 'Q06830',
#  'hgnc': '9352',
#  'ensembl': 'ENSG00000117450',
#  'display': 'entrez(5052) name(peroxiredoxin 1) symbol(PRDX1) taxonomy(9606) umls(C1418879) uniprot(Q06830) hgnc(9352) ensembl(ENSG00000117450) ',
#  'type': 'Gene',
#  'primary': {'identifier': 'entrez', 'cls': 'Gene', 'value': '5052'}}

# %% [markdown]
# ## Step 2: Find drugs that are associated with genes which are associated with PRDX1
#
# In this section, we find all paths in the knowledge graph that connect PRDX1 to any entity that is a chemical compound.  To do that, we will use `FindConnection`.  This class is a convenient wrapper around two advanced functions for **query path planning** and **query path execution**. More advanced features for both query path planning and query path execution are in development and will be documented in the coming months.
#
# The parameters for `FindConnection` are described below:

# %%
from biothings_explorer.user_query_dispatcher import FindConnection

fc = FindConnection(input_obj=prdx1, output_obj='ChemicalSubstance', intermediate_nodes=['Gene'])
fc.connect(verbose=True)
# Out:
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'PRDX1' and 'ChemicalSubstance'. Paths will have 1 intermediate node.
#
# Intermediate node #1 will have these type constraints: Gene
#
#
#
#
# ========== QUERY #1 -- fetch all Gene entities linked to PRDX1 ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because PRDX1 is of type 'Gene', BTE will query our meta-KG for APIs that can take 'Gene' as input and 'Gene' as output
#
# BTE found 3 apis:
#
# API 1. mygene.info(3 API calls)
# API 2. semmedgene(11 API calls)
# API 3. biolink_geneinteraction(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.1: http://mygene.info/v3/query (POST "q=5052&scopes=entrezgene&fields=pantherdb.ortholog&species=human&size=100")
# API 1.2: http://mygene.info/v3/query (POST "q=ENSG00000117450&scopes=pantherdb.ortholog.Ensembl&fields=entrezgene&species=human&size=100")
# API 1.3: http://mygene.info/v3/query (POST "q=9352&scopes=pantherdb.ortholog.HGNC&fields=entrezgene&species=human&size=100")
# API 2.2: https://pending.biothings.io/semmedgene/query (POST "q=C1418879&scopes=affects.protein.umls&fields=umls&species=human&size=100")
# API 2.8: https://pending.biothings.io/semmedgene/query (POST "q=C1418879&scopes=interacts_with.gene.umls&fields=umls&species=human&size=100")
# API 2.1: https://pending.biothings.io/semmedgene/query (POST "q=C1418879&scopes=affects.gene.umls&fields=umls&species=human&size=100")
# API 2.9: https://pending.biothings.io/semmedgene/query (POST "q=C1418879&scopes=interacts_with.protein.umls&fields=umls&species=human&size=100")
# API 2.10: https://pending.biothings.io/semmedgene/query (POST "q=C1418879&scopes=stimulates.protein.umls&fields=umls&species=human&size=100")
# API 2.11: https://pending.biothings.io/semmedgene/query (POST "q=C1418879&scopes=umls&fields=disrupts.protein,associated_with.gene,interacts_with.protein,stimulates.protein,inhibits.protein,disrupts.gene,affects.protein,interacts_with.gene,inhibits.gene,affects.gene&species=human&size=100")
# API 2.5: https://pending.biothings.io/semmedgene/query (POST "q=C1418879&scopes=disrupts.protein.umls&fields=umls&species=human&size=100")
# API 2.4: https://pending.biothings.io/semmedgene/query (POST "q=C1418879&scopes=disrupts.gene.umls&fields=umls&species=human&size=100")
# API 2.7: https://pending.biothings.io/semmedgene/query (POST "q=C1418879&scopes=inhibits.protein.umls&fields=umls&species=human&size=100")
# API 2.6: https://pending.biothings.io/semmedgene/query (POST "q=C1418879&scopes=inhibits.gene.umls&fields=umls&species=human&size=100")
# API 2.3: https://pending.biothings.io/semmedgene/query (POST "q=C1418879&scopes=associated_with.gene.umls&fields=umls&species=human&size=100")
# API 3.1: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:5052/interactions?rows=100
#
#
# ==== Step #3: Output normalization ====
#
# API 3.1 biolink_geneinteraction: 100 hits
# API 1.1 mygene.info: 16 hits
# API 1.2 mygene.info: No hits
# API 1.3 mygene.info: 1 hits
# API 2.1 semmedgene: No hits
# API 2.2 semmedgene: No hits
# API 2.3 semmedgene: No hits
# API 2.4 semmedgene: No hits
# API 2.5 semmedgene: No hits
# API 2.6 semmedgene: 11 hits
# API 2.7 semmedgene: No hits
# API 2.8 semmedgene: 38 hits
# API 2.9 semmedgene: No hits
# API 2.10 semmedgene: No hits
# API 2.11 semmedgene: 85 hits
#
# After id-to-object translation, BTE retrieved 218 unique objects.
#
#
# ========== QUERY #2.1 -- fetch all ChemicalSubstance entities linked to Gene entites ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because None is of type 'Gene', BTE will query our meta-KG for APIs that can take 'Gene' as input and 'ChemicalSubstance' as output
#
# BTE found 5 apis:
#
# API 1. mychem.info(3 API calls)
# API 2. dgidb_gene2chemical(146 API calls)
# API 3. opentarget(162 API calls)
# API 4. robokop_gene2chemical(146 API calls)
# API 5. semmedgene(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 3.10: http://www.dgidb.org/api/v2/interactions.json?genes=PPHLN1
# API 3.1: http://www.dgidb.org/api/v2/interactions.json?genes=ACY1
# API 3.12: http://www.dgidb.org/api/v2/interactions.json?genes=TP63
# API 3.17: http://www.dgidb.org/api/v2/interactions.json?genes=VIRMA
# API 3.15: http://www.dgidb.org/api/v2/interactions.json?genes=DCPS
# API 3.37: http://www.dgidb.org/api/v2/interactions.json?genes=BTRC
# API 3.58: http://www.dgidb.org/api/v2/interactions.json?genes=CPLX2
# dgidb_gene2chemical failed
# API 3.11: http://www.dgidb.org/api/v2/interactions.json?genes=CRY1
# API 3.35: http://www.dgidb.org/api/v2/interactions.json?genes=TLR4
# dgidb_gene2chemical failed
# API 3.7: http://www.dgidb.org/api/v2/interactions.json?genes=CALM1
# API 3.44: http://www.dgidb.org/api/v2/interactions.json?genes=APEX1
# API 3.31: http://www.dgidb.org/api/v2/interactions.json?genes=OTUB1
# API 3.47: http://www.dgidb.org/api/v2/interactions.json?genes=DNPH1
# API 3.19: http://www.dgidb.org/api/v2/interactions.json?genes=PHB
# API 3.5: http://www.dgidb.org/api/v2/interactions.json?genes=DAB2
# API 3.30: http://www.dgidb.org/api/v2/interactions.json?genes=BRCA1
# API 3.24: http://www.dgidb.org/api/v2/interactions.json?genes=COX6B1
# API 2.2: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000051382&datasource=chembl&size=15&fields=drug
# API 2.1: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000036257&datasource=chembl&size=15&fields=drug
# API 3.20: http://www.dgidb.org/api/v2/interactions.json?genes=ISG15
# API 3.16: http://www.dgidb.org/api/v2/interactions.json?genes=SOD2
# API 3.39: http://www.dgidb.org/api/v2/interactions.json?genes=RECQL4
# API 3.40: http://www.dgidb.org/api/v2/interactions.json?genes=SOD1
# API 3.2: http://www.dgidb.org/api/v2/interactions.json?genes=PRTN3
# API 3.8: http://www.dgidb.org/api/v2/interactions.json?genes=PTPN1
# API 3.13: http://www.dgidb.org/api/v2/interactions.json?genes=PBK
# dgidb_gene2chemical failed
# API 2.7: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000108094&datasource=chembl&size=15&fields=drug
# API 3.28: http://www.dgidb.org/api/v2/interactions.json?genes=SH3BGRL2
# API 3.53: http://www.dgidb.org/api/v2/interactions.json?genes=CDK9
# API 3.38: http://www.dgidb.org/api/v2/interactions.json?genes=LAP3
# API 2.4: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000228978&datasource=chembl&size=15&fields=drug
# API 3.50: http://www.dgidb.org/api/v2/interactions.json?genes=CREB1
# API 3.32: http://www.dgidb.org/api/v2/interactions.json?genes=PTEN
# API 3.45: http://www.dgidb.org/api/v2/interactions.json?genes=GABPA
# API 3.29: http://www.dgidb.org/api/v2/interactions.json?genes=CLEC4G
# API 3.43: http://www.dgidb.org/api/v2/interactions.json?genes=SYK
# API 3.42: http://www.dgidb.org/api/v2/interactions.json?genes=PTPRC
# API 3.49: http://www.dgidb.org/api/v2/interactions.json?genes=RPA2
# API 2.5: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000276230&datasource=chembl&size=15&fields=drug
# API 3.51: http://www.dgidb.org/api/v2/interactions.json?genes=RBMS3
# API 3.48: http://www.dgidb.org/api/v2/interactions.json?genes=NTRK1
# API 2.8: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000056097&datasource=chembl&size=15&fields=drug
# API 2.10: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000158555&datasource=chembl&size=15&fields=drug
# API 2.11: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000039068&datasource=chembl&size=15&fields=drug
# API 3.14: http://www.dgidb.org/api/v2/interactions.json?genes=CFTR
# API 3.22: http://www.dgidb.org/api/v2/interactions.json?genes=CUL4B
# API 3.54: http://www.dgidb.org/api/v2/interactions.json?genes=FERMT3
# API 3.36: http://www.dgidb.org/api/v2/interactions.json?genes=CALB2
# dgidb_gene2chemical failed
# dgidb_gene2chemical failed
# API 3.93: http://www.dgidb.org/api/v2/interactions.json?genes=PRKDC
# API 3.9: http://www.dgidb.org/api/v2/interactions.json?genes=ZFR
# API 3.33: http://www.dgidb.org/api/v2/interactions.json?genes=MST1
# API 3.18: http://www.dgidb.org/api/v2/interactions.json?genes=TERF1
# API 3.4: http://www.dgidb.org/api/v2/interactions.json?genes=EEF1A1
# API 3.46: http://www.dgidb.org/api/v2/interactions.json?genes=PPP2R1B
# API 2.13: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000146648&datasource=chembl&size=15&fields=drug
# API 3.25: http://www.dgidb.org/api/v2/interactions.json?genes=UCHL5
# API 3.26: http://www.dgidb.org/api/v2/interactions.json?genes=RC3H1
# API 3.6: http://www.dgidb.org/api/v2/interactions.json?genes=PRRX1
# API 3.52: http://www.dgidb.org/api/v2/interactions.json?genes=DCUN1D1
# API 2.18: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000167193&datasource=chembl&size=15&fields=drug
# API 3.27: http://www.dgidb.org/api/v2/interactions.json?genes=YAP1
# API 2.16: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000023191&datasource=chembl&size=15&fields=drug
# API 3.57: http://www.dgidb.org/api/v2/interactions.json?genes=FYN
# API 2.15: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000157326&datasource=chembl&size=15&fields=drug
# API 3.23: http://www.dgidb.org/api/v2/interactions.json?genes=CFL1
# API 3.21: http://www.dgidb.org/api/v2/interactions.json?genes=SRXN1
# API 3.96: http://www.dgidb.org/api/v2/interactions.json?genes=HECTD1
# API 2.22: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000142168&datasource=chembl&size=15&fields=drug
# API 3.41: http://www.dgidb.org/api/v2/interactions.json?genes=COPS6
# API 3.90: http://www.dgidb.org/api/v2/interactions.json?genes=COX17
# API 3.68: http://www.dgidb.org/api/v2/interactions.json?genes=UBE2M
# API 3.88: http://www.dgidb.org/api/v2/interactions.json?genes=MEPCE
# API 3.77: http://www.dgidb.org/api/v2/interactions.json?genes=VRK3
# API 3.34: http://www.dgidb.org/api/v2/interactions.json?genes=LGALS3
# API 3.70: http://www.dgidb.org/api/v2/interactions.json?genes=CTSD
# API 3.81: http://www.dgidb.org/api/v2/interactions.json?genes=CDC42
# API 3.100: http://www.dgidb.org/api/v2/interactions.json?genes=ETS1
# API 2.21: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000174231&datasource=chembl&size=15&fields=drug
# API 2.3: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000145715&datasource=chembl&size=15&fields=drug
# API 3.97: http://www.dgidb.org/api/v2/interactions.json?genes=PPP2R1A
# API 3.99: http://www.dgidb.org/api/v2/interactions.json?genes=SCCPDH
# API 2.17: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000145388&datasource=chembl&size=15&fields=drug
# API 2.23: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000178691&datasource=chembl&size=15&fields=drug
# API 2.28: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000094631&datasource=chembl&size=15&fields=drug
# API 3.82: http://www.dgidb.org/api/v2/interactions.json?genes=CDH1
# API 2.24: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSGALG00000010243&datasource=chembl&size=15&fields=drug
# API 3.87: http://www.dgidb.org/api/v2/interactions.json?genes=RNF123
# API 3.62: http://www.dgidb.org/api/v2/interactions.json?genes=RNF144A
# API 3.72: http://www.dgidb.org/api/v2/interactions.json?genes=WTAP
# API 3.78: http://www.dgidb.org/api/v2/interactions.json?genes=PRKCZ
# API 2.20: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000143653&datasource=chembl&size=15&fields=drug
# API 3.75: http://www.dgidb.org/api/v2/interactions.json?genes=DAZAP1
# API 3.92: http://www.dgidb.org/api/v2/interactions.json?genes=CUL3
# API 3.84: http://www.dgidb.org/api/v2/interactions.json?genes=ANAPC15
# API 3.85: http://www.dgidb.org/api/v2/interactions.json?genes=PRDX6
# API 3.74: http://www.dgidb.org/api/v2/interactions.json?genes=ERVW-4
# API 2.33: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000228321&datasource=chembl&size=15&fields=drug
# API 2.34: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000115317&datasource=chembl&size=15&fields=drug
# API 3.63: http://www.dgidb.org/api/v2/interactions.json?genes=PRDX2
# API 3.98: http://www.dgidb.org/api/v2/interactions.json?genes=PIDD1
# API 3.61: http://www.dgidb.org/api/v2/interactions.json?genes=HTRA2
# API 3.95: http://www.dgidb.org/api/v2/interactions.json?genes=CDC73
# API 3.59: http://www.dgidb.org/api/v2/interactions.json?genes=RPA1
# API 3.103: http://www.dgidb.org/api/v2/interactions.json?genes=RIOK1
# API 3.86: http://www.dgidb.org/api/v2/interactions.json?genes=GAPDH
# API 3.104: http://www.dgidb.org/api/v2/interactions.json?genes=MTTP
# API 2.26: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000002016&datasource=chembl&size=15&fields=drug
# API 2.14: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000106399&datasource=chembl&size=15&fields=drug
# API 3.76: http://www.dgidb.org/api/v2/interactions.json?genes=CDC37
# API 2.6: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000110063&datasource=chembl&size=15&fields=drug
# API 2.31: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000127445&datasource=chembl&size=15&fields=drug
# API 2.30: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000116132&datasource=chembl&size=15&fields=drug
# API 2.29: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000137713&datasource=chembl&size=15&fields=drug
# API 2.25: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000149781&datasource=chembl&size=15&fields=drug
# API 2.32: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000121879&datasource=chembl&size=15&fields=drug
# API 3.64: http://www.dgidb.org/api/v2/interactions.json?genes=OBSL1
# API 2.9: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000131981&datasource=chembl&size=15&fields=drug
# API 3.3: http://www.dgidb.org/api/v2/interactions.json?genes=PIK3CA
# API 3.105: http://www.dgidb.org/api/v2/interactions.json?genes=RAD23A
# API 3.79: http://www.dgidb.org/api/v2/interactions.json?genes=CRK
# API 2.12: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000136810&datasource=chembl&size=15&fields=drug
# API 3.71: http://www.dgidb.org/api/v2/interactions.json?genes=ZFP36L2
# API 2.35: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000284807&datasource=chembl&size=15&fields=drug
# API 3.108: http://www.dgidb.org/api/v2/interactions.json?genes=AAR2
# API 3.91: http://www.dgidb.org/api/v2/interactions.json?genes=CYLD
# API 2.44: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000010810&datasource=chembl&size=15&fields=drug
# API 3.80: http://www.dgidb.org/api/v2/interactions.json?genes=PDP1
# API 3.65: http://www.dgidb.org/api/v2/interactions.json?genes=PPT1
# API 2.36: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000117322&datasource=chembl&size=15&fields=drug
# API 3.89: http://www.dgidb.org/api/v2/interactions.json?genes=SESN2
# API 3.107: http://www.dgidb.org/api/v2/interactions.json?genes=METTL14
# API 2.40: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000112667&datasource=chembl&size=15&fields=drug
# API 2.39: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000123374&datasource=chembl&size=15&fields=drug
# API 3.56: http://www.dgidb.org/api/v2/interactions.json?genes=TRIM4
# API 3.112: http://www.dgidb.org/api/v2/interactions.json?genes=JTB
# API 3.67: http://www.dgidb.org/api/v2/interactions.json?genes=U2AF2
# API 2.42: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000262418&datasource=chembl&size=15&fields=drug
# API 3.109: http://www.dgidb.org/api/v2/interactions.json?genes=KMT2A
# API 2.43: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000179262&datasource=chembl&size=15&fields=drug
# API 3.111: http://www.dgidb.org/api/v2/interactions.json?genes=PRDX3
# API 3.114: http://www.dgidb.org/api/v2/interactions.json?genes=RPA3
# API 3.66: http://www.dgidb.org/api/v2/interactions.json?genes=AGO4
# API 3.60: http://www.dgidb.org/api/v2/interactions.json?genes=CAT
# API 2.38: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000139842&datasource=chembl&size=15&fields=drug
# API 2.37: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000081237&datasource=chembl&size=15&fields=drug
# API 2.45: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000134371&datasource=chembl&size=15&fields=drug
# API 2.46: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000164093&datasource=chembl&size=15&fields=drug
# API 2.47: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000080546&datasource=chembl&size=15&fields=drug
# API 2.41: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000172757&datasource=chembl&size=15&fields=drug
# API 3.116: http://www.dgidb.org/api/v2/interactions.json?genes=RAB4B
# API 3.110: http://www.dgidb.org/api/v2/interactions.json?genes=VEGFA
# API 3.94: http://www.dgidb.org/api/v2/interactions.json?genes=PRPF8
# API 3.83: http://www.dgidb.org/api/v2/interactions.json?genes=CUL7
# API 3.55: http://www.dgidb.org/api/v2/interactions.json?genes=PRDX4
# API 2.49: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000198668&datasource=chembl&size=15&fields=drug
# API 2.55: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000206439&datasource=chembl&size=15&fields=drug
# API 2.50: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000177595&datasource=chembl&size=15&fields=drug
# API 5.1: https://pending.biothings.io/semmedgene/query (POST "q=C1709127,C1539098,C1825045,C1335607,C3642141,C1708291,C1705691,C1412825,C0036773,C1427363,C1425940,C1419277,C1332102,C0031678,C1825463,C0031727,C2700100,C1426328,C1419243,C1367578,C2984529,C0059256,C1826784,C1826843,C1335208,C3272447,C0027021,C0086661,C1425509,C1427252,C1456380,C1418696,C1420306,C1424590,C1822651,C1420307,C1424868,C0527356,C1413696,C1332812,C1419619,C1709820,C1335262,C1413724,C1336636,C1824317,C1332813,C1423806,C3539596,C1424792,C1439337,C0017822,C0812303,C1414270,C1414905,C0079050,C0071827,C0056467,C1418582,C1413081,C1424135,C1826505,C0669365,C1418837,C1424145,C0812252,C1705581,C2698689,C0017360,C1823619,C1705387,C1333202,C1424518,C1424915,C1421047,C1422009,C1704928,C1419236,C1707161,C1336690,C1419620,C1413290,C1423579,C4285071,C1426741,C0312359,C1425683,C3714973,C1426197,C1705633,C0079427,C1418928,C0164786,C1416831,C1539559,C1413614,C1825621,C1332805,C1418854,C1332809,C1706351,C1335243,C1825689,C1332733,C1419211,C1418270,C0672553,C1709439,C1427633,C0919528,C1332722,C0812201,C1705981,C1538595,C1707152,C0694888,C1332811,C1823127,C1413365,C1424323,C1421986,C0376571,C1335213,C1425522,C0812228,C1705518,C0969119,C0248813,C1413633,C1705047,C1414968,C1413355,C1427952,C1334294,C0287531,C0010642,C0073337,C1424673,C1332810,C0140145,C1418818,C1705442,C1335267,C2681660,C1826565,C0138965,C1412851,C1336604,C0812246,C1427739,C1418881,C1826328,C1825553,C0024750,C1417377,C1708031,C1335892,C1413671,C0085114,C0022959,C1418880,C1705325,C1332695,C1539228,C1418882,C1335285,C1418596,C1426950,C1421999,C3148432,C1335281,C1413850,C1826417,C0919487,C1539902,C1825792,C1414313,C0010531,C0282625,C1413912,C1413138,C1421289,C0033681,C1413826,C1824894,C1539128,C1427105,C1420667,C1332659,C1335212,C1842840,C0074147,C1427424,C1427896,C1705997,C1335248,C1412173,C1333895,C0029073,C1419618,C1413702,C3147237,C0694872,C0007367,C1366537&scopes=umls&fields=interacts_with_reverse.chemical_substance,associated_with.chemical_substance,affects_reverse.chemical_substance,affects.chemical_substance,associated_with_reverse.chemical_substance,interacts_with.chemical_substance&species=human&size=100")
# API 3.118: http://www.dgidb.org/api/v2/interactions.json?genes=CCNB1
# API 2.19: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000131043&datasource=chembl&size=15&fields=drug
# API 2.51: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000186834&datasource=chembl&size=15&fields=drug
# API 3.73: http://www.dgidb.org/api/v2/interactions.json?genes=CR2
# API 3.119: http://www.dgidb.org/api/v2/interactions.json?genes=SUZ12
# API 3.117: http://www.dgidb.org/api/v2/interactions.json?genes=EIF4A3
# API 3.120: http://www.dgidb.org/api/v2/interactions.json?genes=RASA1
# API 3.122: http://www.dgidb.org/api/v2/interactions.json?genes=SESN1
# API 3.123: http://www.dgidb.org/api/v2/interactions.json?genes=GDPD5
# API 3.121: http://www.dgidb.org/api/v2/interactions.json?genes=RNH1
# API 2.52: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000146834&datasource=chembl&size=15&fields=drug
# API 2.53: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000158290&datasource=chembl&size=15&fields=drug
# API 3.125: http://www.dgidb.org/api/v2/interactions.json?genes=TXN
# API 2.54: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000167770&datasource=chembl&size=15&fields=drug
# API 3.69: http://www.dgidb.org/api/v2/interactions.json?genes=AR
# API 2.56: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000173531&datasource=chembl&size=15&fields=drug
# API 2.61: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000112096&datasource=chembl&size=15&fields=drug
# API 3.126: http://www.dgidb.org/api/v2/interactions.json?genes=SLC38A1
# API 2.58: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000105568&datasource=chembl&size=15&fields=drug
# API 3.128: http://www.dgidb.org/api/v2/interactions.json?genes=TDGF1
# API 2.64: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000285441&datasource=chembl&size=15&fields=drug
# API 3.130: http://www.dgidb.org/api/v2/interactions.json?genes=PEBP1
# API 3.129: http://www.dgidb.org/api/v2/interactions.json?genes=LARP7
# API 2.60: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000063244&datasource=chembl&size=15&fields=drug
# API 2.66: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000142208&datasource=chembl&size=15&fields=drug
# API 3.131: http://www.dgidb.org/api/v2/interactions.json?genes=CUL1
# API 3.132: http://www.dgidb.org/api/v2/interactions.json?genes=CUL4A
# API 2.62: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000143543&datasource=chembl&size=15&fields=drug
# API 2.68: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000204490&datasource=chembl&size=15&fields=drug
# API 3.133: http://www.dgidb.org/api/v2/interactions.json?genes=CUL5
# API 2.27: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000274442&datasource=chembl&size=15&fields=drug
# API 2.70: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000284792&datasource=chembl&size=15&fields=drug
# API 3.134: http://www.dgidb.org/api/v2/interactions.json?genes=MTRNR2L1
# API 3.135: http://www.dgidb.org/api/v2/interactions.json?genes=CUL2
# API 3.137: http://www.dgidb.org/api/v2/interactions.json?genes=TRBV20OR9-2
# API 2.67: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000241186&datasource=chembl&size=15&fields=drug
# API 3.136: http://www.dgidb.org/api/v2/interactions.json?genes=NF2
# API 2.69: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000044090&datasource=chembl&size=15&fields=drug
# API 3.140: http://www.dgidb.org/api/v2/interactions.json?genes=PRKN
# API 2.72: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000123131&datasource=chembl&size=15&fields=drug
# API 2.71: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000151692&datasource=chembl&size=15&fields=drug
# API 3.141: http://www.dgidb.org/api/v2/interactions.json?genes=HEXIM1
# API 2.73: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000243989&datasource=chembl&size=15&fields=drug
# API 2.48: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000126432&datasource=chembl&size=15&fields=drug
# API 2.63: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000136997&datasource=chembl&size=15&fields=drug
# API 3.142: http://www.dgidb.org/api/v2/interactions.json?genes=PRDX5
# API 3.143: http://www.dgidb.org/api/v2/interactions.json?genes=COPS5
# API 2.57: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000145920&datasource=chembl&size=15&fields=drug
# API 3.145: http://www.dgidb.org/api/v2/interactions.json?genes=PITX2
# API 3.144: http://www.dgidb.org/api/v2/interactions.json?genes=RAD52
# API 3.138: http://www.dgidb.org/api/v2/interactions.json?genes=MYC
# robokop_gene2chemical failed
# robokop_gene2chemical failed
# robokop_gene2chemical failed
# robokop_gene2chemical failed
# robokop_gene2chemical failed
# robokop_gene2chemical failed
# robokop_gene2chemical failed
# robokop_gene2chemical failed
# robokop_gene2chemical failed
# robokop_gene2chemical failed
# API 3.146: http://www.dgidb.org/api/v2/interactions.json?genes=PPP2R5D
# robokop_gene2chemical failed
# API 2.59: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000168090&datasource=chembl&size=15&fields=drug
# API 3.124: http://www.dgidb.org/api/v2/interactions.json?genes=CDK2
# API 3.139: http://www.dgidb.org/api/v2/interactions.json?genes=PIK3CB
# opentarget failed
# robokop_gene2chemical failed
# opentarget failed
# opentarget failed
# opentarget failed
# robokop_gene2chemical failed
# robokop_gene2chemical failed
# robokop_gene2chemical failed
# robokop_gene2chemical failed
# opentarget failed
# robokop_gene2chemical failed
# opentarget failed
# robokop_gene2chemical failed
# robokop_gene2chemical failed
# robokop_gene2chemical failed
# opentarget failed
# robokop_gene2chemical failed
# opentarget failed
# opentarget failed
# opentarget failed
# robokop_gene2chemical failed
# API 2.76: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000282830&datasource=chembl&size=15&fields=drug
# robokop_gene2chemical failed
# robokop_gene2chemical failed
# robokop_gene2chemical failed
# robokop_gene2chemical failed
# robokop_gene2chemical failed
# opentarget failed
# robokop_gene2chemical failed
# opentarget failed
# opentarget failed
# opentarget failed
# opentarget failed
# robokop_gene2chemical failed
# opentarget failed
# opentarget failed
# API 2.65: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000117984&datasource=chembl&size=15&fields=drug
# robokop_gene2chemical failed
# robokop_gene2chemical failed
# opentarget failed
# robokop_gene2chemical failed
# opentarget failed
# opentarget failed
# opentarget failed
# opentarget failed
# opentarget failed
# API 2.84: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000008405&datasource=chembl&size=15&fields=drug
# API 2.75: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000187608&datasource=chembl&size=15&fields=drug
# robokop_gene2chemical failed
# robokop_gene2chemical failed
# robokop_gene2chemical failed
# robokop_gene2chemical failed
# API 2.77: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000196396&datasource=chembl&size=15&fields=drug
# robokop_gene2chemical failed
# robokop_gene2chemical failed
# robokop_gene2chemical failed
# opentarget failed
# opentarget failed
# robokop_gene2chemical failed
# opentarget failed
# opentarget failed
# opentarget failed
# robokop_gene2chemical failed
# robokop_gene2chemical failed
# opentarget failed
# opentarget failed
# robokop_gene2chemical failed
# opentarget failed
# robokop_gene2chemical failed
# opentarget failed
# API 2.80: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000166266&datasource=chembl&size=15&fields=drug
# API 2.83: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000083799&datasource=chembl&size=15&fields=drug
# API 2.79: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000169083&datasource=chembl&size=15&fields=drug
# robokop_gene2chemical failed
# robokop_gene2chemical failed
# robokop_gene2chemical failed
# API 2.86: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000116750&datasource=chembl&size=15&fields=drug
# API 2.81: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000089220&datasource=chembl&size=15&fields=drug
# opentarget failed
# robokop_gene2chemical failed
# API 2.85: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000136807&datasource=chembl&size=15&fields=drug
# robokop_gene2chemical failed
# robokop_gene2chemical failed
# robokop_gene2chemical failed
# opentarget failed
# opentarget failed
# robokop_gene2chemical failed
# robokop_gene2chemical failed
# robokop_gene2chemical failed
# opentarget failed
# opentarget failed
# opentarget failed
# opentarget failed
# robokop_gene2chemical failed
# opentarget failed
# opentarget failed
# opentarget failed
# opentarget failed
# robokop_gene2chemical failed
# opentarget failed
# opentarget failed
# opentarget failed
# opentarget failed
# API 2.82: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000131238&datasource=chembl&size=15&fields=drug
# API 2.87: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000117748&datasource=chembl&size=15&fields=drug
# robokop_gene2chemical failed
# robokop_gene2chemical failed
# robokop_gene2chemical failed
# robokop_gene2chemical failed
# robokop_gene2chemical failed
# opentarget failed
# robokop_gene2chemical failed
# robokop_gene2chemical failed
# opentarget failed
# opentarget failed
# opentarget failed
# robokop_gene2chemical failed
# opentarget failed
# robokop_gene2chemical failed
# robokop_gene2chemical failed
# opentarget failed
# robokop_gene2chemical failed
# opentarget failed
# opentarget failed
# opentarget failed
# robokop_gene2chemical failed
# opentarget failed
# API 2.88: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000117592&datasource=chembl&size=15&fields=drug
# API 2.115: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000121691&datasource=chembl&size=15&fields=drug
# opentarget failed
# opentarget failed
# API 2.148: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000136869&datasource=chembl&size=15&fields=drug
# API 2.162: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000070831&datasource=chembl&size=15&fields=drug
# API 2.78: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSRNOG00000017695&datasource=chembl&size=15&fields=drug
# API 2.99: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000138823&datasource=chembl&size=15&fields=drug
# API 2.114: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000134954&datasource=chembl&size=15&fields=drug
# API 2.116: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000160957&datasource=chembl&size=15&fields=drug
# API 2.126: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000100823&datasource=chembl&size=15&fields=drug
# API 2.131: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000001626&datasource=chembl&size=15&fields=drug
# API 2.129: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000185345&datasource=chembl&size=15&fields=drug
# API 2.107: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000012048&datasource=chembl&size=15&fields=drug
# API 2.74: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000198400&datasource=chembl&size=15&fields=drug
# API 2.132: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000092148&datasource=chembl&size=15&fields=drug
# API 2.127: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000165025&datasource=chembl&size=15&fields=drug
# API 2.147: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000196415&datasource=chembl&size=15&fields=drug
# API 2.128: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000118260&datasource=chembl&size=15&fields=drug
# API 2.160: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000146833&datasource=chembl&size=15&fields=drug
# API 3.127: http://www.dgidb.org/api/v2/interactions.json?genes=EGFR
# API 4.1: https://robokop.renci.org/api/simple/expand/gene/HGNC:17277/chemical_substance/
# API 4.3: https://robokop.renci.org/api/simple/expand/gene/HGNC:18656/chemical_substance/
# API 4.5: https://robokop.renci.org/api/simple/expand/gene/HGNC:9642/chemical_substance/
# API 4.2: https://robokop.renci.org/api/simple/expand/gene/HGNC:1884/chemical_substance/
# API 1.1: http://mychem.info/v1/query (POST "q=ACY1,PIK3CA,EEF1A1,CALM1,CRY1,TP63,CFTR,VIRMA,TERF1,PHB,COX6B1,UCHL5,BRCA1,MST1,PTEN,TLR4,SOD1,COPS6,PTPRC,SYK,APEX1,GABPA,DNPH1,NTRK1,RBMS3,DCUN1D1,CDK9,FERMT3,FYN,CAT,HTRA2,PRDX2,OBSL1,PPT1,AGO4,U2AF2,UBE2M,AR,CR2,DAZAP1,CDC37,PRKCZ,CDC42,CDH1,ANAPC15,JTB,PRDX6,MEPCE,CYLD,CUL3,PRKDC,CDC73,AKT1,HDAC6,RIOK1,TNF,METTL14,AAR2,VEGFA,DHRS4,RAB4B,RASA1,SESN1,CDK2,EGFR,TDGF1,PEBP1,MTRNR2L1,TRBV20OR9-2,MYC,HEXIM1,PRDX5,HECTD1,RAD52,PRTN3,DAB2,PRRX1,PTPN1,ZFR,PPHLN1,PBK,DCPS,SOD2,ISG15,SRXN1,CUL4B,CFL1,RC3H1,YAP1,SH3BGRL2,LGALS3,OTUB1,CALB2,BTRC,LAP3,RECQL4,PPP2R1B,RPA2,CREB1,CPLX2,PRDX4,TRIM4,RPA1,RNF144A,ERVW-4,CTSD,ZFP36L2,WTAP,VRK3,CRK,PDP1,CUL7,GAPDH,RNF123,SESN2,COX17,PRPF8,PPP2R1A,PIDD1,SCCPDH,ETS1,MTTP,RAD23A,KMT2A,PRDX3,RPA3,PIN1,GDPD5,EIF4A3,CCNB1,SUZ12,RNH1,TXN,SLC38A1,LARP7,CUL1,CUL4A,CUL5,CUL2,NF2,PIK3CB,PRKN,COPS5,CLEC4G,PITX2,PPP2R5D&scopes=drugbank.enzymes.gene_name&fields=drugbank.id&species=human&size=100")
# API 4.4: https://robokop.renci.org/api/simple/expand/gene/HGNC:9588/chemical_substance/
# API 4.7: https://robokop.renci.org/api/simple/expand/gene/HGNC:10291/chemical_substance/
# API 4.10: https://robokop.renci.org/api/simple/expand/gene/HGNC:18184/chemical_substance/
# API 4.13: https://robokop.renci.org/api/simple/expand/gene/HGNC:29330/chemical_substance/
# API 4.6: https://robokop.renci.org/api/simple/expand/gene/HGNC:12435/chemical_substance/
# API 4.15: https://robokop.renci.org/api/simple/expand/gene/HGNC:16132/chemical_substance/
# API 4.12: https://robokop.renci.org/api/simple/expand/gene/HGNC:3189/chemical_substance/
# API 4.8: https://robokop.renci.org/api/simple/expand/gene/HGNC:8975/chemical_substance/
# API 4.14: https://robokop.renci.org/api/simple/expand/gene/HGNC:9302/chemical_substance/
# API 4.9: https://robokop.renci.org/api/simple/expand/gene/HGNC:12680/chemical_substance/
# API 4.11: https://robokop.renci.org/api/simple/expand/gene/HGNC:11850/chemical_substance/
# API 4.17: https://robokop.renci.org/api/simple/expand/gene/HGNC:9495/chemical_substance/
# API 4.18: https://robokop.renci.org/api/simple/expand/gene/HGNC:1735/chemical_substance/
# API 1.3: http://mychem.info/v1/query (POST "q=ACY1,PIK3CA,EEF1A1,CALM1,CRY1,TP63,CFTR,VIRMA,TERF1,PHB,COX6B1,UCHL5,BRCA1,MST1,PTEN,TLR4,SOD1,COPS6,PTPRC,SYK,APEX1,GABPA,DNPH1,NTRK1,RBMS3,DCUN1D1,CDK9,FERMT3,FYN,CAT,HTRA2,PRDX2,OBSL1,PPT1,AGO4,U2AF2,UBE2M,AR,CR2,DAZAP1,CDC37,PRKCZ,CDC42,CDH1,ANAPC15,JTB,PRDX6,MEPCE,CYLD,CUL3,PRKDC,CDC73,AKT1,HDAC6,RIOK1,TNF,METTL14,AAR2,VEGFA,DHRS4,RAB4B,RASA1,SESN1,CDK2,EGFR,TDGF1,PEBP1,MTRNR2L1,TRBV20OR9-2,MYC,HEXIM1,PRDX5,HECTD1,RAD52,PRTN3,DAB2,PRRX1,PTPN1,ZFR,PPHLN1,PBK,DCPS,SOD2,ISG15,SRXN1,CUL4B,CFL1,RC3H1,YAP1,SH3BGRL2,LGALS3,OTUB1,CALB2,BTRC,LAP3,RECQL4,PPP2R1B,RPA2,CREB1,CPLX2,PRDX4,TRIM4,RPA1,RNF144A,ERVW-4,CTSD,ZFP36L2,WTAP,VRK3,CRK,PDP1,CUL7,GAPDH,RNF123,SESN2,COX17,PRPF8,PPP2R1A,PIDD1,SCCPDH,ETS1,MTTP,RAD23A,KMT2A,PRDX3,RPA3,PIN1,GDPD5,EIF4A3,CCNB1,SUZ12,RNH1,TXN,SLC38A1,LARP7,CUL1,CUL4A,CUL5,CUL2,NF2,PIK3CB,PRKN,COPS5,CLEC4G,PITX2,PPP2R5D&scopes=drugcentral.bioactivity.uniprot.gene_symbol&fields=chembl.molecule_chembl_id&species=human&size=100")
# API 4.16: https://robokop.renci.org/api/simple/expand/gene/HGNC:2345/chemical_substance/
# API 4.21: https://robokop.renci.org/api/simple/expand/gene/HGNC:2384/chemical_substance/
# API 1.2: http://mychem.info/v1/query (POST "q=ACY1,PIK3CA,EEF1A1,CALM1,CRY1,TP63,CFTR,VIRMA,TERF1,PHB,COX6B1,UCHL5,BRCA1,MST1,PTEN,TLR4,SOD1,COPS6,PTPRC,SYK,APEX1,GABPA,DNPH1,NTRK1,RBMS3,DCUN1D1,CDK9,FERMT3,FYN,CAT,HTRA2,PRDX2,OBSL1,PPT1,AGO4,U2AF2,UBE2M,AR,CR2,DAZAP1,CDC37,PRKCZ,CDC42,CDH1,ANAPC15,JTB,PRDX6,MEPCE,CYLD,CUL3,PRKDC,CDC73,AKT1,HDAC6,RIOK1,TNF,METTL14,AAR2,VEGFA,DHRS4,RAB4B,RASA1,SESN1,CDK2,EGFR,TDGF1,PEBP1,MTRNR2L1,TRBV20OR9-2,MYC,HEXIM1,PRDX5,HECTD1,RAD52,PRTN3,DAB2,PRRX1,PTPN1,ZFR,PPHLN1,PBK,DCPS,SOD2,ISG15,SRXN1,CUL4B,CFL1,RC3H1,YAP1,SH3BGRL2,LGALS3,OTUB1,CALB2,BTRC,LAP3,RECQL4,PPP2R1B,RPA2,CREB1,CPLX2,PRDX4,TRIM4,RPA1,RNF144A,ERVW-4,CTSD,ZFP36L2,WTAP,VRK3,CRK,PDP1,CUL7,GAPDH,RNF123,SESN2,COX17,PRPF8,PPP2R1A,PIDD1,SCCPDH,ETS1,MTTP,RAD23A,KMT2A,PRDX3,RPA3,PIN1,GDPD5,EIF4A3,CCNB1,SUZ12,RNH1,TXN,SLC38A1,LARP7,CUL1,CUL4A,CUL5,CUL2,NF2,PIK3CB,PRKN,COPS5,CLEC4G,PITX2,PPP2R5D&scopes=drugbank.targets.gene_name&fields=drugbank.id&species=human&size=100")
# API 4.22: https://robokop.renci.org/api/simple/expand/gene/HGNC:9303/chemical_substance/
# API 4.25: https://robokop.renci.org/api/simple/expand/gene/HGNC:2240/chemical_substance/
# API 4.23: https://robokop.renci.org/api/simple/expand/gene/HGNC:12491/chemical_substance/
# API 4.19: https://robokop.renci.org/api/simple/expand/gene/HGNC:587/chemical_substance/
# API 4.29: https://robokop.renci.org/api/simple/expand/gene/HGNC:13447/chemical_substance/
# API 4.30: https://robokop.renci.org/api/simple/expand/gene/HGNC:9812/chemical_substance/
# API 4.31: https://robokop.renci.org/api/simple/expand/gene/HGNC:2551/chemical_substance/
# API 4.32: https://robokop.renci.org/api/simple/expand/gene/HGNC:18996/chemical_substance/
# API 4.26: https://robokop.renci.org/api/simple/expand/gene/HGNC:4037/chemical_substance/
# API 4.28: https://robokop.renci.org/api/simple/expand/gene/HGNC:11180/chemical_substance/
# API 4.24: https://robokop.renci.org/api/simple/expand/gene/HGNC:8912/chemical_substance/
# API 4.27: https://robokop.renci.org/api/simple/expand/gene/HGNC:21024/chemical_substance/
# API 4.20: https://robokop.renci.org/api/simple/expand/gene/HGNC:11892/chemical_substance/
# API 4.33: https://robokop.renci.org/api/simple/expand/gene/HGNC:9354/chemical_substance/
# API 4.34: https://robokop.renci.org/api/simple/expand/gene/HGNC:9355/chemical_substance/
# API 4.37: https://robokop.renci.org/api/simple/expand/gene/HGNC:7773/chemical_substance/
# API 4.35: https://robokop.renci.org/api/simple/expand/gene/HGNC:9142/chemical_substance/
# API 4.36: https://robokop.renci.org/api/simple/expand/gene/HGNC:16846/chemical_substance/
# API 4.41: https://robokop.renci.org/api/simple/expand/gene/HGNC:7380/chemical_substance/
# API 4.39: https://robokop.renci.org/api/simple/expand/gene/HGNC:2362/chemical_substance/
# API 4.45: https://robokop.renci.org/api/simple/expand/gene/HGNC:1442/chemical_substance/
# API 4.42: https://robokop.renci.org/api/simple/expand/gene/HGNC:16985/chemical_substance/
# API 4.43: https://robokop.renci.org/api/simple/expand/gene/HGNC:15567/chemical_substance/
# API 4.38: https://robokop.renci.org/api/simple/expand/gene/HGNC:19678/chemical_substance/
# API 4.46: https://robokop.renci.org/api/simple/expand/gene/HGNC:24275/chemical_substance/
# API 4.40: https://robokop.renci.org/api/simple/expand/gene/HGNC:1435/chemical_substance/
# API 4.47: https://robokop.renci.org/api/simple/expand/gene/HGNC:8031/chemical_substance/
# API 4.44: https://robokop.renci.org/api/simple/expand/gene/HGNC:8630/chemical_substance/
# API 4.53: https://robokop.renci.org/api/simple/expand/gene/HGNC:18424/chemical_substance/
# API 4.50: https://robokop.renci.org/api/simple/expand/gene/HGNC:6201/chemical_substance/
# API 4.52: https://robokop.renci.org/api/simple/expand/gene/HGNC:9782/chemical_substance/
# API 4.49: https://robokop.renci.org/api/simple/expand/gene/HGNC:2264/chemical_substance/
# API 4.54: https://robokop.renci.org/api/simple/expand/gene/HGNC:11701/chemical_substance/
# API 4.59: https://robokop.renci.org/api/simple/expand/gene/HGNC:9312/chemical_substance/
# API 4.58: https://robokop.renci.org/api/simple/expand/gene/HGNC:11179/chemical_substance/
# API 4.51: https://robokop.renci.org/api/simple/expand/gene/HGNC:3488/chemical_substance/
# API 4.48: https://robokop.renci.org/api/simple/expand/gene/HGNC:16753/chemical_substance/
# API 4.64: https://robokop.renci.org/api/simple/expand/gene/HGNC:24500/chemical_substance/
# API 4.61: https://robokop.renci.org/api/simple/expand/gene/HGNC:23151/chemical_substance/
# API 4.63: https://robokop.renci.org/api/simple/expand/gene/HGNC:10074/chemical_substance/
# API 4.57: https://robokop.renci.org/api/simple/expand/gene/HGNC:1144/chemical_substance/
# API 4.60: https://robokop.renci.org/api/simple/expand/gene/HGNC:2683/chemical_substance/
# API 4.55: https://robokop.renci.org/api/simple/expand/gene/HGNC:24912/chemical_substance/
# API 4.68: https://robokop.renci.org/api/simple/expand/gene/HGNC:16783/chemical_substance/
# API 4.62: https://robokop.renci.org/api/simple/expand/gene/HGNC:9413/chemical_substance/
# API 4.56: https://robokop.renci.org/api/simple/expand/gene/HGNC:1748/chemical_substance/
# API 4.78: https://robokop.renci.org/api/simple/expand/gene/HGNC:9871/chemical_substance/
# API 4.66: https://robokop.renci.org/api/simple/expand/gene/HGNC:23156/chemical_substance/
# API 4.65: https://robokop.renci.org/api/simple/expand/gene/HGNC:2584/chemical_substance/
# API 4.74: https://robokop.renci.org/api/simple/expand/gene/HGNC:14064/chemical_substance/
# API 4.75: https://robokop.renci.org/api/simple/expand/gene/HGNC:9353/chemical_substance/
# API 4.70: https://robokop.renci.org/api/simple/expand/gene/HGNC:21218/chemical_substance/
# API 4.77: https://robokop.renci.org/api/simple/expand/gene/HGNC:21595/chemical_substance/
# API 4.71: https://robokop.renci.org/api/simple/expand/gene/HGNC:9949/chemical_substance/
# API 4.72: https://robokop.renci.org/api/simple/expand/gene/HGNC:1108/chemical_substance/
# API 4.67: https://robokop.renci.org/api/simple/expand/gene/HGNC:8607/chemical_substance/
# API 4.76: https://robokop.renci.org/api/simple/expand/gene/HGNC:29812/chemical_substance/
# API 4.73: https://robokop.renci.org/api/simple/expand/gene/HGNC:391/chemical_substance/
# API 4.69: https://robokop.renci.org/api/simple/expand/gene/HGNC:9412/chemical_substance/
#
#
# ==== Step #3: Output normalization ====
#
# API 3.1 dgidb_gene2chemical: 2 hits
# API 3.2 dgidb_gene2chemical: 3 hits
# API 3.3 dgidb_gene2chemical: 149 hits
# API 3.4 dgidb_gene2chemical: 2 hits
# API 3.5 dgidb_gene2chemical: No hits
# API 3.6 dgidb_gene2chemical: No hits
# API 3.7 dgidb_gene2chemical: 15 hits
# API 3.8 dgidb_gene2chemical: 35 hits
# API 3.9 dgidb_gene2chemical: No hits
# API 3.10 dgidb_gene2chemical: No hits
# API 3.11 dgidb_gene2chemical: 1 hits
# API 3.12 dgidb_gene2chemical: No hits
# API 3.13 dgidb_gene2chemical: 1 hits
# API 3.14 dgidb_gene2chemical: 20 hits
# API 3.15 dgidb_gene2chemical: 2 hits
# API 3.16 dgidb_gene2chemical: 2 hits
# API 3.17 dgidb_gene2chemical: No hits
# API 3.18 dgidb_gene2chemical: No hits
# API 3.19 dgidb_gene2chemical: No hits
# API 3.20 dgidb_gene2chemical: 1 hits
# API 3.21 dgidb_gene2chemical: No hits
# API 3.22 dgidb_gene2chemical: No hits
# API 3.23 dgidb_gene2chemical: 1 hits
# API 3.24 dgidb_gene2chemical: 1 hits
# API 3.25 dgidb_gene2chemical: No hits
# API 3.26 dgidb_gene2chemical: No hits
# API 3.27 dgidb_gene2chemical: No hits
# API 3.28 dgidb_gene2chemical: No hits
# API 3.29 dgidb_gene2chemical: No hits
# API 3.30 dgidb_gene2chemical: 29 hits
# API 3.31 dgidb_gene2chemical: No hits
# API 3.32 dgidb_gene2chemical: 104 hits
# API 3.33 dgidb_gene2chemical: 1 hits
# API 3.34 dgidb_gene2chemical: No hits
# API 3.35 dgidb_gene2chemical: 13 hits
# API 3.36 dgidb_gene2chemical: No hits
# API 3.37 dgidb_gene2chemical: 1 hits
# API 3.38 dgidb_gene2chemical: 3 hits
# API 3.39 dgidb_gene2chemical: No hits
# API 3.40 dgidb_gene2chemical: 2 hits
# API 3.41 dgidb_gene2chemical: No hits
# API 3.42 dgidb_gene2chemical: 8 hits
# API 3.43 dgidb_gene2chemical: 20 hits
# API 3.44 dgidb_gene2chemical: 3 hits
# API 3.45 dgidb_gene2chemical: 2 hits
# API 3.46 dgidb_gene2chemical: No hits
# API 3.47 dgidb_gene2chemical: No hits
# API 3.48 dgidb_gene2chemical: 37 hits
# API 3.49 dgidb_gene2chemical: No hits
# API 3.50 dgidb_gene2chemical: 3 hits
# API 3.51 dgidb_gene2chemical: 1 hits
# API 3.52 dgidb_gene2chemical: No hits
# API 3.53 dgidb_gene2chemical: 14 hits
# API 3.54 dgidb_gene2chemical: No hits
# API 3.55 dgidb_gene2chemical: 1 hits
# API 3.56 dgidb_gene2chemical: No hits
# API 3.57 dgidb_gene2chemical: 15 hits
# API 3.58 dgidb_gene2chemical: No hits
# API 3.59 dgidb_gene2chemical: No hits
# API 3.60 dgidb_gene2chemical: 1 hits
# API 3.61 dgidb_gene2chemical: No hits
# API 3.62 dgidb_gene2chemical: No hits
# API 3.63 dgidb_gene2chemical: 1 hits
# API 3.64 dgidb_gene2chemical: No hits
# API 3.65 dgidb_gene2chemical: 3 hits
# API 3.66 dgidb_gene2chemical: No hits
# API 3.67 dgidb_gene2chemical: No hits
# API 3.68 dgidb_gene2chemical: No hits
# API 3.69 dgidb_gene2chemical: 80 hits
# API 3.70 dgidb_gene2chemical: 9 hits
# API 3.71 dgidb_gene2chemical: 1 hits
# API 3.72 dgidb_gene2chemical: No hits
# API 3.73 dgidb_gene2chemical: 2 hits
# API 3.74 dgidb_gene2chemical: No hits
# API 3.75 dgidb_gene2chemical: No hits
# API 3.76 dgidb_gene2chemical: No hits
# API 3.77 dgidb_gene2chemical: No hits
# API 3.78 dgidb_gene2chemical: 10 hits
# API 3.79 dgidb_gene2chemical: No hits
# API 3.80 dgidb_gene2chemical: No hits
# API 3.81 dgidb_gene2chemical: 2 hits
# API 3.82 dgidb_gene2chemical: 7 hits
# API 3.83 dgidb_gene2chemical: No hits
# API 3.84 dgidb_gene2chemical: No hits
# API 3.85 dgidb_gene2chemical: No hits
# API 3.86 dgidb_gene2chemical: 8 hits
# API 3.87 dgidb_gene2chemical: No hits
# API 3.88 dgidb_gene2chemical: No hits
# API 3.89 dgidb_gene2chemical: No hits
# API 3.90 dgidb_gene2chemical: No hits
# API 3.91 dgidb_gene2chemical: No hits
# API 3.92 dgidb_gene2chemical: No hits
# API 3.93 dgidb_gene2chemical: 7 hits
# API 3.94 dgidb_gene2chemical: No hits
# API 3.95 dgidb_gene2chemical: No hits
# API 3.96 dgidb_gene2chemical: No hits
# API 3.97 dgidb_gene2chemical: No hits
# API 3.98 dgidb_gene2chemical: No hits
# API 3.99 dgidb_gene2chemical: No hits
# API 3.100 dgidb_gene2chemical: No hits
# API 3.101 dgidb_gene2chemical: No hits
# API 3.102 dgidb_gene2chemical: No hits
# API 3.103 dgidb_gene2chemical: No hits
# API 3.104 dgidb_gene2chemical: 4 hits
# API 3.105 dgidb_gene2chemical: No hits
# API 3.106 dgidb_gene2chemical: No hits
# API 3.107 dgidb_gene2chemical: No hits
# API 3.108 dgidb_gene2chemical: No hits
# API 3.109 dgidb_gene2chemical: 13 hits
# API 3.110 dgidb_gene2chemical: 33 hits
# API 3.111 dgidb_gene2chemical: No hits
# API 3.112 dgidb_gene2chemical: No hits
# API 3.113 dgidb_gene2chemical: No hits
# API 3.114 dgidb_gene2chemical: No hits
# API 3.115 dgidb_gene2chemical: No hits
# API 3.116 dgidb_gene2chemical: No hits
# API 3.117 dgidb_gene2chemical: No hits
# API 3.118 dgidb_gene2chemical: No hits
# API 3.119 dgidb_gene2chemical: No hits
# API 3.120 dgidb_gene2chemical: No hits
# API 3.121 dgidb_gene2chemical: No hits
# API 3.122 dgidb_gene2chemical: No hits
# API 3.123 dgidb_gene2chemical: No hits
# API 3.124 dgidb_gene2chemical: 142 hits
# API 3.125 dgidb_gene2chemical: 1 hits
# API 3.126 dgidb_gene2chemical: No hits
# API 3.127 dgidb_gene2chemical: 146 hits
# API 3.128 dgidb_gene2chemical: No hits
# API 3.129 dgidb_gene2chemical: No hits
# API 3.130 dgidb_gene2chemical: 2 hits
# API 3.131 dgidb_gene2chemical: No hits
# API 3.132 dgidb_gene2chemical: 3 hits
# API 3.133 dgidb_gene2chemical: No hits
# API 3.134 dgidb_gene2chemical: No hits
# API 3.135 dgidb_gene2chemical: No hits
# API 3.136 dgidb_gene2chemical: 11 hits
# API 3.137 dgidb_gene2chemical: No hits
# API 3.138 dgidb_gene2chemical: 48 hits
# API 3.139 dgidb_gene2chemical: 67 hits
# API 3.140 dgidb_gene2chemical: No hits
# API 3.141 dgidb_gene2chemical: No hits
# API 3.142 dgidb_gene2chemical: 3 hits
# API 3.143 dgidb_gene2chemical: No hits
# API 3.144 dgidb_gene2chemical: 1 hits
# API 3.145 dgidb_gene2chemical: No hits
# API 3.146 dgidb_gene2chemical: No hits
# API 1.1 mychem.info: 19 hits
# API 1.2 mychem.info: 518 hits
# API 1.3 mychem.info: 301 hits
# API 2.1 opentarget: No hits
# API 2.2 opentarget: 15 hits
# API 2.3 opentarget: No hits
# API 2.4 opentarget: No hits
# API 2.5 opentarget: No hits
# API 2.6 opentarget: No hits
# API 2.7 opentarget: No hits
# API 2.8 opentarget: No hits
# API 2.9 opentarget: No hits
# API 2.10 opentarget: No hits
# API 2.11 opentarget: No hits
# API 2.12 opentarget: No hits
# API 2.13 opentarget: 15 hits
# API 2.14 opentarget: No hits
# API 2.15 opentarget: No hits
# API 2.16 opentarget: No hits
# API 2.17 opentarget: No hits
# API 2.18 opentarget: No hits
# API 2.19 opentarget: No hits
# API 2.20 opentarget: No hits
# API 2.21 opentarget: No hits
# API 2.22 opentarget: 2 hits
# API 2.23 opentarget: No hits
# API 2.24 opentarget: No hits
# API 2.25 opentarget: No hits
# API 2.26 opentarget: No hits
# API 2.27 opentarget: No hits
# API 2.28 opentarget: 15 hits
# API 2.29 opentarget: No hits
# API 2.30 opentarget: No hits
# API 2.31 opentarget: No hits
# API 2.32 opentarget: 15 hits
# API 2.33 opentarget: No hits
# API 2.34 opentarget: No hits
# API 2.35 opentarget: No hits
# API 2.36 opentarget: No hits
# API 2.37 opentarget: 10 hits
# API 2.38 opentarget: 15 hits
# API 2.39 opentarget: 15 hits
# API 2.40 opentarget: No hits
# API 2.41 opentarget: No hits
# API 2.42 opentarget: No hits
# API 2.43 opentarget: No hits
# API 2.44 opentarget: 15 hits
# API 2.45 opentarget: No hits
# API 2.46 opentarget: No hits
# API 2.47 opentarget: No hits
# API 2.48 opentarget: No hits
# API 2.49 opentarget: No hits
# API 2.50 opentarget: No hits
# API 2.51 opentarget: No hits
# API 2.52 opentarget: No hits
# API 2.53 opentarget: No hits
# API 2.54 opentarget: No hits
# API 2.55 opentarget: No hits
# API 2.56 opentarget: No hits
# API 2.57 opentarget: No hits
# API 2.58 opentarget: No hits
# API 2.59 opentarget: No hits
# API 2.60 opentarget: No hits
# API 2.61 opentarget: No hits
# API 2.62 opentarget: No hits
# API 2.63 opentarget: No hits
# API 2.64 opentarget: No hits
# API 2.65 opentarget: No hits
# API 2.66 opentarget: 15 hits
# API 2.67 opentarget: 1 hits
# API 2.68 opentarget: No hits
# API 2.69 opentarget: No hits
# API 2.70 opentarget: No hits
# API 2.71 opentarget: No hits
# API 2.72 opentarget: No hits
# API 2.73 opentarget: No hits
# API 2.74 opentarget: 15 hits
# API 2.75 opentarget: No hits
# API 2.76 opentarget: No hits
# API 2.77 opentarget: No hits
# API 2.78 opentarget: No hits
# API 2.79 opentarget: 15 hits
# API 2.80 opentarget: No hits
# API 2.81 opentarget: No hits
# API 2.82 opentarget: No hits
# API 2.83 opentarget: No hits
# API 2.84 opentarget: No hits
# API 2.85 opentarget: 15 hits
# API 2.86 opentarget: No hits
# API 2.87 opentarget: No hits
# API 2.88 opentarget: No hits
# API 2.89 opentarget: No hits
# API 2.90 opentarget: No hits
# API 2.91 opentarget: No hits
# API 2.92 opentarget: No hits
# API 2.93 opentarget: No hits
# API 2.94 opentarget: No hits
# API 2.95 opentarget: No hits
# API 2.96 opentarget: No hits
# API 2.97 opentarget: No hits
# API 2.98 opentarget: No hits
# API 2.99 opentarget: 10 hits
# API 2.100 opentarget: No hits
# API 2.101 opentarget: No hits
# API 2.102 opentarget: No hits
# API 2.103 opentarget: No hits
# API 2.104 opentarget: No hits
# API 2.105 opentarget: No hits
# API 2.106 opentarget: No hits
# API 2.107 opentarget: No hits
# API 2.108 opentarget: No hits
# API 2.109 opentarget: No hits
# API 2.110 opentarget: No hits
# API 2.111 opentarget: No hits
# API 2.112 opentarget: No hits
# API 2.113 opentarget: No hits
# API 2.114 opentarget: No hits
# API 2.115 opentarget: No hits
# API 2.116 opentarget: No hits
# API 2.117 opentarget: No hits
# API 2.118 opentarget: No hits
# API 2.119 opentarget: No hits
# API 2.120 opentarget: No hits
# API 2.121 opentarget: No hits
# API 2.122 opentarget: No hits
# API 2.123 opentarget: No hits
# API 2.124 opentarget: No hits
# API 2.125 opentarget: No hits
# API 2.126 opentarget: No hits
# API 2.127 opentarget: 15 hits
# API 2.128 opentarget: No hits
# API 2.129 opentarget: No hits
# API 2.130 opentarget: No hits
# API 2.131 opentarget: 15 hits
# API 2.132 opentarget: No hits
# API 2.133 opentarget: No hits
# API 2.134 opentarget: No hits
# API 2.135 opentarget: No hits
# API 2.136 opentarget: No hits
# API 2.137 opentarget: No hits
# API 2.138 opentarget: No hits
# API 2.139 opentarget: No hits
# API 2.140 opentarget: No hits
# API 2.141 opentarget: No hits
# API 2.142 opentarget: No hits
# API 2.143 opentarget: No hits
# API 2.144 opentarget: No hits
# API 2.145 opentarget: No hits
# API 2.146 opentarget: No hits
# API 2.147 opentarget: No hits
# API 2.148 opentarget: 3 hits
# API 2.149 opentarget: No hits
# API 2.150 opentarget: No hits
# API 2.151 opentarget: No hits
# API 2.152 opentarget: No hits
# API 2.153 opentarget: No hits
# API 2.154 opentarget: No hits
# API 2.155 opentarget: No hits
# API 2.156 opentarget: No hits
# API 2.157 opentarget: No hits
# API 2.158 opentarget: No hits
# API 2.159 opentarget: No hits
# API 2.160 opentarget: No hits
# API 2.161 opentarget: No hits
# API 2.162 opentarget: No hits
# API 4.1 robokop_gene2chemical: No hits
# API 4.2 robokop_gene2chemical: 7 hits
# API 4.3 robokop_gene2chemical: No hits
# API 4.4 robokop_gene2chemical: 19 hits
# API 4.5 robokop_gene2chemical: 2 hits
# API 4.6 robokop_gene2chemical: 9 hits
# API 4.7 robokop_gene2chemical: No hits
# API 4.8 robokop_gene2chemical: 4 hits
# API 4.9 robokop_gene2chemical: 12 hits
# API 4.10 robokop_gene2chemical: No hits
# API 4.11 robokop_gene2chemical: 7 hits
# API 4.12 robokop_gene2chemical: 1 hits
# API 4.13 robokop_gene2chemical: No hits
# API 4.14 robokop_gene2chemical: No hits
# API 4.15 robokop_gene2chemical: 1 hits
# API 4.16 robokop_gene2chemical: 2 hits
# API 4.17 robokop_gene2chemical: No hits
# API 4.18 robokop_gene2chemical: No hits
# API 4.19 robokop_gene2chemical: 18 hits
# API 4.20 robokop_gene2chemical: 66 hits
# API 4.21 robokop_gene2chemical: No hits
# API 4.22 robokop_gene2chemical: No hits
# API 4.23 robokop_gene2chemical: No hits
# API 4.24 robokop_gene2chemical: No hits
# API 4.25 robokop_gene2chemical: No hits
# API 4.26 robokop_gene2chemical: 2 hits
# API 4.27 robokop_gene2chemical: No hits
# API 4.28 robokop_gene2chemical: 39 hits
# API 4.29 robokop_gene2chemical: No hits
# API 4.30 robokop_gene2chemical: No hits
# API 4.31 robokop_gene2chemical: No hits
# API 4.32 robokop_gene2chemical: No hits
# API 4.33 robokop_gene2chemical: 2 hits
# API 4.34 robokop_gene2chemical: 2 hits
# API 4.35 robokop_gene2chemical: No hits
# API 4.36 robokop_gene2chemical: No hits
# API 4.37 robokop_gene2chemical: 1 hits
# API 4.38 robokop_gene2chemical: No hits
# API 4.39 robokop_gene2chemical: No hits
# API 4.40 robokop_gene2chemical: 2 hits
# API 4.41 robokop_gene2chemical: No hits
# API 4.42 robokop_gene2chemical: No hits
# API 4.43 robokop_gene2chemical: No hits
# API 4.44 robokop_gene2chemical: No hits
# API 4.45 robokop_gene2chemical: No hits
# API 4.46 robokop_gene2chemical: No hits
# API 4.47 robokop_gene2chemical: No hits
# API 4.48 robokop_gene2chemical: 6 hits
# API 4.49 robokop_gene2chemical: 3 hits
# API 4.50 robokop_gene2chemical: No hits
# API 4.51 robokop_gene2chemical: No hits
# API 4.52 robokop_gene2chemical: No hits
# API 4.53 robokop_gene2chemical: No hits
# API 4.54 robokop_gene2chemical: No hits
# API 4.55 robokop_gene2chemical: No hits
# API 4.56 robokop_gene2chemical: 2 hits
# API 4.57 robokop_gene2chemical: No hits
# API 4.58 robokop_gene2chemical: 26 hits
# API 4.59 robokop_gene2chemical: No hits
# API 4.60 robokop_gene2chemical: No hits
# API 4.61 robokop_gene2chemical: No hits
# API 4.62 robokop_gene2chemical: 1 hits
# API 4.63 robokop_gene2chemical: No hits
# API 4.64 robokop_gene2chemical: No hits
# API 4.65 robokop_gene2chemical: 3 hits
# API 4.66 robokop_gene2chemical: No hits
# API 4.67 robokop_gene2chemical: 1 hits
# API 4.68 robokop_gene2chemical: No hits
# API 4.69 robokop_gene2chemical: 1 hits
# API 4.70 robokop_gene2chemical: No hits
# API 4.71 robokop_gene2chemical: No hits
# API 4.72 robokop_gene2chemical: No hits
# API 4.73 robokop_gene2chemical: 23 hits
# API 4.74 robokop_gene2chemical: 1 hits
# API 4.75 robokop_gene2chemical: 7 hits
# API 4.76 robokop_gene2chemical: 1 hits
# API 4.77 robokop_gene2chemical: No hits
# API 4.78 robokop_gene2chemical: No hits
# API 4.79 robokop_gene2chemical: No hits
# API 4.80 robokop_gene2chemical: No hits
# API 4.81 robokop_gene2chemical: No hits
# API 4.82 robokop_gene2chemical: No hits
# API 4.83 robokop_gene2chemical: No hits
# API 4.84 robokop_gene2chemical: No hits
# API 4.85 robokop_gene2chemical: No hits
# API 4.86 robokop_gene2chemical: No hits
# API 4.87 robokop_gene2chemical: No hits
# API 4.88 robokop_gene2chemical: No hits
# API 4.89 robokop_gene2chemical: No hits
# API 4.90 robokop_gene2chemical: No hits
# API 4.91 robokop_gene2chemical: No hits
# API 4.92 robokop_gene2chemical: No hits
# API 4.93 robokop_gene2chemical: No hits
# API 4.94 robokop_gene2chemical: No hits
# API 4.95 robokop_gene2chemical: No hits
# API 4.96 robokop_gene2chemical: No hits
# API 4.97 robokop_gene2chemical: No hits
# API 4.98 robokop_gene2chemical: No hits
# API 4.99 robokop_gene2chemical: No hits
# API 4.100 robokop_gene2chemical: No hits
# API 4.101 robokop_gene2chemical: No hits
# API 4.102 robokop_gene2chemical: No hits
# API 4.103 robokop_gene2chemical: No hits
# API 4.104 robokop_gene2chemical: No hits
# API 4.105 robokop_gene2chemical: No hits
# API 4.106 robokop_gene2chemical: No hits
# API 4.107 robokop_gene2chemical: No hits
# API 4.108 robokop_gene2chemical: No hits
# API 4.109 robokop_gene2chemical: No hits
# API 4.110 robokop_gene2chemical: No hits
# API 4.111 robokop_gene2chemical: No hits
# API 4.112 robokop_gene2chemical: No hits
# API 4.113 robokop_gene2chemical: No hits
# API 4.114 robokop_gene2chemical: No hits
# API 4.115 robokop_gene2chemical: No hits
# API 4.116 robokop_gene2chemical: No hits
# API 4.117 robokop_gene2chemical: No hits
# API 4.118 robokop_gene2chemical: No hits
# API 4.119 robokop_gene2chemical: No hits
# API 4.120 robokop_gene2chemical: No hits
# API 4.121 robokop_gene2chemical: No hits
# API 4.122 robokop_gene2chemical: No hits
# API 4.123 robokop_gene2chemical: No hits
# API 4.124 robokop_gene2chemical: No hits
# API 4.125 robokop_gene2chemical: No hits
# API 4.126 robokop_gene2chemical: No hits
# API 4.127 robokop_gene2chemical: No hits
# API 4.128 robokop_gene2chemical: No hits
# API 4.129 robokop_gene2chemical: No hits
# API 4.130 robokop_gene2chemical: No hits
# API 4.131 robokop_gene2chemical: No hits
# API 4.132 robokop_gene2chemical: No hits
# API 4.133 robokop_gene2chemical: No hits
# API 4.134 robokop_gene2chemical: No hits
# API 4.135 robokop_gene2chemical: No hits
# API 4.136 robokop_gene2chemical: No hits
# API 4.137 robokop_gene2chemical: No hits
# API 4.138 robokop_gene2chemical: No hits
# API 4.139 robokop_gene2chemical: No hits
# API 4.140 robokop_gene2chemical: No hits
# API 4.141 robokop_gene2chemical: No hits
# API 4.142 robokop_gene2chemical: No hits
# API 4.143 robokop_gene2chemical: No hits
# API 4.144 robokop_gene2chemical: No hits
# API 4.145 robokop_gene2chemical: No hits
# API 4.146 robokop_gene2chemical: No hits
# API 5.1 semmedgene: 25595 hits
#
# After id-to-object translation, BTE retrieved 6103 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# In the #1 query, BTE found 218 unique Gene nodes
# In the #2 query, BTE found 6103 unique ChemicalSubstance nodes

# %%
df = fc.display_table_view()

# %% [markdown]
# The df object contains the full output from BioThings Explorer. Each row shows one path that joins the input node (PRDX1) to an intermediate node (a gene or protein) to an ending node (a chemical compound). The data frame includes a set of columns with additional details on each node and edge (including human-readable labels, identifiers, and sources). Let's remove all examples where the output_name (the compound label) is None, and specifically focus on paths with specific mechanistic predicates decreasesActivityOf and targetedBy.

# %% [markdown]
# ### Filter for drugs that targets genes which decrease the activity of PRDX1

# %%
dfFilt = df.loc[df['output_name'].notnull()].query('pred1 == "decreasesActivityOf" and pred2 == "targetedBy"')
dfFilt
# Out:
#        input input_type                pred1 pred1_source   pred1_api  \
# 215    PRDX1       Gene  decreasesActivityOf       semmed  semmedgene
# 346    PRDX1       Gene  decreasesActivityOf       semmed  semmedgene
# 512    PRDX1       Gene  decreasesActivityOf       semmed  semmedgene
# 793    PRDX1       Gene  decreasesActivityOf       semmed  semmedgene
# 899    PRDX1       Gene  decreasesActivityOf       semmed  semmedgene
# ...      ...        ...                  ...          ...         ...
# 32292  PRDX1       Gene  decreasesActivityOf       semmed  semmedgene
# 32321  PRDX1       Gene  decreasesActivityOf       semmed  semmedgene
# 32322  PRDX1       Gene  decreasesActivityOf       semmed  semmedgene
# 32652  PRDX1       Gene  decreasesActivityOf       semmed  semmedgene
# 33232  PRDX1       Gene  decreasesActivityOf       semmed  semmedgene
#
#       pred1_pubmed      node1_id node1_name node1_type       pred2  \
# 215                  entrez:7422      VEGFA       Gene  targetedBy
# 346                  entrez:7422      VEGFA       Gene  targetedBy
# 512                  entrez:1385      CREB1       Gene  targetedBy
# 793                  entrez:7124        TNF       Gene  targetedBy
# 899                  entrez:7124        TNF       Gene  targetedBy
# ...            ...           ...        ...        ...         ...
# 32292                entrez:7124        TNF       Gene  targetedBy
# 32321               entrez:10013      HDAC6       Gene  targetedBy
# 32322               entrez:10013      HDAC6       Gene  targetedBy
# 32652                entrez:7422      VEGFA       Gene  targetedBy
# 33232                entrez:7124        TNF       Gene  targetedBy
#
#       pred2_source            pred2_api pred2_pubmed             output_id  \
# 215    mychem.info          mychem.info         None      drugbank:DB14864
# 346          dgidb  dgidb_gene2chemical         None      chembl:CHEMBL799
# 512          dgidb  dgidb_gene2chemical         None        chembl:CHEMBL3
# 793    mychem.info          mychem.info         None  chembl:CHEMBL1201831
# 899    mychem.info          mychem.info         None   chembl:CHEMBL173373
# ...            ...                  ...          ...                   ...
# 32292  mychem.info          mychem.info         None  chembl:CHEMBL2103838
# 32321  mychem.info          mychem.info         None       chembl:CHEMBL98
# 32322  mychem.info          mychem.info         None       chembl:CHEMBL98
# 32652        dgidb  dgidb_gene2chemical         None       chembl:CHEMBL16
# 33232  mychem.info          mychem.info         None      drugbank:DB10770
#
#               output_name        output_type
# 215               DB14864  ChemicalSubstance
# 346            CILOSTAZOL  ChemicalSubstance
# 512              NICOTINE  ChemicalSubstance
# 793    CERTOLIZUMAB PEGOL  ChemicalSubstance
# 899        ethyl pyruvate  ChemicalSubstance
# ...                   ...                ...
# 32292          DILMAPIMOD  ChemicalSubstance
# 32321          VORINOSTAT  ChemicalSubstance
# 32322          VORINOSTAT  ChemicalSubstance
# 32652           PHENYTOIN  ChemicalSubstance
# 33232             DB10770  ChemicalSubstance
#
# [132 rows x 16 columns]

# %% [markdown]
# ## Step 3: Evaluating Paths based on published pathway figures

# %% [markdown]
# Let's see if PRDX1 (entrez:5052) is in the same pathway as VEGFA (entrez:7422) using our newly created API [PFOCR](http://pending.biothings.io/pfocr)

# %%
import requests

# query pfocr to see if PRDX1 and VEGFA is in the same pathway figure
doc = requests.get('https://pending.biothings.io/pfocr/query?q=associatedWith.genes:5052 AND associatedWith.genes:7422').json()
doc
# Out:
# {'max_score': 10.06258,
#  'took': 1,
#  'total': 1,
#  'hits': [{'_id': 'PMC4776098__srep22392-f1.jpg',
#    '_score': 10.06258,
#    'associatedWith': {'figureUrl': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4776098/bin/srep22392-f1.jpg',
#     'genes': ['1000',
#      '10013',
#      '10451',
#      '10540',
#      '10657',
#      '1072',
#      '1147',
#      '116085',
#      '1232',
#      '1410',
#      '1499',
#      '1600',
#      '161003',
#      '1654',
#      '1956',
#      '207',
#      '2113',
#      '2146',
#      '2194',
#      '226',
#      '2308',
#      '2309',
#      '2324',
#      '2475',
#      '2495',
#      '25',
#      '25759',
#      '2885',
#      '2902',
#      '3091',
#      '3181',
#      '3326',
#      '3329',
#      '3397',
#      '3399',
#      '3717',
#      '3791',
#      '3921',
#      '3927',
#      '399694',
#      '4092',
#      '4171',
#      '4172',
#      '4176',
#      '4282',
#      '4306',
#      '4602',
#      '4609',
#      '4627',
#      '4628',
#      '4846',
#      '4869',
#      '5013',
#      '5052',
#      '5058',
#      '5062',
#      '5063',
#      '5080',
#      '5156',
#      '5290',
#      '5308',
#      '5330',
#      '5335',
#      '53358',
#      '5480',
#      '5578',
#      '5580',
#      '5587',
#      '5590',
#      '5594',
#      '5599',
#      '5604',
#      '5605',
#      '5730',
#      '5764',
#      '5803',
#      '5880',
#      '5894',
#      '5979',
#      '6004',
#      '6097',
#      '6197',
#      '6387',
#      '6464',
#      '6584',
#      '6622',
#      '6624',
#      '6714',
#      '673',
#      '6772',
#      '6773',
#      '6774',
#      '6935',
#      '7001',
#      '7052',
#      '7157',
#      '7204',
#      '7253',
#      '7301',
#      '7422',
#      '7428',
#      '7431',
#      '7852',
#      '8320',
#      '83737',
#      '8407',
#      '84342',
#      '860',
#      '868',
#      '8879',
#      '9112',
#      '91544',
#      '920',
#      '9590',
#      '983'],
#     'pmc': 'PMC4776098'}}]}

# %% [markdown]
# ![](img/srep22392-f1.jpg)
