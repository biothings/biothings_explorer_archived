# %% [markdown]
# # Install and import biothings_explorer

# %%
# !pip install git+https://github.com/biothings/biothings_explorer.git

# %%
from biothings_explorer.smartapi_kg import MetaKG

# %% [markdown]
# # Construct Meta-KG from SmartAPI

# %%
kg = MetaKG()

# %%
kg.constructMetaKG(source="remote")

# %% [markdown]
# # Filter

# %% [markdown]
# ## Filter for Meta-KG operations with Gene as Input and ChemicalSubstance as output

# %%
kg.filter({"input_type": "Gene", "output_type": "ChemicalSubstance"})
# Out:
# [{'inputs': [{'id': 'NCBIGene', 'semantic': 'Gene'}],
#   'outputs': [{'id': 'CHEMBL.COMPOUND', 'semantic': 'ChemicalSubstance'}],
#   'parameters': {'geneid': 'NCBIGene:{inputs[0]}'},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'CHEMBL.COMPOUND': 'associated_with.chembl'}},
#   'source': 'scigraph',
#   'supportBatch': False,
#   'query_operation': {'server': 'https://automat.renci.org/cord19-scigraph',
#    'params': {'geneid': 'NCBIGene:{inputs[0]}'},
#    'request_body': None,
#    'path': '/gene/chemical_substance/{geneid}',
#    'path_params': ['geneid'],
#    'method': 'get',
#    'tags': ['drug', 'gene', 'disease', 'automat', 'translator'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'NCBIGene',
#    'input_type': 'Gene',
#    'output_id': 'CHEMBL.COMPOUND',
#    'output_type': 'ChemicalSubstance',
#    'predicate': 'related_to',
#    'source': 'scigraph',
#    'api_name': 'Automat CORD19 Scigraph API',
#    'smartapi': {'id': '8d5ef70318e800e7020eba5ca812a1b0',
#     'meta': {'ETag': '7a09db3546b07fc7b893b1a6ef6ef696f31fb8a79eb7b63ed86c47fdd0d28798',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-08-13T23:09:11.737217',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:06:28.659989',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/scigraph/smartapi.yaml'}}},
#   'id': 'f4bfe8bb974bf412c817068a54c7c0a13ea7100fe3e18aaadc9de5db'},
#  {'inputs': [{'id': 'NCBIGene', 'semantic': 'Gene'}],
#   'outputs': [{'id': 'CHEBI', 'semantic': 'ChemicalSubstance'}],
#   'parameters': {'geneid': 'NCBIGene:{inputs[0]}'},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'CHEBI': 'associated_with.chebi'}},
#   'source': 'scigraph',
#   'supportBatch': False,
#   'query_operation': {'server': 'https://automat.renci.org/cord19-scigraph',
#    'params': {'geneid': 'NCBIGene:{inputs[0]}'},
#    'request_body': None,
#    'path': '/gene/chemical_substance/{geneid}',
#    'path_params': ['geneid'],
#    'method': 'get',
#    'tags': ['drug', 'gene', 'disease', 'automat', 'translator'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'NCBIGene',
#    'input_type': 'Gene',
#    'output_id': 'CHEBI',
#    'output_type': 'ChemicalSubstance',
#    'predicate': 'related_to',
#    'source': 'scigraph',
#    'api_name': 'Automat CORD19 Scigraph API',
#    'smartapi': {'id': '8d5ef70318e800e7020eba5ca812a1b0',
#     'meta': {'ETag': '7a09db3546b07fc7b893b1a6ef6ef696f31fb8a79eb7b63ed86c47fdd0d28798',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-08-13T23:09:11.737217',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:06:28.659989',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/scigraph/smartapi.yaml'}}},
#   'id': '74b58be1da7e04a9beea9d6a11ad4ebdfa0c9e8cce8acb234d1f0e12'},
#  {'inputs': [{'id': 'NCBIGene', 'semantic': 'Gene'}],
#   'outputs': [{'id': 'CHEMBL.COMPOUND', 'semantic': 'ChemicalSubstance'}],
#   'parameters': {'geneid': 'NCBIGene:{inputs[0]}'},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'CHEMBL.COMPOUND': 'associated_with.chembl'}},
#   'source': 'scibite',
#   'supportBatch': False,
#   'query_operation': {'server': 'https://automat.renci.org/cord19-scibite',
#    'params': {'geneid': 'NCBIGene:{inputs[0]}'},
#    'request_body': None,
#    'path': '/gene/chemical_substance/{geneid}',
#    'path_params': ['geneid'],
#    'method': 'get',
#    'tags': ['drug', 'gene', 'disease', 'automat', 'translator'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'NCBIGene',
#    'input_type': 'Gene',
#    'output_id': 'CHEMBL.COMPOUND',
#    'output_type': 'ChemicalSubstance',
#    'predicate': 'related_to',
#    'source': 'scibite',
#    'api_name': 'Automat CORD19 Scibite API',
#    'smartapi': {'id': '5c5a0b5bc77e5d25d1a04e1385f9fad7',
#     'meta': {'ETag': 'b8c1bdc67be643a85cc63e0b8ed69ac5f559c55b6ed623cc2a7347b414b8ccc0',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-08-13T23:07:39.356659',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:06:30.732940',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/scibite/smartapi.yml'}}},
#   'id': '6c3bb88e3e8fb2037441a8bcb089600c6c506413271d19df5fec9278'},
#  {'inputs': [{'id': 'NCBIGene', 'semantic': 'Gene'}],
#   'outputs': [{'id': 'CHEBI', 'semantic': 'ChemicalSubstance'}],
#   'parameters': {'geneid': 'NCBIGene:{inputs[0]}'},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'CHEBI': 'associated_with.chebi'}},
#   'source': 'scibite',
#   'supportBatch': False,
#   'query_operation': {'server': 'https://automat.renci.org/cord19-scibite',
#    'params': {'geneid': 'NCBIGene:{inputs[0]}'},
#    'request_body': None,
#    'path': '/gene/chemical_substance/{geneid}',
#    'path_params': ['geneid'],
#    'method': 'get',
#    'tags': ['drug', 'gene', 'disease', 'automat', 'translator'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'NCBIGene',
#    'input_type': 'Gene',
#    'output_id': 'CHEBI',
#    'output_type': 'ChemicalSubstance',
#    'predicate': 'related_to',
#    'source': 'scibite',
#    'api_name': 'Automat CORD19 Scibite API',
#    'smartapi': {'id': '5c5a0b5bc77e5d25d1a04e1385f9fad7',
#     'meta': {'ETag': 'b8c1bdc67be643a85cc63e0b8ed69ac5f559c55b6ed623cc2a7347b414b8ccc0',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-08-13T23:07:39.356659',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:06:30.732940',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/scibite/smartapi.yml'}}},
#   'id': 'c3b31ebbc298a09d6bfc33a621e320815157603162abaf011ce3e7d6'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'HGNC', 'semantic': 'Gene'}],
#   'method': 'post',
#   'outputs': [{'id': 'CHEBI', 'semantic': 'ChemicalSubstance'}],
#   'parameters': {'fields': 'associated_with'},
#   'path': '/query',
#   'predicate': 'related_to',
#   'requestBody': {'body': {'q': '{inputs[0]}', 'scopes': 'hgnc'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'related_to': {'CHEBI': 'associated_with.chebi',
#     'pmc': 'associated_with.pmc'}},
#   'source': 'Translator Text Mining Provider',
#   'supportBatch': True,
#   'query_operation': {'server': 'https://biothings.ncats.io/cord_gene',
#    'params': {'fields': 'associated_with'},
#    'request_body': {'body': {'q': '{inputs[0]}', 'scopes': 'hgnc'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['gene', 'annotation', 'query', 'translator', 'biothings'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'HGNC',
#    'input_type': 'Gene',
#    'output_id': 'CHEBI',
#    'output_type': 'ChemicalSubstance',
#    'predicate': 'related_to',
#    'source': 'Translator Text Mining Provider',
#    'api_name': 'CORD Gene API',
#    'smartapi': {'id': '6bc54230a6fa7693b2cd113430387ca7',
#     'meta': {'ETag': '5e7512d15d24b57b52cb15604aaa6c24192f48ef00da9732f23aab3707b2061b',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-04-29T00:00:40.725359',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:05:44.334433',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/cord/cord_gene.yml'}}},
#   'id': '7d35b501443a38bedf81a488998e64b3639bca77f549430f0ca444c6'},
#  {'inputs': [{'id': 'NCBIGene', 'semantic': 'Gene'}],
#   'outputs': [{'id': 'CHEMBL.COMPOUND', 'semantic': 'ChemicalSubstance'}],
#   'parameters': {'geneid': 'NCBIGene:{inputs[0]}'},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'CHEMBL.COMPOUND': 'associated_with.chembl'}},
#   'source': 'pharos',
#   'supportBatch': False,
#   'query_operation': {'server': 'https://automat.renci.org/pharos',
#    'params': {'geneid': 'NCBIGene:{inputs[0]}'},
#    'request_body': None,
#    'path': '/gene/chemical_substance/{geneid}',
#    'path_params': ['geneid'],
#    'method': 'get',
#    'tags': ['drug', 'gene', 'disease', 'automat', 'translator'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'NCBIGene',
#    'input_type': 'Gene',
#    'output_id': 'CHEMBL.COMPOUND',
#    'output_type': 'ChemicalSubstance',
#    'predicate': 'related_to',
#    'source': 'pharos',
#    'api_name': 'Automat PHAROS API',
#    'smartapi': {'id': '4652c55b62f5c20dd35acb3141b0a376',
#     'meta': {'ETag': '638ccc79344185a185c5a724dd326439d0a17ddbcfc70e7acc75280e074e1b3c',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-05-27T16:55:12.354211',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:06:21.900344',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/pharos/smartapi.yaml'}}},
#   'id': 'c243e245b0d0515d90c794e318171ee8a955fe8d36c254db2157feef'},
#  {'inputs': [{'id': 'NCBIGene', 'semantic': 'Gene'}],
#   'outputs': [{'id': 'CHEBI', 'semantic': 'ChemicalSubstance'}],
#   'parameters': {'geneid': 'NCBIGene:{inputs[0]}'},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'CHEBI': 'associated_with.chebi'}},
#   'source': 'pharos',
#   'supportBatch': False,
#   'query_operation': {'server': 'https://automat.renci.org/pharos',
#    'params': {'geneid': 'NCBIGene:{inputs[0]}'},
#    'request_body': None,
#    'path': '/gene/chemical_substance/{geneid}',
#    'path_params': ['geneid'],
#    'method': 'get',
#    'tags': ['drug', 'gene', 'disease', 'automat', 'translator'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'NCBIGene',
#    'input_type': 'Gene',
#    'output_id': 'CHEBI',
#    'output_type': 'ChemicalSubstance',
#    'predicate': 'related_to',
#    'source': 'pharos',
#    'api_name': 'Automat PHAROS API',
#    'smartapi': {'id': '4652c55b62f5c20dd35acb3141b0a376',
#     'meta': {'ETag': '638ccc79344185a185c5a724dd326439d0a17ddbcfc70e7acc75280e074e1b3c',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-05-27T16:55:12.354211',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:06:21.900344',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/pharos/smartapi.yaml'}}},
#   'id': '7efc7b4e11d10a4f40db32207e50f22ae8735d389afb3597424c6b34'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'SYMBOL', 'semantic': 'Gene'}],
#   'outputs': [{'id': 'DRUGBANK', 'semantic': 'ChemicalSubstance'}],
#   'parameters': {'fields': 'drugbank.id', 'size': '250'},
#   'predicate': 'metabolize',
#   'requestBody': {'body': {'q': '{inputs[0]}',
#     'scopes': 'drugbank.enzymes.gene_name'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'metabolize': {'DRUGBANK': 'drugbank.id'}},
#   'source': 'drugbank',
#   'supportBatch': True,
#   'query_operation': {'server': 'https://mychem.info/v1',
#    'params': {'fields': 'drugbank.id', 'size': '250'},
#    'request_body': {'body': {'q': '{inputs[0]}',
#      'scopes': 'drugbank.enzymes.gene_name'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['chemical',
#     'drug',
#     'annotation',
#     'query',
#     'translator',
#     'biothings'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'SYMBOL',
#    'input_type': 'Gene',
#    'output_id': 'DRUGBANK',
#    'output_type': 'ChemicalSubstance',
#    'predicate': 'metabolize',
#    'source': 'drugbank',
#    'api_name': 'MyChem.info API',
#    'smartapi': {'id': '8f08d1446e0bb9c2b323713ce83e2bd3',
#     'meta': {'ETag': '846f7a462e065abd3b97830b42c653e02c2e68141e64bf124cf6cc0d74176535',
#      'github_username': 'newgene',
#      'slug': 'mychem',
#      'timestamp': '2020-05-28T00:00:39.113364',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:04:35.065884',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/mychem.info/openapi_full.yml'}}},
#   'id': 'a67b7d970c49ef7f495375dab9af17995a0283416b2e5506df98e8ab'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'SYMBOL', 'semantic': 'Gene'}],
#   'outputs': [{'id': 'DRUGBANK', 'semantic': 'ChemicalSubstance'}],
#   'parameters': {'fields': 'drugbank.id', 'size': '250'},
#   'predicate': 'physically_interacts_with',
#   'requestBody': {'body': {'q': '{inputs[0]}',
#     'scopes': 'drugbank.targets.gene_name'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'physically_interacts_with': {'DRUGBANK': 'drugbank.id'}},
#   'source': 'drugbank',
#   'supportBatch': True,
#   'query_operation': {'server': 'https://mychem.info/v1',
#    'params': {'fields': 'drugbank.id', 'size': '250'},
#    'request_body': {'body': {'q': '{inputs[0]}',
#      'scopes': 'drugbank.targets.gene_name'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['chemical',
#     'drug',
#     'annotation',
#     'query',
#     'translator',
#     'biothings'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'SYMBOL',
#    'input_type': 'Gene',
#    'output_id': 'DRUGBANK',
#    'output_type': 'ChemicalSubstance',
#    'predicate': 'physically_interacts_with',
#    'source': 'drugbank',
#    'api_name': 'MyChem.info API',
#    'smartapi': {'id': '8f08d1446e0bb9c2b323713ce83e2bd3',
#     'meta': {'ETag': '846f7a462e065abd3b97830b42c653e02c2e68141e64bf124cf6cc0d74176535',
#      'github_username': 'newgene',
#      'slug': 'mychem',
#      'timestamp': '2020-05-28T00:00:39.113364',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:04:35.065884',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/mychem.info/openapi_full.yml'}}},
#   'id': '7322b5c101c8c233e8a23d970de6b75715ed682afa07ed5557565e6e'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'SYMBOL', 'semantic': 'Gene'}],
#   'outputs': [{'id': 'CHEMBL.COMPOUND', 'semantic': 'ChemicalSubstance'}],
#   'parameters': {'fields': 'chembl.molecule_chembl_id', 'size': '250'},
#   'predicate': 'physically_interacts_with',
#   'requestBody': {'body': {'q': '{inputs[0]}',
#     'scopes': 'drugcentral.bioactivity.uniprot.gene_symbol'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'physically_interacts_with': {'CHEMBL.COMPOUND': 'chembl.molecule_chembl_id'}},
#   'source': 'drugcentral',
#   'supportBatch': True,
#   'query_operation': {'server': 'https://mychem.info/v1',
#    'params': {'fields': 'chembl.molecule_chembl_id', 'size': '250'},
#    'request_body': {'body': {'q': '{inputs[0]}',
#      'scopes': 'drugcentral.bioactivity.uniprot.gene_symbol'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['chemical',
#     'drug',
#     'annotation',
#     'query',
#     'translator',
#     'biothings'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'SYMBOL',
#    'input_type': 'Gene',
#    'output_id': 'CHEMBL.COMPOUND',
#    'output_type': 'ChemicalSubstance',
#    'predicate': 'physically_interacts_with',
#    'source': 'drugcentral',
#    'api_name': 'MyChem.info API',
#    'smartapi': {'id': '8f08d1446e0bb9c2b323713ce83e2bd3',
#     'meta': {'ETag': '846f7a462e065abd3b97830b42c653e02c2e68141e64bf124cf6cc0d74176535',
#      'github_username': 'newgene',
#      'slug': 'mychem',
#      'timestamp': '2020-05-28T00:00:39.113364',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:04:35.065884',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/mychem.info/openapi_full.yml'}}},
#   'id': 'dceab01f96a7703aabf77ed7e07de4afcd6155aa50747f6e0ac4899e'},
#  {'inputs': [{'id': 'ENSEMBL', 'semantic': 'Gene'}],
#   'outputs': [{'id': 'CHEMBL.COMPOUND', 'semantic': 'ChemicalSubstance'}],
#   'parameters': {'datasource': 'chembl',
#    'fields': 'drug',
#    'size': 100,
#    'target': '{inputs[0]}'},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'CHEMBL.COMPOUND': 'data.drug.id',
#     'moleculeType': 'data.drug.molecule_type',
#     'name': 'data.drug.molecule_name'}},
#   'source': 'CHEMBL',
#   'supportBatch': False,
#   'query_operation': {'server': 'https://platform-api.opentargets.io/v3',
#    'params': {'datasource': 'chembl',
#     'fields': 'drug',
#     'size': 100,
#     'target': '{inputs[0]}'},
#    'request_body': None,
#    'path': '/platform/public/evidence/filter',
#    'path_params': [],
#    'method': 'get',
#    'tags': ['translator', 'opentarget'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'ENSEMBL',
#    'input_type': 'Gene',
#    'output_id': 'CHEMBL.COMPOUND',
#    'output_type': 'ChemicalSubstance',
#    'predicate': 'related_to',
#    'source': 'CHEMBL',
#    'api_name': 'OpenTarget API',
#    'smartapi': {'id': '542ba165e1b4227854cf7c0a8addcc79',
#     'meta': {'ETag': '48533e703d4c8517807852ccbeaed37b707048697c80c13566a0b9acdc6b77c8',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-08-05T21:55:01.450929',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:06:16.318537',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/opentarget/smartapi.yaml'}}},
#   'id': '0d1b102386251f1c8a6d1132901603f895f6758660467111b54d5eac'},
#  {'inputs': [{'id': 'NCBIGene', 'semantic': 'Gene'}],
#   'outputs': [{'id': 'CHEMBL.COMPOUND', 'semantic': 'ChemicalSubstance'}],
#   'parameters': {'geneid': 'NCBIGene:{inputs[0]}'},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'CHEMBL.COMPOUND': 'associated_with.chembl'}},
#   'source': 'chembio',
#   'supportBatch': False,
#   'query_operation': {'server': 'https://automat.renci.org/chembio',
#    'params': {'geneid': 'NCBIGene:{inputs[0]}'},
#    'request_body': None,
#    'path': '/gene/chemical_substance/{geneid}',
#    'path_params': ['geneid'],
#    'method': 'get',
#    'tags': ['drug', 'gene', 'disease', 'automat', 'translator'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'NCBIGene',
#    'input_type': 'Gene',
#    'output_id': 'CHEMBL.COMPOUND',
#    'output_type': 'ChemicalSubstance',
#    'predicate': 'related_to',
#    'source': 'chembio',
#    'api_name': 'Automat CHEMBIO API',
#    'smartapi': {'id': 'c0c88b5e6728d537860db6fdc6a1d4f0',
#     'meta': {'ETag': 'e334d155bcb1a11e4095a695d4080d1b6d96e0439ebf06b288752a7a8eb4d61e',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-05-27T16:54:23.925602',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:05:45.309620',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/chembio/smartapi.yaml'}}},
#   'id': 'cc11fc21d372702e64e4831dca7b4fc970274acfc4a0f8586e4ae022'},
#  {'inputs': [{'id': 'NCBIGene', 'semantic': 'Gene'}],
#   'outputs': [{'id': 'CHEBI', 'semantic': 'ChemicalSubstance'}],
#   'parameters': {'geneid': 'NCBIGene:{inputs[0]}'},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'CHEBI': 'associated_with.chebi'}},
#   'source': 'chembio',
#   'supportBatch': False,
#   'query_operation': {'server': 'https://automat.renci.org/chembio',
#    'params': {'geneid': 'NCBIGene:{inputs[0]}'},
#    'request_body': None,
#    'path': '/gene/chemical_substance/{geneid}',
#    'path_params': ['geneid'],
#    'method': 'get',
#    'tags': ['drug', 'gene', 'disease', 'automat', 'translator'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'NCBIGene',
#    'input_type': 'Gene',
#    'output_id': 'CHEBI',
#    'output_type': 'ChemicalSubstance',
#    'predicate': 'related_to',
#    'source': 'chembio',
#    'api_name': 'Automat CHEMBIO API',
#    'smartapi': {'id': 'c0c88b5e6728d537860db6fdc6a1d4f0',
#     'meta': {'ETag': 'e334d155bcb1a11e4095a695d4080d1b6d96e0439ebf06b288752a7a8eb4d61e',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-05-27T16:54:23.925602',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:05:45.309620',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/chembio/smartapi.yaml'}}},
#   'id': 'a408e7cf7c08558ad728f0457e01b0a0247221a50e1ae8c7effae8da'},
#  {'inputs': [{'id': 'NCBIGene', 'semantic': 'Gene'}],
#   'outputs': [{'id': 'CHEMBL.COMPOUND', 'semantic': 'ChemicalSubstance'}],
#   'parameters': {'geneid': 'NCBIGene:{inputs[0]}'},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'CHEMBL.COMPOUND': 'associated_with.chembl'}},
#   'source': 'hmdb',
#   'supportBatch': False,
#   'query_operation': {'server': 'https://automat.renci.org/hmdb',
#    'params': {'geneid': 'NCBIGene:{inputs[0]}'},
#    'request_body': None,
#    'path': '/gene/chemical_substance/{geneid}',
#    'path_params': ['geneid'],
#    'method': 'get',
#    'tags': ['drug', 'gene', 'disease', 'automat', 'translator'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'NCBIGene',
#    'input_type': 'Gene',
#    'output_id': 'CHEMBL.COMPOUND',
#    'output_type': 'ChemicalSubstance',
#    'predicate': 'related_to',
#    'source': 'hmdb',
#    'api_name': 'Automat HMDB API',
#    'smartapi': {'id': 'df231f1efca0c3409e28dd5ca7228c1f',
#     'meta': {'ETag': '64db6e41d341bf4f1a35e58132ddfb8cd172577a9fdc5e07404f46230b35db72',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-05-27T16:54:50.943786',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:06:14.595279',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/hmdb/smartapi.yaml'}}},
#   'id': 'cedd4a43912add7d6d11250df3ddaabca70b809e2046f49eae134765'},
#  {'inputs': [{'id': 'NCBIGene', 'semantic': 'Gene'}],
#   'outputs': [{'id': 'CHEBI', 'semantic': 'ChemicalSubstance'}],
#   'parameters': {'geneid': 'NCBIGene:{inputs[0]}'},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'CHEBI': 'associated_with.chebi'}},
#   'source': 'hmdb',
#   'supportBatch': False,
#   'query_operation': {'server': 'https://automat.renci.org/hmdb',
#    'params': {'geneid': 'NCBIGene:{inputs[0]}'},
#    'request_body': None,
#    'path': '/gene/chemical_substance/{geneid}',
#    'path_params': ['geneid'],
#    'method': 'get',
#    'tags': ['drug', 'gene', 'disease', 'automat', 'translator'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'NCBIGene',
#    'input_type': 'Gene',
#    'output_id': 'CHEBI',
#    'output_type': 'ChemicalSubstance',
#    'predicate': 'related_to',
#    'source': 'hmdb',
#    'api_name': 'Automat HMDB API',
#    'smartapi': {'id': 'df231f1efca0c3409e28dd5ca7228c1f',
#     'meta': {'ETag': '64db6e41d341bf4f1a35e58132ddfb8cd172577a9fdc5e07404f46230b35db72',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-05-27T16:54:50.943786',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:06:14.595279',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/hmdb/smartapi.yaml'}}},
#   'id': 'd192f14e7a727f64b046ca4b98b2fe358def5154bcff9e0b57b6c64d'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'UMLS', 'semantic': 'Gene'}],
#   'method': 'post',
#   'outputs': [{'id': 'UMLS', 'semantic': 'ChemicalSubstance'}],
#   'parameters': {'fields': 'affected_by'},
#   'path': '/query',
#   'predicate': 'affected_by',
#   'requestBody': {'body': {'q': '{inputs[0]}', 'scopes': 'umls'}},
#   'response_mapping': {'affected_by': {'pmid': 'affected_by.pmid',
#     'umls': 'affected_by.umls'}},
#   'source': 'SEMMED',
#   'supportBatch': True,
#   'query_operation': {'server': 'https://biothings.ncats.io/semmedgene',
#    'params': {'fields': 'affected_by'},
#    'request_body': {'body': {'q': '{inputs[0]}', 'scopes': 'umls'}},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['disease',
#     'annotation',
#     'query',
#     'translator',
#     'biothings',
#     'semmed'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'UMLS',
#    'input_type': 'Gene',
#    'output_id': 'UMLS',
#    'output_type': 'ChemicalSubstance',
#    'predicate': 'affected_by',
#    'source': 'SEMMED',
#    'api_name': 'SEMMED Gene API',
#    'smartapi': {'id': '81955d376a10505c1c69cd06dbda3047',
#     'meta': {'ETag': 'f94053bc78b3c2f0b97f7afd52d7de2fe083b655e56a53090ad73e12be83673b',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-05-27T16:53:40.804575',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:05:25.590785',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/semmed/semmed_gene.yaml'}}},
#   'id': '57cadbe3957454aa9bcdd68b6534b761b9b016650604c093e3bf6427'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'UMLS', 'semantic': 'Gene'}],
#   'method': 'post',
#   'outputs': [{'id': 'UMLS', 'semantic': 'ChemicalSubstance'}],
#   'parameters': {'fields': 'affects'},
#   'path': '/query',
#   'predicate': 'affects',
#   'requestBody': {'body': {'q': '{inputs[0]}', 'scopes': 'umls'}},
#   'response_mapping': {'affects': {'pmid': 'affects.pmid',
#     'umls': 'affects.umls'}},
#   'source': 'SEMMED',
#   'supportBatch': True,
#   'query_operation': {'server': 'https://biothings.ncats.io/semmedgene',
#    'params': {'fields': 'affects'},
#    'request_body': {'body': {'q': '{inputs[0]}', 'scopes': 'umls'}},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['disease',
#     'annotation',
#     'query',
#     'translator',
#     'biothings',
#     'semmed'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'UMLS',
#    'input_type': 'Gene',
#    'output_id': 'UMLS',
#    'output_type': 'ChemicalSubstance',
#    'predicate': 'affects',
#    'source': 'SEMMED',
#    'api_name': 'SEMMED Gene API',
#    'smartapi': {'id': '81955d376a10505c1c69cd06dbda3047',
#     'meta': {'ETag': 'f94053bc78b3c2f0b97f7afd52d7de2fe083b655e56a53090ad73e12be83673b',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-05-27T16:53:40.804575',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:05:25.590785',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/semmed/semmed_gene.yaml'}}},
#   'id': '4b093bb7831280987c9ee698e615707ab171e04bc3aa7ae64e8d3b50'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'UMLS', 'semantic': 'Gene'}],
#   'method': 'post',
#   'outputs': [{'id': 'UMLS', 'semantic': 'ChemicalSubstance'}],
#   'parameters': {'fields': 'disrupted_by'},
#   'path': '/query',
#   'predicate': 'disrupted_by',
#   'requestBody': {'body': {'q': '{inputs[0]}', 'scopes': 'umls'}},
#   'response_mapping': {'disrupted_by': {'pmid': 'disrupted_by.pmid',
#     'umls': 'disrupted_by.umls'}},
#   'source': 'SEMMED',
#   'supportBatch': True,
#   'query_operation': {'server': 'https://biothings.ncats.io/semmedgene',
#    'params': {'fields': 'disrupted_by'},
#    'request_body': {'body': {'q': '{inputs[0]}', 'scopes': 'umls'}},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['disease',
#     'annotation',
#     'query',
#     'translator',
#     'biothings',
#     'semmed'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'UMLS',
#    'input_type': 'Gene',
#    'output_id': 'UMLS',
#    'output_type': 'ChemicalSubstance',
#    'predicate': 'disrupted_by',
#    'source': 'SEMMED',
#    'api_name': 'SEMMED Gene API',
#    'smartapi': {'id': '81955d376a10505c1c69cd06dbda3047',
#     'meta': {'ETag': 'f94053bc78b3c2f0b97f7afd52d7de2fe083b655e56a53090ad73e12be83673b',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-05-27T16:53:40.804575',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:05:25.590785',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/semmed/semmed_gene.yaml'}}},
#   'id': 'c087bb16a5dad8e257b62922de36b8607910c3d66bef69b59c55b632'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'UMLS', 'semantic': 'Gene'}],
#   'method': 'post',
#   'outputs': [{'id': 'UMLS', 'semantic': 'ChemicalSubstance'}],
#   'parameters': {'fields': 'disrupts'},
#   'path': '/query',
#   'predicate': 'disrupts',
#   'requestBody': {'body': {'q': '{inputs[0]}', 'scopes': 'umls'}},
#   'response_mapping': {'disrupts': {'pmid': 'disrupts.pmid',
#     'umls': 'disrupts.umls'}},
#   'source': 'SEMMED',
#   'supportBatch': True,
#   'query_operation': {'server': 'https://biothings.ncats.io/semmedgene',
#    'params': {'fields': 'disrupts'},
#    'request_body': {'body': {'q': '{inputs[0]}', 'scopes': 'umls'}},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['disease',
#     'annotation',
#     'query',
#     'translator',
#     'biothings',
#     'semmed'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'UMLS',
#    'input_type': 'Gene',
#    'output_id': 'UMLS',
#    'output_type': 'ChemicalSubstance',
#    'predicate': 'disrupts',
#    'source': 'SEMMED',
#    'api_name': 'SEMMED Gene API',
#    'smartapi': {'id': '81955d376a10505c1c69cd06dbda3047',
#     'meta': {'ETag': 'f94053bc78b3c2f0b97f7afd52d7de2fe083b655e56a53090ad73e12be83673b',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-05-27T16:53:40.804575',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:05:25.590785',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/semmed/semmed_gene.yaml'}}},
#   'id': '82ed12d850727fb2362b49e737359cc3f73659580e5f0742b884e0d8'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'UMLS', 'semantic': 'Gene'}],
#   'method': 'post',
#   'outputs': [{'id': 'UMLS', 'semantic': 'ChemicalSubstance'}],
#   'parameters': {'fields': 'negatively_regulated_by'},
#   'path': '/query',
#   'predicate': 'negatively_regulated_by',
#   'requestBody': {'body': {'q': '{inputs[0]}', 'scopes': 'umls'}},
#   'response_mapping': {'negatively_regulated_by': {'pmid': 'negatively_regulated_by.pmid',
#     'umls': 'negatively_regulated_by.umls'}},
#   'source': 'SEMMED',
#   'supportBatch': True,
#   'query_operation': {'server': 'https://biothings.ncats.io/semmedgene',
#    'params': {'fields': 'negatively_regulated_by'},
#    'request_body': {'body': {'q': '{inputs[0]}', 'scopes': 'umls'}},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['disease',
#     'annotation',
#     'query',
#     'translator',
#     'biothings',
#     'semmed'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'UMLS',
#    'input_type': 'Gene',
#    'output_id': 'UMLS',
#    'output_type': 'ChemicalSubstance',
#    'predicate': 'negatively_regulated_by',
#    'source': 'SEMMED',
#    'api_name': 'SEMMED Gene API',
#    'smartapi': {'id': '81955d376a10505c1c69cd06dbda3047',
#     'meta': {'ETag': 'f94053bc78b3c2f0b97f7afd52d7de2fe083b655e56a53090ad73e12be83673b',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-05-27T16:53:40.804575',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:05:25.590785',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/semmed/semmed_gene.yaml'}}},
#   'id': '7d7526ed27ad1de2788356ac285b93ef7fbd55bc1a08e631abc57bd3'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'UMLS', 'semantic': 'Gene'}],
#   'method': 'post',
#   'outputs': [{'id': 'UMLS', 'semantic': 'ChemicalSubstance'}],
#   'parameters': {'fields': 'negatively_regulates'},
#   'path': '/query',
#   'predicate': 'negatively_regulates',
#   'requestBody': {'body': {'q': '{inputs[0]}', 'scopes': 'umls'}},
#   'response_mapping': {'negatively_regulates': {'pmid': 'negatively_regulates.pmid',
#     'umls': 'negatively_regulates.umls'}},
#   'source': 'SEMMED',
#   'supportBatch': True,
#   'query_operation': {'server': 'https://biothings.ncats.io/semmedgene',
#    'params': {'fields': 'negatively_regulates'},
#    'request_body': {'body': {'q': '{inputs[0]}', 'scopes': 'umls'}},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['disease',
#     'annotation',
#     'query',
#     'translator',
#     'biothings',
#     'semmed'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'UMLS',
#    'input_type': 'Gene',
#    'output_id': 'UMLS',
#    'output_type': 'ChemicalSubstance',
#    'predicate': 'negatively_regulates',
#    'source': 'SEMMED',
#    'api_name': 'SEMMED Gene API',
#    'smartapi': {'id': '81955d376a10505c1c69cd06dbda3047',
#     'meta': {'ETag': 'f94053bc78b3c2f0b97f7afd52d7de2fe083b655e56a53090ad73e12be83673b',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-05-27T16:53:40.804575',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:05:25.590785',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/semmed/semmed_gene.yaml'}}},
#   'id': '3449645fea77cbab396dc0b5a1546e4298eacc2147a7e51e9ffec5f5'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'UMLS', 'semantic': 'Gene'}],
#   'method': 'post',
#   'outputs': [{'id': 'UMLS', 'semantic': 'ChemicalSubstance'}],
#   'parameters': {'fields': 'physically_interacts_with'},
#   'path': '/query',
#   'predicate': 'physically_interacts_with',
#   'requestBody': {'body': {'q': '{inputs[0]}', 'scopes': 'umls'}},
#   'response_mapping': {'physically_interacts_with': {'pmid': 'physically_interacts_with.pmid',
#     'umls': 'physically_interacts_with.umls'}},
#   'source': 'SEMMED',
#   'supportBatch': True,
#   'query_operation': {'server': 'https://biothings.ncats.io/semmedgene',
#    'params': {'fields': 'physically_interacts_with'},
#    'request_body': {'body': {'q': '{inputs[0]}', 'scopes': 'umls'}},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['disease',
#     'annotation',
#     'query',
#     'translator',
#     'biothings',
#     'semmed'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'UMLS',
#    'input_type': 'Gene',
#    'output_id': 'UMLS',
#    'output_type': 'ChemicalSubstance',
#    'predicate': 'physically_interacts_with',
#    'source': 'SEMMED',
#    'api_name': 'SEMMED Gene API',
#    'smartapi': {'id': '81955d376a10505c1c69cd06dbda3047',
#     'meta': {'ETag': 'f94053bc78b3c2f0b97f7afd52d7de2fe083b655e56a53090ad73e12be83673b',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-05-27T16:53:40.804575',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:05:25.590785',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/semmed/semmed_gene.yaml'}}},
#   'id': '44e7e06d4f7d467f3c950d3abe06c46538cd42faf1f2ad4c34daa760'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'UMLS', 'semantic': 'Gene'}],
#   'method': 'post',
#   'outputs': [{'id': 'UMLS', 'semantic': 'ChemicalSubstance'}],
#   'parameters': {'fields': 'positively_regulated_by'},
#   'path': '/query',
#   'predicate': 'positively_regulated_by',
#   'requestBody': {'body': {'q': '{inputs[0]}', 'scopes': 'umls'}},
#   'response_mapping': {'positively_regulated_by': {'pmid': 'positively_regulated_by.pmid',
#     'umls': 'positively_regulated_by.umls'}},
#   'source': 'SEMMED',
#   'supportBatch': True,
#   'query_operation': {'server': 'https://biothings.ncats.io/semmedgene',
#    'params': {'fields': 'positively_regulated_by'},
#    'request_body': {'body': {'q': '{inputs[0]}', 'scopes': 'umls'}},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['disease',
#     'annotation',
#     'query',
#     'translator',
#     'biothings',
#     'semmed'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'UMLS',
#    'input_type': 'Gene',
#    'output_id': 'UMLS',
#    'output_type': 'ChemicalSubstance',
#    'predicate': 'positively_regulated_by',
#    'source': 'SEMMED',
#    'api_name': 'SEMMED Gene API',
#    'smartapi': {'id': '81955d376a10505c1c69cd06dbda3047',
#     'meta': {'ETag': 'f94053bc78b3c2f0b97f7afd52d7de2fe083b655e56a53090ad73e12be83673b',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-05-27T16:53:40.804575',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:05:25.590785',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/semmed/semmed_gene.yaml'}}},
#   'id': '6e41bc026b531370b32da88083d3ff0e17539ec2d24e9a8c52dfa9ad'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'UMLS', 'semantic': 'Gene'}],
#   'method': 'post',
#   'outputs': [{'id': 'UMLS', 'semantic': 'ChemicalSubstance'}],
#   'parameters': {'fields': 'positively_regulates'},
#   'path': '/query',
#   'predicate': 'positively_regulates',
#   'requestBody': {'body': {'q': '{inputs[0]}', 'scopes': 'umls'}},
#   'response_mapping': {'positively_regulates': {'pmid': 'positively_regulates.pmid',
#     'umls': 'positively_regulates.umls'}},
#   'source': 'SEMMED',
#   'supportBatch': True,
#   'query_operation': {'server': 'https://biothings.ncats.io/semmedgene',
#    'params': {'fields': 'positively_regulates'},
#    'request_body': {'body': {'q': '{inputs[0]}', 'scopes': 'umls'}},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['disease',
#     'annotation',
#     'query',
#     'translator',
#     'biothings',
#     'semmed'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'UMLS',
#    'input_type': 'Gene',
#    'output_id': 'UMLS',
#    'output_type': 'ChemicalSubstance',
#    'predicate': 'positively_regulates',
#    'source': 'SEMMED',
#    'api_name': 'SEMMED Gene API',
#    'smartapi': {'id': '81955d376a10505c1c69cd06dbda3047',
#     'meta': {'ETag': 'f94053bc78b3c2f0b97f7afd52d7de2fe083b655e56a53090ad73e12be83673b',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-05-27T16:53:40.804575',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:05:25.590785',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/semmed/semmed_gene.yaml'}}},
#   'id': 'ed899ec553d0345e10da932e6b870131982417454b5bfa062bbcff4c'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'UMLS', 'semantic': 'Gene'}],
#   'method': 'post',
#   'outputs': [{'id': 'UMLS', 'semantic': 'ChemicalSubstance'}],
#   'parameters': {'fields': 'related_to'},
#   'path': '/query',
#   'predicate': 'related_to',
#   'requestBody': {'body': {'q': '{inputs[0]}', 'scopes': 'umls'}},
#   'response_mapping': {'related_to': {'pmid': 'related_to.pmid',
#     'umls': 'related_to.umls'}},
#   'source': 'SEMMED',
#   'supportBatch': True,
#   'query_operation': {'server': 'https://biothings.ncats.io/semmedgene',
#    'params': {'fields': 'related_to'},
#    'request_body': {'body': {'q': '{inputs[0]}', 'scopes': 'umls'}},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['disease',
#     'annotation',
#     'query',
#     'translator',
#     'biothings',
#     'semmed'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'UMLS',
#    'input_type': 'Gene',
#    'output_id': 'UMLS',
#    'output_type': 'ChemicalSubstance',
#    'predicate': 'related_to',
#    'source': 'SEMMED',
#    'api_name': 'SEMMED Gene API',
#    'smartapi': {'id': '81955d376a10505c1c69cd06dbda3047',
#     'meta': {'ETag': 'f94053bc78b3c2f0b97f7afd52d7de2fe083b655e56a53090ad73e12be83673b',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-05-27T16:53:40.804575',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:05:25.590785',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/semmed/semmed_gene.yaml'}}},
#   'id': '62916b2ba9c966b10da8afd3d3b254296c744cbe5c53287577afa5da'},
#  {'inputs': [{'id': 'NCBIGene', 'semantic': 'Gene'}],
#   'outputs': [{'id': 'PUBCHEM', 'semantic': 'ChemicalSubstance'}],
#   'parameters': {'fields': 'association.context.disease.mondo,object.PUBCHEM,association.effect_size,association.pvalue',
#    'q': 'subject.NCBIGene:{inputs[0]}%20AND%20association.effect_size:<0%20AND%20association.pvalue:<0.05',
#    'size': '1000',
#    'sort': 'association.pvalue'},
#   'predicate': 'gene_has_variant_that_contributes_to_drug_response_association',
#   'response_mapping': {'gene_has_variant_that_contributes_to_drug_response_association': {'PUBCHEM': 'hits.object.PUBCHEM',
#     'disease_context': 'hits.association.context.disease.mondo',
#     'effect_size': 'hits.association.effect_size',
#     'pvalue': 'hits.association.pvalue'}},
#   'source': 'Multiomics Provider',
#   'supportBatch': False,
#   'query_operation': {'server': 'https://biothings.ncats.io/drug_response_kp',
#    'params': {'fields': 'association.context.disease.mondo,object.PUBCHEM,association.effect_size,association.pvalue',
#     'q': 'subject.NCBIGene:{inputs[0]}%20AND%20association.effect_size:<0%20AND%20association.pvalue:<0.05',
#     'size': '1000',
#     'sort': 'association.pvalue'},
#    'request_body': None,
#    'path': '/query',
#    'path_params': [],
#    'method': 'get',
#    'tags': ['gene',
#     'disease',
#     'chemical',
#     'association',
#     'annotation',
#     'query',
#     'translator',
#     'biothings',
#     'biothings_graph'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'NCBIGene',
#    'input_type': 'Gene',
#    'output_id': 'PUBCHEM',
#    'output_type': 'ChemicalSubstance',
#    'predicate': 'gene_has_variant_that_contributes_to_drug_response_association',
#    'source': 'Multiomics Provider',
#    'api_name': 'Drug Response KP API',
#    'smartapi': {'id': 'adf20dd6ff23dfe18e8e012bde686e31',
#     'meta': {'ETag': '1b11ced56a11abc222c75a20398e28e778ee77b7674e769230aa364656b5762b',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-09-11T00:02:27.304690',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:05:58.059298',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/drug_response_kp/smartapi.yaml'}}},
#   'id': '6e278f9568db777ffcedad5618f00a203cf4becba5523e7f5ce9a6db'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'NCBIGene', 'semantic': 'Gene'}],
#   'outputs': [{'id': 'CHEMBL.COMPOUND', 'semantic': 'ChemicalSubstance'}],
#   'parameters': {'fields': 'object.CHEMBL_COMPOUND,association.provided_by,association.pubmed',
#    'size': 1000},
#   'predicate': 'physically_interacts_with',
#   'requestBody': {'body': {'q': '{inputs[0]}', 'scopes': 'subject.NCBIGene'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'physically_interacts_with': {'CHEMBL.COMPOUND': 'object.CHEMBL_COMPOUND',
#     'pubmed': 'association.pubmed',
#     'source': 'association.provided_by'}},
#   'source': 'DGIdb',
#   'supportBatch': 'ture',
#   'query_operation': {'server': 'https://biothings.ncats.io/dgidb',
#    'params': {'fields': 'object.CHEMBL_COMPOUND,association.provided_by,association.pubmed',
#     'size': 1000},
#    'request_body': {'body': {'q': '{inputs[0]}', 'scopes': 'subject.NCBIGene'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['gene',
#     'chemical',
#     'association',
#     'annotation',
#     'query',
#     'translator',
#     'biothings',
#     'biothings_graph'],
#    'supportBatch': 'ture',
#    'inputSeparator': ','},
#   'association': {'input_id': 'NCBIGene',
#    'input_type': 'Gene',
#    'output_id': 'CHEMBL.COMPOUND',
#    'output_type': 'ChemicalSubstance',
#    'predicate': 'physically_interacts_with',
#    'source': 'DGIdb',
#    'api_name': 'BioThings DGIdb API',
#    'smartapi': {'id': 'e3edd325c76f2992a111b43a907a4870',
#     'meta': {'ETag': '832ad7b7c0e20144712db5430227e191ea53c35820ba2b5a3732add8b337d97a',
#      'github_username': 'newgene',
#      'timestamp': '2020-09-09T00:02:20.664785',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:06:42.656448',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/dgidb/openapi.yml'}}},
#   'id': '52f3c4a0d8e538ea1ee2641e3335a02802ab71ac49d878968104c630'}]

# %% [markdown]
# ## Find Meta-KG operations that converys Gene->Metabolize->ChemicalSubstance

# %%
kg.filter({"input_type": "Gene", "output_type": "ChemicalSubstance", "predicate": "metabolize"})
# Out:
# [{'inputSeparator': ',',
#   'inputs': [{'id': 'SYMBOL', 'semantic': 'Gene'}],
#   'outputs': [{'id': 'DRUGBANK', 'semantic': 'ChemicalSubstance'}],
#   'parameters': {'fields': 'drugbank.id', 'size': '250'},
#   'predicate': 'metabolize',
#   'requestBody': {'body': {'q': '{inputs[0]}',
#     'scopes': 'drugbank.enzymes.gene_name'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'metabolize': {'DRUGBANK': 'drugbank.id'}},
#   'source': 'drugbank',
#   'supportBatch': True,
#   'query_operation': {'server': 'https://mychem.info/v1',
#    'params': {'fields': 'drugbank.id', 'size': '250'},
#    'request_body': {'body': {'q': '{inputs[0]}',
#      'scopes': 'drugbank.enzymes.gene_name'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['chemical',
#     'drug',
#     'annotation',
#     'query',
#     'translator',
#     'biothings'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'SYMBOL',
#    'input_type': 'Gene',
#    'output_id': 'DRUGBANK',
#    'output_type': 'ChemicalSubstance',
#    'predicate': 'metabolize',
#    'source': 'drugbank',
#    'api_name': 'MyChem.info API',
#    'smartapi': {'id': '8f08d1446e0bb9c2b323713ce83e2bd3',
#     'meta': {'ETag': '846f7a462e065abd3b97830b42c653e02c2e68141e64bf124cf6cc0d74176535',
#      'github_username': 'newgene',
#      'slug': 'mychem',
#      'timestamp': '2020-05-28T00:00:39.113364',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:04:35.065884',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/mychem.info/openapi_full.yml'}}},
#   'id': 'a67b7d970c49ef7f495375dab9af17995a0283416b2e5506df98e8ab'}]

# %% [markdown]
# ## Filter for Knowledge Graph Operations supported by MyChem.info as API source

# %%
kg.filter({"api_name": "MyChem.info API"})
# Out:
# [{'inputSeparator': ',',
#   'inputs': [{'id': 'DRUGBANK', 'semantic': 'ChemicalSubstance'}],
#   'outputs': [{'id': 'SYMBOL', 'semantic': 'Gene'}],
#   'parameters': {'fields': 'drugbank.enzymes'},
#   'predicate': 'metabolic_processing_affected_by',
#   'requestBody': {'body': {'q': '{inputs[0]}', 'scopes': 'drugbank.id'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'metabolic_processing_affected_by': {'SYMBOL': 'drugbank.enzymes.gene_name',
#     'action': 'drugbank.enzymes.actions',
#     'function': 'drugbank.enzymes.general_function',
#     'name': 'drugbank.enzymes.name'}},
#   'source': 'drugbank',
#   'supportBatch': True,
#   'query_operation': {'server': 'https://mychem.info/v1',
#    'params': {'fields': 'drugbank.enzymes'},
#    'request_body': {'body': {'q': '{inputs[0]}', 'scopes': 'drugbank.id'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['chemical',
#     'drug',
#     'annotation',
#     'query',
#     'translator',
#     'biothings'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'DRUGBANK',
#    'input_type': 'ChemicalSubstance',
#    'output_id': 'SYMBOL',
#    'output_type': 'Gene',
#    'predicate': 'metabolic_processing_affected_by',
#    'source': 'drugbank',
#    'api_name': 'MyChem.info API',
#    'smartapi': {'id': '8f08d1446e0bb9c2b323713ce83e2bd3',
#     'meta': {'ETag': '846f7a462e065abd3b97830b42c653e02c2e68141e64bf124cf6cc0d74176535',
#      'github_username': 'newgene',
#      'slug': 'mychem',
#      'timestamp': '2020-05-28T00:00:39.113364',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:04:35.065884',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/mychem.info/openapi_full.yml'}}},
#   'id': '4fde0b05729ea187318248c20c8dda79eb9f845c598e5728023b1465'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'DRUGBANK', 'semantic': 'ChemicalSubstance'}],
#   'outputs': [{'id': 'SYMBOL', 'semantic': 'Gene'}],
#   'parameters': {'fields': 'drugbank.targets'},
#   'predicate': 'physically_interacts_with',
#   'requestBody': {'body': {'q': '{inputs[0]}', 'scopes': 'drugbank.id'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'physically_interacts_with': {'SYMBOL': 'drugbank.targets.gene_name',
#     'action': 'drugbank.targets.actions',
#     'function': 'drugbank.targets.general_function',
#     'name': 'drugbank.targets.name',
#     'pubmed': 'drugbank.targets.pmids'}},
#   'source': 'drugbank',
#   'supportBatch': True,
#   'query_operation': {'server': 'https://mychem.info/v1',
#    'params': {'fields': 'drugbank.targets'},
#    'request_body': {'body': {'q': '{inputs[0]}', 'scopes': 'drugbank.id'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['chemical',
#     'drug',
#     'annotation',
#     'query',
#     'translator',
#     'biothings'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'DRUGBANK',
#    'input_type': 'ChemicalSubstance',
#    'output_id': 'SYMBOL',
#    'output_type': 'Gene',
#    'predicate': 'physically_interacts_with',
#    'source': 'drugbank',
#    'api_name': 'MyChem.info API',
#    'smartapi': {'id': '8f08d1446e0bb9c2b323713ce83e2bd3',
#     'meta': {'ETag': '846f7a462e065abd3b97830b42c653e02c2e68141e64bf124cf6cc0d74176535',
#      'github_username': 'newgene',
#      'slug': 'mychem',
#      'timestamp': '2020-05-28T00:00:39.113364',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:04:35.065884',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/mychem.info/openapi_full.yml'}}},
#   'id': '2734fabc84bed1463f8eedcd7fbba6ea0eea7071df6498e6b12d1fc4'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'CHEMBL.COMPOUND', 'semantic': 'ChemicalSubstance'}],
#   'outputs': [{'id': 'SYMBOL', 'semantic': 'Gene'}],
#   'parameters': {'fields': 'drugcentral.bioactivity'},
#   'predicate': 'physically_interacts_with',
#   'requestBody': {'body': {'q': '{inputs[0]}',
#     'scopes': 'chembl.molecule_chembl_id'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'physically_interacts_with': {'SYMBOL': 'drugcentral.bioactivity.uniprot.gene_symbol',
#     'action': 'drugcentral.bioactivity.action_type',
#     'name': 'drugcentral.bioactivity.target_name'}},
#   'source': 'drugcentral',
#   'supportBatch': True,
#   'query_operation': {'server': 'https://mychem.info/v1',
#    'params': {'fields': 'drugcentral.bioactivity'},
#    'request_body': {'body': {'q': '{inputs[0]}',
#      'scopes': 'chembl.molecule_chembl_id'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['chemical',
#     'drug',
#     'annotation',
#     'query',
#     'translator',
#     'biothings'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'CHEMBL.COMPOUND',
#    'input_type': 'ChemicalSubstance',
#    'output_id': 'SYMBOL',
#    'output_type': 'Gene',
#    'predicate': 'physically_interacts_with',
#    'source': 'drugcentral',
#    'api_name': 'MyChem.info API',
#    'smartapi': {'id': '8f08d1446e0bb9c2b323713ce83e2bd3',
#     'meta': {'ETag': '846f7a462e065abd3b97830b42c653e02c2e68141e64bf124cf6cc0d74176535',
#      'github_username': 'newgene',
#      'slug': 'mychem',
#      'timestamp': '2020-05-28T00:00:39.113364',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:04:35.065884',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/mychem.info/openapi_full.yml'}}},
#   'id': '48cbec5848ed162349d08950bc99c7cdda2a24572a2f8dad317c7313'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'CHEMBL.COMPOUND', 'semantic': 'ChemicalSubstance'}],
#   'outputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#   'parameters': {'fields': 'drugcentral.drug_use.indication'},
#   'predicate': 'treats',
#   'requestBody': {'body': {'q': '{inputs[0]}',
#     'scopes': 'chembl.molecule_chembl_id'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'treats': {'SNOMED': 'drugcentral.drug_use.indication.snomed_concept_id',
#     'UMLS': 'drugcentral.drug_use.indication.umls_cui',
#     'name': 'drugcentral.drug_use.indication.concept_name'}},
#   'source': 'drugcentral',
#   'supportBatch': True,
#   'query_operation': {'server': 'https://mychem.info/v1',
#    'params': {'fields': 'drugcentral.drug_use.indication'},
#    'request_body': {'body': {'q': '{inputs[0]}',
#      'scopes': 'chembl.molecule_chembl_id'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['chemical',
#     'drug',
#     'annotation',
#     'query',
#     'translator',
#     'biothings'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'CHEMBL.COMPOUND',
#    'input_type': 'ChemicalSubstance',
#    'output_id': 'UMLS',
#    'output_type': 'Disease',
#    'predicate': 'treats',
#    'source': 'drugcentral',
#    'api_name': 'MyChem.info API',
#    'smartapi': {'id': '8f08d1446e0bb9c2b323713ce83e2bd3',
#     'meta': {'ETag': '846f7a462e065abd3b97830b42c653e02c2e68141e64bf124cf6cc0d74176535',
#      'github_username': 'newgene',
#      'slug': 'mychem',
#      'timestamp': '2020-05-28T00:00:39.113364',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:04:35.065884',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/mychem.info/openapi_full.yml'}}},
#   'id': '956771c10325b8fdd0b1ed2aafef930a643980fdcba8959d043448ba'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'CHEMBL.COMPOUND', 'semantic': 'ChemicalSubstance'}],
#   'outputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#   'parameters': {'fields': 'drugcentral.drug_use.contraindication'},
#   'predicate': 'contraindication',
#   'requestBody': {'body': {'q': '{inputs[0]}',
#     'scopes': 'chembl.molecule_chembl_id'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'contraindication': {'SNOMED': 'drugcentral.drug_use.contraindication.snomed_concept_id',
#     'UMLS': 'drugcentral.drug_use.contraindication.umls_cui',
#     'name': 'drugcentral.drug_use.contraindication.concept_name'}},
#   'source': 'drugcentral',
#   'supportBatch': True,
#   'query_operation': {'server': 'https://mychem.info/v1',
#    'params': {'fields': 'drugcentral.drug_use.contraindication'},
#    'request_body': {'body': {'q': '{inputs[0]}',
#      'scopes': 'chembl.molecule_chembl_id'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['chemical',
#     'drug',
#     'annotation',
#     'query',
#     'translator',
#     'biothings'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'CHEMBL.COMPOUND',
#    'input_type': 'ChemicalSubstance',
#    'output_id': 'UMLS',
#    'output_type': 'Disease',
#    'predicate': 'contraindication',
#    'source': 'drugcentral',
#    'api_name': 'MyChem.info API',
#    'smartapi': {'id': '8f08d1446e0bb9c2b323713ce83e2bd3',
#     'meta': {'ETag': '846f7a462e065abd3b97830b42c653e02c2e68141e64bf124cf6cc0d74176535',
#      'github_username': 'newgene',
#      'slug': 'mychem',
#      'timestamp': '2020-05-28T00:00:39.113364',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:04:35.065884',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/mychem.info/openapi_full.yml'}}},
#   'id': 'f7abaaa996d6c1c827fbf1a8a1276b34d6238b0782ee1d7a039dc1a6'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'SYMBOL', 'semantic': 'Gene'}],
#   'outputs': [{'id': 'DRUGBANK', 'semantic': 'ChemicalSubstance'}],
#   'parameters': {'fields': 'drugbank.id', 'size': '250'},
#   'predicate': 'metabolize',
#   'requestBody': {'body': {'q': '{inputs[0]}',
#     'scopes': 'drugbank.enzymes.gene_name'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'metabolize': {'DRUGBANK': 'drugbank.id'}},
#   'source': 'drugbank',
#   'supportBatch': True,
#   'query_operation': {'server': 'https://mychem.info/v1',
#    'params': {'fields': 'drugbank.id', 'size': '250'},
#    'request_body': {'body': {'q': '{inputs[0]}',
#      'scopes': 'drugbank.enzymes.gene_name'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['chemical',
#     'drug',
#     'annotation',
#     'query',
#     'translator',
#     'biothings'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'SYMBOL',
#    'input_type': 'Gene',
#    'output_id': 'DRUGBANK',
#    'output_type': 'ChemicalSubstance',
#    'predicate': 'metabolize',
#    'source': 'drugbank',
#    'api_name': 'MyChem.info API',
#    'smartapi': {'id': '8f08d1446e0bb9c2b323713ce83e2bd3',
#     'meta': {'ETag': '846f7a462e065abd3b97830b42c653e02c2e68141e64bf124cf6cc0d74176535',
#      'github_username': 'newgene',
#      'slug': 'mychem',
#      'timestamp': '2020-05-28T00:00:39.113364',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:04:35.065884',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/mychem.info/openapi_full.yml'}}},
#   'id': 'a67b7d970c49ef7f495375dab9af17995a0283416b2e5506df98e8ab'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'SYMBOL', 'semantic': 'Gene'}],
#   'outputs': [{'id': 'DRUGBANK', 'semantic': 'ChemicalSubstance'}],
#   'parameters': {'fields': 'drugbank.id', 'size': '250'},
#   'predicate': 'physically_interacts_with',
#   'requestBody': {'body': {'q': '{inputs[0]}',
#     'scopes': 'drugbank.targets.gene_name'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'physically_interacts_with': {'DRUGBANK': 'drugbank.id'}},
#   'source': 'drugbank',
#   'supportBatch': True,
#   'query_operation': {'server': 'https://mychem.info/v1',
#    'params': {'fields': 'drugbank.id', 'size': '250'},
#    'request_body': {'body': {'q': '{inputs[0]}',
#      'scopes': 'drugbank.targets.gene_name'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['chemical',
#     'drug',
#     'annotation',
#     'query',
#     'translator',
#     'biothings'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'SYMBOL',
#    'input_type': 'Gene',
#    'output_id': 'DRUGBANK',
#    'output_type': 'ChemicalSubstance',
#    'predicate': 'physically_interacts_with',
#    'source': 'drugbank',
#    'api_name': 'MyChem.info API',
#    'smartapi': {'id': '8f08d1446e0bb9c2b323713ce83e2bd3',
#     'meta': {'ETag': '846f7a462e065abd3b97830b42c653e02c2e68141e64bf124cf6cc0d74176535',
#      'github_username': 'newgene',
#      'slug': 'mychem',
#      'timestamp': '2020-05-28T00:00:39.113364',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:04:35.065884',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/mychem.info/openapi_full.yml'}}},
#   'id': '7322b5c101c8c233e8a23d970de6b75715ed682afa07ed5557565e6e'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'SYMBOL', 'semantic': 'Gene'}],
#   'outputs': [{'id': 'CHEMBL.COMPOUND', 'semantic': 'ChemicalSubstance'}],
#   'parameters': {'fields': 'chembl.molecule_chembl_id', 'size': '250'},
#   'predicate': 'physically_interacts_with',
#   'requestBody': {'body': {'q': '{inputs[0]}',
#     'scopes': 'drugcentral.bioactivity.uniprot.gene_symbol'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'physically_interacts_with': {'CHEMBL.COMPOUND': 'chembl.molecule_chembl_id'}},
#   'source': 'drugcentral',
#   'supportBatch': True,
#   'query_operation': {'server': 'https://mychem.info/v1',
#    'params': {'fields': 'chembl.molecule_chembl_id', 'size': '250'},
#    'request_body': {'body': {'q': '{inputs[0]}',
#      'scopes': 'drugcentral.bioactivity.uniprot.gene_symbol'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['chemical',
#     'drug',
#     'annotation',
#     'query',
#     'translator',
#     'biothings'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'SYMBOL',
#    'input_type': 'Gene',
#    'output_id': 'CHEMBL.COMPOUND',
#    'output_type': 'ChemicalSubstance',
#    'predicate': 'physically_interacts_with',
#    'source': 'drugcentral',
#    'api_name': 'MyChem.info API',
#    'smartapi': {'id': '8f08d1446e0bb9c2b323713ce83e2bd3',
#     'meta': {'ETag': '846f7a462e065abd3b97830b42c653e02c2e68141e64bf124cf6cc0d74176535',
#      'github_username': 'newgene',
#      'slug': 'mychem',
#      'timestamp': '2020-05-28T00:00:39.113364',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:04:35.065884',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/mychem.info/openapi_full.yml'}}},
#   'id': 'dceab01f96a7703aabf77ed7e07de4afcd6155aa50747f6e0ac4899e'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#   'outputs': [{'id': 'CHEMBL.COMPOUND', 'semantic': 'ChemicalSubstance'}],
#   'parameters': {'fields': 'chembl.molecule_chembl_id', 'size': '250'},
#   'predicate': 'treated_by',
#   'requestBody': {'body': {'q': '{inputs[0]}',
#     'scopes': 'drugcentral.drug_use.indication.umls_cui'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'treated_by': {'CHEMBL.COMPOUND': 'chembl.molecule_chembl_id'}},
#   'source': 'drugcentral',
#   'supportBatch': True,
#   'query_operation': {'server': 'https://mychem.info/v1',
#    'params': {'fields': 'chembl.molecule_chembl_id', 'size': '250'},
#    'request_body': {'body': {'q': '{inputs[0]}',
#      'scopes': 'drugcentral.drug_use.indication.umls_cui'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['chemical',
#     'drug',
#     'annotation',
#     'query',
#     'translator',
#     'biothings'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'UMLS',
#    'input_type': 'Disease',
#    'output_id': 'CHEMBL.COMPOUND',
#    'output_type': 'ChemicalSubstance',
#    'predicate': 'treated_by',
#    'source': 'drugcentral',
#    'api_name': 'MyChem.info API',
#    'smartapi': {'id': '8f08d1446e0bb9c2b323713ce83e2bd3',
#     'meta': {'ETag': '846f7a462e065abd3b97830b42c653e02c2e68141e64bf124cf6cc0d74176535',
#      'github_username': 'newgene',
#      'slug': 'mychem',
#      'timestamp': '2020-05-28T00:00:39.113364',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:04:35.065884',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/mychem.info/openapi_full.yml'}}},
#   'id': '3ee7f66192a7957cf60b68d9b98a9874d86e0e1740b6f649c9f9545d'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#   'outputs': [{'id': 'CHEMBL.COMPOUND', 'semantic': 'ChemicalSubstance'}],
#   'parameters': {'fields': 'chembl.molecule_chembl_id', 'size': '250'},
#   'predicate': 'contraindicated_by',
#   'requestBody': {'body': {'q': '{inputs[0]}',
#     'scopes': 'drugcentral.drug_use.contraindication.umls_cui'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'contraindicated_by': {'CHEMBL.COMPOUND': 'chembl.molecule_chembl_id'}},
#   'source': 'drugcentral',
#   'supportBatch': True,
#   'query_operation': {'server': 'https://mychem.info/v1',
#    'params': {'fields': 'chembl.molecule_chembl_id', 'size': '250'},
#    'request_body': {'body': {'q': '{inputs[0]}',
#      'scopes': 'drugcentral.drug_use.contraindication.umls_cui'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['chemical',
#     'drug',
#     'annotation',
#     'query',
#     'translator',
#     'biothings'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'UMLS',
#    'input_type': 'Disease',
#    'output_id': 'CHEMBL.COMPOUND',
#    'output_type': 'ChemicalSubstance',
#    'predicate': 'contraindicated_by',
#    'source': 'drugcentral',
#    'api_name': 'MyChem.info API',
#    'smartapi': {'id': '8f08d1446e0bb9c2b323713ce83e2bd3',
#     'meta': {'ETag': '846f7a462e065abd3b97830b42c653e02c2e68141e64bf124cf6cc0d74176535',
#      'github_username': 'newgene',
#      'slug': 'mychem',
#      'timestamp': '2020-05-28T00:00:39.113364',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:04:35.065884',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/mychem.info/openapi_full.yml'}}},
#   'id': '0f52fdc1d9748ae7976b9aeeccfd30de94176a861fb6a5fe1878f7b2'}]

# %% [markdown]
# ## Filter for API operations with drugbank as data source

# %%
kg.filter({"source": "drugbank"})
# Out:
# [{'inputSeparator': ',',
#   'inputs': [{'id': 'DRUGBANK', 'semantic': 'ChemicalSubstance'}],
#   'outputs': [{'id': 'SYMBOL', 'semantic': 'Gene'}],
#   'parameters': {'fields': 'drugbank.enzymes'},
#   'predicate': 'metabolic_processing_affected_by',
#   'requestBody': {'body': {'q': '{inputs[0]}', 'scopes': 'drugbank.id'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'metabolic_processing_affected_by': {'SYMBOL': 'drugbank.enzymes.gene_name',
#     'action': 'drugbank.enzymes.actions',
#     'function': 'drugbank.enzymes.general_function',
#     'name': 'drugbank.enzymes.name'}},
#   'source': 'drugbank',
#   'supportBatch': True,
#   'query_operation': {'server': 'https://mychem.info/v1',
#    'params': {'fields': 'drugbank.enzymes'},
#    'request_body': {'body': {'q': '{inputs[0]}', 'scopes': 'drugbank.id'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['chemical',
#     'drug',
#     'annotation',
#     'query',
#     'translator',
#     'biothings'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'DRUGBANK',
#    'input_type': 'ChemicalSubstance',
#    'output_id': 'SYMBOL',
#    'output_type': 'Gene',
#    'predicate': 'metabolic_processing_affected_by',
#    'source': 'drugbank',
#    'api_name': 'MyChem.info API',
#    'smartapi': {'id': '8f08d1446e0bb9c2b323713ce83e2bd3',
#     'meta': {'ETag': '846f7a462e065abd3b97830b42c653e02c2e68141e64bf124cf6cc0d74176535',
#      'github_username': 'newgene',
#      'slug': 'mychem',
#      'timestamp': '2020-05-28T00:00:39.113364',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:04:35.065884',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/mychem.info/openapi_full.yml'}}},
#   'id': '4fde0b05729ea187318248c20c8dda79eb9f845c598e5728023b1465'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'DRUGBANK', 'semantic': 'ChemicalSubstance'}],
#   'outputs': [{'id': 'SYMBOL', 'semantic': 'Gene'}],
#   'parameters': {'fields': 'drugbank.targets'},
#   'predicate': 'physically_interacts_with',
#   'requestBody': {'body': {'q': '{inputs[0]}', 'scopes': 'drugbank.id'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'physically_interacts_with': {'SYMBOL': 'drugbank.targets.gene_name',
#     'action': 'drugbank.targets.actions',
#     'function': 'drugbank.targets.general_function',
#     'name': 'drugbank.targets.name',
#     'pubmed': 'drugbank.targets.pmids'}},
#   'source': 'drugbank',
#   'supportBatch': True,
#   'query_operation': {'server': 'https://mychem.info/v1',
#    'params': {'fields': 'drugbank.targets'},
#    'request_body': {'body': {'q': '{inputs[0]}', 'scopes': 'drugbank.id'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['chemical',
#     'drug',
#     'annotation',
#     'query',
#     'translator',
#     'biothings'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'DRUGBANK',
#    'input_type': 'ChemicalSubstance',
#    'output_id': 'SYMBOL',
#    'output_type': 'Gene',
#    'predicate': 'physically_interacts_with',
#    'source': 'drugbank',
#    'api_name': 'MyChem.info API',
#    'smartapi': {'id': '8f08d1446e0bb9c2b323713ce83e2bd3',
#     'meta': {'ETag': '846f7a462e065abd3b97830b42c653e02c2e68141e64bf124cf6cc0d74176535',
#      'github_username': 'newgene',
#      'slug': 'mychem',
#      'timestamp': '2020-05-28T00:00:39.113364',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:04:35.065884',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/mychem.info/openapi_full.yml'}}},
#   'id': '2734fabc84bed1463f8eedcd7fbba6ea0eea7071df6498e6b12d1fc4'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'SYMBOL', 'semantic': 'Gene'}],
#   'outputs': [{'id': 'DRUGBANK', 'semantic': 'ChemicalSubstance'}],
#   'parameters': {'fields': 'drugbank.id', 'size': '250'},
#   'predicate': 'metabolize',
#   'requestBody': {'body': {'q': '{inputs[0]}',
#     'scopes': 'drugbank.enzymes.gene_name'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'metabolize': {'DRUGBANK': 'drugbank.id'}},
#   'source': 'drugbank',
#   'supportBatch': True,
#   'query_operation': {'server': 'https://mychem.info/v1',
#    'params': {'fields': 'drugbank.id', 'size': '250'},
#    'request_body': {'body': {'q': '{inputs[0]}',
#      'scopes': 'drugbank.enzymes.gene_name'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['chemical',
#     'drug',
#     'annotation',
#     'query',
#     'translator',
#     'biothings'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'SYMBOL',
#    'input_type': 'Gene',
#    'output_id': 'DRUGBANK',
#    'output_type': 'ChemicalSubstance',
#    'predicate': 'metabolize',
#    'source': 'drugbank',
#    'api_name': 'MyChem.info API',
#    'smartapi': {'id': '8f08d1446e0bb9c2b323713ce83e2bd3',
#     'meta': {'ETag': '846f7a462e065abd3b97830b42c653e02c2e68141e64bf124cf6cc0d74176535',
#      'github_username': 'newgene',
#      'slug': 'mychem',
#      'timestamp': '2020-05-28T00:00:39.113364',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:04:35.065884',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/mychem.info/openapi_full.yml'}}},
#   'id': 'a67b7d970c49ef7f495375dab9af17995a0283416b2e5506df98e8ab'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'SYMBOL', 'semantic': 'Gene'}],
#   'outputs': [{'id': 'DRUGBANK', 'semantic': 'ChemicalSubstance'}],
#   'parameters': {'fields': 'drugbank.id', 'size': '250'},
#   'predicate': 'physically_interacts_with',
#   'requestBody': {'body': {'q': '{inputs[0]}',
#     'scopes': 'drugbank.targets.gene_name'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'physically_interacts_with': {'DRUGBANK': 'drugbank.id'}},
#   'source': 'drugbank',
#   'supportBatch': True,
#   'query_operation': {'server': 'https://mychem.info/v1',
#    'params': {'fields': 'drugbank.id', 'size': '250'},
#    'request_body': {'body': {'q': '{inputs[0]}',
#      'scopes': 'drugbank.targets.gene_name'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['chemical',
#     'drug',
#     'annotation',
#     'query',
#     'translator',
#     'biothings'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'SYMBOL',
#    'input_type': 'Gene',
#    'output_id': 'DRUGBANK',
#    'output_type': 'ChemicalSubstance',
#    'predicate': 'physically_interacts_with',
#    'source': 'drugbank',
#    'api_name': 'MyChem.info API',
#    'smartapi': {'id': '8f08d1446e0bb9c2b323713ce83e2bd3',
#     'meta': {'ETag': '846f7a462e065abd3b97830b42c653e02c2e68141e64bf124cf6cc0d74176535',
#      'github_username': 'newgene',
#      'slug': 'mychem',
#      'timestamp': '2020-05-28T00:00:39.113364',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-09-24T00:04:35.065884',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/mychem.info/openapi_full.yml'}}},
#   'id': '7322b5c101c8c233e8a23d970de6b75715ed682afa07ed5557565e6e'}]
