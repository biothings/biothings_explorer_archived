# %%
# import modules from biothings_explorer
from biothings_explorer.hint import Hint
from biothings_explorer.user_query_dispatcher import FindConnection

# %% [markdown]
# **Hint** module: Find corresponding bio-entity representation used in BioThings Explorer based on user input (could be any database IDs, symbols, names)
#
# **FindConnection** module: Find intermediate bio-entities which connects user specified input and output

# %% [markdown]
# ## Step 1: Find representation of "asthma" and "imatinib" in BTE

# %%
ht = Hint()
# find all potential representations of asthma
asthma_hint = ht.query("asthma")
# select the correct representation of asthma
asthma = asthma_hint['DiseaseOrPhenotypicFeature'][0]
asthma
# Out:
# {'mondo': 'MONDO:0004979',
#  'doid': 'DOID:2841',
#  'hp': 'HP:0002099',
#  'umls': 'C0004096',
#  'mesh': 'D001249',
#  'name': 'asthma',
#  'display': 'mondo(MONDO:0004979) doid(DOID:2841) hp(HP:0002099) umls(C0004096) mesh(D001249) name(asthma) ',
#  'type': 'DiseaseOrPhenotypicFeature',
#  'primary': {'identifier': 'mondo',
#   'cls': 'DiseaseOrPhenotypicFeature',
#   'value': 'MONDO:0004979'}}

# %%
# find all potential representations of imatinib
imatinib_hint = ht.query("imatinib")
# select the correct representation of imatinib
imatinib = imatinib_hint['ChemicalSubstance'][0]
imatinib
# Out:
# {'chembl': 'CHEMBL941',
#  'drugbank': 'DB00619',
#  'name': 'IMATINIB',
#  'pubchem': 5291,
#  'umls': 'C0935989',
#  'mesh': 'D000068877',
#  'display': 'chembl(CHEMBL941) drugbank(DB00619) name(IMATINIB) pubchem(5291) umls(C0935989) mesh(D000068877) ',
#  'type': 'ChemicalSubstance',
#  'primary': {'identifier': 'chembl',
#   'cls': 'ChemicalSubstance',
#   'value': 'CHEMBL941'}}

# %% [markdown]
# ## Step 2: Find intermediate nodes connecting imatinib and asthma

# %%
help(FindConnection.__init__)
# Out:
# Help on function __init__ in module biothings_explorer.user_query_dispatcher:
#
# __init__(self, input_obj, output_obj, intermediate_nodes, registry=None)
#     Find relationships in the Knowledge Graph between an Input Object and an Output Object.
#
#     params
#     ------
#     input_obj (required): must be an object returned from Hint corresponding to a specific biomedical entity.
#                           Examples:
#             Hint().query("Fanconi anemia")['DiseaseOrPhenotypicFeature'][0]
#             Hint().query("acetaminophen")['ChemicalSubstance'][0]
#
#     output_obj (required): must EITHER be an object returned from Hint corresponding to a specific biomedical
#                            entity, OR be a string or list of strings corresponding to Biolink Entity classes.
#                            Examples:
#             Hint().query("acetaminophen")['ChemicalSubstance'][0]
#             'Gene'
#             ['Gene','ChemicalSubstance']
#
#     intermediate_nodes (required): the semantic type(s) of the intermediate node(s).  Examples:
#             None                         : no intermediate node, find direct connections only
#             []                           : no intermediate node, find direct connections only
#             ['BiologicalEntity']         : one intermediate node of any semantic type
#             ['Gene']                     : one intermediate node that must be a Gene
#             [('Gene','Pathway')]         : one intermediate node that must be a Gene or a Pathway
#             ['Gene','Pathway']           : two intermediate nodes, first must be a Gene, second must be a Pathway.
#             ['Gene',('Pathway','Gene')]  : two intermediate nodes, first must be a Gene, second must be a Pathway or Gene.
#                                               **NOTE**: queries with more than one intermediate node are currently not supported

# %%
fc = FindConnection(input_obj=asthma, output_obj=imatinib, intermediate_nodes=['Gene'])

# %%
# set verbose=True will display all steps which BTE takes to find the connection
fc.connect(verbose=True)
# Out:
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'asthma' and 'IMATINIB'. Paths will have 1 intermediate node.
#
# Intermediate node #1 will have these type constraints: Gene
#
#
# ==========
# ========== QUERY #1 -- fetch all Gene entities linked to 'asthma' ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because asthma is of type 'DiseaseOrPhenotypicFeature', BTE will query our meta-KG for APIs that can take 'DiseaseOrPhenotypicFeature' as input
#
# BTE found 3 apis:
#
# API 1. biolink_disease2gene(1 API call)
# API 2. semmeddisease(1 API call)
# API 3. mydisease.info(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 3.1: http://mydisease.info/v1/query (POST "q=C0004096&scopes=mondo.xrefs.umls,disgenet.xrefs.umls&fields=disgenet.genes_related_to_disease&species=human&size=100")
# API 2.1: http://pending.biothings.io/semmed/query (POST "q=C0004096&scopes=umls&fields=AFFECTS.gene,AFFECTS_reverse.protein,CAUSES_reverse.gene,AFFECTS_reverse.gene,AFFECTS.protein,ASSOCIATED_WITH.gene&species=human&size=100")
# API 1.1: https://api.monarchinitiative.org/api/bioentity/disease/MONDO:0004979/genes?rows=100
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 biolink_disease2gene: 100 hits
# API 3.1 mydisease.info: 99 hits
# API 2.1 semmeddisease: 550 hits
#
# After id-to-object translation, BTE retrieved 567 unique objects.
#
#
# ==========
# ========== QUERY #2 -- fetch all Gene entities linked to 'IMATINIB' ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because IMATINIB is of type 'ChemicalSubstance', BTE will query our meta-KG for APIs that can take 'ChemicalSubstance' as input
#
# BTE found 3 apis:
#
# API 1. semmedgene(6 API calls)
# API 2. mychem.info(2 API calls)
# API 3. dgidb_chemical2gene(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 2.2: http://mychem.info/v1/query (POST "q=DB00619&scopes=drugbank.id&fields=drugbank.enzymes,drugbank.targets&species=human&size=100")
# API 2.1: http://mychem.info/v1/query (POST "q=CHEMBL941&scopes=chembl.molecule_chembl_id&fields=drugcentral.bioactivity&species=human&size=100")
# API 1.4: https://pending.biothings.io/semmedgene/query (POST "q=C0935989&scopes=associated_with_reverse.chemical_substance.umls&fields=umls&species=human&size=100")
# API 1.1: https://pending.biothings.io/semmedgene/query (POST "q=C0935989&scopes=affects.chemical_substance.umls&fields=umls&species=human&size=100")
# API 1.3: https://pending.biothings.io/semmedgene/query (POST "q=C0935989&scopes=associated_with.chemical_substance.umls&fields=umls&species=human&size=100")
# API 1.2: https://pending.biothings.io/semmedgene/query (POST "q=C0935989&scopes=affects_reverse.chemical_substance.umls&fields=umls&species=human&size=100")
# API 3.1: http://www.dgidb.org/api/v2/interactions.json?drugs=CHEMBL941
# API 1.6: https://pending.biothings.io/semmedgene/query (POST "q=C0935989&scopes=interacts_with_reverse.chemical_substance.umls&fields=umls&species=human&size=100")
# API 1.5: https://pending.biothings.io/semmedgene/query (POST "q=C0935989&scopes=interacts_with.chemical_substance.umls&fields=umls&species=human&size=100")
#
#
# ==== Step #3: Output normalization ====
#
# API 3.1 dgidb_chemical2gene: 34 hits
# API 2.1 mychem.info: 77 hits
# API 2.2 mychem.info: 18 hits
# API 1.1 semmedgene: No hits
# API 1.2 semmedgene: No hits
# API 1.3 semmedgene: No hits
# API 1.4 semmedgene: No hits
# API 1.5 semmedgene: 100 hits
# API 1.6 semmedgene: 100 hits
#
# After id-to-object translation, BTE retrieved 245 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# BTE found 34 unique intermediate nodes connecting 'asthma' and 'IMATINIB'

# %% [markdown]
# ## Step 3: Display and Filter results

# %%
df = fc.display_table_view()

# %%
df
# Out:
#      input                  input_type           pred1 pred1_source  \
# 0   asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 1   asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 2   asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 3   asthma  DiseaseOrPhenotypicFeature  associatedWith      biolink
# 4   asthma  DiseaseOrPhenotypicFeature  associatedWith      biolink
# 5   asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 6   asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 7   asthma  DiseaseOrPhenotypicFeature  associatedWith       semmed
# 8   asthma  DiseaseOrPhenotypicFeature  associatedWith       semmed
# 9   asthma  DiseaseOrPhenotypicFeature  associatedWith       semmed
# 10  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 11  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 12  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 13  asthma  DiseaseOrPhenotypicFeature  associatedWith       semmed
# 14  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 15  asthma  DiseaseOrPhenotypicFeature  associatedWith       semmed
# 16  asthma  DiseaseOrPhenotypicFeature  associatedWith       semmed
# 17  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 18  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 19  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 20  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 21  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 22  asthma  DiseaseOrPhenotypicFeature  associatedWith     disgenet
# 23  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 24  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 25  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 26  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 27  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 28  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 29  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 30  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 31  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 32  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 33  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 34  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 35  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 36  asthma  DiseaseOrPhenotypicFeature  associatedWith       semmed
# 37  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 38  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 39  asthma  DiseaseOrPhenotypicFeature  associatedWith       semmed
# 40  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 41  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 42  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 43  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 44  asthma  DiseaseOrPhenotypicFeature  associatedWith       semmed
# 45  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 46  asthma  DiseaseOrPhenotypicFeature  associatedWith     disgenet
# 47  asthma  DiseaseOrPhenotypicFeature  associatedWith       semmed
# 48  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 49  asthma  DiseaseOrPhenotypicFeature  associatedWith     disgenet
# 50  asthma  DiseaseOrPhenotypicFeature  associatedWith       semmed
# 51  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 52  asthma  DiseaseOrPhenotypicFeature  associatedWith       semmed
# 53  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 54  asthma  DiseaseOrPhenotypicFeature  associatedWith       semmed
# 55  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 56  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 57  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 58  asthma  DiseaseOrPhenotypicFeature  associatedWith       semmed
# 59  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
#
#                pred1_api pred1_pubmed       node1_id node1_name node1_type  \
# 0          semmeddisease                  entrez:613        BCR       Gene
# 1          semmeddisease                  entrez:613        BCR       Gene
# 2          semmeddisease                  entrez:613        BCR       Gene
# 3   biolink_disease2gene                 entrez:4088      SMAD3       Gene
# 4   biolink_disease2gene                 entrez:4088      SMAD3       Gene
# 5          semmeddisease                 entrez:5154      PDGFA       Gene
# 6          semmeddisease                 entrez:5154      PDGFA       Gene
# 7          semmeddisease               umls:C0031727       None       Gene
# 8          semmeddisease               umls:C0031727       None       Gene
# 9          semmeddisease               umls:C1705325       None       Gene
# 10         semmeddisease               umls:C1705325       None       Gene
# 11         semmeddisease               umls:C1367471       None       Gene
# 12         semmeddisease               umls:C3540585       None       Gene
# 13         semmeddisease               umls:C1706005       None       Gene
# 14         semmeddisease               umls:C1706005       None       Gene
# 15         semmeddisease               umls:C1705556       None       Gene
# 16         semmeddisease               umls:C1705556       None       Gene
# 17         semmeddisease               umls:C1705556       None       Gene
# 18         semmeddisease               umls:C1705556       None       Gene
# 19         semmeddisease                 entrez:3932        LCK       Gene
# 20         semmeddisease                 entrez:3932        LCK       Gene
# 21         semmeddisease                 entrez:3932        LCK       Gene
# 22        mydisease.info         None    entrez:1080       CFTR       Gene
# 23         semmeddisease                 entrez:7852      CXCR4       Gene
# 24         semmeddisease                 entrez:7852      CXCR4       Gene
# 25         semmeddisease                 entrez:6850        SYK       Gene
# 26         semmeddisease               umls:C1706438       None       Gene
# 27         semmeddisease               umls:C1704799       None       Gene
# 28         semmeddisease               umls:C1704799       None       Gene
# 29         semmeddisease                  entrez:146     ADRA1D       Gene
# 30         semmeddisease                  entrez:146     ADRA1D       Gene
# 31         semmeddisease                  entrez:947       CD34       Gene
# 32         semmeddisease                  entrez:947       CD34       Gene
# 33         semmeddisease                  entrez:947       CD34       Gene
# 34         semmeddisease                  entrez:947       CD34       Gene
# 35         semmeddisease                 entrez:3439      IFNA1       Gene
# 36         semmeddisease               umls:C1335671       None       Gene
# 37         semmeddisease                  entrez:760        CA2       Gene
# 38         semmeddisease                 entrez:5290     PIK3CA       Gene
# 39         semmeddisease               umls:C0017337       None       Gene
# 40         semmeddisease               umls:C0017337       None       Gene
# 41         semmeddisease                 entrez:5805        PTS       Gene
# 42         semmeddisease                entrez:10899        JTB       Gene
# 43         semmeddisease                entrez:10899        JTB       Gene
# 44         semmeddisease               entrez:373156      GSTK1       Gene
# 45         semmeddisease               entrez:373156      GSTK1       Gene
# 46        mydisease.info         None    entrez:7422      VEGFA       Gene
# 47         semmeddisease                 entrez:7422      VEGFA       Gene
# 48         semmeddisease                 entrez:7422      VEGFA       Gene
# 49        mydisease.info         None    entrez:7124        TNF       Gene
# 50         semmeddisease                 entrez:7124        TNF       Gene
# 51         semmeddisease                 entrez:7124        TNF       Gene
# 52         semmeddisease               umls:C3714973       None       Gene
# 53         semmeddisease               umls:C3714973       None       Gene
# 54         semmeddisease               umls:C0538674       None       Gene
# 55         semmeddisease                 entrez:7076      TIMP1       Gene
# 56         semmeddisease                 entrez:7076      TIMP1       Gene
# 57         semmeddisease               umls:C3889436       None       Gene
# 58         semmeddisease               entrez:133482    SLCO6A1       Gene
# 59         semmeddisease               entrez:133482    SLCO6A1       Gene
#
#                        pred2 pred2_source            pred2_api pred2_pubmed  \
# 0                     target        dgidb  dgidb_chemical2gene         None
# 1   molecularlyInteractsWith   semmedgene           semmedgene         None
# 2   molecularlyInteractsWith   semmedgene           semmedgene         None
# 3   molecularlyInteractsWith   semmedgene           semmedgene         None
# 4   molecularlyInteractsWith   semmedgene           semmedgene         None
# 5   molecularlyInteractsWith   semmedgene           semmedgene         None
# 6   molecularlyInteractsWith   semmedgene           semmedgene         None
# 7   molecularlyInteractsWith   semmedgene           semmedgene         None
# 8   molecularlyInteractsWith   semmedgene           semmedgene         None
# 9   molecularlyInteractsWith   semmedgene           semmedgene         None
# 10  molecularlyInteractsWith   semmedgene           semmedgene         None
# 11  molecularlyInteractsWith   semmedgene           semmedgene         None
# 12  molecularlyInteractsWith   semmedgene           semmedgene         None
# 13  molecularlyInteractsWith   semmedgene           semmedgene         None
# 14  molecularlyInteractsWith   semmedgene           semmedgene         None
# 15  molecularlyInteractsWith   semmedgene           semmedgene         None
# 16  molecularlyInteractsWith   semmedgene           semmedgene         None
# 17  molecularlyInteractsWith   semmedgene           semmedgene         None
# 18  molecularlyInteractsWith   semmedgene           semmedgene         None
# 19                    target  drugcentral          mychem.info         None
# 20  molecularlyInteractsWith   semmedgene           semmedgene         None
# 21  molecularlyInteractsWith   semmedgene           semmedgene         None
# 22  molecularlyInteractsWith   semmedgene           semmedgene         None
# 23  molecularlyInteractsWith   semmedgene           semmedgene         None
# 24  molecularlyInteractsWith   semmedgene           semmedgene         None
# 25                    target  drugcentral          mychem.info         None
# 26  molecularlyInteractsWith   semmedgene           semmedgene         None
# 27  molecularlyInteractsWith   semmedgene           semmedgene         None
# 28  molecularlyInteractsWith   semmedgene           semmedgene         None
# 29  molecularlyInteractsWith   semmedgene           semmedgene         None
# 30  molecularlyInteractsWith   semmedgene           semmedgene         None
# 31  molecularlyInteractsWith   semmedgene           semmedgene         None
# 32  molecularlyInteractsWith   semmedgene           semmedgene         None
# 33  molecularlyInteractsWith   semmedgene           semmedgene         None
# 34  molecularlyInteractsWith   semmedgene           semmedgene         None
# 35  molecularlyInteractsWith   semmedgene           semmedgene         None
# 36  molecularlyInteractsWith   semmedgene           semmedgene         None
# 37                    target  drugcentral          mychem.info         None
# 38  molecularlyInteractsWith   semmedgene           semmedgene         None
# 39  molecularlyInteractsWith   semmedgene           semmedgene         None
# 40  molecularlyInteractsWith   semmedgene           semmedgene         None
# 41  molecularlyInteractsWith   semmedgene           semmedgene         None
# 42  molecularlyInteractsWith   semmedgene           semmedgene         None
# 43  molecularlyInteractsWith   semmedgene           semmedgene         None
# 44  molecularlyInteractsWith   semmedgene           semmedgene         None
# 45  molecularlyInteractsWith   semmedgene           semmedgene         None
# 46  molecularlyInteractsWith   semmedgene           semmedgene         None
# 47  molecularlyInteractsWith   semmedgene           semmedgene         None
# 48  molecularlyInteractsWith   semmedgene           semmedgene         None
# 49  molecularlyInteractsWith   semmedgene           semmedgene         None
# 50  molecularlyInteractsWith   semmedgene           semmedgene         None
# 51  molecularlyInteractsWith   semmedgene           semmedgene         None
# 52  molecularlyInteractsWith   semmedgene           semmedgene         None
# 53  molecularlyInteractsWith   semmedgene           semmedgene         None
# 54  molecularlyInteractsWith   semmedgene           semmedgene         None
# 55  molecularlyInteractsWith   semmedgene           semmedgene         None
# 56  molecularlyInteractsWith   semmedgene           semmedgene         None
# 57  molecularlyInteractsWith   semmedgene           semmedgene         None
# 58  molecularlyInteractsWith   semmedgene           semmedgene         None
# 59  molecularlyInteractsWith   semmedgene           semmedgene         None
#
#            output_id output_name        output_type
# 0   chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 1   chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 2   chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 3   chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 4   chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 5   chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 6   chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 7   chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 8   chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 9   chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 10  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 11  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 12  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 13  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 14  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 15  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 16  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 17  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 18  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 19  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 20  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 21  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 22  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 23  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 24  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 25  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 26  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 27  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 28  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 29  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 30  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 31  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 32  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 33  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 34  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 35  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 36  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 37  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 38  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 39  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 40  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 41  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 42  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 43  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 44  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 45  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 46  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 47  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 48  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 49  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 50  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 51  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 52  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 53  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 54  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 55  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 56  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 57  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 58  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 59  chembl:CHEMBL941    IMATINIB  ChemicalSubstance

# %% [markdown]
# ### Filter by the predicate of the first query

# %%
df[df['pred1'] == 'causedBy']
# Out:
#      input                  input_type     pred1 pred1_source      pred1_api  \
# 0   asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 1   asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 2   asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 5   asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 6   asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 10  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 11  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 12  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 14  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 17  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 18  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 19  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 20  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 21  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 23  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 24  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 25  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 26  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 27  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 28  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 29  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 30  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 31  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 32  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 33  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 34  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 35  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 37  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 38  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 40  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 41  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 42  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 43  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 45  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 48  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 51  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 53  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 55  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 56  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 57  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 59  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
#
#    pred1_pubmed       node1_id node1_name node1_type  \
# 0                   entrez:613        BCR       Gene
# 1                   entrez:613        BCR       Gene
# 2                   entrez:613        BCR       Gene
# 5                  entrez:5154      PDGFA       Gene
# 6                  entrez:5154      PDGFA       Gene
# 10               umls:C1705325       None       Gene
# 11               umls:C1367471       None       Gene
# 12               umls:C3540585       None       Gene
# 14               umls:C1706005       None       Gene
# 17               umls:C1705556       None       Gene
# 18               umls:C1705556       None       Gene
# 19                 entrez:3932        LCK       Gene
# 20                 entrez:3932        LCK       Gene
# 21                 entrez:3932        LCK       Gene
# 23                 entrez:7852      CXCR4       Gene
# 24                 entrez:7852      CXCR4       Gene
# 25                 entrez:6850        SYK       Gene
# 26               umls:C1706438       None       Gene
# 27               umls:C1704799       None       Gene
# 28               umls:C1704799       None       Gene
# 29                  entrez:146     ADRA1D       Gene
# 30                  entrez:146     ADRA1D       Gene
# 31                  entrez:947       CD34       Gene
# 32                  entrez:947       CD34       Gene
# 33                  entrez:947       CD34       Gene
# 34                  entrez:947       CD34       Gene
# 35                 entrez:3439      IFNA1       Gene
# 37                  entrez:760        CA2       Gene
# 38                 entrez:5290     PIK3CA       Gene
# 40               umls:C0017337       None       Gene
# 41                 entrez:5805        PTS       Gene
# 42                entrez:10899        JTB       Gene
# 43                entrez:10899        JTB       Gene
# 45               entrez:373156      GSTK1       Gene
# 48                 entrez:7422      VEGFA       Gene
# 51                 entrez:7124        TNF       Gene
# 53               umls:C3714973       None       Gene
# 55                 entrez:7076      TIMP1       Gene
# 56                 entrez:7076      TIMP1       Gene
# 57               umls:C3889436       None       Gene
# 59               entrez:133482    SLCO6A1       Gene
#
#                        pred2 pred2_source            pred2_api pred2_pubmed  \
# 0                     target        dgidb  dgidb_chemical2gene         None
# 1   molecularlyInteractsWith   semmedgene           semmedgene         None
# 2   molecularlyInteractsWith   semmedgene           semmedgene         None
# 5   molecularlyInteractsWith   semmedgene           semmedgene         None
# 6   molecularlyInteractsWith   semmedgene           semmedgene         None
# 10  molecularlyInteractsWith   semmedgene           semmedgene         None
# 11  molecularlyInteractsWith   semmedgene           semmedgene         None
# 12  molecularlyInteractsWith   semmedgene           semmedgene         None
# 14  molecularlyInteractsWith   semmedgene           semmedgene         None
# 17  molecularlyInteractsWith   semmedgene           semmedgene         None
# 18  molecularlyInteractsWith   semmedgene           semmedgene         None
# 19                    target  drugcentral          mychem.info         None
# 20  molecularlyInteractsWith   semmedgene           semmedgene         None
# 21  molecularlyInteractsWith   semmedgene           semmedgene         None
# 23  molecularlyInteractsWith   semmedgene           semmedgene         None
# 24  molecularlyInteractsWith   semmedgene           semmedgene         None
# 25                    target  drugcentral          mychem.info         None
# 26  molecularlyInteractsWith   semmedgene           semmedgene         None
# 27  molecularlyInteractsWith   semmedgene           semmedgene         None
# 28  molecularlyInteractsWith   semmedgene           semmedgene         None
# 29  molecularlyInteractsWith   semmedgene           semmedgene         None
# 30  molecularlyInteractsWith   semmedgene           semmedgene         None
# 31  molecularlyInteractsWith   semmedgene           semmedgene         None
# 32  molecularlyInteractsWith   semmedgene           semmedgene         None
# 33  molecularlyInteractsWith   semmedgene           semmedgene         None
# 34  molecularlyInteractsWith   semmedgene           semmedgene         None
# 35  molecularlyInteractsWith   semmedgene           semmedgene         None
# 37                    target  drugcentral          mychem.info         None
# 38  molecularlyInteractsWith   semmedgene           semmedgene         None
# 40  molecularlyInteractsWith   semmedgene           semmedgene         None
# 41  molecularlyInteractsWith   semmedgene           semmedgene         None
# 42  molecularlyInteractsWith   semmedgene           semmedgene         None
# 43  molecularlyInteractsWith   semmedgene           semmedgene         None
# 45  molecularlyInteractsWith   semmedgene           semmedgene         None
# 48  molecularlyInteractsWith   semmedgene           semmedgene         None
# 51  molecularlyInteractsWith   semmedgene           semmedgene         None
# 53  molecularlyInteractsWith   semmedgene           semmedgene         None
# 55  molecularlyInteractsWith   semmedgene           semmedgene         None
# 56  molecularlyInteractsWith   semmedgene           semmedgene         None
# 57  molecularlyInteractsWith   semmedgene           semmedgene         None
# 59  molecularlyInteractsWith   semmedgene           semmedgene         None
#
#            output_id output_name        output_type
# 0   chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 1   chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 2   chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 5   chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 6   chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 10  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 11  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 12  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 14  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 17  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 18  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 19  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 20  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 21  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 23  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 24  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 25  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 26  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 27  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 28  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 29  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 30  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 31  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 32  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 33  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 34  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 35  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 37  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 38  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 40  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 41  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 42  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 43  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 45  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 48  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 51  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 53  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 55  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 56  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 57  chembl:CHEMBL941    IMATINIB  ChemicalSubstance
# 59  chembl:CHEMBL941    IMATINIB  ChemicalSubstance

# %% [markdown]
# ### Filter by the predicate of the second query

# %%
df[df['pred2'] == 'target']
# Out:
#      input                  input_type     pred1 pred1_source      pred1_api  \
# 0   asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 19  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 25  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 37  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
#
#    pred1_pubmed     node1_id node1_name node1_type   pred2 pred2_source  \
# 0                 entrez:613        BCR       Gene  target        dgidb
# 19               entrez:3932        LCK       Gene  target  drugcentral
# 25               entrez:6850        SYK       Gene  target  drugcentral
# 37                entrez:760        CA2       Gene  target  drugcentral
#
#               pred2_api pred2_pubmed         output_id output_name  \
# 0   dgidb_chemical2gene         None  chembl:CHEMBL941    IMATINIB
# 19          mychem.info         None  chembl:CHEMBL941    IMATINIB
# 25          mychem.info         None  chembl:CHEMBL941    IMATINIB
# 37          mychem.info         None  chembl:CHEMBL941    IMATINIB
#
#           output_type
# 0   ChemicalSubstance
# 19  ChemicalSubstance
# 25  ChemicalSubstance
# 37  ChemicalSubstance

# %% [markdown]
# ### Check the detailed infomation regarding a specific edge

# %%
fc.display_edge_info('LCK', 'IMATINIB')
# Out:
# {0: {'info': {'bts:name': ['Tyrosine-protein kinase Lck'],
#    'bts:symbol': ['LCK'],
#    '@type': 'Gene',
#    '$input': 'bts:chembl',
#    '$source': 'drugcentral',
#    '$api': 'mychem.info'},
#   'label': 'bts:target',
#   'source': 'drugcentral'},
#  1: {'info': {'@type': 'Gene',
#    'bts:umls': ['C0919477'],
#    '$source': 'semmedgene',
#    '$api': 'semmedgene'},
#   'label': 'bts:molecularlyInteractsWith',
#   'source': 'semmedgene'},
#  2: {'info': {'@type': 'Gene',
#    'bts:umls': ['C0919477'],
#    '$source': 'semmedgene',
#    '$api': 'semmedgene'},
#   'label': 'bts:molecularlyInteractsWith',
#   'source': 'semmedgene'}}
