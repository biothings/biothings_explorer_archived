# %% [markdown]
# # Introduction
#
#
# This notebook demonstrates how BioThings Explorer can be used to execute queries having more than one intermediate nodes (here a "three-hop query").  **Note that this notebook can also be run and modified in Google CoLab ([link](https://colab.research.google.com/github/biothings/biothings_explorer/blob/master/jupyter%20notebooks/Disease%20-%20Gene%20-%20Disease%20-%20Chem%202021-02-03%20relay.ipynb)).**
#
# The original posed TRAPI query was this:
#
# ```
# {
#  "message": {
#   "query_graph": {
#     "edges": {
#       "e0": {
#         "predicate": "biolink:gene_associated_with_condition",
#         "subject": "n0",
#         "object": "n1"
#       },
#       "e1": {
#         "predicate":     "biolink:gene_has_variant_that_contributes_to_disease_association",
#         "subject": "n0",
#         "object": "n2"
#       },
#       "e2": {
#         "subject": "n2",
#         "object": "n3",
#         "predicate": "biolink:correlated_with"
#       }
#     },
#     "nodes": {
#       "n0": {
#         "category": "biolink:Gene"
#       },
#       "n1": {
#         "category": "biolink:Disease",
#         "id": "MONDO:0007254"
#       },
#       "n2": {
#         "category": "biolink:Disease"
#       },
#       "n3": {
#         "category": "biolink:ChemicalSubstance"
#       }
#     }
#   }
#  }
# }
# ```
#
# The original query starts with **"breast cancer" (MONDO:0007254)**.  To reduce the combinatorial explosion, I've replaced that with **"NGLY1-deficiency" (MONDO:0014109)** in the notebook below. The rest of the query path joins that initial disease to a `ChemicalSubstance`, joined by two intermediate nodes with type `Gene` and `Disease`.
#
#
# **Background**: BioThings Explorer can answer two classes of queries -- "EXPLAIN" and "PREDICT".  EXPLAIN queries are described in [EXPLAIN_demo.ipynb](https://github.com/biothings/biothings_explorer/blob/master/jupyter%20notebooks/EXPLAIN_demo.ipynb), and PREDICT queries are described in [PREDICT_demo.ipynb](https://github.com/biothings/biothings_explorer/blob/master/jupyter%20notebooks/PREDICT_demo.ipynb). Here, we describe PREDICT queries and how to use BioThings Explorer to execute them.  A more detailed overview of the BioThings Explorer systems is provided in [these slides](https://docs.google.com/presentation/d/1QWQqqQhPD_pzKryh6Wijm4YQswv8pAjleVORCPyJyDE/edit?usp=sharing).

# %% [markdown]
# ## Step 0: Load BioThings Explorer modules
#
# Install the `biothings_explorer` and `biothings_schema` packages, as described in this [README](https://github.com/biothings/biothings_explorer/blob/master/jupyter%20notebooks/README.md#prerequisite).  This only needs to be done once (but including it here for compability with [colab](https://colab.research.google.com/)).

# %%
# !pip install git+https://github.com/biothings/biothings_explorer#egg=biothings_explorer
# Out:
# Requirement already satisfied: biothings_explorer from git+https://github.com/biothings/biothings_explorer#egg=biothings_explorer in /home/asu/env/bte/lib/python3.8/site-packages (1.0.0)
# Requirement already satisfied: aiohttp in /home/asu/env/bte/lib/python3.8/site-packages (from biothings_explorer) (3.7.3)
# Requirement already satisfied: graphviz>=0.11.1 in /home/asu/env/bte/lib/python3.8/site-packages (from biothings_explorer) (0.16)
# Requirement already satisfied: ipykernel in /home/asu/env/bte/lib/python3.8/site-packages (from biothings_explorer) (5.3.4)
# Requirement already satisfied: ipython in /home/asu/env/bte/lib/python3.8/site-packages (from biothings_explorer) (7.19.0)
# Requirement already satisfied: jsonpath-rw>=1.4.0 in /home/asu/env/bte/lib/python3.8/site-packages (from biothings_explorer) (1.4.0)
# Requirement already satisfied: jupyter in /home/asu/env/bte/lib/python3.8/site-packages (from biothings_explorer) (1.0.0)
# Requirement already satisfied: nest_asyncio in /home/asu/env/bte/lib/python3.8/site-packages (from biothings_explorer) (1.5.1)
# Requirement already satisfied: networkx==2.4 in /home/asu/env/bte/lib/python3.8/site-packages (from biothings_explorer) (2.4)
# Requirement already satisfied: notebook in /home/asu/env/bte/lib/python3.8/site-packages (from biothings_explorer) (6.2.0)
# Requirement already satisfied: pandas in /home/asu/env/bte/lib/python3.8/site-packages (from biothings_explorer) (1.2.1)
# Requirement already satisfied: pyyaml in /home/asu/env/bte/lib/python3.8/site-packages (from biothings_explorer) (5.4.1)
# Requirement already satisfied: requests>=2.21.0 in /home/asu/env/bte/lib/python3.8/site-packages (from biothings_explorer) (2.25.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/asu/env/bte/lib/python3.8/site-packages (from aiohttp->biothings_explorer) (20.3.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/asu/env/bte/lib/python3.8/site-packages (from aiohttp->biothings_explorer) (1.6.3)
# Requirement already satisfied: chardet<4.0,>=2.0 in /home/asu/env/bte/lib/python3.8/site-packages (from aiohttp->biothings_explorer) (3.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/asu/env/bte/lib/python3.8/site-packages (from aiohttp->biothings_explorer) (5.1.0)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in /home/asu/env/bte/lib/python3.8/site-packages (from aiohttp->biothings_explorer) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.5 in /home/asu/env/bte/lib/python3.8/site-packages (from aiohttp->biothings_explorer) (3.7.4.3)
# Requirement already satisfied: tornado>=4.2 in /home/asu/env/bte/lib/python3.8/site-packages (from ipykernel->biothings_explorer) (6.1)
# Requirement already satisfied: traitlets>=4.1.0 in /home/asu/env/bte/lib/python3.8/site-packages (from ipykernel->biothings_explorer) (5.0.5)
# Requirement already satisfied: jupyter-client in /home/asu/env/bte/lib/python3.8/site-packages (from ipykernel->biothings_explorer) (6.1.11)
# Requirement already satisfied: pickleshare in /home/asu/env/bte/lib/python3.8/site-packages (from ipython->biothings_explorer) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/asu/env/bte/lib/python3.8/site-packages (from ipython->biothings_explorer) (3.0.14)
# Requirement already satisfied: jedi>=0.10 in /home/asu/env/bte/lib/python3.8/site-packages (from ipython->biothings_explorer) (0.18.0)
# Requirement already satisfied: backcall in /home/asu/env/bte/lib/python3.8/site-packages (from ipython->biothings_explorer) (0.2.0)
# Requirement already satisfied: pygments in /home/asu/env/bte/lib/python3.8/site-packages (from ipython->biothings_explorer) (2.7.4)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /home/asu/env/bte/lib/python3.8/site-packages (from ipython->biothings_explorer) (4.8.0)
# Requirement already satisfied: decorator in /home/asu/env/bte/lib/python3.8/site-packages (from ipython->biothings_explorer) (4.4.2)
# Requirement already satisfied: setuptools>=18.5 in /home/asu/env/bte/lib/python3.8/site-packages (from ipython->biothings_explorer) (44.0.0)
# Requirement already satisfied: six in /home/asu/env/bte/lib/python3.8/site-packages (from jsonpath-rw>=1.4.0->biothings_explorer) (1.15.0)
# Requirement already satisfied: ply in /home/asu/env/bte/lib/python3.8/site-packages (from jsonpath-rw>=1.4.0->biothings_explorer) (3.11)
# Requirement already satisfied: nbconvert in /home/asu/env/bte/lib/python3.8/site-packages (from jupyter->biothings_explorer) (6.0.7)
# Requirement already satisfied: jupyter-console in /home/asu/env/bte/lib/python3.8/site-packages (from jupyter->biothings_explorer) (6.2.0)
# Requirement already satisfied: ipywidgets in /home/asu/env/bte/lib/python3.8/site-packages (from jupyter->biothings_explorer) (7.6.3)
# Requirement already satisfied: qtconsole in /home/asu/env/bte/lib/python3.8/site-packages (from jupyter->biothings_explorer) (5.0.2)
# Requirement already satisfied: ipython-genutils in /home/asu/env/bte/lib/python3.8/site-packages (from notebook->biothings_explorer) (0.2.0)
# Requirement already satisfied: prometheus-client in /home/asu/env/bte/lib/python3.8/site-packages (from notebook->biothings_explorer) (0.9.0)
# Requirement already satisfied: jinja2 in /home/asu/env/bte/lib/python3.8/site-packages (from notebook->biothings_explorer) (2.11.3)
# Requirement already satisfied: terminado>=0.8.3 in /home/asu/env/bte/lib/python3.8/site-packages (from notebook->biothings_explorer) (0.9.2)
# Requirement already satisfied: argon2-cffi in /home/asu/env/bte/lib/python3.8/site-packages (from notebook->biothings_explorer) (20.1.0)
# Requirement already satisfied: nbformat in /home/asu/env/bte/lib/python3.8/site-packages (from notebook->biothings_explorer) (5.1.2)
# Requirement already satisfied: jupyter-core>=4.6.1 in /home/asu/env/bte/lib/python3.8/site-packages (from notebook->biothings_explorer) (4.7.1)
# Requirement already satisfied: Send2Trash>=1.5.0 in /home/asu/env/bte/lib/python3.8/site-packages (from notebook->biothings_explorer) (1.5.0)
# Requirement already satisfied: pyzmq>=17 in /home/asu/env/bte/lib/python3.8/site-packages (from notebook->biothings_explorer) (22.0.2)
# Requirement already satisfied: numpy>=1.16.5 in /home/asu/env/bte/lib/python3.8/site-packages (from pandas->biothings_explorer) (1.20.0)
# Requirement already satisfied: pytz>=2017.3 in /home/asu/env/bte/lib/python3.8/site-packages (from pandas->biothings_explorer) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/asu/env/bte/lib/python3.8/site-packages (from pandas->biothings_explorer) (2.8.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/asu/env/bte/lib/python3.8/site-packages (from requests>=2.21.0->biothings_explorer) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /home/asu/env/bte/lib/python3.8/site-packages (from requests>=2.21.0->biothings_explorer) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/asu/env/bte/lib/python3.8/site-packages (from requests>=2.21.0->biothings_explorer) (1.26.3)
# Requirement already satisfied: wcwidth in /home/asu/env/bte/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->biothings_explorer) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/asu/env/bte/lib/python3.8/site-packages (from jedi>=0.10->ipython->biothings_explorer) (0.8.1)
# Requirement already satisfied: ptyprocess>=0.5 in /home/asu/env/bte/lib/python3.8/site-packages (from pexpect>4.3; sys_platform != "win32"->ipython->biothings_explorer) (0.7.0)
# Requirement already satisfied: bleach in /home/asu/env/bte/lib/python3.8/site-packages (from nbconvert->jupyter->biothings_explorer) (3.2.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/asu/env/bte/lib/python3.8/site-packages (from nbconvert->jupyter->biothings_explorer) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in /home/asu/env/bte/lib/python3.8/site-packages (from nbconvert->jupyter->biothings_explorer) (0.1.2)
# Requirement already satisfied: testpath in /home/asu/env/bte/lib/python3.8/site-packages (from nbconvert->jupyter->biothings_explorer) (0.4.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /home/asu/env/bte/lib/python3.8/site-packages (from nbconvert->jupyter->biothings_explorer) (0.3)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /home/asu/env/bte/lib/python3.8/site-packages (from nbconvert->jupyter->biothings_explorer) (0.5.1)
# Requirement already satisfied: defusedxml in /home/asu/env/bte/lib/python3.8/site-packages (from nbconvert->jupyter->biothings_explorer) (0.6.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/asu/env/bte/lib/python3.8/site-packages (from nbconvert->jupyter->biothings_explorer) (1.4.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /home/asu/env/bte/lib/python3.8/site-packages (from ipywidgets->jupyter->biothings_explorer) (3.5.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0; python_version >= "3.6" in /home/asu/env/bte/lib/python3.8/site-packages (from ipywidgets->jupyter->biothings_explorer) (1.0.0)
# Requirement already satisfied: qtpy in /home/asu/env/bte/lib/python3.8/site-packages (from qtconsole->jupyter->biothings_explorer) (1.9.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/asu/env/bte/lib/python3.8/site-packages (from jinja2->notebook->biothings_explorer) (1.1.1)
# Requirement already satisfied: cffi>=1.0.0 in /home/asu/env/bte/lib/python3.8/site-packages (from argon2-cffi->notebook->biothings_explorer) (1.14.4)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /home/asu/env/bte/lib/python3.8/site-packages (from nbformat->notebook->biothings_explorer) (3.2.0)
# Requirement already satisfied: packaging in /home/asu/env/bte/lib/python3.8/site-packages (from bleach->nbconvert->jupyter->biothings_explorer) (20.9)
# Requirement already satisfied: webencodings in /home/asu/env/bte/lib/python3.8/site-packages (from bleach->nbconvert->jupyter->biothings_explorer) (0.5.1)
# Requirement already satisfied: async-generator in /home/asu/env/bte/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter->biothings_explorer) (1.10)
# Requirement already satisfied: pycparser in /home/asu/env/bte/lib/python3.8/site-packages (from cffi>=1.0.0->argon2-cffi->notebook->biothings_explorer) (2.20)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/asu/env/bte/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook->biothings_explorer) (0.17.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/asu/env/bte/lib/python3.8/site-packages (from packaging->bleach->nbconvert->jupyter->biothings_explorer) (2.4.7)

# %% [markdown]
# Next, import the relevant modules:
#
# * **Hint**: Find corresponding bio-entity representation used in BioThings Explorer based on user input (could be any database IDs, symbols, names)
# * **FindConnection**: Find intermediate bio-entities which connects user specified input and output

# %%
from biothings_explorer.hint import Hint
from biothings_explorer.user_query_dispatcher import FindConnection
import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# ## Step 1: Find representation of the input disease in BTE
#
# In this step, BioThings Explorer translates our query string into a BioThings object, which contain mappings to many common identifiers.  Generally, the top result returned by the `Hint` module will be the correct item, but you should confirm that using the identifiers shown.
#
# Search terms can correspond to any child of [BiologicalEntity](https://biolink.github.io/biolink-model/docs/BiologicalEntity.html) from the [Biolink Model](https://biolink.github.io/biolink-model/docs/), including `DiseaseOrPhenotypicFeature` (e.g., "lupus"), `ChemicalSubstance` (e.g., "acetaminophen"), `Gene` (e.g., "CDK2"), `BiologicalProcess` (e.g., "T cell differentiation"), and `Pathway` (e.g., "Citric acid cycle").

# %%
ht = Hint()
input_disease = ht.query("MONDO:0014109")["Disease"][0]

input_disease
# Out:
# {'MONDO': 'MONDO:0014109',
#  'DOID': 'DOID:0060728',
#  'UMLS': 'C3808991',
#  'name': 'NGLY1-deficiency',
#  'OMIM': '615273',
#  'ORPHANET': '404454',
#  'primary': {'identifier': 'MONDO',
#   'cls': 'Disease',
#   'value': 'MONDO:0014109'},
#  'display': 'MONDO(MONDO:0014109) DOID(DOID:0060728) OMIM(615273) ORPHANET(404454) UMLS(C3808991) name(NGLY1-deficiency)',
#  'type': 'Disease'}

# %% [markdown]
# ## Step 2: Find `ChemicalSubstance`s that are associated with the input disease through `Gene` and `Disease` as intermediate nodes
#
# In this section, we find all paths in the knowledge graph that connect the input disease to any entity that is a `ChemicalSubstance` feature.  To do that, we will use `FindConnection`.  This class is a convenient wrapper around two advanced functions for **query path planning** and **query path execution**. More advanced features for both query path planning and query path execution are in development and will be documented in the coming months.

# %%
fc = FindConnection(input_obj=input_disease, 
                    output_obj='ChemicalSubstance', 
                    intermediate_nodes=['Gene', 'Disease'])

# %%
fc.connect(verbose=True)
# Out:
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'NGLY1-deficiency' and 'ChemicalSubstance'. Paths will have 2 intermediate node.
#
# Intermediate node #1 will have these type constraints: Gene
#
# Intermediate node #2 will have these type constraints: Disease
#
#
#
# ========== QUERY #1 -- fetch all Gene entities linked to NGLY1-deficiency ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because NGLY1-deficiency is of type 'Disease', BTE will query our meta-KG for APIs that can take 'Disease' as input and 'Gene' as output
#
# BTE found 10 apis:
#
# API 1. hetio(1 API call)
# API 2. biolink(1 API call)
# API 3. mydisease(1 API call)
# API 4. semmed_disease(15 API calls)
# API 5. pharos(1 API call)
# API 6. cord_disease(1 API call)
# API 7. mgi_gene2phenotype(1 API call)
# API 8. scigraph(1 API call)
# API 9. scibite(1 API call)
# API 10. DISEASES(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 3.2: https://biothings.ncats.io/semmed/query?fields=coexists_with (POST -d q=C3808991&scopes=umls)
# API 3.9: https://biothings.ncats.io/semmed/query?fields=disrupted_by (POST -d q=C3808991&scopes=umls)
# API 3.4: https://biothings.ncats.io/semmed/query?fields=positively_regulates (POST -d q=C3808991&scopes=umls)
# API 3.7: https://biothings.ncats.io/semmed/query?fields=positively_regulated_by (POST -d q=C3808991&scopes=umls)
# API 3.5: https://biothings.ncats.io/semmed/query?fields=physically_interacts_with (POST -d q=C3808991&scopes=umls)
# API 3.3: https://biothings.ncats.io/semmed/query?fields=prevented_by (POST -d q=C3808991&scopes=umls)
# API 3.1: https://biothings.ncats.io/semmed/query?fields=affects (POST -d q=C3808991&scopes=umls)
# API 3.8: https://biothings.ncats.io/semmed/query?fields=derives_from (POST -d q=C3808991&scopes=umls)
# API 3.6: https://biothings.ncats.io/semmed/query?fields=treated_by (POST -d q=C3808991&scopes=umls)
# API 3.14: https://biothings.ncats.io/semmed/query?fields=caused_by (POST -d q=C3808991&scopes=umls)
# API 3.10: https://biothings.ncats.io/semmed/query?fields=affected_by (POST -d q=C3808991&scopes=umls)
# API 3.12: https://biothings.ncats.io/semmed/query?fields=related_to (POST -d q=C3808991&scopes=umls)
# API 5.1: https://biothings.ncats.io/cord_disease/query?fields=associated_with (POST -d q=DOID:0060728&scopes=doid)
# API 3.11: https://biothings.ncats.io/semmed/query?fields=negatively_regulates (POST -d q=C3808991&scopes=umls)
# API 3.15: https://biothings.ncats.io/semmed/query?fields=negatively_regulated_by (POST -d q=C3808991&scopes=umls)
# API 3.13: https://biothings.ncats.io/semmed/query?fields=disrupts (POST -d q=C3808991&scopes=umls)
# API 10.1: https://pending.biothings.io/DISEASES/query?fields=DISEASES.associatedWith (POST -d q=DOID:0060728&scopes=DISEASES.doid)
# API 6.1: https://pending.biothings.io/mgigene2phenotype/query?fields=_id&size=300 (POST -d q=DOID:0060728&scopes=mgi.associated_with_disease.doid)
# API 9.1: https://automat.renci.org/cord19-scigraph/disease/gene/MONDO:0014109
# API 4.1: https://automat.renci.org/pharos/disease/gene/MONDO:0014109
# API 7.1: https://automat.renci.org/cord19-scibite/disease/gene/MONDO:0014109
# API 1.1: https://automat.renci.org/hetio/disease/gene/MONDO:0014109
# API 8.1: https://mydisease.info/v1/query?fields=disgenet.genes_related_to_disease.gene_id (POST -d q=C3808991&scopes=mondo.xrefs.umls, disgenet.xrefs.umls)
# API 2.1: https://api.monarchinitiative.org/api/bioentity/disease/MONDO:0014109/genes?rows=200&direct=true
#
#
# ==== Step #3: Output normalization ====
#
# API 6.1 mgi_gene2phenotype: No hits
# API 3.1 semmed_disease: No hits
# API 3.2 semmed_disease: No hits
# API 10.1 DISEASES: 11 hits
# API 3.3 semmed_disease: No hits
# API 3.4 semmed_disease: No hits
# API 3.5 semmed_disease: No hits
# API 3.6 semmed_disease: No hits
# API 3.7 semmed_disease: No hits
# API 9.1 scigraph: No hits
# API 4.1 pharos: No hits
# API 2.1 biolink: 1 hits
# API 3.8 semmed_disease: No hits
# API 3.9 semmed_disease: No hits
# API 5.1 cord_disease: No hits
# API 3.10 semmed_disease: No hits
# API 7.1 scibite: No hits
# API 1.1 hetio: No hits
# API 3.11 semmed_disease: No hits
# API 3.12 semmed_disease: No hits
# API 8.1 mydisease: 8 hits
# API 3.13 semmed_disease: No hits
# API 3.14 semmed_disease: No hits
# API 3.15 semmed_disease: No hits
#
# After id-to-object translation, BTE retrieved 11 unique objects.
#
#
# ========== QUERY #2.1 -- fetch all Disease entities linked to Gene entites ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because None is of type 'Gene', BTE will query our meta-KG for APIs that can take 'Gene' as input and 'Disease' as output
#
# BTE found 10 apis:
#
# API 1. hetio(11 API calls)
# API 2. biolink(11 API calls)
# API 3. semmed_gene(13 API calls)
# API 4. pharos(11 API calls)
# API 5. scibite(11 API calls)
# API 6. scigraph(11 API calls)
# API 7. mydisease(1 API call)
# API 8. ctd(11 API calls)
# API 9. DISEASES(1 API call)
# API 10. cord_gene(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 2.2: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:4779/diseases?rows=200&direct=true
# API 3.1: https://biothings.ncats.io/semmedgene/query?fields=positively_regulates (POST -d q=C1418516,C1539585,C1422076,C1417700,C1418674,C1422080,C1425023,C2681929,C1824901,C1414524,C1823173&scopes=umls)
# API 2.1: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:26232/diseases?rows=200&direct=true
# API 2.3: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:84301/diseases?rows=200&direct=true
# API 3.9: https://biothings.ncats.io/semmedgene/query?fields=treats (POST -d q=C1418516,C1539585,C1422076,C1417700,C1418674,C1422080,C1425023,C2681929,C1824901,C1414524,C1823173&scopes=umls)
# API 2.9: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:29926/diseases?rows=200&direct=true
# API 2.5: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:64772/diseases?rows=200&direct=true
# API 6.7: https://automat.renci.org/cord19-scibite/gene/disease/NCBIGene:5236
# API 6.2: https://automat.renci.org/cord19-scibite/gene/disease/NCBIGene:4779
# API 9.2: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:4779
# API 6.9: https://automat.renci.org/cord19-scibite/gene/disease/NCBIGene:29926
# API 6.11: https://automat.renci.org/cord19-scibite/gene/disease/NCBIGene:5373
# API 2.6: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:26270/diseases?rows=200&direct=true
# API 9.8: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:55768
# API 6.8: https://automat.renci.org/cord19-scibite/gene/disease/NCBIGene:55768
# API 6.6: https://automat.renci.org/cord19-scibite/gene/disease/NCBIGene:26270
# API 4.3: https://automat.renci.org/pharos/gene/disease/NCBIGene:84301
# API 9.7: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:5236
# API 6.4: https://automat.renci.org/cord19-scibite/gene/disease/NCBIGene:11124
# API 9.4: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:11124
# API 9.5: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:64772
# API 6.3: https://automat.renci.org/cord19-scibite/gene/disease/NCBIGene:84301
# API 4.5: https://automat.renci.org/pharos/gene/disease/NCBIGene:64772
# API 4.2: https://automat.renci.org/pharos/gene/disease/NCBIGene:4779
# API 6.5: https://automat.renci.org/cord19-scibite/gene/disease/NCBIGene:64772
# API 6.1: https://automat.renci.org/cord19-scibite/gene/disease/NCBIGene:26232
# API 6.10: https://automat.renci.org/cord19-scibite/gene/disease/NCBIGene:199857
# API 4.4: https://automat.renci.org/pharos/gene/disease/NCBIGene:11124
# API 4.6: https://automat.renci.org/pharos/gene/disease/NCBIGene:26270
# API 4.8: https://automat.renci.org/pharos/gene/disease/NCBIGene:55768
# API 4.7: https://automat.renci.org/pharos/gene/disease/NCBIGene:5236
# API 2.7: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:5236/diseases?rows=200&direct=true
# API 2.8: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:55768/diseases?rows=200&direct=true
# API 2.10: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:199857/diseases?rows=200&direct=true
# API 2.4: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:11124/diseases?rows=200&direct=true
# API 2.11: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:5373/diseases?rows=200&direct=true
# API 8.3: http://ctdbase.org/tools/batchQuery.go?inputType=gene&report=diseases_curated&format=json&inputTerms=84301
# API 8.2: http://ctdbase.org/tools/batchQuery.go?inputType=gene&report=diseases_curated&format=json&inputTerms=4779
# API 9.6: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:26270
# API 8.1: http://ctdbase.org/tools/batchQuery.go?inputType=gene&report=diseases_curated&format=json&inputTerms=26232
# API 8.4: http://ctdbase.org/tools/batchQuery.go?inputType=gene&report=diseases_curated&format=json&inputTerms=11124
# API 10.1: https://biothings.ncats.io/cord_gene/query?fields=associated_with (POST -d q=17646,9115,13581,3578,24622,28287,13585,24578,7781,8905,22923&scopes=hgnc)
# API 3.13: https://biothings.ncats.io/semmedgene/query?fields=affects (POST -d q=C1418516,C1539585,C1422076,C1417700,C1418674,C1422080,C1425023,C2681929,C1824901,C1414524,C1823173&scopes=umls)
# API 3.11: https://biothings.ncats.io/semmedgene/query?fields=affected_by (POST -d q=C1418516,C1539585,C1422076,C1417700,C1418674,C1422080,C1425023,C2681929,C1824901,C1414524,C1823173&scopes=umls)
# API 9.1: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:26232
# API 9.9: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:29926
# API 9.3: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:84301
# API 8.7: http://ctdbase.org/tools/batchQuery.go?inputType=gene&report=diseases_curated&format=json&inputTerms=5236
# API 3.7: https://biothings.ncats.io/semmedgene/query?fields=positively_regulated_by (POST -d q=C1418516,C1539585,C1422076,C1417700,C1418674,C1422080,C1425023,C2681929,C1824901,C1414524,C1823173&scopes=umls)
# API 3.5: https://biothings.ncats.io/semmedgene/query?fields=negatively_regulated_by (POST -d q=C1418516,C1539585,C1422076,C1417700,C1418674,C1422080,C1425023,C2681929,C1824901,C1414524,C1823173&scopes=umls)
# API 3.12: https://biothings.ncats.io/semmedgene/query?fields=negatively_regulates (POST -d q=C1418516,C1539585,C1422076,C1417700,C1418674,C1422080,C1425023,C2681929,C1824901,C1414524,C1823173&scopes=umls)
# API 3.10: https://biothings.ncats.io/semmedgene/query?fields=related_to (POST -d q=C1418516,C1539585,C1422076,C1417700,C1418674,C1422080,C1425023,C2681929,C1824901,C1414524,C1823173&scopes=umls)
# API 3.6: https://biothings.ncats.io/semmedgene/query?fields=causes (POST -d q=C1418516,C1539585,C1422076,C1417700,C1418674,C1422080,C1425023,C2681929,C1824901,C1414524,C1823173&scopes=umls)
# API 3.8: https://biothings.ncats.io/semmedgene/query?fields=prevents (POST -d q=C1418516,C1539585,C1422076,C1417700,C1418674,C1422080,C1425023,C2681929,C1824901,C1414524,C1823173&scopes=umls)
# API 9.10: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:199857
# API 9.11: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:5373
# API 4.9: https://automat.renci.org/pharos/gene/disease/NCBIGene:29926
# API 8.6: http://ctdbase.org/tools/batchQuery.go?inputType=gene&report=diseases_curated&format=json&inputTerms=26270
# API 3.3: https://biothings.ncats.io/semmedgene/query?fields=physically_interacts_with (POST -d q=C1418516,C1539585,C1422076,C1417700,C1418674,C1422080,C1425023,C2681929,C1824901,C1414524,C1823173&scopes=umls)
# API 3.4: https://biothings.ncats.io/semmedgene/query?fields=disrupted_by (POST -d q=C1418516,C1539585,C1422076,C1417700,C1418674,C1422080,C1425023,C2681929,C1824901,C1414524,C1823173&scopes=umls)
# API 3.2: https://biothings.ncats.io/semmedgene/query?fields=disrupts (POST -d q=C1418516,C1539585,C1422076,C1417700,C1418674,C1422080,C1425023,C2681929,C1824901,C1414524,C1823173&scopes=umls)
# API 5.1: https://pending.biothings.io/DISEASES/query?fields=DISEASES.doid&size=250 (POST -d q=PMM2,NFE2L1,ALG14,GMPPA,ENGASE,FBXO2,DDI2,PGM1,NGLY1,FAF1,FBXO6&scopes=DISEASES.associatedWith.symbol)
# API 8.9: http://ctdbase.org/tools/batchQuery.go?inputType=gene&report=diseases_curated&format=json&inputTerms=29926
# API 8.8: http://ctdbase.org/tools/batchQuery.go?inputType=gene&report=diseases_curated&format=json&inputTerms=55768
# API 1.6: https://automat.renci.org/hetio/gene/disease/NCBIGene:26270
# API 1.8: https://automat.renci.org/hetio/gene/disease/NCBIGene:55768
# API 1.3: https://automat.renci.org/hetio/gene/disease/NCBIGene:84301
# API 4.10: https://automat.renci.org/pharos/gene/disease/NCBIGene:199857
# API 1.2: https://automat.renci.org/hetio/gene/disease/NCBIGene:4779
# API 4.11: https://automat.renci.org/pharos/gene/disease/NCBIGene:5373
# API 4.1: https://automat.renci.org/pharos/gene/disease/NCBIGene:26232
# API 1.11: https://automat.renci.org/hetio/gene/disease/NCBIGene:5373
# API 1.5: https://automat.renci.org/hetio/gene/disease/NCBIGene:64772
# API 1.9: https://automat.renci.org/hetio/gene/disease/NCBIGene:29926
# API 8.11: http://ctdbase.org/tools/batchQuery.go?inputType=gene&report=diseases_curated&format=json&inputTerms=5373
# API 8.10: http://ctdbase.org/tools/batchQuery.go?inputType=gene&report=diseases_curated&format=json&inputTerms=199857
# API 1.1: https://automat.renci.org/hetio/gene/disease/NCBIGene:26232
# API 1.7: https://automat.renci.org/hetio/gene/disease/NCBIGene:5236
# API 1.10: https://automat.renci.org/hetio/gene/disease/NCBIGene:199857
# API 8.5: http://ctdbase.org/tools/batchQuery.go?inputType=gene&report=diseases_curated&format=json&inputTerms=64772
# API 1.4: https://automat.renci.org/hetio/gene/disease/NCBIGene:11124
# API 7.1: https://mydisease.info/v1/query?fields=disgenet.xrefs.umls&size=250 (POST -d q=26232,4779,84301,11124,64772,26270,5236,55768,29926,199857,5373&scopes=disgenet.genes_related_to_disease.gene_id)
#
#
# ==== Step #3: Output normalization ====
#
# API 3.1 semmed_gene: No hits
# API 3.2 semmed_gene: 2 hits
# API 2.1 biolink: No hits
# API 2.2 biolink: No hits
# API 2.3 biolink: 1 hits
# API 2.4 biolink: 8 hits
# API 2.5 biolink: No hits
# API 2.6 biolink: No hits
# API 2.7 biolink: 4 hits
# API 2.8 biolink: 1 hits
# API 2.9 biolink: 2 hits
# API 2.10 biolink: 6 hits
# API 2.11 biolink: 4 hits
# API 6.1 scibite: No hits
# API 6.2 scibite: No hits
# API 6.3 scibite: No hits
# API 6.4 scibite: No hits
# API 6.5 scibite: No hits
# API 6.6 scibite: No hits
# API 6.7 scibite: No hits
# API 6.8 scibite: No hits
# API 6.9 scibite: No hits
# API 6.10 scibite: No hits
# API 6.11 scibite: No hits
# API 3.3 semmed_gene: No hits
# API 3.4 semmed_gene: No hits
# API 5.1 DISEASES: 159 hits
# API 9.1 scigraph: No hits
# API 9.2 scigraph: No hits
# API 9.3 scigraph: No hits
# API 9.4 scigraph: No hits
# API 9.5 scigraph: No hits
# API 9.6 scigraph: No hits
# API 9.7 scigraph: No hits
# API 9.8 scigraph: No hits
# API 9.9 scigraph: No hits
# API 9.10 scigraph: No hits
# API 9.11 scigraph: No hits
# API 3.5 semmed_gene: No hits
# API 3.6 semmed_gene: 18 hits
# API 3.7 semmed_gene: No hits
# API 4.1 pharos: No hits
# API 4.2 pharos: No hits
# API 4.3 pharos: No hits
# API 4.4 pharos: No hits
# API 4.5 pharos: No hits
# API 4.6 pharos: No hits
# API 4.7 pharos: No hits
# API 4.8 pharos: No hits
# API 4.9 pharos: No hits
# API 4.10 pharos: No hits
# API 4.11 pharos: No hits
# API 1.1 hetio: No hits
# API 1.2 hetio: No hits
# API 1.3 hetio: No hits
# API 1.4 hetio: No hits
# API 1.5 hetio: No hits
# API 1.6 hetio: No hits
# API 1.7 hetio: No hits
# API 1.8 hetio: No hits
# API 1.9 hetio: No hits
# API 1.10 hetio: No hits
# API 1.11 hetio: No hits
# API 7.1 mydisease: 536 hits
# API 3.8 semmed_gene: 1 hits
# API 3.9 semmed_gene: 14 hits
# API 3.10 semmed_gene: 31 hits
# API 3.11 semmed_gene: No hits
# API 10.1 cord_gene: 27 hits
# API 3.12 semmed_gene: No hits
# API 3.13 semmed_gene: 8 hits
# API 8.1 ctd: No hits
# API 8.2 ctd: No hits
# API 8.3 ctd: No hits
# API 8.4 ctd: No hits
# API 8.5 ctd: No hits
# API 8.6 ctd: 1 hits
# API 8.7 ctd: 4 hits
# API 8.8 ctd: 1 hits
# API 8.9 ctd: 1 hits
# API 8.10 ctd: 1 hits
# API 8.11 ctd: 3 hits
#
# After id-to-object translation, BTE retrieved 565 unique objects.
#
#
# ========== QUERY #3.1 -- fetch all ChemicalSubstance entities linked to Disease entites ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because None is of type 'Disease', BTE will query our meta-KG for APIs that can take 'Disease' as input and 'ChemicalSubstance' as output
#
# BTE found 8 apis:
#
# API 1. hmdb(276 API calls)
# API 2. semmed_disease(15 API calls)
# API 3. pharos(276 API calls)
# API 4. mychem(2 API calls)
# API 5. cord_disease(1 API call)
# API 6. scibite(276 API calls)
# API 7. mydisease(1 API call)
# API 8. scigraph(276 API calls)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 2.4: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0010410
# API 2.1: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0002427
# API 2.5: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0007778
# API 2.9: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0005066
# API 2.3: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0020358
# API 2.15: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0019145
# API 2.23: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0019500
# API 2.8: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0002118
# API 2.16: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0005156
# API 2.12: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0012115
# API 2.11: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0015742
# API 2.60: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0018114
# API 2.58: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0
https://automat.renci.org/cord19-scigraph/disease/chemical_substance/MONDO:0015626
# API 8.76: https://automat.renci.org/cord19-scigraph/disease/chemical_substance/MONDO:0008656
# ...
# API 8.247 scigraph: No hits
# API 8.248 scigraph: No hits
# API 8.249 scigraph: No hits
# API 8.250 scigraph: No hits
# API 8.251 scigraph: No hits
# API 8.252 scigraph: No hits
# API 8.253 scigraph: No hits
# API 8.254 scigraph: No hits
# API 8.255 scigraph: No hits
# API 8.256 scigraph: No hits
# API 8.257 scigraph: No hits
# API 8.258 scigraph: No hits
# API 8.259 scigraph: No hits
# API 8.260 scigraph: No hits
# API 8.261 scigraph: No hits
# API 8.262 scigraph: No hits
# API 8.263 scigraph: No hits
# API 8.264 scigraph: No hits
# API 8.265 scigraph: No hits
# API 8.266 scigraph: No hits
# API 8.267 scigraph: No hits
# API 8.268 scigraph: No hits
# API 8.269 scigraph: No hits
# API 8.270 scigraph: No hits
# API 8.271 scigraph: No hits
# API 8.272 scigraph: No hits
# API 8.273 scigraph: No hits
# API 8.274 scigraph: No hits
# API 8.275 scigraph: No hits
# API 8.276 scigraph: No hits
# API 1.4 semmed_disease: 12581 hits
# API 1.5 semmed_disease: No hits
# API 6.1 scibite: No hits
# API 6.2 scibite: No hits
# API 6.3 scibite: No hits
# API 6.4 scibite: No hits
# API 6.5 scibite: No hits
# API 6.6 scibite: No hits
# API 6.7 scibite: No hits
# API 6.8 scibite: No hits
# API 6.9 scibite: No hits
# API 6.10 scibite: No hits
# API 6.11 scibite: No hits
# API 6.12 scibite: No hits
# API 6.13 scibite: No hits
# API 6.14 scibite: No hits
# API 6.15 scibite: No hits
# API 6.16 scibite: No hits
# API 6.17 scibite: No hits
# API 6.18 scibite: No hits
# API 6.19 scibite: No hits
# API 6.20 scibite: No hits
# API 6.21 scibite: No hits
# API 6.22 scibite: No hits
# API 6.23 scibite: No hits
# API 6.24 scibite: No hits
# API 6.25 scibite: No hits
# API 6.26 scibite: No hits
# API 6.27 scibite: No hits
# API 6.28 scibite: No hits
# API 6.29 scibite: No hits
# API 6.30 scibite: No hits
# API 6.31 scibite: No hits
# API 6.32 scibite: No hits
# API 6.33 scibite: No hits
# API 6.34 scibite: No hits
# API 6.35 scibite: No hits
# API 6.36 scibite: No hits
# API 6.37 scibite: No hits
# API 6.38 scibite: No hits
# API 6.39 scibite: No hits
# API 6.40 scibite: No hits
# API 6.41 scibite: No hits
# API 6.42 scibite: No hits
# API 6.43 scibite: No hits
# API 6.44 scibite: No hits
# API 6.45 scibite: No hits
# API 6.46 scibite: No hits
# API 6.47 scibite: No hits
# API 6.48 scibite: No hits
# API 6.49 scibite: No hits
# API 6.50 scibite: No hits
# API 6.51 scibite: No hits
# API 6.52 scibite: No hits
# API 6.53 scibite: No hits
# API 6.54 scibite: No hits
# API 6.55 scibite: No hits
# API 6.56 scibite: No hits
# API 6.57 scibite: No hits
# API 6.58 scibite: No hits
# API 6.59 scibite: No hits
# API 6.60 scibite: No hits
# API 6.61 scibite: No hits
# API 6.62 scibite: No hits
# API 6.63 scibite: No hits
# API 6.64 scibite: No hits
# API 6.65 scibite: No hits
# API 6.66 scibite: No hits
# API 6.67 scibite: No hits
# API 6.68 scibite: No hits
# API 6.69 scibite: No hits
# API 6.70 scibite: No hits
# API 6.71 scibite: No hits
# API 6.72 scibite: No hits
# API 6.73 scibite: No hits
# API 6.74 scibite: No hits
# API 6.75 scibite: No hits
# API 6.76 scibite: No hits
# API 6.77 scibite: No hits
# API 6.78 scibite: No hits
# API 6.79 scibite: No hits
# API 6.80 scibite: No hits
# API 6.81 scibite: No hits
# API 6.82 scibite: No hits
# API 6.83 scibite: No hits
# API 6.84 scibite: No hits
# API 6.85 scibite: No hits
# API 6.86 scibite: No hits
# API 6.87 scibite: No hits
# API 6.88 scibite: No hits
# API 6.89 scibite: No hits
# API 6.90 scibite: No hits
# API 6.91 scibite: No hits
# API 6.92 scibite: No hits
# API 6.93 scibite: No hits
# API 6.94 scibite: No hits
# API 6.95 scibite: No hits
# API 6.96 scibite: No hits
# API 6.97 scibite: No hits
# API 6.98 scibite: No hits
# API 6.99 scibite: No hits
# API 6.100 scibite: No hits
# API 6.101 scibite: No hits
# API 6.102 scibite: No hits
# API 6.103 scibite: No hits
# API 6.104 scibite: No hits
# API 6.105 scibite: No hits
# API 6.106 scibite: No hits
# API 6.107 scibite: No hits
# API 6.108 scibite: No hits
# API 6.109 scibite: No hits
# API 6.110 scibite: No hits
# API 6.111 scibite: No hits
# API 6.112 scibite: No hits
# API 6.113 scibite: No hits
# API 6.114 scibite: No hits
# API 6.115 scibite: No hits
# API 6.116 scibite: No hits
# API 6.117 scibite: No hits
# API 6.118 scibite: No hits
# API 6.119 scibite: No hits
# API 6.120 scibite: No hits
# API 6.121 scibite: No hits
# API 6.122 scibite: No hits
# API 6.123 scibite: No hits
# API 6.124 scibite: No hits
# API 6.125 scibite: No hits
# API 6.126 scibite: No hits
# API 6.127 scibite: No hits
# API 6.128 scibite: No hits
# API 6.129 scibite: No hits
# API 6.130 scibite: No hits
# API 6.131 scibite: No hits
# API 6.132 scibite: No hits
# API 6.133 scibite: No hits
# API 6.134 scibite: No hits
# API 6.135 scibite: No hits
# API 6.136 scibite: No hits
# API 6.137 scibite: No hits
# API 6.138 scibite: No hits
# API 6.139 scibite: No hits
# API 6.140 scibite: No hits
# API 6.141 scibite: No hits
# API 6.142 scibite: No hits
# API 6.143 scibite: No hits
# API 6.144 scibite: No hits
# API 6.145 scibite: No hits
# API 6.146 scibite: No hits
# API 6.147 scibite: No hits
# API 6.148 scibite: No hits
# API 6.149 scibite: No hits
# API 6.150 scibite: No hits
# API 6.151 scibite: No hits
# API 6.152 scibite: No hits
# API 6.153 scibite: No hits
# API 6.154 scibite: No hits
# API 6.155 scibite: No hits
# API 6.156 scibite: No hits
# API 6.157 scibite: No hits
# API 6.158 scibite: No hits
# API 6.159 scibite: No hits
# API 6.160 scibite: No hits
# API 6.161 scibite: No hits
# API 6.162 scibite: No hits
# API 6.163 scibite: No hits
# API 6.164 scibite: No hits
# API 6.165 scibite: No hits
# API 6.166 scibite: No hits
# API 6.167 scibite: No hits
# API 6.168 scibite: No hits
# API 6.169 scibite: No hits
# API 6.170 scibite: No hits
# API 6.171 scibite: No hits
# API 6.172 scibite: No hits
# API 6.173 scibite: No hits
# API 6.174 scibite: No hits
# API 6.175 scibite: No hits
# API 6.176 scibite: No hits
# API 6.177 scibite: No hits
# API 6.178 scibite: No hits
# API 6.179 scibite: No hits
# API 6.180 scibite: No hits
# API 6.181 scibite: No hits
# API 6.182 scibite: No hits
# API 6.183 scibite: No hits
# API 6.184 scibite: No hits
# API 6.185 scibite: No hits
# API 6.186 scibite: No hits
# API 6.187 scibite: No hits
# API 6.188 scibite: No hits
# API 6.189 scibite: No hits
# API 6.190 scibite: No hits
# API 6.191 scibite: No hits
# API 6.192 scibite: No hits
# API 6.193 scibite: No hits
# API 6.194 scibite: No hits
# API 6.195 scibite: No hits
# API 6.196 scibite: No hits
# API 6.197 scibite: No hits
# API 6.198 scibite: No hits
# API 6.199 scibite: No hits
# API 6.200 scibite: No hits
# API 6.201 scibite: No hits
# API 6.202 scibite: No hits
# API 6.203 scibite: No hits
# API 6.204 scibite: No hits
# API 6.205 scibite: No hits
# API 6.206 scibite: No hits
# API 6.207 scibite: No hits
# API 6.208 scibite: No hits
# API 6.209 scibite: No hits
# API 6.210 scibite: No hits
# API 6.211 scibite: No hits
# API 6.212 scibite: No hits
# API 6.213 scibite: No hits
# API 6.214 scibite: No hits
# API 6.215 scibite: No hits
# API 6.216 scibite: No hits
# API 6.217 scibite: No hits
# API 6.218 scibite: No hits
# API 6.219 scibite: No hits
# API 6.220 scibite: No hits
# API 6.221 scibite: No hits
# API 6.222 scibite: No hits
# API 6.223 scibite: No hits
# API 6.224 scibite: No hits
# API 6.225 scibite: No hits
# API 6.226 scibite: No hits
# API 6.227 scibite: No hits
# API 6.228 scibite: No hits
# API 6.229 scibite: No hits
# API 6.230 scibite: No hits
# API 6.231 scibite: No hits
# API 6.232 scibite: No hits
# API 6.233 scibite: No hits
# API 6.234 scibite: No hits
# API 6.235 scibite: No hits
# API 6.236 scibite: No hits
# API 6.237 scibite: No hits
# API 6.238 scibite: No hits
# API 6.239 scibite: No hits
# API 6.240 scibite: No hits
# API 6.241 scibite: No hits
# API 6.242 scibite: No hits
# API 6.243 scibite: No hits
# API 6.244 scibite: No hits
# API 6.245 scibite: No hits
# API 6.246 scibite: No hits
# API 6.247 scibite: No hits
# API 6.248 scibite: No hits
# API 6.249 scibite: No hits
# API 6.250 scibite: No hits
# API 6.251 scibite: No hits
# API 6.252 scibite: No hits
# API 6.253 scibite: No hits
# API 6.254 scibite: No hits
# API 6.255 scibite: No hits
# API 6.256 scibite: No hits
# API 6.257 scibite: No hits
# API 6.258 scibite: No hits
# API 6.259 scibite: No hits
# API 6.260 scibite: No hits
# API 6.261 scibite: No hits
# API 6.262 scibite: No hits
# API 6.263 scibite: No hits
# API 6.264 scibite: No hits
# API 6.265 scibite: No hits
# API 6.266 scibite: No hits
# API 6.267 scibite: No hits
# API 6.268 scibite: No hits
# API 6.269 scibite: No hits
# API 6.270 scibite: No hits
# API 6.271 scibite: No hits
# API 6.272 scibite: No hits
# API 6.273 scibite: No hits
# API 6.274 scibite: No hits
# API 6.275 scibite: No hits
# API 6.276 scibite: No hits
# API 1.6 semmed_disease: 27753 hits
# API 3.1 pharos: No hits
# API 3.2 pharos: No hits
# API 3.3 pharos: No hits
# API 3.4 pharos: No hits
# API 3.5 pharos: No hits
# API 3.6 pharos: No hits
# API 3.7 pharos: No hits
# API 3.8 pharos: No hits
# API 3.9 pharos: No hits
# API 3.10 pharos: No hits
# API 3.11 pharos: No hits
# API 3.12 pharos: No hits
# API 3.13 pharos: No hits
# API 3.14 pharos: No hits
# API 3.15 pharos: No hits
# API 3.16 pharos: No hits
# API 3.17 pharos: No hits
# API 3.18 pharos: No hits
# API 3.19 pharos: No hits
# API 3.20 pharos: No hits
# API 3.21 pharos: No hits
# API 3.22 pharos: No hits
# API 3.23 pharos: No hits
# API 3.24 pharos: No hits
# API 3.25 pharos: No hits
# API 3.26 pharos: No hits
# API 3.27 pharos: No hits
# API 3.28 pharos: No hits
# API 3.29 pharos: No hits
# API 3.30 pharos: No hits
# API 3.31 pharos: No hits
# API 3.32 pharos: No hits
# API 3.33 pharos: No hits
# API 3.34 pharos: No hits
# API 3.35 pharos: No hits
# API 3.36 pharos: No hits
# API 3.37 pharos: No hits
# API 3.38 pharos: No hits
# API 3.39 pharos: No hits
# API 3.40 pharos: No hits
# API 3.41 pharos: No hits
# API 3.42 pharos: No hits
# API 3.43 pharos: No hits
# API 3.44 pharos: No hits
# API 3.45 pharos: No hits
# API 3.46 pharos: No hits
# API 3.47 pharos: No hits
# API 3.48 pharos: No hits
# API 3.49 pharos: No hits
# API 3.50 pharos: No hits
# API 3.51 pharos: No hits
# API 3.52 pharos: No hits
# API 3.53 pharos: No hits
# API 3.54 pharos: No hits
# API 3.55 pharos: No hits
# API 3.56 pharos: No hits
# API 3.57 pharos: No hits
# API 3.58 pharos: No hits
# API 3.59 pharos: No hits
# API 3.60 pharos: No hits
# API 3.61 pharos: No hits
# API 3.62 pharos: No hits
# API 3.63 pharos: No hits
# API 3.64 pharos: No hits
# API 3.65 pharos: No hits
# API 3.66 pharos: No hits
# API 3.67 pharos: No hits
# API 3.68 pharos: No hits
# API 3.69 pharos: No hits
# API 3.70 pharos: No hits
# API 3.71 pharos: No hits
# API 3.72 pharos: No hits
# API 3.73 pharos: No hits
# API 3.74 pharos: No hits
# API 3.75 pharos: No hits
# API 3.76 pharos: No hits
# API 3.77 pharos: No hits
# API 3.78 pharos: No hits
# API 3.79 pharos: No hits
# API 3.80 pharos: No hits
# API 3.81 pharos: No hits
# API 3.82 pharos: No hits
# API 3.83 pharos: No hits
# API 3.84 pharos: No hits
# API 3.85 pharos: No hits
# API 3.86 pharos: No hits
# API 3.87 pharos: No hits
# API 3.88 pharos: No hits
# API 3.89 pharos: No hits
# API 3.90 pharos: No hits
# API 3.91 pharos: No hits
# API 3.92 pharos: No hits
# API 3.93 pharos: No hits
# API 3.94 pharos: No hits
# API 3.95 pharos: No hits
# API 3.96 pharos: No hits
# API 3.97 pharos: No hits
# API 3.98 pharos: No hits
# API 3.99 pharos: No hits
# API 3.100 pharos: No hits
# API 3.101 pharos: No hits
# API 3.102 pharos: No hits
# API 3.103 pharos: No hits
# API 3.104 pharos: No hits
# API 3.105 pharos: No hits
# API 3.106 pharos: No hits
# API 3.107 pharos: No hits
# API 3.108 pharos: No hits
# API 3.109 pharos: No hits
# API 3.110 pharos: No hits
# API 3.111 pharos: No hits
# API 3.112 pharos: No hits
# API 3.113 pharos: No hits
# API 3.114 pharos: No hits
# API 3.115 pharos: No hits
# API 3.116 pharos: No hits
# API 3.117 pharos: No hits
# API 3.118 pharos: No hits
# API 3.119 pharos: No hits
# API 3.120 pharos: No hits
# API 3.121 pharos: No hits
# API 3.122 pharos: No hits
# API 3.123 pharos: No hits
# API 3.124 pharos: No hits
# API 3.125 pharos: No hits
# API 3.126 pharos: No hits
# API 3.127 pharos: No hits
# API 3.128 pharos: No hits
# API 3.129 pharos: No hits
# API 3.130 pharos: No hits
# API 3.131 pharos: No hits
# API 3.132 pharos: No hits
# API 3.133 pharos: No hits
# API 3.134 pharos: No hits
# API 3.135 pharos: No hits
# API 3.136 pharos: No hits
# API 3.137 pharos: No hits
# API 3.138 pharos: No hits
# API 3.139 pharos: No hits
# API 3.140 pharos: No hits
# API 3.141 pharos: No hits
# API 3.142 pharos: No hits
# API 3.143 pharos: No hits
# API 3.144 pharos: No hits
# API 3.145 pharos: No hits
# API 3.146 pharos: No hits
# API 3.147 pharos: No hits
# API 3.148 pharos: No hits
# API 3.149 pharos: No hits
# API 3.150 pharos: No hits
# API 3.151 pharos: No hits
# API 3.152 pharos: No hits
# API 3.153 pharos: No hits
# API 3.154 pharos: No hits
# API 3.155 pharos: No hits
# API 3.156 pharos: No hits
# API 3.157 pharos: No hits
# API 3.158 pharos: No hits
# API 3.159 pharos: No hits
# API 3.160 pharos: No hits
# API 3.161 pharos: No hits
# API 3.162 pharos: No hits
# API 3.163 pharos: No hits
# API 3.164 pharos: No hits
# API 3.165 pharos: No hits
# API 3.166 pharos: No hits
# API 3.167 pharos: No hits
# API 3.168 pharos: No hits
# API 3.169 pharos: No hits
# API 3.170 pharos: No hits
# API 3.171 pharos: No hits
# API 3.172 pharos: No hits
# API 3.173 pharos: No hits
# API 3.174 pharos: No hits
# API 3.175 pharos: No hits
# API 3.176 pharos: No hits
# API 3.177 pharos: No hits
# API 3.178 pharos: No hits
# API 3.179 pharos: No hits
# API 3.180 pharos: No hits
# API 3.181 pharos: No hits
# API 3.182 pharos: No hits
# API 3.183 pharos: No hits
# API 3.184 pharos: No hits
# API 3.185 pharos: No hits
# API 3.186 pharos: No hits
# API 3.187 pharos: No hits
# API 3.188 pharos: No hits
# API 3.189 pharos: No hits
# API 3.190 pharos: No hits
# API 3.191 pharos: No hits
# API 3.192 pharos: No hits
# API 3.193 pharos: No hits
# API 3.194 pharos: No hits
# API 3.195 pharos: No hits
# API 3.196 pharos: No hits
# API 3.197 pharos: No hits
# API 3.198 pharos: No hits
# API 3.199 pharos: No hits
# API 3.200 pharos: No hits
# API 3.201 pharos: No hits
# API 3.202 pharos: No hits
# API 3.203 pharos: No hits
# API 3.204 pharos: No hits
# API 3.205 pharos: No hits
# API 3.206 pharos: No hits
# API 3.207 pharos: No hits
# API 3.208 pharos: No hits
# API 3.209 pharos: No hits
# API 3.210 pharos: No hits
# API 3.211 pharos: No hits
# API 3.212 pharos: No hits
# API 3.213 pharos: No hits
# API 3.214 pharos: No hits
# API 3.215 pharos: No hits
# API 3.216 pharos: No hits
# API 3.217 pharos: No hits
# API 3.218 pharos: No hits
# API 3.219 pharos: No hits
# API 3.220 pharos: No hits
# API 3.221 pharos: No hits
# API 3.222 pharos: No hits
# API 3.223 pharos: No hits
# API 3.224 pharos: No hits
# API 3.225 pharos: No hits
# API 3.226 pharos: No hits
# API 3.227 pharos: No hits
# API 3.228 pharos: No hits
# API 3.229 pharos: No hits
# API 3.230 pharos: No hits
# API 3.231 pharos: No hits
# API 3.232 pharos: No hits
# API 3.233 pharos: No hits
# API 3.234 pharos: No hits
# API 3.235 pharos: No hits
# API 3.236 pharos: No hits
# API 3.237 pharos: No hits
# API 3.238 pharos: No hits
# API 3.239 pharos: No hits
# API 3.240 pharos: No hits
# API 3.241 pharos: No hits
# API 3.242 pharos: No hits
# API 3.243 pharos: No hits
# API 3.244 pharos: No hits
# API 3.245 pharos: No hits
# API 3.246 pharos: No hits
# API 3.247 pharos: No hits
# API 3.248 pharos: No hits
# API 3.249 pharos: No hits
# API 3.250 pharos: No hits
# API 3.251 pharos: No hits
# API 3.252 pharos: No hits
# API 3.253 pharos: No hits
# API 3.254 pharos: No hits
# API 3.255 pharos: No hits
# API 3.256 pharos: No hits
# API 3.257 pharos: No hits
# API 3.258 pharos: No hits
# API 3.259 pharos: No hits
# API 3.260 pharos: No hits
# API 3.261 pharos: No hits
# API 3.262 pharos: No hits
# API 3.263 pharos: No hits
# API 3.264 pharos: No hits
# API 3.265 pharos: No hits
# API 3.266 pharos: No hits
# API 3.267 pharos: No hits
# API 3.268 pharos: No hits
# API 3.269 pharos: No hits
# API 3.270 pharos: No hits
# API 3.271 pharos: No hits
# API 3.272 pharos: No hits
# API 3.273 pharos: No hits
# API 3.274 pharos: No hits
# API 3.275 pharos: No hits
# API 3.276 pharos: No hits
# API 1.7 semmed_disease: No hits
# API 1.8 semmed_disease: 52255 hits
# API 1.9 semmed_disease: 23763 hits
# API 1.10 semmed_disease: 9 hits
# API 1.11 semmed_disease: No hits
# API 1.12 semmed_disease: 26020 hits
# API 1.13 semmed_disease: No hits
# API 1.14 semmed_disease: 1042 hits
# API 7.1 mydisease: 4591 hits
# API 1.15 semmed_disease: 1 hits
#
# After id-to-object translation, BTE retrieved 18049 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# In the #1 query, BTE found 11 unique Gene nodes
# In the #2 query, BTE found 565 unique Disease nodes
# In the #3 query, BTE found 18049 unique ChemicalSubstance nodes

# %% [markdown]
# ## Step 3: Assemble and filter the results
#
# Let's create a `df` object that contains the full output from BioThings Explorer. Each row will show one path that joins the input node to an intermediate node (a `Gene`) to another intermediate node (a `Disease`) to an ending node (a `ChemicalSubstance`). The data frame includes a set of columns with additional details on each node and edge (including human-readable labels, identifiers, and sources).

# %%
df = fc.display_table_view()

# %%
df
# Out:
#                                                      input input_type  \
# 0        ALACRIMIA - CHOREOATHETOSIS - LIVER DYSFUNCTIO...    Disease
# 1        ALACRIMIA - CHOREOATHETOSIS - LIVER DYSFUNCTIO...    Disease
# 3        ALACRIMIA - CHOREOATHETOSIS - LIVER DYSFUNCTIO...    Disease
# 4        ALACRIMIA - CHOREOATHETOSIS - LIVER DYSFUNCTIO...    Disease
# 10       ALACRIMIA - CHOREOATHETOSIS - LIVER DYSFUNCTIO...    Disease
# ...                                                    ...        ...
# 1438837  ALACRIMIA - CHOREOATHETOSIS - LIVER DYSFUNCTIO...    Disease
# 1438838  ALACRIMIA - CHOREOATHETOSIS - LIVER DYSFUNCTIO...    Disease
# 1438839  ALACRIMIA - CHOREOATHETOSIS - LIVER DYSFUNCTIO...    Disease
# 1438840  ALACRIMIA - CHOREOATHETOSIS - LIVER DYSFUNCTIO...    Disease
# 1438841  ALACRIMIA - CHOREOATHETOSIS - LIVER DYSFUNCTIO...    Disease
#
#               pred1 pred1_source           pred1_api pred1_pubmed node1_type  \
# 0        related_to     disgenet  mydisease.info API         None       Gene
# 1        related_to      DISEASE        DISEASES API         None       Gene
# 3        related_to         None         BioLink API         None       Gene
# 4        related_to     disgenet  mydisease.info API         None       Gene
# 10       related_to     disgenet  mydisease.info API         None       Gene
# ...             ...          ...                 ...          ...        ...
# 1438837  related_to     disgenet  mydisease.info API         None       Gene
# 1438838  related_to     disgenet  mydisease.info API         None       Gene
# 1438839  related_to     disgenet  mydisease.info API         None       Gene
# 1438840  related_to     disgenet  mydisease.info API         None       Gene
# 1438841  related_to     disgenet  mydisease.info API         None       Gene
#
#         node1_name        node1_id       pred2  ... node2_type  \
# 0             PGM1   NCBIGene:5236      treats  ...    Disease
# 1            NGLY1  NCBIGene:55768  related_to  ...    Disease
# 3            NGLY1  NCBIGene:55768  related_to  ...    Disease
# 4            NGLY1  NCBIGene:55768  related_to  ...    Disease
# 10            PGM1   NCBIGene:5236  related_to  ...    Disease
# ...            ...             ...         ...  ...        ...
# 1438837       PGM1   NCBIGene:5236  related_to  ...    Disease
# 1438838       PGM1   NCBIGene:5236  related_to  ...    Disease
# 1438839       PGM1   NCBIGene:5236  related_to  ...    Disease
# 1438840       PGM1   NCBIGene:5236  related_to  ...    Disease
# 1438841       PGM1   NCBIGene:5236  related_to  ...    Disease
#
#                               node2_name             node2_id         pred3  \
# 0                               C0302148        UMLS:C0302148  disrupted_by
# 1                               C0699748        UMLS:C0699748  disrupted_by
# 3                               C0699748        UMLS:C0699748  disrupted_by
# 4                               C0699748        UMLS:C0699748  disrupted_by
# 10                              C0699748        UMLS:C0699748  disrupted_by
# ...                                  ...                  ...           ...
# 1438837                  BENIGN NEOPLASM  MONDO:MONDO:0005165    treated_by
# 1438838                  BENIGN NEOPLASM  MONDO:MONDO:0005165    related_to
# 1438839               CUTANEOUS DISORDER  MONDO:MONDO:0005093    related_to
# 1438840  ANESTHESIA RELATED HYPERTHERMIA  MONDO:MONDO:0018493  prevented_by
# 1438841  ANESTHESIA RELATED HYPERTHERMIA  MONDO:MONDO:0018493     caused_by
#
#                             pred3_source           pred3_api  \
# 0                                 SEMMED  SEMMED Disease API
# 1                                 SEMMED  SEMMED Disease API
# 3                                 SEMMED  SEMMED Disease API
# 4                                 SEMMED  SEMMED Disease API
# 10                                SEMMED  SEMMED Disease API
# ...                                  ...                 ...
# 1438837                           SEMMED  SEMMED Disease API
# 1438838                           SEMMED  SEMMED Disease API
# 1438839  Translator Text Mining Provider    CORD Disease API
# 1438840                           SEMMED  SEMMED Disease API
# 1438841                           SEMMED  SEMMED Disease API
#
#              pred3_pubmed        output_type  \
# 0                28007597  ChemicalSubstance
# 1        23904484,8744542  ChemicalSubstance
# 3        23904484,8744542  ChemicalSubstance
# 4        23904484,8744542  ChemicalSubstance
# 10       23904484,8744542  ChemicalSubstance
# ...                   ...                ...
# 1438837           6261923  ChemicalSubstance
# 1438838          28598117  ChemicalSubstance
# 1438839              None  ChemicalSubstance
# 1438840           9417254  ChemicalSubstance
# 1438841   3944580,3981112  ChemicalSubstance
#
#                                 output_name  \
# 0                                  C1328819
# 1                                  C1328819
# 3                                  C1328819
# 4                                  C1328819
# 10                                 C1328819
# ...                                     ...
# 1438837                              AR 100
# 1438838            NUMB PROTEIN, DROSOPHILA
# 1438839                         CHEBI:63562
# 1438840  1-CHLORO-2-METHYL-4-HYDROXYBENZENE
# 1438841                             PARNATE
#
#                                        output_id
# 0                                  UMLS:C1328819
# 1                                  UMLS:C1328819
# 3                                  UMLS:C1328819
# 4                                  UMLS:C1328819
# 10                                 UMLS:C1328819
# ...                                          ...
# 1438837                              name:AR 100
# 1438838            name:NUMB PROTEIN, DROSOPHILA
# 1438839                        CHEBI:CHEBI:63562
# 1438840  name:1-CHLORO-2-METHYL-4-HYDROXYBENZENE
# 1438841                             name:PARNATE
#
# [791464 rows x 23 columns]

# %% [markdown]
# Let's do some profiling of the predicates, and then let's filter `pred3` to only include `treated_by` edges.

# %%
df.pred1.value_counts()
# Out:
# related_to    791464
# Name: pred1, dtype: int64

# %%
df.pred2.value_counts()
# Out:
# related_to    682484
# causes         67867
# treats         15993
# affects        15002
# disrupts        9858
# prevents         260
# Name: pred2, dtype: int64

# %%
df.pred3.value_counts()
# Out:
# treated_by                   252482
# related_to                   159053
# affected_by                  133456
# caused_by                    124002
# prevented_by                  57189
# disrupted_by                  54730
# contraindicated_by             7046
# negatively_regulated_by        3297
# coexists_with                   111
# affects                          60
# physically_interacts_with        35
# positively_regulated_by           3
# Name: pred3, dtype: int64

# %%
dfFilt = df.loc[df['output_name'].notnull()].query('pred3 == "treated_by"')

# %%
dfFilt
# Out:
#                                                      input input_type  \
# 11       ALACRIMIA - CHOREOATHETOSIS - LIVER DYSFUNCTIO...    Disease
# 13       ALACRIMIA - CHOREOATHETOSIS - LIVER DYSFUNCTIO...    Disease
# 14       ALACRIMIA - CHOREOATHETOSIS - LIVER DYSFUNCTIO...    Disease
# 20       ALACRIMIA - CHOREOATHETOSIS - LIVER DYSFUNCTIO...    Disease
# 32       ALACRIMIA - CHOREOATHETOSIS - LIVER DYSFUNCTIO...    Disease
# ...                                                    ...        ...
# 1438799  ALACRIMIA - CHOREOATHETOSIS - LIVER DYSFUNCTIO...    Disease
# 1438800  ALACRIMIA - CHOREOATHETOSIS - LIVER DYSFUNCTIO...    Disease
# 1438835  ALACRIMIA - CHOREOATHETOSIS - LIVER DYSFUNCTIO...    Disease
# 1438836  ALACRIMIA - CHOREOATHETOSIS - LIVER DYSFUNCTIO...    Disease
# 1438837  ALACRIMIA - CHOREOATHETOSIS - LIVER DYSFUNCTIO...    Disease
#
#               pred1 pred1_source           pred1_api pred1_pubmed node1_type  \
# 11       related_to      DISEASE        DISEASES API         None       Gene
# 13       related_to         None         BioLink API         None       Gene
# 14       related_to     disgenet  mydisease.info API         None       Gene
# 20       related_to     disgenet  mydisease.info API         None       Gene
# 32       related_to     disgenet  mydisease.info API         None       Gene
# ...             ...          ...                 ...          ...        ...
# 1438799  related_to     disgenet  mydisease.info API         None       Gene
# 1438800  related_to     disgenet  mydisease.info API         None       Gene
# 1438835  related_to     disgenet  mydisease.info API         None       Gene
# 1438836  related_to     disgenet  mydisease.info API         None       Gene
# 1438837  related_to     disgenet  mydisease.info API         None       Gene
#
#         node1_name        node1_id       pred2  ... node2_type  \
# 11           NGLY1  NCBIGene:55768  related_to  ...    Disease
# 13           NGLY1  NCBIGene:55768  related_to  ...    Disease
# 14           NGLY1  NCBIGene:55768  related_to  ...    Disease
# 20            PGM1   NCBIGene:5236  related_to  ...    Disease
# 32            PGM1   NCBIGene:5236     affects  ...    Disease
# ...            ...             ...         ...  ...        ...
# 1438799       PGM1   NCBIGene:5236  related_to  ...    Disease
# 1438800       PGM1   NCBIGene:5236  related_to  ...    Disease
# 1438835       PGM1   NCBIGene:5236  related_to  ...    Disease
# 1438836       PGM1   NCBIGene:5236  related_to  ...    Disease
# 1438837       PGM1   NCBIGene:5236  related_to  ...    Disease
#
#               node2_name             node2_id       pred3 pred3_source  \
# 11              C0699748        UMLS:C0699748  treated_by       SEMMED
# 13              C0699748        UMLS:C0699748  treated_by       SEMMED
# 14              C0699748        UMLS:C0699748  treated_by       SEMMED
# 20              C0699748        UMLS:C0699748  treated_by       SEMMED
# 32              C0242656        UMLS:C0242656  treated_by       SEMMED
# ...                  ...                  ...         ...          ...
# 1438799              CAD  MONDO:MONDO:0005010  treated_by       SEMMED
# 1438800              CAD  MONDO:MONDO:0005010  treated_by       SEMMED
# 1438835  BENIGN NEOPLASM  MONDO:MONDO:0005165  treated_by       SEMMED
# 1438836  BENIGN NEOPLASM  MONDO:MONDO:0005165  treated_by       SEMMED
# 1438837  BENIGN NEOPLASM  MONDO:MONDO:0005165  treated_by       SEMMED
#
#                   pred3_api                pred3_pubmed        output_type  \
# 11       SEMMED Disease API                    27821778  ChemicalSubstance
# 13       SEMMED Disease API                    27821778  ChemicalSubstance
# 14       SEMMED Disease API                    27821778  ChemicalSubstance
# 20       SEMMED Disease API                    27821778  ChemicalSubstance
# 32       SEMMED Disease API  24234649,26311256,27529062  ChemicalSubstance
# ...                     ...                         ...                ...
# 1438799  SEMMED Disease API                      347136  ChemicalSubstance
# 1438800  SEMMED Disease API                     1527926  ChemicalSubstance
# 1438835  SEMMED Disease API                     9374344  ChemicalSubstance
# 1438836  SEMMED Disease API                      961054  ChemicalSubstance
# 1438837  SEMMED Disease API                     6261923  ChemicalSubstance
#
#                                        output_name  \
# 11                                        C1328819
# 13                                        C1328819
# 14                                        C1328819
# 20                                        C1328819
# 32                                        C1328819
# ...                                            ...
# 1438799                                      XAVIN
# 1438800                                     PREBET
# 1438835  TECHNETIUM TC 99M DIMERCAPTOSUCCINIC ACID
# 1438836                           KARCHAULI LIQUID
# 1438837                                     AR 100
#
#                                               output_id
# 11                                        UMLS:C1328819
# 13                                        UMLS:C1328819
# 14                                        UMLS:C1328819
# 20                                        UMLS:C1328819
# 32                                        UMLS:C1328819
# ...                                                 ...
# 1438799                                      name:XAVIN
# 1438800                                     name:PREBET
# 1438835  name:TECHNETIUM TC 99M DIMERCAPTOSUCCINIC ACID
# 1438836                           name:KARCHAULI LIQUID
# 1438837                                     name:AR 100
#
# [252482 rows x 23 columns]

# %% [markdown]
# ## Step 4: Summarize output `ChemicalSubstance`s

# %%
dfFilt.output_name.value_counts().head(50)
# Out:
# PHARMACEUTICAL PREPARATIONS                                                                                                                557
# C0450442                                                                                                                                   419
# C0243077                                                                                                                                   381
# C1611640                                                                                                                                   327
# ANTIOXIDANTS                                                                                                                               317
# ADRENAL CORTEX HORMONES                                                                                                                    310
# AGONISTS                                                                                                                                   305
# (+)-GLUCOSE                                                                                                                                300
# C0243076                                                                                                                                   299
# 1-HYDROXYETHANE                                                                                                                            289
# ANTIBIOTIC                                                                                                                                 287
# ANESTHETICS                                                                                                                                279
# 2-((ALL-E)-3,7,11,15,19,23,27,31,35,39-DECAMETHYL-2,6,10,14,18,22,26,30,34,38-TETRACONTADECAENYL)-5,6-DIMETHOXY-3-METHYL-P-BENZOQUINONE    272
# AGENTS, PROTECTIVE                                                                                                                         266
# 4-AMINO-10-METHYLFOLIC ACID                                                                                                                264
# C0309049                                                                                                                                   264
# VITAMIN D                                                                                                                                  263
# C.I. 75300                                                                                                                                 261
# (11BETA)-11,17,21-TRIHYDROXYPREGN-4-ENE-3,20-DIONE                                                                                         260
# ANABOLIC STEROIDS                                                                                                                          259
# 5-METHOXY-N-ACETYLTRYPTAMINE                                                                                                               253
# 2-(ACETYLOXY)BENZOIC ACID                                                                                                                  252
# C1513403                                                                                                                                   248
# AGENTS, ANTI-ANXIETY                                                                                                                       247
# (+-)-CYCLOPHOSPHAMIDE                                                                                                                      246
# 26FE                                                                                                                                       238
# HYDROXYMETHYLGLUTARYL COA REDUCTASE INHIBITORS                                                                                             237
# (17BETA)-ESTRA-1,3,5(10)-TRIENE-3,17-DIOL                                                                                                  235
# (11BETA,16ALPHA)-9-FLUORO-11,17,21-TRIHYDROXY-16-METHYLPREGNA-1,4-DIENE-3,20-DIONE                                                         234
# (-)-RAPAMYCIN                                                                                                                              233
# ANTI-INFLAMMATORY AGENTS, NON-STEROIDAL                                                                                                    233
# GLUCOCORTICOID                                                                                                                             232
# ARALEN                                                                                                                                     230
# (11BETA)-11,17,21-TRIHYDROXYPREGNA-1,4-DIENE-3,20-DIONE                                                                                    230
# 1,2-DEHYDROCORTISONE                                                                                                                       230
# ACIDE ASCORBIQUE                                                                                                                           229
# 17BETA-HYDROXY-4-ANDROSTEN-3-ONE                                                                                                           224
# DIPHTHERIA VACCINES                                                                                                                        222
# (1)O2                                                                                                                                      222
# 10% SODIUM CHLORIDE INJECTION                                                                                                              221
# C0243071                                                                                                                                   220
# BIOLOGICAL RESPONSE MODIFIERS                                                                                                              220
# LACTATE                                                                                                                                    218
# 30ZN                                                                                                                                       217
# ORALIT                                                                                                                                     216
# AGENTS, ANTINEOPLASTIC                                                                                                                     216
# C1254351                                                                                                                                   216
# 1,1-DIMETHYLBIGUANIDE                                                                                                                      215
# 29CU                                                                                                                                       214
# C0597177                                                                                                                                   213
# Name: output_name, dtype: int64

# %% [markdown]
# Suppose we are interested in the links behind `5-METHOXY-N-ACETYLTRYPTAMINE`. Let's examine that subset of paths, specifically printing the frequency of the intermediate `Gene`s and `Disease`s.

# %%
dfFilt2 = dfFilt.query('output_name == "5-METHOXY-N-ACETYLTRYPTAMINE"')
dfFilt2
# Out:
#                                                     input input_type  \
# 140463  ALACRIMIA - CHOREOATHETOSIS - LIVER DYSFUNCTIO...    Disease
# 140465  ALACRIMIA - CHOREOATHETOSIS - LIVER DYSFUNCTIO...    Disease
# 140466  ALACRIMIA - CHOREOATHETOSIS - LIVER DYSFUNCTIO...    Disease
# 140472  ALACRIMIA - CHOREOATHETOSIS - LIVER DYSFUNCTIO...    Disease
# 140495  ALACRIMIA - CHOREOATHETOSIS - LIVER DYSFUNCTIO...    Disease
# ...                                                   ...        ...
# 142491  ALACRIMIA - CHOREOATHETOSIS - LIVER DYSFUNCTIO...    Disease
# 142492  ALACRIMIA - CHOREOATHETOSIS - LIVER DYSFUNCTIO...    Disease
# 142493  ALACRIMIA - CHOREOATHETOSIS - LIVER DYSFUNCTIO...    Disease
# 142496  ALACRIMIA - CHOREOATHETOSIS - LIVER DYSFUNCTIO...    Disease
# 142499  ALACRIMIA - CHOREOATHETOSIS - LIVER DYSFUNCTIO...    Disease
#
#              pred1 pred1_source           pred1_api pred1_pubmed node1_type  \
# 140463  related_to      DISEASE        DISEASES API         None       Gene
# 140465  related_to         None         BioLink API         None       Gene
# 140466  related_to     disgenet  mydisease.info API         None       Gene
# 140472  related_to     disgenet  mydisease.info API         None       Gene
# 140495  related_to      DISEASE        DISEASES API         None       Gene
# ...            ...          ...                 ...          ...        ...
# 142491  related_to     disgenet  mydisease.info API         None       Gene
# 142492  related_to     disgenet  mydisease.info API         None       Gene
# 142493  related_to     disgenet  mydisease.info API         None       Gene
# 142496  related_to     disgenet  mydisease.info API         None       Gene
# 142499  related_to     disgenet  mydisease.info API         None       Gene
#
#        node1_name        node1_id       pred2  ... node2_type  \
# 140463      NGLY1  NCBIGene:55768  related_to  ...    Disease
# 140465      NGLY1  NCBIGene:55768  related_to  ...    Disease
# 140466      NGLY1  NCBIGene:55768  related_to  ...    Disease
# 140472       PGM1   NCBIGene:5236  related_to  ...    Disease
# 140495       PMM2   NCBIGene:5373      causes  ...    Disease
# ...           ...             ...         ...  ...        ...
# 142491       PGM1   NCBIGene:5236  related_to  ...    Disease
# 142492       PGM1   NCBIGene:5236  related_to  ...    Disease
# 142493       PGM1   NCBIGene:5236  related_to  ...    Disease
# 142496       PGM1   NCBIGene:5236  related_to  ...    Disease
# 142499       PGM1   NCBIGene:5236  related_to  ...    Disease
#
#                             node2_name             node2_id       pred3  \
# 140463                        C0699748        UMLS:C0699748  treated_by
# 140465                        C0699748        UMLS:C0699748  treated_by
# 140466                        C0699748        UMLS:C0699748  treated_by
# 140472                        C0699748        UMLS:C0699748  treated_by
# 140495                        C0025362        UMLS:C0025362  treated_by
# ...                                ...                  ...         ...
# 142491             DIFFUSE SCLERODERMA  MONDO:MONDO:0005100  treated_by
# 142492             ACTIVE TUBERCULOSIS  MONDO:MONDO:0018076  treated_by
# 142493                             CAD  MONDO:MONDO:0005010  treated_by
# 142496                             CAD  MONDO:MONDO:0005010  treated_by
# 142499  DISORDER OF GLUCOSE METABOLISM  MONDO:MONDO:0002908  treated_by
#
#        pred3_source           pred3_api  \
# 140463       SEMMED  SEMMED Disease API
# 140465       SEMMED  SEMMED Disease API
# 140466       SEMMED  SEMMED Disease API
# 140472       SEMMED  SEMMED Disease API
# 140495       SEMMED  SEMMED Disease API
# ...             ...                 ...
# 142491       SEMMED  SEMMED Disease API
# 142492       SEMMED  SEMMED Disease API
# 142493       SEMMED  SEMMED Disease API
# 142496       SEMMED  SEMMED Disease API
# 142499       SEMMED  SEMMED Disease API
#
#                                       pred3_pubmed        output_type  \
# 140463                           18289174,23312686  ChemicalSubstance
# 140465                           18289174,23312686  ChemicalSubstance
# 140466                           18289174,23312686  ChemicalSubstance
# 140472                           18289174,23312686  ChemicalSubstance
# 140495                                    15275698  ChemicalSubstance
# ...                                            ...                ...
# 142491                           16173262,16428927  ChemicalSubstance
# 142492                                    22430231  ChemicalSubstance
# 142493  10235654,11777084,15702887,7760612,9441519  ChemicalSubstance
# 142496                  15754851,16377274,20210856  ChemicalSubstance
# 142499                                    26853813  ChemicalSubstance
#
#                          output_name                          output_id
# 140463  5-METHOXY-N-ACETYLTRYPTAMINE  name:5-METHOXY-N-ACETYLTRYPTAMINE
# 140465  5-METHOXY-N-ACETYLTRYPTAMINE  name:5-METHOXY-N-ACETYLTRYPTAMINE
# 140466  5-METHOXY-N-ACETYLTRYPTAMINE  name:5-METHOXY-N-ACETYLTRYPTAMINE
# 140472  5-METHOXY-N-ACETYLTRYPTAMINE  name:5-METHOXY-N-ACETYLTRYPTAMINE
# 140495  5-METHOXY-N-ACETYLTRYPTAMINE  name:5-METHOXY-N-ACETYLTRYPTAMINE
# ...                              ...                                ...
# 142491  5-METHOXY-N-ACETYLTRYPTAMINE  name:5-METHOXY-N-ACETYLTRYPTAMINE
# 142492  5-METHOXY-N-ACETYLTRYPTAMINE  name:5-METHOXY-N-ACETYLTRYPTAMINE
# 142493  5-METHOXY-N-ACETYLTRYPTAMINE  name:5-METHOXY-N-ACETYLTRYPTAMINE
# 142496  5-METHOXY-N-ACETYLTRYPTAMINE  name:5-METHOXY-N-ACETYLTRYPTAMINE
# 142499  5-METHOXY-N-ACETYLTRYPTAMINE  name:5-METHOXY-N-ACETYLTRYPTAMINE
#
# [253 rows x 23 columns]

# %%
dfFilt2.node1_name.value_counts().head(50)
# Out:
# NGLY1     87
# PMM2      45
# PGM1      31
# FAF1      26
# NFE2L1    19
# FBXO2     12
# ENGASE    10
# FBXO6      7
# ALG14      6
# GMPPA      6
# DDI2       4
# Name: node1_name, dtype: int64

# %%
dfFilt2.node2_name.value_counts().head(50)
# Out:
# CONDITION                                   20
# CELL PROCESS DISEASE                        20
# CA                                          19
# MALIGNANT NEOPLASM OF STOMACH                8
# SCOLIOSIS                                    7
# DIABETES                                     6
# DISEASE OF METABOLISM                        6
# AD                                           6
# EPILEPSY, VISUAL                             5
# DIABETES MELLITUS, NON-INSULIN-DEPENDENT     5
# ARTHRITIS OR POLYARTHRITIS, RHEUMATIC        4
# PERICENTRAL PIGMENTARY RETINOPATHY           4
# CARCINOGENESIS                               4
# DISEASE OF LIVER                             4
# BREAST CANCER, FAMILIAL                      4
# FAILURE TO THRIVE                            4
# FEVER                                        4
# OSTEOPENIA                                   4
# C0699748                                     4
# BONE DISEASE                                 3
# C0277785                                     3
# MALIGNANT MELANOMA                           3
# ABSENCE OF PAIN SENSATION                    3
# PAIN                                         3
# APNEA, OBSTRUCTIVE SLEEP                     3
# C0038435                                     3
# GLIOSIS                                      3
# HYPERHIDROSIS DISORDER                       3
# HYPERACTIVE BEHAVIOR                         3
# MYOCLONUS                                    3
# ALS                                          3
# ALCOHOLIC FATTY LIVER                        3
# HEART ATTACK                                 3
# DISEASE OF KIDNEY                            3
# CANCER OF LARGE BOWEL                        2
# HYPERGLYCEMIA                                2
# C0025362                                     2
# INFECTION, VIRAL                             2
# BLOOD DISEASE                                2
# NB                                           2
# INSULIN RESISTANCE                           2
# DISEASE OF NERVOUS SYSTEM                    2
# NEOPLASM METASTASIS                          2
# CAD                                          2
# ADOLESCENT IDIOPATHIC SCOLIOSIS              2
# ALOPECIA                                     2
# ADENOCARCINOMA OF KIDNEY                     2
# MULTIPLE SCLEROSIS, PRIMARY PROGRESSIVE      2
# INDUCED MALARIA                              2
# NEUROLOGIC DEFICITS                          1
# Name: node2_name, dtype: int64

# %% [markdown]
# ## Step 5: export full results to TRAPI
#
# (though this export is not yet TRAPI v1.0 compliant, pending resolution of [this issue](https://github.com/biothings/biothings_explorer/issues/169)...)

# %%
fc.to_reasoner_std()
# Out:
# {'query_graph': {'edges': [{'id': 'e0',
#     'source_id': 'n0',
#     'target_id': 'n1',
#     'directed': True},
#    {'id': 'e1', 'source_id': 'n1', 'target_id': 'n2', 'directed': True},
#    {'id': 'e2', 'source_id': 'n2', 'target_id': 'n3', 'directed': True}],
#   'nodes': [{'id': 'n0', 'type': 'Disease', 'curie': 'MONDO:0014109'},
#    {'id': 'n1', 'type': 'Gene'},
#    {'id': 'n2', 'type': 'Disease'},
#    {'id': 'n3', 'type': 'ChemicalSubstance'}]},
#  'knowledge_graph': {'nodes': [{'id': 'name:NGLY1-deficiency',
#     'name': 'ALACRIMIA - CHOREOATHETOSIS - LIVER DYSFUNCTION SYNDROME',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0014109'],
#                  'DOID': ['DOID:0060728'],
#                  'UMLS': ['C3808991'],
#                  'name': ['ALACRIMIA - CHOREOATHETOSIS - LIVER DYSFUNCTION SYNDROME',
#                   'CDDG',
#                   'CDG IV',
#                   'CDG IV, FORMERLY',
#                   'CONGENITAL DISORDER OF DEGLYCOSYLATION',
#                   'CONGENITAL DISORDER OF DEGLYCOSYLATION; CDDG',
#                   'CONGENITAL DISORDER OF DEGLYCOSYLATION;CDDG',
#                   'CONGENITAL DISORDER OF GLYCOSYLATION TYPE IV',
#                   'CONGENITAL DISORDER OF GLYCOSYLATION TYPE IV; CDG1V',
#                   'CONGENITAL DISORDER OF GLYCOSYLATION, TYPE IV',
#                   'CONGENITAL DISORDER OF GLYCOSYLATION, TYPE IV, FORMERLY',
#                   'DEFICIENCY OF N-GLYCANASE 1',
#                   'NGLY1 DEFICIENCY',
#                   'NGLY1-CDDG',
#                   'NGLY1-DEFICIENCY'],
#                  'OMIM': ['615273'],
#                  'ORPHANET': ['404454']})},
#    {'id': 'SYMBOL:PMM2',
#     'name': 'PHOSPHOMANNOMUTASE 2',
#     'type': 'Gene',
#     'equivalent_identifiers': defaultdict(set,
#                 {'NCBIGene': ['5373'],
#                  'name': ['PHOSPHOMANNOMUTASE 2'],
#                  'SYMBOL': ['PMM2'],
#                  'UMLS': ['C1418674'],
#                  'HGNC': ['9115'],
#                  'UNIPROTKB': ['O15305'],
#                  'ENSEMBL': ['ENSG00000140650']})},
#    {'id': 'SYMBOL:NGLY1',
#     'name': 'N-GLYCANASE 1',
#     'type': 'Gene',
#     'equivalent_identifiers': defaultdict(set,
#                 {'NCBIGene': ['55768'],
#                  'name': ['N-GLYCANASE 1'],
#                  'SYMBOL': ['NGLY1'],
#                  'UMLS': ['C1425023'],
#                  'HGNC': ['17646'],
#                  'UNIPROTKB': ['Q96IV0'],
#                  'ENSEMBL': ['ENSG00000151092']})},
#    {'id': 'SYMBOL:FBXO2',
#     'name': 'F-BOX PROTEIN 2',
#     'type': 'Gene',
#     'equivalent_identifiers': defaultdict(set,
#                 {'NCBIGene': ['26232'],
#                  'name': ['F-BOX PROTEIN 2'],
#                  'SYMBOL': ['FBXO2'],
#                  'UMLS': ['C1422076'],
#                  'HGNC': ['13581'],
#                  'UNIPROTKB': ['Q9UK22'],
#                  'ENSEMBL': ['ENSG00000116661']})},
#    {'id': 'SYMBOL:GMPPA',
#     'name': 'GDP-MANNOSE PYROPHOSPHORYLASE A',
#     'type': 'Gene',
#     'equivalent_identifiers': defaultdict(set,
#                 {'NCBIGene': ['29926'],
#                  'name': ['GDP-MANNOSE PYROPHOSPHORYLASE A'],
#                  'SYMBOL': ['GMPPA'],
#                  'UMLS': ['C1539585'],
#                  'HGNC': ['22923'],
#                  'UNIPROTKB': ['Q96IJ6'],
#                  'ENSEMBL': ['ENSG00000144591']})},
#    {'id': 'SYMBOL:NFE2L1',
#     'name': 'NUCLEAR FACTOR, ERYTHROID 2 LIKE 1',
#     'type': 'Gene',
#     'equivalent_identifiers': defaultdict(set,
#                 {'NCBIGene': ['4779'],
#                  'name': ['NUCLEAR FACTOR, ERYTHROID 2 LIKE 1'],
#                  'SYMBOL': ['NFE2L1'],
#                  'UMLS': ['C1417700'],
#                  'HGNC': ['7781'],
#                  'UNIPROTKB': ['Q14494'],
#                  'ENSEMBL': ['ENSG00000082641']})},
#    {'id': 'SYMBOL:ALG14',
#     'name': 'ALG14 UDP-N-ACETYLGLUCOSAMINYLTRANSFERASE SUBUNIT',
#     'type': 'Gene',
#     'equivalent_identifiers': defaultdict(set,
#                 {'NCBIGene': ['199857'],
#                  'name': ['ALG14 UDP-N-ACETYLGLUCOSAMINYLTRANSFERASE SUBUNIT'],
#                  'SYMBOL': ['ALG14'],
#                  'UMLS': ['C1823173'],
#                  'HGNC': ['28287'],
#                  'UNIPROTKB': ['Q96F25'],
#                  'ENSEMBL': ['ENSG00000172339']})},
#    {'id': 'SYMBOL:FBXO6',
#     'name': 'F-BOX PROTEIN 6',
#     'type': 'Gene',
#     'equivalent_identifiers': defaultdict(set,
#                 {'NCBIGene': ['26270'],
#                  'name': ['F-BOX PROTEIN 6'],
#                  'SYMBOL': ['FBXO6'],
#                  'UMLS': ['C1422080'],
#                  'HGNC': ['13585'],
#                  'UNIPROTKB': ['Q9NRD1'],
#                  'ENSEMBL': ['ENSG00000116663']})},
#    {'id': 'SYMBOL:FAF1',
#     'name': 'FAS ASSOCIATED FACTOR 1',
#     'type': 'Gene',
#     'equivalent_identifiers': defaultdict(set,
#                 {'NCBIGene': ['11124'],
#                  'name': ['FAS ASSOCIATED FACTOR 1'],
#                  'SYMBOL': ['FAF1'],
#                  'UMLS': ['C1414524'],
#                  'HGNC': ['3578'],
#                  'UNIPROTKB': ['Q9UNN5'],
#                  'ENSEMBL': ['ENSG00000185104']})},
#    {'id': 'SYMBOL:DDI2',
#     'name': 'DNA DAMAGE INDUCIBLE 1 HOMOLOG 2',
#     'type': 'Gene',
#     'equivalent_identifiers': defaultdict(set,
#                 {'NCBIGene': ['84301'],
#                  'name': ['DNA DAMAGE INDUCIBLE 1 HOMOLOG 2'],
#                  'SYMBOL': ['DDI2'],
#                  'UMLS': ['C1824901'],
#                  'HGNC': ['24578'],
#                  'UNIPROTKB': ['Q5TDH0'],
#                  'ENSEMBL': ['ENSG00000197312']})},
#    {'id': 'SYMBOL:ENGASE',
#     'name': 'ENDO-BETA-N-ACETYLGLUCOSAMINIDASE',
#     'type': 'Gene',
#     'equivalent_identifiers': defaultdict(set,
#                 {'NCBIGene': ['64772'],
#                  'name': ['ENDO-BETA-N-ACETYLGLUCOSAMINIDASE'],
#                  'SYMBOL': ['ENGASE'],
#                  'UMLS': ['C2681929'],
#                  'HGNC': ['24622'],
#                  'UNIPROTKB': ['Q8NFI3'],
#                  'ENSEMBL': ['ENSG00000167280']})},
#    {'id': 'SYMBOL:PGM1',
#     'name': 'PHOSPHOGLUCOMUTASE 1',
#     'type': 'Gene',
#     'equivalent_identifiers': defaultdict(set,
#                 {'NCBIGene': ['5236'],
#                  'name': ['PHOSPHOGLUCOMUTASE 1'],
#                  'SYMBOL': ['PGM1'],
#                  'UMLS': ['C1418516'],
#                  'HGNC': ['8905'],
#                  'UNIPROTKB': ['P36871'],
#                  'ENSEMBL': ['ENSG00000079739']})},
#    {'id': 'UMLS:C0302148',
#     'name': 'UMLS:C0302148',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C0302148']}},
#    {'id': 'UMLS:C0699748',
#     'name': 'UMLS:C0699748',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C0699748']}},
#    {'id': 'UMLS:C0242656',
#     'name': 'UMLS:C0242656',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C0242656']}},
#    {'id': 'UMLS:C0456091',
#     'name': 'UMLS:C0456091',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C0456091']}},
#    {'id': 'UMLS:C0025362',
#     'name': 'UMLS:C0025362',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C0025362']}},
#    {'id': 'UMLS:C0599732',
#     'name': 'UMLS:C0599732',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C0599732']}},
#    {'id': 'UMLS:C0687133',
#     'name': 'UMLS:C0687133',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C0687133']}},
#    {'id': 'UMLS:C0032780',
#     'name': 'UMLS:C0032780',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C0032780']}},
#    {'id': 'UMLS:C0332482',
#     'name': 'UMLS:C0332482',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C0332482']}},
#    {'id': 'UMLS:C0242354',
#     'name': 'UMLS:C0242354',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C0242354']}},
#    {'id': 'UMLS:C0861154',
#     'name': 'UMLS:C0861154',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C0861154']}},
#    {'id': 'UMLS:C0038435',
#     'name': 'UMLS:C0038435',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C0038435']}},
#    {'id': 'UMLS:C0015376',
#     'name': 'UMLS:C0015376',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C0015376']}},
#    {'id': 'UMLS:C0277785',
#     'name': 'UMLS:C0277785',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C0277785']}},
#    {'id': 'MESH:615273',
#     'name': 'MESH:615273',
#     'type': 'Disease',
#     'equivalent_identifiers': {'MESH': ['615273']}},
#    {'id': 'MESH:615510',
#     'name': 'MESH:615510',
#     'type': 'Disease',
#     'equivalent_identifiers': {'MESH': ['615510']}},
#    {'id': 'MONDO:0033572',
#     'name': 'MONDO:0033572',
#     'type': 'Disease',
#     'equivalent_identifiers': {'MONDO': ['MONDO:0033572']}},
#    {'id': 'MONDO:0033619',
#     'name': 'MONDO:0033619',
#     'type': 'Disease',
#     'equivalent_identifiers': {'MONDO': ['MONDO:0033619']}},
#    {'id': 'DOID:0080552',
#     'name': 'DOID:0080552',
#     'type': 'Disease',
#     'equivalent_identifiers': {'DOID': ['DOID:0080552']}},
#    {'id': 'DOID:0050177',
#     'name': 'DOID:0050177',
#     'type': 'Disease',
#     'equivalent_identifiers': {'DOID': ['DOID:0050177']}},
#    {'id': 'DOID:0111590',
#     'name': 'DOID:0111590',
#     'type': 'Disease',
#     'equivalent_identifiers': {'DOID': ['DOID:0111590']}},
#    {'id': 'DOID:0111953',
#     'name': 'DOID:0111953',
#     'type': 'Disease',
#     'equivalent_identifiers': {'DOID': ['DOID:0111953']}},
#    {'id': 'DOID:0111788',
#     'name': 'DOID:0111788',
#     'type': 'Disease',
#     'equivalent_identifiers': {'DOID': ['DOID:0111788']}},
#    {'id': 'DOID:0111266',
#     'name': 'DOID:0111266',
#     'type': 'Disease',
#     'equivalent_identifiers': {'DOID': ['DOID:0111266']}},
#    {'id': 'DOID:0111255',
#     'name': 'DOID:0111255',
#     'type': 'Disease',
#     'equivalent_identifiers': {'DOID': ['DOID:0111255']}},
#    {'id': 'name:CONDITION',
#     'name': 'CONDITION',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0000001'],
#                  'DOID': ['DOID:4'],
#                  'UMLS': ['C0012634'],
#                  'name': ['CONDITION',
#                   'DISEASE',
#                   'DISEASE OR DISORDER',
#                   'DISEASE OR DISORDER, NON-NEOPLASTIC',
#                   'DISEASES',
#                   'DISEASES AND DISORDERS',
#                   'DISORDER',
#                   'DISORDERS',
#                   'MEDICAL CONDITION',
#                   'OTHER DISEASE'],
#                  'MESH': ['D004194'],
#                  'ORPHANET': ['377788']})},
#    {'id': 'name:ALCOHOLIC FATTY LIVER',
#     'name': 'ALCOHOLIC FATTY LIVER',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0004790'],
#                  'DOID': ['DOID:9452'],
#                  'UMLS': ['C0015695'],
#                  'name': ['ALCOHOLIC FATTY LIVER',
#                   'FATTY CHANGE OF LIVER',
#                   'FATTY LIVER',
#                   'FATTY LIVER DISEASE',
#                   'HEPATIC LIPIDOSIS',
#                   'STEATOSIS OF LIVER'],
#                  'MESH': ['D005234', 'D005235']})},
#    {'id': 'name:HYPERCHOLESTEROLEMIA',
#     'name': 'HYPERCHOLESTEROLEMIA',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0020443'], 'name': ['HYPERCHOLESTEROLEMIA']})},
#    {'id': 'name:NEUROLOGIC DEFICITS',
#     'name': 'NEUROLOGIC DEFICITS',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0521654'], 'name': ['NEUROLOGIC DEFICITS']})},
#    {'id': 'name:CA',
#     'name': 'CA',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0004992'],
#                  'DOID': ['DOID:162', 'DOID:0050687', 'DOID:0050686'],
#                  'UMLS': ['C0006826'],
#                  'name': ['CA',
#                   'CANCER',
#                   'CELL TYPE CANCER',
#                   'MALIGNANCY',
#                   'MALIGNANT GROWTH',
#                   'MALIGNANT NEOPLASM',
#                   'MALIGNANT NEOPLASM (DISEASE)',
#                   'MALIGNANT NEOPLASMS',
#                   'MALIGNANT NEOPLASTIC DISEASE',
#                   'MALIGNANT TUMOR',
#                   'MT',
#                   'NEOPLASM (DISEASE), MALIGNANT',
#                   'NEOPLASM, MALIGNANT',
#                   'ORGAN SYSTEM CANCER',
#                   'PRIMARY CANCER'],
#                  'MESH': ['D009371'],
#                  'OMOP': ['443392']})},
#    {'id': 'name:PATHOLOGIC FISTULA',
#     'name': 'PATHOLOGIC FISTULA',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0016169'], 'name': ['PATHOLOGIC FISTULA']})},
#    {'id': 'name:ACUTE MYOCARDIAL INFARCTION',
#     'name': 'ACUTE MYOCARDIAL INFARCTION',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0004781'],
#                  'DOID': ['DOID:9408'],
#                  'UMLS': ['C0155626'],
#                  'name': ['ACUTE MYOCARDIAL INFARCTION',
#                   'ACUTE MYOCARDIAL INFARCTION (DISEASE)',
#                   'MYOCARDIAL INFARCTION (DISEASE), ACUTE'],
#                  'OMOP': ['312327']})},
#    {'id': 'name:ADENOCARCINOMA',
#     'name': 'ADENOCARCINOMA',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0004970'],
#                  'DOID': ['DOID:299'],
#                  'UMLS': ['C0001418'],
#                  'name': ['ADENOCARCINOMA',
#                   'ADENOCARCINOMA NOS (MORPHOLOGIC ABNORMALITY)',
#                   'ADENOCARCINOMA, MALIGNANT',
#                   'ADENOCARCINOMA, NO SUBTYPE (MORPHOLOGIC ABNORMALITY)',
#                   'ADENOCARCINOMA, NOS',
#                   'ADENOCARCINOMAS',
#                   'ADNOS'],
#                  'MESH': ['D000230']})},
#    {'id': 'name:ATAXIA',
#     'name': 'ATAXIA',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0004134'], 'name': ['ATAXIA']})},
#    {'id': 'name:FAMILIAL HYPERBETALIPOPROTEINAEMIA',
#     'name': 'FAMILIAL HYPERBETALIPOPROTEINAEMIA',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005439'],
#                  'DOID': ['DOID:13810'],
#                  'UMLS': ['C0020445', 'CN118841'],
#                  'name': ['FAMILIAL HYPERBETALIPOPROTEINAEMIA',
#                   'FAMILIAL HYPERCHOLESTEREMIA',
#                   'FAMILIAL HYPERCHOLESTEROLEMIA',
#                   'FREDRICKSON TYPE IIA HYPERLIPOPROTEINEMIA',
#                   'FREDRICKSON TYPE IIA LIPIDAEMIA',
#                   'HYPERBETALIPOPROTEINEMIA',
#                   'HYPERCHOLESTEROLEMIA, FAMILIAL',
#                   'HYPERLIPOPROTEINEMIA TYPE II',
#                   'TYPE II HYPERLIPIDEMIA'],
#                  'MESH': ['D006938']})},
#    {'id': 'name:HEART ATTACK',
#     'name': 'HEART ATTACK',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005068'],
#                  'DOID': ['DOID:5844'],
#                  'UMLS': ['C0027051'],
#                  'name': ['HEART ATTACK',
#                   'INFARCTION (MI), MYOCARDIAL',
#                   'MI',
#                   'MI, MYOCARDIAL INFARCTION',
#                   'MYOCARDIAL INFARCT',
#                   'MYOCARDIAL INFARCTION',
#                   'MYOCARDIAL INFARCTION (DISEASE)',
#                   'MYOCARDIAL INFARCTION, (MI)'],
#                  'MESH': ['D009203']})},
#    {'id': 'name:UREMIA',
#     'name': 'UREMIA',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0007008'],
#                  'DOID': ['DOID:4676'],
#                  'UMLS': ['C0041948'],
#                  'name': ['UREMIA', 'UREMIA OF RENAL ORIGIN'],
#                  'MESH': ['D014511']})},
#    {'id': 'name:BEST DISEASE',
#     'name': 'BEST DISEASE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0000390'],
#                  'DOID': ['DOID:0050661'],
#                  'UMLS': ['C0339510'],
#                  'name': ['BEST DISEASE',
#                   'BEST MACULAR DYSTROPHY',
#                   'JUVENILE-ONSET VITELLIFORM MACULAR DYSTROPHY',
#                   'MACULAR DYSTROPHY, VITELLIFORM',
#                   'VITELLIFORM MACULAR DYSTROPHY'],
#                  'MESH': ['D057826']})},
#    {'id': 'name:LOW FRUSTRATION TOLERANCE',
#     'name': 'LOW FRUSTRATION TOLERANCE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0548883'],
#                  'name': ['LOW FRUSTRATION TOLERANCE']})},
#    {'id': 'name:T LYMPHOCYTE DEFICIENCY',
#     'name': 'T LYMPHOCYTE DEFICIENCY',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0003780'],
#                  'DOID': ['DOID:613'],
#                  'UMLS': ['C1274233'],
#                  'name': ['T LYMPHOCYTE DEFICIENCY',
#                   'T-CELL IMMUNODEFICIENCY',
#                   'T-LYMPHOCYTE DEFICIENCY',
#                   'T-LYMPHOCYTE DEFICIENCY (FINDING)',
#                   'T-LYMPHOCYTE IMMUNODEFICIENCY']})},
#    {'id': 'name:HYPOKINESIA',
#     'name': 'HYPOKINESIA',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0086439'], 'name': ['HYPOKINESIA']})},
#    {'id': 'name:SPERMATOZOA ABNORMAL',
#     'name': 'SPERMATOZOA ABNORMAL',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0541896'], 'name': ['SPERMATOZOA ABNORMAL']})},
#    {'id': 'name:CARBOHYDRATE DEFICIENT GLYCOPROTEIN SYNDROME TYPE IA',
#     'name': 'CARBOHYDRATE DEFICIENT GLYCOPROTEIN SYNDROME TYPE IA',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0008907'],
#                  'UMLS': ['C0349653'],
#                  'name': ['CARBOHYDRATE DEFICIENT GLYCOPROTEIN SYNDROME TYPE IA',
#                   'CARBOHYDRATE-DEFICIENT GLYCOPROTEIN SYNDROME TYPE 1A',
#                   'CARBOHYDRATE-DEFICIENT GLYCOPROTEIN SYNDROME TYPE 1A (FORMERLY)',
#                   'CARBOHYDRATE-DEFICIENT GLYCOPROTEIN SYNDROME, TYPE IA',
#                   'CARBOHYDRATE-DEFICIENT GLYCOPROTEIN SYNDROME, TYPE IA, FORMERLY',
#                   'CDG 1A',
#                   'CDG IA',
#                   'CDG SYNDROME TYPE IA',
#                   'CDG-IA',
#                   'CDG1A',
#                   'CDGIA',
#                   'CONGENITAL DISORDER OF GLYCOSYLATION TYPE 1A',
#                   'CONGENITAL DISORDER OF GLYCOSYLATION TYPE IA',
#                   'CONGENITAL DISORDER OF GLYCOSYLATION, TYPE IA',
#                   'CONGENITAL DISORDER OF GLYCOSYLATION, TYPE IA; CDG1A',
#                   'JAEKEN SYNDROME',
#                   'PHOSPHOMANNOMUTASE 2 DEFICIENCY',
#                   'PMM2-CDG',
#                   'PMM2-CDG (CDG-IA)'],
#                  'MESH': ['C535739'],
#                  'OMIM': ['212065'],
#                  'ORPHANET': ['79318']})},
#    {'id': 'name:GLAUCOMA SIMPLEX',
#     'name': 'GLAUCOMA SIMPLEX',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005338'],
#                  'DOID': ['DOID:1067'],
#                  'UMLS': ['C0017612'],
#                  'name': ['GLAUCOMA SIMPLEX',
#                   'GLAUCOMA, OPEN-ANGLE',
#                   'OPEN ANGLE GLAUCOMA',
#                   'OPEN-ANGLE GLAUCOMA',
#                   'PIGMENTARY GLAUCOMA',
#                   'WIDE-ANGLE GLAUCOMA'],
#                  'MESH': ['D005902'],
#                  'OMOP': ['441284']})},
#    {'id': 'name:ALLERGIC ANGIITIDES',
#     'name': 'ALLERGIC ANGIITIDES',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0015943'],
#                  'DOID': ['DOID:3049'],
#                  'UMLS': ['C0008728'],
#                  'name': ['ALLERGIC ANGIITIDES',
#                   'ALLERGIC ANGIITIDES, GRANULOMATOUS',
#                   'ALLERGIC ANGIITIS',
#                   'ALLERGIC ANGIITIS AND GRANULOMATOSIS',
#                   'ALLERGIC ANGIITIS, GRANULOMATOUS',
#                   'ALLERGIC GRANULOMATOSES',
#                   'ALLERGIC GRANULOMATOSIS',
#                   'ALLERGIC GRANULOMATOSIS ANGIITIS',
#                   'ALLERGIC GRANULOMATOUS AND ANGIITIS',
#                   'ALLERGIC GRANULOMATOUS ANGIITIDES',
#                   'ALLERGIC GRANULOMATOUS ANGIITIS',
#                   'ANGIITIDES, ALLERGIC',
#                   'ANGIITIDES, ALLERGIC GRANULOMATOUS',
#                   'ANGIITIDES, GRANULOMATOUS ALLERGIC',
#                   'ANGIITIS, ALLERGIC',
#                   'ANGIITIS, ALLERGIC GRANULOMATOUS',
#                   'ANGIITIS, GRANULOMATOUS ALLERGIC',
#                   'CHURG STRAUSS SYNDROME',
#                   'CHURG-STRAUSS SYNDROME',
#                   'CHURG-STRAUSS VASCULITIS',
#                   'EGPA',
#                   'EOSINOPHILIC GRANULOMATOSIS WITH POLYANGIITIS',
#                   'EOSINOPHILIC GRANULOMATOUS VASCULITIDES',
#                   'EOSINOPHILIC GRANULOMATOUS VASCULITIS',
#                   'GRANULOMATOSES, ALLERGIC',
#                   'GRANULOMATOSIS, ALLERGIC',
#                   'GRANULOMATOUS ALLERGIC ANGIITIDES',
#                   'GRANULOMATOUS ALLERGIC ANGIITIS',
#                   'GRANULOMATOUS ANGIITIDES, ALLERGIC',
#                   'GRANULOMATOUS ANGIITIS, ALLERGIC',
#                   'GRANULOMATOUS VASCULITIDES, EOSINOPHILIC',
#                   'GRANULOMATOUS VASCULITIS, EOSINOPHILIC',
#                   'SYNDROME, CHURG-STRAUSS',
#                   'VASCULITIDES, EOSINOPHILIC GRANULOMATOUS',
#                   'VASCULITIS, CHURG STRAUSS',
#                   'VASCULITIS, CHURG-STRAUSS',
#                   'VASCULITIS, EOSINOPHILIC GRANULOMATOUS'],
#                  'MESH': ['D015267'],
#                  'ORPHANET': ['183']})},
#    {'id': 'name:ALG1-CDG',
#     'name': 'ALG1-CDG',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005500'],
#                  'DOID': ['DOID:0050570'],
#                  'name': ['ALG1-CDG',
#                   'ALG1-CDG (CDG-1K)',
#                   'ALG11-CDG',
#                   'ALG11-CDG (CDG-1P)',
#                   'ALG12-CDG',
#                   'ALG12-CDG (CDG-1G)',
#                   'ALG2-CDG',
#                   'ALG2-CDG (CDG-1I)',
#                   'ALG3-CDG',
#                   'ALG3-CDG (CDG-1D)',
#                   'ALG6-CDG',
#                   'ALG6-CDG (CDG-1C)',
#                   'ALG8-CDG',
#                   'ALG8-CDG (CDG-1H)',
#                   'ALG9-CDG',
#                   'ALG9-CDG (CDG-1L)',
#                   'CONGENITAL DISORDER OF GLYCOSYLATION TYPE I',
#                   'CONGENITAL DISORDERS OF GLYCOSYLATION, TYPE I',
#                   'DOLK-CDG',
#                   'DOLK-CDG (CDG-1M)',
#                   'DPAGT1-CDG',
#                   'DPAGT1-CDG (CDG-1J)',
#                   'DPM1-CDG',
#                   'DPM1-CDG (CDG-1E)',
#                   'DPM2-CDG',
#                   'DPM2-CDG (CDG-1U)',
#                   'DPM3-CDG',
#                   'DPM3-CDG (CDG-1O)',
#                   'MPDU1-CDG',
#                   'MPDU1-CDG (CDG-1F)',
#                   'MPI-CDG',
#                   'MPI-CDG (CDG-1B)',
#                   'PMM2-CDG',
#                   'PMM2-CDG (CDG-1A)',
#                   'RFT1-CDG',
#                   'RFT1-CDG (CDG-1N)',
#                   'SRD5A3-CDG',
#                   'SRD5A3-CDG (CDG-1Q)']})},
#    {'id': 'name:MODERATE INTELLECTUAL DISABILITY',
#     'name': 'MODERATE INTELLECTUAL DISABILITY',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0026351'],
#                  'name': ['MODERATE INTELLECTUAL DISABILITY']})},
#    {'id': 'name:MUSCLE HYPOTONIA',
#     'name': 'MUSCLE HYPOTONIA',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0026827'], 'name': ['MUSCLE HYPOTONIA']})},
#    {'id': 'name:STRESS DISORDERS, TRAUMATIC',
#     'name': 'STRESS DISORDERS, TRAUMATIC',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0038441'],
#                  'name': ['STRESS DISORDERS, TRAUMATIC']})},
#    {'id': 'name:LOW VISION',
#     'name': 'LOW VISION',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0042798'], 'name': ['LOW VISION']})},
#    {'id': 'name:JOINT LAXITY',
#     'name': 'JOINT LAXITY',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0086437'], 'name': ['JOINT LAXITY']})},
#    {'id': 'name:DEEP VEIN THROMBOSIS',
#     'name': 'DEEP VEIN THROMBOSIS',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0149871'], 'name': ['DEEP VEIN THROMBOSIS']})},
#    {'id': 'name:PREMATURE BIRTH',
#     'name': 'PREMATURE BIRTH',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0151526'], 'name': ['PREMATURE BIRTH']})},
#    {'id': 'name:HYPOREFLEXIA',
#     'name': 'HYPOREFLEXIA',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0151888'], 'name': ['HYPOREFLEXIA']})},
#    {'id': 'name:NEUROLOGIC SYMPTOMS',
#     'name': 'NEUROLOGIC SYMPTOMS',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0235031'], 'name': ['NEUROLOGIC SYMPTOMS']})},
#    {'id': 'name:FIBROSIS, LIVER',
#     'name': 'FIBROSIS, LIVER',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0239946'], 'name': ['FIBROSIS, LIVER']})},
#    {'id': 'name:HYPOALBUMINEMIA',
#     'name': 'HYPOALBUMINEMIA',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0239981'], 'name': ['HYPOALBUMINEMIA']})},
#    {'id': 'name:PARTIAL THROMBOPLASTIN TIME INCREASED (FINDING)',
#     'name': 'PARTIAL THROMBOPLASTIN TIME INCREASED (FINDING)',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0240671'],
#                  'name': ['PARTIAL THROMBOPLASTIN TIME INCREASED (FINDING)']})},
#    {'id': 'name:CONGENITAL ABSENCE OF OVARY',
#     'name': 'CONGENITAL ABSENCE OF OVARY',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0266368'],
#                  'name': ['CONGENITAL ABSENCE OF OVARY']})},
#    {'id': 'name:FAMILIAL NON-IMMUNE HYDROPS FETALIS',
#     'name': 'FAMILIAL NON-IMMUNE HYDROPS FETALIS',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0015193'],
#                  'UMLS': ['C0020305'],
#                  'name': ['FAMILIAL NON-IMMUNE HYDROPS FETALIS',
#                   'FETAL ANASARCA',
#                   'FETAL EDEMA',
#                   'FETAL HYDROPS',
#                   'GENERALIZED FETAL EDEMA',
#                   'HF',
#                   'HYDROPS FETALIS',
#                   'HYDROPS FETALIS (DISEASE)',
#                   'HYDROPS FETALIS NONIMMUNE',
#                   'IDIOPATHIC HYDROPS FETALIS'],
#                  'ORPHANET': ['1041']})},
#    {'id': 'name:POLYNEUROPATHY',
#     'name': 'POLYNEUROPATHY',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0001824'],
#                  'DOID': ['DOID:1389'],
#                  'UMLS': ['C0152025'],
#                  'name': ['POLYNEUROPATHY'],
#                  'MESH': ['D011115'],
#                  'OMOP': ['4174262']})},
#    {'id': 'name:DEJERINE-THOMAS SYNDROME',
#     'name': 'DEJERINE-THOMAS SYNDROME',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0002017'],
#                  'DOID': ['DOID:14784'],
#                  'UMLS': ['C0028968'],
#                  'name': ['DEJERINE-THOMAS SYNDROME',
#                   'OLIVOPONTOCEREBELLAR ATROPHIES',
#                   'OLIVOPONTOCEREBELLAR ATROPHY',
#                   'OPCA',
#                   "THOMAS' SYNDROME",
#                   'WADIA-SWAMI SYNDROME'],
#                  'MESH': ['D009849']})},
#    {'id': 'name:HYPERINSULINEMIA',
#     'name': 'HYPERINSULINEMIA',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0002177'],
#                  'DOID': ['DOID:2018'],
#                  'UMLS': ['C0020459'],
#                  'name': ['HYPERINSULINEMIA',
#                   'HYPERINSULINISM',
#                   'HYPERINSULINISM (DISEASE)'],
#                  'MESH': ['D006946']})},
#    {'id': 'name:DEVELOPMENTAL DELAY (DISORDER)',
#     'name': 'DEVELOPMENTAL DELAY (DISORDER)',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0424605'],
#                  'name': ['DEVELOPMENTAL DELAY (DISORDER)']})},
#    {'id': 'name:LARGE NOSE',
#     'name': 'LARGE NOSE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0426415'], 'name': ['LARGE NOSE']})},
#    {'id': 'name:CEREBELLAR DISEASE',
#     'name': 'CEREBELLAR DISEASE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0002427'],
#                  'DOID': ['DOID:2786'],
#                  'UMLS': ['C0007760'],
#                  'name': ['CEREBELLAR DISEASE',
#                   'CEREBELLAR DISEASES',
#                   'CEREBELLUM DISEASE',
#                   'CEREBELLUM DISEASE OR DISORDER',
#                   'DISEASE OF CEREBELLUM',
#                   'DISEASE OR DISORDER OF CEREBELLUM',
#                   'DISORDER OF CEREBELLUM'],
#                  'MESH': ['D002526']})},
#    {'id': 'name:SYNOPHRYS',
#     'name': 'SYNOPHRYS',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0431447'], 'name': ['SYNOPHRYS']})},
#    {'id': 'name:HYPOPLASIA OF NIPPLE',
#     'name': 'HYPOPLASIA OF NIPPLE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0432355'], 'name': ['HYPOPLASIA OF NIPPLE']})},
#    {'id': 'name:DELAYED SPEECH AND LANGUAGE DEVELOPMENT',
#     'name': 'DELAYED SPEECH AND LANGUAGE DEVELOPMENT',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0454644'],
#                  'name': ['DELAYED SPEECH AND LANGUAGE DEVELOPMENT']})},
#    {'id': 'name:PLATELET COUNT DECREASED',
#     'name': 'PLATELET COUNT DECREASED',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0002049'],
#                  'DOID': ['DOID:1588'],
#                  'UMLS': ['CN130080', 'C0040034'],
#                  'name': ['PLATELET COUNT DECREASED',
#                   'THROMBOCYTOPENIA',
#                   'THROMBOCYTOPENIC DISORDER'],
#                  'MESH': ['D013921']})},
#    {'id': 'name:CONGENITAL KYPHOSCOLIOSIS',
#     'name': 'CONGENITAL KYPHOSCOLIOSIS',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0345392'],
#                  'name': ['CONGENITAL KYPHOSCOLIOSIS']})},
#    {'id': 'name:ELEVATED PLATELET COUNT',
#     'name': 'ELEVATED PLATELET COUNT',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0002249'],
#                  'DOID': ['DOID:2228'],
#                  'UMLS': ['C0836924'],
#                  'name': ['ELEVATED PLATELET COUNT',
#                   'PLATELET COUNT INCREASED',
#                   'THROMBOCYTHAEMIA',
#                   'THROMBOCYTOSIS',
#                   'THROMBOCYTOSIS DISEASE'],
#                  'MESH': ['D013922']})},
#    {'id': 'name:MOTOR RETARDATION',
#     'name': 'MOTOR RETARDATION',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0424230'], 'name': ['MOTOR RETARDATION']})},
#    {'id': 'name:ISOLATED CONGENITAL MICROCEPHALY',
#     'name': 'ISOLATED CONGENITAL MICROCEPHALY',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0016056'],
#                  'UMLS': ['C0025958'],
#                  'name': ['ISOLATED CONGENITAL MICROCEPHALY', 'MICROCEPHALY'],
#                  'ORPHANET': ['199642']})},
#    {'id': 'name:MULTIPLE RENAL CYSTS',
#     'name': 'MULTIPLE RENAL CYSTS',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0431718'], 'name': ['MULTIPLE RENAL CYSTS']})},
#    {'id': 'name:CONGENITAL, HEREDITARY, AND NEONATAL DISEASES AND ABNORMALITIES',
#     'name': 'CONGENITAL, HEREDITARY, AND NEONATAL DISEASES AND ABNORMALITIES',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0027612'],
#                  'name': ['CONGENITAL, HEREDITARY, AND NEONATAL DISEASES AND ABNORMALITIES']})},
#    {'id': 'name:ATRIOVENTRICULAR BLOCK COMPLETE',
#     'name': 'ATRIOVENTRICULAR BLOCK COMPLETE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0000468'],
#                  'DOID': ['DOID:0050823'],
#                  'UMLS': ['C0151517'],
#                  'name': ['ATRIOVENTRICULAR BLOCK COMPLETE',
#                   'ATRIOVENTRICULAR BLOCK, THIRD DEGREE',
#                   'AV BLOCK THIRD DEGREE',
#                   'COMPLETE ATRIOVENTRICULAR BLOCK',
#                   'COMPLETE AV BLOCK',
#                   'COMPLETE HEART BLOCK',
#                   'NON-CONGENITAL COMPLETE ATRIOVENTRICULAR BLOCK',
#                   'THIRD DEGREE ATRIOVENTRICULAR BLOCK',
#                   'THIRD DEGREE AV BLOCK',
#                   'THIRD-DEGREE ATRIOVENTRICULAR BLOCK']})},
#    {'id': 'name:VENTRICULAR ARRHYTHMIA',
#     'name': 'VENTRICULAR ARRHYTHMIA',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0085612'], 'name': ['VENTRICULAR ARRHYTHMIA']})},
#    {'id': 'name:PROTHROMBIN TIME INCREASED',
#     'name': 'PROTHROMBIN TIME INCREASED',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0151872'],
#                  'name': ['PROTHROMBIN TIME INCREASED']})},
#    {'id': 'name:MACROTIA',
#     'name': 'MACROTIA',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0152421'], 'name': ['MACROTIA']})},
#    {'id': 'name:REDUCED FETAL MOVEMENT',
#     'name': 'REDUCED FETAL MOVEMENT',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0235659'], 'name': ['REDUCED FETAL MOVEMENT']})},
#    {'id': 'name:CEREBRAL ATROPHY',
#     'name': 'CEREBRAL ATROPHY',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0235946'], 'name': ['CEREBRAL ATROPHY']})},
#    {'id': 'name:GROWTH HORMONE EXCESS',
#     'name': 'GROWTH HORMONE EXCESS',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0235986'], 'name': ['GROWTH HORMONE EXCESS']})},
#    {'id': 'name:LOW SET EARS',
#     'name': 'LOW SET EARS',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0239234'], 'name': ['LOW SET EARS']})},
#    {'id': 'name:SEVERE MALNUTRITION',
#     'name': 'SEVERE MALNUTRITION',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0311276'], 'name': ['SEVERE MALNUTRITION']})},
#    {'id': 'name:FLEXION CONTRACTURE',
#     'name': 'FLEXION CONTRACTURE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0333068'], 'name': ['FLEXION CONTRACTURE']})},
#    {'id': 'name:VENTRICULAR HYPERTROPHY',
#     'name': 'VENTRICULAR HYPERTROPHY',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0340279'], 'name': ['VENTRICULAR HYPERTROPHY']})},
#    {'id': 'name:UPWARD SLANT OF PALPEBRAL FISSURE',
#     'name': 'UPWARD SLANT OF PALPEBRAL FISSURE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0423109'],
#                  'name': ['UPWARD SLANT OF PALPEBRAL FISSURE']})},
#    {'id': 'name:INTELLECTUAL DISABILITIES',
#     'name': 'INTELLECTUAL DISABILITIES',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0001071'],
#                  'DOID': ['DOID:1059'],
#                  'UMLS': ['C3714756'],
#                  'name': ['INTELLECTUAL DISABILITIES',
#                   'INTELLECTUAL DISABILITY',
#                   'MENTAL RETARDATION',
#                   'MENTAL RETARDATION, AUTOSOMAL RECESSIVE 15'],
#                  'MESH': ['D008607']})},
#    {'id': 'name:EARLY MENOPAUSE',
#     'name': 'EARLY MENOPAUSE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0001119'],
#                  'DOID': ['DOID:10787'],
#                  'UMLS': ['C0025322'],
#                  'name': ['EARLY MENOPAUSE',
#                   'MENOPAUSE - PREMATURE',
#                   'MENOPAUSE PRAECOX',
#                   'POF',
#                   'PREMATURE MENOPAUSE',
#                   'PREMATURE OVARIAN FAILURE'],
#                  'MESH': ['D008594'],
#                  'OMOP': ['198715']})},
#    {'id': 'name:FEEDING DIFFICULTIES',
#     'name': 'FEEDING DIFFICULTIES',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0232466'], 'name': ['FEEDING DIFFICULTIES']})},
#    {'id': 'name:MYOPIA',
#     'name': 'MYOPIA',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0001384'],
#                  'DOID': ['DOID:11830'],
#                  'UMLS': ['C0027092'],
#                  'name': ['MYOPIA',
#                   'MYOPIA (DISEASE)',
#                   'NEAR VISION',
#                   'NEAR-SIGHTEDNESS',
#                   'SHORT-SIGHTEDNESS'],
#                  'MESH': ['D009216'],
#                  'OMOP': ['379805']})},
#    {'id': 'name:SMALL TESTICLE',
#     'name': 'SMALL TESTICLE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0241355'], 'name': ['SMALL TESTICLE']})},
#    {'id': 'name:RETROGNATHIA',
#     'name': 'RETROGNATHIA',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C3494422'], 'name': ['RETROGNATHIA']})},
#    {'id': 'name:UNSPECIFIED VISUAL LOSS',
#     'name': 'UNSPECIFIED VISUAL LOSS',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C3665346'], 'name': ['UNSPECIFIED VISUAL LOSS']})},
#    {'id': 'name:NYSTAGMUS, CTCAE 5.0',
#     'name': 'NYSTAGMUS, CTCAE 5.0',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C4554036'], 'name': ['NYSTAGMUS, CTCAE 5.0']})},
#    {'id': 'name:RENAL CYST',
#     'name': 'RENAL CYST',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C3887499'], 'name': ['RENAL CYST']})},
#    {'id': 'name:ABNORMALITY OF THE PINNA',
#     'name': 'ABNORMALITY OF THE PINNA',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0857379'], 'name': ['ABNORMALITY OF THE PINNA']})},
#    {'id': 'name:MENTAL DEFICIENCY',
#     'name': 'MENTAL DEFICIENCY',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0917816'], 'name': ['MENTAL DEFICIENCY']})},
#    {'id': 'name:PRIMARY HYPOGONADISM',
#     'name': 'PRIMARY HYPOGONADISM',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0948896'], 'name': ['PRIMARY HYPOGONADISM']})},
#    {'id': 'name:TUMOR CELL INVASION',
#     'name': 'TUMOR CELL INVASION',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C1269955'], 'name': ['TUMOR CELL INVASION']})},
#    {'id': 'name:DELAYED MYELINATION',
#     'name': 'DELAYED MYELINATION',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C1277241'], 'name': ['DELAYED MYELINATION']})},
#    {'id': 'name:DYSARTHRIA',
#     'name': 'DYSARTHRIA',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0013362'], 'name': ['DYSARTHRIA']})},
#    {'id': 'name:FEVER',
#     'name': 'FEVER',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0015967'], 'name': ['FEVER']})},
#    {'id': 'name:AGENESIS OF HEMIDIAPHRAGM',
#     'name': 'AGENESIS OF HEMIDIAPHRAGM',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005711', 'MONDO:0007719'],
#                  'UMLS': ['C0019284', 'C0235833'],
#                  'name': ['AGENESIS OF HEMIDIAPHRAGM',
#                   'CDH',
#                   'CONGENITAL DIAPHRAGMATIC DEFECT',
#                   'CONGENITAL DIAPHRAGMATIC HERNIA',
#                   'DIAPHRAGM, COMPLETE AGENESIS OF',
#                   'DIAPHRAGM, UNILATERAL AGENESIS OF',
#                   'DIAPHRAGMATIC DEFECT, CONGENITAL',
#                   'DIAPHRAGMATIC HERNIA',
#                   'DIAPHRAGMATIC HERNIA 1',
#                   'DIAPHRAGMATIC HERNIA, CONGENITAL',
#                   'DIAPHRAGMATIC HERNIA, CONGENITAL 1',
#                   'DIH1',
#                   'HEMIDIAPHRAGM, AGENESIS OF',
#                   'HERNIA, CONGENITAL DIAPHRAGMATIC',
#                   'UNILATERAL AGENESIS OF DIAPHRAGM'],
#                  'OMIM': ['142340'],
#                  'DOID': ['DOID:3827'],
#                  'MESH': ['D006548'],
#                  'ORPHANET': ['2140'],
#                  'OMOP': ['4066010']})},
#    {'id': 'name:INSULIN RESISTANCE',
#     'name': 'INSULIN RESISTANCE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0021655'], 'name': ['INSULIN RESISTANCE']})},
#    {'id': 'name:INVERSION OF NIPPLE (DISORDER)',
#     'name': 'INVERSION OF NIPPLE (DISORDER)',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0008100'],
#                  'UMLS': ['C0269269'],
#                  'name': ['INVERSION OF NIPPLE (DISORDER)',
#                   'MAMMILLAE INVERTITAE',
#                   'NIPPLES INVERTED'],
#                  'OMIM': ['163600']})},
#    {'id': 'name:NYSTAGMUS, CTCAE 3.0',
#     'name': 'NYSTAGMUS, CTCAE 3.0',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C1963184'], 'name': ['NYSTAGMUS, CTCAE 3.0']})},
#    {'id': 'name:PEDIATRIC FAILURE TO THRIVE',
#     'name': 'PEDIATRIC FAILURE TO THRIVE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C2315100'],
#                  'name': ['PEDIATRIC FAILURE TO THRIVE']})},
#    {'id': 'name:FEEDING DIFFICULTIES IN INFANCY',
#     'name': 'FEEDING DIFFICULTIES IN INFANCY',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C2674608'],
#                  'name': ['FEEDING DIFFICULTIES IN INFANCY']})},
#    {'id': 'name:IMPAIRED ANTIGEN-SPECIFIC RESPONSE',
#     'name': 'IMPAIRED ANTIGEN-SPECIFIC RESPONSE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C4531146'],
#                  'name': ['IMPAIRED ANTIGEN-SPECIFIC RESPONSE']})},
#    {'id': 'name:ROD-CONE DYSTROPHY',
#     'name': 'ROD-CONE DYSTROPHY',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C4551714'], 'name': ['ROD-CONE DYSTROPHY']})},
#    {'id': 'name:PIGMENTARY RETINOPATHY',
#     'name': 'PIGMENTARY RETINOPATHY',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C4551715'], 'name': ['PIGMENTARY RETINOPATHY']})},
#    {'id': 'name:ANGINA PECTORIS',
#     'name': 'ANGINA PECTORIS',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0002962'], 'name': ['ANGINA PECTORIS']})},
#    {'id': 'name:REDUCED FACTOR IX ACTIVITY',
#     'name': 'REDUCED FACTOR IX ACTIVITY',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C4023159'],
#                  'name': ['REDUCED FACTOR IX ACTIVITY']})},
#    {'id': 'name:PHOTORECEPTOR LAYER LOSS ON MACULAR OCT',
#     'name': 'PHOTORECEPTOR LAYER LOSS ON MACULAR OCT',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C4073079'],
#                  'name': ['PHOTORECEPTOR LAYER LOSS ON MACULAR OCT']})},
#    {'id': 'name:KYPHOSIS DEFORMITY OF SPINE',
#     'name': 'KYPHOSIS DEFORMITY OF SPINE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C0022821'],
#                  'name': ['KYPHOSIS DEFORMITY OF SPINE']})},
#    {'id': "name:'HABSBURG JAW'",
#     'name': "'HABSBURG JAW'",
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0008312'],
#                  'UMLS': ['CN203311', 'C0399526'],
#                  'name': ["'HABSBURG JAW'",
#                   "'HAPSBURG JAW'",
#                   'AUTOSOMAL DOMINANT PROGNATHISM',
#                   'CLASS III MALOCCLUSION',
#                   'HABSBURG JAW',
#                   'HAPSBURG JAW',
#                   'PROGNATHISM MANDIBULAR',
#                   'PROGNATHISM, MANDIBULAR'],
#                  'MESH': ['D008313'],
#                  'OMIM': ['176700'],
#                  'ORPHANET': ['2964']})},
#    {'id': 'name:WIDE SPACED NIPPLES',
#     'name': 'WIDE SPACED NIPPLES',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C1827524'], 'name': ['WIDE SPACED NIPPLES']})},
#    {'id': 'name:LONG FACE',
#     'name': 'LONG FACE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C1836047'], 'name': ['LONG FACE']})},
#    {'id': 'name:DEPRESSED NASAL BRIDGE',
#     'name': 'DEPRESSED NASAL BRIDGE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C1836542'], 'name': ['DEPRESSED NASAL BRIDGE']})},
#    {'id': 'name:PROMINENT FOREHEAD',
#     'name': 'PROMINENT FOREHEAD',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C1837260'], 'name': ['PROMINENT FOREHEAD']})},
#    {'id': 'name:TYPE I TRANSFERRIN ISOFORM PROFILE',
#     'name': 'TYPE I TRANSFERRIN ISOFORM PROFILE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C1837899'],
#                  'name': ['TYPE I TRANSFERRIN ISOFORM PROFILE']})},
#    {'id': 'name:PROXIMAL TUBULOPATHY',
#     'name': 'PROXIMAL TUBULOPATHY',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C1839603'], 'name': ['PROXIMAL TUBULOPATHY']})},
#    {'id': 'name:ANTEVERTED NOSTRIL',
#     'name': 'ANTEVERTED NOSTRIL',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C1840077'], 'name': ['ANTEVERTED NOSTRIL']})},
#    {'id': 'name:PLATYSPONDYLY',
#     'name': 'PLATYSPONDYLY',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'UMLS': ['C