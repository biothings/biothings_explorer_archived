# %% [markdown]
# # Find treatment for Crohn's Disease

# %% [markdown]
# Patient details can be found at [this use case described by MediKanren team](https://github.com/webyrd/mediKanren/blob/master/contrib/medikanren/use-cases/PMI-20-10.pdf)

# %% [markdown]
# The query below tries to mimic the strategy used by MediKanren team. We're looking to find ChemicalSubstances/Drugs which targets genes participating in IL1R Signaling Pathway.

# %% [markdown]
# ## Import BTE TRAPI module

# %%
from biothings_explorer.trapi import TRAPI
tp = TRAPI()

# %% [markdown]
# ## Set Query Graph. (Pathway -> Gene -> ChemicalSubstance)

# %%
qg = {
	"message": {
		"query_graph": {
			"nodes": {
				"n0": {
					"id": "WIKIPATHWAYS:WP195",
					"category":"biolink:Pathway"
				},
                "n1": {
                    "category": "biolink:Gene"
                },
                "n2": {
                    "category": "biolink:ChemicalSubstance"
                }
			},
			"edges": {
                "e01": {
					"subject": "n0",
                    "object": "n1"
                },
                "e02": {
					"subject": "n1",
                    "object": "n2"
                }
			}
		}
	}
}
tp.query_graph = qg

# %% [markdown]
# ## Make the query

# %%
tp.query()
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# /opt/anaconda3/envs/BTE/lib/python3.9/site-packages/urllib3/connection.py in _new_conn(self)
#     168         try:
# --> 169             conn = connection.create_connection(
#     170                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# /opt/anaconda3/envs/BTE/lib/python3.9/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      95     if err is not None:
# ---> 96         raise err
#      97
#
# /opt/anaconda3/envs/BTE/lib/python3.9/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      85                 sock.bind(source_address)
# ---> 86             sock.connect(sa)
#      87             return sock
#
# TimeoutError: [Errno 60] Operation timed out
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /opt/anaconda3/envs/BTE/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# /opt/anaconda3/envs/BTE/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# /opt/anaconda3/envs/BTE/lib/python3.9/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#
# /opt/anaconda3/envs/BTE/lib/python3.9/site-packages/urllib3/connection.py in connect(self)
#     352         # Add certificate verification
# --> 353         conn = self._new_conn()
#     354         hostname = self.host
#
# /opt/anaconda3/envs/BTE/lib/python3.9/site-packages/urllib3/connection.py in _new_conn(self)
#     180         except SocketError as e:
# --> 181             raise NewConnectionError(
#     182                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x7f817c769af0>: Failed to establish a new connection: [Errno 60] Operation timed out
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /opt/anaconda3/envs/BTE/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# /opt/anaconda3/envs/BTE/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# /opt/anaconda3/envs/BTE/lib/python3.9/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     573         if new_retry.is_exhausted():
# --> 574             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     575
#
# MaxRetryError: HTTPSConnectionPool(host='dev.api.bte.ncats.io', port=443): Max retries exceeded with url: /v1/query (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f817c769af0>: Failed to establish a new connection: [Errno 60] Operation timed out'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# /opt/anaconda3/envs/BTE/lib/python3.9/site-packages/biothings_explorer/trapi/__init__.py in query(self, qg)
#      43         try:
# ---> 44             r = requests.post(self._url, json=qg)
#      45         except:
#
# /opt/anaconda3/envs/BTE/lib/python3.9/site-packages/requests/api.py in post(url, data, json, **kwargs)
#     118
# --> 119     return request('post', url, data=data, json=json, **kwargs)
#     120
#
# /opt/anaconda3/envs/BTE/lib/python3.9/site-packages/requests/api.py in request(method, url, **kwargs)
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#
# /opt/anaconda3/envs/BTE/lib/python3.9/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#
# /opt/anaconda3/envs/BTE/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#
# /opt/anaconda3/envs/BTE/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#
# ConnectionError: HTTPSConnectionPool(host='dev.api.bte.ncats.io', port=443): Max retries exceeded with url: /v1/query (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f817c769af0>: Failed to establish a new connection: [Errno 60] Operation timed out'))
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-4-d47519b34f66> in <module>
# ----> 1 tp.query()
#
# /opt/anaconda3/envs/BTE/lib/python3.9/site-packages/biothings_explorer/trapi/__init__.py in query(self, qg)
#      44             r = requests.post(self._url, json=qg)
#      45         except:
# ---> 46             raise Exception("Your query fails")
#      47         if r.status_code != 200:
#      48             raise Exception(
#
# Exception: Your query fails

# %% [markdown]
# ## Visualize the results for query edge e02 as DataFrame

# %%
df = tp.to_dataframe("e02")
df
# Out:
#                      api         object               object_name  \
# 0      [SEMMED Gene API]   CHEBI:143496  TROGLITAZONE GLUCURONIDE
# 1      [SEMMED Gene API]   MESH:C005274                  naringin
# 2      [SEMMED Gene API]     CHEBI:8364                  PRAZOSIN
# 3      [SEMMED Gene API]    CHEBI:31401                CILOSTAZOL
# 4      [SEMMED Gene API]    CHEBI:67486                HYPEROSIDE
# ...                  ...            ...                       ...
# 11143  [SEMMED Gene API]  UMLS:C0243077             UMLS:C0243077
# 11144  [SEMMED Gene API]   MESH:D010957                  Plasmids
# 11145  [SEMMED Gene API]   MESH:C075569                    E 3330
# 11146  [SEMMED Gene API]   MESH:D007477                      Ions
# 11147  [SEMMED Gene API]    CHEBI:28834          DEOXYCHOLIC ACID
#
#        object_num_source_nodes                                      predicate  \
# 0                            5  biolink:entity_positively_regulated_by_entity
# 1                            5  biolink:entity_negatively_regulated_by_entity
# 2                            4  biolink:entity_negatively_regulated_by_entity
# 3                            3  biolink:entity_positively_regulated_by_entity
# 4                            2  biolink:entity_negatively_regulated_by_entity
# ...                        ...                                            ...
# 11143                        6              biolink:physically_interacts_with
# 11144                       13  biolink:entity_negatively_regulated_by_entity
# 11145                        1  biolink:entity_positively_regulated_by_entity
# 11146                        7  biolink:entity_positively_regulated_by_entity
# 11147                        6              biolink:physically_interacts_with
#
#       provided_by                                       publications  \
# 0        [SEMMED]                                    [PMID:12052469]
# 1        [SEMMED]                     [PMID:26908354, PMID:27006302]
# 2        [SEMMED]                                    [PMID:12032367]
# 3        [SEMMED]                                    [PMID:27484958]
# 4        [SEMMED]                                    [PMID:26526086]
# ...           ...                                                ...
# 11143    [SEMMED]  [PMID:26284425, PMID:24150799, PMID:25181477, ...
# 11144    [SEMMED]                     [PMID:26392416, PMID:17897860]
# 11145    [SEMMED]                                    [PMID:27637330]
# 11146    [SEMMED]                                    [PMID:23894078]
# 11147    [SEMMED]                                    [PMID:16920701]
#
#              subject subject_name
# 0      NCBIGENE:5295       PIK3R1
# 1      NCBIGENE:5599        MAPK8
# 2      NCBIGENE:5599        MAPK8
# 3       NCBIGENE:207         AKT1
# 4      NCBIGENE:5594        MAPK1
# ...              ...          ...
# 11143   NCBIGENE:207         AKT1
# 11144  NCBIGENE:5594        MAPK1
# 11145  NCBIGENE:5594        MAPK1
# 11146  NCBIGENE:5595        MAPK3
# 11147  NCBIGENE:5781       PTPN11
#
# [11148 rows x 9 columns]

# %% [markdown]
# ## Sort by drugs which target most of the IL1 Signaling pathway participants

# %%
df.sort_values(by='object_num_source_nodes', ascending=False)[["object", "object_name", "object_num_source_nodes"]].drop_duplicates().head(20)
# Out:
#                              object                  object_name  \
# 6874                   MESH:D008070          Lipopolysaccharides
# 10531                  MESH:D034741       RNA, Small Interfering
# 10574                  MESH:D017382      Reactive Oxygen Species
# 8513                   MESH:D004364  Pharmaceutical Preparations
# 10988                  MESH:D035683                    MicroRNAs
# 6470                   MESH:D001665                Binding Sites
# 8967                   MESH:D012333               RNA, Messenger
# 6640                   MESH:D002273                  Carcinogens
# 10474                 UMLS:C1328819                UMLS:C1328819
# 6623                    CHEBI:15903              GLUCOSE OXIDASE
# 358                     CHEBI:16480                 NITRIC OXIDE
# 1868                     CHEBI:9168                    SIROLIMUS
# 1491                    CHEBI:16236                      ALCOHOL
# 8848                    CHEBI:86971  RESVERATROL 4'-METHYL ETHER
# 8562                   CHEBI:137177                          DNA
# 2636                  UMLS:C1519315                UMLS:C1519315
# 6827                   MESH:D012330         RNA, Double-Stranded
# 9273                   MESH:C093973                     PD 98059
# 6076   CHEMBL.COMPOUND:CHEMBL278663      PARA-METHOXYAMPHETAMINE
# 2468                    CHEBI:16469                    ESTRADIOL
#
#        object_num_source_nodes
# 6874                        37
# 10531                       31
# 10574                       25
# 8513                        25
# 10988                       24
# 6470                        22
# 8967                        22
# 6640                        20
# 10474                       19
# 6623                        18
# 358                         17
# 1868                        17
# 1491                        16
# 8848                        16
# 8562                        16
# 2636                        15
# 6827                        15
# 9273                        15
# 6076                        15
# 2468                        15

# %% [markdown]
# ## Find all associations between Curcumin and IL1 Signaling pathway participants

# %%
df.loc[df['object_name'] == "Curcumin"]
# Out:
#                      api      object object_name  object_num_source_nodes  \
# 504    [SEMMED Gene API]  CHEBI:3962    Curcumin                       15
# 605    [SEMMED Gene API]  CHEBI:3962    Curcumin                       15
# 629    [SEMMED Gene API]  CHEBI:3962    Curcumin                       15
# 918    [SEMMED Gene API]  CHEBI:3962    Curcumin                       15
# 946    [SEMMED Gene API]  CHEBI:3962    Curcumin                       15
# 1393   [SEMMED Gene API]  CHEBI:3962    Curcumin                       15
# 1606   [SEMMED Gene API]  CHEBI:3962    Curcumin                       15
# 1839   [SEMMED Gene API]  CHEBI:3962    Curcumin                       15
# 2072   [SEMMED Gene API]  CHEBI:3962    Curcumin                       15
# 2090   [SEMMED Gene API]  CHEBI:3962    Curcumin                       15
# 2331   [SEMMED Gene API]  CHEBI:3962    Curcumin                       15
# 2422   [SEMMED Gene API]  CHEBI:3962    Curcumin                       15
# 2441   [SEMMED Gene API]  CHEBI:3962    Curcumin                       15
# 2578   [SEMMED Gene API]  CHEBI:3962    Curcumin                       15
# 3017   [SEMMED Gene API]  CHEBI:3962    Curcumin                       15
# 3064   [SEMMED Gene API]  CHEBI:3962    Curcumin                       15
# 3067   [SEMMED Gene API]  CHEBI:3962    Curcumin                       15
# 3384   [SEMMED Gene API]  CHEBI:3962    Curcumin                       15
# 4085   [SEMMED Gene API]  CHEBI:3962    Curcumin                       15
# 4087   [SEMMED Gene API]  CHEBI:3962    Curcumin                       15
# 4300   [SEMMED Gene API]  CHEBI:3962    Curcumin                       15
# 4356   [SEMMED Gene API]  CHEBI:3962    Curcumin                       15
# 4656   [SEMMED Gene API]  CHEBI:3962    Curcumin                       15
# 4788   [SEMMED Gene API]  CHEBI:3962    Curcumin                       15
# 6234   [SEMMED Gene API]  CHEBI:3962    Curcumin                       15
# 6309   [SEMMED Gene API]  CHEBI:3962    Curcumin                       15
# 8222   [SEMMED Gene API]  CHEBI:3962    Curcumin                       15
# 8565   [SEMMED Gene API]  CHEBI:3962    Curcumin                       15
# 8582   [SEMMED Gene API]  CHEBI:3962    Curcumin                       15
# 8663   [SEMMED Gene API]  CHEBI:3962    Curcumin                       15
# 9511   [SEMMED Gene API]  CHEBI:3962    Curcumin                       15
# 9670   [SEMMED Gene API]  CHEBI:3962    Curcumin                       15
# 10308  [SEMMED Gene API]  CHEBI:3962    Curcumin                       15
# 10859  [SEMMED Gene API]  CHEBI:3962    Curcumin                       15
#
#                                            predicate provided_by  \
# 504    biolink:entity_negatively_regulated_by_entity    [SEMMED]
# 605    biolink:entity_positively_regulated_by_entity    [SEMMED]
# 629    biolink:entity_negatively_regulated_by_entity    [SEMMED]
# 918    biolink:entity_negatively_regulated_by_entity    [SEMMED]
# 946    biolink:entity_negatively_regulated_by_entity    [SEMMED]
# 1393   biolink:entity_negatively_regulated_by_entity    [SEMMED]
# 1606   biolink:entity_negatively_regulated_by_entity    [SEMMED]
# 1839      biolink:entity_negatively_regulates_entity    [SEMMED]
# 2072               biolink:physically_interacts_with    [SEMMED]
# 2090      biolink:entity_positively_regulates_entity    [SEMMED]
# 2331               biolink:physically_interacts_with    [SEMMED]
# 2422   biolink:entity_negatively_regulated_by_entity    [SEMMED]
# 2441   biolink:entity_positively_regulated_by_entity    [SEMMED]
# 2578               biolink:physically_interacts_with    [SEMMED]
# 3017   biolink:entity_positively_regulated_by_entity    [SEMMED]
# 3064   biolink:entity_negatively_regulated_by_entity    [SEMMED]
# 3067      biolink:entity_negatively_regulates_entity    [SEMMED]
# 3384   biolink:entity_positively_regulated_by_entity    [SEMMED]
# 4085   biolink:entity_negatively_regulated_by_entity    [SEMMED]
# 4087   biolink:entity_negatively_regulated_by_entity    [SEMMED]
# 4300   biolink:entity_negatively_regulated_by_entity    [SEMMED]
# 4356   biolink:entity_negatively_regulated_by_entity    [SEMMED]
# 4656      biolink:entity_positively_regulates_entity    [SEMMED]
# 4788      biolink:entity_negatively_regulates_entity    [SEMMED]
# 6234               biolink:physically_interacts_with    [SEMMED]
# 6309   biolink:entity_negatively_regulated_by_entity    [SEMMED]
# 8222               biolink:physically_interacts_with    [SEMMED]
# 8565      biolink:entity_negatively_regulates_entity    [SEMMED]
# 8582               biolink:physically_interacts_with    [SEMMED]
# 8663   biolink:entity_positively_regulated_by_entity    [SEMMED]
# 9511      biolink:entity_negatively_regulates_entity    [SEMMED]
# 9670   biolink:entity_negatively_regulated_by_entity    [SEMMED]
# 10308              biolink:physically_interacts_with    [SEMMED]
# 10859              biolink:physically_interacts_with    [SEMMED]
#
#                                             publications        subject  \
# 504    [PMID:16007726, PMID:17276891, PMID:23857913, ...  NCBIGENE:5594
# 605                                      [PMID:19360344]  NCBIGENE:6347
# 629    [PMID:27916071, PMID:25260874, PMID:16116955, ...  NCBIGENE:5970
# 918        [PMID:21272158, PMID:20937593, PMID:23042094]  NCBIGENE:3551
# 946    [PMID:15352173, PMID:11981161, PMID:19763044, ...  NCBIGENE:5599
# 1393   [PMID:15022320, PMID:18976114, PMID:27888616, ...  NCBIGENE:6347
# 1606                                     [PMID:17332930]  NCBIGENE:5295
# 1839                                     [PMID:16299382]   NCBIGENE:207
# 2072                                     [PMID:16046709]  NCBIGENE:3654
# 2090                      [PMID:22483553, PMID:22507634]   NCBIGENE:207
# 2331   [PMID:24631908, PMID:25200041, PMID:10611441, ...  NCBIGENE:5594
# 2422       [PMID:28628927, PMID:21324484, PMID:16678799]  NCBIGENE:4615
# 2441   [PMID:25198898, PMID:9674701, PMID:15095415, P...  NCBIGENE:5599
# 2578                                     [PMID:28611265]  NCBIGENE:8878
# 3017   [PMID:26974552, PMID:23954767, PMID:17640567, ...   NCBIGENE:207
# 3064                                     [PMID:14634121]  NCBIGENE:5781
# 3067                      [PMID:21729550, PMID:18588981]  NCBIGENE:5970
# 3384   [PMID:21584871, PMID:21242275, PMID:25200041, ...  NCBIGENE:5594
# 4085   [PMID:29110611, PMID:26166196, PMID:12682902, ...   NCBIGENE:207
# 4087                                     [PMID:17332930]  NCBIGENE:5296
# 4300                                      [PMID:9674701]  NCBIGENE:6885
# 4356                      [PMID:19771848, PMID:27122821]  NCBIGENE:5595
# 4656                                     [PMID:23511143]  NCBIGENE:5594
# 4788                      [PMID:22443687, PMID:19771847]  NCBIGENE:5594
# 6234                      [PMID:19002562, PMID:28628927]  NCBIGENE:4615
# 6309                                     [PMID:28611265]  NCBIGENE:8878
# 8222   [PMID:27817102, PMID:15491342, PMID:24631908, ...  NCBIGENE:5599
# 8565                                     [PMID:27470399]  NCBIGENE:6347
# 8582   [PMID:24870723, PMID:24910117, PMID:27208432, ...   NCBIGENE:207
# 8663       [PMID:12473670, PMID:22552693, PMID:20026325]  NCBIGENE:5970
# 9511                      [PMID:22443687, PMID:19771847]  NCBIGENE:5599
# 9670                                      [PMID:9674701]  NCBIGENE:4214
# 10308                                    [PMID:19771848]  NCBIGENE:5595
# 10859  [PMID:23457487, PMID:16619535, PMID:25961579, ...  NCBIGENE:5970
#
#       subject_name
# 504          MAPK1
# 605           CCL2
# 629           RELA
# 918          IKBKB
# 946          MAPK8
# 1393          CCL2
# 1606        PIK3R1
# 1839          AKT1
# 2072         IRAK1
# 2090          AKT1
# 2331         MAPK1
# 2422         MYD88
# 2441         MAPK8
# 2578        SQSTM1
# 3017          AKT1
# 3064        PTPN11
# 3067          RELA
# 3384         MAPK1
# 4085          AKT1
# 4087        PIK3R2
# 4300        MAP3K7
# 4356         MAPK3
# 4656         MAPK1
# 4788         MAPK1
# 6234         MYD88
# 6309        SQSTM1
# 8222         MAPK8
# 8565          CCL2
# 8582          AKT1
# 8663          RELA
# 9511         MAPK8
# 9670        MAP3K1
# 10308        MAPK3
# 10859         RELA

# %% [markdown]
# ## View detailed table

# %%
df_detailed = tp.to_dataframe("e02", info_level=3)
df_detailed.loc[df_detailed['object_name'] == "Curcumin"]
# Out:
#              subject subject_name subject_category  \
# 504    NCBIGENE:5594        MAPK1     biolink:Gene
# 605    NCBIGENE:6347         CCL2     biolink:Gene
# 629    NCBIGENE:5970         RELA     biolink:Gene
# 918    NCBIGENE:3551        IKBKB     biolink:Gene
# 946    NCBIGENE:5599        MAPK8     biolink:Gene
# 1393   NCBIGENE:6347         CCL2     biolink:Gene
# 1606   NCBIGENE:5295       PIK3R1     biolink:Gene
# 1839    NCBIGENE:207         AKT1     biolink:Gene
# 2072   NCBIGENE:3654        IRAK1     biolink:Gene
# 2090    NCBIGENE:207         AKT1     biolink:Gene
# 2331   NCBIGENE:5594        MAPK1     biolink:Gene
# 2422   NCBIGENE:4615        MYD88     biolink:Gene
# 2441   NCBIGENE:5599        MAPK8     biolink:Gene
# 2578   NCBIGENE:8878       SQSTM1     biolink:Gene
# 3017    NCBIGENE:207         AKT1     biolink:Gene
# 3064   NCBIGENE:5781       PTPN11     biolink:Gene
# 3067   NCBIGENE:5970         RELA     biolink:Gene
# 3384   NCBIGENE:5594        MAPK1     biolink:Gene
# 4085    NCBIGENE:207         AKT1     biolink:Gene
# 4087   NCBIGENE:5296       PIK3R2     biolink:Gene
# 4300   NCBIGENE:6885       MAP3K7     biolink:Gene
# 4356   NCBIGENE:5595        MAPK3     biolink:Gene
# 4656   NCBIGENE:5594        MAPK1     biolink:Gene
# 4788   NCBIGENE:5594        MAPK1     biolink:Gene
# 6234   NCBIGENE:4615        MYD88     biolink:Gene
# 6309   NCBIGENE:8878       SQSTM1     biolink:Gene
# 8222   NCBIGENE:5599        MAPK8     biolink:Gene
# 8565   NCBIGENE:6347         CCL2     biolink:Gene
# 8582    NCBIGENE:207         AKT1     biolink:Gene
# 8663   NCBIGENE:5970         RELA     biolink:Gene
# 9511   NCBIGENE:5599        MAPK8     biolink:Gene
# 9670   NCBIGENE:4214       MAP3K1     biolink:Gene
# 10308  NCBIGENE:5595        MAPK3     biolink:Gene
# 10859  NCBIGENE:5970         RELA     biolink:Gene
#
#                           subject_equivalent_identifiers  \
# 504    [NCBIGENE:5594, name:mitogen-activated protein...
# 605    [NCBIGENE:6347, name:C-C motif chemokine ligan...
# 629    [NCBIGENE:5970, name:RELA proto-oncogene, NF-k...
# 918    [NCBIGENE:3551, name:inhibitor of nuclear fact...
# 946    [NCBIGENE:5599, name:mitogen-activated protein...
# 1393   [NCBIGENE:6347, name:C-C motif chemokine ligan...
# 1606   [NCBIGENE:5295, name:phosphoinositide-3-kinase...
# 1839   [NCBIGENE:207, name:AKT serine/threonine kinas...
# 2072   [NCBIGENE:3654, name:interleukin 1 receptor as...
# 2090   [NCBIGENE:207, name:AKT serine/threonine kinas...
# 2331   [NCBIGENE:5594, name:mitogen-activated protein...
# 2422   [NCBIGENE:4615, name:MYD88 innate immune signa...
# 2441   [NCBIGENE:5599, name:mitogen-activated protein...
# 2578   [NCBIGENE:8878, name:sequestosome 1, SYMBOL:SQ...
# 3017   [NCBIGENE:207, name:AKT serine/threonine kinas...
# 3064   [NCBIGENE:5781, name:protein tyrosine phosphat...
# 3067   [NCBIGENE:5970, name:RELA proto-oncogene, NF-k...
# 3384   [NCBIGENE:5594, name:mitogen-activated protein...
# 4085   [NCBIGENE:207, name:AKT serine/threonine kinas...
# 4087   [NCBIGENE:5296, name:phosphoinositide-3-kinase...
# 4300   [NCBIGENE:6885, name:mitogen-activated protein...
# 4356   [NCBIGENE:5595, name:mitogen-activated protein...
# 4656   [NCBIGENE:5594, name:mitogen-activated protein...
# 4788   [NCBIGENE:5594, name:mitogen-activated protein...
# 6234   [NCBIGENE:4615, name:MYD88 innate immune signa...
# 6309   [NCBIGENE:8878, name:sequestosome 1, SYMBOL:SQ...
# 8222   [NCBIGENE:5599, name:mitogen-activated protein...
# 8565   [NCBIGENE:6347, name:C-C motif chemokine ligan...
# 8582   [NCBIGENE:207, name:AKT serine/threonine kinas...
# 8663   [NCBIGENE:5970, name:RELA proto-oncogene, NF-k...
# 9511   [NCBIGENE:5599, name:mitogen-activated protein...
# 9670   [NCBIGENE:4214, name:mitogen-activated protein...
# 10308  [NCBIGENE:5595, name:mitogen-activated protein...
# 10859  [NCBIGENE:5970, name:RELA proto-oncogene, NF-k...
#
#        subject_num_source_nodes  subject_num_target_nodes  \
# 504                           1                      1415
# 605                           1                       391
# 629                           1                       496
# 918                           1                       103
# 946                           1                      1050
# 1393                          1                       391
# 1606                          1                        97
# 1839                          1                      1840
# 2072                          1                        53
# 2090                          1                      1840
# 2331                          1                      1415
# 2422                          1                       127
# 2441                          1                      1050
# 2578                          1                       152
# 3017                          1                      1840
# 3064                          1                       161
# 3067                          1                       496
# 3384                          1                      1415
# 4085                          1                      1840
# 4087                          1                        81
# 4300                          1                        83
# 4356                          1                       348
# 4656                          1                      1415
# 4788                          1                      1415
# 6234                          1                       127
# 6309                          1                       152
# 8222                          1                      1050
# 8565                          1                       391
# 8582                          1                      1840
# 8663                          1                       496
# 9511                          1                      1050
# 9670                          1                        37
# 10308                         1                       348
# 10859                         1                       496
#
#       subject_source_qg_nodes subject_target_qg_nodes  \
# 504                      [n0]                    [n2]
# 605                      [n0]                    [n2]
# 629                      [n0]                    [n2]
# 918                      [n0]                    [n2]
# 946                      [n0]                    [n2]
# 1393                     [n0]                    [n2]
# 1606                     [n0]                    [n2]
# 1839                     [n0]                    [n2]
# 2072                     [n0]                    [n2]
# 2090                     [n0]                    [n2]
# 2331                     [n0]                    [n2]
# 2422                     [n0]                    [n2]
# 2441                     [n0]                    [n2]
# 2578                     [n0]                    [n2]
# 3017                     [n0]                    [n2]
# 3064                     [n0]                    [n2]
# 3067                     [n0]                    [n2]
# 3384                     [n0]                    [n2]
# 4085                     [n0]                    [n2]
# 4087                     [n0]                    [n2]
# 4300                     [n0]                    [n2]
# 4356                     [n0]                    [n2]
# 4656                     [n0]                    [n2]
# 4788                     [n0]                    [n2]
# 6234                     [n0]                    [n2]
# 6309                     [n0]                    [n2]
# 8222                     [n0]                    [n2]
# 8565                     [n0]                    [n2]
# 8582                     [n0]                    [n2]
# 8663                     [n0]                    [n2]
# 9511                     [n0]                    [n2]
# 9670                     [n0]                    [n2]
# 10308                    [n0]                    [n2]
# 10859                    [n0]                    [n2]
#
#                                         subject_interpro subject_type_of_gene  \
# 504    [Protein kinase domain, Mitogen-activated prot...     [protein-coding]
# 605    [CC chemokine, conserved site, Chemokine inter...     [protein-coding]
# 629    [NF-kappa-B/Dorsal, IPT domain, p53-like trans...     [protein-coding]
# 918    [Ubiquitin-like domain, Protein kinase domain,...     [protein-coding]
# 946    [Protein kinase domain, Mitogen-activated prot...     [protein-coding]
# 1393   [CC chemokine, conserved site, Chemokine inter...     [protein-coding]
# 1606   [Rho GTPase-activating protein domain, SH2 dom...     [protein-coding]
# 1839   [Protein kinase domain, AGC-kinase, C-terminal...     [protein-coding]
# 2072   [Death domain, Protein kinase domain, Serine-t...     [protein-coding]
# 2090   [Protein kinase domain, AGC-kinase, C-terminal...     [protein-coding]
# 2331   [Protein kinase domain, Mitogen-activated prot...     [protein-coding]
# 2422   [Toll/interleukin-1 receptor homology (TIR) do...     [protein-coding]
# 2441   [Protein kinase domain, Mitogen-activated prot...     [protein-coding]
# 2578   [PB1 domain, Zinc finger, ZZ-type, UBA-like su...     [protein-coding]
# 3017   [Protein kinase domain, AGC-kinase, C-terminal...     [protein-coding]
# 3064   [PTP type protein phosphatase, Tyrosine specif...     [protein-coding]
# 3067   [NF-kappa-B/Dorsal, IPT domain, p53-like trans...     [protein-coding]
# 3384   [Protein kinase domain, Mitogen-activated prot...     [protein-coding]
# 4085   [Protein kinase domain, AGC-kinase, C-terminal...     [protein-coding]
# 4087   [Rho GTPase-activating protein domain, SH2 dom...     [protein-coding]
# 4300   [Protein kinase domain, Serine-threonine/tyros...     [protein-coding]
# 4356   [Protein kinase domain, Mitogen-activated prot...     [protein-coding]
# 4656   [Protein kinase domain, Mitogen-activated prot...     [protein-coding]
# 4788   [Protein kinase domain, Mitogen-activated prot...     [protein-coding]
# 6234   [Toll/interleukin-1 receptor homology (TIR) do...     [protein-coding]
# 6309   [PB1 domain, Zinc finger, ZZ-type, UBA-like su...     [protein-coding]
# 8222   [Protein kinase domain, Mitogen-activated prot...     [protein-coding]
# 8565   [CC chemokine, conserved site, Chemokine inter...     [protein-coding]
# 8582   [Protein kinase domain, AGC-kinase, C-terminal...     [protein-coding]
# 8663   [NF-kappa-B/Dorsal, IPT domain, p53-like trans...     [protein-coding]
# 9511   [Protein kinase domain, Mitogen-activated prot...     [protein-coding]
# 9670   [Protein kinase domain, Zinc finger, RING-type...     [protein-coding]
# 10308  [Protein kinase domain, Mitogen-activated prot...     [protein-coding]
# 10859  [NF-kappa-B/Dorsal, IPT domain, p53-like trans...     [protein-coding]
#
#        ... object_drugbank_kingdom          object_drugbank_superclass  \
# 504    ...     [Organic compounds]  [Phenylpropanoids and polyketides]
# 605    ...     [Organic compounds]  [Phenylpropanoids and polyketides]
# 629    ...     [Organic compounds]  [Phenylpropanoids and polyketides]
# 918    ...     [Organic compounds]  [Phenylpropanoids and polyketides]
# 946    ...     [Organic compounds]  [Phenylpropanoids and polyketides]
# 1393   ...     [Organic compounds]  [Phenylpropanoids and polyketides]
# 1606   ...     [Organic compounds]  [Phenylpropanoids and polyketides]
# 1839   ...     [Organic compounds]  [Phenylpropanoids and polyketides]
# 2072   ...     [Organic compounds]  [Phenylpropanoids and polyketides]
# 2090   ...     [Organic compounds]  [Phenylpropanoids and polyketides]
# 2331   ...     [Organic compounds]  [Phenylpropanoids and polyketides]
# 2422   ...     [Organic compounds]  [Phenylpropanoids and polyketides]
# 2441   ...     [Organic compounds]  [Phenylpropanoids and polyketides]
# 2578   ...     [Organic compounds]  [Phenylpropanoids and polyketides]
# 3017   ...     [Organic compounds]  [Phenylpropanoids and polyketides]
# 3064   ...     [Organic compounds]  [Phenylpropanoids and polyketides]
# 3067   ...     [Organic compounds]  [Phenylpropanoids and polyketides]
# 3384   ...     [Organic compounds]  [Phenylpropanoids and polyketides]
# 4085   ...     [Organic compounds]  [Phenylpropanoids and polyketides]
# 4087   ...     [Organic compounds]  [Phenylpropanoids and polyketides]
# 4300   ...     [Organic compounds]  [Phenylpropanoids and polyketides]
# 4356   ...     [Organic compounds]  [Phenylpropanoids and polyketides]
# 4656   ...     [Organic compounds]  [Phenylpropanoids and polyketides]
# 4788   ...     [Organic compounds]  [Phenylpropanoids and polyketides]
# 6234   ...     [Organic compounds]  [Phenylpropanoids and polyketides]
# 6309   ...     [Organic compounds]  [Phenylpropanoids and polyketides]
# 8222   ...     [Organic compounds]  [Phenylpropanoids and polyketides]
# 8565   ...     [Organic compounds]  [Phenylpropanoids and polyketides]
# 8582   ...     [Organic compounds]  [Phenylpropanoids and polyketides]
# 8663   ...     [Organic compounds]  [Phenylpropanoids and polyketides]
# 9511   ...     [Organic compounds]  [Phenylpropanoids and polyketides]
# 9670   ...     [Organic compounds]  [Phenylpropanoids and polyketides]
# 10308  ...     [Organic compounds]  [Phenylpropanoids and polyketides]
# 10859  ...     [Organic compounds]  [Phenylpropanoids and polyketides]
#
#       object_indications object_mesh_pharmacology_class provided_by  \
# 504                  NaN                            NaN    [SEMMED]
# 605                  NaN                            NaN    [SEMMED]
# 629                  NaN                            NaN    [SEMMED]
# 918                  NaN                            NaN    [SEMMED]
# 946                  NaN                            NaN    [SEMMED]
# 1393                 NaN                            NaN    [SEMMED]
# 1606                 NaN                            NaN    [SEMMED]
# 1839                 NaN                            NaN    [SEMMED]
# 2072                 NaN                            NaN    [SEMMED]
# 2090                 NaN                            NaN    [SEMMED]
# 2331                 NaN                            NaN    [SEMMED]
# 2422                 NaN                            NaN    [SEMMED]
# 2441                 NaN                            NaN    [SEMMED]
# 2578                 NaN                            NaN    [SEMMED]
# 3017                 NaN                            NaN    [SEMMED]
# 3064                 NaN                            NaN    [SEMMED]
# 3067                 NaN                            NaN    [SEMMED]
# 3384                 NaN                            NaN    [SEMMED]
# 4085                 NaN                            NaN    [SEMMED]
# 4087                 NaN                            NaN    [SEMMED]
# 4300                 NaN                            NaN    [SEMMED]
# 4356                 NaN                            NaN    [SEMMED]
# 4656                 NaN                            NaN    [SEMMED]
# 4788                 NaN                            NaN    [SEMMED]
# 6234                 NaN                            NaN    [SEMMED]
# 6309                 NaN                            NaN    [SEMMED]
# 8222                 NaN                            NaN    [SEMMED]
# 8565                 NaN                            NaN    [SEMMED]
# 8582                 NaN                            NaN    [SEMMED]
# 8663                 NaN                            NaN    [SEMMED]
# 9511                 NaN                            NaN    [SEMMED]
# 9670                 NaN                            NaN    [SEMMED]
# 10308                NaN                            NaN    [SEMMED]
# 10859                NaN                            NaN    [SEMMED]
#
#                      api                                       publications  \
# 504    [SEMMED Gene API]  [PMID:16007726, PMID:17276891, PMID:23857913, ...
# 605    [SEMMED Gene API]                                    [PMID:19360344]
# 629    [SEMMED Gene API]  [PMID:27916071, PMID:25260874, PMID:16116955, ...
# 918    [SEMMED Gene API]      [PMID:21272158, PMID:20937593, PMID:23042094]
# 946    [SEMMED Gene API]  [PMID:15352173, PMID:11981161, PMID:19763044, ...
# 1393   [SEMMED Gene API]  [PMID:15022320, PMID:18976114, PMID:27888616, ...
# 1606   [SEMMED Gene API]                                    [PMID:17332930]
# 1839   [SEMMED Gene API]                                    [PMID:16299382]
# 2072   [SEMMED Gene API]                                    [PMID:16046709]
# 2090   [SEMMED Gene API]                     [PMID:22483553, PMID:22507634]
# 2331   [SEMMED Gene API]  [PMID:24631908, PMID:25200041, PMID:10611441, ...
# 2422   [SEMMED Gene API]      [PMID:28628927, PMID:21324484, PMID:16678799]
# 2441   [SEMMED Gene API]  [PMID:25198898, PMID:9674701, PMID:15095415, P...
# 2578   [SEMMED Gene API]                                    [PMID:28611265]
# 3017   [SEMMED Gene API]  [PMID:26974552, PMID:23954767, PMID:17640567, ...
# 3064   [SEMMED Gene API]                                    [PMID:14634121]
# 3067   [SEMMED Gene API]                     [PMID:21729550, PMID:18588981]
# 3384   [SEMMED Gene API]  [PMID:21584871, PMID:21242275, PMID:25200041, ...
# 4085   [SEMMED Gene API]  [PMID:29110611, PMID:26166196, PMID:12682902, ...
# 4087   [SEMMED Gene API]                                    [PMID:17332930]
# 4300   [SEMMED Gene API]                                     [PMID:9674701]
# 4356   [SEMMED Gene API]                     [PMID:19771848, PMID:27122821]
# 4656   [SEMMED Gene API]                                    [PMID:23511143]
# 4788   [SEMMED Gene API]                     [PMID:22443687, PMID:19771847]
# 6234   [SEMMED Gene API]                     [PMID:19002562, PMID:28628927]
# 6309   [SEMMED Gene API]                                    [PMID:28611265]
# 8222   [SEMMED Gene API]  [PMID:27817102, PMID:15491342, PMID:24631908, ...
# 8565   [SEMMED Gene API]                                    [PMID:27470399]
# 8582   [SEMMED Gene API]  [PMID:24870723, PMID:24910117, PMID:27208432, ...
# 8663   [SEMMED Gene API]      [PMID:12473670, PMID:22552693, PMID:20026325]
# 9511   [SEMMED Gene API]                     [PMID:22443687, PMID:19771847]
# 9670   [SEMMED Gene API]                                     [PMID:9674701]
# 10308  [SEMMED Gene API]                                    [PMID:19771848]
# 10859  [SEMMED Gene API]  [PMID:23457487, PMID:16619535, PMID:25961579, ...
#
#       object_contraindications object_fda_epc_pharmacology_class moleculeType
# 504                        NaN                               NaN          NaN
# 605                        NaN                               NaN          NaN
# 629                        NaN                               NaN          NaN
# 918                        NaN                               NaN          NaN
# 946                        NaN                               NaN          NaN
# 1393                       NaN                               NaN          NaN
# 1606                       NaN                               NaN          NaN
# 1839                       NaN                               NaN          NaN
# 2072                       NaN                               NaN          NaN
# 2090                       NaN                               NaN          NaN
# 2331                       NaN                               NaN          NaN
# 2422                       NaN                               NaN          NaN
# 2441                       NaN                               NaN          NaN
# 2578                       NaN                               NaN          NaN
# 3017                       NaN                               NaN          NaN
# 3064                       NaN                               NaN          NaN
# 3067                       NaN                               NaN          NaN
# 3384                       NaN                               NaN          NaN
# 4085                       NaN                               NaN          NaN
# 4087                       NaN                               NaN          NaN
# 4300                       NaN                               NaN          NaN
# 4356                       NaN                               NaN          NaN
# 4656                       NaN                               NaN          NaN
# 4788                       NaN                               NaN          NaN
# 6234                       NaN                               NaN          NaN
# 6309                       NaN                               NaN          NaN
# 8222                       NaN                               NaN          NaN
# 8565                       NaN                               NaN          NaN
# 8582                       NaN                               NaN          NaN
# 8663                       NaN                               NaN          NaN
# 9511                       NaN                               NaN          NaN
# 9670                       NaN                               NaN          NaN
# 10308                      NaN                               NaN          NaN
# 10859                      NaN                               NaN          NaN
#
# [34 rows x 34 columns]
