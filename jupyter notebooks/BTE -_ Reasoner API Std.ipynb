# %%
from biothings_explorer.hint import Hint
from biothings_explorer.user_query_dispatcher import SingleEdgeQueryDispatcher

# %%
ht = Hint()

# %%
ace2 = ht.query("ACE2")['Gene'][0]
ace2
# Out:
# {'NCBIGene': '59272',
#  'name': 'angiotensin I converting enzyme 2',
#  'SYMBOL': 'ACE2',
#  'UMLS': 'C1422064',
#  'HGNC': '13557',
#  'UNIPROTKB': 'Q9BYF1',
#  'ENSEMBL': 'ENSG00000130234',
#  'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '59272'},
#  'display': 'NCBIGene(59272) ENSEMBL(ENSG00000130234) HGNC(13557) UMLS(C1422064) UNIPROTKB(Q9BYF1) SYMBOL(ACE2)',
#  'type': 'Gene'}

# %%
fc = SingleEdgeQueryDispatcher(inppu)

# %%
fc.connect(verbose=True)
# Out:
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'ACE2' and 'Disease'.                   Paths will have 1 intermediate node.
#
# Intermediate node #1 will have these type constraints: ChemicalSubstance
#
#
#
# ========== QUERY #1 -- fetch all ChemicalSubstance entities linked to ACE2 ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because ACE2 is of type 'Gene', BTE will query our meta-KG for APIs that can take 'Gene' as input and 'ChemicalSubstance' as output
#
# BTE found 10 apis:
#
# API 1. pharos(1 API call)
# API 2. chembio(1 API call)
# API 3. semmed_gene(10 API calls)
# API 4. dgidb(1 API call)
# API 5. hmdb(1 API call)
# API 6. opentarget(1 API call)
# API 7. scigraph(1 API call)
# API 8. cord_gene(1 API call)
# API 9. scibite(1 API call)
# API 10. mychem(3 API calls)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 3.1: https://biothings.ncats.io/semmedgene/query?fields=negatively_regulates (POST -d q=C1422064&scopes=umls)
# API 3.8: https://biothings.ncats.io/semmedgene/query?fields=disrupts (POST -d q=C1422064&scopes=umls)
# API 10.3: https://mychem.info/v1/query?fields=chembl.molecule_chembl_id&size=250 (POST -d q=ACE2&scopes=drugcentral.bioactivity.uniprot.gene_symbol)
# API 3.2: https://biothings.ncats.io/semmedgene/query?fields=physically_interacts_with (POST -d q=C1422064&scopes=umls)
# API 10.2: https://mychem.info/v1/query?fields=drugbank.id&size=250 (POST -d q=ACE2&scopes=drugbank.enzymes.gene_name)
# API 3.7: https://biothings.ncats.io/semmedgene/query?fields=negatively_regulated_by (POST -d q=C1422064&scopes=umls)
# API 10.1: https://mychem.info/v1/query?fields=drugbank.id&size=250 (POST -d q=ACE2&scopes=drugbank.targets.gene_name)
# API 3.9: https://biothings.ncats.io/semmedgene/query?fields=disrupted_by (POST -d q=C1422064&scopes=umls)
# API 3.4: https://biothings.ncats.io/semmedgene/query?fields=affected_by (POST -d q=C1422064&scopes=umls)
# API 3.6: https://biothings.ncats.io/semmedgene/query?fields=positively_regulated_by (POST -d q=C1422064&scopes=umls)
# API 3.5: https://biothings.ncats.io/semmedgene/query?fields=related_to (POST -d q=C1422064&scopes=umls)
# API 3.3: https://biothings.ncats.io/semmedgene/query?fields=affects (POST -d q=C1422064&scopes=umls)
# API 3.10: https://biothings.ncats.io/semmedgene/query?fields=positively_regulates (POST -d q=C1422064&scopes=umls)
# API 8.1: https://biothings.ncats.io/cord_gene/query?fields=associated_with (POST -d q=13557&scopes=hgnc)
# API 6.1: https://platform-api.opentargets.io/v3/platform/public/evidence/filter?target=ENSG00000130234&datasource=chembl&size=100&fields=drug
# API 4.1: http://dgidb.genome.wustl.edu/api/v2/interactions.json?genes=ACE2
# API 1.1: https://automat.renci.org/pharos/gene/chemical_substance/NCBIGene:59272
# API 5.1: https://automat.renci.org/hmdb/gene/chemical_substance/NCBIGene:59272
# API 2.1: https://automat.renci.org/chembio/gene/chemical_substance/NCBIGene:59272
# API 9.1: https://automat.renci.org/cord19_scibite_v2/gene/chemical_substance/NCBIGene:59272
# API 7.1: https://automat.renci.org/cord19_scigraph_v2/gene/chemical_substance/NCBIGene:59272
#
#
# ==== Step #3: Output normalization ====
#
# API 6.1 opentarget: No hits
# API 9.1 scibite: 45 hits
# API 3.1 semmed_gene: 3 hits
# API 3.2 semmed_gene: 19 hits
# API 3.3 semmed_gene: No hits
# API 3.4 semmed_gene: No hits
# API 7.1 scigraph: 57 hits
# API 3.5 semmed_gene: No hits
# API 4.1 dgidb: 4 hits
# API 3.6 semmed_gene: 15 hits
# API 10.1 mychem: 4 hits
# API 8.1 cord_gene: 5 hits
# API 3.7 semmed_gene: 9 hits
# API 1.1 pharos: 52 hits
# API 3.8 semmed_gene: No hits
# API 2.1 chembio: No hits
# API 10.2 mychem: No hits
# API 3.9 semmed_gene: No hits
# API 5.1 hmdb: 5 hits
# API 10.3 mychem: 2 hits
# API 3.10 semmed_gene: 2 hits
#
# After id-to-object translation, BTE retrieved 185 unique objects.
#
#
# ========== QUERY #2.1 -- fetch all Disease entities linked to ChemicalSubstance entites ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because None is of type 'ChemicalSubstance', BTE will query our meta-KG for APIs that can take 'ChemicalSubstance' as input and 'Disease' as output
#
# BTE found 8 apis:
#
# API 1. pharos(116 API calls)
# API 2. mydisease(1 API call)
# API 3. cord_chemical(1 API call)
# API 4. hmdb(116 API calls)
# API 5. semmed_chemical(14 API calls)
# API 6. scigraph(116 API calls)
# API 7. scibite(116 API calls)
# API 8. mychem(2 API calls)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.79: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:17295
# API 1.79 pharos failed
# API 1.101: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:33699
# API 1.101 pharos failed
# API 1.67: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:53000
# API 1.67 pharos failed
# API 1.29: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:8899
# API 1.29 pharos failed
# API 1.66: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:80132
# API 1.66 pharos failed
# API 1.93: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:31932
# API 1.93 pharos failed
# API 1.90: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:6980
# API 1.90 pharos failed
# API 1.104: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:17115
# API 1.104 pharos failed
# API 1.97: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:27363
# API 1.97 pharos failed
# API 1.92: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:28775
# API 1.92 pharos failed
# API 1.96: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:35222
# API 1.96 pharos failed
# API 1.91: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:48706
# API 1.91 pharos failed
# API 1.70: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:80144
# API 1.70 pharos failed
# API 1.102: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:3390
# API 1.102 pharos failed
# API 1.61: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:17234
# API 1.61 pharos failed
# API 1.84: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:4784
# API 1.84 pharos failed
# API 1.15: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:50178
# API 1.15 pharos failed
# API 1.71: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:31593
# API 1.71 pharos failed
# API 1.75: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:2588
# API 1.75 pharos failed
# API 1.20: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:48432
# API 1.20 pharos failed
# API 1.76: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:48705
# API 1.76 pharos failed
# API 1.81: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:5729
# API 1.81 pharos failed
# API 1.89: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:16480
# API 1.89 pharos failed
# API 1.87: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:138186
# API 1.87 pharos failed
# API 1.85: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:30145
# API 1.85 pharos failed
# API 4.15: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:50178
# API 1.28: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:33708
# API 1.28 pharos failed
# API 1.94: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:5420
# API 1.94 pharos failed
# API 4.66: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:80132
# API 1.26: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:4786
# API 1.26 pharos failed
# API 1.86: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:26667
# API 1.86 pharos failed
# API 1.106: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:17823
# API 1.106 pharos failed
# API 1.64: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:9927
# API 1.64 pharos failed
# API 1.65: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:9464
# API 1.65 pharos failed
# API 1.95: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:37670
# API 1.95 pharos failed
# API 1.69: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:33709
# API 1.69 pharos failed
# API 1.72: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:48343
# API 1.72 pharos failed
# API 1.88: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:81146
# API 1.88 pharos failed
# API 1.98: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:39548
# API 1.98 pharos failed
# API 1.77: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:4727
# API 1.77 pharos failed
# API 1.63: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:5132
# API 1.63 pharos failed
# API 1.103: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:58048
# API 1.103 pharos failed
# API 1.31: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:16526
# API 1.31 pharos failed
# API 1.74: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:3165
# API 1.74 pharos failed
# API 4.14: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:137052
# API 1.73: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:35620
# API 1.73 pharos failed
# API 4.16: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:17196
# API 4.12: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:137218
# API 4.9: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:35457
# API 4.85: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:30145
# API 4.69: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:33709
# API 1.80: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:50122
# API 1.80 pharos failed
# API 1.99: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:6476
# API 1.99 pharos failed
# API 4.74: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:3165
# API 4.68: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:17996
# API 4.10: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:7542
# API 4.13: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:4300
# API 1.22: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:90705
# API 1.22 pharos failed
# API 1.78: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:17822
# API 1.78 pharos failed
# API 1.19: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:34543
# API 1.19 pharos failed
# API 1.24: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:35235
# API 1.24 pharos failed
# API 1.27: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:2718
# API 1.27 pharos failed
# API 1.35: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:9434
# API 1.35 pharos failed
# API 1.33: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:5679
# API 1.33 pharos failed
# API 1.17: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:8459
# API 1.17 pharos failed
# API 1.25: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:15903
# API 1.25 pharos failed
# API 1.68: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:17996
# API 1.68 pharos failed
# API 1.82: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:80128
# API 1.82 pharos failed
# API 1.83: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:16973
# API 1.83 pharos failed
# API 1.16: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:17196
# API 1.16 pharos failed
# API 1.34: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:24433
# API 1.34 pharos failed
# API 1.23: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:137177
# API 1.23 pharos failed
# API 1.36: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:83828
# API 1.36 pharos failed
# API 1.105: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:42223
# API 1.105 pharos failed
# API 1.32: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:27732
# API 1.32 pharos failed
# API 1.62: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:75095
# API 1.62 pharos failed
# API 1.100: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:16240
# API 1.100 pharos failed
# API 1.30: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:39061
# API 1.30 pharos failed
# API 1.21: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:3638
# API 1.21 pharos failed
# API 1.18: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:5801
# API 1.18 pharos failed
# API 4.82: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:80128
# API 4.76: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:48705
# API 4.84: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:4784
# API 4.77: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:4727
# API 4.87: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:138186
# API 5.1: https://biothings.ncats.io/semmedchemical/query?fields=positively_regulates (POST -d q=C0062068,C0014025,C0288171,C0031434,C0003018,C0071162,C0700447,C0772162,C0007012,C0007009,C1705480,C0003364,C0217087,C0013982,C0000379,C0006100,C0013227,C0036189,C0012854,C0001026,C0031453,C0058206,C0012447,C0050133,C0014027,C0033399,C0002006,C0674432,C1172934,C0006938,C2002836,C0003995,C0035696,C0037982,C0060700,C0076189,C0003751,C1257987,C0216784,C0020336,C1246476,C0036720,C0386393,C0065374,C0020281,C0289313,C0085241,C0243192,C0016384,C0248719,C0058282,C1101610,C0682921,C0286651,C2742796,C0968382,C0055661,C0684162,C0719949,C0036860,C0038432,C0028128,C0065556,C0014939,C0066685,C0001962,C1098320,C0017725,C0011710,C0043047,C0006644,C1314787,C0008269,C0251673,C0292818,C0126174,C0003015,C0019392,C0608663,C0007549,C0309049,C0038734,C0006674,C0046616&scopes=umls)
# API 4.71: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:31593
# API 4.80: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:50122
# API 4.17: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:8459
# API 4.11: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:43755
# API 4.70: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:80144
# API 4.75: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:2588
# API 4.81: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:5729
# API 4.79: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:17295
# API 4.72: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:48343
# API 4.67: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:53000
# API 4.83: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:16973
# API 4.78: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:17822
# API 4.73: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:35620
# API 4.86: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:26667
# API 1.44: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:28044
# API 1.44 pharos failed
# API 1.42: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:6541
# API 1.42 pharos failed
# API 1.50: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:46761
# API 1.50 pharos failed
# API 1.45: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:3380
# API 1.45 pharos failed
# API 1.41: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:33384
# API 1.41 pharos failed
# API 1.39: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:31781
# API 1.39 pharos failed
# API 4.88: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:81146
# API 1.43: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:27584
# API 1.43 pharos failed
# API 4.92: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:28775
# API 4.96: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:35222
# API 1.37: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:50686
# API 1.37 pharos failed
# API 4.89: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:16480
# API 1.54: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:35489
# API 1.54 pharos failed
# API 1.51: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:6503
# API 1.51 pharos failed
# API 1.55: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:90695
# API 1.55 pharos failed
# API 4.95: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:37670
# API 4.91: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:48706
# API 4.94: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:5420
# API 1.52: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:16670
# API 1.52 pharos failed
# API 1.38: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:16236
# API 1.38 pharos failed
# API 4.93: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:31932
# API 4.105: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:42223
# API 4.90: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:6980
# API 1.46: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:81724
# API 1.46 pharos failed
# API 1.49: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:48416
# API 1.49 pharos failed
# API 1.40: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:90531
# API 1.40 pharos failed
# API 1.60: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:3347
# API 1.60 pharos failed
# API 1.47: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:36044
# API 1.47 pharos failed
# API 1.58: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:2720
# API 1.58 pharos failed
# API 1.57: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:52211
# API 1.57 pharos failed
# API 1.53: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:135632
# API 1.53 pharos failed
# API 1.48: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:55490
# API 1.48 pharos failed
# API 1.56: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:77954
# API 1.56 pharos failed
# API 1.3: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:38730
# API 1.3 pharos failed
# API 4.107: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:45409
# API 1.1: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:80127
# API 1.1 pharos failed
# API 1.2: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:5959
# API 1.2 pharos failed
# API 1.59: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:80131
# API 1.59 pharos failed
# API 4.104: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:17115
# API 4.106: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:17823
# API 4.100: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:16240
# API 4.97: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:27363
# API 4.110: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:48433
# API 4.109: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:15377
# API 4.101: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:33699
# API 4.102: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:3390
# API 4.99: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:6476
# API 4.98: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:39548
# API 4.108: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:9288
# API 4.103: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:58048
# API 4.111: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:16737
# API 2.1: https://mydisease.info/v1/query?fields=disgenet.xrefs.mesh&size=250 (POST -d q=D000806,D015281,D002244,D009569,C034532,D015104,D004656,C529716,D012503,D000077154,C049347,C023676,C506722,D000068557,D004133,C469726,D004367,D002738,C031637,D000959,C002302,D005947,C112035,D011395,D002110,C505809,D014867,C523665,C081643,C084178,D012721,C100082,D000068756,C081489,D004247,D002117,D013148,D017706,D000450,D000105,D003900,D010649,D002216,D019808,D010830,D000069059,D016686,D006886,C089730,D035683,C085746,C042834,C081309,C039656,D002245,C065179,C055987,D001920,D045162,D005485,D001216,D013311,C543528,D012694,C432165,D004642,D015773,D000431,D006569,D013438,D061466,D004364,C020845,C004648,D004967,D019438,D012333,C058302,C097933,C016671,C027794,C003915,Q000819,D000809,D000077333,C437965,C043561,D006861,C010882&scopes=ctd.chemical_related_to_disease.mesh_chemical_id)
# API 1.6: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:36080
# API 1.6 pharos failed
# API 1.4: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:17089
# API 1.4 pharos failed
# API 1.7: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:4294
# API 1.7 pharos failed
# API 1.5: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:22587
# API 1.5 pharos failed
# API 1.9: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:35457
# API 1.9 pharos failed
# API 1.8: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:9241
# API 1.8 pharos failed
# API 1.12: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:137218
# API 1.12 pharos failed
# API 1.11: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:43755
# API 1.11 pharos failed
# API 1.10: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:7542
# API 1.10 pharos failed
# API 1.14: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:137052
# API 1.14 pharos failed
# API 1.13: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:4300
# API 1.13 pharos failed
# API 6.92: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:28775
# API 6.105: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:42223
# API 6.90: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:6980
# API 4.19: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:34543
# API 6.88: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:81146
# API 4.18: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:5801
# API 6.87: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:138186
# API 6.93: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:31932
# API 6.94: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:5420
# API 6.99: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:6476
# API 5.3: https://biothings.ncats.io/semmedchemical/query?fields=negatively_regulated_by (POST -d q=C0062068,C0014025,C0288171,C0031434,C0003018,C0071162,C0700447,C0772162,C0007012,C0007009,C1705480,C0003364,C0217087,C0013982,C0000379,C0006100,C0013227,C0036189,C0012854,C0001026,C0031453,C0058206,C0012447,C0050133,C0014027,C0033399,C0002006,C0674432,C1172934,C0006938,C2002836,C0003995,C0035696,C0037982,C0060700,C0076189,C0003751,C1257987,C0216784,C0020336,C1246476,C0036720,C0386393,C0065374,C0020281,C0289313,C0085241,C0243192,C0016384,C0248719,C0058282,C1101610,C0682921,C0286651,C2742796,C0968382,C0055661,C0684162,C0719949,C0036860,C0038432,C0028128,C0065556,C0014939,C0066685,C0001962,C1098320,C0017725,C0011710,C0043047,C0006644,C1314787,C0008269,C0251673,C0292818,C0126174,C0003015,C0019392,C0608663,C0007549,C0309049,C0038734,C0006674,C0046616&scopes=umls)
# API 4.20: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:48432
# API 7.77: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:4727
# API 7.78: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:17822
# API 7.79: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:17295
# API 7.80: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:50122
# API 7.81: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:5729
# API 6.104: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:17115
# API 6.113: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:4167
# API 6.112: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:6960
# API 6.114: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:131170
# API 6.102: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:3390
# API 6.98: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:39548
# API 6.101: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:33699
# API 6.95: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:37670
# API 6.106: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:17823
# API 7.82: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:80128
# API 7.83: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:16973
# API 6.103: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:58048
# API 6.107: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:45409
# API 8.1: https://mychem.info/v1/query?fields=drugcentral.drug_use.indication (POST -d q=CHEMBL1627733,CHEMBL49732,CHEMBL398545,CHEMBL3183193,CHEMBL729,CHEMBL257726,CHEMBL2109212,CHEMBL843,CHEMBL1326,CHEMBL578,CHEMBL2103830,CHEMBL1790017,CHEMBL846,CHEMBL76,CHEMBL1069,CHEMBL1393,CHEMBL408448,CHEMBL65567,CHEMBL402987,CHEMBL1729579,CHEMBL400527,CHEMBL1627737,CHEMBL1200469,CHEMBL191,CHEMBL253428,CHEMBL34241,CHEMBL1627734,CHEMBL3234446,CHEMBL410509,CHEMBL590799,CHEMBL19429,CHEMBL71595,CHEMBL577,CHEMBL252009,CHEMBL411557,CHEMBL35241,CHEMBL7064,CHEMBL252391,CHEMBL404117,CHEMBL409721,CHEMBL1725279,CHEMBL437242,CHEMBL1016,CHEMBL301523,CHEMBL3349878,CHEMBL2108700,CHEMBL253224,CHEMBL252003,CHEMBL2108986,CHEMBL289277,CHEMBL1200659,CHEMBL1234579,CHEMBL58510,CHEMBL260677,CHEMBL38380,CHEMBL806,CHEMBL90260,CHEMBL254900,CHEMBL411052,CHEMBL263663,CHEMBL411298,CHEMBL254493,CHEMBL1200335,CHEMBL592868,CHEMBL262670,CHEMBL1200542,CHEMBL1165,CHEMBL117,CHEMBL406291,CHEMBL58832,CHEMBL34868,CHEMBL564,CHEMBL257026,CHEMBL393220,CHEMBL251809,CHEMBL1201405,CHEMBL545,CHEMBL1560,CHEMBL1669,CHEMBL1222250,CHEMBL1487,CHEMBL268984,CHEMBL1201224,CHEMBL258698,CHEMBL438223,CHEMBL2095223,CHEMBL254911,CHEMBL1017,CHEMBL415330,CHEMBL257727,CHEMBL401397,CHEMBL261121,CHEMBL257229,CHEMBL541388,CHEMBL1200689,CHEMBL1201528,CHEMBL525960,CHEMBL2270068,CHEMBL258333,CHEMBL261423,CHEMBL1516,CHEMBL521035,CHEMBL254703,CHEMBL273453,CHEMBL55659,CHEMBL426566,CHEMBL35482,CHEMBL409105,CHEMBL1690,CHEMBL272925,CHEMBL3144487,CHEMBL437595,CHEMBL1614854,CHEMBL1627993,CHEMBL1513,CHEMBL260273,CHEMBL124025,CHEMBL121,CHEMBL411942,CHEMBL1200697,CHEMBL271225,CHEMBL408182,CHEMBL398771,CHEMBL333687,CHEMBL436639,CHEMBL269996,CHEMBL251808,CHEMBL1231413,CHEMBL400526,CHEMBL251804,CHEMBL429844,CHEMBL1651906,CHEMBL271224,CHEMBL1237,CHEMBL11298,CHEMBL163,CHEMBL408705,CHEMBL449317,CHEMBL1627738,CHEMBL401086,CHEMBL269997,CHEMBL254495,CHEMBL565612,CHEMBL995,CHEMBL1098659,CHEMBL1200569,CHEMBL254282,CHEMBL1627729,CHEMBL115622,CHEMBL1498,CHEMBL10,CHEMBL1200692,CHEMBL373742,CHEMBL257270,CHEMBL113,CHEMBL271223,CHEMBL1627731,CHEMBL186705,CHEMBL1231871,CHEMBL398940,CHEMBL1200534,CHEMBL46917,CHEMBL350414,CHEMBL1535&scopes=chembl.molecule_chembl_id)
# API 6.115: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:40448
# API 6.89: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:16480
# API 6.59: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:80131
# API 6.64: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:9927
# API 6.110: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:48433
# API 6.100: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:16240
# API 6.62: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:75095
# API 6.51: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:6503
# API 6.44: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:28044
# API 6.65: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:9464
# API 6.56: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:77954
# API 6.48: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:55490
# API 6.108: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:9288
# API 6.54: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:35489
# API 8.2: https://mychem.info/v1/query?fields=drugcentral.drug_use.contraindication (POST -d q=CHEMBL1627733,CHEMBL49732,CHEMBL398545,CHEMBL3183193,CHEMBL729,CHEMBL257726,CHEMBL2109212,CHEMBL843,CHEMBL1326,CHEMBL578,CHEMBL2103830,CHEMBL1790017,CHEMBL846,CHEMBL76,CHEMBL1069,CHEMBL1393,CHEMBL408448,CHEMBL65567,CHEMBL402987,CHEMBL1729579,CHEMBL400527,CHEMBL1627737,CHEMBL1200469,CHEMBL191,CHEMBL253428,CHEMBL34241,CHEMBL1627734,CHEMBL3234446,CHEMBL410509,CHEMBL590799,CHEMBL19429,CHEMBL71595,CHEMBL577,CHEMBL252009,CHEMBL411557,CHEMBL35241,CHEMBL7064,CHEMBL252391,CHEMBL404117,CHEMBL409721,CHEMBL1725279,CHEMBL437242,CHEMBL1016,CHEMBL301523,CHEMBL3349878,CHEMBL2108700,CHEMBL253224,CHEMBL252003,CHEMBL2108986,CHEMBL289277,CHEMBL1200659,CHEMBL1234579,CHEMBL58510,CHEMBL260677,CHEMBL38380,CHEMBL806,CHEMBL90260,CHEMBL254900,CHEMBL411052,CHEMBL263663,CHEMBL411298,CHEMBL254493,CHEMBL1200335,CHEMBL592868,CHEMBL262670,CHEMBL1200542,CHEMBL1165,CHEMBL117,CHEMBL406291,CHEMBL58832,CHEMBL34868,CHEMBL564,CHEMBL257026,CHEMBL393220,CHEMBL251809,CHEMBL1201405,CHEMBL545,CHEMBL1560,CHEMBL1669,CHEMBL1222250,CHEMBL1487,CHEMBL268984,CHEMBL1201224,CHEMBL258698,CHEMBL438223,CHEMBL2095223,CHEMBL254911,CHEMBL1017,CHEMBL415330,CHEMBL257727,CHEMBL401397,CHEMBL261121,CHEMBL257229,CHEMBL541388,CHEMBL1200689,CHEMBL1201528,CHEMBL525960,CHEMBL2270068,CHEMBL258333,CHEMBL261423,CHEMBL1516,CHEMBL521035,CHEMBL254703,CHEMBL273453,CHEMBL55659,CHEMBL426566,CHEMBL35482,CHEMBL409105,CHEMBL1690,CHEMBL272925,CHEMBL3144487,CHEMBL437595,CHEMBL1614854,CHEMBL1627993,CHEMBL1513,CHEMBL260273,CHEMBL124025,CHEMBL121,CHEMBL411942,CHEMBL1200697,CHEMBL271225,CHEMBL408182,CHEMBL398771,CHEMBL333687,CHEMBL436639,CHEMBL269996,CHEMBL251808,CHEMBL1231413,CHEMBL400526,CHEMBL251804,CHEMBL429844,CHEMBL1651906,CHEMBL271224,CHEMBL1237,CHEMBL11298,CHEMBL163,CHEMBL408705,CHEMBL449317,CHEMBL1627738,CHEMBL401086,CHEMBL269997,CHEMBL254495,CHEMBL565612,CHEMBL995,CHEMBL1098659,CHEMBL1200569,CHEMBL254282,CHEMBL1627729,CHEMBL115622,CHEMBL1498,CHEMBL10,CHEMBL1200692,CHEMBL373742,CHEMBL257270,CHEMBL113,CHEMBL271223,CHEMBL1627731,CHEMBL186705,CHEMBL1231871,CHEMBL398940,CHEMBL1200534,CHEMBL46917,CHEMBL350414,CHEMBL1535&scopes=chembl.molecule_chembl_id)
# API 6.57: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:52211
# API 6.45: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:3380
# API 6.50: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:46761
# API 6.96: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:35222
# API 6.46: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:81724
# API 6.91: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:48706
# API 6.58: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:2720
# API 6.116: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:9937
# API 6.60: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:3347
# API 6.55: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:90695
# API 6.71: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:31593
# API 6.81: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:5729
# API 6.75: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:2588
# API 6.82: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:80128
# API 6.42: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:6541
# API 6.80: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:50122
# API 6.41: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:33384
# API 6.97: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:27363
# API 6.69: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:33709
# API 6.83: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:16973
# API 6.67: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:53000
# API 6.72: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:48343
# API 6.63: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:5132
# API 6.47: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:36044
# API 6.52: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:16670
# API 6.53: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:135632
# API 6.66: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:80132
# API 7.85: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:30145
# API 6.70: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:80144
# API 6.49: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:48416
# API 7.93: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:31932
# API 7.84: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:4784
# API 7.89: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:16480
# API 7.91: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:48706
# API 7.88: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:81146
# API 7.92: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:28775
# API 7.86: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:26667
# API 7.87: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:138186
# API 7.94: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:5420
# API 6.78: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:17822
# API 6.77: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:4727
# API 6.74: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:3165
# API 6.86: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:26667
# API 6.79: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:17295
# API 6.68: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:17996
# API 6.85: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:30145
# API 6.109: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:15377
# API 6.84: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:4784
# API 6.43: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:27584
# API 7.103: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:58048
# API 7.95: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:37670
# API 7.99: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:6476
# API 7.102: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:3390
# API 7.100: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:16240
# API 7.97: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:27363
# API 4.7: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:4294
# API 7.96: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:35222
# API 7.104: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:17115
# API 7.101: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:33699
# API 7.109: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:15377
# API 7.108: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:9288
# API 6.73: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:35620
# API 6.111: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:16737
# API 7.110: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:48433
# API 7.111: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:16737
# API 6.76: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:48705
# API 6.61: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:17234
# API 6.3: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:38730
# API 4.8: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:9241
# API 4.115: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:40448
# API 4.112: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:6960
# API 4.116: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:9937
# API 6.1: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:80127
# API 7.113: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:4167
# API 7.114: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:131170
# API 7.38: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:16236
# API 4.113: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:4167
# API 7.31: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:16526
# API 7.40: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:90531
# API 7.116: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:9937
# API 7.37: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:50686
# API 4.6: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:36080
# API 7.33: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:5679
# API 7.34: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:24433
# API 7.36: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:83828
# API 7.41: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:33384
# API 7.115: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:40448
# API 5.13: https://biothings.ncats.io/semmedchemical/query?fields=produced_by (POST -d q=C0062068,C0014025,C0288171,C0031434,C0003018,C0071162,C0700447,C0772162,C0007012,C0007009,C1705480,C0003364,C0217087,C0013982,C0000379,C0006100,C0013227,C0036189,C0012854,C0001026,C0031453,C0058206,C0012447,C0050133,C0014027,C0033399,C0002006,C0674432,C1172934,C0006938,C2002836,C0003995,C0035696,C0037982,C0060700,C0076189,C0003751,C1257987,C0216784,C0020336,C1246476,C0036720,C0386393,C0065374,C0020281,C0289313,C0085241,C0243192,C0016384,C0248719,C0058282,C1101610,C0682921,C0286651,C2742796,C0968382,C0055661,C0684162,C0719949,C0036860,C0038432,C0028128,C0065556,C0014939,C0066685,C0001962,C1098320,C0017725,C0011710,C0043047,C0006644,C1314787,C0008269,C0251673,C0292818,C0126174,C0003015,C0019392,C0608663,C0007549,C0309049,C0038734,C0006674,C0046616&scopes=umls)
# API 7.32: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:27732
# API 7.112: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:6960
# API 6.2: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:5959
# API 7.35: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:9434
# API 4.114: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:131170
# API 7.39: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:31781
# API 6.4: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:17089
# API 6.5: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:22587
# API 7.90: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:6980
# API 7.47: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:36044
# API 6.14: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:137052
# API 7.50: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:46761
# API 6.13: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:4300
# API 7.49: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:48416
# API 7.44: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:28044
# API 6.7: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:4294
# API 6.12: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:137218
# API 6.16: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:17196
# API 6.15: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:50178
# API 6.21: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:3638
# API 7.51: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:6503
# API 7.52: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:16670
# API 6.17: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:8459
# API 7.56: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:77954
# API 7.53: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:135632
# API 7.55: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:90695
# API 7.58: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:2720
# API 7.54: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:35489
# API 6.18: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:5801
# API 7.57: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:52211
# API 6.23: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:137177
# API 7.61: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:17234
# API 6.25: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:15903
# API 7.59: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:80131
# API 6.19: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:34543
# API 6.22: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:90705
# API 6.20: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:48432
# API 5.5: https://biothings.ncats.io/semmedchemical/query?fields=positively_regulated_by (POST -d q=C0062068,C0014025,C0288171,C0031434,C0003018,C0071162,C0700447,C0772162,C0007012,C0007009,C1705480,C0003364,C0217087,C0013982,C0000379,C0006100,C0013227,C0036189,C0012854,C0001026,C0031453,C0058206,C0012447,C0050133,C0014027,C0033399,C0002006,C0674432,C1172934,C0006938,C2002836,C0003995,C0035696,C0037982,C0060700,C0076189,C0003751,C1257987,C0216784,C0020336,C1246476,C0036720,C0386393,C0065374,C0020281,C0289313,C0085241,C0243192,C0016384,C0248719,C0058282,C1101610,C0682921,C0286651,C2742796,C0968382,C0055661,C0684162,C0719949,C0036860,C0038432,C0028128,C0065556,C0014939,C0066685,C0001962,C1098320,C0017725,C0011710,C0043047,C0006644,C1314787,C0008269,C0251673,C0292818,C0126174,C0003015,C0019392,C0608663,C0007549,C0309049,C0038734,C0006674,C0046616&scopes=umls)
# API 6.24: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:35235
# API 5.12: https://biothings.ncats.io/semmedchemical/query?fields=affected_by (POST -d q=C0062068,C0014025,C0288171,C0031434,C0003018,C0071162,C0700447,C0772162,C0007012,C0007009,C1705480,C0003364,C0217087,C0013982,C0000379,C0006100,C0013227,C0036189,C0012854,C0001026,C0031453,C0058206,C0012447,C0050133,C0014027,C0033399,C0002006,C0674432,C1172934,C0006938,C2002836,C0003995,C0035696,C0037982,C0060700,C0076189,C0003751,C1257987,C0216784,C0020336,C1246476,C0036720,C0386393,C0065374,C0020281,C0289313,C0085241,C0243192,C0016384,C0248719,C0058282,C1101610,C0682921,C0286651,C2742796,C0968382,C0055661,C0684162,C0719949,C0036860,C0038432,C0028128,C0065556,C0014939,C0066685,C0001962,C1098320,C0017725,C0011710,C0043047,C0006644,C1314787,C0008269,C0251673,C0292818,C0126174,C0003015,C0019392,C0608663,C0007549,C0309049,C0038734,C0006674,C0046616&scopes=umls)
# API 5.8: https://biothings.ncats.io/semmedchemical/query?fields=prevents (POST -d q=C0062068,C0014025,C0288171,C0031434,C0003018,C0071162,C0700447,C0772162,C0007012,C0007009,C1705480,C0003364,C0217087,C0013982,C0000379,C0006100,C0013227,C0036189,C0012854,C0001026,C0031453,C0058206,C0012447,C0050133,C0014027,C0033399,C0002006,C0674432,C1172934,C0006938,C2002836,C0003995,C0035696,C0037982,C0060700,C0076189,C0003751,C1257987,C0216784,C0020336,C1246476,C0036720,C0386393,C0065374,C0020281,C0289313,C0085241,C0243192,C0016384,C0248719,C0058282,C1101610,C0682921,C0286651,C2742796,C0968382,C0055661,C0684162,C0719949,C0036860,C0038432,C0028128,C0065556,C0014939,C0066685,C0001962,C1098320,C0017725,C0011710,C0043047,C0006644,C1314787,C0008269,C0251673,C0292818,C0126174,C0003015,C0019392,C0608663,C0007549,C0309049,C0038734,C0006674,C0046616&scopes=umls)
# API 5.14: https://biothings.ncats.io/semmedchemical/query?fields=causes (POST -d q=C0062068,C0014025,C0288171,C0031434,C0003018,C0071162,C0700447,C0772162,C0007012,C0007009,C1705480,C0003364,C0217087,C0013982,C0000379,C0006100,C0013227,C0036189,C0012854,C0001026,C0031453,C0058206,C0012447,C0050133,C0014027,C0033399,C0002006,C0674432,C1172934,C0006938,C2002836,C0003995,C0035696,C0037982,C0060700,C0076189,C0003751,C1257987,C0216784,C0020336,C1246476,C0036720,C0386393,C0065374,C0020281,C0289313,C0085241,C0243192,C0016384,C0248719,C0058282,C1101610,C0682921,C0286651,C2742796,C0968382,C0055661,C0684162,C0719949,C0036860,C0038432,C0028128,C0065556,C0014939,C0066685,C0001962,C1098320,C0017725,C0011710,C0043047,C0006644,C1314787,C0008269,C0251673,C0292818,C0126174,C0003015,C0019392,C0608663,C0007549,C0309049,C0038734,C0006674,C0046616&scopes=umls)
# API 5.6: https://biothings.ncats.io/semmedchemical/query?fields=disrupts (POST -d q=C0062068,C0014025,C0288171,C0031434,C0003018,C0071162,C0700447,C0772162,C0007012,C0007009,C1705480,C0003364,C0217087,C0013982,C0000379,C0006100,C0013227,C0036189,C0012854,C0001026,C0031453,C0058206,C0012447,C0050133,C0014027,C0033399,C0002006,C0674432,C1172934,C0006938,C2002836,C0003995,C0035696,C0037982,C0060700,C0076189,C0003751,C1257987,C0216784,C0020336,C1246476,C0036720,C0386393,C0065374,C0020281,C0289313,C0085241,C0243192,C0016384,C0248719,C0058282,C1101610,C0682921,C0286651,C2742796,C0968382,C0055661,C0684162,C0719949,C0036860,C0038432,C0028128,C0065556,C0014939,C0066685,C0001962,C1098320,C0017725,C0011710,C0043047,C0006644,C1314787,C0008269,C0251673,C0292818,C0126174,C0003015,C0019392,C0608663,C0007549,C0309049,C0038734,C0006674,C0046616&scopes=umls)
# ...
# API 4.27 hmdb failed
# API 4.1 hmdb failed
# API 7.60: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:3347
# API 7.48: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:55490
# API 7.46: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:81724
# API 6.10: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:7542
# API 5.7: https://biothings.ncats.io/semmedchemical/query?fields=coexists_with (POST -d q=C0062068,C0014025,C0288171,C0031434,C0003018,C0071162,C0700447,C0772162,C0007012,C0007009,C1705480,C0003364,C0217087,C0013982,C0000379,C0006100,C0013227,C0036189,C0012854,C0001026,C0031453,C0058206,C0012447,C0050133,C0014027,C0033399,C0002006,C0674432,C1172934,C0006938,C2002836,C0003995,C0035696,C0037982,C0060700,C0076189,C0003751,C1257987,C0216784,C0020336,C1246476,C0036720,C0386393,C0065374,C0020281,C0289313,C0085241,C0243192,C0016384,C0248719,C0058282,C1101610,C0682921,C0286651,C2742796,C0968382,C0055661,C0684162,C0719949,C0036860,C0038432,C0028128,C0065556,C0014939,C0066685,C0001962,C1098320,C0017725,C0011710,C0043047,C0006644,C1314787,C0008269,C0251673,C0292818,C0126174,C0003015,C0019392,C0608663,C0007549,C0309049,C0038734,C0006674,C0046616&scopes=umls)
# API 6.27: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:2718
# API 4.31 hmdb failed
# API 6.6: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:36080
# API 6.28: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:33708
# API 4.35 hmdb failed
# API 4.36 hmdb failed
# API 1.112: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:6960
# API 1.112 pharos failed
# API 1.109: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:15377
# API 1.109 pharos failed
# API 1.108: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:9288
# API 1.108 pharos failed
# API 4.33 hmdb failed
# API 1.111: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:16737
# API 1.111 pharos failed
# API 1.113: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:4167
# API 1.113 pharos failed
# API 1.110: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:48433
# API 1.110 pharos failed
# API 1.107: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:45409
# API 1.107 pharos failed
# API 4.3: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:38730
# API 4.5: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:22587
# API 4.23: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:137177
# API 4.21: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:3638
# API 4.4: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:17089
# API 7.66: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:80132
# API 6.33: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:5679
# API 4.2: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:5959
# API 4.22: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:90705
# API 4.24: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:35235
# API 7.70: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:80144
# API 7.67: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:53000
# API 7.73: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:35620
# API 7.76: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:48705
# API 7.75: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:2588
# API 7.69: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:33709
# API 4.25: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:15903
# API 4.26: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:4786
# API 7.68: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:17996
# API 7.72: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:48343
# API 7.71: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:31593
# API 6.38: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:16236
# API 6.34: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:24433
# API 6.37: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:50686
# API 6.36: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:83828
# API 6.40: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:90531
# API 6.31: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:16526
# API 4.34 hmdb failed
# API 5.2: https://biothings.ncats.io/semmedchemical/query?fields=treats (POST -d q=C0062068,C0014025,C0288171,C0031434,C0003018,C0071162,C0700447,C0772162,C0007012,C0007009,C1705480,C0003364,C0217087,C0013982,C0000379,C0006100,C0013227,C0036189,C0012854,C0001026,C0031453,C0058206,C0012447,C0050133,C0014027,C0033399,C0002006,C0674432,C1172934,C0006938,C2002836,C0003995,C0035696,C0037982,C0060700,C0076189,C0003751,C1257987,C0216784,C0020336,C1246476,C0036720,C0386393,C0065374,C0020281,C0289313,C0085241,C0243192,C0016384,C0248719,C0058282,C1101610,C0682921,C0286651,C2742796,C0968382,C0055661,C0684162,C0719949,C0036860,C0038432,C0028128,C0065556,C0014939,C0066685,C0001962,C1098320,C0017725,C0011710,C0043047,C0006644,C1314787,C0008269,C0251673,C0292818,C0126174,C0003015,C0019392,C0608663,C0007549,C0309049,C0038734,C0006674,C0046616&scopes=umls)
# API 6.35: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:9434
# API 5.11: https://biothings.ncats.io/semmedchemical/query?fields=physically_interacts_with (POST -d q=C0062068,C0014025,C0288171,C0031434,C0003018,C0071162,C0700447,C0772162,C0007012,C0007009,C1705480,C0003364,C0217087,C0013982,C0000379,C0006100,C0013227,C0036189,C0012854,C0001026,C0031453,C0058206,C0012447,C0050133,C0014027,C0033399,C0002006,C0674432,C1172934,C0006938,C2002836,C0003995,C0035696,C0037982,C0060700,C0076189,C0003751,C1257987,C0216784,C0020336,C1246476,C0036720,C0386393,C0065374,C0020281,C0289313,C0085241,C0243192,C0016384,C0248719,C0058282,C1101610,C0682921,C0286651,C2742796,C0968382,C0055661,C0684162,C0719949,C0036860,C0038432,C0028128,C0065556,C0014939,C0066685,C0001962,C1098320,C0017725,C0011710,C0043047,C0006644,C1314787,C0008269,C0251673,C0292818,C0126174,C0003015,C0019392,C0608663,C0007549,C0309049,C0038734,C0006674,C0046616&scopes=umls)
# API 1.115: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:40448
# API 1.115 pharos failed
# API 1.116 pharos failed
# API 4.29 hmdb failed
# API 7.43: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:27584
# API 7.23 scibite failed
# API 7.74: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:3165
# API 6.11: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:43755
# API 7.24 scibite failed
# API 6.9: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:35457
# API 4.30: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:39061
# API 4.61 hmdb failed
# API 4.62 hmdb failed
# API 7.28 scibite failed
# API 7.29 scibite failed
# API 6.32: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:27732
# API 7.3: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:38730
# API 4.38: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:16236
# API 7.4: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:17089
# API 7.6: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:36080
# API 4.40: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:90531
# API 7.13: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:4300
# API 7.5: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:22587
# API 4.44: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:28044
# API 4.46: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:81724
# API 7.7: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:4294
# API 7.9: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:35457
# API 7.12: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:137218
# API 4.43: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:27584
# API 7.18: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:5801
# API 4.49: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:48416
# API 4.54: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:35489
# API 4.51: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:6503
# API 7.15: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:50178
# API 4.52: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:16670
# API 4.48: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:55490
# API 4.41: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:33384
# API 4.45: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:3380
# API 7.16: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:17196
# API 4.47: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:36044
# API 7.14: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:137052
# API 4.42: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:6541
# API 7.10: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:7542
# API 4.53: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:135632
# API 4.50: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:46761
# API 4.63 hmdb failed
# API 6.39: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:31781
# API 7.25 scibite failed
# API 4.57: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:52211
# API 7.30 scibite failed
# API 6.30: https://automat.renci.org/cord19_scigraph_v2/chemical_substance/disease/CHEBI:39061
# API 7.2: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:5959
# API 7.8: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:9241
# API 1.114: https://automat.renci.org/pharos/chemical_substance/disease/CHEBI:131170
# API 1.114 pharos failed
# API 4.37: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:50686
# API 4.28: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:33708
# API 7.27: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:2718
# API 7.1: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:80127
# API 4.56: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:77954
# API 4.39: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:31781
# API 4.32: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:27732
# API 7.22: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:90705
# API 4.59: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:80131
# API 4.58: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:2720
# API 7.11: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:43755
# API 7.17: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:8459
# API 7.26: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:4786
# API 7.20: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:48432
# API 4.55: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:90695
# API 4.64: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:9927
# API 4.65: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:9464
# API 4.60: https://automat.renci.org/hmdb/chemical_substance/disease/CHEBI:3347
# API 7.21: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:3638
# API 7.19: https://automat.renci.org/cord19_scibite_v2/chemical_substance/disease/CHEBI:34543
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-5a1ed2769b04> in <module>()
# ----> 1 fc.connect(verbose=True)
#
# ~/Documents/work/biothings_explorer/bte_schema/biothings_explorer/user_query_dispatcher.py in connect(self, verbose)
#    1156
#    1157     def connect(self, verbose=False):
# -> 1158         self.fc.connect(verbose=verbose)
#    1159
#    1160     def to_json(self):
#
# ~/Documents/work/biothings_explorer/bte_schema/biothings_explorer/user_query_dispatcher.py in connect(self, verbose)
#     912                             pred=None,
#     913                         )
# --> 914                         self.seqd[query_id].query(verbose=verbose)
#     915                         if len(self.seqd[query_id].G) < 2:
#     916                             break
#
# ~/Documents/work/biothings_explorer/bte_schema/biothings_explorer/user_query_dispatcher.py in query(self, verbose)
#     376         source_nodes_cnt = len(self.G)
#     377         # make API calls and restructure API outputs
# --> 378         (_res, log) = self.dp.dispatch(input_edges, verbose=verbose, loop=self.loop)
#     379         self.log += log
#     380         # load API outputs into the MultiDiGraph
#
# ~/Documents/work/biothings_explorer/bte_schema/biothings_explorer/api_call_dispatcher.py in dispatch(self, edges, verbose, loop)
#     180         # print(apis, inputs, modes, vals, grped_edges)
#     181         responses, self.log = self.caller.call_apis(
# --> 182             self.get_all_edges(query_id2inputs_mapping), verbose=verbose, loop=loop
#     183         )
#     184         if verbose:
#
# ~/Documents/work/biothings_explorer/bte_schema/biothings_explorer/apicall.py in call_apis(self, inputs, verbose, loop)
#     195         if not loop:
#     196             loop = asyncio.new_event_loop()
# --> 197         return (loop.run_until_complete(self.run(inputs, verbose=verbose)), self.log)
#     198         # res = asyncio.run(self.run(inputs, verbose=verbose))
#     199         # return (res, self.log)
#
# ~/anaconda3/lib/python3.6/asyncio/base_events.py in run_until_complete(self, future)
#     453         future.add_done_callback(_run_until_complete_cb)
#     454         try:
# --> 455             self.run_forever()
#     456         except:
#     457             if new_task and future.done() and not future.cancelled():
#
# ~/anaconda3/lib/python3.6/asyncio/base_events.py in run_forever(self)
#     420             events._set_running_loop(self)
#     421             while True:
# --> 422                 self._run_once()
#     423                 if self._stopping:
#     424                     break
#
# ~/anaconda3/lib/python3.6/asyncio/base_events.py in _run_once(self)
#    1394                            timeout * 1e3, dt * 1e3)
#    1395         else:
# -> 1396             event_list = self._selector.select(timeout)
#    1397         self._process_events(event_list)
#    1398
#
# ~/anaconda3/lib/python3.6/selectors.py in select(self, timeout)
#     575             ready = []
#     576             try:
# --> 577                 kev_list = self._kqueue.control(None, max_ev, timeout)
#     578             except InterruptedError:
#     579                 return ready
#
# KeyboardInterrupt:

# %%
output = fc.to_reasoner_std()

# %%
output.keys()
# Out:
# dict_keys(['question_graph', 'knowledge_graph', 'results'])

# %%
output['question_graph']
# Out:
# {'edges': [{'id': 'e0',
#    'source_id': 'n0',
#    'target_id': 'n1',
#    'directed': True},
#   {'id': 'e1', 'source_id': 'n1', 'target_id': 'n2', 'directed': True}],
#  'nodes': [{'id': 'n0', 'type': 'Gene'},
#   {'id': 'n1', 'type': 'ChemicalSubstance'},
#   {'id': 'n2', 'type': 'DiseaseOrPhenotypicFeature'}]}

# %%
output['knowledge_graph']['nodes'][:20]
# Out:
# [{'id': 'ENTREZ:ACE2',
#   'name': ['angiotensin-converting enzyme homolog',
#    'metalloprotease MPROT15',
#    'angiotensin-converting enzyme 2',
#    'angiotensin I converting enzyme (peptidyl-dipeptidase A) 2',
#    'ACE-related carboxypeptidase',
#    'angiotensin I converting enzyme 2',
#    'peptidyl-dipeptidase A'],
#   'type': 'Gene',
#   'equivalent_identifiers': {'bts:ensembl': ['ENSG00000130234'],
#    'bts:hgnc': ['13557'],
#    'bts:omim': ['300335'],
#    'bts:entrez': ['59272'],
#    'bts:pharos': [],
#    'bts:umls': ['C1422064'],
#    'bts:unigene': ['Hs.178098'],
#    'bts:pharmgkb': ['PA425'],
#    'bts:name': ['angiotensin-converting enzyme homolog',
#     'metalloprotease MPROT15',
#     'angiotensin-converting enzyme 2',
#     'angiotensin I converting enzyme (peptidyl-dipeptidase A) 2',
#     'ACE-related carboxypeptidase',
#     'angiotensin I converting enzyme 2',
#     'peptidyl-dipeptidase A'],
#    'bts:symbol': ['ACE2']}},
#  {'id': 'CHEMBL:CHEMBL260273',
#   'name': [],
#   'type': 'ChemicalSubstance',
#   'equivalent_identifiers': {'bts:inchi': ['InChI=1S/C22H33N2O6P/c1-15(2)12-19(23-16(3)25)21(26)24-11-7-10-20(24)31(29,30)14-18(22(27)28)13-17-8-5-4-6-9-17/h4-6,8-9,15,18-20H,7,10-14H2,1-3H3,(H,23,25)(H,27,28)(H,29,30)/t18-,19+,20+/m1/s1'],
#    'bts:inchikey': ['DGMLSHVZZKUDPN-AABGKKOBSA-N'],
#    'bts:rxcui': [],
#    'bts:smiles': ['CC(C)C[C@H](NC(=O)C)C(=O)N1CCC[C@@H]1P(=O)(O)C[C@@H](Cc2ccccc2)C(=O)O'],
#    'bts:pubchem': [24827312],
#    'bts:chembl': ['CHEMBL260273'],
#    'bts:drugbank': [],
#    'bts:name': [],
#    'bts:unii': [],
#    'bts:umls': [],
#    'bts:mesh': []}},
#  {'id': 'CHEMBL:CHEMBL429844',
#   'name': [],
#   'type': 'ChemicalSubstance',
#   'equivalent_identifiers': {'bts:inchi': ['InChI=1S/C19H23Cl2N3O4/c1-11(2)3-16(18(25)26)23-17(19(27)28)7-15-8-22-10-24(15)9-12-4-13(20)6-14(21)5-12/h4-6,8,10-11,16-17,23H,3,7,9H2,1-2H3,(H,25,26)(H,27,28)/t16-,17-/m0/s1'],
#    'bts:inchikey': ['NTCCRGGIJNDEAB-IRXDYDNUSA-N'],
#    'bts:rxcui': [],
#    'bts:smiles': ['CC(C)C[C@H](N[C@@H](Cc1cncn1Cc2cc(Cl)cc(Cl)c2)C(=O)O)C(=O)O'],
#    'bts:pubchem': [448281],
#    'bts:chembl': ['CHEMBL429844'],
#    'bts:drugbank': ['DB12271'],
#    'bts:name': [],
#    'bts:unii': ['4LD0ZHV25K'],
#    'bts:umls': [],
#    'bts:mesh': []}},
#  {'id': 'DRUGBANK:DB05203',
#   'name': [],
#   'type': 'ChemicalSubstance',
#   'equivalent_identifiers': {'bts:inchi': [],
#    'bts:inchikey': [],
#    'bts:rxcui': [],
#    'bts:smiles': [],
#    'bts:pubchem': [],
#    'bts:chembl': [],
#    'bts:drugbank': ['DB05203'],
#    'bts:name': [],
#    'bts:unii': [],
#    'bts:umls': [],
#    'bts:mesh': []}},
#  {'id': 'UMLS:C0003015',
#   'name': None,
#   'type': 'ChemicalSubstance',
#   'equivalent_identifiers': {'bts:umls': ['C0003015']}},
#  {'id': 'UMLS:C0012854',
#   'name': None,
#   'type': 'ChemicalSubstance',
#   'equivalent_identifiers': {'bts:umls': ['C0012854']}},
#  {'id': 'UMLS:C0058206',
#   'name': None,
#   'type': 'ChemicalSubstance',
#   'equivalent_identifiers': {'bts:umls': ['C0058206']}},
#  {'id': 'UMLS:C0065556',
#   'name': None,
#   'type': 'ChemicalSubstance',
#   'equivalent_identifiers': {'bts:umls': ['C0065556']}},
#  {'id': 'UMLS:C0682921',
#   'name': None,
#   'type': 'ChemicalSubstance',
#   'equivalent_identifiers': {'bts:umls': ['C0682921']}},
#  {'id': 'UMLS:C0772162',
#   'name': None,
#   'type': 'ChemicalSubstance',
#   'equivalent_identifiers': {'bts:umls': ['C0772162']}},
#  {'id': 'UMLS:C1098320',
#   'name': None,
#   'type': 'ChemicalSubstance',
#   'equivalent_identifiers': {'bts:umls': ['C1098320']}},
#  {'id': 'UMLS:C1314787',
#   'name': None,
#   'type': 'ChemicalSubstance',
#   'equivalent_identifiers': {'bts:umls': ['C1314787']}},
#  {'id': 'UMLS:C0014939',
#   'name': None,
#   'type': 'ChemicalSubstance',
#   'equivalent_identifiers': {'bts:umls': ['C0014939']}},
#  {'id': 'UMLS:C0309049',
#   'name': None,
#   'type': 'ChemicalSubstance',
#   'equivalent_identifiers': {'bts:umls': ['C0309049']}},
#  {'id': 'UMLS:C0608663',
#   'name': None,
#   'type': 'ChemicalSubstance',
#   'equivalent_identifiers': {'bts:umls': ['C0608663']}},
#  {'id': 'UMLS:C0684162',
#   'name': None,
#   'type': 'ChemicalSubstance',
#   'equivalent_identifiers': {'bts:umls': ['C0684162']}},
#  {'id': 'UMLS:C1257987',
#   'name': None,
#   'type': 'ChemicalSubstance',
#   'equivalent_identifiers': {'bts:umls': ['C1257987']}},
#  {'id': 'NAME:LISINOPRIL',
#   'name': ['LISINOPRIL'],
#   'type': 'ChemicalSubstance',
#   'equivalent_identifiers': {'bts:inchi': ['InChI=1S/C21H31N3O5/c22-13-5-4-9-16(19(25)24-14-6-10-18(24)21(28)29)23-17(20(26)27)12-11-15-7-2-1-3-8-15/h1-3,7-8,16-18,23H,4-6,9-14,22H2,(H,26,27)(H,28,29)/t16-,17-,18-/m0/s1'],
#    'bts:inchikey': ['RLAWWYSOJDYHDC-BZSNNMDCSA-N'],
#    'bts:rxcui': [],
#    'bts:smiles': ['NCCCC[C@H](N[C@@H](CCc1ccccc1)C(=O)O)C(=O)N2CCC[C@H]2C(=O)O'],
#    'bts:pubchem': [11865407],
#    'bts:chembl': ['CHEMBL1237'],
#    'bts:drugbank': ['DB00722'],
#    'bts:name': ['LISINOPRIL'],
#    'bts:unii': ['7Q3P4BS2FD'],
#    'bts:umls': ['C0065374'],
#    'bts:mesh': ['D017706']}},
#  {'id': 'NAME:FLUTAMIDE',
#   'name': ['FLUTAMIDE'],
#   'type': 'ChemicalSubstance',
#   'equivalent_identifiers': {'bts:inchi': ['InChI=1S/C11H11F3N2O3/c1-6(2)10(17)15-7-3-4-9(16(18)19)8(5-7)11(12,13)14/h3-6H,1-2H3,(H,15,17)'],
#    'bts:inchikey': ['MKXKFYHWDHIYRV-UHFFFAOYSA-N'],
#    'bts:rxcui': ['4508'],
#    'bts:smiles': ['CC(C)C(=O)Nc1ccc(c(c1)C(F)(F)F)[N+](=O)[O-]'],
#    'bts:pubchem': [3397],
#    'bts:chembl': ['CHEMBL806'],
#    'bts:drugbank': ['DB00499'],
#    'bts:name': ['FLUTAMIDE'],
#    'bts:unii': ['76W6J0943E'],
#    'bts:umls': ['C0016384'],
#    'bts:mesh': ['D005485']}},
#  {'id': 'NAME:MOEXIPRIL',
#   'name': ['MOEXIPRIL'],
#   'type': 'ChemicalSubstance',
#   'equivalent_identifiers': {'bts:inchi': ['InChI=1S/C27H34N2O7/c1-5-36-27(33)21(12-11-18-9-7-6-8-10-18)28-17(2)25(30)29-16-20-15-24(35-4)23(34-3)14-19(20)13-22(29)26(31)32/h6-10,14-15,17,21-22,28H,5,11-13,16H2,1-4H3,(H,31,32)/t17-,21-,22-/m0/s1'],
#    'bts:inchikey': ['UWWDHYUMIORJTA-HSQYWUDLSA-N'],
#    'bts:rxcui': ['30131'],
#    'bts:smiles': ['CCOC(=O)[C@H](CCc1ccccc1)N[C@@H](C)C(=O)N2Cc3cc(OC)c(OC)cc3C[C@H]2C(=O)O'],
#    'bts:pubchem': [40466988],
#    'bts:chembl': ['CHEMBL1165'],
#    'bts:drugbank': ['DB00691'],
#    'bts:name': ['MOEXIPRIL'],
#    'bts:unii': ['WT87C52TJZ'],
#    'bts:umls': ['C0066685'],
#    'bts:mesh': ['C058302']}}]

# %%
output['knowledge_graph']['edges'][:20]
# Out:
# [{'source_id': 'ENTREZ:ACE2',
#   'target_id': 'CHEMBL:CHEMBL260273',
#   'edge_source': 'dgidb_gene2chemical',
#   'id': '2720cfda869ff775b4c06f199d7e345331bd83b0',
#   'type': 'targetedBy'},
#  {'source_id': 'ENTREZ:ACE2',
#   'target_id': 'CHEMBL:CHEMBL429844',
#   'edge_source': 'dgidb_gene2chemical',
#   'id': 'c766ed7c37f23ead58a4e83777d61b0de4d0b19c',
#   'type': 'targetedBy'},
#  {'source_id': 'ENTREZ:ACE2',
#   'target_id': 'DRUGBANK:DB05203',
#   'edge_source': 'mychem.info',
#   'id': '03ce86b5f42fc668191c4a9b494c7e60c5c34f14',
#   'type': 'targetedBy'},
#  {'source_id': 'ENTREZ:ACE2',
#   'target_id': 'UMLS:C0003015',
#   'edge_source': 'semmedgene',
#   'id': 'a8bd272d050d9c12af163735b9b9edac2b07a719',
#   'type': 'molecularlyInteractsWith'},
#  {'source_id': 'ENTREZ:ACE2',
#   'target_id': 'UMLS:C0003015',
#   'edge_source': 'semmedgene',
#   'id': 'a8bd272d050d9c12af163735b9b9edac2b07a719',
#   'type': 'molecularlyInteractsWith'},
#  {'source_id': 'ENTREZ:ACE2',
#   'target_id': 'UMLS:C0012854',
#   'edge_source': 'semmedgene',
#   'id': '57091960ded0f1bcf6af15357296ef50629e39aa',
#   'type': 'molecularlyInteractsWith'},
#  {'source_id': 'ENTREZ:ACE2',
#   'target_id': 'UMLS:C0058206',
#   'edge_source': 'semmedgene',
#   'id': 'c4e994c106dd4dc9404ac1be7973d94f10f71366',
#   'type': 'molecularlyInteractsWith'},
#  {'source_id': 'ENTREZ:ACE2',
#   'target_id': 'UMLS:C0065556',
#   'edge_source': 'semmedgene',
#   'id': 'b3a259f71b23307a859d8d64687e8a5e1ac179f4',
#   'type': 'molecularlyInteractsWith'},
#  {'source_id': 'ENTREZ:ACE2',
#   'target_id': 'UMLS:C0682921',
#   'edge_source': 'semmedgene',
#   'id': '5311d640414bfb77414343da2f539eca0cd04c4f',
#   'type': 'molecularlyInteractsWith'},
#  {'source_id': 'ENTREZ:ACE2',
#   'target_id': 'UMLS:C0772162',
#   'edge_source': 'semmedgene',
#   'id': '50c16358e9035afc3c468db1116ea0f0ae9a99d6',
#   'type': 'molecularlyInteractsWith'},
#  {'source_id': 'ENTREZ:ACE2',
#   'target_id': 'UMLS:C1098320',
#   'edge_source': 'semmedgene',
#   'id': 'e99c3887db5dda334dad4b36fbf81ee8fbbcc4bf',
#   'type': 'molecularlyInteractsWith'},
#  {'source_id': 'ENTREZ:ACE2',
#   'target_id': 'UMLS:C1314787',
#   'edge_source': 'semmedgene',
#   'id': '9200a57504f3cc566228c0e869911be38d3e8fb8',
#   'type': 'molecularlyInteractsWith'},
#  {'source_id': 'ENTREZ:ACE2',
#   'target_id': 'UMLS:C0014939',
#   'edge_source': 'semmedgene',
#   'id': '74a87309f99a09831b3ca128b68765ebb50cc5f4',
#   'type': 'molecularlyInteractsWith'},
#  {'source_id': 'ENTREZ:ACE2',
#   'target_id': 'UMLS:C0309049',
#   'edge_source': 'semmedgene',
#   'id': '0abafcc58fdf8af5b773c72838808fd743cb82ed',
#   'type': 'molecularlyInteractsWith'},
#  {'source_id': 'ENTREZ:ACE2',
#   'target_id': 'UMLS:C0608663',
#   'edge_source': 'semmedgene',
#   'id': '7857fc4e384612d831bacf07544cb8d30aadc778',
#   'type': 'molecularlyInteractsWith'},
#  {'source_id': 'ENTREZ:ACE2',
#   'target_id': 'UMLS:C0684162',
#   'edge_source': 'semmedgene',
#   'id': '8b3fe6386a542f5ebdb2ebec09392b0e74aa6d11',
#   'type': 'molecularlyInteractsWith'},
#  {'source_id': 'ENTREZ:ACE2',
#   'target_id': 'UMLS:C1257987',
#   'edge_source': 'semmedgene',
#   'id': '717065d336b8d8feba7c1cbbf6ad8677c48bd0c5',
#   'type': 'molecularlyInteractsWith'},
#  {'source_id': 'ENTREZ:ACE2',
#   'target_id': 'NAME:LISINOPRIL',
#   'edge_source': 'dgidb_gene2chemical',
#   'id': '5c205c2308628f99cd159100ba5403bade269c12',
#   'type': 'targetedBy'},
#  {'source_id': 'ENTREZ:ACE2',
#   'target_id': 'NAME:FLUTAMIDE',
#   'edge_source': 'dgidb_gene2chemical',
#   'id': '4d9841ccde52d05c02c30e008a802415261db683',
#   'type': 'targetedBy'},
#  {'source_id': 'ENTREZ:ACE2',
#   'target_id': 'NAME:MOEXIPRIL',
#   'edge_source': 'mychem.info',
#   'id': '0c238a195f643c7411ce77eeb91610bb64b42315',
#   'type': 'targetedBy'}]

# %%
output['results'][:20]
# Out:
# [{'node_bindings': {'n0': ['ENTREZ:ACE2'], 'n1': ['CHEMBL:CHEMBL260273']},
#   'edge_bindings': {'e0': ['2720cfda869ff775b4c06f199d7e345331bd83b0']}},
#  {'node_bindings': {'n0': ['ENTREZ:ACE2'], 'n1': ['CHEMBL:CHEMBL429844']},
#   'edge_bindings': {'e0': ['c766ed7c37f23ead58a4e83777d61b0de4d0b19c']}},
#  {'node_bindings': {'n0': ['ENTREZ:ACE2'], 'n1': ['DRUGBANK:DB05203']},
#   'edge_bindings': {'e0': ['03ce86b5f42fc668191c4a9b494c7e60c5c34f14']}},
#  {'node_bindings': {'n0': ['ENTREZ:ACE2'], 'n1': ['UMLS:C0003015']},
#   'edge_bindings': {'e0': ['a8bd272d050d9c12af163735b9b9edac2b07a719',
#     'a8bd272d050d9c12af163735b9b9edac2b07a719']}},
#  {'node_bindings': {'n0': ['ENTREZ:ACE2'], 'n1': ['UMLS:C0012854']},
#   'edge_bindings': {'e0': ['57091960ded0f1bcf6af15357296ef50629e39aa']}},
#  {'node_bindings': {'n0': ['ENTREZ:ACE2'], 'n1': ['UMLS:C0058206']},
#   'edge_bindings': {'e0': ['c4e994c106dd4dc9404ac1be7973d94f10f71366']}},
#  {'node_bindings': {'n0': ['ENTREZ:ACE2'], 'n1': ['UMLS:C0065556']},
#   'edge_bindings': {'e0': ['b3a259f71b23307a859d8d64687e8a5e1ac179f4']}},
#  {'node_bindings': {'n0': ['ENTREZ:ACE2'], 'n1': ['UMLS:C0682921']},
#   'edge_bindings': {'e0': ['5311d640414bfb77414343da2f539eca0cd04c4f']}},
#  {'node_bindings': {'n0': ['ENTREZ:ACE2'], 'n1': ['UMLS:C0772162']},
#   'edge_bindings': {'e0': ['50c16358e9035afc3c468db1116ea0f0ae9a99d6']}},
#  {'node_bindings': {'n0': ['ENTREZ:ACE2'], 'n1': ['UMLS:C1098320']},
#   'edge_bindings': {'e0': ['e99c3887db5dda334dad4b36fbf81ee8fbbcc4bf']}},
#  {'node_bindings': {'n0': ['ENTREZ:ACE2'], 'n1': ['UMLS:C1314787']},
#   'edge_bindings': {'e0': ['9200a57504f3cc566228c0e869911be38d3e8fb8']}},
#  {'node_bindings': {'n0': ['ENTREZ:ACE2'], 'n1': ['UMLS:C0014939']},
#   'edge_bindings': {'e0': ['74a87309f99a09831b3ca128b68765ebb50cc5f4']}},
#  {'node_bindings': {'n0': ['ENTREZ:ACE2'], 'n1': ['UMLS:C0309049']},
#   'edge_bindings': {'e0': ['0abafcc58fdf8af5b773c72838808fd743cb82ed']}},
#  {'node_bindings': {'n0': ['ENTREZ:ACE2'], 'n1': ['UMLS:C0608663']},
#   'edge_bindings': {'e0': ['7857fc4e384612d831bacf07544cb8d30aadc778']}},
#  {'node_bindings': {'n0': ['ENTREZ:ACE2'], 'n1': ['UMLS:C0684162']},
#   'edge_bindings': {'e0': ['8b3fe6386a542f5ebdb2ebec09392b0e74aa6d11']}},
#  {'node_bindings': {'n0': ['ENTREZ:ACE2'], 'n1': ['UMLS:C1257987']},
#   'edge_bindings': {'e0': ['717065d336b8d8feba7c1cbbf6ad8677c48bd0c5']}},
#  {'node_bindings': {'n0': ['ENTREZ:ACE2'], 'n1': ['NAME:LISINOPRIL']},
#   'edge_bindings': {'e0': ['5c205c2308628f99cd159100ba5403bade269c12']}},
#  {'node_bindings': {'n0': ['ENTREZ:ACE2'], 'n1': ['NAME:FLUTAMIDE']},
#   'edge_bindings': {'e0': ['4d9841ccde52d05c02c30e008a802415261db683']}},
#  {'node_bindings': {'n0': ['ENTREZ:ACE2'], 'n1': ['NAME:MOEXIPRIL']},
#   'edge_bindings': {'e0': ['0c238a195f643c7411ce77eeb91610bb64b42315']}},
#  {'node_bindings': {'n0': ['ENTREZ:ACE2'], 'n1': ['NAME:ENALAPRILAT']},
#   'edge_bindings': {'e0': ['0cfe25c7e88f1171da31971b80f977c3caa50291']}}]
