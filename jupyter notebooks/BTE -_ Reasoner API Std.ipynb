# %%
from biothings_explorer.hint import Hint
from biothings_explorer.user_query_dispatcher import FindConnection

# %%
ht = Hint()

# %%
ace2 = ht.query("ACE2")['Gene'][0]
ace2
# Out:
# {'entrez': '59272',
#  'name': 'angiotensin I converting enzyme 2',
#  'symbol': 'ACE2',
#  'taxonomy': 9606,
#  'umls': 'C1422064',
#  'uniprot': 'Q9BYF1',
#  'hgnc': '13557',
#  'display': 'entrez(59272) name(angiotensin I converting enzyme 2) symbol(ACE2) taxonomy(9606) umls(C1422064) uniprot(Q9BYF1) hgnc(13557) ',
#  'type': 'Gene',
#  'primary': {'identifier': 'entrez', 'cls': 'Gene', 'value': '59272'}}

# %%
fc = FindConnection(input_obj=ace2,
                    output_obj='DiseaseOrPhenotypicFeature',
                    intermediate_nodes='ChemicalSubstance')

# %%
fc.connect(verbose=True)
# Out:
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'ACE2' and 'DiseaseOrPhenotypicFeature'. Paths will have 1 intermediate node.
#
# Intermediate node #1 will have these type constraints: ChemicalSubstance
#
#
#
#
# ========== QUERY #1 -- fetch all ChemicalSubstance entities linked to ACE2 ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because ACE2 is of type 'Gene', BTE will query our meta-KG for APIs that can take 'Gene' as input
#
# BTE found 3 apis:
#
# API 1. semmedgene(1 API call)
# API 2. mychem.info(3 API calls)
# API 3. dgidb_gene2chemical(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 2.1: http://mychem.info/v1/query (POST "q=ACE2&scopes=drugbank.enzymes.gene_name&fields=drugbank.id&species=human&size=100")
# API 2.3: http://mychem.info/v1/query (POST "q=ACE2&scopes=drugcentral.bioactivity.uniprot.gene_symbol&fields=chembl.molecule_chembl_id&species=human&size=100")
# API 2.2: http://mychem.info/v1/query (POST "q=ACE2&scopes=drugbank.targets.gene_name&fields=drugbank.id&species=human&size=100")
# API 3.1: http://www.dgidb.org/api/v2/interactions.json?genes=ACE2
# API 1.1: https://pending.biothings.io/semmedgene/query (POST "q=C1422064&scopes=umls&fields=associated_with.chemical_substance,affects_reverse.chemical_substance,affects.chemical_substance,interacts_with.chemical_substance,interacts_with_reverse.chemical_substance,associated_with_reverse.chemical_substance&species=human&size=100")
#
#
# ==== Step #3: Output normalization ====
#
# API 3.1 dgidb_gene2chemical: 4 hits
# API 2.1 mychem.info: No hits
# API 2.2 mychem.info: 2 hits
# API 2.3 mychem.info: 2 hits
# API 1.1 semmedgene: 19 hits
#
# After id-to-object translation, BTE retrieved 26 unique objects.
#
#
# ========== QUERY #2.1 -- fetch all DiseaseOrPhenotypicFeature entities linked to ChemicalSubstance entites ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because the inputs is of type 'ChemicalSubstance', BTE will query our meta-KG for APIs that can take 'ChemicalSubstance' as input
#
# BTE found 3 apis:
#
# API 1. mychem.info(1 API call)
# API 2. mydisease.info(1 API call)
# API 3. semmeddisease(5 API calls)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 3.1: http://pending.biothings.io/semmed/query (POST "q=C0006674,C0682921,C0017725,C1314787,C0003015,C0065374,C0012854,C0772162,C0248719,C0286651,C0309049,C0608663,C0058206,C1098320,C1257987,C0014939,C0036860,C0001962,C0016384,C0014027,C0684162,C0065556,C0066685&scopes=AFFECTS.chemical_substance.umls&fields=umls&species=human&size=100")
# API 2.1: http://mydisease.info/v1/query (POST "q=D005485,C058302,D005947,D017706,D000069059,D000431,C065179,D012721,D002117,C084178,D015773&scopes=ctd.chemical_related_to_disease.mesh_chemical_id&fields=mondo.xrefs.mesh,disgenet.xrefs.mesh&species=human&size=100")
# API 3.3: http://pending.biothings.io/semmed/query (POST "q=C0006674,C0682921,C0017725,C1314787,C0003015,C0065374,C0012854,C0772162,C0248719,C0286651,C0309049,C0608663,C0058206,C1098320,C1257987,C0014939,C0036860,C0001962,C0016384,C0014027,C0684162,C0065556,C0066685&scopes=ASSOCIATED_WITH.chemical_substance.umls&fields=umls&species=human&size=100")
# API 1.1: http://mychem.info/v1/query (POST "q=CHEMBL260273,CHEMBL1614854,CHEMBL1487,CHEMBL429844,CHEMBL846,CHEMBL1165,CHEMBL545,CHEMBL1017,CHEMBL577,CHEMBL806,CHEMBL46917,CHEMBL1237&scopes=chembl.molecule_chembl_id&fields=drugcentral.drug_use.contraindication,drugcentral.drug_use.indication&species=human&size=100")
# API 3.5: http://pending.biothings.io/semmed/query (POST "q=C0006674,C0682921,C0017725,C1314787,C0003015,C0065374,C0012854,C0772162,C0248719,C0286651,C0309049,C0608663,C0058206,C1098320,C1257987,C0014939,C0036860,C0001962,C0016384,C0014027,C0684162,C0065556,C0066685&scopes=TREATS_reverse.chemical_substance.umls&fields=umls&species=human&size=100")
# API 3.4: http://pending.biothings.io/semmed/query (POST "q=C0006674,C0682921,C0017725,C1314787,C0003015,C0065374,C0012854,C0772162,C0248719,C0286651,C0309049,C0608663,C0058206,C1098320,C1257987,C0014939,C0036860,C0001962,C0016384,C0014027,C0684162,C0065556,C0066685&scopes=ASSOCIATED_WITH_reverse.chemical_substance.umls&fields=umls&species=human&size=100")
# API 3.2: http://pending.biothings.io/semmed/query (POST "q=C0006674,C0682921,C0017725,C1314787,C0003015,C0065374,C0012854,C0772162,C0248719,C0286651,C0309049,C0608663,C0058206,C1098320,C1257987,C0014939,C0036860,C0001962,C0016384,C0014027,C0684162,C0065556,C0066685&scopes=AFFECTS_reverse.chemical_substance.umls&fields=umls&species=human&size=100")
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 mychem.info: 181 hits
# API 2.1 mydisease.info: 7 hits
# API 3.1 semmeddisease: 1 hits
# API 3.2 semmeddisease: 1022 hits
# API 3.3 semmeddisease: 1 hits
# API 3.4 semmeddisease: 540 hits
# API 3.5 semmeddisease: 1215 hits
#
# After id-to-object translation, BTE retrieved 1759 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# In the #1 query, BTE found 26 unique ChemicalSubstance nodes
# In the #2 query, BTE found 1759 unique DiseaseOrPhenotypicFeature nodes

# %%
output = fc.to_reasoner_std()

# %%
output.keys()
# Out:
# dict_keys(['question_graph', 'knowledge_graph'])

# %%
output['question_graph']
# Out:
# {'edges': [{'id': 'e0',
#    'source_id': 'n0',
#    'target_id': 'n1',
#    'directed': True},
#   {'id': 'e1', 'source_id': 'n1', 'target_id': 'n2', 'directed': True}],
#  'nodes': [{'id': 'n0', 'type': 'Gene'},
#   {'id': 'n1', 'type': 'ChemicalSubstance'},
#   {'id': 'n2', 'type': 'DiseaseOrPhenotypicFeature'}]}

# %%
output['knowledge_graph']['nodes'][:20]
# Out:
# [{'id': 'ENTREZ:ACE2',
#   'name': ['ACE-related carboxypeptidase',
#    'peptidyl-dipeptidase A',
#    'angiotensin I converting enzyme (peptidyl-dipeptidase A) 2',
#    'angiotensin-converting enzyme 2',
#    'angiotensin I converting enzyme 2',
#    'metalloprotease MPROT15',
#    'angiotensin-converting enzyme homolog'],
#   'type': 'Gene',
#   'equivalent_identifiers': {'bts:ensembl': ['ENSG00000130234'],
#    'bts:hgnc': ['13557'],
#    'bts:omim': ['300335'],
#    'bts:entrez': ['59272'],
#    'bts:pharos': [],
#    'bts:umls': ['C1422064'],
#    'bts:unigene': ['Hs.178098'],
#    'bts:pharmgkb': ['PA425'],
#    'bts:name': ['ACE-related carboxypeptidase',
#     'peptidyl-dipeptidase A',
#     'angiotensin I converting enzyme (peptidyl-dipeptidase A) 2',
#     'angiotensin-converting enzyme 2',
#     'angiotensin I converting enzyme 2',
#     'metalloprotease MPROT15',
#     'angiotensin-converting enzyme homolog'],
#    'bts:symbol': ['ACE2']}},
#  {'id': 'CHEMBL:CHEMBL260273',
#   'name': [],
#   'type': 'ChemicalSubstance',
#   'equivalent_identifiers': {'bts:inchi': ['InChI=1S/C22H33N2O6P/c1-15(2)12-19(23-16(3)25)21(26)24-11-7-10-20(24)31(29,30)14-18(22(27)28)13-17-8-5-4-6-9-17/h4-6,8-9,15,18-20H,7,10-14H2,1-3H3,(H,23,25)(H,27,28)(H,29,30)/t18-,19+,20+/m1/s1'],
#    'bts:inchikey': ['DGMLSHVZZKUDPN-AABGKKOBSA-N'],
#    'bts:rxcui': [],
#    'bts:smiles': ['CC(C)C[C@H](NC(=O)C)C(=O)N1CCC[C@@H]1P(=O)(O)C[C@@H](Cc2ccccc2)C(=O)O'],
#    'bts:pubchem': [24827312],
#    'bts:chembl': ['CHEMBL260273'],
#    'bts:drugbank': [],
#    'bts:name': [],
#    'bts:unii': [],
#    'bts:umls': [],
#    'bts:mesh': []}},
#  {'id': 'CHEMBL:CHEMBL429844',
#   'name': [],
#   'type': 'ChemicalSubstance',
#   'equivalent_identifiers': {'bts:inchi': ['InChI=1S/C19H23Cl2N3O4/c1-11(2)3-16(18(25)26)23-17(19(27)28)7-15-8-22-10-24(15)9-12-4-13(20)6-14(21)5-12/h4-6,8,10-11,16-17,23H,3,7,9H2,1-2H3,(H,25,26)(H,27,28)/t16-,17-/m0/s1'],
#    'bts:inchikey': ['NTCCRGGIJNDEAB-IRXDYDNUSA-N'],
#    'bts:rxcui': [],
#    'bts:smiles': ['CC(C)C[C@H](N[C@@H](Cc1cncn1Cc2cc(Cl)cc(Cl)c2)C(=O)O)C(=O)O'],
#    'bts:pubchem': [448281],
#    'bts:chembl': ['CHEMBL429844'],
#    'bts:drugbank': ['DB12271'],
#    'bts:name': [],
#    'bts:unii': ['4LD0ZHV25K'],
#    'bts:umls': [],
#    'bts:mesh': []}},
#  {'id': 'DRUGBANK:DB05203',
#   'name': [],
#   'type': 'ChemicalSubstance',
#   'equivalent_identifiers': {'bts:inchi': [],
#    'bts:inchikey': [],
#    'bts:rxcui': [],
#    'bts:smiles': [],
#    'bts:pubchem': [],
#    'bts:chembl': [],
#    'bts:drugbank': ['DB05203'],
#    'bts:name': [],
#    'bts:unii': [],
#    'bts:umls': [],
#    'bts:mesh': []}},
#  {'id': 'UMLS:C0003015',
#   'name': None,
#   'type': 'ChemicalSubstance',
#   'equivalent_identifiers': {'bts:umls': ['C0003015']}},
#  {'id': 'UMLS:C0012854',
#   'name': None,
#   'type': 'ChemicalSubstance',
#   'equivalent_identifiers': {'bts:umls': ['C0012854']}},
#  {'id': 'UMLS:C0058206',
#   'name': None,
#   'type': 'ChemicalSubstance',
#   'equivalent_identifiers': {'bts:umls': ['C0058206']}},
#  {'id': 'UMLS:C0065556',
#   'name': None,
#   'type': 'ChemicalSubstance',
#   'equivalent_identifiers': {'bts:umls': ['C0065556']}},
#  {'id': 'UMLS:C0682921',
#   'name': None,
#   'type': 'ChemicalSubstance',
#   'equivalent_identifiers': {'bts:umls': ['C0682921']}},
#  {'id': 'UMLS:C0772162',
#   'name': None,
#   'type': 'ChemicalSubstance',
#   'equivalent_identifiers': {'bts:umls': ['C0772162']}},
#  {'id': 'UMLS:C1098320',
#   'name': None,
#   'type': 'ChemicalSubstance',
#   'equivalent_identifiers': {'bts:umls': ['C1098320']}},
#  {'id': 'UMLS:C1314787',
#   'name': None,
#   'type': 'ChemicalSubstance',
#   'equivalent_identifiers': {'bts:umls': ['C1314787']}},
#  {'id': 'UMLS:C0014939',
#   'name': None,
#   'type': 'ChemicalSubstance',
#   'equivalent_identifiers': {'bts:umls': ['C0014939']}},
#  {'id': 'UMLS:C0309049',
#   'name': None,
#   'type': 'ChemicalSubstance',
#   'equivalent_identifiers': {'bts:umls': ['C0309049']}},
#  {'id': 'UMLS:C0608663',
#   'name': None,
#   'type': 'ChemicalSubstance',
#   'equivalent_identifiers': {'bts:umls': ['C0608663']}},
#  {'id': 'UMLS:C0684162',
#   'name': None,
#   'type': 'ChemicalSubstance',
#   'equivalent_identifiers': {'bts:umls': ['C0684162']}},
#  {'id': 'UMLS:C1257987',
#   'name': None,
#   'type': 'ChemicalSubstance',
#   'equivalent_identifiers': {'bts:umls': ['C1257987']}},
#  {'id': 'NAME:LISINOPRIL',
#   'name': ['LISINOPRIL'],
#   'type': 'ChemicalSubstance',
#   'equivalent_identifiers': {'bts:inchi': ['InChI=1S/C21H31N3O5/c22-13-5-4-9-16(19(25)24-14-6-10-18(24)21(28)29)23-17(20(26)27)12-11-15-7-2-1-3-8-15/h1-3,7-8,16-18,23H,4-6,9-14,22H2,(H,26,27)(H,28,29)/t16-,17-,18-/m0/s1'],
#    'bts:inchikey': ['RLAWWYSOJDYHDC-BZSNNMDCSA-N'],
#    'bts:rxcui': [],
#    'bts:smiles': ['NCCCC[C@H](N[C@@H](CCc1ccccc1)C(=O)O)C(=O)N2CCC[C@H]2C(=O)O'],
#    'bts:pubchem': [11865407],
#    'bts:chembl': ['CHEMBL1237'],
#    'bts:drugbank': ['DB00722'],
#    'bts:name': ['LISINOPRIL'],
#    'bts:unii': ['7Q3P4BS2FD'],
#    'bts:umls': ['C0065374'],
#    'bts:mesh': ['D017706']}},
#  {'id': 'NAME:FLUTAMIDE',
#   'name': ['FLUTAMIDE'],
#   'type': 'ChemicalSubstance',
#   'equivalent_identifiers': {'bts:inchi': ['InChI=1S/C11H11F3N2O3/c1-6(2)10(17)15-7-3-4-9(16(18)19)8(5-7)11(12,13)14/h3-6H,1-2H3,(H,15,17)'],
#    'bts:inchikey': ['MKXKFYHWDHIYRV-UHFFFAOYSA-N'],
#    'bts:rxcui': ['4508'],
#    'bts:smiles': ['CC(C)C(=O)Nc1ccc(c(c1)C(F)(F)F)[N+](=O)[O-]'],
#    'bts:pubchem': [3397],
#    'bts:chembl': ['CHEMBL806'],
#    'bts:drugbank': ['DB00499'],
#    'bts:name': ['FLUTAMIDE'],
#    'bts:unii': ['76W6J0943E'],
#    'bts:umls': ['C0016384'],
#    'bts:mesh': ['D005485']}},
#  {'id': 'NAME:MOEXIPRIL',
#   'name': ['MOEXIPRIL'],
#   'type': 'ChemicalSubstance',
#   'equivalent_identifiers': {'bts:inchi': ['InChI=1S/C27H34N2O7/c1-5-36-27(33)21(12-11-18-9-7-6-8-10-18)28-17(2)25(30)29-16-20-15-24(35-4)23(34-3)14-19(20)13-22(29)26(31)32/h6-10,14-15,17,21-22,28H,5,11-13,16H2,1-4H3,(H,31,32)/t17-,21-,22-/m0/s1'],
#    'bts:inchikey': ['UWWDHYUMIORJTA-HSQYWUDLSA-N'],
#    'bts:rxcui': ['30131'],
#    'bts:smiles': ['CCOC(=O)[C@H](CCc1ccccc1)N[C@@H](C)C(=O)N2Cc3cc(OC)c(OC)cc3C[C@H]2C(=O)O'],
#    'bts:pubchem': [40466988],
#    'bts:chembl': ['CHEMBL1165'],
#    'bts:drugbank': ['DB00691'],
#    'bts:name': ['MOEXIPRIL'],
#    'bts:unii': ['WT87C52TJZ'],
#    'bts:umls': ['C0066685'],
#    'bts:mesh': ['C058302']}}]

# %%
output['knowledge_graph']['edges'][:20]
# Out:
# [{'source_id': 'ENTREZ:ACE2',
#   'target_id': 'CHEMBL:CHEMBL260273',
#   'edge_source': 'dgidb_gene2chemical',
#   'id': '5aadff64a408f86742b1713d6b72a028f7b55410',
#   'type': 'targetedBy'},
#  {'source_id': 'ENTREZ:ACE2',
#   'target_id': 'CHEMBL:CHEMBL429844',
#   'edge_source': 'dgidb_gene2chemical',
#   'id': '95be923e67d9c4515a26c12ebe2ca60708333c37',
#   'type': 'targetedBy'},
#  {'source_id': 'ENTREZ:ACE2',
#   'target_id': 'DRUGBANK:DB05203',
#   'edge_source': 'mychem.info',
#   'id': '294e26c42490c18a0682d361f0f4f034c990168a',
#   'type': 'targetedBy'},
#  {'source_id': 'ENTREZ:ACE2',
#   'target_id': 'UMLS:C0003015',
#   'edge_source': 'semmedgene',
#   'id': '455dd85c2d852c66f1788973009f958fe637faf0',
#   'type': 'molecularlyInteractsWith'},
#  {'source_id': 'ENTREZ:ACE2',
#   'target_id': 'UMLS:C0003015',
#   'edge_source': 'semmedgene',
#   'id': '455dd85c2d852c66f1788973009f958fe637faf0',
#   'type': 'molecularlyInteractsWith'},
#  {'source_id': 'ENTREZ:ACE2',
#   'target_id': 'UMLS:C0012854',
#   'edge_source': 'semmedgene',
#   'id': 'e76ad7381816a97151eed51ba612ca6b6dd4bd38',
#   'type': 'molecularlyInteractsWith'},
#  {'source_id': 'ENTREZ:ACE2',
#   'target_id': 'UMLS:C0058206',
#   'edge_source': 'semmedgene',
#   'id': 'd2534ce989a118acd43e2093d765da5770a26527',
#   'type': 'molecularlyInteractsWith'},
#  {'source_id': 'ENTREZ:ACE2',
#   'target_id': 'UMLS:C0065556',
#   'edge_source': 'semmedgene',
#   'id': '76e5c3fbddeef1c475b114efcd37a3588301bc2d',
#   'type': 'molecularlyInteractsWith'},
#  {'source_id': 'ENTREZ:ACE2',
#   'target_id': 'UMLS:C0682921',
#   'edge_source': 'semmedgene',
#   'id': '6fd57d0c4b6958c9ae544933db7f83d0e0e4ee85',
#   'type': 'molecularlyInteractsWith'},
#  {'source_id': 'ENTREZ:ACE2',
#   'target_id': 'UMLS:C0772162',
#   'edge_source': 'semmedgene',
#   'id': '0b295e6c10e35f8ae0be81d19fbfcc323cb2181e',
#   'type': 'molecularlyInteractsWith'},
#  {'source_id': 'ENTREZ:ACE2',
#   'target_id': 'UMLS:C1098320',
#   'edge_source': 'semmedgene',
#   'id': 'c0680029f086b554c878376060ee72017b372faa',
#   'type': 'molecularlyInteractsWith'},
#  {'source_id': 'ENTREZ:ACE2',
#   'target_id': 'UMLS:C1314787',
#   'edge_source': 'semmedgene',
#   'id': '8f8ee477200b69d63a6bf5b2edeeaf5db952c526',
#   'type': 'molecularlyInteractsWith'},
#  {'source_id': 'ENTREZ:ACE2',
#   'target_id': 'UMLS:C0014939',
#   'edge_source': 'semmedgene',
#   'id': 'e2ad6af60ef4cfc5a6e773642fc52b920c44120b',
#   'type': 'molecularlyInteractsWith'},
#  {'source_id': 'ENTREZ:ACE2',
#   'target_id': 'UMLS:C0309049',
#   'edge_source': 'semmedgene',
#   'id': '9faf2ae469ab0c2f89ae0dabd5cfa41f1e6b4cf7',
#   'type': 'molecularlyInteractsWith'},
#  {'source_id': 'ENTREZ:ACE2',
#   'target_id': 'UMLS:C0608663',
#   'edge_source': 'semmedgene',
#   'id': '40ebda98b79a83b7a2256b4420c5aa91b1ba417d',
#   'type': 'molecularlyInteractsWith'},
#  {'source_id': 'ENTREZ:ACE2',
#   'target_id': 'UMLS:C0684162',
#   'edge_source': 'semmedgene',
#   'id': 'b7a982c53a0b9d3990ae834fd9ca92086bb1b073',
#   'type': 'molecularlyInteractsWith'},
#  {'source_id': 'ENTREZ:ACE2',
#   'target_id': 'UMLS:C1257987',
#   'edge_source': 'semmedgene',
#   'id': '78d0f5670c60b4f31db119d0a5f8a43b5af487be',
#   'type': 'molecularlyInteractsWith'},
#  {'source_id': 'ENTREZ:ACE2',
#   'target_id': 'NAME:LISINOPRIL',
#   'edge_source': 'dgidb_gene2chemical',
#   'id': 'f795b20f977206aac0828d515ca786880001d382',
#   'type': 'targetedBy'},
#  {'source_id': 'ENTREZ:ACE2',
#   'target_id': 'NAME:FLUTAMIDE',
#   'edge_source': 'dgidb_gene2chemical',
#   'id': '14af488600796a0677268d0d09e302bfd1a9d896',
#   'type': 'targetedBy'},
#  {'source_id': 'ENTREZ:ACE2',
#   'target_id': 'NAME:MOEXIPRIL',
#   'edge_source': 'mychem.info',
#   'id': '1552b984522b6133ef6d717cdb9eac5103d57adb',
#   'type': 'targetedBy'}]
