# %% [markdown]
# # Important prerequisite
# 1. The package doesn't work with the newest version of Jupyter Notebook, run the following commands in your terminal before initiating the Notebook
# 2. pip install notebook==5.7.5
# 3. pip install tornado==4.5.3

# %% [markdown]
# # Install dependencies

# %% [markdown]
# Don't worry about the error messages during installation, you will be fine.

# %%
# uncomment the following line if you haven't installed bte_schema
# !pip install git+https://github.com/kevinxin90/bte_schema#egg=bte_schema

# %%
# uncomment the following line if you haven't installed biothings_schema
#pip install git+https://github.com/biothings/biothings_schema.py#egg=biothings_schema.py

# %% [markdown]
# ## Initiating the package

# %%
# import the query module
from biothings_explorer.user_query_dispatcher import SingleEdgeQueryDispatcher
# import the hint module (suggest hits based on your input)
from biothings_explorer.hint import Hint
# import the registry module
from biothings_explorer.registry import Registry
reg = Registry()
ht = Hint()

# %% [markdown]
# ## Feature 1: Single Hop Query
# Query from a specific biological entity (e.g. entrezgene 1017) to other semantic types (e.g. ChemicalSubstance)

# %% [markdown]
# ### The example below will query all ChemicalSubstances related to Entrezgene 1017

# %% [markdown]
# ### Step1: Get your input

# %%
# use the hint the module to let BioThings Explorer suggest the inputs for you
a = ht.query('1019')
# the output of the hint module is grouped by semantic types
a
# Out:
# {'Gene': [{'entrez': '1019',
#    'name': 'cyclin dependent kinase 4',
#    'symbol': 'CDK4',
#    'taxonomy': 9606,
#    'umls': 'C0694873',
#    'display': 'entrez(1019) name(cyclin dependent kinase 4) symbol(CDK4) taxonomy(9606) umls(C0694873) ',
#    'type': 'Gene',
#    'primary': {'identifier': 'entrez', 'cls': 'Gene', 'value': '1019'}}],
#  'SequenceVariant': [],
#  'ChemicalSubstance': [{'pubchem': 1019,
#    'display': 'pubchem(1019) ',
#    'type': 'ChemicalSubstance',
#    'primary': {'identifier': 'pubchem',
#     'cls': 'ChemicalSubstance',
#     'value': 1019}},
#   {'drugbank': 'DB05832',
#    'pubchem': 9830969,
#    'display': 'drugbank(DB05832) pubchem(9830969) ',
#    'type': 'ChemicalSubstance',
#    'primary': {'identifier': 'drugbank',
#     'cls': 'ChemicalSubstance',
#     'value': 'DB05832'}},
#   {'name': 'RSD 1019',
#    'umls': 'C0971384',
#    'display': 'name(RSD 1019) umls(C0971384) ',
#    'type': 'ChemicalSubstance',
#    'primary': {'identifier': 'umls',
#     'cls': 'ChemicalSubstance',
#     'value': 'C0971384'}}],
#  'DiseaseOrPhenotypicFeature': [{'mondo': 'MONDO:0005246',
#    'doid': 'DOID:1019',
#    'hp': 'HP:0002754',
#    'umls': 'C0158372',
#    'mesh': 'D010019',
#    'name': 'osteomyelitis (disease)',
#    'display': 'mondo(MONDO:0005246) doid(DOID:1019) hp(HP:0002754) umls(C0158372) mesh(D010019) name(osteomyelitis (disease)) ',
#    'type': 'DiseaseOrPhenotypicFeature',
#    'primary': {'identifier': 'mondo',
#     'cls': 'DiseaseOrPhenotypicFeature',
#     'value': 'MONDO:0005246'}}],
#  'Pathway': [],
#  'MolecularFunction': [],
#  'CellularComponent': [],
#  'BiologicalProcess': [],
#  'Anatomy': [],
#  'PhenotypicFeature': []}

# %%
# select your input object
input_obj = a['Gene'][0]
input_obj
# Out:
# {'entrez': '1019',
#  'name': 'cyclin dependent kinase 4',
#  'symbol': 'CDK4',
#  'taxonomy': 9606,
#  'umls': 'C0694873',
#  'display': 'entrez(1019) name(cyclin dependent kinase 4) symbol(CDK4) taxonomy(9606) umls(C0694873) ',
#  'type': 'Gene',
#  'primary': {'identifier': 'entrez', 'cls': 'Gene', 'value': '1019'}}

# %% [markdown]
# ### Step2: Make Single Hop Query

# %% [markdown]
# A couple required parameters in order to perform the query:
# 1. input_obj: This is the object which serves as the start point of your query.
# 2. output_cls: This is the output class which serves as the end point of your query. If you don't specify this parameter, this tool will automatically search all possible output classes for you.
# 3. output_id: This is optional. The identifier type you want the output to be.
# 4. pred: This is also optional. The predicate linking your input and output. If you don't specify, this tool will automatically search all possible linkages.

# %%
seqd = SingleEdgeQueryDispatcher(input_obj=input_obj,
                                 output_cls='ChemicalSubstance',
                                 output_id='bts:chembl',
                                 registry=reg)
seqd.query()

# %% [markdown]
# ### Step3: Understand the results

# %% [markdown]
# The result of the query would be a networkx MultiDiGraph connecting from your input to all possible outputs.

# %% [markdown]
# #### Show results in JSON format

# %% [markdown]
# nodes: All nodes in the graph
#
# links: All edges in the graph

# %%
seqd.to_json()
# Out:
# {'directed': True,
#  'multigraph': True,
#  'graph': {},
#  'nodes': [{'type': 'Gene',
#    'identifier': 'bts:entrez',
#    'level': 1,
#    'equivalent_ids': {'bts:ensembl': ['ENSG00000135446'],
#     'bts:hgnc': ['1773'],
#     'bts:omim': ['123829'],
#     'bts:entrez': ['1019'],
#     'bts:pharos': [],
#     'bts:umls': ['C0694873'],
#     'bts:unigene': ['Hs.95577'],
#     'bts:pharmgkb': ['PA102'],
#     'bts:symbol': ['CDK4']},
#    'id': '1019'},
#   {'identifier': 'bts:chembl',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:inchi': ['InChI=1S/C27H32F2N8/c1-5-35-8-10-36(11-9-35)16-19-6-7-24(30-14-19)33-27-31-15-22(29)25(34-27)20-12-21(28)26-23(13-20)37(17(2)3)18(4)32-26/h6-7,12-15,17H,5,8-11,16H2,1-4H3,(H,30,31,33,34)'],
#     'bts:inchikey': ['UZWDCWONPYILKI-UHFFFAOYSA-N'],
#     'bts:rxcui': [],
#     'bts:smiles': ['CCN1CCN(Cc2ccc(Nc3ncc(F)c(n3)c4cc(F)c5nc(C)n(C(C)C)c5c4)nc2)CC1'],
#     'bts:pubchem': [46220502],
#     'bts:chembl': ['CHEMBL3301610'],
#     'bts:drugbank': ['DB12001'],
#     'bts:unii': ['60UAB198HK'],
#     'bts:mesh': []},
#    'id': 'CHEMBL3301610'},
#   {'identifier': 'bts:chembl',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:inchi': ['InChI=1S/C24H29N7O2/c1-15-19-14-27-24(28-20-8-7-18(13-26-20)30-11-9-25-10-12-30)29-22(19)31(17-5-3-4-6-17)23(33)21(15)16(2)32/h7-8,13-14,17,25H,3-6,9-12H2,1-2H3,(H,26,27,28,29)'],
#     'bts:inchikey': ['AHJRHEGDXFFMBM-UHFFFAOYSA-N'],
#     'bts:rxcui': ['1601374'],
#     'bts:smiles': ['CC(=O)C1=C(C)c2cnc(Nc3ccc(cn3)N4CCNCC4)nc2N(C5CCCC5)C1=O'],
#     'bts:pubchem': [5330286],
#     'bts:chembl': ['CHEMBL189963'],
#     'bts:drugbank': ['DB09073'],
#     'bts:unii': ['G9ZF61LE7G'],
#     'bts:mesh': []},
#    'id': 'CHEMBL189963'},
#   {'identifier': 'bts:chembl',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:inchi': ['InChI=1S/C25H32N8O/c1-25(2)14-16-15-27-24(29-20(16)22-19(25)21(23(34)26-3)30-32(22)5)28-17-6-8-18(9-7-17)33-12-10-31(4)11-13-33/h6-9,15H,10-14H2,1-5H3,(H,26,34)(H,27,28,29)'],
#     'bts:inchikey': ['RXZMYLDMFYNEIM-UHFFFAOYSA-N'],
#     'bts:rxcui': [],
#     'bts:smiles': ['CNC(=O)c1nn(C)c2c3nc(Nc4ccc(cc4)N5CCN(C)CC5)ncc3CC(C)(C)c12'],
#     'bts:pubchem': [16718576],
#     'bts:chembl': ['CHEMBL564829'],
#     'bts:drugbank': [],
#     'bts:unii': ['688000M8S8'],
#     'bts:mesh': []},
#    'id': 'CHEMBL564829'},
#   {'identifier': 'bts:chembl',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:inchi': [],
#     'bts:inchikey': [],
#     'bts:rxcui': [],
#     'bts:smiles': [],
#     'bts:pubchem': [],
#     'bts:chembl': ['CHEMBL3544942'],
#     'bts:drugbank': [],
#     'bts:unii': [],
#     'bts:mesh': []},
#    'id': 'CHEMBL3544942'},
#   {'identifier': 'bts:chembl',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:inchi': ['InChI=1S/C28H26N4O4/c1-28-25(35-3)15(29-2)12-18(36-28)31-16-10-6-4-8-13(16)19-21-22(27(34)30-26(21)33)20-14-9-5-7-11-17(14)32(28)24(20)23(19)31/h4-11,15,18,25,27,29,34H,12H2,1-3H3,(H,30,33)/t15-,18-,25-,27+,28+/m1/s1'],
#     'bts:inchikey': ['PBCZSGKMGDDXIJ-KRUBCLEUSA-N'],
#     'bts:rxcui': [],
#     'bts:smiles': ['CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n3c4ccccc4c5c6[C@H](O)NC(=O)c6c7c8ccccc8n2c7c35'],
#     'bts:pubchem': [3078519],
#     'bts:chembl': ['CHEMBL574737'],
#     'bts:drugbank': [],
#     'bts:unii': [],
#     'bts:mesh': []},
#    'id': 'CHEMBL574737'},
#   {'identifier': 'bts:chembl',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:inchi': ['InChI=1S/C21H20ClNO5/c1-23-7-6-12(17(27)10-23)19-14(24)8-15(25)20-16(26)9-18(28-21(19)20)11-4-2-3-5-13(11)22/h2-5,8-9,12,17,24-25,27H,6-7,10H2,1H3/t12-,17+/m0/s1'],
#     'bts:inchikey': ['BIIVYFLTOXDAOV-YVEFUNNKSA-N'],
#     'bts:rxcui': [],
#     'bts:smiles': ['CN1CC[C@@H]([C@H](O)C1)c2c(O)cc(O)c3C(=O)C=C(Oc23)c4ccccc4Cl'],
#     'bts:pubchem': [5287969],
#     'bts:chembl': ['CHEMBL428690'],
#     'bts:drugbank': ['DB03496'],
#     'bts:unii': ['45AD6X575G'],
#     'bts:mesh': ['C077990']},
#    'id': 'CHEMBL428690'},
#   {'identifier': 'bts:chembl',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:inchi': ['InChI=1S/C16H17Cl2N5O2/c17-10-2-1-3-11(18)13(10)15(24)22-12-8-20-23-14(12)16(25)21-9-4-6-19-7-5-9/h1-3,8-9,19H,4-7H2,(H,20,23)(H,21,25)(H,22,24)'],
#     'bts:inchikey': ['OVPNQJVDAFNBDN-UHFFFAOYSA-N'],
#     'bts:rxcui': [],
#     'bts:smiles': ['Clc1cccc(Cl)c1C(=O)Nc2c[nH]nc2C(=O)NC3CCNCC3'],
#     'bts:pubchem': [11338033],
#     'bts:chembl': ['CHEMBL445813'],
#     'bts:drugbank': ['DB08142'],
#     'bts:unii': ['X1BF92PW9T'],
#     'bts:mesh': []},
#    'id': 'CHEMBL445813'},
#   {'identifier': 'bts:chembl',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:inchi': ['InChI=1S/C23H30N6O2/c1-3-29(4-2)22(30)17-10-12-18(13-11-17)26-23-27-20-19(24-15-25-20)21(28-23)31-14-16-8-6-5-7-9-16/h10-13,15-16H,3-9,14H2,1-2H3,(H2,24,25,26,27,28)'],
#     'bts:inchikey': ['XHEQSRJCJTWWAH-UHFFFAOYSA-N'],
#     'bts:rxcui': [],
#     'bts:smiles': ['CCN(CC)C(=O)c1ccc(Nc2nc(OCC3CCCCC3)c4nc[nH]c4n2)cc1'],
#     'bts:pubchem': [10202471],
#     'bts:chembl': ['CHEMBL1802728'],
#     'bts:drugbank': [],
#     'bts:unii': [],
#     'bts:mesh': []},
#    'id': 'CHEMBL1802728'},
#   {'identifier': 'bts:chembl',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:inchi': ['InChI=1S/C18H10N2O/c21-18-13-6-2-4-8-15(13)20-10-9-12-11-5-1-3-7-14(11)19-16(12)17(18)20/h1-10H/p+1'],
#     'bts:inchikey': ['WYQIPCUPNMRAKP-UHFFFAOYSA-O'],
#     'bts:rxcui': [],
#     'bts:smiles': ['O=C1c2ccccc2[n+]3ccc4c5ccccc5[nH]c4c13'],
#     'bts:pubchem': [73293],
#     'bts:chembl': ['CHEMBL602937'],
#     'bts:drugbank': [],
#     'bts:unii': [],
#     'bts:mesh': []},
#    'id': 'CHEMBL602937'},
#   {'identifier': 'bts:chembl',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:inchi': ['InChI=1S/C11H18N2O3/c1-4-6-7(3)11(5-2)8(14)12-10(16)13-9(11)15/h7H,4-6H2,1-3H3,(H2,12,13,14,15,16)'],
#     'bts:inchikey': ['WEXRUCMBJFQVBZ-UHFFFAOYSA-N'],
#     'bts:rxcui': [],
#     'bts:smiles': ['CCCC(C)C1(CC)C(=O)NC(=O)NC1=O'],
#     'bts:pubchem': [4737],
#     'bts:chembl': ['CHEMBL448'],
#     'bts:drugbank': ['DB00312'],
#     'bts:unii': [],
#     'bts:mesh': ['D010424']},
#    'id': 'CHEMBL448'},
#   {'identifier': 'bts:chembl',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:inchi': ['InChI=1S/C19H25ClN6O/c1-11(2)15(9-27)23-19-24-17(22-14-7-5-6-13(20)8-14)16-18(25-19)26(10-21-16)12(3)4/h5-8,10-12,15,27H,9H2,1-4H3,(H2,22,23,24,25)/t15-/m0/s1'],
#     'bts:inchikey': ['PMXCMJLOPOFPBT-HNNXBMFYSA-N'],
#     'bts:rxcui': [],
#     'bts:smiles': ['CC(C)[C@H](CO)Nc1nc(Nc2cccc(Cl)c2)c3ncn(C(C)C)c3n1'],
#     'bts:pubchem': [456214],
#     'bts:chembl': ['CHEMBL23327'],
#     'bts:drugbank': ['DB04751'],
#     'bts:unii': [],
#     'bts:mesh': []},
#    'id': 'CHEMBL23327'},
#   {'identifier': 'bts:chembl',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:inchi': ['InChI=1S/C20H25ClN6O3/c1-10(2)15(8-28)24-20-25-17(16-18(26-20)27(9-22-16)11(3)4)23-12-5-6-13(19(29)30)14(21)7-12/h5-7,9-11,15,28H,8H2,1-4H3,(H,29,30)(H2,23,24,25,26)/t15-/m0/s1'],
#     'bts:inchikey': ['ZKDXRFMOHZVXSG-HNNXBMFYSA-N'],
#     'bts:rxcui': [],
#     'bts:smiles': ['CC(C)[C@H](CO)Nc1nc(Nc2ccc(C(=O)O)c(Cl)c2)c3ncn(C(C)C)c3n1'],
#     'bts:pubchem': [448991],
#     'bts:chembl': ['CHEMBL23254'],
#     'bts:drugbank': ['DB02733'],
#     'bts:unii': [],
#     'bts:mesh': []},
#    'id': 'CHEMBL23254'},
#   {'identifier': 'bts:chembl',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:inchi': ['InChI=1S/C29H35N7O4/c1-39-16-13-34-9-11-35(12-10-34)19-20-5-7-21(8-6-20)26-25-27(32-31-26)22-3-2-4-23(24(22)28(25)37)30-29(38)33-36-14-17-40-18-15-36/h2-8H,9-19H2,1H3,(H,31,32)(H2,30,33,38)'],
#     'bts:inchikey': ['XLSYZSRXVVCHLS-UHFFFAOYSA-N'],
#     'bts:rxcui': [],
#     'bts:smiles': ['COCCN1CCN(Cc2ccc(cc2)c3n[nH]c4c5cccc(NC(=O)NN6CCOCC6)c5C(=O)c34)CC1'],
#     'bts:pubchem': [11285002],
#     'bts:chembl': ['CHEMBL3545083'],
#     'bts:drugbank': [],
#     'bts:unii': ['1GAJ98SC2X'],
#     'bts:mesh': []},
#    'id': 'CHEMBL3545083'},
#   {'identifier': 'bts:chembl',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:inchi': ['InChI=1S/C23H30N8O/c1-29(2)22(32)19-13-16-14-26-23(28-21(16)31(19)17-5-3-4-6-17)27-20-8-7-18(15-25-20)30-11-9-24-10-12-30/h7-8,13-15,17,24H,3-6,9-12H2,1-2H3,(H,25,26,27,28)'],
#     'bts:inchikey': ['RHXHGRAEPCAFML-UHFFFAOYSA-N'],
#     'bts:rxcui': [],
#     'bts:smiles': ['CN(C)C(=O)c1cc2cnc(Nc3ccc(cn3)N4CCNCC4)nc2n1C5CCCC5'],
#     'bts:pubchem': [44631912],
#     'bts:chembl': ['CHEMBL3545110'],
#     'bts:drugbank': ['DB11730'],
#     'bts:unii': ['TK8ERE8P56'],
#     'bts:mesh': []},
#    'id': 'CHEMBL3545110'},
#   {'identifier': 'bts:chembl',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:inchi': ['InChI=1S/C21H20ClNO5/c1-23-7-6-12(14(23)10-24)19-15(25)8-16(26)20-17(27)9-18(28-21(19)20)11-4-2-3-5-13(11)22/h2-5,8-9,12,14,24-26H,6-7,10H2,1H3'],
#     'bts:inchikey': ['QLUYMIVVAYRECT-UHFFFAOYSA-N'],
#     'bts:rxcui': [],
#     'bts:smiles': ['CN1CCC(C1CO)c2c(O)cc(O)c3C(=O)C=C(Oc23)c4ccccc4Cl'],
#     'bts:pubchem': [9952923],
#     'bts:chembl': ['CHEMBL3545283'],
#     'bts:drugbank': [],
#     'bts:unii': [],
#     'bts:mesh': []},
#    'id': 'CHEMBL3545283'},
#   {'identifier': 'bts:chembl',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:inchi': ['InChI=1S/C23H25N5O3S/c1-27-8-10-28(11-9-27)17-5-3-16(4-6-17)25-23-26-22(24)21(32-23)20(29)15-2-7-18-19(14-15)31-13-12-30-18/h2-7,14H,8-13,24H2,1H3,(H,25,26)'],
#     'bts:inchikey': ['YGEYFDLYGXSZCP-UHFFFAOYSA-N'],
#     'bts:rxcui': [],
#     'bts:smiles': ['CN1CCN(CC1)c2ccc(Nc3nc(N)c(s3)C(=O)c4ccc5OCCOc5c4)cc2'],
#     'bts:pubchem': [9911652],
#     'bts:chembl': ['CHEMBL1956070'],
#     'bts:drugbank': [],
#     'bts:unii': [],
#     'bts:mesh': []},
#    'id': 'CHEMBL1956070'},
#   {'identifier': 'bts:chembl',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:inchi': ['InChI=1S/C13H11N3O2/c1-18-9-2-3-12-10(5-9)11(13(17)16-12)4-8-6-14-7-15-8/h2-7H,1H3,(H,14,15)(H,16,17)/b11-4-'],
#     'bts:inchikey': ['QNUKRWAIZMBVCU-WCIBSUBMSA-N'],
#     'bts:rxcui': [],
#     'bts:smiles': ['COc1ccc2NC(=O)\\C(=C/c3cnc[nH]3)\\c2c1'],
#     'bts:pubchem': [5289419],
#     'bts:chembl': ['CHEMBL258805'],
#     'bts:drugbank': ['DB03428'],
#     'bts:unii': [],
#     'bts:mesh': []},
#    'id': 'CHEMBL258805'},
#   {'identifier': 'bts:chembl',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:inchi': ['InChI=1S/C31H43N3O8/c1-8-12-33-26-21-13-17(2)14-25(41-7)27(36)19(4)15-20(5)29(42-31(32)39)24(40-6)11-9-10-18(3)30(38)34-22(28(21)37)16-23(26)35/h8-11,15-17,19,24-25,27,29,33,36H,1,12-14H2,2-7H3,(H2,32,39)(H,34,38)/b11-9+,18-10+,20-15+/t17-,19+,24+,25+,27-,29+/m1/s1'],
#     'bts:inchikey': ['AYUNIORJHRXIBJ-HTLBVUBBSA-N'],
#     'bts:rxcui': [],
#     'bts:smiles': ['CO[C@H]1C[C@H](C)CC2=C(NCC=C)C(=O)C=C(NC(=O)\\C(=C\\C=C\\[C@H](OC)[C@@H](OC(=O)N)\\C(=C\\[C@H](C)[C@H]1O)\\C)\\C)C2=O'],
#     'bts:pubchem': [6440175],
#     'bts:chembl': ['CHEMBL126955'],
#     'bts:drugbank': [],
#     'bts:unii': [],
#     'bts:mesh': []},
#    'id': 'CHEMBL126955'},
#   {'identifier': 'bts:chembl',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:inchi': ['InChI=1S/C20H16N2O4/c1-2-20(25)14-8-16-17-12(7-11-5-3-4-6-15(11)21-17)9-22(16)18(23)13(14)10-26-19(20)24/h3-8,25H,2,9-10H2,1H3/t20-/m0/s1'],
#     'bts:inchikey': ['VSJKWCGYPAHWDS-FQEVSTJZSA-N'],
#     'bts:rxcui': [],
#     'bts:smiles': ['CC[C@@]1(O)C(=O)OCC2=C1C=C3N(Cc4cc5ccccc5nc34)C2=O'],
#     'bts:pubchem': [24360],
#     'bts:chembl': ['CHEMBL65'],
#     'bts:drugbank': ['DB04690'],
#     'bts:unii': ['XT3Z54Z28A'],
#     'bts:mesh': ['D002166']},
#    'id': 'CHEMBL65'},
#   {'identifier': 'bts:chembl',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:inchi': ['InChI=1S/C22H29FO5/c1-12-8-16-15-5-4-13-9-14(25)6-7-19(13,2)21(15,23)17(26)10-20(16,3)22(12,28)18(27)11-24/h6-7,9,12,15-17,24,26,28H,4-5,8,10-11H2,1-3H3/t12-,15+,16+,17+,19+,20+,21+,22+/m1/s1'],
#     'bts:inchikey': ['UREBDLICKHMUKA-CXSFZGCWSA-N'],
#     'bts:rxcui': ['3264'],
#     'bts:smiles': ['C[C@@H]1C[C@H]2[C@@H]3CCC4=CC(=O)C=C[C@]4(C)[C@@]3(F)[C@@H](O)C[C@]2(C)[C@@]1(O)C(=O)CO'],
#     'bts:pubchem': [5743],
#     'bts:chembl': ['CHEMBL384467'],
#     'bts:drugbank': ['DB01234'],
#     'bts:unii': ['7S5I7G3JQL'],
#     'bts:mesh': ['D003907']},
#    'id': 'CHEMBL384467'},
#   {'identifier': 'bts:chembl',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:inchi': ['InChI=1S/C18H21N5O2S/c1-12(2)23-13(3)20-11-17(23)16-9-10-19-18(22-16)21-14-5-7-15(8-6-14)26(4,24)25/h5-12H,1-4H3,(H,19,21,22)'],
#     'bts:inchikey': ['WJRRGYBTGDJBFX-UHFFFAOYSA-N'],
#     'bts:rxcui': [],
#     'bts:smiles': ['CC(C)n1c(C)ncc1c2ccnc(Nc3ccc(cc3)S(=O)(=O)C)n2'],
#     'bts:pubchem': [16747683],
#     'bts:chembl': ['CHEMBL488436'],
#     'bts:drugbank': [],
#     'bts:unii': ['276Z913G29'],
#     'bts:mesh': []},
#    'id': 'CHEMBL488436'},
#   {'identifier': 'bts:chembl',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:inchi': ['InChI=1S/C19H31N5O2/c1-12(2)10-15(25)20-17-14-11-24(19(3,4)16(14)21-22-17)18(26)13-6-8-23(5)9-7-13/h12-13H,6-11H2,1-5H3,(H2,20,21,22,25)'],
#     'bts:inchikey': ['HUXYBQXJVXOMKX-UHFFFAOYSA-N'],
#     'bts:rxcui': [],
#     'bts:smiles': ['CC(C)CC(=O)Nc1n[nH]c2c1CN(C(=O)C3CCN(C)CC3)C2(C)C'],
#     'bts:pubchem': [46191454],
#     'bts:chembl': ['CHEMBL1230607'],
#     'bts:drugbank': ['DB12686'],
#     'bts:unii': ['MKS45S912B'],
#     'bts:mesh': []},
#    'id': 'CHEMBL1230607'},
#   {'identifier': 'bts:chembl',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:inchi': ['InChI=1S/C18H21F2N5O4S/c1-29-13-4-3-12(19)15(20)14(13)16(26)11-9-22-18(24-17(11)21)23-10-5-7-25(8-6-10)30(2,27)28/h3-4,9-10H,5-8H2,1-2H3,(H3,21,22,23,24)'],
#     'bts:inchikey': ['JRNJNYBQQYBCLE-UHFFFAOYSA-N'],
#     'bts:rxcui': [],
#     'bts:smiles': ['COc1ccc(F)c(F)c1C(=O)c2cnc(NC3CCN(CC3)S(=O)(=O)C)nc2N'],
#     'bts:pubchem': [6918852],
#     'bts:chembl': ['CHEMBL384304'],
#     'bts:drugbank': ['DB08094'],
#     'bts:unii': ['T61871RKRI'],
#     'bts:mesh': []},
#    'id': 'CHEMBL384304'},
#   {'identifier': 'bts:chembl',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:inchi': [],
#     'bts:inchikey': [],
#     'bts:rxcui': [],
#     'bts:smiles': [],
#     'bts:pubchem': [],
#     'bts:chembl': ['CHEMBL3544940'],
#     'bts:drugbank': [],
#     'bts:unii': [],
#     'bts:mesh': []},
#    'id': 'CHEMBL3544940'},
#   {'identifier': 'bts:chembl',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:inchi': [],
#     'bts:inchikey': [],
#     'bts:rxcui': [],
#     'bts:smiles': [],
#     'bts:pubchem': [],
#     'bts:chembl': ['CHEMBL3545218'],
#     'bts:drugbank': [],
#     'bts:unii': [],
#     'bts:mesh': []},
#    'id': 'CHEMBL3545218'},
#   {'identifier': 'bts:chembl',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:inchi': ['InChI=1S/C22H24N2O7S/c1-5-31-19-11-14(9-10-18(19)30-3)17(12-32(4,28)29)24-21(26)15-7-6-8-16(23-13(2)25)20(15)22(24)27/h6-11,17H,5,12H2,1-4H3,(H,23,25)/t17-/m1/s1'],
#     'bts:inchikey': ['IMOZEMNVLZVGJZ-QGZVFWFLSA-N'],
#     'bts:rxcui': ['1492727'],
#     'bts:smiles': ['CCOc1cc(ccc1OC)[C@@H](CS(=O)(=O)C)N2C(=O)c3cccc(NC(=O)C)c3C2=O'],
#     'bts:pubchem': [11561674],
#     'bts:chembl': ['CHEMBL514800'],
#     'bts:drugbank': ['DB05676'],
#     'bts:unii': ['UP7QBP99PN'],
#     'bts:mesh': ['C505730']},
#    'id': 'CHEMBL514800'},
#   {'identifier': 'bts:chembl',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:inchi': ['InChI=1S/C22H16N4O4/c1-24-10-15(13-5-3-4-6-17(13)24)19-20(22(28)23-21(19)27)16-11-25(2)18-9-12(26(29)30)7-8-14(16)18/h3-11H,1-2H3,(H,23,27,28)'],
#     'bts:inchikey': ['OVSKGTONMLKNPZ-UHFFFAOYSA-N'],
#     'bts:rxcui': [],
#     'bts:smiles': ['Cn1cc(C2=C(C(=O)NC2=O)c3cn(C)c4cc(ccc34)[N+](=O)[O-])c5ccccc15'],
#     'bts:pubchem': [5327686],
#     'bts:chembl': ['CHEMBL52885'],
#     'bts:drugbank': ['DB05608'],
#     'bts:unii': ['DNZ11VPY7Q'],
#     'bts:mesh': []},
#    'id': 'CHEMBL52885'},
#   {'identifier': 'bts:chembl',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:inchi': ['InChI=1S/C23H20F2N6/c1-3-26-9-14-10-27-11-17(12(14)2)13-4-5-19-16(6-13)21(31-30-19)23-28-20-8-15(24)7-18(25)22(20)29-23/h4-8,10-11,26,30-31H,3,9H2,1-2H3/b23-21+'],
#     'bts:inchikey': ['RBOKLZGCVRXGEP-XTQSDGFTSA-N'],
#     'bts:rxcui': [],
#     'bts:smiles': ['CCNCc1cncc(c1C)c2ccc3NN\\C(=C\\4/N=C5C=C(F)C=C(F)C5=N4)\\c3c2'],
#     'bts:pubchem': [],
#     'bts:chembl': ['CHEMBL3545420'],
#     'bts:drugbank': [],
#     'bts:unii': [],
#     'bts:mesh': []},
#    'id': 'CHEMBL3545420'},
#   {'identifier': 'bts:chembl',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:inchi': ['InChI=1S/C23H30N8O.C4H6O4/c1-29(2)22(32)19-13-16-14-26-23(28-21(16)31(19)17-5-3-4-6-17)27-20-8-7-18(15-25-20)30-11-9-24-10-12-30;5-3(6)1-2-4(7)8/h7-8,13-15,17,24H,3-6,9-12H2,1-2H3,(H,25,26,27,28);1-2H2,(H,5,6)(H,7,8)'],
#     'bts:inchikey': ['NHANOMFABJQAAH-UHFFFAOYSA-N'],
#     'bts:rxcui': [],
#     'bts:smiles': ['CN(C)C(=O)c1cc2cnc(Nc3ccc(cn3)N4CCNCC4)nc2n1C5CCCC5.OC(=O)CCC(=O)O'],
#     'bts:pubchem': [57334219],
#     'bts:chembl': ['CHEMBL3707266'],
#     'bts:drugbank': [],
#     'bts:unii': ['BG7HLX2919'],
#     'bts:mesh': []},
#    'id': 'CHEMBL3707266'},
#   {'identifier': 'bts:chembl',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:inchi': ['InChI=1S/C10H14N2/c1-12-7-3-5-10(12)9-4-2-6-11-8-9/h2,4,6,8,10H,3,5,7H2,1H3/t10-/m0/s1'],
#     'bts:inchikey': ['SNICXCGAKADSCV-JTQLQIEISA-N'],
#     'bts:rxcui': ['7407'],
#     'bts:smiles': ['CN1CCC[C@H]1c2cccnc2'],
#     'bts:pubchem': [89594],
#     'bts:chembl': ['CHEMBL3'],
#     'bts:drugbank': ['DB00184'],
#     'bts:unii': ['6M3C89ZY6R'],
#     'bts:mesh': ['D061485', 'D009538']},
#    'id': 'CHEMBL3'},
#   {'identifier': 'bts:chembl',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:inchi': ['InChI=1S/C21H30O2/c1-13(22)17-6-7-18-16-5-4-14-12-15(23)8-10-20(14,2)19(16)9-11-21(17,18)3/h12,16-19H,4-11H2,1-3H3/t16-,17+,18-,19-,20-,21+/m0/s1'],
#     'bts:inchikey': ['RJKFOVLPORLFTN-LEKSSAKUSA-N'],
#     'bts:rxcui': ['8727'],
#     'bts:smiles': ['CC(=O)[C@H]1CC[C@H]2[C@@H]3CCC4=CC(=O)CC[C@]4(C)[C@H]3CC[C@]12C'],
#     'bts:pubchem': [5994],
#     'bts:chembl': ['CHEMBL103'],
#     'bts:drugbank': ['DB00396'],
#     'bts:unii': ['4G7DS2Q64Y'],
#     'bts:mesh': ['C400424', 'D011374']},
#    'id': 'CHEMBL103'},
#   {'identifier': 'bts:chembl',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:inchi': ['InChI=1S/C6H8O6/c7-1-2(8)5-3(9)4(10)6(11)12-5/h2,5,7-10H,1H2/t2-,5+/m0/s1'],
#     'bts:inchikey': ['CIWBSHSKHKDKBQ-JLAZNSOCSA-N'],
#     'bts:rxcui': ['1151'],
#     'bts:smiles': ['OC[C@H](O)[C@H]1OC(=O)C(=C1O)O'],
#     'bts:pubchem': [54670067],
#     'bts:chembl': ['CHEMBL196'],
#     'bts:drugbank': ['DB00126'],
#     'bts:unii': ['PQ6CK8PD0R'],
#     'bts:mesh': ['D001205']},
#    'id': 'CHEMBL196'},
#   {'identifier': 'bts:chembl',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:inchi': ['InChI=1S/C28H36ClN5O3S/c1-17(2)37-25-15-21(20-10-12-30-13-11-20)19(5)14-24(25)33-28-31-16-22(29)27(34-28)32-23-8-6-7-9-26(23)38(35,36)18(3)4/h6-9,14-18,20,30H,10-13H2,1-5H3,(H2,31,32,33,34)'],
#     'bts:inchikey': ['VERWOWGGCGHDQE-UHFFFAOYSA-N'],
#     'bts:rxcui': ['1535457'],
#     'bts:smiles': ['CC(C)Oc1cc(C2CCNCC2)c(C)cc1Nc3ncc(Cl)c(Nc4ccccc4S(=O)(=O)C(C)C)n3'],
#     'bts:pubchem': [57379345],
#     'bts:chembl': ['CHEMBL2403108'],
#     'bts:drugbank': ['DB09063'],
#     'bts:unii': ['K418KG2GET'],
#     'bts:mesh': []},
#    'id': 'CHEMBL2403108'},
#   {'identifier': 'bts:chembl',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:inchi': ['InChI=1S/C28H28N4O3/c1-30(2)15-18-11-12-31-16-21(19-7-3-5-9-23(19)31)25-26(28(34)29-27(25)33)22-17-32(13-14-35-18)24-10-6-4-8-20(22)24/h3-10,16-18H,11-15H2,1-2H3,(H,29,33,34)/t18-/m0/s1'],
#     'bts:inchikey': ['ZCBUQCWBWNUWSU-SFHVURJKSA-N'],
#     'bts:rxcui': [],
#     'bts:smiles': ['CN(C)C[C@@H]1CCn2cc(C3=C(C(=O)NC3=O)c4cn(CCO1)c5ccccc45)c6ccccc26'],
#     'bts:pubchem': [153999],
#     'bts:chembl': ['CHEMBL91829'],
#     'bts:drugbank': ['DB11829'],
#     'bts:unii': ['721809WQCP'],
#     'bts:mesh': ['C099154']},
#    'id': 'CHEMBL91829'},
#   {'identifier': 'bts:chembl',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:inchi': ['InChI=1S/C15H10O7/c16-7-4-10(19)12-11(5-7)22-15(14(21)13(12)20)6-1-2-8(17)9(18)3-6/h1-5,16-19,21H'],
#     'bts:inchikey': ['REFJWTPEDVJJIY-UHFFFAOYSA-N'],
#     'bts:rxcui': ['9060'],
#     'bts:smiles': ['OC1=C(Oc2cc(O)cc(O)c2C1=O)c3ccc(O)c(O)c3'],
#     'bts:pubchem': [5280343],
#     'bts:chembl': ['CHEMBL50'],
#     'bts:drugbank': ['DB04216'],
#     'bts:unii': ['9IKM0I5T1E'],
#     'bts:mesh': ['D011794', 'C401828']},
#    'id': 'CHEMBL50'},
#   {'identifier': 'bts:chembl',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:inchi': ['InChI=1S/C31H33N5O4/c1-34-15-17-36(18-16-34)20-27(37)35(2)24-12-10-23(11-13-24)32-29(21-7-5-4-6-8-21)28-25-14-9-22(31(39)40-3)19-26(25)33-30(28)38/h4-14,19,32H,15-18,20H2,1-3H3,(H,33,38)/b29-28-'],
#     'bts:inchikey': ['XZXHXSATPCNXJR-ZIADKAODSA-N'],
#     'bts:rxcui': ['1592737'],
#     'bts:smiles': ['COC(=O)c1ccc2\\C(=C(\\Nc3ccc(cc3)N(C)C(=O)CN4CCN(C)CC4)/c5ccccc5)\\C(=O)Nc2c1'],
#     'bts:pubchem': [],
#     'bts:chembl': ['CHEMBL502835'],
#     'bts:drugbank': ['DB09079'],
#     'bts:unii': ['G6HRD2P839'],
#     'bts:mesh': ['C530716']},
#    'id': 'CHEMBL502835'},
#   {'identifier': 'bts:chembl',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:inchi': ['InChI=1S/C22H27FN4O2/c1-5-27(6-2)10-9-24-22(29)20-13(3)19(25-14(20)4)12-17-16-11-15(23)7-8-18(16)26-21(17)28/h7-8,11-12,25H,5-6,9-10H2,1-4H3,(H,24,29)(H,26,28)/b17-12-'],
#     'bts:inchikey': ['WINHZLLDWRZWRT-ATVHPVEESA-N'],
#     'bts:rxcui': ['357977'],
#     'bts:smiles': ['CCN(CC)CCNC(=O)c1c(C)[nH]c(\\C=C\\2/C(=O)Nc3ccc(F)cc23)c1C'],
#     'bts:pubchem': [5329102],
#     'bts:chembl': ['CHEMBL535'],
#     'bts:drugbank': ['DB01268'],
#     'bts:unii': ['V99T50803M'],
#     'bts:mesh': ['C473478']},
#    'id': 'CHEMBL535'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C0005456']},
#    'id': 'C0005456'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C0007090']},
#    'id': 'C0007090'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C0013227']},
#    'id': 'C0013227'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C0016360']},
#    'id': 'C0016360'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C0017725']},
#    'id': 'C0017725'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C0018282']},
#    'id': 'C0018282'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C0034243']},
#    'id': 'C0034243'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C0036681']},
#    'id': 'C0036681'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C0038317']},
#    'id': 'C0038317'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C0040845']},
#    'id': 'C0040845'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C0073096']},
#    'id': 'C0073096'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C0144576']},
#    'id': 'C0144576'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C0243077']},
#    'id': 'C0243077'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C0608663']},
#    'id': 'C0608663'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C0661318']},
#    'id': 'C0661318'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C0662253']},
#    'id': 'C0662253'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C0675974']},
#    'id': 'C0675974'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C0729218']},
#    'id': 'C0729218'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C0962559']},
#    'id': 'C0962559'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C1101610']},
#    'id': 'C1101610'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C1518434']},
#    'id': 'C1518434'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C1522485']},
#    'id': 'C1522485'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C1568660']},
#    'id': 'C1568660'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C0001455']},
#    'id': 'C0001455'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C0011777']},
#    'id': 'C0011777'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C0012854']},
#    'id': 'C0012854'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C0013879']},
#    'id': 'C0013879'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C0034760']},
#    'id': 'C0034760'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C0042866']},
#    'id': 'C0042866'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C0061202']},
#    'id': 'C0061202'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C0061275']},
#    'id': 'C0061275'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C0062565']},
#    'id': 'C0062565'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C0074554']},
#    'id': 'C0074554'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C0085170']},
#    'id': 'C0085170'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C0220806']},
#    'id': 'C0220806'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C0245514']},
#    'id': 'C0245514'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C0289993']},
#    'id': 'C0289993'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C0309049']},
#    'id': 'C0309049'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C0309276']},
#    'id': 'C0309276'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C0450442']},
#    'id': 'C0450442'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C0600334']},
#    'id': 'C0600334'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C0950779']},
#    'id': 'C0950779'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C1099354']},
#    'id': 'C1099354'},
#   {'identifier': 'bts:umls',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:umls': ['C1171350']},
#    'id': 'C1171350'},
#   {'identifier': 'bts:chembl',
#    'type': 'ChemicalSubstance',
#    'level': 2,
#    'equivalent_ids': {'bts:inchi': ['InChI=1S/C23H26FN6O9P/c1-23(2)21(31)30(11-38-40(32,33)34)20-14(39-23)6-7-17(28-20)27-19-13(24)10-25-22(29-19)26-12-8-15(35-3)18(37-5)16(9-12)36-4/h6-10H,11H2,1-5H3,(H2,32,33,34)(H2,25,26,27,28,29)'],
#     'bts:inchikey': ['GKDRMWXFWHEQQT-UHFFFAOYSA-N'],
#     'bts:rxcui': [],
#     'bts:smiles': ['COc1cc(Nc2ncc(F)c(Nc3ccc4OC(C)(C)C(=O)N(COP(=O)(O)O)c4n3)n2)cc(OC)c1OC'],
#     'bts:pubchem': [11671467],
#     'bts:chembl': ['CHEMBL2103830'],
#     'bts:drugbank': ['DB12010'],
#     'bts:unii': ['SQ8A3S5101'],
#     'bts:mesh': ['C523665']},
#    'id': 'CHEMBL2103830'}],
#  'links': [{'info': {'bts:chembl': ['CHEMBL3301610'],
#     'bts:name': ['ABEMACICLIB'],
#     'bts:source': ['ClearityFoundationBiomarkers',
#      'ClearityFoundationClinicalTrial',
#      'OncoKB',
#      'GuideToPharmacologyInteractions',
#      'ChemblInteractions',
#      'CancerCommons'],
#     'bts:publication': [21610706, 23569312, 20601955, 26324739],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:symbol',
#     '$source': 'dgidb'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL3301610',
#    'key': 0},
#   {'info': {'@type': 'ChemicalSubstance',
#     'bts:chembl': ['CHEMBL3301610'],
#     '$source': 'mychem.info'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL3301610',
#    'key': 1},
#   {'info': {'@type': 'ChemicalSubstance',
#     'bts:drugbank': ['DB12001'],
#     '$source': 'mychem.info'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL3301610',
#    'key': 2},
#   {'info': {'bts:chembl': ['CHEMBL189963'],
#     'bts:name': ['PALBOCICLIB'],
#     'bts:source': ['TALC',
#      'ClearityFoundationBiomarkers',
#      'MyCancerGenome',
#      'ClearityFoundationClinicalTrial',
#      'OncoKB',
#      'GuideToPharmacologyInteractions',
#      'ChemblInteractions',
#      'CIViC',
#      'DrugBank',
#      'CancerCommons',
#      'MyCancerGenomeClinicalTrial',
#      'TTD'],
#     'bts:publication': [21610706,
#      23569312,
#      20601955,
#      27124835,
#      26324739,
#      26528855,
#      23898052,
#      15542782],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:symbol',
#     '$source': 'dgidb'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL189963',
#    'key': 0},
#   {'info': {'@type': 'ChemicalSubstance',
#     'bts:chembl': ['CHEMBL189963'],
#     '$source': 'mychem.info'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL189963',
#    'key': 1},
#   {'info': {'@type': 'ChemicalSubstance',
#     'bts:drugbank': ['DB09073'],
#     '$source': 'mychem.info'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL189963',
#    'key': 2},
#   {'info': {'bts:chembl': ['CHEMBL564829'],
#     'bts:name': ['MILCICLIB'],
#     'bts:source': ['GuideToPharmacologyInteractions', 'ChemblInteractions'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:symbol',
#     '$source': 'dgidb'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL564829',
#    'key': 0},
#   {'info': {'bts:chembl': ['CHEMBL3544942'],
#     'bts:name': ['Roniciclib'],
#     'bts:source': ['ClearityFoundationBiomarkers',
#      'ChemblInteractions',
#      'CancerCommons'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:symbol',
#     '$source': 'dgidb'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL3544942',
#    'key': 0},
#   {'info': {'bts:chembl': ['CHEMBL574737'],
#     'bts:name': ['(7S)-HYDROXYL-STAUROSPORINE'],
#     'bts:source': ['ChemblInteractions'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:symbol',
#     '$source': 'dgidb'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL574737',
#    'key': 0},
#   {'info': {'bts:chembl': ['CHEMBL428690'],
#     'bts:name': ['ALVOCIDIB'],
#     'bts:source': ['MyCancerGenome',
#      'TdgClinicalTrial',
#      'GuideToPharmacologyInteractions',
#      'ChemblInteractions',
#      'DrugBank'],
#     'bts:publication': [11752352],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:symbol',
#     '$source': 'dgidb'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL428690',
#    'key': 0},
#   {'info': {'@type': 'ChemicalSubstance',
#     'bts:drugbank': ['DB03496'],
#     '$source': 'mychem.info'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL428690',
#    'key': 1},
#   {'info': {'bts:chembl': ['CHEMBL445813'],
#     'bts:name': ['AT-7519'],
#     'bts:source': ['GuideToPharmacologyInteractions', 'ChemblInteractions'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:symbol',
#     '$source': 'dgidb'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL445813',
#    'key': 0},
#   {'info': {'bts:chembl': ['CHEMBL1802728'],
#     'bts:name': ['CHEMBL1802728'],
#     'bts:source': ['GuideToPharmacologyInteractions'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:symbol',
#     '$source': 'dgidb'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL1802728',
#    'key': 0},
#   {'info': {'bts:chembl': ['CHEMBL602937'],
#     'bts:name': ['FASCAPLYSIN'],
#     'bts:source': ['GuideToPharmacologyInteractions'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:symbol',
#     '$source': 'dgidb'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL602937',
#    'key': 0},
#   {'info': {'bts:chembl': ['CHEMBL448'],
#     'bts:name': ['PENTOBARBITAL'],
#     'bts:source': ['GuideToPharmacologyInteractions'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:symbol',
#     '$source': 'dgidb'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL448',
#    'key': 0},
#   {'info': {'bts:chembl': ['CHEMBL23327'],
#     'bts:name': ['PURVALANOLA'],
#     'bts:source': ['GuideToPharmacologyInteractions'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:symbol',
#     '$source': 'dgidb'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL23327',
#    'key': 0},
#   {'info': {'bts:chembl': ['CHEMBL23254'],
#     'bts:name': ['PURVALANOL B'],
#     'bts:source': ['GuideToPharmacologyInteractions'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:symbol',
#     '$source': 'dgidb'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL23254',
#    'key': 0},
#   {'info': {'@type': 'ChemicalSubstance',
#     'bts:drugbank': ['DB02733'],
#     '$source': 'mychem.info'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL23254',
#    'key': 1},
#   {'info': {'bts:chembl': ['CHEMBL3545083'],
#     'bts:name': ['RGB-286638'],
#     'bts:source': ['GuideToPharmacologyInteractions', 'ChemblInteractions'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:symbol',
#     '$source': 'dgidb'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL3545083',
#    'key': 0},
#   {'info': {'bts:chembl': ['CHEMBL3545110'],
#     'bts:name': ['Ribociclib'],
#     'bts:source': ['ClearityFoundationBiomarkers',
#      'MyCancerGenome',
#      'TdgClinicalTrial',
#      'GuideToPharmacologyInteractions',
#      'ChemblInteractions',
#      'CGI',
#      'DrugBank'],
#     'bts:publication': [24045179],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:symbol',
#     '$source': 'dgidb'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL3545110',
#    'key': 0},
#   {'info': {'@type': 'ChemicalSubstance',
#     'bts:chembl': ['CHEMBL3545110'],
#     '$source': 'mychem.info'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL3545110',
#    'key': 1},
#   {'info': {'@type': 'ChemicalSubstance',
#     'bts:drugbank': ['DB11730'],
#     '$source': 'mychem.info'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL3545110',
#    'key': 2},
#   {'info': {'bts:chembl': ['CHEMBL3545283'],
#     'bts:name': ['Riviciclib'],
#     'bts:source': ['GuideToPharmacologyInteractions',
#      'ChemblInteractions',
#      'TTD'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:symbol',
#     '$source': 'dgidb'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL3545283',
#    'key': 0},
#   {'info': {'bts:chembl': ['CHEMBL1956070'],
#     'bts:name': ['CHEMBL1956070'],
#     'bts:source': ['GuideToPharmacologyInteractions'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:symbol',
#     '$source': 'dgidb'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL1956070',
#    'key': 0},
#   {'info': {'bts:chembl': ['CHEMBL258805'],
#     'bts:name': ['INDIRUBIN SULFATE'],
#     'bts:source': ['GuideToPharmacologyInteractions'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:symbol',
#     '$source': 'dgidb'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL258805',
#    'key': 0},
#   {'info': {'bts:chembl': ['CHEMBL126955'],
#     'bts:name': ['CHEMBL126955'],
#     'bts:source': ['NCI'],
#     'bts:publication': [16203796],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:symbol',
#     '$source': 'dgidb'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL126955',
#    'key': 0},
#   {'info': {'bts:chembl': ['CHEMBL65'],
#     'bts:name': ['CAMPTOTHECIN'],
#     'bts:source': ['NCI'],
#     'bts:publication': [10777774],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:symbol',
#     '$source': 'dgidb'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL65',
#    'key': 0},
#   {'info': {'bts:chembl': ['CHEMBL384467'],
#     'bts:name': ['DEXAMETHASONE'],
#     'bts:source': ['NCI'],
#     'bts:publication': [7664296],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:symbol',
#     '$source': 'dgidb'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL384467',
#    'key': 0},
#   {'info': {'bts:chembl': ['CHEMBL488436'],
#     'bts:name': ['AZD-5438'],
#     'bts:source': ['ChemblInteractions'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:symbol',
#     '$source': 'dgidb'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL488436',
#    'key': 0},
#   {'info': {'bts:chembl': ['CHEMBL1230607'],
#     'bts:name': ['PHA-793887'],
#     'bts:source': ['ChemblInteractions'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:symbol',
#     '$source': 'dgidb'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL1230607',
#    'key': 0},
#   {'info': {'bts:chembl': ['CHEMBL384304'],
#     'bts:name': ['RG-547'],
#     'bts:source': ['ChemblInteractions', 'TTD'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:symbol',
#     '$source': 'dgidb'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL384304',
#    'key': 0},
#   {'info': {'bts:chembl': ['CHEMBL3544940'],
#     'bts:name': ['G1T28-1'],
#     'bts:source': ['ChemblInteractions'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:symbol',
#     '$source': 'dgidb'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL3544940',
#    'key': 0},
#   {'info': {'bts:chembl': ['CHEMBL3545218'],
#     'bts:name': ['Voruciclib'],
#     'bts:source': ['ChemblInteractions', 'TTD'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:symbol',
#     '$source': 'dgidb'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL3545218',
#    'key': 0},
#   {'info': {'bts:chembl': ['CHEMBL514800'],
#     'bts:name': ['APREMILAST'],
#     'bts:source': ['TTD'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:symbol',
#     '$source': 'dgidb'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL514800',
#    'key': 0},
#   {'info': {'bts:chembl': ['CHEMBL52885'],
#     'bts:name': ['ENMD-981693'],
#     'bts:source': ['TTD'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:symbol',
#     '$source': 'dgidb'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL52885',
#    'key': 0},
#   {'info': {'bts:chembl': ['CHEMBL3545420'],
#     'bts:name': ['AG-24322'],
#     'bts:source': ['ChemblInteractions', 'TTD'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:symbol',
#     '$source': 'dgidb'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL3545420',
#    'key': 0},
#   {'info': {'bts:chembl': ['CHEMBL3707266'],
#     'bts:name': ['RIBOCICLIB SUCCINATE'],
#     'bts:source': ['ChemblInteractions'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:symbol',
#     '$source': 'dgidb'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL3707266',
#    'key': 0},
#   {'info': {'bts:chembl': ['CHEMBL3'],
#     'bts:name': ['NICOTINE'],
#     'bts:source': ['NCI'],
#     'bts:publication': [15231866],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:symbol',
#     '$source': 'dgidb'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL3',
#    'key': 0},
#   {'info': {'bts:chembl': ['CHEMBL103'],
#     'bts:name': ['PROGESTERONE'],
#     'bts:source': ['NCI'],
#     'bts:publication': [10713180],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:symbol',
#     '$source': 'dgidb'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL103',
#    'key': 0},
#   {'info': {'bts:chembl': ['CHEMBL196'],
#     'bts:name': ['ASCORBATE'],
#     'bts:source': ['NCI'],
#     'bts:publication': [16944783],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:symbol',
#     '$source': 'dgidb'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL196',
#    'key': 0},
#   {'info': {'@type': 'ChemicalSubstance',
#     'bts:chembl': ['CHEMBL2403108'],
#     '$source': 'mychem.info'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL2403108',
#    'key': 0},
#   {'info': {'@type': 'ChemicalSubstance',
#     'bts:chembl': ['CHEMBL91829'],
#     '$source': 'mychem.info'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL91829',
#    'key': 0},
#   {'info': {'@type': 'ChemicalSubstance',
#     'bts:chembl': ['CHEMBL50'],
#     '$source': 'mychem.info'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL50',
#    'key': 0},
#   {'info': {'@type': 'ChemicalSubstance',
#     'bts:chembl': ['CHEMBL502835'],
#     '$source': 'mychem.info'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL502835',
#    'key': 0},
#   {'info': {'@type': 'ChemicalSubstance',
#     'bts:chembl': ['CHEMBL535'],
#     '$source': 'mychem.info'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL535',
#    'key': 0},
#   {'info': {'bts:umls': ['C0005456'],
#     'bts:pubmed': ['16892371', '16892371'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0005456',
#    'key': 0},
#   {'info': {'bts:umls': ['C0007090'],
#     'bts:pubmed': ['9855016', '10688915', '18632627'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0007090',
#    'key': 0},
#   {'info': {'bts:umls': ['C0007090'],
#     'bts:pubmed': ['9855016', '10688915', '18632627'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0007090',
#    'key': 1},
#   {'info': {'bts:umls': ['C0007090'],
#     'bts:pubmed': ['15781632'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0007090',
#    'key': 2},
#   {'info': {'bts:umls': ['C0007090'],
#     'bts:pubmed': ['15781632'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0007090',
#    'key': 3},
#   {'info': {'bts:umls': ['C0013227'],
#     'bts:pubmed': ['12684681', '16319987'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0013227',
#    'key': 0},
#   {'info': {'bts:umls': ['C0013227'],
#     'bts:pubmed': ['12684681', '16319987'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0013227',
#    'key': 1},
#   {'info': {'bts:umls': ['C0013227'],
#     'bts:pubmed': ['17923872'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0013227',
#    'key': 2},
#   {'info': {'bts:umls': ['C0013227'],
#     'bts:pubmed': ['17923872'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0013227',
#    'key': 3},
#   {'info': {'bts:umls': ['C0016360'],
#     'bts:pubmed': ['27793037'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0016360',
#    'key': 0},
#   {'info': {'bts:umls': ['C0016360'],
#     'bts:pubmed': ['27793037'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0016360',
#    'key': 1},
#   {'info': {'bts:umls': ['C0017725'],
#     'bts:pubmed': ['12401721'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0017725',
#    'key': 0},
#   {'info': {'bts:umls': ['C0018282'],
#     'bts:pubmed': ['11448101', '12376477', '22869556', '25998161', '27020862'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0018282',
#    'key': 0},
#   {'info': {'bts:umls': ['C0034243'],
#     'bts:pubmed': ['18839518'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0034243',
#    'key': 0},
#   {'info': {'bts:umls': ['C0034243'],
#     'bts:pubmed': ['18839518'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0034243',
#    'key': 1},
#   {'info': {'bts:umls': ['C0036681'],
#     'bts:pubmed': ['8175758'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0036681',
#    'key': 0},
#   {'info': {'bts:umls': ['C0038317'],
#     'bts:pubmed': ['24848372'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0038317',
#    'key': 0},
#   {'info': {'bts:umls': ['C0040845'],
#     'bts:pubmed': ['9260897'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0040845',
#    'key': 0},
#   {'info': {'bts:umls': ['C0040845'],
#     'bts:pubmed': ['9259311'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0040845',
#    'key': 1},
#   {'info': {'bts:umls': ['C0040845'],
#     'bts:pubmed': ['9259311'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0040845',
#    'key': 2},
#   {'info': {'bts:umls': ['C0073096'],
#     'bts:pubmed': ['23522452'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0073096',
#    'key': 0},
#   {'info': {'bts:umls': ['C0144576'],
#     'bts:pubmed': ['25722690'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0144576',
#    'key': 0},
#   {'info': {'bts:umls': ['C0144576'],
#     'bts:pubmed': ['25722690'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0144576',
#    'key': 1},
#   {'info': {'bts:umls': ['C0243077'],
#     'bts:pubmed': ['8981359',
#      '9683802',
#      '11426564',
#      '19197160',
#      '21108658',
#      '18414028',
#      '18414028',
#      '22263797',
#      '23470834',
#      '24689233'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0243077',
#    'key': 0},
#   {'info': {'bts:umls': ['C0243077'],
#     'bts:pubmed': ['16898268'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0243077',
#    'key': 1},
#   {'info': {'bts:umls': ['C0243077'],
#     'bts:pubmed': ['9106657', '20539760', '18760195', '24250202'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0243077',
#    'key': 2},
#   {'info': {'bts:umls': ['C0608663'],
#     'bts:pubmed': ['27832629'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0608663',
#    'key': 0},
#   {'info': {'bts:umls': ['C0661318'],
#     'bts:pubmed': ['22198210'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0661318',
#    'key': 0},
#   {'info': {'bts:umls': ['C0662253'],
#     'bts:pubmed': ['12903464'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0662253',
#    'key': 0},
#   {'info': {'bts:umls': ['C0675974'],
#     'bts:pubmed': ['16203796', '18281495'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0675974',
#    'key': 0},
#   {'info': {'bts:umls': ['C0729218'],
#     'bts:pubmed': ['18929848'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0729218',
#    'key': 0},
#   {'info': {'bts:umls': ['C0962559'],
#     'bts:pubmed': ['17706465'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0962559',
#    'key': 0},
#   {'info': {'bts:umls': ['C1101610'],
#     'bts:pubmed': ['24771630'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C1101610',
#    'key': 0},
#   {'info': {'bts:umls': ['C1101610'],
#     'bts:pubmed': ['24771630'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C1101610',
#    'key': 1},
#   {'info': {'bts:umls': ['C1518434'],
#     'bts:pubmed': ['17894419'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C1518434',
#    'key': 0},
#   {'info': {'bts:umls': ['C1522485'],
#     'bts:pubmed': ['10702611'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C1522485',
#    'key': 0},
#   {'info': {'bts:umls': ['C1568660'],
#     'bts:pubmed': ['21871868'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C1568660',
#    'key': 0},
#   {'info': {'bts:umls': ['C1568660'],
#     'bts:pubmed': ['21871868'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C1568660',
#    'key': 1},
#   {'info': {'bts:umls': ['C1568660'],
#     'bts:pubmed': ['25801820'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C1568660',
#    'key': 2},
#   {'info': {'bts:umls': ['C0001455'],
#     'bts:pubmed': ['18799615'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0001455',
#    'key': 0},
#   {'info': {'bts:umls': ['C0001455'],
#     'bts:pubmed': ['10537037'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0001455',
#    'key': 1},
#   {'info': {'bts:umls': ['C0011777'],
#     'bts:pubmed': ['9275052'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0011777',
#    'key': 0},
#   {'info': {'bts:umls': ['C0012854'],
#     'bts:pubmed': ['9516974'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0012854',
#    'key': 0},
#   {'info': {'bts:umls': ['C0012854'],
#     'bts:pubmed': ['9516974'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0012854',
#    'key': 1},
#   {'info': {'bts:umls': ['C0013879'],
#     'bts:pubmed': ['23006472'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0013879',
#    'key': 0},
#   {'info': {'bts:umls': ['C0013879'],
#     'bts:pubmed': ['23006472'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0013879',
#    'key': 1},
#   {'info': {'bts:umls': ['C0034760'],
#     'bts:pubmed': ['23552696'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0034760',
#    'key': 0},
#   {'info': {'bts:umls': ['C0042866'],
#     'bts:pubmed': ['25721671'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0042866',
#    'key': 0},
#   {'info': {'bts:umls': ['C0061202'],
#     'bts:pubmed': ['25588108'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0061202',
#    'key': 0},
#   {'info': {'bts:umls': ['C0061202'],
#     'bts:pubmed': ['18490856'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0061202',
#    'key': 1},
#   {'info': {'bts:umls': ['C0061275'],
#     'bts:pubmed': ['27706758'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0061275',
#    'key': 0},
#   {'info': {'bts:umls': ['C0062565'],
#     'bts:pubmed': ['11120786'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0062565',
#    'key': 0},
#   {'info': {'bts:umls': ['C0074554'],
#     'bts:pubmed': ['20878096'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0074554',
#    'key': 0},
#   {'info': {'bts:umls': ['C0085170'],
#     'bts:pubmed': ['21315112'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0085170',
#    'key': 0},
#   {'info': {'bts:umls': ['C0220806'],
#     'bts:pubmed': ['25695870'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0220806',
#    'key': 0},
#   {'info': {'bts:umls': ['C0220806'],
#     'bts:pubmed': ['25695870'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0220806',
#    'key': 1},
#   {'info': {'bts:umls': ['C0245514'],
#     'bts:pubmed': ['17573040'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0245514',
#    'key': 0},
#   {'info': {'bts:umls': ['C0289993'],
#     'bts:pubmed': ['10228011'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0289993',
#    'key': 0},
#   {'info': {'bts:umls': ['C0309049'],
#     'bts:pubmed': ['15123247'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0309049',
#    'key': 0},
#   {'info': {'bts:umls': ['C0309276'],
#     'bts:pubmed': ['16506209'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0309276',
#    'key': 0},
#   {'info': {'bts:umls': ['C0309276'],
#     'bts:pubmed': ['16506209'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0309276',
#    'key': 1},
#   {'info': {'bts:umls': ['C0450442'],
#     'bts:pubmed': ['9258408'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0450442',
#    'key': 0},
#   {'info': {'bts:umls': ['C0600334'],
#     'bts:pubmed': ['23530816'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0600334',
#    'key': 0},
#   {'info': {'bts:umls': ['C0950779'],
#     'bts:pubmed': ['8831499'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C0950779',
#    'key': 0},
#   {'info': {'bts:umls': ['C1099354'],
#     'bts:pubmed': ['18006822', '20539760'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C1099354',
#    'key': 0},
#   {'info': {'bts:umls': ['C1171350'],
#     'bts:pubmed': ['27670681'],
#     '@type': 'ChemicalSubstance',
#     '$input': 'bts:umls',
#     '$source': 'semmed'},
#    'label': 'bts:molecularlyInteractsWith',
#    'source': '1019',
#    'target': 'C1171350',
#    'key': 0},
#   {'info': {'@type': 'ChemicalSubstance',
#     'bts:drugbank': ['DB12010'],
#     '$source': 'mychem.info'},
#    'label': 'bts:targetedBy',
#    'source': '1019',
#    'target': 'CHEMBL2103830',
#    'key': 0}]}

# %% [markdown]
# #### List all output ids

# %%
seqd.output_ids
# Out:
# {'ChemicalSubstance': {'chembl:CHEMBL3301610': {'bts:inchi': ['InChI=1S/C27H32F2N8/c1-5-35-8-10-36(11-9-35)16-19-6-7-24(30-14-19)33-27-31-15-22(29)25(34-27)20-12-21(28)26-23(13-20)37(17(2)3)18(4)32-26/h6-7,12-15,17H,5,8-11,16H2,1-4H3,(H,30,31,33,34)'],
#    'bts:inchikey': ['UZWDCWONPYILKI-UHFFFAOYSA-N'],
#    'bts:rxcui': [],
#    'bts:smiles': ['CCN1CCN(Cc2ccc(Nc3ncc(F)c(n3)c4cc(F)c5nc(C)n(C(C)C)c5c4)nc2)CC1'],
#    'bts:pubchem': [46220502],
#    'bts:chembl': ['CHEMBL3301610'],
#    'bts:drugbank': ['DB12001'],
#    'bts:unii': ['60UAB198HK'],
#    'bts:mesh': []},
#   'chembl:CHEMBL189963': {'bts:inchi': ['InChI=1S/C24H29N7O2/c1-15-19-14-27-24(28-20-8-7-18(13-26-20)30-11-9-25-10-12-30)29-22(19)31(17-5-3-4-6-17)23(33)21(15)16(2)32/h7-8,13-14,17,25H,3-6,9-12H2,1-2H3,(H,26,27,28,29)'],
#    'bts:inchikey': ['AHJRHEGDXFFMBM-UHFFFAOYSA-N'],
#    'bts:rxcui': ['1601374'],
#    'bts:smiles': ['CC(=O)C1=C(C)c2cnc(Nc3ccc(cn3)N4CCNCC4)nc2N(C5CCCC5)C1=O'],
#    'bts:pubchem': [5330286],
#    'bts:chembl': ['CHEMBL189963'],
#    'bts:drugbank': ['DB09073'],
#    'bts:unii': ['G9ZF61LE7G'],
#    'bts:mesh': []},
#   'chembl:CHEMBL564829': {'bts:inchi': ['InChI=1S/C25H32N8O/c1-25(2)14-16-15-27-24(29-20(16)22-19(25)21(23(34)26-3)30-32(22)5)28-17-6-8-18(9-7-17)33-12-10-31(4)11-13-33/h6-9,15H,10-14H2,1-5H3,(H,26,34)(H,27,28,29)'],
#    'bts:inchikey': ['RXZMYLDMFYNEIM-UHFFFAOYSA-N'],
#    'bts:rxcui': [],
#    'bts:smiles': ['CNC(=O)c1nn(C)c2c3nc(Nc4ccc(cc4)N5CCN(C)CC5)ncc3CC(C)(C)c12'],
#    'bts:pubchem': [16718576],
#    'bts:chembl': ['CHEMBL564829'],
#    'bts:drugbank': [],
#    'bts:unii': ['688000M8S8'],
#    'bts:mesh': []},
#   'chembl:CHEMBL3544942': {'bts:inchi': [],
#    'bts:inchikey': [],
#    'bts:rxcui': [],
#    'bts:smiles': [],
#    'bts:pubchem': [],
#    'bts:chembl': ['CHEMBL3544942'],
#    'bts:drugbank': [],
#    'bts:unii': [],
#    'bts:mesh': []},
#   'chembl:CHEMBL574737': {'bts:inchi': ['InChI=1S/C28H26N4O4/c1-28-25(35-3)15(29-2)12-18(36-28)31-16-10-6-4-8-13(16)19-21-22(27(34)30-26(21)33)20-14-9-5-7-11-17(14)32(28)24(20)23(19)31/h4-11,15,18,25,27,29,34H,12H2,1-3H3,(H,30,33)/t15-,18-,25-,27+,28+/m1/s1'],
#    'bts:inchikey': ['PBCZSGKMGDDXIJ-KRUBCLEUSA-N'],
#    'bts:rxcui': [],
#    'bts:smiles': ['CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n3c4ccccc4c5c6[C@H](O)NC(=O)c6c7c8ccccc8n2c7c35'],
#    'bts:pubchem': [3078519],
#    'bts:chembl': ['CHEMBL574737'],
#    'bts:drugbank': [],
#    'bts:unii': [],
#    'bts:mesh': []},
#   'chembl:CHEMBL428690': {'bts:inchi': ['InChI=1S/C21H20ClNO5/c1-23-7-6-12(17(27)10-23)19-14(24)8-15(25)20-16(26)9-18(28-21(19)20)11-4-2-3-5-13(11)22/h2-5,8-9,12,17,24-25,27H,6-7,10H2,1H3/t12-,17+/m0/s1'],
#    'bts:inchikey': ['BIIVYFLTOXDAOV-YVEFUNNKSA-N'],
#    'bts:rxcui': [],
#    'bts:smiles': ['CN1CC[C@@H]([C@H](O)C1)c2c(O)cc(O)c3C(=O)C=C(Oc23)c4ccccc4Cl'],
#    'bts:pubchem': [5287969],
#    'bts:chembl': ['CHEMBL428690'],
#    'bts:drugbank': ['DB03496'],
#    'bts:unii': ['45AD6X575G'],
#    'bts:mesh': ['C077990']},
#   'chembl:CHEMBL445813': {'bts:inchi': ['InChI=1S/C16H17Cl2N5O2/c17-10-2-1-3-11(18)13(10)15(24)22-12-8-20-23-14(12)16(25)21-9-4-6-19-7-5-9/h1-3,8-9,19H,4-7H2,(H,20,23)(H,21,25)(H,22,24)'],
#    'bts:inchikey': ['OVPNQJVDAFNBDN-UHFFFAOYSA-N'],
#    'bts:rxcui': [],
#    'bts:smiles': ['Clc1cccc(Cl)c1C(=O)Nc2c[nH]nc2C(=O)NC3CCNCC3'],
#    'bts:pubchem': [11338033],
#    'bts:chembl': ['CHEMBL445813'],
#    'bts:drugbank': ['DB08142'],
#    'bts:unii': ['X1BF92PW9T'],
#    'bts:mesh': []},
#   'chembl:CHEMBL1802728': {'bts:inchi': ['InChI=1S/C23H30N6O2/c1-3-29(4-2)22(30)17-10-12-18(13-11-17)26-23-27-20-19(24-15-25-20)21(28-23)31-14-16-8-6-5-7-9-16/h10-13,15-16H,3-9,14H2,1-2H3,(H2,24,25,26,27,28)'],
#    'bts:inchikey': ['XHEQSRJCJTWWAH-UHFFFAOYSA-N'],
#    'bts:rxcui': [],
#    'bts:smiles': ['CCN(CC)C(=O)c1ccc(Nc2nc(OCC3CCCCC3)c4nc[nH]c4n2)cc1'],
#    'bts:pubchem': [10202471],
#    'bts:chembl': ['CHEMBL1802728'],
#    'bts:drugbank': [],
#    'bts:unii': [],
#    'bts:mesh': []},
#   'chembl:CHEMBL602937': {'bts:inchi': ['InChI=1S/C18H10N2O/c21-18-13-6-2-4-8-15(13)20-10-9-12-11-5-1-3-7-14(11)19-16(12)17(18)20/h1-10H/p+1'],
#    'bts:inchikey': ['WYQIPCUPNMRAKP-UHFFFAOYSA-O'],
#    'bts:rxcui': [],
#    'bts:smiles': ['O=C1c2ccccc2[n+]3ccc4c5ccccc5[nH]c4c13'],
#    'bts:pubchem': [73293],
#    'bts:chembl': ['CHEMBL602937'],
#    'bts:drugbank': [],
#    'bts:unii': [],
#    'bts:mesh': []},
#   'chembl:CHEMBL448': {'bts:inchi': ['InChI=1S/C11H18N2O3/c1-4-6-7(3)11(5-2)8(14)12-10(16)13-9(11)15/h7H,4-6H2,1-3H3,(H2,12,13,14,15,16)'],
#    'bts:inchikey': ['WEXRUCMBJFQVBZ-UHFFFAOYSA-N'],
#    'bts:rxcui': [],
#    'bts:smiles': ['CCCC(C)C1(CC)C(=O)NC(=O)NC1=O'],
#    'bts:pubchem': [4737],
#    'bts:chembl': ['CHEMBL448'],
#    'bts:drugbank': ['DB00312'],
#    'bts:unii': [],
#    'bts:mesh': ['D010424']},
#   'chembl:CHEMBL23327': {'bts:inchi': ['InChI=1S/C19H25ClN6O/c1-11(2)15(9-27)23-19-24-17(22-14-7-5-6-13(20)8-14)16-18(25-19)26(10-21-16)12(3)4/h5-8,10-12,15,27H,9H2,1-4H3,(H2,22,23,24,25)/t15-/m0/s1'],
#    'bts:inchikey': ['PMXCMJLOPOFPBT-HNNXBMFYSA-N'],
#    'bts:rxcui': [],
#    'bts:smiles': ['CC(C)[C@H](CO)Nc1nc(Nc2cccc(Cl)c2)c3ncn(C(C)C)c3n1'],
#    'bts:pubchem': [456214],
#    'bts:chembl': ['CHEMBL23327'],
#    'bts:drugbank': ['DB04751'],
#    'bts:unii': [],
#    'bts:mesh': []},
#   'chembl:CHEMBL23254': {'bts:inchi': ['InChI=1S/C20H25ClN6O3/c1-10(2)15(8-28)24-20-25-17(16-18(26-20)27(9-22-16)11(3)4)23-12-5-6-13(19(29)30)14(21)7-12/h5-7,9-11,15,28H,8H2,1-4H3,(H,29,30)(H2,23,24,25,26)/t15-/m0/s1'],
#    'bts:inchikey': ['ZKDXRFMOHZVXSG-HNNXBMFYSA-N'],
#    'bts:rxcui': [],
#    'bts:smiles': ['CC(C)[C@H](CO)Nc1nc(Nc2ccc(C(=O)O)c(Cl)c2)c3ncn(C(C)C)c3n1'],
#    'bts:pubchem': [448991],
#    'bts:chembl': ['CHEMBL23254'],
#    'bts:drugbank': ['DB02733'],
#    'bts:unii': [],
#    'bts:mesh': []},
#   'chembl:CHEMBL3545083': {'bts:inchi': ['InChI=1S/C29H35N7O4/c1-39-16-13-34-9-11-35(12-10-34)19-20-5-7-21(8-6-20)26-25-27(32-31-26)22-3-2-4-23(24(22)28(25)37)30-29(38)33-36-14-17-40-18-15-36/h2-8H,9-19H2,1H3,(H,31,32)(H2,30,33,38)'],
#    'bts:inchikey': ['XLSYZSRXVVCHLS-UHFFFAOYSA-N'],
#    'bts:rxcui': [],
#    'bts:smiles': ['COCCN1CCN(Cc2ccc(cc2)c3n[nH]c4c5cccc(NC(=O)NN6CCOCC6)c5C(=O)c34)CC1'],
#    'bts:pubchem': [11285002],
#    'bts:chembl': ['CHEMBL3545083'],
#    'bts:drugbank': [],
#    'bts:unii': ['1GAJ98SC2X'],
#    'bts:mesh': []},
#   'chembl:CHEMBL3545110': {'bts:inchi': ['InChI=1S/C23H30N8O/c1-29(2)22(32)19-13-16-14-26-23(28-21(16)31(19)17-5-3-4-6-17)27-20-8-7-18(15-25-20)30-11-9-24-10-12-30/h7-8,13-15,17,24H,3-6,9-12H2,1-2H3,(H,25,26,27,28)'],
#    'bts:inchikey': ['RHXHGRAEPCAFML-UHFFFAOYSA-N'],
#    'bts:rxcui': [],
#    'bts:smiles': ['CN(C)C(=O)c1cc2cnc(Nc3ccc(cn3)N4CCNCC4)nc2n1C5CCCC5'],
#    'bts:pubchem': [44631912],
#    'bts:chembl': ['CHEMBL3545110'],
#    'bts:drugbank': ['DB11730'],
#    'bts:unii': ['TK8ERE8P56'],
#    'bts:mesh': []},
#   'chembl:CHEMBL3545283': {'bts:inchi': ['InChI=1S/C21H20ClNO5/c1-23-7-6-12(14(23)10-24)19-15(25)8-16(26)20-17(27)9-18(28-21(19)20)11-4-2-3-5-13(11)22/h2-5,8-9,12,14,24-26H,6-7,10H2,1H3'],
#    'bts:inchikey': ['QLUYMIVVAYRECT-UHFFFAOYSA-N'],
#    'bts:rxcui': [],
#    'bts:smiles': ['CN1CCC(C1CO)c2c(O)cc(O)c3C(=O)C=C(Oc23)c4ccccc4Cl'],
#    'bts:pubchem': [9952923],
#    'bts:chembl': ['CHEMBL3545283'],
#    'bts:drugbank': [],
#    'bts:unii': [],
#    'bts:mesh': []},
#   'chembl:CHEMBL1956070': {'bts:inchi': ['InChI=1S/C23H25N5O3S/c1-27-8-10-28(11-9-27)17-5-3-16(4-6-17)25-23-26-22(24)21(32-23)20(29)15-2-7-18-19(14-15)31-13-12-30-18/h2-7,14H,8-13,24H2,1H3,(H,25,26)'],
#    'bts:inchikey': ['YGEYFDLYGXSZCP-UHFFFAOYSA-N'],
#    'bts:rxcui': [],
#    'bts:smiles': ['CN1CCN(CC1)c2ccc(Nc3nc(N)c(s3)C(=O)c4ccc5OCCOc5c4)cc2'],
#    'bts:pubchem': [9911652],
#    'bts:chembl': ['CHEMBL1956070'],
#    'bts:drugbank': [],
#    'bts:unii': [],
#    'bts:mesh': []},
#   'chembl:CHEMBL258805': {'bts:inchi': ['InChI=1S/C13H11N3O2/c1-18-9-2-3-12-10(5-9)11(13(17)16-12)4-8-6-14-7-15-8/h2-7H,1H3,(H,14,15)(H,16,17)/b11-4-'],
#    'bts:inchikey': ['QNUKRWAIZMBVCU-WCIBSUBMSA-N'],
#    'bts:rxcui': [],
#    'bts:smiles': ['COc1ccc2NC(=O)\\C(=C/c3cnc[nH]3)\\c2c1'],
#    'bts:pubchem': [5289419],
#    'bts:chembl': ['CHEMBL258805'],
#    'bts:drugbank': ['DB03428'],
#    'bts:unii': [],
#    'bts:mesh': []},
#   'chembl:CHEMBL126955': {'bts:inchi': ['InChI=1S/C31H43N3O8/c1-8-12-33-26-21-13-17(2)14-25(41-7)27(36)19(4)15-20(5)29(42-31(32)39)24(40-6)11-9-10-18(3)30(38)34-22(28(21)37)16-23(26)35/h8-11,15-17,19,24-25,27,29,33,36H,1,12-14H2,2-7H3,(H2,32,39)(H,34,38)/b11-9+,18-10+,20-15+/t17-,19+,24+,25+,27-,29+/m1/s1'],
#    'bts:inchikey': ['AYUNIORJHRXIBJ-HTLBVUBBSA-N'],
#    'bts:rxcui': [],
#    'bts:smiles': ['CO[C@H]1C[C@H](C)CC2=C(NCC=C)C(=O)C=C(NC(=O)\\C(=C\\C=C\\[C@H](OC)[C@@H](OC(=O)N)\\C(=C\\[C@H](C)[C@H]1O)\\C)\\C)C2=O'],
#    'bts:pubchem': [6440175],
#    'bts:chembl': ['CHEMBL126955'],
#    'bts:drugbank': [],
#    'bts:unii': [],
#    'bts:mesh': []},
#   'chembl:CHEMBL65': {'bts:inchi': ['InChI=1S/C20H16N2O4/c1-2-20(25)14-8-16-17-12(7-11-5-3-4-6-15(11)21-17)9-22(16)18(23)13(14)10-26-19(20)24/h3-8,25H,2,9-10H2,1H3/t20-/m0/s1'],
#    'bts:inchikey': ['VSJKWCGYPAHWDS-FQEVSTJZSA-N'],
#    'bts:rxcui': [],
#    'bts:smiles': ['CC[C@@]1(O)C(=O)OCC2=C1C=C3N(Cc4cc5ccccc5nc34)C2=O'],
#    'bts:pubchem': [24360],
#    'bts:chembl': ['CHEMBL65'],
#    'bts:drugbank': ['DB04690'],
#    'bts:unii': ['XT3Z54Z28A'],
#    'bts:mesh': ['D002166']},
#   'chembl:CHEMBL384467': {'bts:inchi': ['InChI=1S/C22H29FO5/c1-12-8-16-15-5-4-13-9-14(25)6-7-19(13,2)21(15,23)17(26)10-20(16,3)22(12,28)18(27)11-24/h6-7,9,12,15-17,24,26,28H,4-5,8,10-11H2,1-3H3/t12-,15+,16+,17+,19+,20+,21+,22+/m1/s1'],
#    'bts:inchikey': ['UREBDLICKHMUKA-CXSFZGCWSA-N'],
#    'bts:rxcui': ['3264'],
#    'bts:smiles': ['C[C@@H]1C[C@H]2[C@@H]3CCC4=CC(=O)C=C[C@]4(C)[C@@]3(F)[C@@H](O)C[C@]2(C)[C@@]1(O)C(=O)CO'],
#    'bts:pubchem': [5743],
#    'bts:chembl': ['CHEMBL384467'],
#    'bts:drugbank': ['DB01234'],
#    'bts:unii': ['7S5I7G3JQL'],
#    'bts:mesh': ['D003907']},
#   'chembl:CHEMBL488436': {'bts:inchi': ['InChI=1S/C18H21N5O2S/c1-12(2)23-13(3)20-11-17(23)16-9-10-19-18(22-16)21-14-5-7-15(8-6-14)26(4,24)25/h5-12H,1-4H3,(H,19,21,22)'],
#    'bts:inchikey': ['WJRRGYBTGDJBFX-UHFFFAOYSA-N'],
#    'bts:rxcui': [],
#    'bts:smiles': ['CC(C)n1c(C)ncc1c2ccnc(Nc3ccc(cc3)S(=O)(=O)C)n2'],
#    'bts:pubchem': [16747683],
#    'bts:chembl': ['CHEMBL488436'],
#    'bts:drugbank': [],
#    'bts:unii': ['276Z913G29'],
#    'bts:mesh': []},
#   'chembl:CHEMBL1230607': {'bts:inchi': ['InChI=1S/C19H31N5O2/c1-12(2)10-15(25)20-17-14-11-24(19(3,4)16(14)21-22-17)18(26)13-6-8-23(5)9-7-13/h12-13H,6-11H2,1-5H3,(H2,20,21,22,25)'],
#    'bts:inchikey': ['HUXYBQXJVXOMKX-UHFFFAOYSA-N'],
#    'bts:rxcui': [],
#    'bts:smiles': ['CC(C)CC(=O)Nc1n[nH]c2c1CN(C(=O)C3CCN(C)CC3)C2(C)C'],
#    'bts:pubchem': [46191454],
#    'bts:chembl': ['CHEMBL1230607'],
#    'bts:drugbank': ['DB12686'],
#    'bts:unii': ['MKS45S912B'],
#    'bts:mesh': []},
#   'chembl:CHEMBL384304': {'bts:inchi': ['InChI=1S/C18H21F2N5O4S/c1-29-13-4-3-12(19)15(20)14(13)16(26)11-9-22-18(24-17(11)21)23-10-5-7-25(8-6-10)30(2,27)28/h3-4,9-10H,5-8H2,1-2H3,(H3,21,22,23,24)'],
#    'bts:inchikey': ['JRNJNYBQQYBCLE-UHFFFAOYSA-N'],
#    'bts:rxcui': [],
#    'bts:smiles': ['COc1ccc(F)c(F)c1C(=O)c2cnc(NC3CCN(CC3)S(=O)(=O)C)nc2N'],
#    'bts:pubchem': [6918852],
#    'bts:chembl': ['CHEMBL384304'],
#    'bts:drugbank': ['DB08094'],
#    'bts:unii': ['T61871RKRI'],
#    'bts:mesh': []},
#   'chembl:CHEMBL3544940': {'bts:inchi': [],
#    'bts:inchikey': [],
#    'bts:rxcui': [],
#    'bts:smiles': [],
#    'bts:pubchem': [],
#    'bts:chembl': ['CHEMBL3544940'],
#    'bts:drugbank': [],
#    'bts:unii': [],
#    'bts:mesh': []},
#   'chembl:CHEMBL3545218': {'bts:inchi': [],
#    'bts:inchikey': [],
#    'bts:rxcui': [],
#    'bts:smiles': [],
#    'bts:pubchem': [],
#    'bts:chembl': ['CHEMBL3545218'],
#    'bts:drugbank': [],
#    'bts:unii': [],
#    'bts:mesh': []},
#   'chembl:CHEMBL514800': {'bts:inchi': ['InChI=1S/C22H24N2O7S/c1-5-31-19-11-14(9-10-18(19)30-3)17(12-32(4,28)29)24-21(26)15-7-6-8-16(23-13(2)25)20(15)22(24)27/h6-11,17H,5,12H2,1-4H3,(H,23,25)/t17-/m1/s1'],
#    'bts:inchikey': ['IMOZEMNVLZVGJZ-QGZVFWFLSA-N'],
#    'bts:rxcui': ['1492727'],
#    'bts:smiles': ['CCOc1cc(ccc1OC)[C@@H](CS(=O)(=O)C)N2C(=O)c3cccc(NC(=O)C)c3C2=O'],
#    'bts:pubchem': [11561674],
#    'bts:chembl': ['CHEMBL514800'],
#    'bts:drugbank': ['DB05676'],
#    'bts:unii': ['UP7QBP99PN'],
#    'bts:mesh': ['C505730']},
#   'chembl:CHEMBL52885': {'bts:inchi': ['InChI=1S/C22H16N4O4/c1-24-10-15(13-5-3-4-6-17(13)24)19-20(22(28)23-21(19)27)16-11-25(2)18-9-12(26(29)30)7-8-14(16)18/h3-11H,1-2H3,(H,23,27,28)'],
#    'bts:inchikey': ['OVSKGTONMLKNPZ-UHFFFAOYSA-N'],
#    'bts:rxcui': [],
#    'bts:smiles': ['Cn1cc(C2=C(C(=O)NC2=O)c3cn(C)c4cc(ccc34)[N+](=O)[O-])c5ccccc15'],
#    'bts:pubchem': [5327686],
#    'bts:chembl': ['CHEMBL52885'],
#    'bts:drugbank': ['DB05608'],
#    'bts:unii': ['DNZ11VPY7Q'],
#    'bts:mesh': []},
#   'chembl:CHEMBL3545420': {'bts:inchi': ['InChI=1S/C23H20F2N6/c1-3-26-9-14-10-27-11-17(12(14)2)13-4-5-19-16(6-13)21(31-30-19)23-28-20-8-15(24)7-18(25)22(20)29-23/h4-8,10-11,26,30-31H,3,9H2,1-2H3/b23-21+'],
#    'bts:inchikey': ['RBOKLZGCVRXGEP-XTQSDGFTSA-N'],
#    'bts:rxcui': [],
#    'bts:smiles': ['CCNCc1cncc(c1C)c2ccc3NN\\C(=C\\4/N=C5C=C(F)C=C(F)C5=N4)\\c3c2'],
#    'bts:pubchem': [],
#    'bts:chembl': ['CHEMBL3545420'],
#    'bts:drugbank': [],
#    'bts:unii': [],
#    'bts:mesh': []},
#   'chembl:CHEMBL3707266': {'bts:inchi': ['InChI=1S/C23H30N8O.C4H6O4/c1-29(2)22(32)19-13-16-14-26-23(28-21(16)31(19)17-5-3-4-6-17)27-20-8-7-18(15-25-20)30-11-9-24-10-12-30;5-3(6)1-2-4(7)8/h7-8,13-15,17,24H,3-6,9-12H2,1-2H3,(H,25,26,27,28);1-2H2,(H,5,6)(H,7,8)'],
#    'bts:inchikey': ['NHANOMFABJQAAH-UHFFFAOYSA-N'],
#    'bts:rxcui': [],
#    'bts:smiles': ['CN(C)C(=O)c1cc2cnc(Nc3ccc(cn3)N4CCNCC4)nc2n1C5CCCC5.OC(=O)CCC(=O)O'],
#    'bts:pubchem': [57334219],
#    'bts:chembl': ['CHEMBL3707266'],
#    'bts:drugbank': [],
#    'bts:unii': ['BG7HLX2919'],
#    'bts:mesh': []},
#   'chembl:CHEMBL3': {'bts:inchi': ['InChI=1S/C10H14N2/c1-12-7-3-5-10(12)9-4-2-6-11-8-9/h2,4,6,8,10H,3,5,7H2,1H3/t10-/m0/s1'],
#    'bts:inchikey': ['SNICXCGAKADSCV-JTQLQIEISA-N'],
#    'bts:rxcui': ['7407'],
#    'bts:smiles': ['CN1CCC[C@H]1c2cccnc2'],
#    'bts:pubchem': [89594],
#    'bts:chembl': ['CHEMBL3'],
#    'bts:drugbank': ['DB00184'],
#    'bts:unii': ['6M3C89ZY6R'],
#    'bts:mesh': ['D061485', 'D009538']},
#   'chembl:CHEMBL103': {'bts:inchi': ['InChI=1S/C21H30O2/c1-13(22)17-6-7-18-16-5-4-14-12-15(23)8-10-20(14,2)19(16)9-11-21(17,18)3/h12,16-19H,4-11H2,1-3H3/t16-,17+,18-,19-,20-,21+/m0/s1'],
#    'bts:inchikey': ['RJKFOVLPORLFTN-LEKSSAKUSA-N'],
#    'bts:rxcui': ['8727'],
#    'bts:smiles': ['CC(=O)[C@H]1CC[C@H]2[C@@H]3CCC4=CC(=O)CC[C@]4(C)[C@H]3CC[C@]12C'],
#    'bts:pubchem': [5994],
#    'bts:chembl': ['CHEMBL103'],
#    'bts:drugbank': ['DB00396'],
#    'bts:unii': ['4G7DS2Q64Y'],
#    'bts:mesh': ['C400424', 'D011374']},
#   'chembl:CHEMBL196': {'bts:inchi': ['InChI=1S/C6H8O6/c7-1-2(8)5-3(9)4(10)6(11)12-5/h2,5,7-10H,1H2/t2-,5+/m0/s1'],
#    'bts:inchikey': ['CIWBSHSKHKDKBQ-JLAZNSOCSA-N'],
#    'bts:rxcui': ['1151'],
#    'bts:smiles': ['OC[C@H](O)[C@H]1OC(=O)C(=C1O)O'],
#    'bts:pubchem': [54670067],
#    'bts:chembl': ['CHEMBL196'],
#    'bts:drugbank': ['DB00126'],
#    'bts:unii': ['PQ6CK8PD0R'],
#    'bts:mesh': ['D001205']},
#   'chembl:CHEMBL2403108': {'bts:inchi': ['InChI=1S/C28H36ClN5O3S/c1-17(2)37-25-15-21(20-10-12-30-13-11-20)19(5)14-24(25)33-28-31-16-22(29)27(34-28)32-23-8-6-7-9-26(23)38(35,36)18(3)4/h6-9,14-18,20,30H,10-13H2,1-5H3,(H2,31,32,33,34)'],
#    'bts:inchikey': ['VERWOWGGCGHDQE-UHFFFAOYSA-N'],
#    'bts:rxcui': ['1535457'],
#    'bts:smiles': ['CC(C)Oc1cc(C2CCNCC2)c(C)cc1Nc3ncc(Cl)c(Nc4ccccc4S(=O)(=O)C(C)C)n3'],
#    'bts:pubchem': [57379345],
#    'bts:chembl': ['CHEMBL2403108'],
#    'bts:drugbank': ['DB09063'],
#    'bts:unii': ['K418KG2GET'],
#    'bts:mesh': []},
#   'chembl:CHEMBL91829': {'bts:inchi': ['InChI=1S/C28H28N4O3/c1-30(2)15-18-11-12-31-16-21(19-7-3-5-9-23(19)31)25-26(28(34)29-27(25)33)22-17-32(13-14-35-18)24-10-6-4-8-20(22)24/h3-10,16-18H,11-15H2,1-2H3,(H,29,33,34)/t18-/m0/s1'],
#    'bts:inchikey': ['ZCBUQCWBWNUWSU-SFHVURJKSA-N'],
#    'bts:rxcui': [],
#    'bts:smiles': ['CN(C)C[C@@H]1CCn2cc(C3=C(C(=O)NC3=O)c4cn(CCO1)c5ccccc45)c6ccccc26'],
#    'bts:pubchem': [153999],
#    'bts:chembl': ['CHEMBL91829'],
#    'bts:drugbank': ['DB11829'],
#    'bts:unii': ['721809WQCP'],
#    'bts:mesh': ['C099154']},
#   'chembl:CHEMBL50': {'bts:inchi': ['InChI=1S/C15H10O7/c16-7-4-10(19)12-11(5-7)22-15(14(21)13(12)20)6-1-2-8(17)9(18)3-6/h1-5,16-19,21H'],
#    'bts:inchikey': ['REFJWTPEDVJJIY-UHFFFAOYSA-N'],
#    'bts:rxcui': ['9060'],
#    'bts:smiles': ['OC1=C(Oc2cc(O)cc(O)c2C1=O)c3ccc(O)c(O)c3'],
#    'bts:pubchem': [5280343],
#    'bts:chembl': ['CHEMBL50'],
#    'bts:drugbank': ['DB04216'],
#    'bts:unii': ['9IKM0I5T1E'],
#    'bts:mesh': ['D011794', 'C401828']},
#   'chembl:CHEMBL502835': {'bts:inchi': ['InChI=1S/C31H33N5O4/c1-34-15-17-36(18-16-34)20-27(37)35(2)24-12-10-23(11-13-24)32-29(21-7-5-4-6-8-21)28-25-14-9-22(31(39)40-3)19-26(25)33-30(28)38/h4-14,19,32H,15-18,20H2,1-3H3,(H,33,38)/b29-28-'],
#    'bts:inchikey': ['XZXHXSATPCNXJR-ZIADKAODSA-N'],
#    'bts:rxcui': ['1592737'],
#    'bts:smiles': ['COC(=O)c1ccc2\\C(=C(\\Nc3ccc(cc3)N(C)C(=O)CN4CCN(C)CC4)/c5ccccc5)\\C(=O)Nc2c1'],
#    'bts:pubchem': [],
#    'bts:chembl': ['CHEMBL502835'],
#    'bts:drugbank': ['DB09079'],
#    'bts:unii': ['G6HRD2P839'],
#    'bts:mesh': ['C530716']},
#   'chembl:CHEMBL535': {'bts:inchi': ['InChI=1S/C22H27FN4O2/c1-5-27(6-2)10-9-24-22(29)20-13(3)19(25-14(20)4)12-17-16-11-15(23)7-8-18(16)26-21(17)28/h7-8,11-12,25H,5-6,9-10H2,1-4H3,(H,24,29)(H,26,28)/b17-12-'],
#    'bts:inchikey': ['WINHZLLDWRZWRT-ATVHPVEESA-N'],
#    'bts:rxcui': ['357977'],
#    'bts:smiles': ['CCN(CC)CCNC(=O)c1c(C)[nH]c(\\C=C\\2/C(=O)Nc3ccc(F)cc23)c1C'],
#    'bts:pubchem': [5329102],
#    'bts:chembl': ['CHEMBL535'],
#    'bts:drugbank': ['DB01268'],
#    'bts:unii': ['V99T50803M'],
#    'bts:mesh': ['C473478']},
#   'umls:C0005456': {'bts:umls': ['C0005456']},
#   'umls:C0007090': {'bts:umls': ['C0007090']},
#   'umls:C0013227': {'bts:umls': ['C0013227']},
#   'umls:C0016360': {'bts:umls': ['C0016360']},
#   'umls:C0017725': {'bts:umls': ['C0017725']},
#   'umls:C0018282': {'bts:umls': ['C0018282']},
#   'umls:C0034243': {'bts:umls': ['C0034243']},
#   'umls:C0036681': {'bts:umls': ['C0036681']},
#   'umls:C0038317': {'bts:umls': ['C0038317']},
#   'umls:C0040845': {'bts:umls': ['C0040845']},
#   'umls:C0073096': {'bts:umls': ['C0073096']},
#   'umls:C0144576': {'bts:umls': ['C0144576']},
#   'umls:C0243077': {'bts:umls': ['C0243077']},
#   'umls:C0608663': {'bts:umls': ['C0608663']},
#   'umls:C0661318': {'bts:umls': ['C0661318']},
#   'umls:C0662253': {'bts:umls': ['C0662253']},
#   'umls:C0675974': {'bts:umls': ['C0675974']},
#   'umls:C0729218': {'bts:umls': ['C0729218']},
#   'umls:C0962559': {'bts:umls': ['C0962559']},
#   'umls:C1101610': {'bts:umls': ['C1101610']},
#   'umls:C1518434': {'bts:umls': ['C1518434']},
#   'umls:C1522485': {'bts:umls': ['C1522485']},
#   'umls:C1568660': {'bts:umls': ['C1568660']},
#   'umls:C0001455': {'bts:umls': ['C0001455']},
#   'umls:C0011777': {'bts:umls': ['C0011777']},
#   'umls:C0012854': {'bts:umls': ['C0012854']},
#   'umls:C0013879': {'bts:umls': ['C0013879']},
#   'umls:C0034760': {'bts:umls': ['C0034760']},
#   'umls:C0042866': {'bts:umls': ['C0042866']},
#   'umls:C0061202': {'bts:umls': ['C0061202']},
#   'umls:C0061275': {'bts:umls': ['C0061275']},
#   'umls:C0062565': {'bts:umls': ['C0062565']},
#   'umls:C0074554': {'bts:umls': ['C0074554']},
#   'umls:C0085170': {'bts:umls': ['C0085170']},
#   'umls:C0220806': {'bts:umls': ['C0220806']},
#   'umls:C0245514': {'bts:umls': ['C0245514']},
#   'umls:C0289993': {'bts:umls': ['C0289993']},
#   'umls:C0309049': {'bts:umls': ['C0309049']},
#   'umls:C0309276': {'bts:umls': ['C0309276']},
#   'umls:C0450442': {'bts:umls': ['C0450442']},
#   'umls:C0600334': {'bts:umls': ['C0600334']},
#   'umls:C0950779': {'bts:umls': ['C0950779']},
#   'umls:C1099354': {'bts:umls': ['C1099354']},
#   'umls:C1171350': {'bts:umls': ['C1171350']},
#   'chembl:CHEMBL2103830': {'bts:inchi': ['InChI=1S/C23H26FN6O9P/c1-23(2)21(31)30(11-38-40(32,33)34)20-14(39-23)6-7-17(28-20)27-19-13(24)10-25-22(29-19)26-12-8-15(35-3)18(37-5)16(9-12)36-4/h6-10H,11H2,1-5H3,(H2,32,33,34)(H2,25,26,27,28,29)'],
#    'bts:inchikey': ['GKDRMWXFWHEQQT-UHFFFAOYSA-N'],
#    'bts:rxcui': [],
#    'bts:smiles': ['COc1cc(Nc2ncc(F)c(Nc3ccc4OC(C)(C)C(=O)N(COP(=O)(O)O)c4n3)n2)cc(OC)c1OC'],
#    'bts:pubchem': [11671467],
#    'bts:chembl': ['CHEMBL2103830'],
#    'bts:drugbank': ['DB12010'],
#    'bts:unii': ['SQ8A3S5101'],
#    'bts:mesh': ['C523665']}}}

# %% [markdown]
# #### Dig deep into the network

# %%
# List all nodes
seqd.show_all_nodes()
# Out:
# ['1019',
#  'CHEMBL3301610',
#  'CHEMBL189963',
#  'CHEMBL564829',
#  'CHEMBL3544942',
#  'CHEMBL574737',
#  'CHEMBL428690',
#  'CHEMBL445813',
#  'CHEMBL1802728',
#  'CHEMBL602937',
#  'CHEMBL448',
#  'CHEMBL23327',
#  'CHEMBL23254',
#  'CHEMBL3545083',
#  'CHEMBL3545110',
#  'CHEMBL3545283',
#  'CHEMBL1956070',
#  'CHEMBL258805',
#  'CHEMBL126955',
#  'CHEMBL65',
#  'CHEMBL384467',
#  'CHEMBL488436',
#  'CHEMBL1230607',
#  'CHEMBL384304',
#  'CHEMBL3544940',
#  'CHEMBL3545218',
#  'CHEMBL514800',
#  'CHEMBL52885',
#  'CHEMBL3545420',
#  'CHEMBL3707266',
#  'CHEMBL3',
#  'CHEMBL103',
#  'CHEMBL196',
#  'CHEMBL2403108',
#  'CHEMBL91829',
#  'CHEMBL50',
#  'CHEMBL502835',
#  'CHEMBL535',
#  'C0005456',
#  'C0007090',
#  'C0013227',
#  'C0016360',
#  'C0017725',
#  'C0018282',
#  'C0034243',
#  'C0036681',
#  'C0038317',
#  'C0040845',
#  'C0073096',
#  'C0144576',
#  'C0243077',
#  'C0608663',
#  'C0661318',
#  'C0662253',
#  'C0675974',
#  'C0729218',
#  'C0962559',
#  'C1101610',
#  'C1518434',
#  'C1522485',
#  'C1568660',
#  'C0001455',
#  'C0011777',
#  'C0012854',
#  'C0013879',
#  'C0034760',
#  'C0042866',
#  'C0061202',
#  'C0061275',
#  'C0062565',
#  'C0074554',
#  'C0085170',
#  'C0220806',
#  'C0245514',
#  'C0289993',
#  'C0309049',
#  'C0309276',
#  'C0450442',
#  'C0600334',
#  'C0950779',
#  'C1099354',
#  'C1171350',
#  'CHEMBL2103830']

# %%
# list all edges
seqd.show_all_edges()
# Out:
# [('1019', 'CHEMBL3301610'),
#  ('1019', 'CHEMBL3301610'),
#  ('1019', 'CHEMBL3301610'),
#  ('1019', 'CHEMBL189963'),
#  ('1019', 'CHEMBL189963'),
#  ('1019', 'CHEMBL189963'),
#  ('1019', 'CHEMBL564829'),
#  ('1019', 'CHEMBL3544942'),
#  ('1019', 'CHEMBL574737'),
#  ('1019', 'CHEMBL428690'),
#  ('1019', 'CHEMBL428690'),
#  ('1019', 'CHEMBL445813'),
#  ('1019', 'CHEMBL1802728'),
#  ('1019', 'CHEMBL602937'),
#  ('1019', 'CHEMBL448'),
#  ('1019', 'CHEMBL23327'),
#  ('1019', 'CHEMBL23254'),
#  ('1019', 'CHEMBL23254'),
#  ('1019', 'CHEMBL3545083'),
#  ('1019', 'CHEMBL3545110'),
#  ('1019', 'CHEMBL3545110'),
#  ('1019', 'CHEMBL3545110'),
#  ('1019', 'CHEMBL3545283'),
#  ('1019', 'CHEMBL1956070'),
#  ('1019', 'CHEMBL258805'),
#  ('1019', 'CHEMBL126955'),
#  ('1019', 'CHEMBL65'),
#  ('1019', 'CHEMBL384467'),
#  ('1019', 'CHEMBL488436'),
#  ('1019', 'CHEMBL1230607'),
#  ('1019', 'CHEMBL384304'),
#  ('1019', 'CHEMBL3544940'),
#  ('1019', 'CHEMBL3545218'),
#  ('1019', 'CHEMBL514800'),
#  ('1019', 'CHEMBL52885'),
#  ('1019', 'CHEMBL3545420'),
#  ('1019', 'CHEMBL3707266'),
#  ('1019', 'CHEMBL3'),
#  ('1019', 'CHEMBL103'),
#  ('1019', 'CHEMBL196'),
#  ('1019', 'CHEMBL2403108'),
#  ('1019', 'CHEMBL91829'),
#  ('1019', 'CHEMBL50'),
#  ('1019', 'CHEMBL502835'),
#  ('1019', 'CHEMBL535'),
#  ('1019', 'C0005456'),
#  ('1019', 'C0007090'),
#  ('1019', 'C0007090'),
#  ('1019', 'C0007090'),
#  ('1019', 'C0007090'),
#  ('1019', 'C0013227'),
#  ('1019', 'C0013227'),
#  ('1019', 'C0013227'),
#  ('1019', 'C0013227'),
#  ('1019', 'C0016360'),
#  ('1019', 'C0016360'),
#  ('1019', 'C0017725'),
#  ('1019', 'C0018282'),
#  ('1019', 'C0034243'),
#  ('1019', 'C0034243'),
#  ('1019', 'C0036681'),
#  ('1019', 'C0038317'),
#  ('1019', 'C0040845'),
#  ('1019', 'C0040845'),
#  ('1019', 'C0040845'),
#  ('1019', 'C0073096'),
#  ('1019', 'C0144576'),
#  ('1019', 'C0144576'),
#  ('1019', 'C0243077'),
#  ('1019', 'C0243077'),
#  ('1019', 'C0243077'),
#  ('1019', 'C0608663'),
#  ('1019', 'C0661318'),
#  ('1019', 'C0662253'),
#  ('1019', 'C0675974'),
#  ('1019', 'C0729218'),
#  ('1019', 'C0962559'),
#  ('1019', 'C1101610'),
#  ('1019', 'C1101610'),
#  ('1019', 'C1518434'),
#  ('1019', 'C1522485'),
#  ('1019', 'C1568660'),
#  ('1019', 'C1568660'),
#  ('1019', 'C1568660'),
#  ('1019', 'C0001455'),
#  ('1019', 'C0001455'),
#  ('1019', 'C0011777'),
#  ('1019', 'C0012854'),
#  ('1019', 'C0012854'),
#  ('1019', 'C0013879'),
#  ('1019', 'C0013879'),
#  ('1019', 'C0034760'),
#  ('1019', 'C0042866'),
#  ('1019', 'C0061202'),
#  ('1019', 'C0061202'),
#  ('1019', 'C0061275'),
#  ('1019', 'C0062565'),
#  ('1019', 'C0074554'),
#  ('1019', 'C0085170'),
#  ('1019', 'C0220806'),
#  ('1019', 'C0220806'),
#  ('1019', 'C0245514'),
#  ('1019', 'C0289993'),
#  ('1019', 'C0309049'),
#  ('1019', 'C0309276'),
#  ('1019', 'C0309276'),
#  ('1019', 'C0450442'),
#  ('1019', 'C0600334'),
#  ('1019', 'C0950779'),
#  ('1019', 'C1099354'),
#  ('1019', 'C1171350'),
#  ('1019', 'CHEMBL2103830')]

# %%
# see details of a specific edge
seqd.display_edge_info('1019', 'CHEMBL448')
# Out:
# {0: {'info': {'bts:chembl': ['CHEMBL448'],
#    'bts:name': ['PENTOBARBITAL'],
#    'bts:source': ['GuideToPharmacologyInteractions'],
#    '@type': 'ChemicalSubstance',
#    '$input': 'bts:symbol',
#    '$source': 'dgidb'},
#   'label': 'bts:targetedBy',
#   'source': 'dgidb'}}

# %%
# see details of a specific node
seqd.display_node_info('CHEMBL448')
# Out:
# {'identifier': 'bts:chembl',
#  'type': 'ChemicalSubstance',
#  'level': 2,
#  'equivalent_ids': {'bts:inchi': ['InChI=1S/C11H18N2O3/c1-4-6-7(3)11(5-2)8(14)12-10(16)13-9(11)15/h7H,4-6H2,1-3H3,(H2,12,13,14,15,16)'],
#   'bts:inchikey': ['WEXRUCMBJFQVBZ-UHFFFAOYSA-N'],
#   'bts:rxcui': [],
#   'bts:smiles': ['CCCC(C)C1(CC)C(=O)NC(=O)NC1=O'],
#   'bts:pubchem': [4737],
#   'bts:chembl': ['CHEMBL448'],
#   'bts:drugbank': ['DB00312'],
#   'bts:unii': [],
#   'bts:mesh': ['D010424']}}

# %% [markdown]
# ### (Optional) Do it the hard way

# %% [markdown]
# You can still use this tool without the hint module. In this case, specify your parameters as the following:
# 1. input_cls: required, The semantic type of your input
# 2. input_id: required, The identifier type of your input
# 3. values: required, The input value
# 4. output_cls: required, The semantic type of your output
# 5. output_id: optional, the identifier type of your output

# %%
seqd = SingleEdgeQueryDispatcher(input_cls="Gene",
                                 input_id="bts:entrez",
                                 values="1019",
                                 output_cls="ChemicalSubstance",
                                 output_id="bts:chembl",
                                 registry=reg)
seqd.query()

# %%
seqd.G.nodes()
# Out:
# NodeView(('1019', 'CHEMBL3301610', 'CHEMBL189963', 'CHEMBL564829', 'CHEMBL3544942', 'CHEMBL574737', 'CHEMBL428690', 'CHEMBL445813', 'CHEMBL1802728', 'CHEMBL602937', 'CHEMBL448', 'CHEMBL23327', 'CHEMBL23254', 'CHEMBL3545083', 'CHEMBL3545110', 'CHEMBL3545283', 'CHEMBL1956070', 'CHEMBL258805', 'CHEMBL126955', 'CHEMBL65', 'CHEMBL384467', 'CHEMBL488436', 'CHEMBL1230607', 'CHEMBL384304', 'CHEMBL3544940', 'CHEMBL3545218', 'CHEMBL514800', 'CHEMBL52885', 'CHEMBL3545420', 'CHEMBL3707266', 'CHEMBL3', 'CHEMBL103', 'CHEMBL196', 'CHEMBL2403108', 'CHEMBL91829', 'CHEMBL50', 'CHEMBL502835', 'CHEMBL535', 'C0005456', 'C0007090', 'C0013227', 'C0016360', 'C0017725', 'C0018282', 'C0034243', 'C0036681', 'C0038317', 'C0040845', 'C0073096', 'C0144576', 'C0243077', 'C0608663', 'C0661318', 'C0662253', 'C0675974', 'C0729218', 'C0962559', 'C1101610', 'C1518434', 'C1522485', 'C1568660', 'C0001455', 'C0011777', 'C0012854', 'C0013879', 'C0034760', 'C0042866', 'C0061202', 'C0061275', 'C0062565', 'C0074554', 'C0085170', 'C0220806', 'C0245514', 'C0289993', 'C0309049', 'C0309276', 'C0450442', 'C0600334', 'C0950779', 'C1099354', 'C1171350', 'CHEMBL2103830'))

# %% [markdown]
# ## Feature 2: Multi Hop Query

# %% [markdown]
# Query from a specific biological entity (e.g. entrezgene 1017) to other semantic types (e.g. ChemicalSubstance) through multiple hops, e.g. ChemicalSubstance -> Gene -> Disease

# %%
# Initiate the multi hop module
from biothings_explorer.user_query_dispatcher import MultiEdgeQueryDispatcher

# %% [markdown]
# ### The tutorial below create edges from Riluzole(ChemicalSubstance) to Gene, then to Disease, which is to first find genes related to riluzole, and then find diseases related to genes

# %% [markdown]
# ### Step1: Decide on your input

# %%
a = ht.query('riluzole')
a
# Out:
# {'Gene': [],
#  'SequenceVariant': [],
#  'ChemicalSubstance': [{'chembl': 'CHEMBL744',
#    'drugbank': 'DB00740',
#    'name': 'RILUZOLE',
#    'pubchem': 5070,
#    'display': 'chembl(CHEMBL744) drugbank(DB00740) name(RILUZOLE) pubchem(5070) ',
#    'type': 'ChemicalSubstance',
#    'primary': {'identifier': 'chembl',
#     'cls': 'ChemicalSubstance',
#     'value': 'CHEMBL744'}},
#   {'name': 'Riluzole',
#    'umls': 'C0073379',
#    'display': 'name(Riluzole) umls(C0073379) ',
#    'type': 'ChemicalSubstance',
#    'primary': {'identifier': 'umls',
#     'cls': 'ChemicalSubstance',
#     'value': 'C0073379'}}],
#  'DiseaseOrPhenotypicFeature': [],
#  'Pathway': [],
#  'MolecularFunction': [],
#  'CellularComponent': [],
#  'BiologicalProcess': [],
#  'Anatomy': [],
#  'PhenotypicFeature': []}

# %%
input_obj = a['ChemicalSubstance'][0]
input_obj
# Out:
# {'chembl': 'CHEMBL744',
#  'drugbank': 'DB00740',
#  'name': 'RILUZOLE',
#  'pubchem': 5070,
#  'display': 'chembl(CHEMBL744) drugbank(DB00740) name(RILUZOLE) pubchem(5070) ',
#  'type': 'ChemicalSubstance',
#  'primary': {'identifier': 'chembl',
#   'cls': 'ChemicalSubstance',
#   'value': 'CHEMBL744'}}

# %% [markdown]
# ### Step2: Construct your edges

# %% [markdown]
# the format of edges should be like [(subject1, pred1, object1), (subject2, pred2, object2), ...]
#
# The object of an edge should always be the same as the subject of its proceeding edge

# %% [markdown]
# Note: You can leave pred as None. In this case, the tool will search for all potential edges

# %%
edges = [('ChemicalSubstance', None, 'Gene'), ('Gene', None, 'DiseaseOrPhenotypicFeature')]

# %% [markdown]
# ### Step3: Execute the query

# %%
meqd = MultiEdgeQueryDispatcher(input_obj=input_obj,
                                edges=edges,
                                registry=reg)

# %%
meqd.query()
# Out:
# start to query for associations between ChemicalSubstance and Gene...
# finished! Find 23 hits.
# start to query for associations between Gene and DiseaseOrPhenotypicFeature...
# finished! Find 741 hits.

# %% [markdown]
# ### Step4: Explore the results

# %%
# show all nodes in the graph
meqd.show_all_nodes()
# Out:
# ['CHEMBL744',
#  '6331',
#  '23657',
#  '50801',
#  '3780',
#  '3783',
#  '6329',
#  '6334',
#  '6335',
#  '6336',
#  '6332',
#  '6326',
#  '6323',
#  '11280',
#  '6328',
#  '1083',
#  'PTR1',
#  '3782',
#  '6530',
#  '116443',
#  '3781',
#  '1544',
#  '1543',
#  'MONDO:0001823',
#  'MONDO:0004981',
#  'MONDO:0016333',
#  'MONDO:0010086',
#  'MONDO:0019171',
#  'MONDO:0008685',
#  'MONDO:0015470',
#  'MONDO:0015263',
#  'MONDO:0015281',
#  'MONDO:0018054',
#  'MONDO:0024562',
#  'MONDO:0011376',
#  'MONDO:0011377',
#  'MONDO:0011003',
#  'MONDO:0011001',
#  'MONDO:0012061',
#  'MONDO:0013530',
#  'MONDO:0019490',
#  'MONDO:0007240',
#  'MONDO:0008646',
#  'C0340493',
#  'C0264913',
#  'C1842820',
#  'C1861983',
#  'C1861984',
#  'C0085610',
#  'C0151636',
#  'C0232216',
#  'C2752013',
#  'C0151878',
#  'C1832603',
#  'C0011071',
#  'C1861987',
#  'C0600228',
#  'C2748542',
#  'C0007820',
#  'C0264912',
#  'C0085615',
#  'C0030252',
#  'C0264886',
#  'C0235480',
#  'C0039070',
#  'C0013404',
#  'C0023211',
#  'C1843738',
#  'C2931401',
#  'C0003811',
#  'C1859062',
#  'C3276240',
#  'C1838527',
#  'C0855329',
#  'C1841659',
#  'C0522055',
#  'C4025008',
#  'C0040479',
#  'C3809288',
#  'C4020899',
#  'C0027627',
#  'MONDO:0004989',
#  'MONDO:0017910',
#  'MONDO:0014737',
#  'C0038002',
#  'C0019209',
#  'C0022346',
#  'C0311468',
#  'C1863769',
#  'C0206160',
#  'C2675920',
#  'MONDO:0018940',
#  'MONDO:0042979',
#  'MONDO:0020483',
#  'MONDO:0020482',
#  'MONDO:0020481',
#  'MONDO:0020344',
#  'MONDO:0013620',
#  'MONDO:0013234',
#  'MONDO:0008224',
#  'MONDO:0008223',
#  'MONDO:0008195',
#  'C2931826',
#  'C4022754',
#  'C0237304',
#  'C0221055',
#  'C0162292',
#  'C0232466',
#  'C4020730',
#  'C0151576',
#  'C1854301',
#  'C1855580',
#  'C2265792',
#  'C1850309',
#  'C0026821',
#  'C4021553',
#  'C1850667',
#  'C1861403',
#  'C1868623',
#  'C0947912',
#  'C3807980',
#  'C4023179',
#  'C1866210',
#  'C0677600',
#  'C1866934',
#  'C4025572',
#  'C3714580',
#  'C0238358',
#  'C1279412',
#  'C1837514',
#  'C1866862',
#  'C0751883',
#  'C3502630',
#  'C1848924',
#  'C0751359',
#  'C4020874',
#  'C0020461',
#  'C0011168',
#  'C0027125',
#  'C0424585',
#  'C0015644',
#  'C0151786',
#  'C1855520',
#  'C0221170',
#  'C0026826',
#  'C0020621',
#  'C0038450',
#  'C0476403',
#  'C1868433',
#  'C1839039',
#  'C0575081',
#  'C1837098',
#  'C0008031',
#  'C0231528',
#  'MONDO:0016021',
#  'MONDO:0005414',
#  'MONDO:0017615',
#  'MONDO:0011178',
#  'MONDO:0013801',
#  'MONDO:0013680',
#  'MONDO:0014903',
#  'MONDO:0018614',
#  'C0036572',
#  'C0025362',
#  'C0683322',
#  'C0543888',
#  'C0744641',
#  'C0013384',
#  'C0234967',
#  'C0234428',
#  'C0004134',
#  'C1855019',
#  'C1850493',
#  'C0423224',
#  'C0026827',
#  'C1833488',
#  'C0085583',
#  'C1864897',
#  'C1855009',
#  'C1857121',
#  'C0751495',
#  'C0005586',
#  'C0040822',
#  'C0557874',
#  'C0338656',
#  'C0027066',
#  'C1859678',
#  'C0270851',
#  'C4025846',
#  'C4020876',
#  'C1855996',
#  'C1843146',
#  'C0392699',
#  'C1836174',
#  'C4020875',
#  'C1850456',
#  'C0917816',
#  'C1836830',
#  'C0424688',
#  'C0234533',
#  'C1836550',
#  'C0019372',
#  'C1843367',
#  'C0007758',
#  'C0423903',
#  'C1851936',
#  'C1527366',
#  'MONDO:0005276',
#  'MONDO:0005090',
#  'MONDO:0000032',
#  'MONDO:0018214',
#  'MONDO:0024309',
#  'MONDO:0011794',
#  'MONDO:0019941',
#  'MONDO:0013470',
#  'MONDO:0017629',
#  'MONDO:0007571',
#  'MONDO:0008179',
#  'MONDO:0009459',
#  'C4021611',
#  'C0016382',
#  'C0428977',
#  'C0038990',
#  'C4023511',
#  'C0752323',
#  'C4021768',
#  'C0700078',
#  'C0270948',
#  'C4025676',
#  'C0027796',
#  'C0015393',
#  'C0270914',
#  'C2930971',
#  'C0917715',
#  'C1858285',
#  'C0011991',
#  'C4021759',
#  'C0030193',
#  'C3551426',
#  'C4021801',
#  'C4021741',
#  'C0042024',
#  'C1833225',
#  'C0237326',
#  'C2364082',
#  'C0494475',
#  'C0234146',
#  'C1860099',
#  'C0014553',
#  'C0349506',
#  'C0233514',
#  'C4020868',
#  'C0241772',
#  'C0426886',
#  'C1857640',
#  'C4021745',
#  'C0151934',
#  'C0020458',
#  'C3151229',
#  'C4025744',
#  'C0222716',
#  'C0234958',
#  'C2751756',
#  'C0024003',
#  'C0700590',
#  'C0014805',
#  'C0018834',
#  'C1837522',
#  'C0151827',
#  'C0344232',
#  'C1849148',
#  'C0033774',
#  'C1854494',
#  'C1837602',
#  'C0041834',
#  'C0344307',
#  'C2674432',
#  'C1836509',
#  'C1843479',
#  'C0150055',
#  'C0039231',
#  'C1855739',
#  'C0278124',
#  'C1857171',
#  'C4025660',
#  'MONDO:0007915',
#  'MONDO:0018319',
#  'MONDO:0014246',
#  'C0020429',
#  'C0018794',
#  'C1853562',
#  'MONDO:0004976',
#  'MONDO:0005488',
#  'MONDO:0005180',
#  'MONDO:0016227',
#  'MONDO:0004985',
#  'MONDO:0005076',
#  'MONDO:0011140',
#  'MONDO:0011904',
#  'MONDO:0013388',
#  'MONDO:0018097',
#  'C0010520',
#  'C0426970',
#  'C4023515',
#  'C0877017',
#  'C4049830',
#  'C0014550',
#  'C0009952',
#  'C0151611',
#  '100379198',
#  'MONDO:0005027',
#  'MONDO:0005579',
#  'MONDO:0005384',
#  'MONDO:0020476',
#  'MONDO:0018925',
#  'MONDO:0011461',
#  'MONDO:0012320',
#  'MONDO:0016532',
#  'MONDO:0017385',
#  'C0154671',
#  'C0456909',
#  'C0018989',
#  'C0235946',
#  'C0270834',
#  'C1850601',
#  'C4020887',
#  'C0238111',
#  'C4020860',
#  'C1837352',
#  'C4023479',
#  'C0234985',
#  'C0856975',
#  'C0149958',
#  'C0424295',
#  'C0085636',
#  'C1457883',
#  'C4048268',
#  'C0001807',
#  'C0595948',
#  'C1836508',
#  'C0375206',
#  'C1847514',
#  'C1846620',
#  'C0270846',
#  'C0424323',
#  'C0271215',
#  'C0006111',
#  'MONDO:0015364',
#  'MONDO:0014247',
#  'MONDO:0014244',
#  'C0013363',
#  'MONDO:0000215',
#  'MONDO:0054776',
#  'MONDO:0033371',
#  'MONDO:0005159',
#  'MONDO:0004975',
#  'C0036341',
#  'MONDO:0011479',
#  'C0011581',
#  'C2063866',
#  'C4021099',
#  'C0011573',
#  'C0085159',
#  'C1535893',
#  'MONDO:0015925',
#  'MONDO:0012727',
#  'MONDO:0008383',
#  'MONDO:0006714',
#  'C0242350',
#  'MONDO:0005258',
#  'MONDO:0005544',
#  'C0333641',
#  'C0273115',
#  'C0023904',
#  'C1852091',
#  'C1961102',
#  'C0751688',
#  'C0018273',
#  'C0041755',
#  'C0023893',
#  'C0085096',
#  'C0005612',
#  'C0086132',
#  'C1527304',
#  'C0003860',
#  'C1449861',
#  'C0011609',
#  'C0018800',
#  'C0000786',
#  'C0011853',
#  'C0039239',
#  'C0345904',
#  'C2239176',
#  'C0242706',
#  'C0028797',
#  'C0740457',
#  'C0026691',
#  'C0270611',
#  'C0015967',
#  'C0235169',
#  'C0741923',
#  'C0233649',
#  'C0028778',
#  'C0476643',
#  'C1155266',
#  'C1306577',
#  'C0016059',
#  'C0085612',
#  'C1395184',
#  'C0232219',
#  'C0428908',
#  'C0006384',
#  'C0277785',
#  'C0085611',
#  'C0861148',
#  'C1457887',
#  'C1442161',
#  'C0685108',
#  'C0340652',
#  'C1519606',
#  'C0007194',
#  'C0410000',
#  'C0560175',
#  'C0442893',
#  'C0520886',
#  'C0752351',
#  'C1335499',
#  'C0544885',
#  'C0699748',
#  'C1140999',
#  'C0687133',
#  'C0242379',
#  'C0600688',
#  'C0858970',
#  'C0021368',
#  'C0035204',
#  'C0151763',
#  'C0232910',
#  'C0555061',
#  'C0012860',
#  'C0518010',
#  'C0596321',
#  'C0858952',
#  'C1504598',
#  'C0178874',
#  'C0596263',
#  'C0241526',
#  'C1511660',
#  'C1527330',
#  'C0687675',
#  'C0281169',
#  'C0242184',
#  'C0020564',
#  'C0007103',
#  'C0242606',
#  'C0035242',
#  'C0596402',
#  'C0235378',
#  'C0040038',
#  'C0043046',
#  'C0152018',
#  'C0025568',
#  'C0598309',
#  'C0036974',
#  'C0442804',
#  'C0596763',
#  'C0004093',
#  'C0879626',
#  'C1510885',
#  'C0443168',
#  'C0027651',
#  'C0013221',
#  'C1285498',
#  'C1516170',
#  'C0231162',
#  'C1287298',
#  'C1397014',
#  'C0683321',
#  'C0857121',
#  'C1320396',
#  'C0456070',
#  'C0220981',
#  'C1518294',
#  'C0015934',
#  'C0038999',
#  'C0598463',
#  'C0010957',
#  'C0235394',
#  'C0429631',
#  'C0391976',
#  'C0162703',
#  'C0015376',
#  'C0459840',
#  'C0024530',
#  'C0237963',
#  'C0036690',
#  'C0745765',
#  'C0029925',
#  'C0010068',
#  'C1512409',
#  'C0079380',
#  'C1290905',
#  'C0037274',
#  'C0558176',
#  'C0038433',
#  'C0012359',
#  'C0242656',
#  'C0332482',
#  'C0001925',
#  'C0241863',
#  'C0221198',
#  'C0013604',
#  'C0260397',
#  'C0741282',
#  'C0522224',
#  'C1260954',
#  'C0023066',
#  'C0086439',
#  'C1113650',
#  'C0422814',
#  'C0238705',
#  'C0497247',
#  'C1512032',
#  'C1522225',
#  'C0153690',
#  'C0263541',
#  'C0856984',
#  'C0342923',
#  'C0205858',
#  'C0008073',
#  'C0814120',
#  'C0162735',
#  'C0038435',
#  'C0027746',
#  'C0333951',
#  'C0151686',
#  'C0598935',
#  'C0021655',
#  'C1156244',
#  'MONDO:0012066',
#  'MONDO:0007171',
#  'MONDO:0005477',
#  'MONDO:0002442',
#  'MONDO:0014163',
#  'MONDO:0005098',
#  'MONDO:0000745',
#  'MONDO:0000465',
#  'MONDO:0011057',
#  'MONDO:0007264',
#  'MONDO:0013367',
#  'MONDO:0007263',
#  'MONDO:0013370',
#  'MONDO:0005310',
#  'MONDO:0005021',
#  'MONDO:0000190',
#  'MONDO:0014152',
#  'MONDO:0004938',
#  'MONDO:0000001',
#  'MONDO:0011122',
#  'MONDO:0002254',
#  'MONDO:0005156',
#  'MONDO:0005052',
#  'MONDO:0019956',
#  'MONDO:0005267',
#  'MONDO:0005453',
#  'MONDO:0009327',
#  'MONDO:0019512',
#  'MONDO:0005480',
#  'MONDO:0021042',
#  'MONDO:0005055',
#  'MONDO:0007845',
#  'MONDO:0005133',
#  'MONDO:0015305',
#  'MONDO:0001152',
#  'MONDO:0005053',
#  'MONDO:0006684',
#  'MONDO:0005299',
#  'MONDO:0018874',
#  'MONDO:0003664',
#  'MONDO:0020100',
#  'MONDO:0020103',
#  'MONDO:0008689',
#  'MONDO:0005044',
#  'MONDO:0021661',
#  'MONDO:0012026',
#  'MONDO:0016107',
#  'MONDO:0008056',
#  'MONDO:0016120',
#  'MONDO:0016121',
#  'MONDO:0005181',
#  'MONDO:0019016',
#  'MONDO:0011266',
#  'MONDO:0005336',
#  'MONDO:0006497',
#  'MONDO:0018959',
#  'MONDO:0019952',
#  'MONDO:0016122',
#  'MONDO:0000995',
#  'MONDO:0000728',
#  'MONDO:0007402',
#  'MONDO:0008055',
#  'MONDO:0009710',
#  'MONDO:0020169',
#  'MONDO:0008225',
#  'MONDO:0001071',
#  'MONDO:0005071',
#  'MONDO:0014151',
#  'MONDO:0015139',
#  'MONDO:0015427',
#  'MONDO:0001210',
#  'MONDO:0002016',
#  'MONDO:0024613',
#  'MONDO:0024612',
#  'MONDO:0007743',
#  'MONDO:0016027',
#  'MONDO:0007366',
#  'MONDO:0002125',
#  'MONDO:0005260',
#  'MONDO:0005277',
#  'MONDO:0008000',
#  'MONDO:0003233',
#  'MONDO:0003620',
#  'MONDO:0020126',
#  'MONDO:0005244',
#  'MONDO:0002203',
#  'MONDO:0012092',
#  'MONDO:0010682',
#  'MONDO:0020074',
#  'MONDO:0007186',
#  'MONDO:0007056',
#  'MONDO:0007057',
#  'MONDO:0011416',
#  'MONDO:0005328',
#  'MONDO:0008794',
#  'MONDO:0006527',
#  'MONDO:0010826',
#  'MONDO:0018497',
#  'MONDO:0007435',
#  'MONDO:0009699',
#  'MONDO:0006560',
#  'MONDO:0011876',
#  'MONDO:0016028',
#  'MONDO:0019369',
#  'MONDO:0005240',
#  'MONDO:0003634',
#  'MONDO:0002909',
#  'MONDO:0006022',
#  'MONDO:0016215',
#  'MONDO:0011990',
#  'MONDO:0016022',
#  'MONDO:0012245',
#  'MONDO:0022687',
#  'MONDO:0001941',
#  'MONDO:0005475',
#  'MONDO:0005395',
#  'MONDO:0015143',
#  'MONDO:0001385',
#  'MONDO:0002028',
#  'MONDO:0011851',
#  'MONDO:0001170',
#  'MONDO:0005560',
#  'MONDO:0004843',
#  'MONDO:0000500',
#  'MONDO:0005096',
#  'MONDO:0006710',
#  'MONDO:0002025',
#  'MONDO:0010244',
#  'MONDO:0005487',
#  'MONDO:0008414',
#  'MONDO:0012511',
#  'MONDO:0005263',
#  'MONDO:0002050',
#  'MONDO:0007079',
#  'MONDO:0021246',
#  'MONDO:0005517',
#  'MONDO:0012048',
#  'MONDO:0005371',
#  'MONDO:0008004',
#  'MONDO:0024529',
#  'MONDO:0004910',
#  'MONDO:0004992',
#  'MONDO:0021063',
#  'MONDO:0008575',
#  'MONDO:0015887',
#  'MONDO:0005148',
#  'MONDO:0015122',
#  'MONDO:0007455',
#  'MONDO:0005015',
#  'MONDO:0011751',
#  'MONDO:0005002',
#  'MONDO:0002332',
#  'MONDO:0008449',
#  'MONDO:0019351',
#  'MONDO:0018075',
#  'MONDO:0002732',
#  'MONDO:0021117',
#  'MONDO:0013108',
#  'MONDO:0004967',
#  'MONDO:0015104',
#  'MONDO:0005335',
#  'MONDO:0005154',
#  'MONDO:0001117',
#  'MONDO:0010096',
#  'MONDO:0018972',
#  'MONDO:0024331',
#  'MONDO:0024327',
#  'MONDO:0006826',
#  'MONDO:0005227',
#  'MONDO:0004970',
#  'MONDO:0005294',
#  'MONDO:0006525',
#  'MONDO:0006499',
#  'MONDO:0019749',
#  'MONDO:0021163',
#  'MONDO:0020025',
#  'MONDO:0005372',
#  'MONDO:0005271',
#  'MONDO:0015868',
#  'MONDO:0021100',
#  'MONDO:0007254',
#  'MONDO:0008315',
#  'MONDO:0021259',
#  'MONDO:0023122',
#  'MONDO:0011098',
#  'MONDO:0007256',
#  'MONDO:0018531',
#  'MONDO:0018666',
#  'MONDO:0016216',
#  'MONDO:0015870',
#  'MONDO:0002367',
#  'MONDO:0010138',
#  'MONDO:0005364',
#  'MONDO:0019091',
#  'MONDO:0009061',
#  'MONDO:0003198',
#  'MONDO:0005515',
#  'MONDO:0001187',
#  'MONDO:0015278',
#  'MONDO:0005192',
#  'MONDO:0017632',
#  'MONDO:0002691',
#  'MONDO:0005311',
#  'MONDO:0003573']

# %%
# Display the path connecting two nodes in the graph
meqd.show_path('CHEMBL744', 'MONDO:0011376')
# Out:
# [['CHEMBL744', '6331', 'MONDO:0011376'],
#  ['CHEMBL744', '6331', 'MONDO:0011376'],
#  ['CHEMBL744', '6331', 'MONDO:0011376'],
#  ['CHEMBL744', '6331', 'MONDO:0011376']]

# %%
# Display detailed edge information
meqd.display_edge_info('CHEMBL744', '6331')
# Out:
# {0: {'info': {'bts:entrez': [6331],
#    'bts:name': ['SODIUM VOLTAGE-GATED CHANNEL ALPHA SUBUNIT 5'],
#    'bts:source': ['TdgClinicalTrial', 'ChemblInteractions', 'DrugBank'],
#    'bts:publication': [20590601, 17139284, 9262334, 17016423, 12440368],
#    '@type': 'Gene',
#    '$input': 'bts:chembl',
#    '$source': 'dgidb'},
#   'label': 'bts:target',
#   'source': 'dgidb'},
#  1: {'info': {'bts:name': ['Sodium channel protein type 5 subunit alpha'],
#    'bts:symbol': ['SCN5A'],
#    'bts:action': ['BLOCKER'],
#    '@type': 'Gene',
#    '$input': 'bts:chembl',
#    '$source': 'drugcentral'},
#   'label': 'bts:target',
#   'source': 'drugcentral'}}

# %%
# display detailed edge information
meqd.display_edge_info('6331', 'MONDO:0011376')
# Out:
# {0: {'info': {'bts:mondo': ['MONDO:0011376'],
#    'bts:source': ['https://data.monarchinitiative.org/ttl/omim.ttl',
#     'https://data.monarchinitiative.org/ttl/orphanet.ttl',
#     'https://data.monarchinitiative.org/ttl/clinvar.nt'],
#    '@type': 'DiseaseOrPhenotypicFeature',
#    '$input': 'bts:entrez',
#    '$source': 'biolink'},
#   'label': 'bts:associatedWith',
#   'source': 'biolink'},
#  1: {'info': {'@type': 'DiseaseOrPhenotypicFeature',
#    'bts:umls': ['C2751898'],
#    '$source': 'mydisease.info'},
#   'label': 'bts:umls',
#   'source': 'mydisease.info'}}

# %%
meqd.display_node_info('MONDO:0011376')
# Out:
# {'identifier': 'bts:mondo',
#  'type': 'DiseaseOrPhenotypicFeature',
#  'level': 2,
#  'equivalent_ids': {'bts:mondo': ['MONDO:0011376'],
#   'bts:doid': [],
#   'bts:bfo': [],
#   'bts:cohd': [],
#   'bts:hp': [],
#   'bts:kegg': [],
#   'bts:meddra': [],
#   'bts:medgen': [],
#   'bts:mesh': ['C567851'],
#   'bts:omim': ['603829'],
#   'bts:umls': ['C2751898']}}

# %% [markdown]
# ## Feature3: Discover connections between two bio-entities
#
# Find connections between two bio-entities through one or more intermediate nodes

# %%
# initialize the connect module
from biothings_explorer.user_query_dispatcher import Connect

# %% [markdown]
# ### Step 1: Decide on your input and output

# %%
# search for riluzole
a = ht.query("riluzole")
a
# Out:
# {'Gene': [],
#  'SequenceVariant': [],
#  'ChemicalSubstance': [{'chembl': 'CHEMBL744',
#    'drugbank': 'DB00740',
#    'name': 'RILUZOLE',
#    'pubchem': 5070,
#    'display': 'chembl(CHEMBL744) drugbank(DB00740) name(RILUZOLE) pubchem(5070) ',
#    'type': 'ChemicalSubstance',
#    'primary': {'identifier': 'chembl',
#     'cls': 'ChemicalSubstance',
#     'value': 'CHEMBL744'}},
#   {'name': 'Riluzole',
#    'umls': 'C0073379',
#    'display': 'name(Riluzole) umls(C0073379) ',
#    'type': 'ChemicalSubstance',
#    'primary': {'identifier': 'umls',
#     'cls': 'ChemicalSubstance',
#     'value': 'C0073379'}}],
#  'DiseaseOrPhenotypicFeature': [],
#  'Pathway': [],
#  'MolecularFunction': [],
#  'CellularComponent': [],
#  'BiologicalProcess': [],
#  'Anatomy': [],
#  'PhenotypicFeature': []}

# %%
# select the input object from the hint results
input_obj = a['ChemicalSubstance'][0]
input_obj
# Out:
# {'chembl': 'CHEMBL744',
#  'drugbank': 'DB00740',
#  'name': 'RILUZOLE',
#  'pubchem': 5070,
#  'display': 'chembl(CHEMBL744) drugbank(DB00740) name(RILUZOLE) pubchem(5070) ',
#  'type': 'ChemicalSubstance',
#  'primary': {'identifier': 'chembl',
#   'cls': 'ChemicalSubstance',
#   'value': 'CHEMBL744'}}

# %%
# search for "Amyotrophic Lateral Sclerosis"
b = ht.query("Amyotrophic Lateral Sclerosis")
b
# Out:
# {'Gene': [{'entrez': '406238',
#    'name': 'amyotrophic lateral sclerosis 7',
#    'symbol': 'ALS7',
#    'taxonomy': 9606,
#    'umls': 'C2681918',
#    'display': 'entrez(406238) name(amyotrophic lateral sclerosis 7) symbol(ALS7) taxonomy(9606) umls(C2681918) ',
#    'type': 'Gene',
#    'primary': {'identifier': 'entrez', 'cls': 'Gene', 'value': '406238'}},
#   {'entrez': '253',
#    'name': 'amyotrophic lateral sclerosis 3 (autosomal dominant)',
#    'symbol': 'ALS3',
#    'taxonomy': 9606,
#    'umls': 'C1412368',
#    'display': 'entrez(253) name(amyotrophic lateral sclerosis 3 (autosomal dominant)) symbol(ALS3) taxonomy(9606) umls(C1412368) ',
#    'type': 'Gene',
#    'primary': {'identifier': 'entrez', 'cls': 'Gene', 'value': '253'}},
#   {'entrez': '40410',
#    'name': 'Amyotrophic lateral sclerosis 2',
#    'symbol': 'Als2',
#    'taxonomy': 7227,
#    'display': 'entrez(40410) name(Amyotrophic lateral sclerosis 2) symbol(Als2) taxonomy(7227) ',
#    'type': 'Gene',
#    'primary': {'identifier': 'entrez', 'cls': 'Gene', 'value': '40410'}},
#   {'name': 'amyotrophic lateral sclerosis 2b (juvenile)',
#    'symbol': 'als2b',
#    'taxonomy': 33528,
#    'display': 'name(amyotrophic lateral sclerosis 2b (juvenile)) symbol(als2b) taxonomy(33528) ',
#    'type': 'Gene',
#    'primary': {'identifier': 'symbol', 'cls': 'Gene', 'value': 'als2b'}},
#   {'name': 'amyotrophic lateral sclerosis 2b (juvenile)',
#    'symbol': 'als2b',
#    'taxonomy': 8090,
#    'display': 'name(amyotrophic lateral sclerosis 2b (juvenile)) symbol(als2b) taxonomy(8090) ',
#    'type': 'Gene',
#    'primary': {'identifier': 'symbol', 'cls': 'Gene', 'value': 'als2b'}}],
#  'SequenceVariant': [],
#  'ChemicalSubstance': [],
#  'DiseaseOrPhenotypicFeature': [{'mondo': 'MONDO:0004976',
#    'doid': 'DOID:332',
#    'umls': 'C0002736',
#    'mesh': 'D000690',
#    'name': 'amyotrophic lateral sclerosis',
#    'display': 'mondo(MONDO:0004976) doid(DOID:332) umls(C0002736) mesh(D000690) name(amyotrophic lateral sclerosis) ',
#    'type': 'DiseaseOrPhenotypicFeature',
#    'primary': {'identifier': 'mondo',
#     'cls': 'DiseaseOrPhenotypicFeature',
#     'value': 'MONDO:0004976'}},
#   {'mondo': 'MONDO:0014181',
#    'doid': 'DOID:0060211',
#    'umls': 'C3715156',
#    'name': 'amyotrophic lateral sclerosis type 20',
#    'display': 'mondo(MONDO:0014181) doid(DOID:0060211) umls(C3715156) name(amyotrophic lateral sclerosis type 20) ',
#    'type': 'DiseaseOrPhenotypicFeature',
#    'primary': {'identifier': 'mondo',
#     'cls': 'DiseaseOrPhenotypicFeature',
#     'value': 'MONDO:0014181'}},
#   {'mondo': 'MONDO:0013264',
#    'doid': 'DOID:0060203',
#    'umls': 'C3150692',
#    'name': 'amyotrophic lateral sclerosis type 12',
#    'display': 'mondo(MONDO:0013264) doid(DOID:0060203) umls(C3150692) name(amyotrophic lateral sclerosis type 12) ',
#    'type': 'DiseaseOrPhenotypicFeature',
#    'primary': {'identifier': 'mondo',
#     'cls': 'DiseaseOrPhenotypicFeature',
#     'value': 'MONDO:0013264'}},
#   {'mondo': 'MONDO:0012077',
#    'doid': 'DOID:0050752',
#    'umls': 'C1837728',
#    'mesh': 'C563895',
#    'name': 'amyotrophic lateral sclerosis type 8',
#    'display': 'mondo(MONDO:0012077) doid(DOID:0050752) umls(C1837728) mesh(C563895) name(amyotrophic lateral sclerosis type 8) ',
#    'type': 'DiseaseOrPhenotypicFeature',
#    'primary': {'identifier': 'mondo',
#     'cls': 'DiseaseOrPhenotypicFeature',
#     'value': 'MONDO:0012077'}},
#   {'mondo': 'MONDO:0000711',
#    'doid': 'DOID:0060204',
#    'name': 'amyotrophic lateral sclerosis type 13',
#    'display': 'mondo(MONDO:0000711) doid(DOID:0060204) name(amyotrophic lateral sclerosis type 13) ',
#    'type': 'DiseaseOrPhenotypicFeature',
#    'primary': {'identifier': 'mondo',
#     'cls': 'DiseaseOrPhenotypicFeature',
#     'value': 'MONDO:0000711'}}],
#  'Pathway': [{'name': 'Amyotrophic lateral sclerosis (ALS)',
#    'wikipathways': 'WP2447',
#    'display': 'name(Amyotrophic lateral sclerosis (ALS)) wikipathways(WP2447) ',
#    'type': 'Pathway',
#    'primary': {'identifier': 'wikipathways',
#     'cls': 'Pathway',
#     'value': 'WP2447'}},
#   {'name': 'Amyotrophic lateral sclerosis (ALS) - Mus musculus (mouse)',
#    'kegg': 'mmu05014',
#    'display': 'name(Amyotrophic lateral sclerosis (ALS) - Mus musculus (mouse)) kegg(mmu05014) ',
#    'type': 'Pathway',
#    'primary': {'identifier': 'kegg', 'cls': 'Pathway', 'value': 'mmu05014'}},
#   {'name': 'Amyotrophic lateral sclerosis (ALS) - Homo sapiens (human)',
#    'kegg': 'hsa05014',
#    'display': 'name(Amyotrophic lateral sclerosis (ALS) - Homo sapiens (human)) kegg(hsa05014) ',
#    'type': 'Pathway',
#    'primary': {'identifier': 'kegg', 'cls': 'Pathway', 'value': 'hsa05014'}}],
#  'MolecularFunction': [],
#  'CellularComponent': [],
#  'BiologicalProcess': [],
#  'Anatomy': [],
#  'PhenotypicFeature': []}

# %%
# select the output object from the hint results
output_obj = b['DiseaseOrPhenotypicFeature'][0]
output_obj
# Out:
# {'mondo': 'MONDO:0004976',
#  'doid': 'DOID:332',
#  'umls': 'C0002736',
#  'mesh': 'D000690',
#  'name': 'amyotrophic lateral sclerosis',
#  'display': 'mondo(MONDO:0004976) doid(DOID:332) umls(C0002736) mesh(D000690) name(amyotrophic lateral sclerosis) ',
#  'type': 'DiseaseOrPhenotypicFeature',
#  'primary': {'identifier': 'mondo',
#   'cls': 'DiseaseOrPhenotypicFeature',
#   'value': 'MONDO:0004976'}}

# %% [markdown]
# ### Step2: Find connections between your input and output

# %%
cc = Connect(input_obj=input_obj, output_obj=output_obj, registry=reg)

# %%
cc.connect()
# Out:
# processing step 1 ...
# processing step 2 ...
# query completed
# Find connection

# %% [markdown]
# ### Step3: Find how your input and output is connected

# %%
# find the path connecting from your input to output
cc.show_path()
# Out:
# [['CHEMBL744', '6332', 'MONDO:0004976']]

# %%
# show detailed edge information
cc.display_edge_info(start_node='CHEMBL744', end_node="6332")
# Out:
# {0: {'info': {'bts:entrez': [6332],
#    'bts:name': ['SODIUM VOLTAGE-GATED CHANNEL ALPHA SUBUNIT 7'],
#    'bts:source': ['ChemblInteractions'],
#    '@type': 'Gene',
#    '$input': 'bts:chembl',
#    '$source': 'dgidb'},
#   'label': 'bts:target',
#   'source': 'dgidb'}}

# %%
# show detailed edge information
cc.display_edge_info(start_node="6332", end_node="MONDO:0004976")
# Out:
# {0: {'info': {'bts:mondo': ['MONDO:0004976'],
#    'bts:source': ['https://data.monarchinitiative.org/ttl/gwascatalog.ttl'],
#    '@type': 'DiseaseOrPhenotypicFeature',
#    '$input': 'bts:entrez',
#    '$source': 'biolink'},
#   'label': 'bts:associatedWith',
#   'source': 'biolink'}}

# %%
# return the graph connectin from input to output in JSON
cc.to_json()
# Out:
# {'directed': True,
#  'multigraph': True,
#  'graph': {},
#  'nodes': [{'identifier': 'bts:mondo',
#    'type': 'DiseaseOrPhenotypicFeature',
#    'level': 2,
#    'equivalent_ids': {'bts:mondo': ['MONDO:0004976'],
#     'bts:doid': ['DOID:332'],
#     'bts:bfo': [],
#     'bts:cohd': ['373182'],
#     'bts:hp': [],
#     'bts:kegg': ['05014'],
#     'bts:meddra': ['10002026'],
#     'bts:medgen': [],
#     'bts:mesh': ['D000690'],
#     'bts:omim': [],
#     'bts:umls': ['C0002736']},
#    'id': 'MONDO:0004976'},
#   {'type': 'ChemicalSubstance',
#    'identifier': 'bts:chembl',
#    'level': 1,
#    'equivalent_ids': {'bts:inchi': ['InChI=1S/C8H5F3N2OS/c9-8(10,11)14-4-1-2-5-6(3-4)15-7(12)13-5/h1-3H,(H2,12,13)'],
#     'bts:inchikey': ['FTALBRSUTCGOEG-UHFFFAOYSA-N'],
#     'bts:rxcui': ['35623'],
#     'bts:smiles': ['Nc1nc2ccc(OC(F)(F)F)cc2s1'],
#     'bts:pubchem': [5070],
#     'bts:chembl': ['CHEMBL744'],
#     'bts:drugbank': ['DB00740'],
#     'bts:unii': ['7LJ087RS6F'],
#     'bts:mesh': ['D019782']},
#    'id': 'CHEMBL744'},
#   {'identifier': 'bts:entrez',
#    'type': 'Gene',
#    'level': 2,
#    'equivalent_ids': {'bts:ensembl': ['ENSG00000136546'],
#     'bts:hgnc': ['10594'],
#     'bts:omim': ['182392'],
#     'bts:entrez': ['6332'],
#     'bts:pharos': [],
#     'bts:umls': ['C1419865'],
#     'bts:unigene': ['Hs.596087', 'Hs.644853'],
#     'bts:pharmgkb': ['PA35008'],
#     'bts:symbol': ['SCN7A']},
#    'id': '6332'}],
#  'links': [{'info': {'bts:entrez': [6332],
#     'bts:name': ['SODIUM VOLTAGE-GATED CHANNEL ALPHA SUBUNIT 7'],
#     'bts:source': ['ChemblInteractions'],
#     '@type': 'Gene',
#     '$input': 'bts:chembl',
#     '$source': 'dgidb'},
#    'label': 'bts:target',
#    'source': 'CHEMBL744',
#    'target': '6332',
#    'key': 0},
#   {'info': {'bts:mondo': ['MONDO:0004976'],
#     'bts:source': ['https://data.monarchinitiative.org/ttl/gwascatalog.ttl'],
#     '@type': 'DiseaseOrPhenotypicFeature',
#     '$input': 'bts:entrez',
#     '$source': 'biolink'},
#    'label': 'bts:associatedWith',
#    'source': '6332',
#    'target': 'MONDO:0004976',
#    'key': 0}]}
