# %%
# import modules from biothings_explorer
from biothings_explorer.hint import Hint
from biothings_explorer.user_query_dispatcher import FindConnection

# %% [markdown]
# **Hint** module: Find corresponding bio-entity representation used in BioThings Explorer based on user input (could be any database IDs, symbols, names)
#
# **FindConnection** module: Find intermediate bio-entities which connects user specified input and output

# %% [markdown]
# ## Step 1: Find representation of "CXCR4" in BTE

# %%
ht = Hint()
# find all potential representations of CXCR4
cxcr4_hint = ht.query("CXCR4")
# select the correct representation of CXCR4
cxcr4 = cxcr4_hint['Gene'][0]
cxcr4
# Out:
# {'entrez': '7852',
#  'name': 'C-X-C motif chemokine receptor 4',
#  'symbol': 'CXCR4',
#  'taxonomy': 9606,
#  'umls': 'C1332823',
#  'display': 'entrez(7852) name(C-X-C motif chemokine receptor 4) symbol(CXCR4) taxonomy(9606) umls(C1332823) ',
#  'type': 'Gene',
#  'primary': {'identifier': 'entrez', 'cls': 'Gene', 'value': '7852'}}

# %% [markdown]
# ## Step 2: Find drugs that are associated with CXCR4

# %%
fc = FindConnection(input_obj=cxcr4, output_obj='ChemicalSubstance', intermediate_nodes=None)

# %%
fc.connect(verbose=True)
# Out:
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'CXCR4' and 'ChemicalSubstance'. Paths will have 0 intermediate node.
#
#
#
# ========== QUERY #1 -- fetch all ChemicalSubstance entities linked to CXCR4 ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because CXCR4 is of type 'Gene', BTE will query our meta-KG for APIs that can take 'Gene' as input
#
# BTE found 3 apis:
#
# 1. semmedgene
# 2. dgidb_gene2chemical
# 3. mychem.info
#
#
# ==== Step #2: Query path execution ====
#
# 3-1. http://mychem.info/v1/query (POST "q=CXCR4&scopes=drugbank.enzymes.gene_name&fields=drugbank.id&species=human&size=100")
# 3-3. http://mychem.info/v1/query (POST "q=CXCR4&scopes=drugcentral.bioactivity.uniprot.gene_symbol&fields=chembl.molecule_chembl_id&species=human&size=100")
# 3-2. http://mychem.info/v1/query (POST "q=CXCR4&scopes=drugbank.targets.gene_name&fields=drugbank.id&species=human&size=100")
# 2-1. http://www.dgidb.org/api/v2/interactions.json?genes=CXCR4
# 1-1. https://pending.biothings.io/semmedgene/query (POST "q=C1332823&scopes=umls&fields=associated_with_reverse.chemical_substance,interacts_with.chemical_substance,interacts_with_reverse.chemical_substance,affects.chemical_substance,affects_reverse.chemical_substance,associated_with.chemical_substance&species=human&size=100")
#
#
# ==== Step #3: Output normalization ====
#
# 2-1. dgidb_gene2chemical: 15 hits
# 3-1. mychem.info: No hits
# 3-2. mychem.info: 5 hits
# 3-3. mychem.info: 1 hits
# 1-1. semmedgene: 391 hits
#
# After id-to-object translation, BTE retrieved 187 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# In the #1 query, BTE found 187 unique ChemicalSubstance nodes

# %% [markdown]
# ## Step 3: Display and Filter results

# %%
df = fc.display_table_view()

# %%
df
# Out:
#      input input_type                         pred1 pred1_source  \
# 0    CXCR4       Gene                bts:targetedBy        dgidb
# 1    CXCR4       Gene                bts:targetedBy        dgidb
# 2    CXCR4       Gene  bts:molecularlyInteractsWith       semmed
# 3    CXCR4       Gene  bts:molecularlyInteractsWith       semmed
# 4    CXCR4       Gene  bts:molecularlyInteractsWith       semmed
# ..     ...        ...                           ...          ...
# 407  CXCR4       Gene  bts:molecularlyInteractsWith       semmed
# 408  CXCR4       Gene  bts:molecularlyInteractsWith       semmed
# 409  CXCR4       Gene  bts:molecularlyInteractsWith       semmed
# 410  CXCR4       Gene  bts:molecularlyInteractsWith       semmed
# 411  CXCR4       Gene  bts:molecularlyInteractsWith       semmed
#
#                pred1_api                                       pred1_pubmed  \
# 0    dgidb_gene2chemical                                               None
# 1    dgidb_gene2chemical                                               None
# 2             semmedgene  17120266,11752220,9298754,16300475,18410746,20...
# 3             semmedgene        11752220,9298754,16300475,18410746,20043638
# 4             semmedgene                                           10758170
# ..                   ...                                                ...
# 407           semmedgene                17629396,21784762,21784762,22558266
# 408           semmedgene                                           19665027
# 409           semmedgene                                           19665027
# 410           semmedgene                                  27251585,27251585
# 411           semmedgene                                  27251585,27251585
#
#             output        output_type
# 0          POL6326  ChemicalSubstance
# 1    CHEMBL2104426  ChemicalSubstance
# 2         C0376565  ChemicalSubstance
# 3         C0376565  ChemicalSubstance
# 4         C1291802  ChemicalSubstance
# ..             ...                ...
# 407       C0001128  ChemicalSubstance
# 408       C0243042  ChemicalSubstance
# 409       C0243042  ChemicalSubstance
# 410       C0392938  ChemicalSubstance
# 411       C0392938  ChemicalSubstance
#
# [412 rows x 8 columns]
