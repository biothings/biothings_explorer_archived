# %%
from biothings_explorer.hint import Hint
from biothings_explorer.user_query_dispatcher import FindConnection

# %%
ht = Hint()
ace2 = ht.query("ACE2")['Gene'][0]
ace2
# Out:
# {'NCBIGene': '59272',
#  'name': 'angiotensin I converting enzyme 2',
#  'SYMBOL': 'ACE2',
#  'UMLS': 'C1422064',
#  'HGNC': '13557',
#  'UNIPROTKB': 'Q9BYF1',
#  'ENSEMBL': 'ENSG00000130234',
#  'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '59272'},
#  'display': 'NCBIGene(59272) ENSEMBL(ENSG00000130234) HGNC(13557) UMLS(C1422064) UNIPROTKB(Q9BYF1) SYMBOL(ACE2)',
#  'type': 'Gene'}

# %%
fc = FindConnection(input_obj=ace2,
                    output_obj='Disease',
                    intermediate_nodes=None)

# %%
fc.connect(verbose=True)
# Out:
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'ACE2' and 'Disease'.                   Paths will have 0 intermediate node.
#
#
#
# ========== QUERY #1 -- fetch all Disease entities linked to ACE2 ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because ACE2 is of type 'Gene', BTE will query our meta-KG for APIs that can take 'Gene' as input and 'Disease' as output
#
# BTE found 10 apis:
#
# API 1. cord_gene(1 API call)
# API 2. semmed_gene(13 API calls)
# API 3. biolink(1 API call)
# API 4. scibite(1 API call)
# API 5. ctd(1 API call)
# API 6. DISEASES(1 API call)
# API 7. mydisease(1 API call)
# API 8. pharos(1 API call)
# API 9. hetio(1 API call)
# API 10. scigraph(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 7.1: http://mydisease.info/v1/query?fields=disgenet.xrefs.umls&size=250 (POST -d q=59272&scopes=disgenet.genes_related_to_disease.gene_id)
# API 3.4: https://biothings.ncats.io/semmedgene/query?fields=disrupted_by (POST -d q=C1422064&scopes=umls)
# API 3.11: https://biothings.ncats.io/semmedgene/query?fields=affected_by (POST -d q=C1422064&scopes=umls)
# API 3.3: https://biothings.ncats.io/semmedgene/query?fields=physically_interacts_with (POST -d q=C1422064&scopes=umls)
# API 3.7: https://biothings.ncats.io/semmedgene/query?fields=positively_regulated_by (POST -d q=C1422064&scopes=umls)
# API 3.9: https://biothings.ncats.io/semmedgene/query?fields=treats (POST -d q=C1422064&scopes=umls)
# API 3.10: https://biothings.ncats.io/semmedgene/query?fields=related_to (POST -d q=C1422064&scopes=umls)
# API 2.1: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:59272/diseases?rows=200
# API 3.2: https://biothings.ncats.io/semmedgene/query?fields=disrupts (POST -d q=C1422064&scopes=umls)
# API 3.1: https://biothings.ncats.io/semmedgene/query?fields=positively_regulates (POST -d q=C1422064&scopes=umls)
# API 3.12: https://biothings.ncats.io/semmedgene/query?fields=negatively_regulates (POST -d q=C1422064&scopes=umls)
# API 3.5: https://biothings.ncats.io/semmedgene/query?fields=negatively_regulated_by (POST -d q=C1422064&scopes=umls)
# API 3.6: https://biothings.ncats.io/semmedgene/query?fields=causes (POST -d q=C1422064&scopes=umls)
# API 3.8: https://biothings.ncats.io/semmedgene/query?fields=prevents (POST -d q=C1422064&scopes=umls)
# API 3.13: https://biothings.ncats.io/semmedgene/query?fields=affects (POST -d q=C1422064&scopes=umls)
# API 5.1: http://ctdbase.org/tools/batchQuery.go?inputType=gene&report=diseases_curated&format=json&inputTerms=59272
# API 6.1: https://pending.biothings.io/DISEASES/query?fields=DISEASES.doid&size=250 (POST -d q=ACE2&scopes=DISEASES.associatedWith.symbol)
# API 1.1: https://biothings.ncats.io/cord_gene/query?fields=associated_with (POST -d q=13557&scopes=hgnc)
# API 8.1: https://automat.renci.org/pharos/gene/disease/NCBIGene:59272
# API 9.1: https://automat.renci.org/hetio/gene/disease/NCBIGene:59272
# API 10.1: https://automat.renci.org/cord19_scigraph_v2/gene/disease/NCBIGene:59272
# API 4.1: https://automat.renci.org/cord19_scibite_v2/gene/disease/NCBIGene:59272
#
#
# ==== Step #3: Output normalization ====
#
# API 3.1 semmed_gene: No hits
# API 3.2 semmed_gene: 8 hits
# API 3.3 semmed_gene: No hits
# API 4.1 scibite: 44 hits
# API 3.4 semmed_gene: No hits
# API 6.1 DISEASES: 31 hits
# API 3.5 semmed_gene: No hits
# API 3.6 semmed_gene: 17 hits
# API 3.7 semmed_gene: No hits
# API 8.1 pharos: 4 hits
# API 9.1 hetio: 5 hits
# API 2.1 biolink: No hits
# API 7.1 mydisease: 7 hits
# API 3.8 semmed_gene: 6 hits
# API 3.9 semmed_gene: 12 hits
# API 10.1 scigraph: 41 hits
# API 3.10 semmed_gene: 57 hits
# API 3.11 semmed_gene: No hits
# API 1.1 cord_gene: 4 hits
# API 3.12 semmed_gene: No hits
# API 3.13 semmed_gene: 17 hits
# API 5.1 ctd: 17 hits
#
# After id-to-object translation, BTE retrieved 156 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# In the #1 query, BTE found 156 unique Disease nodes

# %%
fc.to_reasoner_std()
# Out:
# {'query_graph': {'edges': [{'id': 'e0',
#     'source_id': 'n0',
#     'target_id': 'n1',
#     'directed': True}],
#   'nodes': [{'id': 'n0', 'type': 'Gene', 'curie': ['NCBIGene:59272']},
#    {'id': 'n1', 'type': 'Disease'}]},
#  'knowledge_graph': {'nodes': [{'id': 'SYMBOL:ACE2',
#     'name': 'ANGIOTENSIN I CONVERTING ENZYME 2',
#     'type': 'Gene',
#     'equivalent_identifiers': defaultdict(set,
#                 {'NCBIGene': ['59272'],
#                  'name': ['ANGIOTENSIN I CONVERTING ENZYME 2'],
#                  'SYMBOL': ['ACE2'],
#                  'UMLS': ['C1422064'],
#                  'HGNC': ['13557'],
#                  'UNIPROTKB': ['Q9BYF1'],
#                  'ENSEMBL': ['ENSG00000130234']})},
#    {'id': 'UMLS:C0221198',
#     'name': 'UMLS:C0221198',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C0221198']}},
#    {'id': 'UMLS:C0262613',
#     'name': 'UMLS:C0262613',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C0262613']}},
#    {'id': 'UMLS:C0264716',
#     'name': 'UMLS:C0264716',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C0264716']}},
#    {'id': 'UMLS:C1397014',
#     'name': 'UMLS:C1397014',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C1397014']}},
#    {'id': 'UMLS:C0009566',
#     'name': 'UMLS:C0009566',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C0009566']}},
#    {'id': 'UMLS:C0011847',
#     'name': 'UMLS:C0011847',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C0011847']}},
#    {'id': 'UMLS:C0015697',
#     'name': 'UMLS:C0015697',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C0015697']}},
#    {'id': 'UMLS:C0242606',
#     'name': 'UMLS:C0242606',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C0242606']}},
#    {'id': 'UMLS:C0332448',
#     'name': 'UMLS:C0332448',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C0332448']}},
#    {'id': 'UMLS:C0340515',
#     'name': 'UMLS:C0340515',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C0340515']}},
#    {'id': 'UMLS:C0522569',
#     'name': 'UMLS:C0522569',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C0522569']}},
#    {'id': 'UMLS:C1291117',
#     'name': 'UMLS:C1291117',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C1291117']}},
#    {'id': 'UMLS:C0277785',
#     'name': 'UMLS:C0277785',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C0277785']}},
#    {'id': 'UMLS:C0699748',
#     'name': 'UMLS:C0699748',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C0699748']}},
#    {'id': 'UMLS:C1155266',
#     'name': 'UMLS:C1155266',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C1155266']}},
#    {'id': 'UMLS:C0231176',
#     'name': 'UMLS:C0231176',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C0231176']}},
#    {'id': 'UMLS:C1301752',
#     'name': 'UMLS:C1301752',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C1301752']}},
#    {'id': 'UMLS:C0030660',
#     'name': 'UMLS:C0030660',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C0030660']}},
#    {'id': 'UMLS:C0087086',
#     'name': 'UMLS:C0087086',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C0087086']}},
#    {'id': 'UMLS:C0149939',
#     'name': 'UMLS:C0149939',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C0149939']}},
#    {'id': 'UMLS:C0520863',
#     'name': 'UMLS:C0520863',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C0520863']}},
#    {'id': 'UMLS:C0878751',
#     'name': 'UMLS:C0878751',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C0878751']}},
#    {'id': 'UMLS:C0920563',
#     'name': 'UMLS:C0920563',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C0920563']}},
#    {'id': 'UMLS:C1301700',
#     'name': 'UMLS:C1301700',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C1301700']}},
#    {'id': 'UMLS:C0879626',
#     'name': 'UMLS:C0879626',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C0879626']}},
#    {'id': 'UMLS:C0160420',
#     'name': 'UMLS:C0160420',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C0160420']}},
#    {'id': 'UMLS:C0518003',
#     'name': 'UMLS:C0518003',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C0518003']}},
#    {'id': 'UMLS:C0684309',
#     'name': 'UMLS:C0684309',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C0684309']}},
#    {'id': 'UMLS:C0687133',
#     'name': 'UMLS:C0687133',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C0687133']}},
#    {'id': 'UMLS:C1446614',
#     'name': 'UMLS:C1446614',
#     'type': 'Disease',
#     'equivalent_identifiers': {'UMLS': ['C1446614']}},
#    {'id': 'MONDO:MONDO:0100096',
#     'name': 'MONDO:MONDO:0100096',
#     'type': 'Disease',
#     'equivalent_identifiers': {'MONDO': ['MONDO:0100096']}},
#    {'id': 'MESH:D000022',
#     'name': 'MESH:D000022',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MESH:D000022'], 'MESH': ['D000022']})},
#    {'id': 'MESH:C000657245',
#     'name': 'MESH:C000657245',
#     'type': 'Disease',
#     'equivalent_identifiers': {'MESH': ['C000657245']}},
#    {'id': 'MESH:D007249',
#     'name': 'MESH:D007249',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MESH:D007249'], 'MESH': ['D007249']})},
#    {'id': 'MESH:D055370',
#     'name': 'MESH:D055370',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MESH:D055370'], 'MESH': ['D055370']})},
#    {'id': 'DOID:DOID:162',
#     'name': 'DOID:DOID:162',
#     'type': 'Disease',
#     'equivalent_identifiers': {'DOID': ['DOID:162']}},
#    {'id': 'DOID:DOID:0080600',
#     'name': 'DOID:DOID:0080600',
#     'type': 'Disease',
#     'equivalent_identifiers': {'DOID': ['DOID:0080600']}},
#    {'id': 'NAME:INFLAMMATION',
#     'name': 'INFLAMMATION',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['C0021368'],
#                  'UMLS': ['C0021368'],
#                  'name': ['INFLAMMATION']})},
#    {'id': 'NAME:PULMONARY FIBROSIS',
#     'name': 'PULMONARY FIBROSIS',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0002771'],
#                  'DOID': ['DOID:3770'],
#                  'UMLS': ['C0034069'],
#                  'name': ['PULMONARY FIBROSIS'],
#                  'MESH': ['D011658']})},
#    {'id': 'NAME:MYOCARDIAL FIBROSIS',
#     'name': 'MYOCARDIAL FIBROSIS',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['C0151654'],
#                  'UMLS': ['C0151654'],
#                  'name': ['MYOCARDIAL FIBROSIS']})},
#    {'id': 'NAME:AAA1',
#     'name': 'AAA1',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0007031', 'MONDO:0024521'],
#                  'UMLS': ['C0162871', 'C1853365'],
#                  'name': ['AAA1',
#                   'AORTIC ANEURYSM, ABDOMINAL',
#                   'AORTIC ANEURYSM, FAMILIAL ABDOMINAL 1',
#                   'FAMILIAL ABDOMINAL AORTIC ANEURYSM'],
#                  'ORPHANET': ['86'],
#                  'OMIM': ['100070']})},
#    {'id': 'NAME:CARDIOVASCULAR DISEASE',
#     'name': 'CARDIOVASCULAR DISEASE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0004995'],
#                  'DOID': ['DOID:1287'],
#                  'UMLS': ['C0007222'],
#                  'name': ['CARDIOVASCULAR DISEASE', 'CARDIOVASCULAR DISEASES'],
#                  'MESH': ['D002318']})},
#    {'id': 'NAME:FIBROSIS',
#     'name': 'FIBROSIS',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['C0016059'],
#                  'UMLS': ['C0016059'],
#                  'name': ['FIBROSIS']})},
#    {'id': 'NAME:CONGENITAL HEART DEFECTS',
#     'name': 'CONGENITAL HEART DEFECTS',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005453'],
#                  'DOID': ['DOID:1682'],
#                  'UMLS': ['C0152021', 'C0018798'],
#                  'name': ['CONGENITAL HEART DEFECTS',
#                   'CONGENITAL HEART DISEASE'],
#                  'MESH': ['D006330']})},
#    {'id': 'NAME:HYPERGLYCEMIA',
#     'name': 'HYPERGLYCEMIA',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0002909'],
#                  'DOID': ['DOID:4195'],
#                  'UMLS': ['C0020456'],
#                  'name': ['HYPERGLYCEMIA'],
#                  'MESH': ['D006943']})},
#    {'id': 'NAME:WEIGHT GAIN',
#     'name': 'WEIGHT GAIN',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['C0043094'],
#                  'UMLS': ['C0043094'],
#                  'name': ['WEIGHT GAIN']})},
#    {'id': 'NAME:GLOMERULOSCLEROSIS',
#     'name': 'GLOMERULOSCLEROSIS',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0000490'],
#                  'DOID': ['DOID:0050851'],
#                  'UMLS': ['C0178664'],
#                  'name': ['GLOMERULOSCLEROSIS',
#                   'GLOMERULOSCLEROSIS (DISORDER)']})},
#    {'id': 'NAME:ACUTE LUNG INJURY',
#     'name': 'ACUTE LUNG INJURY',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0015796'],
#                  'UMLS': ['C0242488'],
#                  'name': ['ACUTE LUNG INJURY'],
#                  'MESH': ['D055371'],
#                  'ORPHANET': ['178320']})},
#    {'id': 'NAME:ACUTE RESPIRATORY CORONAVIRUS INFECTION',
#     'name': 'ACUTE RESPIRATORY CORONAVIRUS INFECTION',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0015370', 'MONDO:0005091'],
#                  'DOID': ['DOID:2945'],
#                  'UMLS': ['C1175175'],
#                  'name': ['ACUTE RESPIRATORY CORONAVIRUS INFECTION',
#                   'SEVERE ACUTE RESPIRATORY SYNDROME'],
#                  'MESH': ['D045169'],
#                  'ORPHANET': ['140896']})},
#    {'id': 'NAME:INSULIN RESISTANCE',
#     'name': 'INSULIN RESISTANCE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['C0021655'],
#                  'UMLS': ['C0021655'],
#                  'name': ['INSULIN RESISTANCE']})},
#    {'id': 'NAME:MALIGNANT SQUAMOUS CELL NEOPLASM',
#     'name': 'MALIGNANT SQUAMOUS CELL NEOPLASM',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005096', 'MONDO:0000500'],
#                  'DOID': ['DOID:1749', 'DOID:0050865'],
#                  'UMLS': ['C0751688', 'C0007137'],
#                  'name': ['MALIGNANT SQUAMOUS CELL NEOPLASM',
#                   'SQUAMOUS CELL CARCINOMA',
#                   'TONGUE SQUAMOUS CELL CARCINOMA'],
#                  'MESH': ['D018307', 'D002294']})},
#    {'id': 'NAME:DISEASE',
#     'name': 'DISEASE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0000001'],
#                  'DOID': ['DOID:4'],
#                  'UMLS': ['C0012634'],
#                  'name': ['DISEASE'],
#                  'MESH': ['D004194'],
#                  'ORPHANET': ['377788']})},
#    {'id': 'NAME:DYSAUTONOMIA',
#     'name': 'DYSAUTONOMIA',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['C0013363'],
#                  'UMLS': ['C0013363'],
#                  'name': ['DYSAUTONOMIA']})},
#    {'id': 'NAME:CONGESTIVE HEART FAILURE',
#     'name': 'CONGESTIVE HEART FAILURE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005009', 'MONDO:0005252'],
#                  'UMLS': ['C0018801', 'C0018802'],
#                  'name': ['CONGESTIVE HEART FAILURE', 'HEART FAILURE'],
#                  'MESH': ['D006333'],
#                  'DOID': ['DOID:6000']})},
#    {'id': 'NAME:RIGHT VENTRICULAR HYPERTROPHY',
#     'name': 'RIGHT VENTRICULAR HYPERTROPHY',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['C0162770'],
#                  'UMLS': ['C0162770'],
#                  'name': ['RIGHT VENTRICULAR HYPERTROPHY']})},
#    {'id': 'NAME:GLOMERULAR DISEASE',
#     'name': 'GLOMERULAR DISEASE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0019722'],
#                  'UMLS': ['C0268731'],
#                  'name': ['GLOMERULAR DISEASE', 'RENAL GLOMERULAR DISEASE'],
#                  'ORPHANET': ['93548']})},
#    {'id': 'NAME:ADENOCARCINOMA',
#     'name': 'ADENOCARCINOMA',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0004970'],
#                  'DOID': ['DOID:299'],
#                  'UMLS': ['C0001418'],
#                  'name': ['ADENOCARCINOMA'],
#                  'MESH': ['D000230']})},
#    {'id': 'NAME:ALZHEIMER DISEASE TYPE 1',
#     'name': 'ALZHEIMER DISEASE TYPE 1',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0007088', 'MONDO:0004975'],
#                  'DOID': ['DOID:10652'],
#                  'UMLS': ['C0002395', 'C1863052'],
#                  'name': ['ALZHEIMER DISEASE TYPE 1',
#                   'ALZHEIMER DISEASE, FAMILIAL, 1',
#                   "ALZHEIMER'S DISEASE",
#                   'ALZHEIMERS DISEASE'],
#                  'MESH': ['D000544'],
#                  'OMIM': ['104300']})},
#    {'id': 'NAME:ARTERIOSCLEROTIC CARDIOVASCULAR DISEASE',
#     'name': 'ARTERIOSCLEROTIC CARDIOVASCULAR DISEASE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0002276', 'MONDO:0005311'],
#                  'DOID': ['DOID:2348', 'DOID:1936'],
#                  'UMLS': ['C3665365', 'C0004153'],
#                  'name': ['ARTERIOSCLEROTIC CARDIOVASCULAR DISEASE',
#                   'ARTERIOSCLEROTIC CARDIOVASCULAR DISEASE, NOS',
#                   'ATHEROSCLEROSIS'],
#                  'MESH': ['D050197']})},
#    {'id': 'NAME:ATRIAL FIBRILLATION',
#     'name': 'ATRIAL FIBRILLATION',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0004981'],
#                  'DOID': ['DOID:0060224'],
#                  'UMLS': ['C0004238'],
#                  'name': ['ATRIAL FIBRILLATION',
#                   'ATRIAL FIBRILLATION (DISEASE)'],
#                  'MESH': ['D001281']})},
#    {'id': 'NAME:HEREDITARY PAPILLARY RENAL CARCINOMA',
#     'name': 'HEREDITARY PAPILLARY RENAL CARCINOMA',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005086', 'MONDO:0005549', 'MONDO:0017884'],
#                  'UMLS': ['C0007134',
#                   'C2931899',
#                   'C1306837',
#                   'C1336839',
#                   'C0879257'],
#                  'name': ['HEREDITARY PAPILLARY RENAL CARCINOMA',
#                   'PAPILLARY RENAL CELL CARCINOMA',
#                   'PAPILLARY RENAL CELL CARCINOMA, FAMILIAL',
#                   'RENAL CELL ADENOCARCINOMA',
#                   'RENAL CELL CARCINOMA',
#                   'RENAL CELL CARCINOMA (DISEASE)',
#                   'TYPE 1 PAPILLARY RENAL CELL CARCINOMA'],
#                  'DOID': ['DOID:4465', 'DOID:4450'],
#                  'MESH': ['D002292'],
#                  'ORPHANET': ['217071', '319298'],
#                  'OMIM': ['605074']})},
#    {'id': 'NAME:CARDIOMYOPATHY, DILATED',
#     'name': 'CARDIOMYOPATHY, DILATED',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005021'],
#                  'DOID': ['DOID:12930'],
#                  'UMLS': ['C0007193'],
#                  'name': ['CARDIOMYOPATHY, DILATED', 'DILATED CARDIOMYOPATHY'],
#                  'MESH': ['D002311'],
#                  'ORPHANET': ['217604']})},
#    {'id': 'NAME:DIABETES MELLITUS, INSULIN-DEPENDENT',
#     'name': 'DIABETES MELLITUS, INSULIN-DEPENDENT',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005147'],
#                  'DOID': ['DOID:9744'],
#                  'UMLS': ['C0011854'],
#                  'name': ['DIABETES MELLITUS, INSULIN-DEPENDENT',
#                   'TYPE 1 DIABETES MELLITUS'],
#                  'MESH': ['D003922']})},
#    {'id': 'NAME:DIABETES MELLITUS',
#     'name': 'DIABETES MELLITUS',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005015'],
#                  'DOID': ['DOID:9351'],
#                  'UMLS': ['C0011849'],
#                  'name': ['DIABETES MELLITUS', 'DIABETES MELLITUS (DISEASE)'],
#                  'MESH': ['D003920']})},
#    {'id': 'NAME:DIABETIC NEPHROPATHY',
#     'name': 'DIABETIC NEPHROPATHY',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005016'],
#                  'UMLS': ['C0011881'],
#                  'name': ['DIABETIC NEPHROPATHY'],
#                  'MESH': ['D003928']})},
#    {'id': 'NAME:IGA GLOMERULONEPHRITIS',
#     'name': 'IGA GLOMERULONEPHRITIS',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005342'],
#                  'DOID': ['DOID:2986'],
#                  'UMLS': ['C0017661'],
#                  'name': ['IGA GLOMERULONEPHRITIS'],
#                  'MESH': ['D005922']})},
#    {'id': 'NAME:MEMBRANOUS GLOMERULONEPHRITIS',
#     'name': 'MEMBRANOUS GLOMERULONEPHRITIS',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005376'],
#                  'DOID': ['DOID:10976'],
#                  'UMLS': ['C0017665'],
#                  'name': ['MEMBRANOUS GLOMERULONEPHRITIS'],
#                  'MESH': ['D015433']})},
#    {'id': 'NAME:HYPERPLASIA',
#     'name': 'HYPERPLASIA',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005043'],
#                  'UMLS': ['C0020507'],
#                  'name': ['HYPERPLASIA'],
#                  'MESH': ['D006965']})},
#    {'id': 'NAME:HYPERTENSION',
#     'name': 'HYPERTENSION',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005044'],
#                  'DOID': ['DOID:10763'],
#                  'UMLS': ['C0020538'],
#                  'name': ['HYPERTENSION', 'HYPERTENSIVE DISEASE'],
#                  'MESH': ['D006973']})},
#    {'id': 'NAME:RENAL HYPERTENSION',
#     'name': 'RENAL HYPERTENSION',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0001105'],
#                  'DOID': ['DOID:1073'],
#                  'UMLS': ['C0020544'],
#                  'name': ['RENAL HYPERTENSION'],
#                  'MESH': ['D006977']})},
#    {'id': 'NAME:HYPERTROPHY',
#     'name': 'HYPERTROPHY',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['C0020564'],
#                  'UMLS': ['C0020564'],
#                  'name': ['HYPERTROPHY']})},
#    {'id': 'NAME:INFARCTION',
#     'name': 'INFARCTION',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['C0021308'],
#                  'UMLS': ['C0021308'],
#                  'name': ['INFARCTION']})},
#    {'id': 'NAME:KIDNEY DISEASE',
#     'name': 'KIDNEY DISEASE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005240'],
#                  'DOID': ['DOID:557'],
#                  'UMLS': ['C0022658'],
#                  'name': ['KIDNEY DISEASE', 'KIDNEY DISEASES'],
#                  'MESH': ['D007674']})},
#    {'id': 'NAME:CHRONIC KIDNEY DISEASE',
#     'name': 'CHRONIC KIDNEY DISEASE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005300'],
#                  'DOID': ['DOID:784'],
#                  'UMLS': ['C1561643', 'C0022661'],
#                  'name': ['CHRONIC KIDNEY DISEASE',
#                   'CHRONIC KIDNEY DISEASES',
#                   'KIDNEY FAILURE, CHRONIC'],
#                  'MESH': ['D007676', 'D051436']})},
#    {'id': 'NAME:LUNG DISEASE',
#     'name': 'LUNG DISEASE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005275'],
#                  'DOID': ['DOID:850'],
#                  'UMLS': ['C0024115'],
#                  'name': ['LUNG DISEASE', 'LUNG DISEASES'],
#                  'MESH': ['D008171']})},
#    {'id': 'NAME:MYOCARDIAL INFARCTION',
#     'name': 'MYOCARDIAL INFARCTION',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005068'],
#                  'DOID': ['DOID:5844'],
#                  'UMLS': ['C0027051'],
#                  'name': ['MYOCARDIAL INFARCTION',
#                   'MYOCARDIAL INFARCTION (DISEASE)'],
#                  'MESH': ['D009203']})},
#    {'id': 'NAME:PROTEINURIA',
#     'name': 'PROTEINURIA',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0003634'],
#                  'DOID': ['DOID:576'],
#                  'UMLS': ['C0033687'],
#                  'name': ['PROTEINURIA'],
#                  'MESH': ['D011507']})},
#    {'id': 'NAME:REPERFUSION INJURY',
#     'name': 'REPERFUSION INJURY',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['C0035126'],
#                  'UMLS': ['C0035126'],
#                  'name': ['REPERFUSION INJURY']})},
#    {'id': 'NAME:ACUTE RESPIRATORY DISTRESS SYNDROME',
#     'name': 'ACUTE RESPIRATORY DISTRESS SYNDROME',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0006502', 'MONDO:0001278'],
#                  'DOID': ['DOID:11394'],
#                  'UMLS': ['C0035222'],
#                  'name': ['ACUTE RESPIRATORY DISTRESS SYNDROME',
#                   'ADULT RESPIRATORY DISTRESS SYNDROME',
#                   'RESPIRATORY DISTRESS SYNDROME, ADULT'],
#                  'MESH': ['D012128']})},
#    {'id': 'NAME:CHAGAS DISEASE',
#     'name': 'CHAGAS DISEASE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0001444'],
#                  'DOID': ['DOID:12140'],
#                  'UMLS': ['C0041234'],
#                  'name': ['CHAGAS DISEASE'],
#                  'ORPHANET': ['3386']})},
#    {'id': 'NAME:ANEURYSM',
#     'name': 'ANEURYSM',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005385', 'MONDO:0019048'],
#                  'UMLS': ['C0042373', 'C0002940', 'C0752130'],
#                  'name': ['ANEURYSM',
#                   'RARE VASCULAR DISEASE',
#                   'SPINAL CORD ISCHEMIA',
#                   'VASCULAR DISEASE',
#                   'VASCULAR DISEASES'],
#                  'ORPHANET': ['68362'],
#                  'DOID': ['DOID:178'],
#                  'MESH': ['D014652', 'D000783', 'D020758', 'D020760']})},
#    {'id': 'NAME:ESSENTIAL HYPERTENSION',
#     'name': 'ESSENTIAL HYPERTENSION',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0001134'],
#                  'DOID': ['DOID:10825'],
#                  'UMLS': ['C0085580'],
#                  'name': ['ESSENTIAL HYPERTENSION'],
#                  'MESH': ['C562386']})},
#    {'id': 'NAME:FIBROSIS, LIVER',
#     'name': 'FIBROSIS, LIVER',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['C0239946'],
#                  'UMLS': ['C0239946'],
#                  'name': ['FIBROSIS, LIVER']})},
#    {'id': 'NAME:DYSLIPIDEMIAS',
#     'name': 'DYSLIPIDEMIAS',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0015123'],
#                  'UMLS': ['C0242339'],
#                  'name': ['DYSLIPIDEMIAS', 'RARE DYSLIPIDEMIA'],
#                  'ORPHANET': ['101953']})},
#    {'id': 'NAME:VENTRICULAR DYSFUNCTION',
#     'name': 'VENTRICULAR DYSFUNCTION',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['C0242973'],
#                  'UMLS': ['C0242973'],
#                  'name': ['VENTRICULAR DYSFUNCTION']})},
#    {'id': 'NAME:KIDNEY ONCOCYTOMA',
#     'name': 'KIDNEY ONCOCYTOMA',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0003825'],
#                  'DOID': ['DOID:6245'],
#                  'UMLS': ['C0346255'],
#                  'name': ['KIDNEY ONCOCYTOMA', 'ONCOCYTOMA, RENAL'],
#                  'MESH': ['C537750']})},
#    {'id': 'NAME:LEFT VENTRICULAR HYPERTROPHY',
#     'name': 'LEFT VENTRICULAR HYPERTROPHY',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['C0149721'],
#                  'UMLS': ['C0149721'],
#                  'name': ['LEFT VENTRICULAR HYPERTROPHY']})},
#    {'id': 'NAME:DIABETIC RETINOPATHY',
#     'name': 'DIABETIC RETINOPATHY',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005266'],
#                  'DOID': ['DOID:8947'],
#                  'UMLS': ['C0011884'],
#                  'name': ['DIABETIC RETINOPATHY'],
#                  'MESH': ['D003930']})},
#    {'id': 'NAME:HEART DISEASE',
#     'name': 'HEART DISEASE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005267'],
#                  'DOID': ['DOID:114'],
#                  'UMLS': ['C0018799'],
#                  'name': ['HEART DISEASE', 'HEART DISEASES'],
#                  'MESH': ['D006331']})},
#    {'id': 'NAME:IDIOPATHIC CARDIOMYOPATHY',
#     'name': 'IDIOPATHIC CARDIOMYOPATHY',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005110'],
#                  'UMLS': ['C0033141'],
#                  'name': ['IDIOPATHIC CARDIOMYOPATHY']})},
#    {'id': 'NAME:PELLAGRA',
#     'name': 'PELLAGRA',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0019975'],
#                  'DOID': ['DOID:8457'],
#                  'UMLS': ['C0030783'],
#                  'name': ['PELLAGRA'],
#                  'MESH': ['D010383'],
#                  'ORPHANET': ['97352']})},
#    {'id': 'NAME:HARTNUP DISEASE',
#     'name': 'HARTNUP DISEASE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0009324'],
#                  'DOID': ['DOID:1060'],
#                  'UMLS': ['C0018609'],
#                  'name': ['HARTNUP DISEASE'],
#                  'MESH': ['D006250'],
#                  'OMIM': ['234500'],
#                  'ORPHANET': ['2116']})},
#    {'id': 'NAME:ACUTE MYOCARDIAL INFARCTION',
#     'name': 'ACUTE MYOCARDIAL INFARCTION',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0004781'],
#                  'DOID': ['DOID:9408'],
#                  'UMLS': ['C0155626'],
#                  'name': ['ACUTE MYOCARDIAL INFARCTION']})},
#    {'id': 'NAME:NON-SMALL CELL LUNG CARCINOMA',
#     'name': 'NON-SMALL CELL LUNG CARCINOMA',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005233'],
#                  'DOID': ['DOID:3908'],
#                  'UMLS': ['C0007131'],
#                  'name': ['NON-SMALL CELL LUNG CARCINOMA',
#                   'NON-SMALL CELL LUNG CARCINOMA (DISEASE)'],
#                  'MESH': ['D002289']})},
#    {'id': 'NAME:CEREBROVASCULAR ACCIDENT',
#     'name': 'CEREBROVASCULAR ACCIDENT',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0011057'],
#                  'DOID': ['DOID:6713'],
#                  'UMLS': ['C0007820', 'C0038454', 'C0948008'],
#                  'name': ['CEREBROVASCULAR ACCIDENT',
#                   'CEREBROVASCULAR DISORDER',
#                   'CEREBROVASCULAR DISORDERS',
#                   'ISCHEMIC STROKE'],
#                  'MESH': ['D020521', 'D002561'],
#                  'OMIM': ['601367']})},
#    {'id': 'NAME:ADENOCARCINOMA OF LUNG (DISORDER)',
#     'name': 'ADENOCARCINOMA OF LUNG (DISORDER)',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005061'],
#                  'DOID': ['DOID:3910'],
#                  'UMLS': ['C1335060', 'C0152013'],
#                  'name': ['ADENOCARCINOMA OF LUNG (DISORDER)',
#                   'LUNG ADENOCARCINOMA'],
#                  'MESH': ['C538231']})},
#    {'id': 'NAME:DYSEQUILIBRIUM SYNDROME',
#     'name': 'DYSEQUILIBRIUM SYNDROME',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0009133'],
#                  'DOID': ['DOID:0050997'],
#                  'UMLS': ['C0394006'],
#                  'name': ['DYSEQUILIBRIUM SYNDROME'],
#                  'MESH': ['C535731'],
#                  'ORPHANET': ['1766']})},
#    {'id': 'NAME:CARDIOMYOPATHIES',
#     'name': 'CARDIOMYOPATHIES',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0004994'],
#                  'DOID': ['DOID:0050700'],
#                  'UMLS': ['C0878544', 'C0036529'],
#                  'name': ['CARDIOMYOPATHIES', 'CARDIOMYOPATHY'],
#                  'MESH': ['D009202'],
#                  'ORPHANET': ['167848']})},
#    {'id': 'NAME:HEART FAILURE',
#     'name': 'HEART FAILURE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005252'],
#                  'UMLS': ['C0018801'],
#                  'name': ['HEART FAILURE'],
#                  'MESH': ['D006333']})},
#    {'id': 'NAME:ACUTE RESPIRATORY FAILURE',
#     'name': 'ACUTE RESPIRATORY FAILURE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0021113'],
#                  'DOID': ['DOID:11162'],
#                  'UMLS': ['C1145670', 'C0264490'],
#                  'name': ['ACUTE RESPIRATORY FAILURE', 'RESPIRATORY FAILURE'],
#                  'MESH': ['D012131']})},
#    {'id': "NAME:ALZHEIMER'S DISEASE",
#     'name': "ALZHEIMER'S DISEASE",
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0004975'],
#                  'DOID': ['DOID:10652'],
#                  'UMLS': ['C0002395'],
#                  'name': ["ALZHEIMER'S DISEASE", 'ALZHEIMERS DISEASE'],
#                  'MESH': ['D000544']})},
#    {'id': 'NAME:PULMONARY HYPERTENSION',
#     'name': 'PULMONARY HYPERTENSION',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005149'],
#                  'DOID': ['DOID:6432'],
#                  'UMLS': ['C0020542'],
#                  'name': ['PULMONARY HYPERTENSION'],
#                  'MESH': ['D006976']})},
#    {'id': 'NAME:DIABETES MELLITUS, NON-INSULIN-DEPENDENT',
#     'name': 'DIABETES MELLITUS, NON-INSULIN-DEPENDENT',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005148'],
#                  'DOID': ['DOID:9352'],
#                  'UMLS': ['C0011860'],
#                  'name': ['DIABETES MELLITUS, NON-INSULIN-DEPENDENT',
#                   'TYPE 2 DIABETES MELLITUS'],
#                  'MESH': ['D003924']})},
#    {'id': 'NAME:METABOLIC DISEASE',
#     'name': 'METABOLIC DISEASE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005066'],
#                  'DOID': ['DOID:0014667'],
#                  'UMLS': ['C0025517'],
#                  'name': ['METABOLIC DISEASE', 'METABOLIC DISEASES'],
#                  'MESH': ['D008659']})},
#    {'id': 'NAME:CORONAVINAE INFECTIOUS DISEASE',
#     'name': 'CORONAVINAE INFECTIOUS DISEASE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005719'],
#                  'name': ['CORONAVINAE INFECTIOUS DISEASE'],
#                  'MESH': ['D018352']})},
#    {'id': 'NAME:PULMONARY EDEMA',
#     'name': 'PULMONARY EDEMA',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0006932'],
#                  'DOID': ['DOID:11396'],
#                  'UMLS': ['C0034063'],
#                  'name': ['PULMONARY EDEMA'],
#                  'MESH': ['D011654']})},
#    {'id': 'NAME:CHRONIC RENAL FAILURE SYNDROME',
#     'name': 'CHRONIC RENAL FAILURE SYNDROME',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0024327'],
#                  'UMLS': ['C0022661'],
#                  'name': ['CHRONIC RENAL FAILURE SYNDROME',
#                   'KIDNEY FAILURE, CHRONIC'],
#                  'MESH': ['D051436']})},
#    {'id': 'NAME:SEVERE ACUTE RESPIRATORY SYNDROME',
#     'name': 'SEVERE ACUTE RESPIRATORY SYNDROME',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005091'],
#                  'DOID': ['DOID:2945'],
#                  'UMLS': ['C1175175'],
#                  'name': ['SEVERE ACUTE RESPIRATORY SYNDROME'],
#                  'MESH': ['D045169']})},
#    {'id': 'NAME:ARTERIOSCLEROSIS',
#     'name': 'ARTERIOSCLEROSIS',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0002277'],
#                  'DOID': ['DOID:2349'],
#                  'UMLS': ['C0003850'],
#                  'name': ['ARTERIOSCLEROSIS', 'ARTERIOSCLEROSIS (DISEASE)'],
#                  'MESH': ['D001161']})},
#    {'id': 'NAME:RENAL AMINOACIDURIA',
#     'name': 'RENAL AMINOACIDURIA',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0006944'],
#                  'name': ['RENAL AMINOACIDURIA'],
#                  'MESH': ['D000608']})},
#    {'id': 'NAME:PLEURAL TUBERCULOSIS',
#     'name': 'PLEURAL TUBERCULOSIS',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005922'],
#                  'DOID': ['DOID:106'],
#                  'UMLS': ['C0041326'],
#                  'name': ['PLEURAL TUBERCULOSIS'],
#                  'MESH': ['D014396']})},
#    {'id': 'NAME:CORONARY ARTERIOSCLEROSIS',
#     'name': 'CORONARY ARTERIOSCLEROSIS',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005010'],
#                  'DOID': ['DOID:3393'],
#                  'UMLS': ['C0151744',
#                   'C0010054',
#                   'C0264694',
#                   'C0010068',
#                   'C1956346'],
#                  'name': ['CORONARY ARTERIOSCLEROSIS',
#                   'CORONARY ARTERY DISEASE',
#                   'CORONARY HEART DISEASE',
#                   'MYOCARDIAL ISCHEMIA'],
#                  'MESH': ['D003324', 'D017202', 'D003327']})},
#    {'id': 'NAME:INFERTILITY DUE TO EXTRATESTICULAR CAUSE',
#     'name': 'INFERTILITY DUE TO EXTRATESTICULAR CAUSE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0001877'],
#                  'DOID': ['DOID:14096'],
#                  'UMLS': ['C0021360'],
#                  'name': ['INFERTILITY DUE TO EXTRATESTICULAR CAUSE']})},
#    {'id': 'NAME:CIRRHOSIS OF LIVER',
#     'name': 'CIRRHOSIS OF LIVER',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005155'],
#                  'DOID': ['DOID:5082'],
#                  'UMLS': ['C0023890'],
#                  'name': ['CIRRHOSIS OF LIVER', 'LIVER CIRRHOSIS'],
#                  'MESH': ['D008103']})},
#    {'id': 'NAME:SYSTOLIC HEART FAILURE',
#     'name': 'SYSTOLIC HEART FAILURE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0006993'],
#                  'DOID': ['DOID:9651'],
#                  'UMLS': ['C1135191'],
#                  'name': ['SYSTOLIC HEART FAILURE'],
#                  'MESH': ['D054143']})},
#    {'id': 'NAME:IDIOPATHIC PULMONARY HYPERTENSION',
#     'name': 'IDIOPATHIC PULMONARY HYPERTENSION',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0015924'],
#                  'UMLS': ['C2973725', 'C0152171'],
#                  'name': ['IDIOPATHIC PULMONARY HYPERTENSION',
#                   'PULMONARY ARTERIAL HYPERTENSION'],
#                  'MESH': ['C536282'],
#                  'ORPHANET': ['182090']})},
#    {'id': 'NAME:INFARCTION, MIDDLE CEREBRAL ARTERY',
#     'name': 'INFARCTION, MIDDLE CEREBRAL ARTERY',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0006857'],
#                  'DOID': ['DOID:3525'],
#                  'UMLS': ['C0740392'],
#                  'name': ['INFARCTION, MIDDLE CEREBRAL ARTERY',
#                   'MIDDLE CEREBRAL ARTERY INFARCTION'],
#                  'MESH': ['D020244']})},
#    {'id': 'NAME:ATHEROSCLEROSIS',
#     'name': 'ATHEROSCLEROSIS',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005311'],
#                  'DOID': ['DOID:1936'],
#                  'UMLS': ['C0004153'],
#                  'name': ['ATHEROSCLEROSIS'],
#                  'MESH': ['D050197']})},
#    {'id': 'NAME:ABDOMINAL AORTIC ANEURYSM',
#     'name': 'ABDOMINAL AORTIC ANEURYSM',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005350'],
#                  'DOID': ['DOID:7693'],
#                  'UMLS': ['C0162871'],
#                  'name': ['ABDOMINAL AORTIC ANEURYSM',
#                   'AORTIC ANEURYSM, ABDOMINAL'],
#                  'MESH': ['D017544']})},
#    {'id': 'NAME:ENDOMYOCARDIAL FIBROSIS',
#     'name': 'ENDOMYOCARDIAL FIBROSIS',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0006746'],
#                  'DOID': ['DOID:12932'],
#                  'UMLS': ['C0553980'],
#                  'name': ['ENDOMYOCARDIAL FIBROSIS'],
#                  'MESH': ['D004719']})},
#    {'id': 'NAME:GLAUCOMA',
#     'name': 'GLAUCOMA',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005041'],
#                  'DOID': ['DOID:1686'],
#                  'UMLS': ['C0017601'],
#                  'name': ['GLAUCOMA', 'GLAUCOMA (DISEASE)'],
#                  'MESH': ['D005901']})},
#    {'id': 'NAME:BILIARY CIRRHOSIS',
#     'name': 'BILIARY CIRRHOSIS',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005388'],
#                  'DOID': ['DOID:12236'],
#                  'UMLS': ['C0023892', 'C0008312', 'C0859942'],
#                  'name': ['BILIARY CIRRHOSIS',
#                   "HANOT'S CIRRHOSIS",
#                   'PRIMARY BILIARY CHOLANGITIS',
#                   'PRIMARY BILIARY CIRRHOSIS'],
#                  'MESH': ['D008105'],
#                  'ORPHANET': ['186']})},
#    {'id': 'NAME:NICOTINE DEPENDENCE',
#     'name': 'NICOTINE DEPENDENCE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0008575'],
#                  'DOID': ['DOID:0050742'],
#                  'UMLS': ['C1861063', 'C0028043'],
#                  'name': ['NICOTINE DEPENDENCE',
#                   'TOBACCO ADDICTION, SUSCEPTIBILITY TO (FINDING)'],
#                  'MESH': ['D012907', 'D014029'],
#                  'OMIM': ['188890']})},
#    {'id': 'NAME:SPONTANEOUS ABORTION',
#     'name': 'SPONTANEOUS ABORTION',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['C0000786'],
#                  'UMLS': ['C0000786'],
#                  'name': ['SPONTANEOUS ABORTION']})},
#    {'id': 'NAME:INJURY',
#     'name': 'INJURY',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0021178'],
#                  'UMLS': ['C3263723'],
#                  'name': ['INJURY']})},
#    {'id': 'NAME:HYPOTENSION (DISEASE)',
#     'name': 'HYPOTENSION (DISEASE)',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005468'],
#                  'name': ['HYPOTENSION (DISEASE)'],
#                  'MESH': ['D007022']})},
#    {'id': 'NAME:MECONIUM ASPIRATION SYNDROME',
#     'name': 'MECONIUM ASPIRATION SYNDROME',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0006851'],
#                  'DOID': ['DOID:11049'],
#                  'UMLS': ['C0025048'],
#                  'name': ['MECONIUM ASPIRATION SYNDROME'],
#                  'MESH': ['D008471'],
#                  'ORPHANET': ['70588']})},
#    {'id': 'NAME:MCCUNE-ALBRIGHT SYNDROME',
#     'name': 'MCCUNE-ALBRIGHT SYNDROME',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0018919'],
#                  'UMLS': ['C0242292'],
#                  'name': ['MCCUNE-ALBRIGHT SYNDROME'],
#                  'MESH': ['D005359'],
#                  'ORPHANET': ['562']})},
#    {'id': 'NAME:LYMPHOPENIA',
#     'name': 'LYMPHOPENIA',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0003783'],
#                  'DOID': ['DOID:614'],
#                  'UMLS': ['C0024312'],
#                  'name': ['LYMPHOPENIA', 'LYMPHOPENIA (DISEASE)'],
#                  'MESH': ['D008231']})},
#    {'id': 'NAME:MACROPHAGE ACTIVATION SYNDROME',
#     'name': 'MACROPHAGE ACTIVATION SYNDROME',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0015545'],
#                  'UMLS': ['C1096155'],
#                  'name': ['MACROPHAGE ACTIVATION SYNDROME'],
#                  'MESH': ['D055501'],
#                  'ORPHANET': ['158061']})},
#    {'id': 'NAME:NEURAL TUBE DEFECT',
#     'name': 'NEURAL TUBE DEFECT',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0018075'],
#                  'DOID': ['DOID:0080074'],
#                  'UMLS': ['C0027794'],
#                  'name': ['NEURAL TUBE DEFECT', 'NEURAL TUBE DEFECTS'],
#                  'MESH': ['D009436'],
#                  'ORPHANET': ['3388']})},
#    {'id': 'NAME:RETINITIS PIGMENTOSA 3',
#     'name': 'RETINITIS PIGMENTOSA 3',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0010227'],
#                  'DOID': ['DOID:0110414'],
#                  'UMLS': ['C1845667'],
#                  'name': ['RETINITIS PIGMENTOSA 3'],
#                  'MESH': ['C564520'],
#                  'OMIM': ['300029']})},
#    {'id': 'NAME:URINARY SYSTEM DISEASE',
#     'name': 'URINARY SYSTEM DISEASE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0002118'],
#                  'DOID': ['DOID:18'],
#                  'UMLS': ['C1335051'],
#                  'name': ['URINARY SYSTEM DISEASE'],
#                  'MESH': ['D014570']})},
#    {'id': 'NAME:CONGENITAL NONBULLOUS ICHTHYOSIFORM ERYTHRODERMA',
#     'name': 'CONGENITAL NONBULLOUS ICHTHYOSIFORM ERYTHRODERMA',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0017778'],
#                  'UMLS': ['C0079154'],
#                  'name': ['CONGENITAL NONBULLOUS ICHTHYOSIFORM ERYTHRODERMA',
#                   'LAMELLAR ICHTHYOSIS'],
#                  'MESH': ['D017490'],
#                  'ORPHANET': ['313']})},
#    {'id': 'NAME:SYNDROMIC DISEASE',
#     'name': 'SYNDROMIC DISEASE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0002254'],
#                  'DOID': ['DOID:225'],
#                  'UMLS': ['C0039082'],
#                  'name': ['SYNDROMIC DISEASE'],
#                  'MESH': ['D013577']})},
#    {'id': 'NAME:KIDNEY FAILURE',
#     'name': 'KIDNEY FAILURE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0001106'],
#                  'DOID': ['DOID:1074'],
#                  'UMLS': ['C0035078'],
#                  'name': ['KIDNEY FAILURE'],
#                  'MESH': ['D051437']})},
#    {'id': 'NAME:IMPAIRED RENAL FUNCTION DISEASE',
#     'name': 'IMPAIRED RENAL FUNCTION DISEASE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0001343'],
#                  'DOID': ['DOID:11705'],
#                  'UMLS': ['C0029791'],
#                  'name': ['IMPAIRED RENAL FUNCTION DISEASE']})},
#    {'id': 'NAME:ACUTE KIDNEY FAILURE',
#     'name': 'ACUTE KIDNEY FAILURE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0002492'],
#                  'DOID': ['DOID:3021'],
#                  'name': ['ACUTE KIDNEY FAILURE'],
#                  'MESH': ['D058186']})},
#    {'id': 'NAME:PNEUMONIA',
#     'name': 'PNEUMONIA',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005249'],
#                  'DOID': ['DOID:552'],
#                  'UMLS': ['C0032285'],
#                  'name': ['PNEUMONIA'],
#                  'MESH': ['D011014']})},
#    {'id': 'NAME:FOCAL GLOMERULOSCLEROSIS',
#     'name': 'FOCAL GLOMERULOSCLEROSIS',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005363'],
#                  'DOID': ['DOID:1312'],
#                  'UMLS': ['C0017668'],
#                  'name': ['FOCAL GLOMERULOSCLEROSIS',
#                   'FOCAL SEGMENTAL GLOMERULOSCLEROSIS'],
#                  'MESH': ['D005923']})},
#    {'id': 'NAME:LIVER DISEASE',
#     'name': 'LIVER DISEASE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005154'],
#                  'DOID': ['DOID:409'],
#                  'UMLS': ['C0023895'],
#                  'name': ['LIVER DISEASE', 'LIVER DISEASES'],
#                  'MESH': ['D008107']})},
#    {'id': 'NAME:KIDNEY CANCER',
#     'name': 'KIDNEY CANCER',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0002367'],
#                  'DOID': ['DOID:263'],
#                  'UMLS': ['C0740457', 'C0022665', 'C0494158'],
#                  'name': ['KIDNEY CANCER',
#                   'KIDNEY NEOPLASM',
#                   'MALIGNANT NEOPLASM OF KIDNEY'],
#                  'MESH': ['D007680']})},
#    {'id': 'NAME:CHOLERA',
#     'name': 'CHOLERA',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0015766'],
#                  'DOID': ['DOID:1498'],
#                  'UMLS': ['C0008354'],
#                  'name': ['CHOLERA'],
#                  'MESH': ['D002771'],
#                  'ORPHANET': ['173']})},
#    {'id': 'NAME:MALARIA',
#     'name': 'MALARIA',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0005136'],
#                  'DOID': ['DOID:12365'],
#                  'UMLS': ['C1969379',
#                   'C1970029',
#                   'C1970028',
#                   'C0024530',
#                   'C2720293',
#                   'C1855457'],
#                  'name': ['MALARIA',
#                   'MALARIA, CEREBRAL, RESISTANCE TO',
#                   'MALARIA, CEREBRAL, SUSCEPTIBILITY TO (FINDING)',
#                   'MALARIA, RESISTANCE TO',
#                   'MALARIA, SEVERE, SUSCEPTIBILITY TO',
#                   'MALARIA, SUSCEPTIBILITY TO (FINDING)'],
#                  'MESH': ['D008288'],
#                  'ORPHANET': ['673']})},
#    {'id': 'NAME:INTERSTITIAL LUNG DISEASE',
#     'name': 'INTERSTITIAL LUNG DISEASE',
#     'type': 'Disease',
#     'equivalent_identifiers': defaultdict(set,
#                 {'MONDO': ['MONDO:0015925'],
#                  'DOID': ['DOID:3082'],
#                  'UMLS': ['C0206062'],
#                  'name': ['INTERSTITIAL LUNG DISEASE',
#                   'LUNG DISEASES, INTERSTITIAL'],
# ...
#    {'qg_id': 'e1',
#     'kg_id': ['e88189d0ccaacdbb182041af39958b381e910feff4ab4a3226c6a120fd0d75e1',
#      'b6c915ea5ccfa27388af9de93d0593653fe31e5cd789729613ccaa90749f4d71',
#      'b6c915ea5ccfa27388af9de93d0593653fe31e5cd789729613ccaa90749f4d71',
#      '7e686e75d17c035a7a9aa31630390f080e190576ea8990cfa0339164c96e9545']},
#    {'qg_id': 'e1',
#     'kg_id': ['46591f81d17129594df60d2eb0db8591430ffe93525eccfd1bc240414f66c9e7']},
#    {'qg_id': 'e1',
#     'kg_id': ['efde7cd3eff5f38a00981bcf9cfed63e0f835fff53ab367981266acfed12ce68',
#      '27e0a09609ba657f3a213a31e738454abd3184559e6f9ae74dfb497f3e6fff96',
#      '27e0a09609ba657f3a213a31e738454abd3184559e6f9ae74dfb497f3e6fff96',
#      'f182273c1c60831ed6cdba436517b683b922c03a66b75c12e71e582b909cb7bf',
#      '560201ead362975d3bbf83ce523d41c5823a08abfd0ef7edb7720a04ae314ae8',
#      'e40e4bc0b1a80b1312a136f33edf88abc2a2e6c93e875a2c209074a61f8709e6']},
#    {'qg_id': 'e1',
#     'kg_id': ['0be844e5cf5a296a88ab38339d62bc9c9aad4b507eaf4390c8c59bb647cc176a']},
#    {'qg_id': 'e1',
#     'kg_id': ['f401cd9eb7718339b4bfba31df8797d0983d8a91ca9ef831fbc662ac7746f8df']},
#    {'qg_id': 'e1',
#     'kg_id': ['bbb273751c009612f9385110e318190952bbe67667bf0943ecf624407e7760d9']},
#    {'qg_id': 'e1',
#     'kg_id': ['a7f074de225f5f855bf4917942c62ce7340641c8b16dbced0d86d4f408f4f687']},
#    {'qg_id': 'e1',
#     'kg_id': ['74affc7ab74201b9ac82449e6ad4ea440e6abdf7f35859b460e0d761516fd948']},
#    {'qg_id': 'e1',
#     'kg_id': ['3f866d51f05c2c7a2eb3b86ce6cad194aeb5bb70e702a670982e7451895c0352',
#      'da2ea5e1d4cbb6d510aa690066d4cd65db62fb49a0ef5947c37b4a5ce097aba0']},
#    {'qg_id': 'e1',
#     'kg_id': ['3370404df649704904faafb036409428192567e3af158fbd599e6491d0cdd049']},
#    {'qg_id': 'e1',
#     'kg_id': ['b93e9a0d60bfb30bebe52519add2ae5507a798b06a61e20d8a35043417d3161f']},
#    {'qg_id': 'e1',
#     'kg_id': ['f4eb92f071a7dd2396d8304b43ad26495b4b3f87bd4c8c43e52d1ba926ca58d9',
#      '33be72657d4695e8383a1afe5a9bda334465b0a281e7c9328f5ccb5db0fe4d3d']},
#    {'qg_id': 'e1',
#     'kg_id': ['41bb56edbe606e28ebd6a65f489523440707f811ed8d292b86fcd0369996ec7d',
#      '3166fb068a214cf538159169d3c0d07fb5af723fbb82e29a873cce00b51f2ff4',
#      'dd59897523b852209cbdf07accf2f31614147ce878dc3c423305a505c4d7daa0',
#      'a47fc7bcd2925141d980115a0f3165a5ad6b4e3500aeb88e4719ee7db87f7499']},
#    {'qg_id': 'e1',
#     'kg_id': ['a5f15293fa22fe44a6a5e51a3f8c79ec662a30804a0b0f437dcb5177dc4f86e7',
#      '4e2d2bdbc28a98baf692dc5c598c10489acf8c4b957699c1889a598207b421ee',
#      '318720636189bf7f6e76436aec3748d81da2db72a256161b4d6401b09a2d6936',
#      '39a0aa4495e6f6292eae1094f74962ac508e7a42c984e06d60c852506125a8ae',
#      'f4a16bb459f704d0d823a337a03f230eb7b20ee576de931da0d23c56a2bfc66d',
#      '54c02a7d30dcd25808c0241236a4823d4d2778c8acad1ecf8cdede94810ebd89']},
#    {'qg_id': 'e1',
#     'kg_id': ['92bc00632d0e94959cb94f82d5a63c817955efd204b4cdff1d95ff4a63f940c3']},
#    {'qg_id': 'e1',
#     'kg_id': ['c352641395318aa4fc981d9e8cd8380669b9a0f8faf37a8951d2947cdfe7970b']},
#    {'qg_id': 'e1',
#     'kg_id': ['ea5574bee776322721c064413e2eb76feb00978021d44c1caa7a41c0d26110ba']},
#    {'qg_id': 'e1',
#     'kg_id': ['97d41705ba9448c8b2fe32b47305444c11dc9adc935651e79156c7dbc1d6f80c',
#      '3700204a350bd30625927cf6f3ce4f47efd979c2f2cd46a1bd716d1c54bbb897',
#      '6588b3baca37eba3ad2449347846dc709a5ed6486d0591c571f3b8f849628ac4',
#      '021209522646a4b2d62b31ba640281ad6e1e35aaf16d72fbe4a3c9609fbf6b54',
#      '54b0b80bebd220af3e3dbce706b64916df7c42c9f9f4e2484e8709eac10df23a',
#      'ccf3a35fbd3441d4556e43c3084ff001abe77e889e8535cd4bc86d792e4d9b1f',
#      '8c59b7c0264ea0c1218ed347a3e293c679cd2bfb6e9f4de76f09b4d2d2f44f55']},
#    {'qg_id': 'e1',
#     'kg_id': ['95a26062d645af0466c51024efccb759361c7c96174c7fc6945fdd39969948a6']},
#    {'qg_id': 'e1',
#     'kg_id': ['3feb46d82d1d901f721c29bb80ad7a181c7b3184ae7eca13a1affb65afe3aec9',
#      'ec5f819fd1b7380b17cd70e59c29753f0857021860e9aeda2cbf6177088e220b']},
#    {'qg_id': 'e1',
#     'kg_id': ['dbc864d5291d3b011e3636ce40a01e3b59c71127dad11228a280ec3e5aca07bb']},
#    {'qg_id': 'e1',
#     'kg_id': ['423656fe81f09912689818aacc351aa1c8da17aa925ff1b0534cf0f3a6010215',
#      'f5bae474fa4631cc2ac3574188e0a33fbd5d6fa31573db4f8c76eaf7c59e7a51',
#      '0c1b24b7a5d151104c125a08fa0c2f82f6e18261501dd33444234549d9753b6e',
#      '787cf83fd81bbe1632d2858d606a4dcdb62b891677d6e41038dad9c4e81ce295',
#      'e8232374aedad003e82865ee7e44feef2f63b27ab5f546592a2fd1e6d3f8299b']},
#    {'qg_id': 'e1',
#     'kg_id': ['ff838eff7ebaa08fa588db1e1fdca9c94db8a57cb0dd6a71663b2d9e2591c897',
#      '1a734728687d877362e15c5bd84104f95af1eaf6aa0e3b3919d627515c2196b1',
#      '8e5e00e5e92815fd8b9356c046cf5a25ad8364bb25f5cd91dff8a38b2419d01c']},
#    {'qg_id': 'e1',
#     'kg_id': ['a2c9d32bbf2fc6785b7cdc3572cd326c6e1608f322b21b7f009490b3c7cd5662',
#      '32153cfe9af6d7c9655c22adb51d5ae0952ffc86df9ba3fb074a167ffa200a77',
#      '698e3f21ffe96cce0e79eb2314d0b3b9c5be5a075b4068e8a5206795d672e28a']},
#    {'qg_id': 'e1',
#     'kg_id': ['39276487ef6d8a9dab0f9c199c2eee6c5c45bea3f1d4e766ef62a9f6a7e1e0ae',
#      '472a9d42581a2079fcd8a4760576d9f501b1963591e54cb4d5dfbc1ea5a6ac44',
#      '81a3f162187a6e136fb11077420cd245f50cdc7c0fa422ca0fdb923a2bfaf9c0']},
#    {'qg_id': 'e1',
#     'kg_id': ['1c7178e5402e8bc37c728c843e9c849999f91e4149a7e42fe6b5db1ea14e8db8',
#      '4a067b01c5c52562e6c8ccf371cae7750d73e4ccf5462785c808a71f1742a2a9']},
#    {'qg_id': 'e1',
#     'kg_id': ['580b194ef443ce9de25f271abb18b70ae95c96d1d80e8d553ddfd7a7f5a2ae54']},
#    {'qg_id': 'e1',
#     'kg_id': ['d1a99d703e534da440e26466f78136c23fa22253f59e503587962a178f76aacc',
#      'f277d247365609256ccb2fc2c7f86838bc87f37bc1a5e6715c479d2bb5a10d8f',
#      'e12cfad06ec77da2a0ce00cad821b9eaa973adb192a83e48d462ad6e1c44e03b',
#      '7affd5f2012b82addff35768345c4b454a4048955332a6d30ad79c7739a34edf']},
#    {'qg_id': 'e1',
#     'kg_id': ['cac363eceff6addbc711c2e2051d22ae67071e7784b29298e1896ce97e369deb']},
#    {'qg_id': 'e1',
#     'kg_id': ['55d7c8d588310f427fe817a34baf6aecc0797c396c86a649b57285e138036604']},
#    {'qg_id': 'e1',
#     'kg_id': ['d43dd4752ab14a7be685d7b01394d151b438f7a0bf60a80716eee10644eaa2e9',
#      '8e98d00aa5b87b71ea720ff0a5e811c3898042e700123f3fb43527947c06a64d']},
#    {'qg_id': 'e1',
#     'kg_id': ['2ec40c1da0a5b3bc91be13c63227da477e0c32209d284d8b6b43592f6906e4cf']},
#    {'qg_id': 'e1',
#     'kg_id': ['92eb818cffafcf4d313a7652473f561c8e90c19a7d2899db9caeacb7d7914489']},
#    {'qg_id': 'e1',
#     'kg_id': ['e13464fbf78fe65fc38a79cc18d9d4916f9e87f1045e94415f27d4091fdd7503']},
#    {'qg_id': 'e1',
#     'kg_id': ['17a52d8ba3fbb14ca5ba9cb4a7eabfeffa9d119a1cf3be6e773f616cb92eab5a']},
#    {'qg_id': 'e1',
#     'kg_id': ['08ec32afc0b8c6a44640f1ae7aae6ad246b89743adf5783e3607f5cbd49c9aef']},
#    {'qg_id': 'e1',
#     'kg_id': ['005a642ad5a275c0fc5e6d51284fb7e3ad06eb1d408191dd9e6d3035bdf12834',
#      'dbdcd42ef2135bfa9f95ce07118224be0154709ad32520e1a3e9ff621333ba9a',
#      'e3af0d41a9cfcc843b96bb1da767b39d9dbe3b0d46e7e4f181a640f1c3e12703']},
#    {'qg_id': 'e1',
#     'kg_id': ['682429b5781e313a54141224b00955eddb90a0ddea3adbfa603fb92df1636736',
#      '238a27d49f378ce348bfc81513d43ce213cad925093b94ff32ef99b5ae7378cf']},
#    {'qg_id': 'e1',
#     'kg_id': ['34507f13d239d6e9b6bcee61907c17fb68c89c3d7a4d9212733aa11645a96a57']},
#    {'qg_id': 'e1',
#     'kg_id': ['b86ac375e1760a8f6076404a58a51dcacf492dde5076826d5c5702f45647dd24']},
#    {'qg_id': 'e1',
#     'kg_id': ['e34c427d48a4688c7f36b53f8d2512fd4c2efb1dba7b5d853d7deb12f6be500d',
#      '8585282a798087f780c8f48c511399c83c7959f5deec996f82c3cc938551928e',
#      '16536a2812a48a5ecfccb371dd44353b16862f1507921d5c112739ee77e1e155',
#      'e1ec04d3385fda47a2020ff592386c9b6cb5d7acac478537cbe38d82897fd00c']},
#    {'qg_id': 'e1',
#     'kg_id': ['413c281acea2af1fb952b6597678d875febb1158407081952bd36f8fa3f8e9db']},
#    {'qg_id': 'e1',
#     'kg_id': ['91b45d772d8fe0f60fc979670aed392bd2fc588fef7f69b2965738ddfb2c4921']},
#    {'qg_id': 'e1',
#     'kg_id': ['fe81b2f826d70733c526fd7e0e9b795fcba680bc3586771eeb24e51760557e20',
#      '9452fe8e4dee5b0a7a599c06d000915991f16002e85e76105c66669427bf0121',
#      '030cfa03b38726ea76156c615af9e411f59c3d2f472c47adbe7f057eca50be12']},
#    {'qg_id': 'e1',
#     'kg_id': ['49f1a7382358cdcc8934bb21f8c5ef25df5ec05d21d5477136f4e27572eb130c']},
#    {'qg_id': 'e1',
#     'kg_id': ['a17cf0c685c93ea9d3d231c3f0f7e18ffc8c55ed1f2098bb511c46fbc6ef81b9']},
#    {'qg_id': 'e1',
#     'kg_id': ['f4954f23fdd6337a53e7ac04e9bf041fbc61b80bc481cf77280a31c96e960dec',
#      '2659e8d668ade0a2d812ab217627bbad753288a805cc80ce65de81a6a9e0f2fc']},
#    {'qg_id': 'e1',
#     'kg_id': ['87187f8fb312c5fa5011ea4e6384ccec5ca957c177b5bb5904e0aad38dffcb04',
#      '5b2bab8759feb8c4094b229f9b1bcfbcbc1176f7b6ca8e1e545dad0d32b11e3b']},
#    {'qg_id': 'e1',
#     'kg_id': ['204b6c0b79d80fb36de2a259a2bbe6f5e18f078555dd77247e7807142922225f',
#      '9de489aa957198b1f4f39a9415ba67bbcad8dbe3c7805a7ee52c09c8b3b6f16b',
#      '662c7cb84434ba99acb4a48ade18d0600694db35a0b5876188813b2fd31e89f7']},
#    {'qg_id': 'e1',
#     'kg_id': ['3bc6b09be0d68db8139f5daaa34327cdbe2700a33428bfad98955bb4e235879e']},
#    {'qg_id': 'e1',
#     'kg_id': ['053ed6b5e9304c6b11bd099d8fe62284c8331711094e1f2de066e0f4dc07d2b0',
#      'f3d00df65f761f7cbbeeecee4e60bd8ebd1241cfc37648b9a3ae87e155fea916',
#      'f8404fcf904f86a3a60ec33f6e02403128f840b5ad21f28ff8c9a916035fd12b',
#      '2ad97f1a399cd884d92f7594c11396fcf8dae5938d4e38cd54e5d1cb10a6f321']},
#    {'qg_id': 'e1',
#     'kg_id': ['2f4973c6acc126f1670ad85471dfe4773f7fadc1cd62a67134787d9de820e3b9']},
#    {'qg_id': 'e1',
#     'kg_id': ['9d918045e93cd8c46f0e623f221f1e262d4637f6f4b26195e9bfaa023a5bdc1d']},
#    {'qg_id': 'e1',
#     'kg_id': ['67c8b8696870533ae52920ef1801e8724bbf2b45fce45b2b966f8732f0f96c8c',
#      '24129ac043c90b2163a5455042833854c762656f1402f7d698a52cef71fae7d9']},
#    {'qg_id': 'e1',
#     'kg_id': ['544cc899a8b724c73c040887be5a7c06c685547ffcb6fe6fe5ae99cb4b483c6f',
#      '070044fab45637149d0e00964885f329bead4acb55653dedbfb866c885527b74']},
#    {'qg_id': 'e1',
#     'kg_id': ['e1a0cedb6e20a1c1f9fe8f63031aaaf2a9feff1373a891581f36458087263e5e']},
#    {'qg_id': 'e1',
#     'kg_id': ['57a3774ed11c347f208c34da97addc114ad784dbeae3dab6023c0950531f4d29',
#      'b207f00aaa67fc61c219ca5987cfa32861fb0ad93c416ff09768836020d67927',
#      'ee7e1d9b82d00adc169f571ced1bd600a9aad65400edc0b40b4fa6732095e521',
#      'aeebae037ac8d967ee1890647ab4df44da2810cff4011391c3c9d92f53277628']},
#    {'qg_id': 'e1',
#     'kg_id': ['c420ab0b91598a761279669e6a8174b4f93692bbb283e659e306d2aa631bbb13',
#      'e23a68d6ddfb60908a3c64e4cd216a8effac1f1f555ebe4b317996c98f5175a8']},
#    {'qg_id': 'e1',
#     'kg_id': ['7047ff6dbc6eccab30444a7d9ad3ea1d56e77fad0d0bcc3ebfa624a838cd5e59']},
#    {'qg_id': 'e1',
#     'kg_id': ['ae91b63c795b2c47b5c8a6ff3e8e6a28db4c5228dd20af422aed42bc676822be']},
#    {'qg_id': 'e1',
#     'kg_id': ['b1f4d2e84be1bcc95117c22fa336ba016bc1c1be171a47674a3061af02a47b57',
#      '32499d916421b05a5d0387850079d6a33d57eca8cd8a2755f1ef0171ce24c8e2',
#      '81100704727dc9c98be14f110ea6eb2d9dec0d681eee9e45bc6d81805c5aec07',
#      '3d59affa10203cd411ac7ce524b2c4d6e53b96dcb3dddd2e5cdda6bef4a11623']},
#    {'qg_id': 'e1',
#     'kg_id': ['4260775caf225a83efad04826f80e7ea1ace95236cec89ddf75a1e1dac451725']},
#    {'qg_id': 'e1',
#     'kg_id': ['fe7466d70de274129260e34bf9a34c76c1067990267ecfdfe1595572b02d71c9']},
#    {'qg_id': 'e1',
#     'kg_id': ['25010132b0420b8f61532aae734412a82f9eeb4a1bf20d706e610c2304aa5b18']},
#    {'qg_id': 'e1',
#     'kg_id': ['4ac37ea10620eddacb7ccc84b37e3d4f10caa29f0ddd3ec6368223a00e7b4714']},
#    {'qg_id': 'e1',
#     'kg_id': ['18ad1989d0fa0c52597bf77a2378310fae64f7a363147bfd0f8b84604aff6dab']},
#    {'qg_id': 'e1',
#     'kg_id': ['afb57a90b86fe2157768803153bce4b84f707de073afaf8e002b436c4accbc1e',
#      '456e36c0c89767818250f3c995d79e2adce90239165ac554a4e3f90ba9e35199',
#      '9ca7c55b29f973dc96f5ebcad59d27ab3cea3f44f7f8329f965bfe5ba1529652']},
#    {'qg_id': 'e1',
#     'kg_id': ['5e9e37b632a7a04567b77b51eedec1a830d0d22f9a46e7361340081e956f2f3d',
#      'eee5ba68576b631b9a73aa0add04c1cca530b96b9c4ddeeca96063a2613c9617']},
#    {'qg_id': 'e1',
#     'kg_id': ['874d1963481207af3c4613ec629c02447de6a08d6abfcf3083a611c572410e78',
#      'f343175b7be09b6c6cc7d6af4e26d8576db242f347f626d7d97bab2b6311c1d2',
#      '7ef068915fb89c0fdf0c9cb382444503e1e0f488693f17b0094d86db125cb1c9']},
#    {'qg_id': 'e1',
#     'kg_id': ['684468fa78dd8cffbb1982b03d1c7838baaafb5e3dbc1ec29efb8772c1b9deb3']},
#    {'qg_id': 'e1',
#     'kg_id': ['103087e6859fdf8d5e3b277867f7901267e7c973ccd6db4acb4b4d2b4ef28038']},
#    {'qg_id': 'e1',
#     'kg_id': ['66b131b2779bb64110c3aceb2c9fb1a6a9c70d26a61d6504770082779e39469e']},
#    {'qg_id': 'e1',
#     'kg_id': ['270384df221c421cdd154a17603620f9054a9583873fa7c351d3612bf2c7292d']},
#    {'qg_id': 'e1',
#     'kg_id': ['688ad0310a6b127f0cf3dbc8f0f5a8c29f4109b2a81893201a6ea11b495d4264']},
#    {'qg_id': 'e1',
#     'kg_id': ['ffa17de00004abce428d81f8202790625515a77b36144b56c7bd51d5aa398ac0']},
#    {'qg_id': 'e1',
#     'kg_id': ['f86785bff87a49ad85a5ebafb32796c58e25b17ac48be6225d81a00207c282a4']},
#    {'qg_id': 'e1',
#     'kg_id': ['de65d938225e1ee64509109df0e05781a098322d61fea5000b055fe6a9d19f22']},
#    {'qg_id': 'e1',
#     'kg_id': ['9337b6d5be030084d85ba90d7136b9fec4ef047fb1a9a89105d1406e4b3f763c']},
#    {'qg_id': 'e1',
#     'kg_id': ['1de0ad27800c22f33e7f82ac819bf9b2158c58fcb760f641a8ad76699218493a']},
#    {'qg_id': 'e1',
#     'kg_id': ['e4507d4ad3792649dbfc9f964967fcb76329e0cbb851711e47bbd9356280b22c']},
#    {'qg_id': 'e1',
#     'kg_id': ['2f84d7da19db1aa1be5b2cdab171877c84fe50131eb6fe9ebdf0198f2df10bfc',
#      'e123da61dc2c15606ed6eade8c56bf4cbf7473850946aebef2f94503ced0e6d1']},
#    {'qg_id': 'e1',
#     'kg_id': ['6ab171c242d364c7f9c4d2e0c03216408f3d454cce894917e5fcc21750bddf0b']},
#    {'qg_id': 'e1',
#     'kg_id': ['37dd42e7250c0c7dadaf1ad3e7f86f33083e028ef21e5aa4cdce9ef69a314f53']},
#    {'qg_id': 'e1',
#     'kg_id': ['3265fce641091e8cf29822d3fe091507401541ca2b415b9ba2fc814e4ab660eb']},
#    {'qg_id': 'e1',
#     'kg_id': ['3cf1dcaf7b7b416b6c81e7f4b548715c0547d15d2b21dc231c4910ba565e74b0']},
#    {'qg_id': 'e1',
#     'kg_id': ['fa8c0d8ceb5832b6d475728f666277ca74e2c612a3498413286dcaf502b2bd72']},
#    {'qg_id': 'e1',
#     'kg_id': ['c2d584c6bbab2cbb0aa8c559719e0a0ac24c1bf4e5ec589523a7faf27343a823']},
#    {'qg_id': 'e1',
#     'kg_id': ['8bc7bb32aad278bf21491dcd8e23759003344977525e67036be753946903aafb',
#      '6459d7b3b033117957daec8cfe8575be3a58ec0aac9c1767c90446e1a52716db']},
#    {'qg_id': 'e1',
#     'kg_id': ['72c633d2b3a50111ee27212ec6c980970c119ad5ede1dfa5ab038db492f3568a']},
#    {'qg_id': 'e1',
#     'kg_id': ['6a9f2e4f396f0d448f53a207b855bf56aabf20fc8377f12dcd70bd99ed65655f']},
#    {'qg_id': 'e1',
#     'kg_id': ['da51e85931196ea92cf4548a6ee4cc5426d03432902159f47a96f9ce985ad833']},
#    {'qg_id': 'e1',
#     'kg_id': ['28d88fa74ec35f4898afab89899b3645c704eaf2e49451ef7a707acac1dbbb60']},
#    {'qg_id': 'e1',
#     'kg_id': ['a4c56a28f4838f9686c561e7d49adf56d6654e409f7abb1eecbe8adcef030195']},
#    {'qg_id': 'e1',
#     'kg_id': ['826703f88bb75a55f1d72d648d6c23c9ca50e73e710f8ad2926228db0ff0342d']},
#    {'qg_id': 'e1',
#     'kg_id': ['6d7c4ea868aded9d0f23acfd6befb255327cbe7d3e3406f7bc9ac844735d0067']},
#    {'qg_id': 'e1',
#     'kg_id': ['16046ac73505e0bed760837ada41aae921695131fff7e5ab9c54d02c9861982b']},
#    {'qg_id': 'e1',
#     'kg_id': ['07ec3f84631e22d06df842b513077548855ed2ff1acf01afd213d9620a75f481']},
#    {'qg_id': 'e1',
#     'kg_id': ['30cec71d8f08aa6986cd49f0cd495371ae688b96742fb896a53d21c876823057']},
#    {'qg_id': 'e1',
#     'kg_id': ['4d32beb8c380662518c53e2c781864a91f27f648c6accbe15e9b061764f11083']},
#    {'qg_id': 'e1',
#     'kg_id': ['555573504dd82ae9f06a23bd9753fbad4bf595b083bdd4708e536f2afc2002f1']},
#    {'qg_id': 'e1',
#     'kg_id': ['458c2b9728f93afd36ef0959d290b2077edc44fe7cd58b2d78454c5122b6dc5b']},
#    {'qg_id': 'e1',
#     'kg_id': ['3a6f138857680a79d03ad64a6bf3d157d269ee39a46a0b66d373f65ca8c2fa72']},
#    {'qg_id': 'e1',
#     'kg_id': ['9f18b7b9f22ac873b984670b5762eade5fa6efb6beb52d8e15f92e64eeac0d51']},
#    {'qg_id': 'e1',
#     'kg_id': ['738e253259b2a932e718a64bc2c120832f8e5860e58e8033b8714475085101dc']},
#    {'qg_id': 'e1',
#     'kg_id': ['3964e4286cc7046719fff98a1932c486f6304c2195d21f24cdfa1789d64dd8e8']}]}}
