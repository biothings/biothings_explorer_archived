# %%
# import modules from biothings_explorer
from biothings_explorer.hint import Hint
from biothings_explorer.user_query_dispatcher import FindConnection

# %% [markdown]
# **Hint** module: Find corresponding bio-entity representation used in BioThings Explorer based on user input (could be any database IDs, symbols, names)
#
# **FindConnection** module: Find intermediate bio-entities which connects user specified input and output

# %% [markdown]
# ## Step 1: Find representation of "asthma" and "imatinib" in BTE

# %%
ht = Hint()
# find all potential representations of asthma
asthma_hint = ht.query("asthma")
# select the correct representation of asthma
asthma = asthma_hint['DiseaseOrPhenotypicFeature'][0]
asthma
# Out:
# {'mondo': 'MONDO:0004979',
#  'doid': 'DOID:2841',
#  'hp': 'HP:0002099',
#  'umls': 'C0004096',
#  'mesh': 'D001249',
#  'name': 'asthma',
#  'display': 'mondo(MONDO:0004979) doid(DOID:2841) hp(HP:0002099) umls(C0004096) mesh(D001249) name(asthma) ',
#  'type': 'DiseaseOrPhenotypicFeature',
#  'primary': {'identifier': 'mondo',
#   'cls': 'DiseaseOrPhenotypicFeature',
#   'value': 'MONDO:0004979'}}

# %%
# find all potential representations of imatinib
imatinib_hint = ht.query("imatinib")
# select the correct representation of imatinib
imatinib = imatinib_hint['ChemicalSubstance'][0]
imatinib
# Out:
# {'chembl': 'CHEMBL941',
#  'drugbank': 'DB00619',
#  'name': 'IMATINIB',
#  'pubchem': 5291,
#  'umls': 'C0935989',
#  'mesh': 'D000068877',
#  'display': 'chembl(CHEMBL941) drugbank(DB00619) name(IMATINIB) pubchem(5291) umls(C0935989) mesh(D000068877) ',
#  'type': 'ChemicalSubstance',
#  'primary': {'identifier': 'chembl',
#   'cls': 'ChemicalSubstance',
#   'value': 'CHEMBL941'}}

# %% [markdown]
# ## Step 2: Find intermediate nodes connecting imatinib and asthma

# %%
help(FindConnection)
# Out:
# Help on class FindConnection in module biothings_explorer.user_query_dispatcher:
#
# class FindConnection(builtins.object)
#  |  FindConnection(input_obj, output_obj, intermediate_nodes, registry=None)
#  |
#  |  find relationships between one specific entity and a class of entity types
#  |
#  |  params
#  |  ------
#  |  input_obj: the input object returned from Hint, required
#  |  output_obj: the class of entities as output, required
#  |      could be None, str, or a list of entity classes
#  |  intermediate_nodes: the semantic type(s) of the intermediate node
#  |      could be None, which represents any semantic type, or a list of semantic types
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, input_obj, output_obj, intermediate_nodes, registry=None)
#  |      params
#  |      ------
#  |      input_obj: the input object returned from Hint, required
#  |      output_obj: the class of entities as output, required
#  |          could be None, str, or a list of entity classes
#  |      intermediate_nodes: the semantic type(s) of the intermediate node
#  |          could be None, which represents any semantic type, or a list of semantic types
#  |
#  |  connect(self, verbose=False)
#  |
#  |  display_edge_info(self, start_node, end_node)
#  |      display detailed edge info between start node and end node
#  |
#  |      Params
#  |      ------
#  |      start_node: str, start node id
#  |      end_node: str, end node id
#  |
#  |  display_node_info(self, node)
#  |      show detailed node information
#  |
#  |      Params
#  |      ------
#  |      node: str, node id
#  |
#  |  display_table_view(self)
#  |      Display the query results as a pandas table
#  |
#  |      Examples
#  |      --------
#  |      >>> df = fc.display_table_view()
#  |      >>> df
#  |
#  |  show_all_edges(self)
#  |      show all edges in the graph
#  |
#  |  show_all_nodes(self)
#  |      show all nodes in the graph
#  |
#  |  show_path(self, remove_duplicate=True)
#  |
#  |  to_json(self)
#  |      convert the graph into JSON through networkx
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
fc = FindConnection(input_obj=asthma, output_obj=imatinib, intermediate_nodes=['Gene'])

# %%
# set verbose=True will display all steps which BTE takes to find the connection
fc.connect(verbose=True)
# Out:
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'asthma' and 'IMATINIB'. Paths will have 1 intermediate node.
#
# Intermediate node #1 will have these type constraints: Gene
#
#
# ==========
# ========== QUERY #1 -- fetch all Gene entities linked to 'asthma' ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because asthma is of type 'DiseaseOrPhenotypicFeature', BTE will query our meta-KG for APIs that can take 'DiseaseOrPhenotypicFeature' as input
#
# BTE found 3 apis:
#
# 1. biolink_disease2gene
# 2. semmeddisease
# 3. mydisease.info
#
#
# ==== Step #2: Query path execution ====
#
# 3-1. http://mydisease.info/v1/query (POST "q=C0004096&scopes=mondo.xrefs.umls,disgenet.xrefs.umls&fields=disgenet.genes_related_to_disease&species=human&size=100")
# 2-1. http://pending.biothings.io/semmed/query (POST "q=C0004096&scopes=umls&fields=AFFECTS_reverse.gene,AFFECTS_reverse.protein,AFFECTS.protein,CAUSES_reverse.gene,ASSOCIATED_WITH.gene,AFFECTS.gene&species=human&size=100")
# 1-1. https://api.monarchinitiative.org/api/bioentity/disease/MONDO:0004979/genes?rows=100
#
#
# ==== Step #3: Output normalization ====
#
# 1-1. biolink_disease2gene: 100 hits
# 3-1. mydisease.info: 99 hits
# 2-1. semmeddisease: 550 hits
#
# After id-to-object translation, BTE retrieved 567 unique objects.
#
#
# ==========
# ========== QUERY #2 -- fetch all bioentities linked to 'IMATINIB' ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because IMATINIB is of type 'ChemicalSubstance', BTE will query our meta-KG for APIs that can take 'ChemicalSubstance' as input
#
# BTE found 3 apis:
#
# 1. mychem.info
# 2. semmedgene
# 3. dgidb_chemical2gene
#
#
# ==== Step #2: Query path execution ====
#
# 1-2. http://mychem.info/v1/query (POST "q=DB00619&scopes=drugbank.id&fields=drugbank.targets,drugbank.enzymes&species=human&size=100")
# 1-1. http://mychem.info/v1/query (POST "q=CHEMBL941&scopes=chembl.molecule_chembl_id&fields=drugcentral.bioactivity&species=human&size=100")
# 2-4. https://pending.biothings.io/semmedgene/query (POST "q=C0935989&scopes=associated_with_reverse.chemical_substance.umls&fields=umls&species=human&size=100")
# 3-1. http://www.dgidb.org/api/v2/interactions.json?drugs=CHEMBL941
# 2-6. https://pending.biothings.io/semmedgene/query (POST "q=C0935989&scopes=interacts_with_reverse.chemical_substance.umls&fields=umls&species=human&size=100")
# 2-1. https://pending.biothings.io/semmedgene/query (POST "q=C0935989&scopes=affects.chemical_substance.umls&fields=umls&species=human&size=100")
# 2-3. https://pending.biothings.io/semmedgene/query (POST "q=C0935989&scopes=associated_with.chemical_substance.umls&fields=umls&species=human&size=100")
# 2-2. https://pending.biothings.io/semmedgene/query (POST "q=C0935989&scopes=affects_reverse.chemical_substance.umls&fields=umls&species=human&size=100")
# 2-5. https://pending.biothings.io/semmedgene/query (POST "q=C0935989&scopes=interacts_with.chemical_substance.umls&fields=umls&species=human&size=100")
#
#
# ==== Step #3: Output normalization ====
#
# 3-1. dgidb_chemical2gene: 34 hits
# 1-1. mychem.info: 77 hits
# 1-2. mychem.info: 18 hits
# 2-1. semmedgene: No hits
# 2-2. semmedgene: No hits
# 2-3. semmedgene: No hits
# 2-4. semmedgene: No hits
# 2-5. semmedgene: 100 hits
# 2-6. semmedgene: 100 hits
#
# After id-to-object translation, BTE retrieved 245 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# BTE found 34 unique intermediate nodes connecting 'asthma' and 'IMATINIB'

# %% [markdown]
# ## Step 3: Display and Filter results

# %%
df = fc.display_table_view()

# %%
df
# Out:
#      input                  input_type           pred1 pred1_source  \
# 0   asthma  DiseaseOrPhenotypicFeature  associatedWith     disgenet
# 1   asthma  DiseaseOrPhenotypicFeature  associatedWith     disgenet
# 2   asthma  DiseaseOrPhenotypicFeature  associatedWith       semmed
# 3   asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 4   asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 5   asthma  DiseaseOrPhenotypicFeature  associatedWith       semmed
# 6   asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 7   asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 8   asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 9   asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 10  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 11  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 12  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 13  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 14  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 15  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 16  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 17  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 18  asthma  DiseaseOrPhenotypicFeature  associatedWith       semmed
# 19  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 20  asthma  DiseaseOrPhenotypicFeature  associatedWith       semmed
# 21  asthma  DiseaseOrPhenotypicFeature  associatedWith       semmed
# 22  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 23  asthma  DiseaseOrPhenotypicFeature  associatedWith       semmed
# 24  asthma  DiseaseOrPhenotypicFeature  associatedWith       semmed
# 25  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 26  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 27  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 28  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 29  asthma  DiseaseOrPhenotypicFeature  associatedWith       semmed
# 30  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 31  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 32  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 33  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 34  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 35  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 36  asthma  DiseaseOrPhenotypicFeature  associatedWith       semmed
# 37  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 38  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 39  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 40  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 41  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 42  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 43  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 44  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 45  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 46  asthma  DiseaseOrPhenotypicFeature  associatedWith       semmed
# 47  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 48  asthma  DiseaseOrPhenotypicFeature  associatedWith       semmed
# 49  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 50  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 51  asthma  DiseaseOrPhenotypicFeature  associatedWith       semmed
# 52  asthma  DiseaseOrPhenotypicFeature  associatedWith       semmed
# 53  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 54  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
# 55  asthma  DiseaseOrPhenotypicFeature  associatedWith      biolink
# 56  asthma  DiseaseOrPhenotypicFeature  associatedWith      biolink
# 57  asthma  DiseaseOrPhenotypicFeature  associatedWith     disgenet
# 58  asthma  DiseaseOrPhenotypicFeature  associatedWith       semmed
# 59  asthma  DiseaseOrPhenotypicFeature        causedBy       semmed
#
#                pred1_api                                       pred1_pubmed  \
# 0         mydisease.info                                               None
# 1         mydisease.info                                               None
# 2          semmeddisease                                   1323298,25862459
# 3          semmeddisease        15660518,22387292,9120022,19533439,17950015
# 4          semmeddisease                                           20523070
# 5          semmeddisease                                            1721608
# 6          semmeddisease                                            6459694
# 7          semmeddisease                                           20528593
# 8          semmeddisease                                           20528593
# 9          semmeddisease                                           21270400
# 10         semmeddisease                                           21270400
# 11         semmeddisease                                           18683785
# 12         semmeddisease                                           18683785
# 13         semmeddisease                                           18683785
# 14         semmeddisease                                           22452921
# 15         semmeddisease                          14968124,21170080,9847290
# 16         semmeddisease                                            9847290
# 17         semmeddisease                          1882540,12777405,12777405
# 18         semmeddisease                                  21189606,21189606
# 19         semmeddisease                                           25113532
# 20         semmeddisease                11224726,11836685,16931638,18558635
# 21         semmeddisease                                           27442134
# 22         semmeddisease                                  19232703,20523070
# 23         semmeddisease                                           16322752
# 24         semmeddisease                                           16322752
# 25         semmeddisease                                           18480254
# 26         semmeddisease                                           18480254
# 27         semmeddisease                                           16804324
# 28         semmeddisease                                           16804324
# 29         semmeddisease                                           23307299
# 30         semmeddisease                                           17619555
# 31         semmeddisease                                  14630618,14630618
# 32         semmeddisease                                  14630618,14630618
# 33         semmeddisease                                  14630618,14630618
# 34         semmeddisease                                  14630618,14630618
# 35         semmeddisease                                           19155479
# 36         semmeddisease                                           23307299
# 37         semmeddisease                                           17619555
# 38         semmeddisease  18514752,9309799,17572010,24937476,17572010,16...
# 39         semmeddisease                                           20528593
# 40         semmeddisease                                           20528593
# 41         semmeddisease                                           20528593
# 42         semmeddisease                                           22452921
# 43         semmeddisease                                           19232703
# 44         semmeddisease                                           11943720
# 45         semmeddisease                                           11943720
# 46         semmeddisease                                           27442134
# 47         semmeddisease                                           19232703
# 48         semmeddisease  10957684,11665340,15715950,15744455,16217591,1...
# 49         semmeddisease  8711779,9351591,16088626,12225254,11665340,175...
# 50         semmeddisease                                           21646800
# 51         semmeddisease                                           20880147
# 52         semmeddisease                                           20880147
# 53         semmeddisease                                           19246655
# 54         semmeddisease                                           19246655
# 55  biolink_disease2gene  27182965,29273806,24388013,29785011,20860503,3...
# 56  biolink_disease2gene                                  31036433,30929738
# 57        mydisease.info                                               None
# 58         semmeddisease                27453339,25862459,22900522,19787077
# 59         semmeddisease  12324676,12324676,12324676,12373263,12373263,1...
#
#          node1_id node1_name node1_type                     pred2  \
# 0     entrez:1080       CFTR       Gene  molecularlyInteractsWith
# 1     entrez:7124        TNF       Gene  molecularlyInteractsWith
# 2     entrez:7124        TNF       Gene  molecularlyInteractsWith
# 3     entrez:7124        TNF       Gene  molecularlyInteractsWith
# 4   umls:C3540585       None       Gene  molecularlyInteractsWith
# 5   umls:C1706005       None       Gene  molecularlyInteractsWith
# 6   umls:C1706005       None       Gene  molecularlyInteractsWith
# 7   umls:C1704799       None       Gene  molecularlyInteractsWith
# 8   umls:C1704799       None       Gene  molecularlyInteractsWith
# 9    entrez:10899        JTB       Gene  molecularlyInteractsWith
# 10   entrez:10899        JTB       Gene  molecularlyInteractsWith
# 11    entrez:3932        LCK       Gene                    target
# 12    entrez:3932        LCK       Gene  molecularlyInteractsWith
# 13    entrez:3932        LCK       Gene  molecularlyInteractsWith
# 14  umls:C1367471       None       Gene  molecularlyInteractsWith
# 15    entrez:7076      TIMP1       Gene  molecularlyInteractsWith
# 16    entrez:7076      TIMP1       Gene  molecularlyInteractsWith
# 17     entrez:760        CA2       Gene                    target
# 18  umls:C0538674       None       Gene  molecularlyInteractsWith
# 19    entrez:6850        SYK       Gene                    target
# 20  umls:C1335671       None       Gene  molecularlyInteractsWith
# 21  umls:C1705325       None       Gene  molecularlyInteractsWith
# 22  umls:C1705325       None       Gene  molecularlyInteractsWith
# 23  umls:C0031727       None       Gene  molecularlyInteractsWith
# 24  umls:C0031727       None       Gene  molecularlyInteractsWith
# 25     entrez:146     ADRA1D       Gene  molecularlyInteractsWith
# 26     entrez:146     ADRA1D       Gene  molecularlyInteractsWith
# 27    entrez:5154      PDGFA       Gene  molecularlyInteractsWith
# 28    entrez:5154      PDGFA       Gene  molecularlyInteractsWith
# 29  entrez:373156      GSTK1       Gene  molecularlyInteractsWith
# 30  entrez:373156      GSTK1       Gene  molecularlyInteractsWith
# 31     entrez:947       CD34       Gene  molecularlyInteractsWith
# 32     entrez:947       CD34       Gene  molecularlyInteractsWith
# 33     entrez:947       CD34       Gene  molecularlyInteractsWith
# 34     entrez:947       CD34       Gene  molecularlyInteractsWith
# 35    entrez:5805        PTS       Gene  molecularlyInteractsWith
# 36  entrez:133482    SLCO6A1       Gene  molecularlyInteractsWith
# 37  entrez:133482    SLCO6A1       Gene  molecularlyInteractsWith
# 38    entrez:3439      IFNA1       Gene  molecularlyInteractsWith
# 39     entrez:613        BCR       Gene                    target
# 40     entrez:613        BCR       Gene  molecularlyInteractsWith
# 41     entrez:613        BCR       Gene  molecularlyInteractsWith
# 42  umls:C1706438       None       Gene  molecularlyInteractsWith
# 43    entrez:5290     PIK3CA       Gene  molecularlyInteractsWith
# 44    entrez:7852      CXCR4       Gene  molecularlyInteractsWith
# 45    entrez:7852      CXCR4       Gene  molecularlyInteractsWith
# 46  umls:C3714973       None       Gene  molecularlyInteractsWith
# 47  umls:C3714973       None       Gene  molecularlyInteractsWith
# 48  umls:C0017337       None       Gene  molecularlyInteractsWith
# 49  umls:C0017337       None       Gene  molecularlyInteractsWith
# 50  umls:C3889436       None       Gene  molecularlyInteractsWith
# 51  umls:C1705556       None       Gene  molecularlyInteractsWith
# 52  umls:C1705556       None       Gene  molecularlyInteractsWith
# 53  umls:C1705556       None       Gene  molecularlyInteractsWith
# 54  umls:C1705556       None       Gene  molecularlyInteractsWith
# 55    entrez:4088      SMAD3       Gene  molecularlyInteractsWith
# 56    entrez:4088      SMAD3       Gene  molecularlyInteractsWith
# 57    entrez:7422      VEGFA       Gene  molecularlyInteractsWith
# 58    entrez:7422      VEGFA       Gene  molecularlyInteractsWith
# 59    entrez:7422      VEGFA       Gene  molecularlyInteractsWith
#
#    pred2_source            pred2_api pred2_pubmed    output        output_type
# 0    semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 1    semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 2    semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 3    semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 4    semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 5    semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 6    semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 7    semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 8    semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 9    semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 10   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 11  drugcentral          mychem.info         None  IMATINIB  ChemicalSubstance
# 12   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 13   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 14   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 15   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 16   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 17  drugcentral          mychem.info         None  IMATINIB  ChemicalSubstance
# 18   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 19  drugcentral          mychem.info         None  IMATINIB  ChemicalSubstance
# 20   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 21   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 22   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 23   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 24   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 25   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 26   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 27   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 28   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 29   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 30   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 31   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 32   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 33   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 34   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 35   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 36   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 37   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 38   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 39        dgidb  dgidb_chemical2gene         None  IMATINIB  ChemicalSubstance
# 40   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 41   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 42   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 43   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 44   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 45   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 46   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 47   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 48   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 49   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 50   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 51   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 52   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 53   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 54   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 55   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 56   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 57   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 58   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance
# 59   semmedgene           semmedgene         None  IMATINIB  ChemicalSubstance

# %% [markdown]
# ### Filter by the predicate of the first query

# %%
df[df['pred1'] == 'causedBy']
# Out:
#      input                  input_type     pred1 pred1_source      pred1_api  \
# 3   asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 4   asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 6   asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 7   asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 8   asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 9   asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 10  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 11  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 12  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 13  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 14  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 15  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 16  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 17  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 19  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 22  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 25  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 26  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 27  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 28  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 30  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 31  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 32  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 33  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 34  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 35  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 37  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 38  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 39  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 40  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 41  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 42  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 43  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 44  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 45  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 47  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 49  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 50  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 53  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 54  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 59  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
#
#                                          pred1_pubmed       node1_id  \
# 3         15660518,22387292,9120022,19533439,17950015    entrez:7124
# 4                                            20523070  umls:C3540585
# 6                                             6459694  umls:C1706005
# 7                                            20528593  umls:C1704799
# 8                                            20528593  umls:C1704799
# 9                                            21270400   entrez:10899
# 10                                           21270400   entrez:10899
# 11                                           18683785    entrez:3932
# 12                                           18683785    entrez:3932
# 13                                           18683785    entrez:3932
# 14                                           22452921  umls:C1367471
# 15                          14968124,21170080,9847290    entrez:7076
# 16                                            9847290    entrez:7076
# 17                          1882540,12777405,12777405     entrez:760
# 19                                           25113532    entrez:6850
# 22                                  19232703,20523070  umls:C1705325
# 25                                           18480254     entrez:146
# 26                                           18480254     entrez:146
# 27                                           16804324    entrez:5154
# 28                                           16804324    entrez:5154
# 30                                           17619555  entrez:373156
# 31                                  14630618,14630618     entrez:947
# 32                                  14630618,14630618     entrez:947
# 33                                  14630618,14630618     entrez:947
# 34                                  14630618,14630618     entrez:947
# 35                                           19155479    entrez:5805
# 37                                           17619555  entrez:133482
# 38  18514752,9309799,17572010,24937476,17572010,16...    entrez:3439
# 39                                           20528593     entrez:613
# 40                                           20528593     entrez:613
# 41                                           20528593     entrez:613
# 42                                           22452921  umls:C1706438
# 43                                           19232703    entrez:5290
# 44                                           11943720    entrez:7852
# 45                                           11943720    entrez:7852
# 47                                           19232703  umls:C3714973
# 49  8711779,9351591,16088626,12225254,11665340,175...  umls:C0017337
# 50                                           21646800  umls:C3889436
# 53                                           19246655  umls:C1705556
# 54                                           19246655  umls:C1705556
# 59  12324676,12324676,12324676,12373263,12373263,1...    entrez:7422
#
#    node1_name node1_type                     pred2 pred2_source  \
# 3         TNF       Gene  molecularlyInteractsWith   semmedgene
# 4        None       Gene  molecularlyInteractsWith   semmedgene
# 6        None       Gene  molecularlyInteractsWith   semmedgene
# 7        None       Gene  molecularlyInteractsWith   semmedgene
# 8        None       Gene  molecularlyInteractsWith   semmedgene
# 9         JTB       Gene  molecularlyInteractsWith   semmedgene
# 10        JTB       Gene  molecularlyInteractsWith   semmedgene
# 11        LCK       Gene                    target  drugcentral
# 12        LCK       Gene  molecularlyInteractsWith   semmedgene
# 13        LCK       Gene  molecularlyInteractsWith   semmedgene
# 14       None       Gene  molecularlyInteractsWith   semmedgene
# 15      TIMP1       Gene  molecularlyInteractsWith   semmedgene
# 16      TIMP1       Gene  molecularlyInteractsWith   semmedgene
# 17        CA2       Gene                    target  drugcentral
# 19        SYK       Gene                    target  drugcentral
# 22       None       Gene  molecularlyInteractsWith   semmedgene
# 25     ADRA1D       Gene  molecularlyInteractsWith   semmedgene
# 26     ADRA1D       Gene  molecularlyInteractsWith   semmedgene
# 27      PDGFA       Gene  molecularlyInteractsWith   semmedgene
# 28      PDGFA       Gene  molecularlyInteractsWith   semmedgene
# 30      GSTK1       Gene  molecularlyInteractsWith   semmedgene
# 31       CD34       Gene  molecularlyInteractsWith   semmedgene
# 32       CD34       Gene  molecularlyInteractsWith   semmedgene
# 33       CD34       Gene  molecularlyInteractsWith   semmedgene
# 34       CD34       Gene  molecularlyInteractsWith   semmedgene
# 35        PTS       Gene  molecularlyInteractsWith   semmedgene
# 37    SLCO6A1       Gene  molecularlyInteractsWith   semmedgene
# 38      IFNA1       Gene  molecularlyInteractsWith   semmedgene
# 39        BCR       Gene                    target        dgidb
# 40        BCR       Gene  molecularlyInteractsWith   semmedgene
# 41        BCR       Gene  molecularlyInteractsWith   semmedgene
# 42       None       Gene  molecularlyInteractsWith   semmedgene
# 43     PIK3CA       Gene  molecularlyInteractsWith   semmedgene
# 44      CXCR4       Gene  molecularlyInteractsWith   semmedgene
# 45      CXCR4       Gene  molecularlyInteractsWith   semmedgene
# 47       None       Gene  molecularlyInteractsWith   semmedgene
# 49       None       Gene  molecularlyInteractsWith   semmedgene
# 50       None       Gene  molecularlyInteractsWith   semmedgene
# 53       None       Gene  molecularlyInteractsWith   semmedgene
# 54       None       Gene  molecularlyInteractsWith   semmedgene
# 59      VEGFA       Gene  molecularlyInteractsWith   semmedgene
#
#               pred2_api pred2_pubmed    output        output_type
# 3            semmedgene         None  IMATINIB  ChemicalSubstance
# 4            semmedgene         None  IMATINIB  ChemicalSubstance
# 6            semmedgene         None  IMATINIB  ChemicalSubstance
# 7            semmedgene         None  IMATINIB  ChemicalSubstance
# 8            semmedgene         None  IMATINIB  ChemicalSubstance
# 9            semmedgene         None  IMATINIB  ChemicalSubstance
# 10           semmedgene         None  IMATINIB  ChemicalSubstance
# 11          mychem.info         None  IMATINIB  ChemicalSubstance
# 12           semmedgene         None  IMATINIB  ChemicalSubstance
# 13           semmedgene         None  IMATINIB  ChemicalSubstance
# 14           semmedgene         None  IMATINIB  ChemicalSubstance
# 15           semmedgene         None  IMATINIB  ChemicalSubstance
# 16           semmedgene         None  IMATINIB  ChemicalSubstance
# 17          mychem.info         None  IMATINIB  ChemicalSubstance
# 19          mychem.info         None  IMATINIB  ChemicalSubstance
# 22           semmedgene         None  IMATINIB  ChemicalSubstance
# 25           semmedgene         None  IMATINIB  ChemicalSubstance
# 26           semmedgene         None  IMATINIB  ChemicalSubstance
# 27           semmedgene         None  IMATINIB  ChemicalSubstance
# 28           semmedgene         None  IMATINIB  ChemicalSubstance
# 30           semmedgene         None  IMATINIB  ChemicalSubstance
# 31           semmedgene         None  IMATINIB  ChemicalSubstance
# 32           semmedgene         None  IMATINIB  ChemicalSubstance
# 33           semmedgene         None  IMATINIB  ChemicalSubstance
# 34           semmedgene         None  IMATINIB  ChemicalSubstance
# 35           semmedgene         None  IMATINIB  ChemicalSubstance
# 37           semmedgene         None  IMATINIB  ChemicalSubstance
# 38           semmedgene         None  IMATINIB  ChemicalSubstance
# 39  dgidb_chemical2gene         None  IMATINIB  ChemicalSubstance
# 40           semmedgene         None  IMATINIB  ChemicalSubstance
# 41           semmedgene         None  IMATINIB  ChemicalSubstance
# 42           semmedgene         None  IMATINIB  ChemicalSubstance
# 43           semmedgene         None  IMATINIB  ChemicalSubstance
# 44           semmedgene         None  IMATINIB  ChemicalSubstance
# 45           semmedgene         None  IMATINIB  ChemicalSubstance
# 47           semmedgene         None  IMATINIB  ChemicalSubstance
# 49           semmedgene         None  IMATINIB  ChemicalSubstance
# 50           semmedgene         None  IMATINIB  ChemicalSubstance
# 53           semmedgene         None  IMATINIB  ChemicalSubstance
# 54           semmedgene         None  IMATINIB  ChemicalSubstance
# 59           semmedgene         None  IMATINIB  ChemicalSubstance

# %% [markdown]
# ### Filter by the predicate of the second query

# %%
df[df['pred2'] == 'target']
# Out:
#      input                  input_type     pred1 pred1_source      pred1_api  \
# 11  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 17  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 19  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
# 39  asthma  DiseaseOrPhenotypicFeature  causedBy       semmed  semmeddisease
#
#                  pred1_pubmed     node1_id node1_name node1_type   pred2  \
# 11                   18683785  entrez:3932        LCK       Gene  target
# 17  1882540,12777405,12777405   entrez:760        CA2       Gene  target
# 19                   25113532  entrez:6850        SYK       Gene  target
# 39                   20528593   entrez:613        BCR       Gene  target
#
#    pred2_source            pred2_api pred2_pubmed    output        output_type
# 11  drugcentral          mychem.info         None  IMATINIB  ChemicalSubstance
# 17  drugcentral          mychem.info         None  IMATINIB  ChemicalSubstance
# 19  drugcentral          mychem.info         None  IMATINIB  ChemicalSubstance
# 39        dgidb  dgidb_chemical2gene         None  IMATINIB  ChemicalSubstance

# %% [markdown]
# ### Check the detailed infomation regarding a specific edge

# %%
fc.display_edge_info('LCK', 'IMATINIB')
# Out:
# {0: {'info': {'bts:name': ['Tyrosine-protein kinase Lck'],
#    'bts:symbol': ['LCK'],
#    '@type': 'Gene',
#    '$input': 'bts:chembl',
#    '$source': 'drugcentral',
#    '$api': 'mychem.info'},
#   'label': 'bts:target',
#   'source': 'drugcentral'},
#  1: {'info': {'@type': 'Gene',
#    'bts:umls': ['C0919477'],
#    '$source': 'semmedgene',
#    '$api': 'semmedgene'},
#   'label': 'bts:molecularlyInteractsWith',
#   'source': 'semmedgene'},
#  2: {'info': {'@type': 'Gene',
#    'bts:umls': ['C0919477'],
#    '$source': 'semmedgene',
#    '$api': 'semmedgene'},
#   'label': 'bts:molecularlyInteractsWith',
#   'source': 'semmedgene'}}
